# %%
import torch
from torch import nn
import torchvision
import torchvision.transforms as transforms
from torch.nn import functional as F
from d2l import torch as d2l
import numpy as np
import pandas as pd
from ptflops import get_model_complexity_info
from pathlib import Path
import subprocess
import os
import time
import functools

# %%
torch.cuda.reset_peak_memory_stats()
torch.cuda.empty_cache()

# %% [markdown]
# ### Model

# %%
class Inception_mod5(nn.Module):
    # c1--c4是每条路径的输出通道数
    def __init__(self, in_channels, c3, **kwargs):
        super(Inception_mod5, self).__init__(**kwargs)
        # 线路1，单1x1卷积层
        # self.p1_1 = nn.Conv2d(in_channels, c1, kernel_size=1)
        # 线路2，1x1卷积层后接3x3卷积层
        # self.p2_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        # self.p2_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
        # 线路3，1x1卷积层后接5x5卷积层
        self.p3_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        self.p3_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 线路4，3x3最大汇聚层后接1x1卷积层
        # self.p4_1 = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        # self.p4_2 = nn.Conv2d(in_channels, c4, kernel_size=1)

    def forward(self, x):
        # p1 = F.relu(self.p1_1(x))
        # p2 = F.relu(self.p2_2(F.relu(self.p2_1(x))))
        p3 = F.relu(self.p3_2(F.relu(self.p3_1(x))))
        # p4 = F.relu(self.p4_2(self.p4_1(x)))
        # 在通道维度上连结输出
        return torch.cat([p3], dim=1)
    
def Googlenet_mod5(img_channel, num_labels):
    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b2 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=1),
                   nn.ReLU(),
                   nn.Conv2d(64, 192, kernel_size=3, padding=1),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b3 = nn.Sequential(Inception_mod5(192, (16, 32)),
                   Inception_mod5(32, (32, 96)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b4 = nn.Sequential(Inception_mod5(96, (16, 48)),
                   Inception_mod5(48,(24, 64)),
                   Inception_mod5(64, (24, 64)),
                   Inception_mod5(64, (32, 64)),
                   Inception_mod5(64, (32, 128)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b5 = nn.Sequential(Inception_mod5(128, (32, 128)),
                   Inception_mod5(128, (48, 128)),
                   nn.AdaptiveAvgPool2d((1,1)),
                   nn.Flatten())

    net = nn.Sequential(b1, b2, b3, b4, b5, nn.Linear(128, num_labels))
    return net

# %%
class Inception_mod6(nn.Module):
    # c1--c4是每条路径的输出通道数
    def __init__(self, in_channels, c3, **kwargs):
        super(Inception_mod6, self).__init__(**kwargs)
        # 线路1，单1x1卷积层
        # self.p1_1 = nn.Conv2d(in_channels, c1, kernel_size=1)
        # 线路2，1x1卷积层后接3x3卷积层
        self.p2_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        self.p2_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 线路3，1x1卷积层后接5x5卷积层
        self.p3_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        self.p3_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 线路4，3x3最大汇聚层后接1x1卷积层
        # self.p4_1 = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        # self.p4_2 = nn.Conv2d(in_channels, c4, kernel_size=1)

    def forward(self, x):
        # p1 = F.relu(self.p1_1(x))
        # p2 = F.relu(self.p2_1(x))
        p2 = F.relu(self.p2_2(F.relu(self.p2_1(x))))
        p3 = F.relu(self.p3_2(F.relu(self.p3_1(x))))
        # p4 = F.relu(self.p4_2(self.p4_1(x)))
        # 在通道维度上连结输出
        return torch.cat((p2, p3), dim=1)
    
def Googlenet_mod6(img_channel, num_labels):
    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b2 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=1),
                   nn.ReLU(),
                   nn.Conv2d(64, 192, kernel_size=3, padding=1),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b3 = nn.Sequential(Inception_mod6(192, (16, 32)),
                   Inception_mod6(64, (32, 96)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b4 = nn.Sequential(Inception_mod6(96*2, (16, 48)),
                   Inception_mod6(48*2, (24, 64)),
                   Inception_mod6(64*2, (24, 64)),
                   Inception_mod6(64*2, (32, 64)),
                   Inception_mod6(64*2, (32, 128)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b5 = nn.Sequential(Inception_mod6(128*2, (32, 128)),
                   Inception_mod6(128*2, (48, 128)),
                   nn.AdaptiveAvgPool2d((1,1)),
                   nn.Flatten())

    net = nn.Sequential(b1, b2, b3, b4, b5, nn.Linear(128*2, num_labels))
    return net

# %%
class Inception_mod7(nn.Module):
    # c1--c4是每条路径的输出通道数
    def __init__(self, in_channels, c3, **kwargs):
        super(Inception_mod7, self).__init__(**kwargs)
        # 线路1，单1x1卷积层
        self.p1_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        self.p1_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 线路2，1x1卷积层后接3x3卷积层
        self.p2_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        self.p2_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 线路3，1x1卷积层后接5x5卷积层
        self.p3_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        self.p3_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 线路4，3x3最大汇聚层后接1x1卷积层
        # self.p4_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        # self.p4_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)

    def forward(self, x):
        # p1 = F.relu(self.p1_1(x))
        # p2 = F.relu(self.p2_1(x))
        # p3 = F.relu(self.p3_1(x))
        p1 = F.relu(self.p1_2(F.relu(self.p1_1(x))))
        p2 = F.relu(self.p2_2(F.relu(self.p2_1(x))))
        p3 = F.relu(self.p3_2(F.relu(self.p3_1(x))))
        # p4 = F.relu(self.p4_2(F.relu(self.p4_1(x))))
        # 在通道维度上连结输出
        return torch.cat((p1,p2, p3), dim=1)
    
def Googlenet_mod7(img_channel, num_labels):
    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b2 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=1),
                   nn.ReLU(),
                   nn.Conv2d(64, 192, kernel_size=3, padding=1),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b3 = nn.Sequential(Inception_mod7(192, (16, 32)),
                   Inception_mod7(32*3, (32, 96)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b4 = nn.Sequential(Inception_mod7(96*3, (16, 48)),
                   Inception_mod7(48*3, (24, 64)),
                   Inception_mod7(64*3, (24, 64)),
                   Inception_mod7(64*3, (32, 64)),
                   Inception_mod7(64*3, (32, 128)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b5 = nn.Sequential(Inception_mod7(128*3, (32, 128)),
                   Inception_mod7(128*3, (48, 128)),
                   nn.AdaptiveAvgPool2d((1,1)),
                   nn.Flatten())

    net = nn.Sequential(b1, b2, b3, b4, b5, nn.Linear(128*3, num_labels))
    return net

# %%
class Inception_mod8(nn.Module):
    # c1--c4是每条路径的输出通道数
    def __init__(self, in_channels, c3, **kwargs):
        super(Inception_mod8, self).__init__(**kwargs)
        # 线路3，1x1卷积层后接5x5卷积层
        self.p1_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        self.p1_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 线路3，1x1卷积层后接5x5卷积层
        self.p2_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        self.p2_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 线路3，1x1卷积层后接5x5卷积层
        self.p3_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        self.p3_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 线路3，1x1卷积层后接5x5卷积层
        self.p4_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        self.p4_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)

    def forward(self, x):
        p1 = F.relu(self.p1_2(F.relu(self.p1_1(x))))
        p2 = F.relu(self.p2_2(F.relu(self.p2_1(x))))
        p3 = F.relu(self.p3_2(F.relu(self.p3_1(x))))
        p4 = F.relu(self.p4_2(F.relu(self.p4_1(x))))
        # 在通道维度上连结输出
        return torch.cat((p1, p2, p3, p4), dim=1)
    
def Googlenet_mod8(img_channel, num_labels):
    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b2 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=1),
                   nn.ReLU(),
                   nn.Conv2d(64, 192, kernel_size=3, padding=1),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b3 = nn.Sequential(Inception_mod8(192, (16, 32)),
                   Inception_mod8(32*4, (32, 96)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b4 = nn.Sequential(Inception_mod8(96*4, (16, 48)),
                   Inception_mod8(48*4, (24, 64)),
                   Inception_mod8(64*4, (24, 64)),
                   Inception_mod8(64*4, (32, 64)),
                   Inception_mod8(64*4, (32, 128)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b5 = nn.Sequential(Inception_mod8(128*4, (32, 128)),
                   Inception_mod8(128*4, (48, 128)),
                   nn.AdaptiveAvgPool2d((1,1)),
                   nn.Flatten())

    net = nn.Sequential(b1, b2, b3, b4, b5, nn.Linear(128*4, num_labels))
    return net

# %%
# class Inception_mod8(nn.Module):
#     # c1--c4是每条路径的输出通道数
#     def __init__(self, in_channels, c2, **kwargs):
#         super(Inception_mod8, self).__init__(**kwargs)
#         # 线路1，单1x1卷积层
#         self.p1_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
#         self.p1_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
#         # 线路2，1x1卷积层后接3x3卷积层
#         self.p2_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
#         self.p2_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
#         # 线路3，1x1卷积层后接5x5卷积层
#         self.p3_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
#         self.p3_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
#         # 线路4，3x3最大汇聚层后接1x1卷积层
#         self.p4_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
#         self.p4_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)

#     def forward(self, x):
#         p1 = F.relu(self.p1_2(F.relu(self.p1_1(x))))
#         p2 = F.relu(self.p2_2(F.relu(self.p2_1(x))))
#         p3 = F.relu(self.p3_2(F.relu(self.p3_1(x))))
#         p4 = F.relu(self.p4_2(F.relu(self.p4_1(x))))
#         # 在通道维度上连结输出
#         return torch.cat((p1, p2, p3, p4), dim=1)
    
def Googlenet_mod9(img_channel, num_labels):
    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b2 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=1),
                   nn.ReLU(),
                   nn.Conv2d(64, 192, kernel_size=3, padding=1),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    # b3 = nn.Sequential(Inception_mod8(192, (96, 128)),
    #                Inception_mod8(128*4, (128, 192)),
    #                nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    # b4 = nn.Sequential(Inception_mod8(192*4, (96, 208)),
    #                Inception_mod8(208*4, (112, 224)),
    #                Inception_mod8(224*4, (128, 256)),
    #                Inception_mod8(256*4, (144, 288)),
    #                Inception_mod8(288*4, (160, 320)),
    #                nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    # b5 = nn.Sequential(Inception_mod8(320*4, (160, 320)),
    #                Inception_mod8(320*4, (192, 384)),
    #                nn.AdaptiveAvgPool2d((1,1)),
    #                nn.Flatten())
    
    b5 = nn.Sequential(
                   nn.AdaptiveAvgPool2d((1,1)),
                   nn.Flatten())

    net = nn.Sequential(b1, b2, b5, nn.Linear(192, num_labels))
    return net

# %%
# net = Googlenet_mod5(1, 10) 
# net = Googlenet_mod6(1, 10) 
# net = Googlenet_mod7(1, 10) 
# net = Googlenet_mod8(1, 10) 
net = Googlenet_mod9(1, 10) 
LayerName = []
block_num = 0
incep_num = 0

for num, layer in net.named_children():  # 使用 named_children 来获取层名和层
    layername = layer.__class__.__name__
    print(f"{num}: {layername}")  # 打印层名和层类名
    
    if layer.__class__.__name__ == 'Sequential':
        block_num += 1
        for sublayernum, sublayer in layer.named_children():  # 再次使用 named_children
            sublayername = sublayer.__class__.__name__
            if sublayername == 'Inception_mod5':
                incep_num += 1
            print(f"  {sublayernum}: {sublayername}")
            layer_label = f'{layername[0]}{num}_{sublayername[0]}{sublayernum}'
            LayerName.append(layer_label)  # 收集子块的类型
                        
print('The layer name is:', LayerName)
print(f'The length of layer name is: {len(LayerName)}')
print('The number of blocks is:', block_num)
print('The number of inception blocks is:', incep_num)
# Out:
# 0: Sequential
#   0: Conv2d
#   1: ReLU
#   2: MaxPool2d
# 1: Sequential
#   0: Conv2d
#   1: ReLU
#   2: Conv2d
#   3: ReLU
#   4: MaxPool2d
# 2: Sequential
#   0: AdaptiveAvgPool2d
#   1: Flatten
# 3: Linear
# The layer name is: ['S0_C0', 'S0_R1', 'S0_M2', 'S1_C0', 'S1_R1', 'S1_C2', 'S1_R3', 'S1_M4', 'S2_A0', 'S2_F1']
# The length of layer name is: 10
# The number of blocks is: 3
# The number of inception blocks is: 0

# %% [markdown]
# build different alexnet model for different datasets

# %%
# 对于不同的数据集，要设置不同的img_channel和num_labels
# Fashion-MNIST中的图像通道数为1，类别数为10
googlenet_fmod5 = Googlenet_mod5(1, 10)
googlenet_fmod6 = Googlenet_mod6(1, 10)
googlenet_fmod7 = Googlenet_mod7(1, 10)
googlenet_fmod8 = Googlenet_mod8(1, 10)
googlenet_fmod9 = Googlenet_mod9(1, 10)
# CIFAR100中的图像通道数为3，类别数为100
googlenet_cmod5 = Googlenet_mod5(3, 100)
googlenet_cmod6 = Googlenet_mod6(3, 100)
googlenet_cmod7 = Googlenet_mod7(3, 100)
googlenet_cmod8 = Googlenet_mod8(3, 100)
googlenet_cmod9 = Googlenet_mod9(3, 100)

# %%
# fashion mnist
print('The model complexity of googlenet_fmod5:')
with torch.cuda.device(0):
    macs_f, params_f = get_model_complexity_info(googlenet_fmod5, (1, 224, 224), as_strings=True,
                                            print_per_layer_stat=True, verbose=True)
    print('{:<30}  {:<8}'.format('Computational complexity: ', macs_f))
    print('{:<30}  {:<8}'.format('Number of parameters: ', params_f))

print('*'*50)
print('The model complexity of googlenet_fmod6:')
with torch.cuda.device(0):
    macs_f, params_f = get_model_complexity_info(googlenet_fmod6, (1, 224, 224), as_strings=True,
                                            print_per_layer_stat=True, verbose=True)
    print('{:<30}  {:<8}'.format('Computational complexity: ', macs_f))
    print('{:<30}  {:<8}'.format('Number of parameters: ', params_f))
    
print('*'*50)
print('The model complexity of googlenet_fmod7:')
with torch.cuda.device(0):
    macs_f, params_f = get_model_complexity_info(googlenet_fmod7, (1, 224, 224), as_strings=True,
                                            print_per_layer_stat=True, verbose=True)
    print('{:<30}  {:<8}'.format('Computational complexity: ', macs_f))
    print('{:<30}  {:<8}'.format('Number of parameters: ', params_f))
    
print('*'*50)
print('The model complexity of googlenet_fmod8:')
with torch.cuda.device(0):
    macs_f, params_f = get_model_complexity_info(googlenet_fmod8, (1, 224, 224), as_strings=True,
                                            print_per_layer_stat=True, verbose=True)
    print('{:<30}  {:<8}'.format('Computational complexity: ', macs_f))
    print('{:<30}  {:<8}'.format('Number of parameters: ', params_f))

print('*'*50)
print('The model complexity of googlenet_fmod9:')
with torch.cuda.device(0):
    macs_f, params_f = get_model_complexity_info(googlenet_fmod9, (1, 224, 224), as_strings=True,
                                            print_per_layer_stat=True, verbose=True)
    print('{:<30}  {:<8}'.format('Computational complexity: ', macs_f))
    print('{:<30}  {:<8}'.format('Number of parameters: ', params_f))

print('*'*200)
# cifar100
print('The model complexity of googlenet_cmod5:')
with torch.cuda.device(0):
    macs_c, params_c = get_model_complexity_info(googlenet_cmod5, (3, 224, 224), as_strings=True,
                                            print_per_layer_stat=True, verbose=True)
    print('{:<30}  {:<8}'.format('Computational complexity: ', macs_c))
    print('{:<30}  {:<8}'.format('Number of parameters: ', params_c))

print('*'*50)
print('The model complexity of googlenet_cmod6:')
with torch.cuda.device(0):
    macs_c, params_c = get_model_complexity_info(googlenet_cmod6, (3, 224, 224), as_strings=True,
                                            print_per_layer_stat=True, verbose=True)
    print('{:<30}  {:<8}'.format('Computational complexity: ', macs_c))
    print('{:<30}  {:<8}'.format('Number of parameters: ', params_c))
    
print('*'*50)
print('The model complexity of googlenet_cmod7:')
with torch.cuda.device(0):
    macs_c, params_c = get_model_complexity_info(googlenet_cmod7, (3, 224, 224), as_strings=True,
                                            print_per_layer_stat=True, verbose=True)
    print('{:<30}  {:<8}'.format('Computational complexity: ', macs_c))
    print('{:<30}  {:<8}'.format('Number of parameters: ', params_c))
    
print('*'*50)
print('The model complexity of googlenet_cmod8:')
with torch.cuda.device(0):
    macs_c, params_c = get_model_complexity_info(googlenet_cmod8, (3, 224, 224), as_strings=True,
                                            print_per_layer_stat=True, verbose=True)
    print('{:<30}  {:<8}'.format('Computational complexity: ', macs_c))
    print('{:<30}  {:<8}'.format('Number of parameters: ', params_c))
    
print('*'*50)
print('The model complexity of googlenet_cmod9:')
with torch.cuda.device(0):
    macs_c, params_c = get_model_complexity_info(googlenet_cmod9, (3, 224, 224), as_strings=True,
                                            print_per_layer_stat=True, verbose=True)
    print('{:<30}  {:<8}'.format('Computational complexity: ', macs_c))
    print('{:<30}  {:<8}'.format('Number of parameters: ', params_c))
# Out:
# The model complexity of googlenet_fmod5:
# Warning: module Inception_mod5 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   738.3 k, 100.000% Params, 541.03 MMac, 99.381% MACs,
#   (0): Sequential(
#     3.2 k, 0.433% Params, 41.75 MMac, 7.668% MACs,
#     (0): Conv2d(3.2 k, 0.433% Params, 40.14 MMac, 7.373% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.147% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.147% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 15.569% Params, 361.87 MMac, 66.471% MACs,
#     (0): Conv2d(4.16 k, 0.563% Params, 13.05 MMac, 2.396% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.037% MACs, )
#     (2): Conv2d(110.78 k, 15.005% Params, 347.42 MMac, 63.817% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.111% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.111% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     93.87 k, 12.715% Params, 73.67 MMac, 13.532% MACs,
#     (0): Inception_mod5(
#       15.92 k, 2.156% Params, 12.48 MMac, 2.293% MACs,
#       (p3_1): Conv2d(3.09 k, 0.418% Params, 2.42 MMac, 0.445% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 1.738% Params, 10.06 MMac, 1.848% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod5(
#       77.95 k, 10.558% Params, 61.11 MMac, 11.226% MACs,
#       (p3_1): Conv2d(1.06 k, 0.143% Params, 827.9 KMac, 0.152% MACs, 32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 10.415% Params, 60.29 MMac, 11.074% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 75.26 KMac, 0.014% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     258.42 k, 35.002% Params, 50.67 MMac, 9.308% MACs,
#     (0): Inception_mod5(
#       20.8 k, 2.817% Params, 4.08 MMac, 0.749% MACs,
#       (p3_1): Conv2d(1.55 k, 0.210% Params, 304.19 KMac, 0.056% MACs, 96, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 2.607% Params, 3.77 MMac, 0.693% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod5(
#       39.64 k, 5.369% Params, 7.77 MMac, 1.427% MACs,
#       (p3_1): Conv2d(1.18 k, 0.159% Params, 230.5 KMac, 0.042% MACs, 48, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 5.210% Params, 7.54 MMac, 1.385% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): Inception_mod5(
#       40.02 k, 5.421% Params, 7.84 MMac, 1.441% MACs,
#       (p3_1): Conv2d(1.56 k, 0.211% Params, 305.76 KMac, 0.056% MACs, 64, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 5.210% Params, 7.54 MMac, 1.385% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (3): Inception_mod5(
#       53.34 k, 7.225% Params, 10.46 MMac, 1.921% MACs,
#       (p3_1): Conv2d(2.08 k, 0.282% Params, 407.68 KMac, 0.075% MACs, 64, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 6.944% Params, 10.05 MMac, 1.846% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (4): Inception_mod5(
#       104.61 k, 14.169% Params, 20.5 MMac, 3.766% MACs,
#       (p3_1): Conv2d(2.08 k, 0.282% Params, 407.68 KMac, 0.075% MACs, 64, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 13.887% Params, 20.1 MMac, 3.691% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 25.09 KMac, 0.005% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     266.58 k, 36.107% Params, 13.07 MMac, 2.401% MACs,
#     (0): Inception_mod5(
#       106.66 k, 14.446% Params, 5.23 MMac, 0.960% MACs,
#       (p3_1): Conv2d(4.13 k, 0.559% Params, 202.27 KMac, 0.037% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 13.887% Params, 5.02 MMac, 0.923% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod5(
#       159.92 k, 21.661% Params, 7.84 MMac, 1.439% MACs,
#       (p3_1): Conv2d(6.19 k, 0.839% Params, 303.41 KMac, 0.056% MACs, 128, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 20.822% Params, 7.53 MMac, 1.384% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 6.27 KMac, 0.001% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(1.29 k, 0.175% Params, 1.29 KMac, 0.000% MACs, in_features=128, out_features=10, bias=True)
# )
# Computational complexity:       544.4 MMac
# Number of parameters:           738.3 k
# **************************************************
# The model complexity of googlenet_fmod6:
# Warning: module Inception_mod6 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   1.4 M, 100.000% Params, 684.32 MMac, 99.458% MACs,
#   (0): Sequential(
#     3.2 k, 0.229% Params, 41.75 MMac, 6.067% MACs,
#     (0): Conv2d(3.2 k, 0.229% Params, 40.14 MMac, 5.834% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.117% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.117% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 8.224% Params, 361.87 MMac, 52.594% MACs,
#     (0): Conv2d(4.16 k, 0.298% Params, 13.05 MMac, 1.896% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.029% MACs, )
#     (2): Conv2d(110.78 k, 7.927% Params, 347.42 MMac, 50.494% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.088% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.088% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     189.79 k, 13.580% Params, 148.95 MMac, 21.648% MACs,
#     (0): Inception_mod6(
#       31.84 k, 2.278% Params, 24.96 MMac, 3.628% MACs,
#       (p2_1): Conv2d(3.09 k, 0.221% Params, 2.42 MMac, 0.352% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(12.83 k, 0.918% Params, 10.06 MMac, 1.462% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(3.09 k, 0.221% Params, 2.42 MMac, 0.352% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.918% Params, 10.06 MMac, 1.462% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod6(
#       157.95 k, 11.302% Params, 123.83 MMac, 17.998% MACs,
#       (p2_1): Conv2d(2.08 k, 0.149% Params, 1.63 MMac, 0.237% MACs, 64, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(76.9 k, 5.502% Params, 60.29 MMac, 8.762% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(2.08 k, 0.149% Params, 1.63 MMac, 0.237% MACs, 64, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 5.502% Params, 60.29 MMac, 8.762% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.022% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     533.47 k, 38.170% Params, 104.61 MMac, 15.204% MACs,
#     (0): Inception_mod6(
#       44.67 k, 3.196% Params, 8.76 MMac, 1.273% MACs,
#       (p2_1): Conv2d(3.09 k, 0.221% Params, 605.25 KMac, 0.088% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(19.25 k, 1.377% Params, 3.77 MMac, 0.548% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(3.09 k, 0.221% Params, 605.25 KMac, 0.088% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 1.377% Params, 3.77 MMac, 0.548% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod6(
#       81.58 k, 5.837% Params, 15.99 MMac, 2.324% MACs,
#       (p2_1): Conv2d(2.33 k, 0.167% Params, 456.29 KMac, 0.066% MACs, 96, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(38.46 k, 2.752% Params, 7.54 MMac, 1.096% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(2.33 k, 0.167% Params, 456.29 KMac, 0.066% MACs, 96, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 2.752% Params, 7.54 MMac, 1.096% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): Inception_mod6(
#       83.12 k, 5.947% Params, 16.29 MMac, 2.368% MACs,
#       (p2_1): Conv2d(3.1 k, 0.222% Params, 606.82 KMac, 0.088% MACs, 128, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(38.46 k, 2.752% Params, 7.54 MMac, 1.096% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(3.1 k, 0.222% Params, 606.82 KMac, 0.088% MACs, 128, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 2.752% Params, 7.54 MMac, 1.096% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (3): Inception_mod6(
#       110.78 k, 7.927% Params, 21.71 MMac, 3.156% MACs,
#       (p2_1): Conv2d(4.13 k, 0.295% Params, 809.09 KMac, 0.118% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(51.26 k, 3.668% Params, 10.05 MMac, 1.460% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(4.13 k, 0.295% Params, 809.09 KMac, 0.118% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 3.668% Params, 10.05 MMac, 1.460% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (4): Inception_mod6(
#       213.31 k, 15.263% Params, 41.81 MMac, 6.077% MACs,
#       (p2_1): Conv2d(4.13 k, 0.295% Params, 809.09 KMac, 0.118% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(102.53 k, 7.336% Params, 20.1 MMac, 2.921% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(4.13 k, 0.295% Params, 809.09 KMac, 0.118% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 7.336% Params, 20.1 MMac, 2.921% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 50.18 KMac, 0.007% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     553.63 k, 39.613% Params, 27.14 MMac, 3.945% MACs,
#     (0): Inception_mod6(
#       221.5 k, 15.849% Params, 10.85 MMac, 1.577% MACs,
#       (p2_1): Conv2d(8.22 k, 0.588% Params, 402.98 KMac, 0.059% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(102.53 k, 7.336% Params, 5.02 MMac, 0.730% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(8.22 k, 0.588% Params, 402.98 KMac, 0.059% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 7.336% Params, 5.02 MMac, 0.730% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod6(
#       332.13 k, 23.764% Params, 16.27 MMac, 2.365% MACs,
#       (p2_1): Conv2d(12.34 k, 0.883% Params, 604.46 KMac, 0.088% MACs, 256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(153.73 k, 10.999% Params, 7.53 MMac, 1.095% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(12.34 k, 0.883% Params, 604.46 KMac, 0.088% MACs, 256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 10.999% Params, 7.53 MMac, 1.095% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 12.54 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(2.57 k, 0.184% Params, 2.57 KMac, 0.000% MACs, in_features=256, out_features=10, bias=True)
# )
# Computational complexity:       688.04 MMac
# Number of parameters:           1.4 M
# **************************************************
# The model complexity of googlenet_fmod7:
# Warning: module Inception_mod7 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   2.1 M, 100.000% Params, 833.47 MMac, 99.512% MACs,
#   (0): Sequential(
#     3.2 k, 0.153% Params, 41.75 MMac, 4.984% MACs,
#     (0): Conv2d(3.2 k, 0.153% Params, 40.14 MMac, 4.793% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.096% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.096% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 5.484% Params, 361.87 MMac, 43.205% MACs,
#     (0): Conv2d(4.16 k, 0.198% Params, 13.05 MMac, 1.558% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.024% MACs, )
#     (2): Conv2d(110.78 k, 5.285% Params, 347.42 MMac, 41.480% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.072% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.072% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     287.76 k, 13.728% Params, 225.83 MMac, 26.963% MACs,
#     (0): Inception_mod7(
#       47.76 k, 2.279% Params, 37.44 MMac, 4.471% MACs,
#       (p1_1): Conv2d(3.09 k, 0.147% Params, 2.42 MMac, 0.289% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(12.83 k, 0.612% Params, 10.06 MMac, 1.201% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(3.09 k, 0.147% Params, 2.42 MMac, 0.289% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(12.83 k, 0.612% Params, 10.06 MMac, 1.201% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(3.09 k, 0.147% Params, 2.42 MMac, 0.289% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.612% Params, 10.06 MMac, 1.201% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod7(
#       240.0 k, 11.450% Params, 188.16 MMac, 22.465% MACs,
#       (p1_1): Conv2d(3.1 k, 0.148% Params, 2.43 MMac, 0.291% MACs, 96, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(76.9 k, 3.669% Params, 60.29 MMac, 7.198% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(3.1 k, 0.148% Params, 2.43 MMac, 0.291% MACs, 96, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(76.9 k, 3.669% Params, 60.29 MMac, 7.198% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(3.1 k, 0.148% Params, 2.43 MMac, 0.291% MACs, 96, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 3.669% Params, 60.29 MMac, 7.198% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 225.79 KMac, 0.027% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     825.17 k, 39.367% Params, 161.81 MMac, 19.319% MACs,
#     (0): Inception_mod7(
#       71.62 k, 3.417% Params, 14.04 MMac, 1.676% MACs,
#       (p1_1): Conv2d(4.62 k, 0.221% Params, 906.3 KMac, 0.108% MACs, 288, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(19.25 k, 0.918% Params, 3.77 MMac, 0.450% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(4.62 k, 0.221% Params, 906.3 KMac, 0.108% MACs, 288, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(19.25 k, 0.918% Params, 3.77 MMac, 0.450% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(4.62 k, 0.221% Params, 906.3 KMac, 0.108% MACs, 288, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 0.918% Params, 3.77 MMac, 0.450% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod7(
#       125.83 k, 6.003% Params, 24.66 MMac, 2.945% MACs,
#       (p1_1): Conv2d(3.48 k, 0.166% Params, 682.08 KMac, 0.081% MACs, 144, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(38.46 k, 1.835% Params, 7.54 MMac, 0.900% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(3.48 k, 0.166% Params, 682.08 KMac, 0.081% MACs, 144, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(38.46 k, 1.835% Params, 7.54 MMac, 0.900% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(3.48 k, 0.166% Params, 682.08 KMac, 0.081% MACs, 144, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 1.835% Params, 7.54 MMac, 0.900% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): Inception_mod7(
#       129.29 k, 6.168% Params, 25.34 MMac, 3.026% MACs,
#       (p1_1): Conv2d(4.63 k, 0.221% Params, 907.87 KMac, 0.108% MACs, 192, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(38.46 k, 1.835% Params, 7.54 MMac, 0.900% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(4.63 k, 0.221% Params, 907.87 KMac, 0.108% MACs, 192, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(38.46 k, 1.835% Params, 7.54 MMac, 0.900% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(4.63 k, 0.221% Params, 907.87 KMac, 0.108% MACs, 192, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 1.835% Params, 7.54 MMac, 0.900% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (3): Inception_mod7(
#       172.32 k, 8.221% Params, 33.77 MMac, 4.033% MACs,
#       (p1_1): Conv2d(6.18 k, 0.295% Params, 1.21 MMac, 0.145% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(51.26 k, 2.446% Params, 10.05 MMac, 1.200% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(6.18 k, 0.295% Params, 1.21 MMac, 0.145% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(51.26 k, 2.446% Params, 10.05 MMac, 1.200% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(6.18 k, 0.295% Params, 1.21 MMac, 0.145% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 2.446% Params, 10.05 MMac, 1.200% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (4): Inception_mod7(
#       326.11 k, 15.558% Params, 63.92 MMac, 7.631% MACs,
#       (p1_1): Conv2d(6.18 k, 0.295% Params, 1.21 MMac, 0.145% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(102.53 k, 4.891% Params, 20.1 MMac, 2.399% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(6.18 k, 0.295% Params, 1.21 MMac, 0.145% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(102.53 k, 4.891% Params, 20.1 MMac, 2.399% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(6.18 k, 0.295% Params, 1.21 MMac, 0.145% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 4.891% Params, 20.1 MMac, 2.399% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 75.26 KMac, 0.009% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     861.17 k, 41.084% Params, 42.22 MMac, 5.040% MACs,
#     (0): Inception_mod7(
#       344.54 k, 16.437% Params, 16.88 MMac, 2.016% MACs,
#       (p1_1): Conv2d(12.32 k, 0.588% Params, 603.68 KMac, 0.072% MACs, 384, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(102.53 k, 4.891% Params, 5.02 MMac, 0.600% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(12.32 k, 0.588% Params, 603.68 KMac, 0.072% MACs, 384, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(102.53 k, 4.891% Params, 5.02 MMac, 0.600% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(12.32 k, 0.588% Params, 603.68 KMac, 0.072% MACs, 384, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 4.891% Params, 5.02 MMac, 0.600% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod7(
#       516.62 k, 24.647% Params, 25.31 MMac, 3.022% MACs,
#       (p1_1): Conv2d(18.48 k, 0.882% Params, 905.52 KMac, 0.108% MACs, 384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(153.73 k, 7.334% Params, 7.53 MMac, 0.899% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(18.48 k, 0.882% Params, 905.52 KMac, 0.108% MACs, 384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(153.73 k, 7.334% Params, 7.53 MMac, 0.899% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(18.48 k, 0.882% Params, 905.52 KMac, 0.108% MACs, 384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 7.334% Params, 7.53 MMac, 0.899% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 18.82 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(3.85 k, 0.184% Params, 3.85 KMac, 0.000% MACs, in_features=384, out_features=10, bias=True)
# )
# Computational complexity:       837.56 MMac
# Number of parameters:           2.1 M
# **************************************************
# The model complexity of googlenet_fmod8:
# Warning: module Inception_mod8 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   2.83 M, 100.000% Params, 988.5 MMac, 99.552% MACs,
#   (0): Sequential(
#     3.2 k, 0.113% Params, 41.75 MMac, 4.204% MACs,
#     (0): Conv2d(3.2 k, 0.113% Params, 40.14 MMac, 4.043% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.081% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.081% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 4.056% Params, 361.87 MMac, 36.444% MACs,
#     (0): Conv2d(4.16 k, 0.147% Params, 13.05 MMac, 1.314% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.020% MACs, )
#     (2): Conv2d(110.78 k, 3.909% Params, 347.42 MMac, 34.989% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.061% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.061% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     387.78 k, 13.684% Params, 304.32 MMac, 30.648% MACs,
#     (0): Inception_mod8(
#       63.68 k, 2.247% Params, 49.93 MMac, 5.028% MACs,
#       (p1_1): Conv2d(3.09 k, 0.109% Params, 2.42 MMac, 0.244% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(12.83 k, 0.453% Params, 10.06 MMac, 1.013% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(3.09 k, 0.109% Params, 2.42 MMac, 0.244% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(12.83 k, 0.453% Params, 10.06 MMac, 1.013% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(3.09 k, 0.109% Params, 2.42 MMac, 0.244% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.453% Params, 10.06 MMac, 1.013% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(3.09 k, 0.109% Params, 2.42 MMac, 0.244% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(12.83 k, 0.453% Params, 10.06 MMac, 1.013% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod8(
#       324.1 k, 11.437% Params, 254.09 MMac, 25.590% MACs,
#       (p1_1): Conv2d(4.13 k, 0.146% Params, 3.24 MMac, 0.326% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(76.9 k, 2.714% Params, 60.29 MMac, 6.071% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(4.13 k, 0.146% Params, 3.24 MMac, 0.326% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(76.9 k, 2.714% Params, 60.29 MMac, 6.071% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(4.13 k, 0.146% Params, 3.24 MMac, 0.326% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 2.714% Params, 60.29 MMac, 6.071% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(4.13 k, 0.146% Params, 3.24 MMac, 0.326% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(76.9 k, 2.714% Params, 60.29 MMac, 6.071% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 301.06 KMac, 0.030% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     1.13 M, 40.000% Params, 222.27 MMac, 22.385% MACs,
#     (0): Inception_mod8(
#       101.63 k, 3.586% Params, 19.92 MMac, 2.006% MACs,
#       (p1_1): Conv2d(6.16 k, 0.217% Params, 1.21 MMac, 0.122% MACs, 384, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(19.25 k, 0.679% Params, 3.77 MMac, 0.380% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(6.16 k, 0.217% Params, 1.21 MMac, 0.122% MACs, 384, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(19.25 k, 0.679% Params, 3.77 MMac, 0.380% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(6.16 k, 0.217% Params, 1.21 MMac, 0.122% MACs, 384, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 0.679% Params, 3.77 MMac, 0.380% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(6.16 k, 0.217% Params, 1.21 MMac, 0.122% MACs, 384, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(19.25 k, 0.679% Params, 3.77 MMac, 0.380% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod8(
#       172.38 k, 6.083% Params, 33.79 MMac, 3.403% MACs,
#       (p1_1): Conv2d(4.63 k, 0.163% Params, 907.87 KMac, 0.091% MACs, 192, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(38.46 k, 1.357% Params, 7.54 MMac, 0.759% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(4.63 k, 0.163% Params, 907.87 KMac, 0.091% MACs, 192, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(38.46 k, 1.357% Params, 7.54 MMac, 0.759% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(4.63 k, 0.163% Params, 907.87 KMac, 0.091% MACs, 192, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 1.357% Params, 7.54 MMac, 0.759% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(4.63 k, 0.163% Params, 907.87 KMac, 0.091% MACs, 192, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(38.46 k, 1.357% Params, 7.54 MMac, 0.759% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): Inception_mod8(
#       178.53 k, 6.300% Params, 34.99 MMac, 3.524% MACs,
#       (p1_1): Conv2d(6.17 k, 0.218% Params, 1.21 MMac, 0.122% MACs, 256, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(38.46 k, 1.357% Params, 7.54 MMac, 0.759% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(6.17 k, 0.218% Params, 1.21 MMac, 0.122% MACs, 256, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(38.46 k, 1.357% Params, 7.54 MMac, 0.759% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(6.17 k, 0.218% Params, 1.21 MMac, 0.122% MACs, 256, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 1.357% Params, 7.54 MMac, 0.759% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(6.17 k, 0.218% Params, 1.21 MMac, 0.122% MACs, 256, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(38.46 k, 1.357% Params, 7.54 MMac, 0.759% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (3): Inception_mod8(
#       237.95 k, 8.397% Params, 46.64 MMac, 4.697% MACs,
#       (p1_1): Conv2d(8.22 k, 0.290% Params, 1.61 MMac, 0.162% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(51.26 k, 1.809% Params, 10.05 MMac, 1.012% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(8.22 k, 0.290% Params, 1.61 MMac, 0.162% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(51.26 k, 1.809% Params, 10.05 MMac, 1.012% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(8.22 k, 0.290% Params, 1.61 MMac, 0.162% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 1.809% Params, 10.05 MMac, 1.012% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(8.22 k, 0.290% Params, 1.61 MMac, 0.162% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(51.26 k, 1.809% Params, 10.05 MMac, 1.012% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (4): Inception_mod8(
#       443.01 k, 15.633% Params, 86.83 MMac, 8.745% MACs,
#       (p1_1): Conv2d(8.22 k, 0.290% Params, 1.61 MMac, 0.162% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(102.53 k, 3.618% Params, 20.1 MMac, 2.024% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(8.22 k, 0.290% Params, 1.61 MMac, 0.162% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(102.53 k, 3.618% Params, 20.1 MMac, 2.024% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(8.22 k, 0.290% Params, 1.61 MMac, 0.162% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 3.618% Params, 20.1 MMac, 2.024% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(8.22 k, 0.290% Params, 1.61 MMac, 0.162% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(102.53 k, 3.618% Params, 20.1 MMac, 2.024% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.010% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     1.19 M, 41.965% Params, 58.3 MMac, 5.871% MACs,
#     (0): Inception_mod8(
#       475.78 k, 16.790% Params, 23.31 MMac, 2.348% MACs,
#       (p1_1): Conv2d(16.42 k, 0.579% Params, 804.38 KMac, 0.081% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(102.53 k, 3.618% Params, 5.02 MMac, 0.506% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(16.42 k, 0.579% Params, 804.38 KMac, 0.081% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(102.53 k, 3.618% Params, 5.02 MMac, 0.506% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(16.42 k, 0.579% Params, 804.38 KMac, 0.081% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 3.618% Params, 5.02 MMac, 0.506% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(16.42 k, 0.579% Params, 804.38 KMac, 0.081% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(102.53 k, 3.618% Params, 5.02 MMac, 0.506% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod8(
#       713.41 k, 25.176% Params, 34.96 MMac, 3.521% MACs,
#       (p1_1): Conv2d(24.62 k, 0.869% Params, 1.21 MMac, 0.122% MACs, 512, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(153.73 k, 5.425% Params, 7.53 MMac, 0.759% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(24.62 k, 0.869% Params, 1.21 MMac, 0.122% MACs, 512, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(153.73 k, 5.425% Params, 7.53 MMac, 0.759% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(24.62 k, 0.869% Params, 1.21 MMac, 0.122% MACs, 512, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 5.425% Params, 7.53 MMac, 0.759% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(24.62 k, 0.869% Params, 1.21 MMac, 0.122% MACs, 512, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(153.73 k, 5.425% Params, 7.53 MMac, 0.759% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 25.09 KMac, 0.003% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(5.13 k, 0.181% Params, 5.13 KMac, 0.001% MACs, in_features=512, out_features=10, bias=True)
# )
# Computational complexity:       992.94 MMac
# Number of parameters:           2.83 M
# **************************************************
# The model complexity of googlenet_fmod9:
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   120.07 k, 100.000% Params, 403.77 MMac, 99.223% MACs,
#   (0): Sequential(
#     3.2 k, 2.665% Params, 41.75 MMac, 10.259% MACs,
#     (0): Conv2d(3.2 k, 2.665% Params, 40.14 MMac, 9.864% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.197% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.197% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 95.728% Params, 361.87 MMac, 88.927% MACs,
#     (0): Conv2d(4.16 k, 3.465% Params, 13.05 MMac, 3.206% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.049% MACs, )
#     (2): Conv2d(110.78 k, 92.263% Params, 347.42 MMac, 85.376% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.148% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.148% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     0, 0.000% Params, 150.53 KMac, 0.037% MACs,
#     (0): AdaptiveAvgPool2d(0, 0.000% Params, 150.53 KMac, 0.037% MACs, output_size=(1, 1))
#     (1): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (3): Linear(1.93 k, 1.607% Params, 1.93 KMac, 0.000% MACs, in_features=192, out_features=10, bias=True)
# )
# Computational complexity:       406.93 MMac
# Number of parameters:           120.07 k
# ********************************************************************************************************************************************************************************************************
# The model complexity of googlenet_cmod5:
# Warning: module Inception_mod5 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   756.18 k, 100.000% Params, 619.72 MMac, 99.459% MACs,
#   (0): Sequential(
#     9.47 k, 1.253% Params, 120.42 MMac, 19.327% MACs,
#     (0): Conv2d(9.47 k, 1.253% Params, 118.82 MMac, 19.069% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.129% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.129% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 15.201% Params, 361.87 MMac, 58.077% MACs,
#     (0): Conv2d(4.16 k, 0.550% Params, 13.05 MMac, 2.094% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.032% MACs, )
#     (2): Conv2d(110.78 k, 14.650% Params, 347.42 MMac, 55.758% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.097% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.097% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     93.87 k, 12.414% Params, 73.67 MMac, 11.824% MACs,
#     (0): Inception_mod5(
#       15.92 k, 2.105% Params, 12.48 MMac, 2.003% MACs,
#       (p3_1): Conv2d(3.09 k, 0.408% Params, 2.42 MMac, 0.389% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 1.697% Params, 10.06 MMac, 1.615% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod5(
#       77.95 k, 10.309% Params, 61.11 MMac, 9.808% MACs,
#       (p3_1): Conv2d(1.06 k, 0.140% Params, 827.9 KMac, 0.133% MACs, 32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 10.169% Params, 60.29 MMac, 9.675% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 75.26 KMac, 0.012% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     258.42 k, 34.174% Params, 50.67 MMac, 8.133% MACs,
#     (0): Inception_mod5(
#       20.8 k, 2.751% Params, 4.08 MMac, 0.654% MACs,
#       (p3_1): Conv2d(1.55 k, 0.205% Params, 304.19 KMac, 0.049% MACs, 96, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 2.545% Params, 3.77 MMac, 0.605% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod5(
#       39.64 k, 5.242% Params, 7.77 MMac, 1.247% MACs,
#       (p3_1): Conv2d(1.18 k, 0.156% Params, 230.5 KMac, 0.037% MACs, 48, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 5.087% Params, 7.54 MMac, 1.210% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): Inception_mod5(
#       40.02 k, 5.293% Params, 7.84 MMac, 1.259% MACs,
#       (p3_1): Conv2d(1.56 k, 0.206% Params, 305.76 KMac, 0.049% MACs, 64, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 5.087% Params, 7.54 MMac, 1.210% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (3): Inception_mod5(
#       53.34 k, 7.054% Params, 10.46 MMac, 1.678% MACs,
#       (p3_1): Conv2d(2.08 k, 0.275% Params, 407.68 KMac, 0.065% MACs, 64, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 6.779% Params, 10.05 MMac, 1.613% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (4): Inception_mod5(
#       104.61 k, 13.834% Params, 20.5 MMac, 3.291% MACs,
#       (p3_1): Conv2d(2.08 k, 0.275% Params, 407.68 KMac, 0.065% MACs, 64, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 13.559% Params, 20.1 MMac, 3.225% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 25.09 KMac, 0.004% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     266.58 k, 35.253% Params, 13.07 MMac, 2.097% MACs,
#     (0): Inception_mod5(
#       106.66 k, 14.105% Params, 5.23 MMac, 0.839% MACs,
#       (p3_1): Conv2d(4.13 k, 0.546% Params, 202.27 KMac, 0.032% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 13.559% Params, 5.02 MMac, 0.806% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod5(
#       159.92 k, 21.148% Params, 7.84 MMac, 1.258% MACs,
#       (p3_1): Conv2d(6.19 k, 0.819% Params, 303.41 KMac, 0.049% MACs, 128, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 20.330% Params, 7.53 MMac, 1.209% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 6.27 KMac, 0.001% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(12.9 k, 1.706% Params, 12.9 KMac, 0.002% MACs, in_features=128, out_features=100, bias=True)
# )
# Computational complexity:       623.09 MMac
# Number of parameters:           756.18 k
# **************************************************
# The model complexity of googlenet_cmod6:
# Warning: module Inception_mod6 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   1.43 M, 100.000% Params, 763.02 MMac, 99.514% MACs,
#   (0): Sequential(
#     9.47 k, 0.664% Params, 120.42 MMac, 15.706% MACs,
#     (0): Conv2d(9.47 k, 0.664% Params, 118.82 MMac, 15.496% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.105% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.105% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 8.055% Params, 361.87 MMac, 47.196% MACs,
#     (0): Conv2d(4.16 k, 0.292% Params, 13.05 MMac, 1.701% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.026% MACs, )
#     (2): Conv2d(110.78 k, 7.763% Params, 347.42 MMac, 45.311% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.079% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.079% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     189.79 k, 13.300% Params, 148.95 MMac, 19.426% MACs,
#     (0): Inception_mod6(
#       31.84 k, 2.231% Params, 24.96 MMac, 3.256% MACs,
#       (p2_1): Conv2d(3.09 k, 0.216% Params, 2.42 MMac, 0.316% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(12.83 k, 0.899% Params, 10.06 MMac, 1.312% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(3.09 k, 0.216% Params, 2.42 MMac, 0.316% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.899% Params, 10.06 MMac, 1.312% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod6(
#       157.95 k, 11.069% Params, 123.83 MMac, 16.151% MACs,
#       (p2_1): Conv2d(2.08 k, 0.146% Params, 1.63 MMac, 0.213% MACs, 64, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(76.9 k, 5.389% Params, 60.29 MMac, 7.863% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(2.08 k, 0.146% Params, 1.63 MMac, 0.213% MACs, 64, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 5.389% Params, 60.29 MMac, 7.863% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.020% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     533.47 k, 37.384% Params, 104.61 MMac, 13.644% MACs,
#     (0): Inception_mod6(
#       44.67 k, 3.130% Params, 8.76 MMac, 1.142% MACs,
#       (p2_1): Conv2d(3.09 k, 0.216% Params, 605.25 KMac, 0.079% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(19.25 k, 1.349% Params, 3.77 MMac, 0.492% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(3.09 k, 0.216% Params, 605.25 KMac, 0.079% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 1.349% Params, 3.77 MMac, 0.492% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod6(
#       81.58 k, 5.717% Params, 15.99 MMac, 2.086% MACs,
#       (p2_1): Conv2d(2.33 k, 0.163% Params, 456.29 KMac, 0.060% MACs, 96, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(38.46 k, 2.695% Params, 7.54 MMac, 0.983% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(2.33 k, 0.163% Params, 456.29 KMac, 0.060% MACs, 96, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 2.695% Params, 7.54 MMac, 0.983% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): Inception_mod6(
#       83.12 k, 5.825% Params, 16.29 MMac, 2.125% MACs,
#       (p2_1): Conv2d(3.1 k, 0.217% Params, 606.82 KMac, 0.079% MACs, 128, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(38.46 k, 2.695% Params, 7.54 MMac, 0.983% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(3.1 k, 0.217% Params, 606.82 KMac, 0.079% MACs, 128, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 2.695% Params, 7.54 MMac, 0.983% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (3): Inception_mod6(
#       110.78 k, 7.763% Params, 21.71 MMac, 2.832% MACs,
#       (p2_1): Conv2d(4.13 k, 0.289% Params, 809.09 KMac, 0.106% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(51.26 k, 3.592% Params, 10.05 MMac, 1.310% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(4.13 k, 0.289% Params, 809.09 KMac, 0.106% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 3.592% Params, 10.05 MMac, 1.310% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (4): Inception_mod6(
#       213.31 k, 14.948% Params, 41.81 MMac, 5.453% MACs,
#       (p2_1): Conv2d(4.13 k, 0.289% Params, 809.09 KMac, 0.106% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(102.53 k, 7.185% Params, 20.1 MMac, 2.621% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(4.13 k, 0.289% Params, 809.09 KMac, 0.106% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 7.185% Params, 20.1 MMac, 2.621% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 50.18 KMac, 0.007% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     553.63 k, 38.797% Params, 27.14 MMac, 3.540% MACs,
#     (0): Inception_mod6(
#       221.5 k, 15.522% Params, 10.85 MMac, 1.416% MACs,
#       (p2_1): Conv2d(8.22 k, 0.576% Params, 402.98 KMac, 0.053% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(102.53 k, 7.185% Params, 5.02 MMac, 0.655% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(8.22 k, 0.576% Params, 402.98 KMac, 0.053% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 7.185% Params, 5.02 MMac, 0.655% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod6(
#       332.13 k, 23.274% Params, 16.27 MMac, 2.123% MACs,
#       (p2_1): Conv2d(12.34 k, 0.864% Params, 604.46 KMac, 0.079% MACs, 256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(153.73 k, 10.773% Params, 7.53 MMac, 0.982% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(12.34 k, 0.864% Params, 604.46 KMac, 0.079% MACs, 256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 10.773% Params, 7.53 MMac, 0.982% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 12.54 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(25.7 k, 1.801% Params, 25.7 KMac, 0.003% MACs, in_features=256, out_features=100, bias=True)
# )
# Computational complexity:       766.74 MMac
# Number of parameters:           1.43 M
# **************************************************
# The model complexity of googlenet_cmod7:
# Warning: module Inception_mod7 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   2.14 M, 100.000% Params, 912.18 MMac, 99.554% MACs,
#   (0): Sequential(
#     9.47 k, 0.443% Params, 120.42 MMac, 13.143% MACs,
#     (0): Conv2d(9.47 k, 0.443% Params, 118.82 MMac, 12.967% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.088% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.088% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 5.379% Params, 361.87 MMac, 39.494% MACs,
# ...
#       (p2_1): Conv2d(6.18 k, 0.289% Params, 1.21 MMac, 0.132% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(102.53 k, 4.798% Params, 20.1 MMac, 2.193% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(6.18 k, 0.289% Params, 1.21 MMac, 0.132% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 4.798% Params, 20.1 MMac, 2.193% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 75.26 KMac, 0.008% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     861.17 k, 40.298% Params, 42.22 MMac, 4.607% MACs,
#     (0): Inception_mod7(
#       344.54 k, 16.123% Params, 16.88 MMac, 1.843% MACs,
#       (p1_1): Conv2d(12.32 k, 0.577% Params, 603.68 KMac, 0.066% MACs, 384, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(102.53 k, 4.798% Params, 5.02 MMac, 0.548% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(12.32 k, 0.577% Params, 603.68 KMac, 0.066% MACs, 384, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(102.53 k, 4.798% Params, 5.02 MMac, 0.548% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(12.32 k, 0.577% Params, 603.68 KMac, 0.066% MACs, 384, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 4.798% Params, 5.02 MMac, 0.548% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod7(
#       516.62 k, 24.175% Params, 25.31 MMac, 2.763% MACs,
#       (p1_1): Conv2d(18.48 k, 0.865% Params, 905.52 KMac, 0.099% MACs, 384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(153.73 k, 7.194% Params, 7.53 MMac, 0.822% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(18.48 k, 0.865% Params, 905.52 KMac, 0.099% MACs, 384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(153.73 k, 7.194% Params, 7.53 MMac, 0.822% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(18.48 k, 0.865% Params, 905.52 KMac, 0.099% MACs, 384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 7.194% Params, 7.53 MMac, 0.822% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 18.82 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(38.5 k, 1.802% Params, 38.5 KMac, 0.004% MACs, in_features=384, out_features=100, bias=True)
# )
# Computational complexity:       916.27 MMac
# Number of parameters:           2.14 M
# **************************************************
# The model complexity of googlenet_cmod8:
# Warning: module Inception_mod8 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   2.89 M, 100.000% Params, 1.07 GMac, 99.585% MACs,
#   (0): Sequential(
#     9.47 k, 0.328% Params, 120.42 MMac, 11.237% MACs,
#     (0): Conv2d(9.47 k, 0.328% Params, 118.82 MMac, 11.087% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.075% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.075% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 3.983% Params, 361.87 MMac, 33.767% MACs,
#     (0): Conv2d(4.16 k, 0.144% Params, 13.05 MMac, 1.217% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.019% MACs, )
#     (2): Conv2d(110.78 k, 3.838% Params, 347.42 MMac, 32.419% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.056% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.056% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     387.78 k, 13.436% Params, 304.32 MMac, 28.397% MACs,
#     (0): Inception_mod8(
#       63.68 k, 2.206% Params, 49.93 MMac, 4.659% MACs,
#       (p1_1): Conv2d(3.09 k, 0.107% Params, 2.42 MMac, 0.226% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(12.83 k, 0.445% Params, 10.06 MMac, 0.939% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(3.09 k, 0.107% Params, 2.42 MMac, 0.226% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(12.83 k, 0.445% Params, 10.06 MMac, 0.939% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(3.09 k, 0.107% Params, 2.42 MMac, 0.226% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.445% Params, 10.06 MMac, 0.939% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(3.09 k, 0.107% Params, 2.42 MMac, 0.226% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(12.83 k, 0.445% Params, 10.06 MMac, 0.939% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod8(
#       324.1 k, 11.229% Params, 254.09 MMac, 23.710% MACs,
#       (p1_1): Conv2d(4.13 k, 0.143% Params, 3.24 MMac, 0.302% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(76.9 k, 2.664% Params, 60.29 MMac, 5.625% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(4.13 k, 0.143% Params, 3.24 MMac, 0.302% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(76.9 k, 2.664% Params, 60.29 MMac, 5.625% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(4.13 k, 0.143% Params, 3.24 MMac, 0.302% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 2.664% Params, 60.29 MMac, 5.625% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(4.13 k, 0.143% Params, 3.24 MMac, 0.302% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(76.9 k, 2.664% Params, 60.29 MMac, 5.625% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 301.06 KMac, 0.028% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     1.13 M, 39.274% Params, 222.27 MMac, 20.740% MACs,
#     (0): Inception_mod8(
#       101.63 k, 3.521% Params, 19.92 MMac, 1.859% MACs,
#       (p1_1): Conv2d(6.16 k, 0.213% Params, 1.21 MMac, 0.113% MACs, 384, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(19.25 k, 0.667% Params, 3.77 MMac, 0.352% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(6.16 k, 0.213% Params, 1.21 MMac, 0.113% MACs, 384, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(19.25 k, 0.667% Params, 3.77 MMac, 0.352% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(6.16 k, 0.213% Params, 1.21 MMac, 0.113% MACs, 384, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 0.667% Params, 3.77 MMac, 0.352% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(6.16 k, 0.213% Params, 1.21 MMac, 0.113% MACs, 384, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(19.25 k, 0.667% Params, 3.77 MMac, 0.352% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod8(
#       172.38 k, 5.973% Params, 33.79 MMac, 3.153% MACs,
#       (p1_1): Conv2d(4.63 k, 0.160% Params, 907.87 KMac, 0.085% MACs, 192, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(38.46 k, 1.333% Params, 7.54 MMac, 0.703% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(4.63 k, 0.160% Params, 907.87 KMac, 0.085% MACs, 192, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(38.46 k, 1.333% Params, 7.54 MMac, 0.703% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(4.63 k, 0.160% Params, 907.87 KMac, 0.085% MACs, 192, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 1.333% Params, 7.54 MMac, 0.703% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(4.63 k, 0.160% Params, 907.87 KMac, 0.085% MACs, 192, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(38.46 k, 1.333% Params, 7.54 MMac, 0.703% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): Inception_mod8(
#       178.53 k, 6.186% Params, 34.99 MMac, 3.265% MACs,
#       (p1_1): Conv2d(6.17 k, 0.214% Params, 1.21 MMac, 0.113% MACs, 256, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(38.46 k, 1.333% Params, 7.54 MMac, 0.703% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(6.17 k, 0.214% Params, 1.21 MMac, 0.113% MACs, 256, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(38.46 k, 1.333% Params, 7.54 MMac, 0.703% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(6.17 k, 0.214% Params, 1.21 MMac, 0.113% MACs, 256, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 1.333% Params, 7.54 MMac, 0.703% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(6.17 k, 0.214% Params, 1.21 MMac, 0.113% MACs, 256, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(38.46 k, 1.333% Params, 7.54 MMac, 0.703% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (3): Inception_mod8(
#       237.95 k, 8.245% Params, 46.64 MMac, 4.352% MACs,
#       (p1_1): Conv2d(8.22 k, 0.285% Params, 1.61 MMac, 0.150% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(51.26 k, 1.776% Params, 10.05 MMac, 0.938% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(8.22 k, 0.285% Params, 1.61 MMac, 0.150% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(51.26 k, 1.776% Params, 10.05 MMac, 0.938% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(8.22 k, 0.285% Params, 1.61 MMac, 0.150% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 1.776% Params, 10.05 MMac, 0.938% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(8.22 k, 0.285% Params, 1.61 MMac, 0.150% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(51.26 k, 1.776% Params, 10.05 MMac, 0.938% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (4): Inception_mod8(
#       443.01 k, 15.349% Params, 86.83 MMac, 8.102% MACs,
#       (p1_1): Conv2d(8.22 k, 0.285% Params, 1.61 MMac, 0.150% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(102.53 k, 3.552% Params, 20.1 MMac, 1.875% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(8.22 k, 0.285% Params, 1.61 MMac, 0.150% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(102.53 k, 3.552% Params, 20.1 MMac, 1.875% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(8.22 k, 0.285% Params, 1.61 MMac, 0.150% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 3.552% Params, 20.1 MMac, 1.875% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(8.22 k, 0.285% Params, 1.61 MMac, 0.150% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(102.53 k, 3.552% Params, 20.1 MMac, 1.875% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.009% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     1.19 M, 41.203% Params, 58.3 MMac, 5.440% MACs,
#     (0): Inception_mod8(
#       475.78 k, 16.485% Params, 23.31 MMac, 2.175% MACs,
#       (p1_1): Conv2d(16.42 k, 0.569% Params, 804.38 KMac, 0.075% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(102.53 k, 3.552% Params, 5.02 MMac, 0.469% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(16.42 k, 0.569% Params, 804.38 KMac, 0.075% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(102.53 k, 3.552% Params, 5.02 MMac, 0.469% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(16.42 k, 0.569% Params, 804.38 KMac, 0.075% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 3.552% Params, 5.02 MMac, 0.469% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(16.42 k, 0.569% Params, 804.38 KMac, 0.075% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(102.53 k, 3.552% Params, 5.02 MMac, 0.469% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod8(
#       713.41 k, 24.718% Params, 34.96 MMac, 3.262% MACs,
#       (p1_1): Conv2d(24.62 k, 0.853% Params, 1.21 MMac, 0.113% MACs, 512, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(153.73 k, 5.326% Params, 7.53 MMac, 0.703% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p2_1): Conv2d(24.62 k, 0.853% Params, 1.21 MMac, 0.113% MACs, 512, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(153.73 k, 5.326% Params, 7.53 MMac, 0.703% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p3_1): Conv2d(24.62 k, 0.853% Params, 1.21 MMac, 0.113% MACs, 512, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 5.326% Params, 7.53 MMac, 0.703% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): Conv2d(24.62 k, 0.853% Params, 1.21 MMac, 0.113% MACs, 512, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(153.73 k, 5.326% Params, 7.53 MMac, 0.703% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 25.09 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(51.3 k, 1.777% Params, 51.3 KMac, 0.005% MACs, in_features=512, out_features=100, bias=True)
# )
# Computational complexity:       1.07 GMac
# Number of parameters:           2.89 M
# **************************************************
# The model complexity of googlenet_cmod9:
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   143.72 k, 100.000% Params, 482.46 MMac, 99.349% MACs,
#   (0): Sequential(
#     9.47 k, 6.591% Params, 120.42 MMac, 24.798% MACs,
#     (0): Conv2d(9.47 k, 6.591% Params, 118.82 MMac, 24.467% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.165% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.165% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 79.980% Params, 361.87 MMac, 74.517% MACs,
#     (0): Conv2d(4.16 k, 2.895% Params, 13.05 MMac, 2.686% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.041% MACs, )
#     (2): Conv2d(110.78 k, 77.085% Params, 347.42 MMac, 71.541% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.124% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.124% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     0, 0.000% Params, 150.53 KMac, 0.031% MACs,
#     (0): AdaptiveAvgPool2d(0, 0.000% Params, 150.53 KMac, 0.031% MACs, output_size=(1, 1))
#     (1): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (3): Linear(19.3 k, 13.429% Params, 19.3 KMac, 0.004% MACs, in_features=192, out_features=100, bias=True)
# )
# Computational complexity:       485.62 MMac
# Number of parameters:           143.72 k

# %% [markdown]
# ### Datasets

# %%
X_f = torch.randn(size=(1, 1, 224, 224), dtype=torch.float32) # fashion mnist
X_c = torch.randn(size=(1, 3, 224, 224), dtype=torch.float32) # cifar100

for layer in googlenet_fmod6:
    X_f=layer(X_f)
    print(layer.__class__.__name__,'output shape:\t',X_f.shape)

print('*'*50)

for layer in googlenet_cmod6:
    X_c=layer(X_c)
    print(layer.__class__.__name__,'output shape:\t',X_c.shape)
# Out:
# Sequential output shape:	 torch.Size([1, 64, 56, 56])
# Sequential output shape:	 torch.Size([1, 192, 28, 28])
# Sequential output shape:	 torch.Size([1, 192, 14, 14])
# Sequential output shape:	 torch.Size([1, 256, 7, 7])
# Sequential output shape:	 torch.Size([1, 256])
# Linear output shape:	 torch.Size([1, 10])
# **************************************************
# Sequential output shape:	 torch.Size([1, 64, 56, 56])
# Sequential output shape:	 torch.Size([1, 192, 28, 28])
# Sequential output shape:	 torch.Size([1, 192, 14, 14])
# Sequential output shape:	 torch.Size([1, 256, 7, 7])
# Sequential output shape:	 torch.Size([1, 256])
# Linear output shape:	 torch.Size([1, 100])

# %%
# load the data
# fashion mnist
def get_dataloader_workers():
    """Use 4 processes to read the data.

    Defined in :numref:`sec_utils`"""
    return 4

def load_data_fashion_mnist(batch_size, resize=None):
    """下载Fashion-MNIST数据集，然后将其加载到内存中

    Defined in :numref:`sec_fashion_mnist`"""
    trans = [transforms.ToTensor()]
    if resize:
        trans.insert(0, transforms.Resize(resize))
    trans = transforms.Compose(trans)
    mnist_train = torchvision.datasets.FashionMNIST(
        root="../data", train=True, transform=trans, download=True)
    mnist_test = torchvision.datasets.FashionMNIST(
        root="../data", train=False, transform=trans, download=True)
    return (torch.utils.data.DataLoader(mnist_train, batch_size, shuffle=True,
                            num_workers=get_dataloader_workers()),
            torch.utils.data.DataLoader(mnist_test, batch_size, shuffle=False,
                            num_workers=get_dataloader_workers()))

def load_data_cifar100(batch_size, resize=None):
    """Download the Fashion-MNIST dataset and then load it into memory.

    Defined in :numref:`sec_utils`"""
    trans = [transforms.ToTensor()]
    if resize:
        trans.insert(0, transforms.Resize(resize))
    trans = transforms.Compose(trans)
    # import the cifar100 dataset
    cifar_train = torchvision.datasets.CIFAR100(
        root="../data", train=True, transform=trans, download=True)
    cifar_test = torchvision.datasets.CIFAR100(
        root="../data", train=False, transform=trans, download=True)
    return (torch.utils.data.DataLoader(cifar_train, batch_size, shuffle=True,
                                        num_workers=get_dataloader_workers()),
            torch.utils.data.DataLoader(cifar_test, batch_size, shuffle=False,
                                        num_workers=get_dataloader_workers()))

# %% [markdown]
# ### Parameters

# %%
# batch_size = [128, 256, 512]
batch_size = [256]
# epochs = [10, 20, 30, 40, 50]
epochs = [20]
rounds = 1

# %% [markdown]
# ### Train Model

# %%
def train_func(net, train_iter, test_iter, LayerName, num_epochs, lr, device):
    def init_weights(m): # 初始化权重
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            nn.init.xavier_uniform_(m.weight)
    net.apply(init_weights)
    print('training on', device)
    net.to(device)
    # record each block running time
    Layers_time = np.zeros((len(LayerName), num_epochs)) # each row is a layer, each column is an epoch
    Train_part_time = np.zeros((4, num_epochs)) # store the time to device, forward and backward time, and test time of each epoch
    Train_acc = np.zeros(num_epochs) # store the training accuracy of each epoch
    Test_acc = np.zeros(num_epochs) # store the test accuracy of each epoch
    Epoch_time = np.zeros(num_epochs) # store the total time of each epoch
    Epoch_energy = np.zeros((num_epochs,1), dtype='object') # store the total energy of each epoch
    timer = d2l.Timer()
    train_timer = d2l.Timer()
    ttd_timer = d2l.Timer()
    forward_timer = d2l.Timer()
    backward_timer = d2l.Timer()
    layer_timer = d2l.Timer()
    test_timer = d2l.Timer()
    optimizer = torch.optim.SGD(net.parameters(), lr=lr)
    loss_fn = nn.CrossEntropyLoss()
    # start training
    for epoch in range(num_epochs):
        print('The epoch is:', epoch+1)
        timer.start()
        net.train()
        ttd_epoch, forward_epoch, backward_epoch, testtime_epoch= 0.0, 0.0, 0.0, 0.0
        layer_epoch = np.zeros((len(LayerName), 1)) # store the total running time of each layer in one epoch
        metric = d2l.Accumulator(3)  # train_loss, train_acc, num_examples   
        # start the nvidia-smi command
        with open('gpu_power_usage.csv', 'w') as file:
            # Start the nvidia-smi command
            nvidia_smi_process = subprocess.Popen(
                ["nvidia-smi", "--query-gpu=power.draw", "--format=csv", "--loop-ms=1000"],
                stdout=file,  # Redirect the output directly to the file
                stderr=subprocess.PIPE,
                text=True)
        train_timer.start()
        for i, (X, y) in enumerate(train_iter):
            batch_block_num = 0
            print('The batch is:', i+1)
            optimizer.zero_grad()
            # to device
            torch.cuda.synchronize()  # 等待数据传输完成
            ttd_timer.start()
            X, y = X.to(device), y.to(device)
            torch.cuda.synchronize()  # 等待数据传输完成
            ttd_epoch += ttd_timer.stop()
            # forward
            forward_timer.start()
            y_hat = X
            for num, layer in net.named_children():
                layername = layer.__class__.__name__
                if layername == 'Sequential':
                    for sublayernum, sublayer in layer.named_children():
                        sublayername = sublayer.__class__.__name__
                        Layer_label = f'{layername[0]}{num}_{sublayername[0]}{sublayernum}'
                        layer_index = LayerName.index(Layer_label)
                        # print('The layer index is:', layer_index, 'The layer label is:', Layer_label)
                        layer_timer.start()
                        y_hat = sublayer(y_hat)
                        torch.cuda.synchronize()
                        layer_epoch[layer_index] += layer_timer.stop()
            torch.cuda.synchronize()
            forward_epoch += forward_timer.stop()
            # loss
            l = loss_fn(y_hat, y)
            # backward
            torch.cuda.synchronize()  # 等待数据传输完成
            backward_timer.start()
            l.backward()
            torch.cuda.synchronize()  # 等待数据传输完成
            backward_epoch += backward_timer.stop()
            # optimize
            optimizer.step()
            torch.cuda.synchronize()  # 等待数据传输完成
            with torch.no_grad():
                metric.add(l*X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            train_acc = metric[1] / metric[2]
        train_epoch = train_timer.stop()
        test_timer.start()
        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        testtime_epoch = test_timer.stop()
        print(f'train acc {train_acc:.3f}, test acc {test_acc:.3f}')
        print('epoch %d, time %f sec' % (epoch+1, timer.sum()))
        # store the time and acc data
        Epoch_time[epoch] = timer.stop()
        print(f'The total time of the {epoch} is:', Epoch_time[epoch])
        Layers_time[:, epoch] = layer_epoch.flatten()
        Train_part_time[:, epoch] = ttd_epoch, forward_epoch, backward_epoch, testtime_epoch
        print(ttd_epoch, forward_epoch, backward_epoch, testtime_epoch)
        Train_acc[epoch] = train_acc
        Test_acc[epoch] = test_acc
        # stop the nvidia-smi command
        nvidia_smi_process.terminate()
        # calculate the energy consumption of each epoch
        GPU_df = pd.read_csv('gpu_power_usage.csv')
        for row in range(len(GPU_df)):
            GPU_df.iloc[row,0] = GPU_df.iloc[row,0].replace(' W','')
        Consumption_df = GPU_df.astype(float)  
        EnergyDatai = Consumption_df.iloc[:,0].values # 将数据转换为numpy数组
        # store the energy data
        Epoch_energy[epoch,0] = EnergyDatai
    return Layers_time, Train_part_time, Train_acc, Test_acc, Epoch_time, Epoch_energy

# %% [markdown]
# ### Train the model

# %%
def train_model_f(main_folder, batch_size, num_epochs, round, lr, device, LayerName, model_f):
    print(f'The epoch is set: {num_epochs}, batch is set: {batch_size}, is in {round+1}th running')
    # create the folder to store the data
    epoch_batch_folder = main_folder/f'E{num_epochs}_B{batch_size}_R{round}'
    # 判断文件是否存在
    if epoch_batch_folder.exists():
        print("文件存在。")
    else:
        os.makedirs(epoch_batch_folder)
        print("文件不存在，已创建。")
        print("文件创建于：", epoch_batch_folder)
    train_iter, test_iter = load_data_fashion_mnist(batch_size, resize=224)
    # show the shape of the data
    list_of_i = []
    for i, (X, y) in enumerate(train_iter):
        if i < 3:
            print('the shape of the', i, 'batch of the train_iter is:', X.shape)
        else:
            pass
        list_of_i.append(i)
    print(f'The number of batches is: {np.array(list_of_i).shape}')
    Layers_time, Train_part_time, Train_acc, Test_acc, \
        Epoch_time, Epoch_energy = train_func(model_f, train_iter, test_iter, LayerName, num_epochs, lr, device)
    # save the data
    np.save(epoch_batch_folder/'Layers_time.npy', Layers_time)
    np.save(epoch_batch_folder/'Train_part_time.npy', Train_part_time)
    np.save(epoch_batch_folder/'Train_acc.npy', Train_acc)
    np.save(epoch_batch_folder/'Test_acc.npy', Test_acc)
    np.save(epoch_batch_folder/'Epoch_time.npy', Epoch_time)
    np.save(epoch_batch_folder/'Epoch_energy.npy', Epoch_energy)

# %%
def train_model_c(main_folder, batch_size, num_epochs, round, lr, device, LayerName, model_c):
    print(f'The epoch is set: {num_epochs}, batch is set: {batch_size}, is in {round+1}th running')
    # create the folder to store the data
    epoch_batch_folder = main_folder/f'E{num_epochs}_B{batch_size}_R{round}'
    # 判断文件是否存在
    if epoch_batch_folder.exists():
        print("文件存在。")
        pass
    else:
        os.makedirs(epoch_batch_folder)
        print("文件不存在，已创建。")
        print("文件创建于：", epoch_batch_folder)
        train_iter, test_iter = load_data_cifar100(batch_size, resize=224)
        # show the shape of the data
        list_of_i = []
        for i, (X, y) in enumerate(train_iter):
            if i < 3:
                print('the shape of the', i, 'batch of the train_iter is:', X.shape)
            else:
                pass
            list_of_i.append(i)
        print(f'The number of batches is: {np.array(list_of_i).shape}')
        Layers_time, Train_part_time, Train_acc, Test_acc, \
            Epoch_time, Epoch_energy = train_func(model_c, train_iter, test_iter, LayerName, num_epochs, lr, device)
        # save the data
        np.save(epoch_batch_folder/'Layers_time.npy', Layers_time)
        np.save(epoch_batch_folder/'Train_part_time.npy', Train_part_time)
        np.save(epoch_batch_folder/'Train_acc.npy', Train_acc)
        np.save(epoch_batch_folder/'Test_acc.npy', Test_acc)
        np.save(epoch_batch_folder/'Epoch_time.npy', Epoch_time)
        np.save(epoch_batch_folder/'Epoch_energy.npy', Epoch_energy)

# %%
lr = 0.01
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('The device is:', device)
# Out:
# The device is: cuda

# %% [markdown]
# ### Path

# %%
googlenet_fmod5
googlenet_fmod6
googlenet_fmod7
googlenet_fmod8
googlenet_fmod9
# CIFAR100中的
googlenet_cmod5
googlenet_cmod6
googlenet_cmod7
googlenet_cmod8
googlenet_cmod9
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=(1, 1))
#     (1): Flatten(start_dim=1, end_dim=-1)
#   )
#   (3): Linear(in_features=192, out_features=100, bias=True)
# )

# %%
'''find the Model path'''
# find the current path
current_path = os.getcwd()
print('The current path is:', current_path)

# find the parent path
parent_path = Path(current_path).parent
print('The parent path is:', parent_path)

pathnum = [9]
# find the data path
for i in pathnum:
    data_path = parent_path / f'Data/googlenet_mod{i}_mod2'
    print('The data path is:', data_path)
    if i == 5:
        model_f = googlenet_fmod5
        model_c = googlenet_cmod5
    elif i == 6:
        model_f = googlenet_fmod6
        model_c = googlenet_cmod6
    elif i == 7:
        model_f = googlenet_fmod7
        model_c = googlenet_cmod7
    elif i == 8:
        model_f = googlenet_fmod8
        model_c = googlenet_cmod8  
    elif i == 9:
        model_f = googlenet_fmod9
        model_c = googlenet_cmod9
    # train the model
    ##########################################################
    # Fashion-MNIST
    # create the folder to store the data
    main_folder = data_path/'fashion_mnist'
    print('The folder is:', main_folder)
    # find out that if the folder exists in the data path
    # 判断文件是否存在
    if main_folder.exists():
        print("文件存在。")
    else:
        os.makedirs(main_folder)
        print("文件不存在，已创建。")
        print("文件创建于：", main_folder)
    for epoch in epochs:
        for batch in batch_size:
            for round in range(rounds):
                train_model_f(main_folder, batch, epoch, round, lr, device, LayerName, model_f)
    ##########################################################
    # CIFAR100
    # create the folder to store the data
    main_folder = data_path/'cifar100'
    print('The folder is:', main_folder)
    # find out that if the folder exists in the data path
    # 判断文件是否存在
    if main_folder.exists():
        print("文件存在。")
    else:
        os.makedirs(main_folder)
        print("文件不存在，已创建。")
        print("文件创建于：", main_folder)
    for epoch in epochs:
        for batch in batch_size:
            for round in range(rounds):
                train_model_c(main_folder, batch, epoch, round, lr, device, LayerName, model_c)
# Out:
# The current path is: /root/GreenAI/Cloud/4090/code
# The parent path is: /root/GreenAI/Cloud/4090
# The data path is: /root/GreenAI/Cloud/4090/Data/googlenet_mod9_mod2
# The folder is: /root/GreenAI/Cloud/4090/Data/googlenet_mod9_mod2/fashion_mnist
# 文件不存在，已创建。
# 文件创建于： /root/GreenAI/Cloud/4090/Data/googlenet_mod9_mod2/fashion_mnist
# The epoch is set: 20, batch is set: 256, is in 1th running
# 文件不存在，已创建。
# 文件创建于： /root/GreenAI/Cloud/4090/Data/googlenet_mod9_mod2/fashion_mnist/E20_B256_R0
# the shape of the 0 batch of the train_iter is: torch.Size([256, 1, 224, 224])
# the shape of the 1 batch of the train_iter is: torch.Size([256, 1, 224, 224])
# the shape of the 2 batch of the train_iter is: torch.Size([256, 1, 224, 224])
# The number of batches is: (235,)
# training on cuda
# The epoch is: 1
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# train acc 0.100, test acc 0.100
# epoch 1, time 0.000000 sec
# The total time of the 0 is: 19.44029688835144
# 2.82672119140625 3.6248581409454346 6.280640363693237 2.5197107791900635
# The epoch is: 2
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# train acc 0.132, test acc 0.100
# epoch 2, time 19.440297 sec
# The total time of the 1 is: 18.790141344070435
# 2.32295298576355 3.6024932861328125 6.2737836837768555 2.668663263320923
# The epoch is: 3
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# train acc 0.188, test acc 0.100
# epoch 3, time 38.230438 sec
# The total time of the 2 is: 18.396443367004395
# 2.1975035667419434 3.6028003692626953 6.26897120475769 2.5126543045043945
# The epoch is: 4
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# train acc 0.215, test acc 0.100
# epoch 4, time 56.626882 sec
# The total time of the 3 is: 19.628564596176147
# 2.698734760284424 3.6105644702911377 6.292677640914917 2.752331256866455
# The epoch is: 5
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# train acc 0.257, test acc 0.100
# epoch 5, time 76.255446 sec
# The total time of the 4 is: 19.47040867805481
# 2.785569429397583 3.6088802814483643 6.293975591659546 2.6433825492858887
# The epoch is: 6
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# train acc 0.268, test acc 0.100
# epoch 6, time 95.725855 sec
# The total time of the 5 is: 19.187034368515015
# 2.591463088989258 3.606851816177368 6.299054384231567 2.6322903633117676
# The epoch is: 7
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# train acc 0.276, test acc 0.100
# epoch 7, time 114.912889 sec
# The total time of the 6 is: 19.212909698486328
# 2.4412574768066406 3.6062238216400146 6.281407117843628 2.7154757976531982
# The epoch is: 8
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# train acc 0.287, test acc 0.100
# epoch 8, time 134.125799 sec
# The total time of the 7 is: 19.267200469970703
# 2.612013101577759 3.620673894882202 6.2816972732543945 2.5358011722564697
# The epoch is: 9
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# train acc 0.291, test acc 0.100
# epoch 9, time 153.392999 sec
# The total time of the 8 is: 18.40851402282715
# 2.229802131652832 3.603923797607422 6.262865781784058 2.6141605377197266
# The epoch is: 10
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# train acc 0.298, test acc 0.100
# epoch 10, time 171.801513 sec
# The total time of the 9 is: 19.390992403030396
# 2.7288897037506104 3.6174776554107666 6.299427032470703 2.4127864837646484
# The epoch is: 11
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# ...
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# train acc 0.036, test acc 0.010
# epoch 16, time 441.656144 sec
# The total time of the 15 is: 28.92983627319336
# 6.1994359493255615 3.14819073677063 5.697110652923584 4.938687086105347
# The epoch is: 17
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# train acc 0.036, test acc 0.011
# epoch 17, time 470.585981 sec
# The total time of the 16 is: 28.56956648826599
# 6.09194803237915 3.1413769721984863 5.70159912109375 5.027273893356323
# The epoch is: 18
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# train acc 0.038, test acc 0.010
# epoch 18, time 499.155547 sec
# The total time of the 17 is: 28.518698692321777
# 6.1806066036224365 3.137763738632202 5.697980642318726 4.622623682022095
# The epoch is: 19
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# train acc 0.038, test acc 0.011
# epoch 19, time 527.674246 sec
# The total time of the 18 is: 29.050870895385742
# 6.263721466064453 3.1452202796936035 5.705147981643677 4.908590078353882
# The epoch is: 20
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# train acc 0.039, test acc 0.010
# epoch 20, time 556.725117 sec
# The total time of the 19 is: 29.748799085617065
# 6.3496222496032715 3.151416778564453 5.684972047805786 5.088980197906494
