# %% [markdown]
# ## This code is to find out the different of each epoch and batch size combination

# %%
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Path

# %%
'''find the Model path'''
# find the current path
current_path = os.getcwd()
print('The current path is:', current_path)

# find the parent path
parent_path = Path(current_path).parent
print('The parent path is:', parent_path)

# find the data path
data_path = parent_path / 'Data/alexnet/cifar100/'
print('The data path is:', data_path)
# Out:
# The current path is: /root/GreenAI/Cloud/4090/code
# The parent path is: /root/GreenAI/Cloud/4090
# The data path is: /root/GreenAI/Cloud/4090/Data/alexnet/cifar100

# %% [markdown]
# ### extract data

# %%
batch_sizes = [64, 128, 256, 512,1024]
epochs = [10, 20, 30, 40, 50,80,100]
rounds = 1

# %% [markdown]
# #### read all the data from all the folders

# %%
folder_list = []
for epoch in epochs:
    for batch in batch_sizes:
        for round in range(rounds):
            folder_name = 'E' + str(epoch) + '_B' + str(batch) + '_R' + str(round)
            # print('The folder name is:', folder_name)
            folder_list.append(folder_name)
            
# find the folders in the data path
folder_names = os.listdir(data_path)
print('The folder names are:', folder_names)
print('The folder list is:', folder_list)

# find the common folders
common_folders = list(set(folder_list).intersection(folder_names))
# sort the common folders
common_folders.sort()
print('The common folders are:', common_folders)
print(len(common_folders))
# Out:
# The folder names are: ['E10_B128_R0', 'E10_B256_R0', 'E10_B512_R0', 'E20_B64_R0', 'E20_B128_R0', 'E20_B256_R0', 'E20_B512_R0', 'E30_B64_R0', 'E30_B128_R0', 'E30_B256_R0', 'E30_B512_R0', 'E40_B64_R0', 'E40_B128_R0', 'E40_B256_R0', 'E40_B512_R0', 'E50_B128_R0', 'E50_B256_R0', 'E50_B512_R0', 'E10_B64_R0', 'E50_B64_R0', 'E80_B64_R0', 'E80_B128_R0', 'E80_B256_R0', 'E80_B512_R0', 'E80_B1024_R0', 'E100_B64_R0']
# The folder list is: ['E10_B64_R0', 'E10_B128_R0', 'E10_B256_R0', 'E10_B512_R0', 'E10_B1024_R0', 'E20_B64_R0', 'E20_B128_R0', 'E20_B256_R0', 'E20_B512_R0', 'E20_B1024_R0', 'E30_B64_R0', 'E30_B128_R0', 'E30_B256_R0', 'E30_B512_R0', 'E30_B1024_R0', 'E40_B64_R0', 'E40_B128_R0', 'E40_B256_R0', 'E40_B512_R0', 'E40_B1024_R0', 'E50_B64_R0', 'E50_B128_R0', 'E50_B256_R0', 'E50_B512_R0', 'E50_B1024_R0', 'E80_B64_R0', 'E80_B128_R0', 'E80_B256_R0', 'E80_B512_R0', 'E80_B1024_R0', 'E100_B64_R0', 'E100_B128_R0', 'E100_B256_R0', 'E100_B512_R0', 'E100_B1024_R0']
# The common folders are: ['E100_B64_R0', 'E10_B128_R0', 'E10_B256_R0', 'E10_B512_R0', 'E10_B64_R0', 'E20_B128_R0', 'E20_B256_R0', 'E20_B512_R0', 'E20_B64_R0', 'E30_B128_R0', 'E30_B256_R0', 'E30_B512_R0', 'E30_B64_R0', 'E40_B128_R0', 'E40_B256_R0', 'E40_B512_R0', 'E40_B64_R0', 'E50_B128_R0', 'E50_B256_R0', 'E50_B512_R0', 'E50_B64_R0', 'E80_B1024_R0', 'E80_B128_R0', 'E80_B256_R0', 'E80_B512_R0', 'E80_B64_R0']
# 26

# %% [markdown]
# ### analysis data

# %% [markdown]
# #### find the data in same epoch and batch size

# %%
name_dic = {
    'EpochEnergy': 'Epoch_energy',
    'EpochTime': 'Epoch_time',
    'TestAcc': 'Test_acc',
    'TrainAcc': 'Train_acc',
    'LayerTime': 'Layer_time',
    'TrainTime': 'Train_time',
    'TrainPartTime': 'Train_part_time'
}

# %%
# find the folders that have same epoch and batch size in common_folders
same_epoch_batch = []
for folder in common_folders:
    epoch = int(folder.split('_')[0][1:])
    batch = int(folder.split('_')[1][1:])
    same_epoch_batch.append((epoch, batch))
print('The same epoch and batch size are:', same_epoch_batch)

# find in each combination of epoch and batch size, find out the folder names
epoch_batch_folders = {}
for epoch, batch in same_epoch_batch:
    epoch_batch_folders[(epoch, batch)] = []
    for folder in common_folders:
        if int(folder.split('_')[0][1:]) == epoch and int(folder.split('_')[1][1:]) == batch:
            epoch_batch_folders[(epoch, batch)].append(folder)
print('The epoch and batch size folders are:', epoch_batch_folders)
# for each combination of epoch and batch size, find the average test accuracy, and the average energy consumption
avgenergy_acc = {}
energy_acc = {}
avgenergy_power = {}

for eb_comb in epoch_batch_folders:
    print('The epoch and batch size combination is:', eb_comb)
    # show the lenth of the values in the dictionary
    num_values = len(epoch_batch_folders[eb_comb])
    # print('The number of values in the dictionary is:', num_values)
    round_acc = np.zeros((num_values, 1))
    round_energy = np.zeros((num_values, 1))
    round_avgenergy = np.zeros((num_values, 1))
    powersec_round = np.zeros((num_values, 1))
    for folder in epoch_batch_folders[eb_comb]:
        files_path = data_path / folder
        files = os.listdir(files_path)
        # print('The files in the folder are:', files_path, files)
        test_acc = []
        epoch_energy = []
        powersec_epoch = []
        for f in files:
            name = f.split('.')[0]
            file_path = files_path / f
            if name in name_dic['TestAcc']:
                TestAcc = np.load(file_path, allow_pickle=True)
                test_acc.append(TestAcc[-1]) # get the last test accuracy
            elif name in name_dic['EpochEnergy']:
                EpochEnergy = np.load(file_path, allow_pickle=True)
                for energyrow in EpochEnergy:
                    power_persec = np.mean(energyrow[0]) # get the avg power consumpt¡ion of each second in the epoch
                    powersec_epoch.append(power_persec)
                    sum_row = np.sum(energyrow[0]) # sum the energy consumption of each epoch
                    epoch_energy.append(sum_row)
        # add to the round_acc and round_energy
        indexfolder = folder.split('_')[-1][1:]
        round_acc[int(indexfolder)] = np.mean(test_acc)
        powersec_round[int(indexfolder)] = np.mean(powersec_epoch)
        round_avgenergy[int(indexfolder)] = np.mean(epoch_energy)  
        round_energy[int(indexfolder)] = np.sum(epoch_energy)
    # calculate the average test accuracy and energy consumption
    avg_acc = np.mean(round_acc)
    powersec = np.mean(powersec_round)
    avg_avgenergy = np.mean(round_avgenergy)
    avg_energy = np.mean(round_energy)
    avg_acc = '{:.3f}'.format(avg_acc)
    powersec = '{:.3f}'.format(powersec)
    avg_avgenergy = '{:.3f}'.format(avg_avgenergy)
    avg_energy = '{:.3f}'.format(avg_energy)
    print(f'The average test accuracy is: {avg_acc}')
    print(f'The average of average power consumption per second is: {powersec}')
    print(f'The average of average epoch energy consumption is: {avg_avgenergy}')
    print(f'The average of total energy consumption is: {avg_energy}')
    # save the average test accuracy and energy consumption to the dictionary,
    # the key is the eb_comb, and the value is the average test accuracy and energy consumption\
    avgenergy_acc[eb_comb] = (avg_acc, avg_avgenergy)
    energy_acc[eb_comb] = (avg_acc, avg_energy)
    avgenergy_power[eb_comb] = (powersec, avg_avgenergy)

print('The energy consumption and accuracy are:', energy_acc)
print('The average energy consumption and accuracy are:', avgenergy_acc)
print('The power consumption per second is:', avgenergy_power)
# Out:
# The same epoch and batch size are: [(100, 64), (10, 128), (10, 256), (10, 512), (10, 64), (20, 128), (20, 256), (20, 512), (20, 64), (30, 128), (30, 256), (30, 512), (30, 64), (40, 128), (40, 256), (40, 512), (40, 64), (50, 128), (50, 256), (50, 512), (50, 64), (80, 1024), (80, 128), (80, 256), (80, 512), (80, 64)]
# The epoch and batch size folders are: {(100, 64): ['E100_B64_R0'], (10, 128): ['E10_B128_R0'], (10, 256): ['E10_B256_R0'], (10, 512): ['E10_B512_R0'], (10, 64): ['E10_B64_R0'], (20, 128): ['E20_B128_R0'], (20, 256): ['E20_B256_R0'], (20, 512): ['E20_B512_R0'], (20, 64): ['E20_B64_R0'], (30, 128): ['E30_B128_R0'], (30, 256): ['E30_B256_R0'], (30, 512): ['E30_B512_R0'], (30, 64): ['E30_B64_R0'], (40, 128): ['E40_B128_R0'], (40, 256): ['E40_B256_R0'], (40, 512): ['E40_B512_R0'], (40, 64): ['E40_B64_R0'], (50, 128): ['E50_B128_R0'], (50, 256): ['E50_B256_R0'], (50, 512): ['E50_B512_R0'], (50, 64): ['E50_B64_R0'], (80, 1024): ['E80_B1024_R0'], (80, 128): ['E80_B128_R0'], (80, 256): ['E80_B256_R0'], (80, 512): ['E80_B512_R0'], (80, 64): ['E80_B64_R0']}
# The epoch and batch size combination is: (100, 64)
# The average test accuracy is: 0.502
# The average of average power consumption per second is: 101.571
# The average of average epoch energy consumption is: 3216.730
# The average of total energy consumption is: 321673.010
# The epoch and batch size combination is: (10, 128)
# The average test accuracy is: 0.222
# The average of average power consumption per second is: 95.453
# The average of average epoch energy consumption is: 3097.983
# The average of total energy consumption is: 30979.830
# The epoch and batch size combination is: (10, 256)
# The average test accuracy is: 0.114
# The average of average power consumption per second is: 111.562
# The average of average epoch energy consumption is: 2979.747
# The average of total energy consumption is: 29797.470
# The epoch and batch size combination is: (10, 512)
# The average test accuracy is: 0.040
# The average of average power consumption per second is: 118.351
# The average of average epoch energy consumption is: 3188.331
# The average of total energy consumption is: 31883.310
# The epoch and batch size combination is: (10, 64)
# The average test accuracy is: 0.308
# The average of average power consumption per second is: 101.856
# The average of average epoch energy consumption is: 3065.587
# The average of total energy consumption is: 30655.870
# The epoch and batch size combination is: (20, 128)
# The average test accuracy is: 0.363
# The average of average power consumption per second is: 98.419
# The average of average epoch energy consumption is: 3000.423
# The average of total energy consumption is: 60008.450
# The epoch and batch size combination is: (20, 256)
# The average test accuracy is: 0.260
# The average of average power consumption per second is: 105.050
# The average of average epoch energy consumption is: 2935.135
# The average of total energy consumption is: 58702.710
# The epoch and batch size combination is: (20, 512)
# The average test accuracy is: 0.158
# The average of average power consumption per second is: 119.415
# The average of average epoch energy consumption is: 3169.486
# The average of total energy consumption is: 63389.710
# The epoch and batch size combination is: (20, 64)
# The average test accuracy is: 0.447
# The average of average power consumption per second is: 99.392
# The average of average epoch energy consumption is: 3122.115
# The average of total energy consumption is: 62442.290
# The epoch and batch size combination is: (30, 128)
# The average test accuracy is: 0.421
# The average of average power consumption per second is: 101.237
# The average of average epoch energy consumption is: 2845.340
# The average of total energy consumption is: 85360.200
# The epoch and batch size combination is: (30, 256)
# The average test accuracy is: 0.325
# The average of average power consumption per second is: 106.207
# The average of average epoch energy consumption is: 3007.064
# The average of total energy consumption is: 90211.910
# The epoch and batch size combination is: (30, 512)
# The average test accuracy is: 0.208
# The average of average power consumption per second is: 110.092
# The average of average epoch energy consumption is: 3176.188
# The average of total energy consumption is: 95285.630
# The epoch and batch size combination is: (30, 64)
# The average test accuracy is: 0.485
# The average of average power consumption per second is: 99.465
# The average of average epoch energy consumption is: 3039.653
# The average of total energy consumption is: 91189.580
# The epoch and batch size combination is: (40, 128)
# The average test accuracy is: 0.459
# The average of average power consumption per second is: 98.038
# The average of average epoch energy consumption is: 2958.678
# The average of total energy consumption is: 118347.120
# The epoch and batch size combination is: (40, 256)
# The average test accuracy is: 0.367
# The average of average power consumption per second is: 103.643
# The average of average epoch energy consumption is: 3023.978
# The average of total energy consumption is: 120959.110
# The epoch and batch size combination is: (40, 512)
# The average test accuracy is: 0.281
# The average of average power consumption per second is: 111.823
# The average of average epoch energy consumption is: 3208.762
# The average of total energy consumption is: 128350.460
# The epoch and batch size combination is: (40, 64)
# The average test accuracy is: 0.493
# The average of average power consumption per second is: 96.905
# The average of average epoch energy consumption is: 3123.948
# The average of total energy consumption is: 124957.940
# The epoch and batch size combination is: (50, 128)
# The average test accuracy is: 0.476
# The average of average power consumption per second is: 103.152
# The average of average epoch energy consumption is: 2835.810
# The average of total energy consumption is: 141790.500
# The epoch and batch size combination is: (50, 256)
# The average test accuracy is: 0.399
# The average of average power consumption per second is: 112.689
# The average of average epoch energy consumption is: 3012.917
# The average of total energy consumption is: 150645.840
# The epoch and batch size combination is: (50, 512)
# The average test accuracy is: 0.303
# The average of average power consumption per second is: 120.170
# The average of average epoch energy consumption is: 3184.624
# The average of total energy consumption is: 159231.220
# The epoch and batch size combination is: (50, 64)
# The average test accuracy is: 0.517
# The average of average power consumption per second is: 101.030
# The average of average epoch energy consumption is: 3099.029
# The average of total energy consumption is: 154951.450
# The epoch and batch size combination is: (80, 1024)
# The average test accuracy is: 0.282
# The average of average power consumption per second is: 118.725
# The average of average epoch energy consumption is: 3408.839
# The average of total energy consumption is: 272707.100
# The epoch and batch size combination is: (80, 128)
# The average test accuracy is: 0.491
# The average of average power consumption per second is: 106.598
# The average of average epoch energy consumption is: 2975.773
# The average of total energy consumption is: 238061.820
# The epoch and batch size combination is: (80, 256)
# The average test accuracy is: 0.450
# The average of average power consumption per second is: 118.216
# The average of average epoch energy consumption is: 3140.789
# The average of total energy consumption is: 251263.120
# The epoch and batch size combination is: (80, 512)
# The average test accuracy is: 0.389
# The average of average power consumption per second is: 120.135
# The average of average epoch energy consumption is: 3231.326
# The average of total energy consumption is: 258506.050
# The epoch and batch size combination is: (80, 64)
# The average test accuracy is: 0.517
# The average of average power consumption per second is: 99.716
# The average of average epoch energy consumption is: 3251.733
# The average of total energy consumption is: 260138.610
# The energy consumption and accuracy are: {(100, 64): ('0.502', '321673.010'), (10, 128): ('0.222', '30979.830'), (10, 256): ('0.114', '29797.470'), (10, 512): ('0.040', '31883.310'), (10, 64): ('0.308', '30655.870'), (20, 128): ('0.363', '60008.450'), (20, 256): ('0.260', '58702.710'), (20, 512): ('0.158', '63389.710'), (20, 64): ('0.447', '62442.290'), (30, 128): ('0.421', '85360.200'), (30, 256): ('0.325', '90211.910'), (30, 512): ('0.208', '95285.630'), (30, 64): ('0.485', '91189.580'), (40, 128): ('0.459', '118347.120'), (40, 256): ('0.367', '120959.110'), (40, 512): ('0.281', '128350.460'), (40, 64): ('0.493', '124957.940'), (50, 128): ('0.476', '141790.500'), (50, 256): ('0.399', '150645.840'), (50, 512): ('0.303', '159231.220'), (50, 64): ('0.517', '154951.450'), (80, 1024): ('0.282', '272707.100'), (80, 128): ('0.491', '238061.820'), (80, 256): ('0.450', '251263.120'), (80, 512): ('0.389', '258506.050'), (80, 64): ('0.517', '260138.610')}
# The average energy consumption and accuracy are: {(100, 64): ('0.502', '3216.730'), (10, 128): ('0.222', '3097.983'), (10, 256): ('0.114', '2979.747'), (10, 512): ('0.040', '3188.331'), (10, 64): ('0.308', '3065.587'), (20, 128): ('0.363', '3000.423'), (20, 256): ('0.260', '2935.135'), (20, 512): ('0.158', '3169.486'), (20, 64): ('0.447', '3122.115'), (30, 128): ('0.421', '2845.340'), (30, 256): ('0.325', '3007.064'), (30, 512): ('0.208', '3176.188'), (30, 64): ('0.485', '3039.653'), (40, 128): ('0.459', '2958.678'), (40, 256): ('0.367', '3023.978'), (40, 512): ('0.281', '3208.762'), (40, 64): ('0.493', '3123.948'), (50, 128): ('0.476', '2835.810'), (50, 256): ('0.399', '3012.917'), (50, 512): ('0.303', '3184.624'), (50, 64): ('0.517', '3099.029'), (80, 1024): ('0.282', '3408.839'), (80, 128): ('0.491', '2975.773'), (80, 256): ('0.450', '3140.789'), (80, 512): ('0.389', '3231.326'), (80, 64): ('0.517', '3251.733')}
# The power consumption per second is: {(100, 64): ('101.571', '3216.730'), (10, 128): ('95.453', '3097.983'), (10, 256): ('111.562', '2979.747'), (10, 512): ('118.351', '3188.331'), (10, 64): ('101.856', '3065.587'), (20, 128): ('98.419', '3000.423'), (20, 256): ('105.050', '2935.135'), (20, 512): ('119.415', '3169.486'), (20, 64): ('99.392', '3122.115'), (30, 128): ('101.237', '2845.340'), (30, 256): ('106.207', '3007.064'), (30, 512): ('110.092', '3176.188'), (30, 64): ('99.465', '3039.653'), (40, 128): ('98.038', '2958.678'), (40, 256): ('103.643', '3023.978'), (40, 512): ('111.823', '3208.762'), (40, 64): ('96.905', '3123.948'), (50, 128): ('103.152', '2835.810'), (50, 256): ('112.689', '3012.917'), (50, 512): ('120.170', '3184.624'), (50, 64): ('101.030', '3099.029'), (80, 1024): ('118.725', '3408.839'), (80, 128): ('106.598', '2975.773'), (80, 256): ('118.216', '3140.789'), (80, 512): ('120.135', '3231.326'), (80, 64): ('99.716', '3251.733')}

# %% [markdown]
# ### plot results

# %%
'''
The accuracy is the average of 5 rounds final test accuracy
The energy consumption is the average of 5 rounds total energy consumption
'''
# Prepare lists for plotting
energies = [float(values[1]) for values in energy_acc.values()]
accuracies = [float(values[0]) for values in energy_acc.values()]
labels = [f"e={key[0]}, b={key[1]}" for key in energy_acc.keys()]

# Extracting unique Param1 values and assigning colors
unique_param1 = np.unique([key[0] for key in energy_acc.keys()])
colors = ['blue', 'green', 'red', 'yellow', 'black', 'purple', 'orange']
color_map = dict(zip(unique_param1, colors))

# Prepare lists for plotting with colors
colors_for_plot = [color_map[key[0]] for key in energy_acc.keys()]

# Create scatter plot with colors
plt.figure(figsize=(10, 6))
for (energy, accuracy, label, color) in zip(energies, accuracies, labels, colors_for_plot):
    plt.scatter(energy, accuracy, color=color, label=label if label.split(',')[0] not in plt.gca().get_legend_handles_labels()[1] else "")
    plt.text(energy, accuracy, label, fontsize=9)

# Adding titles and labels
plt.title('total energy consumption vs accuracy')
plt.xlabel('Energy')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(title="energy and acc", loc='lower right', fontsize=5, title_fontsize='small')

# Show plot
plt.show()

# %%
'''
The accuracy is the average of 5 rounds final test accuracy
The energy consumption is the average of 5 rounds total energy consumption
'''
# Prepare lists for plotting
energies = [float(values[1]) for values in avgenergy_acc.values()]
accuracies = [float(values[0]) for values in avgenergy_acc.values()]
labels = [f"e={key[0]}, b={key[1]}" for key in avgenergy_acc.keys()]

# Extracting unique Param1 values and assigning colors
unique_param1 = np.unique([key[0] for key in avgenergy_acc.keys()])
colors = ['blue', 'green', 'red', 'yellow', 'black', 'purple', 'orange']
color_map = dict(zip(unique_param1, colors))

# Prepare lists for plotting with colors
colors_for_plot = [color_map[key[0]] for key in avgenergy_acc.keys()]

# Create scatter plot with colors
plt.figure(figsize=(10, 6))
for (energy, accuracy, label, color) in zip(energies, accuracies, labels, colors_for_plot):
    plt.scatter(energy, accuracy, color=color, label=label if label.split(',')[0] not in plt.gca().get_legend_handles_labels()[1] else "")
    plt.text(energy, accuracy, label, fontsize=9)

# Adding titles and labels
plt.title('average energy consumption vs accuracy')
plt.xlabel('avg Energy')
plt.ylabel('Accuracy')
plt.grid(True)
# set the legend size
plt.legend(title="avg energy and acc", loc='lower right', fontsize=5, title_fontsize='small')

# Show plot
plt.show()

# %%
'''
The accuracy is the average of 5 rounds power consumption per second
The energy consumption is the average of 5 rounds total energy consumption
'''
# Prepare lists for plotting
energies = [float(values[1]) for values in avgenergy_power.values()]
accuracies = [float(values[0]) for values in avgenergy_power.values()]
labels = [f"e={key[0]}, b={key[1]}" for key in avgenergy_power.keys()]

# Extracting unique Param1 values and assigning colors
unique_param1 = np.unique([key[0] for key in avgenergy_power.keys()])
colors = ['blue', 'green', 'red', 'yellow', 'black', 'purple', 'orange']
color_map = dict(zip(unique_param1, colors))

# Prepare lists for plotting with colors
colors_for_plot = [color_map[key[0]] for key in avgenergy_power.keys()]

# Create scatter plot with colors
plt.figure(figsize=(10, 6))
for (energy, accuracy, label, color) in zip(energies, accuracies, labels, colors_for_plot):
    plt.scatter(energy, accuracy, color=color, label=label if label.split(',')[0] not in plt.gca().get_legend_handles_labels()[1] else "")
    plt.text(energy, accuracy, label, fontsize=9)

# Adding titles and labels
plt.title('average energy consumption vs power')
plt.xlabel('avg Energy')
plt.ylabel('power per second')
plt.grid(True)
plt.legend(title="avg energy and power", loc='lower right', fontsize=5, title_fontsize='small')

# Show plot
plt.show()

# %%
# Data dictionary
data = avgpower_std
# Extract unique epochs and batch sizes
epochs = sorted(set(e for e, _ in data.keys()))
batch_sizes = sorted(set(b for _, b in data.keys()))

# Colors and labels for different epochs
colors = ['b', 'g', 'r', 'y', 'black']  # Blue, Green, Red, Yellow, Purple for epochs 10, 20, 30
labels = ['Epoch 10', 'Epoch 20', 'Epoch 30', 'Epoch 40', 'Epoch 50', 'Epoch 80', 'Epoch 100']

# Create a figure
plt.figure(figsize=(12, 8))

# Plot data with annotations
for i, epoch in enumerate(epochs):
    x = []
    y = []
    yerr = []
    for batch_size in batch_sizes:
        avg_power, std_dev = data[(epoch, batch_size)]
        x.append(batch_size)
        y.append(float(avg_power))
        yerr.append(float(std_dev))
        
        # Annotate each data point
        plt.text(batch_size, float(avg_power), f'({epoch},{batch_size})')

    # Plot error bars and points
    plt.errorbar(x, y, yerr=yerr, fmt='o-', color=colors[i], capsize=5, label=labels[i])

# Set labels and title
plt.xlabel('Batch Size')
plt.ylabel('Average Power Consumption')
plt.title('Power Consumption vs Batch Size for Different Epochs')
plt.grid(True)
plt.legend()

# Display the plot
plt.show()
