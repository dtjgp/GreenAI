# %% [markdown]
# ## This code is to find out the different of each epoch and batch size combination

# %%
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Path

# %%
'''find the Model path'''
# find the current path
current_path = os.getcwd()
print('The current path is:', current_path)

# find the parent path
parent_path = Path(current_path).parent
print('The parent path is:', parent_path)

# find the data path
data_path = parent_path / 'Data/alexnet/fashion_mnist/'
print('The data path is:', data_path)
# Out:
# The current path is: /Users/dtjgp/Learning/GreenAI/Cloud/4090/code
# The parent path is: /Users/dtjgp/Learning/GreenAI/Cloud/4090
# The data path is: /Users/dtjgp/Learning/GreenAI/Cloud/4090/Data/alexnet/fashion_mnist

# %% [markdown]
# ### extract data

# %%
batch_sizes = [64, 128, 256, 512,1024, 2048]
epochs = [10, 20, 30, 40, 50]
rounds = 3

# %% [markdown]
# #### read all the data from all the folders

# %%
folder_list = []
for epoch in epochs:
    for batch in batch_sizes:
        for round in range(rounds):
            folder_name = 'E' + str(epoch) + '_B' + str(batch) + '_R' + str(round)
            # print('The folder name is:', folder_name)
            folder_list.append(folder_name)
            
# find the folders in the data path
folder_names = os.listdir(data_path)
print('The folder names are:', folder_names)
print('The folder list is:', folder_list)

# find the common folders
common_folders = list(set(folder_list).intersection(folder_names))
# sort the common folders
common_folders.sort()
print('The common folders are:', common_folders)
print(len(common_folders))
# Out:
# The folder names are: ['E20_B256_R1', 'E50_B64_R1', 'E30_B256_R1', 'E30_B128_R2', 'E20_B128_R2', 'E20_B64_R2', 'E50_B64_R0', 'E20_B256_R0', 'E30_B256_R0', 'E10_B128_R0', 'E40_B64_R0', 'E30_B64_R2', 'E50_B512_R1', 'E40_B512_R1', 'E10_B128_R1', 'E10_B256_R2', 'E30_B2048_R0', 'E50_B512_R0', 'E40_B512_R0', 'E40_B64_R1', 'E10_B64_R2', 'E20_B512_R1', 'E30_B512_R1', 'E10_B1024_R0', 'E20_B512_R0', 'E30_B512_R0', 'E40_B128_R2', 'E50_B128_R2', 'E50_B256_R1', 'E40_B256_R1', 'E20_B2048_R0', 'E10_B512_R2', 'E50_B256_R0', 'E40_B256_R0', 'E30_B128_R1', 'E20_B128_R1', 'E20_B256_R2', 'E50_B64_R2', 'E20_B64_R0', 'E30_B256_R2', 'E20_B64_R1', 'E30_B128_R0', 'E20_B128_R0', 'E20_B1024_R0', 'E30_B64_R1', 'E50_B512_R2', 'E40_B512_R2', 'E10_B256_R0', 'E30_B64_R0', 'E40_B64_R2', 'E40_B1024_R0', 'E10_B256_R1', 'E10_B2048_R0', 'E10_B128_R2', 'E20_B512_R2', 'E30_B512_R2', 'E10_B64_R1', 'E12_B256_R0', 'E10_B64_R0', 'E30_B1024_R0', 'E50_B256_R2', 'E40_B256_R2', 'E40_B128_R1', 'E50_B128_R1', 'E10_B512_R0', 'E40_B128_R0', 'E50_B128_R0', 'E10_B512_R1']
2', 'E40_B256_R0', 'E40_B256_R1', 'E40_B256_R2', 'E40_B512_R0', 'E40_B512_R1', 'E40_B512_R2', 'E40_B64_R0', 'E40_B64_R1', 'E40_B64_R2', 'E50_B128_R0', 'E50_B128_R1', 'E50_B128_R2', 'E50_B256_R0', 'E50_B256_R1', 'E50_B256_R2', 'E50_B512_R0', 'E50_B512_R1', 'E50_B512_R2', 'E50_B64_R0', 'E50_B64_R1', 'E50_B64_R2']
# 67

# %% [markdown]
# ### analysis data

# %% [markdown]
# #### find the data in same epoch and batch size

# %%
name_dic = {
    'EpochEnergy': 'Epoch_energy',
    'EpochTime': 'Epoch_time',
    'TestAcc': 'Test_acc',
    'TrainAcc': 'Train_acc',
    'LayerTime': 'Layer_time',
    'TrainTime': 'Train_time',
    'TrainPartTime': 'Train_part_time'
}

# %%
# find the folders that have same epoch and batch size in common_folders
same_epoch_batch = []
for folder in common_folders:
    epoch = int(folder.split('_')[0][1:])
    batch = int(folder.split('_')[1][1:])
    same_epoch_batch.append((epoch, batch))
print('The same epoch and batch size are:', same_epoch_batch)

# find in each combination of epoch and batch size, find out the folder names
epoch_batch_folders = {}
for epoch, batch in same_epoch_batch:
    epoch_batch_folders[(epoch, batch)] = []
    for folder in common_folders:
        if int(folder.split('_')[0][1:]) == epoch and int(folder.split('_')[1][1:]) == batch:
            epoch_batch_folders[(epoch, batch)].append(folder)
print('The epoch and batch size folders are:', epoch_batch_folders)
# for each combination of epoch and batch size, find the average test accuracy, and the average energy consumption
avgenergy_acc = {}
energy_acc = {}
avgenergy_power = {}
avgpower_std = {}
epochpower_std = {}
epochpower_epoch = {}

for eb_comb in epoch_batch_folders:
    epoch_num = eb_comb[0]
    print('The epoch and batch size combination is:', eb_comb)
    # show the lenth of the values in the dictionary
    num_values = len(epoch_batch_folders[eb_comb])
    # print('The number of values in the dictionary is:', num_values)
    round_acc = np.zeros((num_values, 1))
    round_energy = np.zeros((num_values, 1))
    round_avgenergy = np.zeros((num_values, 1))
    powersec_round = np.zeros((num_values, 1))
    powerstd_epoch = np.zeros((num_values, 1))
    for folder in epoch_batch_folders[eb_comb]:
        files_path = data_path / folder
        files = os.listdir(files_path)
        # print('The files in the folder are:', files_path, files)
        test_acc = []
        epoch_energy = []
        powersec_epoch = []
        powerstd_epoch = []
        for f in files:
            name = f.split('.')[0]
            file_path = files_path / f
            if name in name_dic['TestAcc']:
                TestAcc = np.load(file_path, allow_pickle=True)
                test_acc.append(TestAcc[-1]) # get the last test accuracy
            elif name in name_dic['EpochEnergy']:
                EpochEnergy = np.load(file_path, allow_pickle=True)
                for energyrow in EpochEnergy:
                    # get the power consumption of each second in the epoch as well as the std of the power consumption
                    power_persec = np.mean(energyrow[0]) # get the avg power consumpt¡ion of each second in the epoch
                    power_std = np.std(energyrow[0]) # get the std of the power consumption of each second in the epoch
                    powersec_epoch.append(power_persec)
                    powerstd_epoch.append(power_std)
                    sum_row = np.sum(energyrow[0]) # sum the energy consumption of each epoch
                    epoch_energy.append(sum_row)
        # add to the round_acc and round_energy
        indexfolder = folder.split('_')[-1][1:]
        round_acc[int(indexfolder)] = np.mean(test_acc)
        powersec_round[int(indexfolder)] = np.mean(powersec_epoch)
        powerstd_epoch[int(indexfolder)] = np.mean(powerstd_epoch)
        round_avgenergy[int(indexfolder)] = np.mean(epoch_energy)  
        round_energy[int(indexfolder)] = np.sum(epoch_energy)
    # calculate the average test accuracy and energy consumption
    avg_acc = np.mean(round_acc)
    powersec = np.mean(powersec_round)
    powerstd = np.mean(powerstd_epoch)
    avg_avgenergy = np.mean(round_avgenergy)
    avg_energy = np.mean(round_energy)
    avg_acc = '{:.3f}'.format(avg_acc)
    powerstd = '{:.3f}'.format(powerstd)
    powersec = '{:.3f}'.format(powersec)
    avg_avgenergy = '{:.3f}'.format(avg_avgenergy)
    avg_energy = '{:.3f}'.format(avg_energy)
    print(f'The average test accuracy is: {avg_acc}')
    print(f'The average of average power consumption per second is: {powersec}')
    print(f'The average of average epoch energy consumption is: {avg_avgenergy}')
    print(f'The average of total energy consumption is: {avg_energy}')
    print(f'The average of power consumption std is: {powerstd}')
    # save the average test accuracy and energy consumption to the dictionary,
    # the key is the eb_comb, and the value is the average test accuracy and energy consumption\
    avgenergy_acc[eb_comb] = (avg_acc, avg_avgenergy)
    energy_acc[eb_comb] = (avg_acc, avg_energy)
    avgenergy_power[eb_comb] = (powersec, avg_avgenergy)
    avgpower_std[eb_comb] = (powersec, powerstd)
    epochpower_std[eb_comb] = (avg_avgenergy, powerstd)
    epochpower_epoch[eb_comb] = (epoch_num, avg_avgenergy)


print('The energy consumption and accuracy are:', energy_acc)
print('The average energy consumption and accuracy are:', avgenergy_acc)
print('The power consumption per second is:', avgenergy_power)
print('The power consumption and std are:', avgpower_std)
print('The power consumption and std of epoch are:', epochpower_std)
print('The power consumption and epoch are:', epochpower_epoch)
# Out:
# The same epoch and batch size are: [(10, 1024), (10, 128), (10, 128), (10, 128), (10, 2048), (10, 256), (10, 256), (10, 256), (10, 512), (10, 512), (10, 512), (10, 64), (10, 64), (10, 64), (20, 1024), (20, 128), (20, 128), (20, 128), (20, 2048), (20, 256), (20, 256), (20, 256), (20, 512), (20, 512), (20, 512), (20, 64), (20, 64), (20, 64), (30, 1024), (30, 128), (30, 128), (30, 128), (30, 2048), (30, 256), (30, 256), (30, 256), (30, 512), (30, 512), (30, 512), (30, 64), (30, 64), (30, 64), (40, 1024), (40, 128), (40, 128), (40, 128), (40, 256), (40, 256), (40, 256), (40, 512), (40, 512), (40, 512), (40, 64), (40, 64), (40, 64), (50, 128), (50, 128), (50, 128), (50, 256), (50, 256), (50, 256), (50, 512), (50, 512), (50, 512), (50, 64), (50, 64), (50, 64)]
# The epoch and batch size folders are: {(10, 1024): ['E10_B1024_R0'], (10, 128): ['E10_B128_R0', 'E10_B128_R1', 'E10_B128_R2'], (10, 2048): ['E10_B2048_R0'], (10, 256): ['E10_B256_R0', 'E10_B256_R1', 'E10_B256_R2'], (10, 512): ['E10_B512_R0', 'E10_B512_R1', 'E10_B512_R2'], (10, 64): ['E10_B64_R0', 'E10_B64_R1', 'E10_B64_R2'], (20, 1024): ['E20_B1024_R0'], (20, 128): ['E20_B128_R0', 'E20_B128_R1', 'E20_B128_R2'], (20, 2048): ['E20_B2048_R0'], (20, 256): ['E20_B256_R0', 'E20_B256_R1', 'E20_B256_R2'], (20, 512): ['E20_B512_R0', 'E20_B512_R1', 'E20_B512_R2'], (20, 64): ['E20_B64_R0', 'E20_B64_R1', 'E20_B64_R2'], (30, 1024): ['E30_B1024_R0'], (30, 128): ['E30_B128_R0', 'E30_B128_R1', 'E30_B128_R2'], (30, 2048): ['E30_B2048_R0'], (30, 256): ['E30_B256_R0', 'E30_B256_R1', 'E30_B256_R2'], (30, 512): ['E30_B512_R0', 'E30_B512_R1', 'E30_B512_R2'], (30, 64): ['E30_B64_R0', 'E30_B64_R1', 'E30_B64_R2'], (40, 1024): ['E40_B1024_R0'], (40, 128): ['E40_B128_R0', 'E40_B128_R1', 'E40_B128_R2'], (40, 256): ['E40_B256_R0', 'E40_B256_R1', 'E40_B256_R2'], (40, 512): ['E40_B512_R0', 'E40_B512_R1', 'E40_B512_R2'], (40, 64): ['E40_B64_R0', 'E40_B64_R1', 'E40_B64_R2'], (50, 128): ['E50_B128_R0', 'E50_B128_R1', 'E50_B128_R2'], (50, 256): ['E50_B256_R0', 'E50_B256_R1', 'E50_B256_R2'], (50, 512): ['E50_B512_R0', 'E50_B512_R1', 'E50_B512_R2'], (50, 64): ['E50_B64_R0', 'E50_B64_R1', 'E50_B64_R2']}
# The epoch and batch size combination is: (10, 1024)
# The average test accuracy is: 0.790
# The average of average power consumption per second is: 153.521
# The average of average epoch energy consumption is: 2669.003
# The average of total energy consumption is: 26690.030
# The average of power consumption std is: 43.676
# The epoch and batch size combination is: (10, 128)
# The average test accuracy is: 0.886
# The average of average power consumption per second is: 160.682
# The average of average epoch energy consumption is: 3120.123
# The average of total energy consumption is: 31201.233
# The average of power consumption std is: 32.780
# The epoch and batch size combination is: (10, 2048)
# The average test accuracy is: 0.669
# The average of average power consumption per second is: 143.781
# The average of average epoch energy consumption is: 2715.174
# The average of total energy consumption is: 27151.740
# The average of power consumption std is: 53.569
# The epoch and batch size combination is: (10, 256)
# The average test accuracy is: 0.863
# The average of average power consumption per second is: 159.873
# The average of average epoch energy consumption is: 3021.187
# The average of total energy consumption is: 30211.867
# The average of power consumption std is: 36.903
# The epoch and batch size combination is: (10, 512)
# The average test accuracy is: 0.810
# The average of average power consumption per second is: 165.847
# The average of average epoch energy consumption is: 2919.223
# The average of total energy consumption is: 29192.227
# The average of power consumption std is: 40.006
# The epoch and batch size combination is: (10, 64)
# The average test accuracy is: 0.897
# The average of power consumption std is: 44.031
# The epoch and batch size combination is: (40, 128)
# The average test accuracy is: 0.920
# The average of average power consumption per second is: 156.123
# The average of average epoch energy consumption is: 3133.088
# The average of total energy consumption is: 125323.530
# The average of power consumption std is: 31.710
# The epoch and batch size combination is: (40, 256)
# The average test accuracy is: 0.897
# The average of average power consumption per second is: 159.568
# The average of average epoch energy consumption is: 3083.936
# The average of total energy consumption is: 123357.443
# The average of power consumption std is: 36.625
# The epoch and batch size combination is: (40, 512)
# The average test accuracy is: 0.884
# The average of average power consumption per second is: 163.046
# The average of average epoch energy consumption is: 2981.746
# The average of total energy consumption is: 119269.833
# The average of power consumption std is: 41.646
# The epoch and batch size combination is: (40, 64)
# The average test accuracy is: 0.924
# The average of average power consumption per second is: 140.615
# The average of average epoch energy consumption is: 3125.881
# The average of total energy consumption is: 125035.257
# The average of power consumption std is: 31.533
# The epoch and batch size combination is: (50, 128)
# The average test accuracy is: 0.924
# The average of average power consumption per second is: 158.790
# The average of average epoch energy consumption is: 3137.756
# The average of total energy consumption is: 156887.823
# The average of power consumption std is: 32.889
# The epoch and batch size combination is: (50, 256)
# The average test accuracy is: 0.907
# The average of average power consumption per second is: 160.245
# The average of average epoch energy consumption is: 3086.679
# The average of total energy consumption is: 154333.927
# The average of power consumption std is: 36.327
# The epoch and batch size combination is: (50, 512)
# The average test accuracy is: 0.882
# The average of average power consumption per second is: 162.529
# The average of average epoch energy consumption is: 3029.440
# The average of total energy consumption is: 151472.023
# The average of power consumption std is: 40.327
# The epoch and batch size combination is: (50, 64)
# The average test accuracy is: 0.926
# The average of average power consumption per second is: 142.818
# The average of average epoch energy consumption is: 3123.881
# The average of total energy consumption is: 156194.067
# The average of power consumption std is: 29.784
# The energy consumption and accuracy are: {(10, 1024): ('0.790', '26690.030'), (10, 128): ('0.886', '31201.233'), (10, 2048): ('0.669', '27151.740'), (10, 256): ('0.863', '30211.867'), (10, 512): ('0.810', '29192.227'), (10, 64): ('0.897', '30663.797'), (20, 1024): ('0.849', '53899.870'), (20, 128): ('0.906', '62595.870'), (20, 2048): ('0.795', '52945.460'), (20, 256): ('0.884', '58584.500'), (20, 512): ('0.865', '59324.083'), (20, 64): ('0.914', '61286.583'), (30, 1024): ('0.859', '80674.940'), (30, 128): ('0.915', '96218.223'), (30, 2048): ('0.822', '79806.690'), (30, 256): ('0.896', '92621.567'), (30, 512): ('0.877', '90020.337'), (30, 64): ('0.924', '92204.333'), (40, 1024): ('0.873', '107429.750'), (40, 128): ('0.920', '125323.530'), (40, 256): ('0.897', '123357.443'), (40, 512): ('0.884', '119269.833'), (40, 64): ('0.924', '125035.257'), (50, 128): ('0.924', '156887.823'), (50, 256): ('0.907', '154333.927'), (50, 512): ('0.882', '151472.023'), (50, 64): ('0.926', '156194.067')}
# The power consumption and std of epoch are: {(10, 1024): ('2669.003', '43.676'), (10, 128): ('3120.123', '32.780'), (10, 2048): ('2715.174', '53.569'), (10, 256): ('3021.187', '36.903'), (10, 512): ('2919.223', '40.006'), (10, 64): ('3066.380', '28.857'), (20, 1024): ('2694.993', '43.976'), (20, 128): ('3129.793', '32.945'), (20, 2048): ('2647.273', '57.247'), (20, 256): ('2929.225', '36.289'), (20, 512): ('2966.204', '41.042'), (20, 64): ('3064.329', '27.399'), (30, 1024): ('2689.165', '45.168'), (30, 128): ('3207.274', '34.085'), (30, 2048): ('2660.223', '57.144'), (30, 256): ('3087.386', '35.257'), (30, 512): ('3000.678', '40.454'), (30, 64): ('3073.478', '24.204'), (40, 1024): ('2685.744', '44.031'), (40, 128): ('3133.088', '31.710'), (40, 256): ('3083.936', '36.625'), (40, 512): ('2981.746', '41.646'), (40, 64): ('3125.881', '31.533'), (50, 128): ('3137.756', '32.889'), (50, 256): ('3086.679', '36.327'), (50, 512): ('3029.440', '40.327'), (50, 64): ('3123.881', '29.784')}
# The power consumption and epoch are: {(10, 1024): (10, '2669.003'), (10, 128): (10, '3120.123'), (10, 2048): (10, '2715.174'), (10, 256): (10, '3021.187'), (10, 512): (10, '2919.223'), (10, 64): (10, '3066.380'), (20, 1024): (20, '2694.993'), (20, 128): (20, '3129.793'), (20, 2048): (20, '2647.273'), (20, 256): (20, '2929.225'), (20, 512): (20, '2966.204'), (20, 64): (20, '3064.329'), (30, 1024): (30, '2689.165'), (30, 128): (30, '3207.274'), (30, 2048): (30, '2660.223'), (30, 256): (30, '3087.386'), (30, 512): (30, '3000.678'), (30, 64): (30, '3073.478'), (40, 1024): (40, '2685.744'), (40, 128): (40, '3133.088'), (40, 256): (40, '3083.936'), (40, 512): (40, '2981.746'), (40, 64): (40, '3125.881'), (50, 128): (50, '3137.756'), (50, 256): (50, '3086.679'), (50, 512): (50, '3029.440'), (50, 64): (50, '3123.881')}

# %% [markdown]
# ### plot results

# %%
'''
The accuracy is the average of 5 rounds final test accuracy
The energy consumption is the total of 5 rounds total energy consumption
'''
# Prepare lists for plotting
energies = [float(values[1]) for values in energy_acc.values()]
accuracies = [float(values[0]) for values in energy_acc.values()]
labels = [f"e={key[0]}, b={key[1]}" for key in energy_acc.keys()]

# Extracting unique Param1 values and assigning colors
unique_param1 = np.unique([key[0] for key in energy_acc.keys()])
colors = ['blue', 'green', 'red', 'cyan', 'magenta']
color_map = dict(zip(unique_param1, colors))

# Prepare lists for plotting with colors
colors_for_plot = [color_map[key[0]] for key in energy_acc.keys()]

# Create scatter plot with colors
plt.figure(figsize=(10, 6))
for (energy, accuracy, label, color) in zip(energies, accuracies, labels, colors_for_plot):
    plt.scatter(energy, accuracy, color=color, label=label if label.split(',')[0] not in plt.gca().get_legend_handles_labels()[1] else "")
    plt.text(energy, accuracy, label, fontsize=9)

# Adding titles and labels
plt.title('total energy consumption vs accuracy')
plt.xlabel('Energy')
plt.ylabel('Accuracy')
plt.grid(True)
# set the legend to outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Show plot
plt.show()

# %%
'''
The accuracy is the average of 5 rounds final test accuracy
The energy consumption is the total of 5 rounds total energy consumption
'''
# Prepare lists for plotting
energies = [float(values[1]) for values in epochpower_epoch.values()]
epoch = [float(values[0]) for values in epochpower_epoch.values()]
labels = [f"e={key[0]}, b={key[1]}" for key in epochpower_epoch.keys()]

# Extracting unique Param1 values and assigning colors
unique_param1 = np.unique([key[0] for key in epochpower_epoch.keys()])
colors = ['blue', 'green', 'red', 'cyan', 'magenta']
color_map = dict(zip(unique_param1, colors))

# Prepare lists for plotting with colors
colors_for_plot = [color_map[key[0]] for key in epochpower_epoch.keys()]

# Create scatter plot with colors
plt.figure(figsize=(10, 6))
for (energy, epochi, label, color) in zip(energies, epoch, labels, colors_for_plot):
    plt.scatter(energy, epochi, color=color, label=label if label.split(',')[0] not in plt.gca().get_legend_handles_labels()[1] else "")
    plt.text(energy, epochi, label, fontsize=9)

# Adding titles and labels, set the legend to be outside of the plot
plt.title('total energy consumption vs epoch')
plt.xlabel('Energy')
plt.ylabel('Epoch_num')
plt.grid(True)
plt.legend(title="energy and acc", bbox_to_anchor=(1.05, 1), loc='upper left')

# Show plot
plt.show()

# %%
'''
The accuracy is the average of 5 rounds final test accuracy
The energy consumption is the average of 5 rounds total energy consumption
'''
# Prepare lists for plotting
energies = [float(values[1]) for values in avgenergy_acc.values()]
accuracies = [float(values[0]) for values in avgenergy_acc.values()]
labels = [f"e={key[0]}, b={key[1]}" for key in avgenergy_acc.keys()]

# Extracting unique Param1 values and assigning colors
unique_param1 = np.unique([key[0] for key in avgenergy_acc.keys()])
colors = ['blue', 'green', 'red', 'cyan', 'magenta']
color_map = dict(zip(unique_param1, colors))

# Prepare lists for plotting with colors
colors_for_plot = [color_map[key[0]] for key in avgenergy_acc.keys()]

# Create scatter plot with colors
plt.figure(figsize=(10, 6))
for (energy, accuracy, label, color) in zip(energies, accuracies, labels, colors_for_plot):
    plt.scatter(energy, accuracy, color=color, label=label if label.split(',')[0] not in plt.gca().get_legend_handles_labels()[1] else "")
    plt.text(energy, accuracy, label, fontsize=9)

# Adding titles and labels
plt.title('average energy consumption vs accuracy')
plt.xlabel('avg Energy')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(title="energy and acc", loc='lower right', fontsize=5, title_fontsize='small')

# Show plot
plt.show()

# %%
'''
The accuracy is the average of 5 rounds power consumption per second
The energy consumption is the average of 5 rounds total energy consumption
'''
# Prepare lists for plotting
energies = [float(values[1]) for values in avgenergy_power.values()]
accuracies = [float(values[0]) for values in avgenergy_power.values()]
labels = [f"e={key[0]}, b={key[1]}" for key in avgenergy_power.keys()]

# Extracting unique Param1 values and assigning colors
unique_param1 = np.unique([key[0] for key in avgenergy_power.keys()])
colors = ['blue', 'green', 'red', 'cyan', 'magenta']
color_map = dict(zip(unique_param1, colors))

# Prepare lists for plotting with colors
colors_for_plot = [color_map[key[0]] for key in avgenergy_power.keys()]

# Create scatter plot with colors
plt.figure(figsize=(10, 6))
for (energy, accuracy, label, color) in zip(energies, accuracies, labels, colors_for_plot):
    plt.scatter(energy, accuracy, color=color, label=label if label.split(',')[0] not in plt.gca().get_legend_handles_labels()[1] else "")
    plt.text(energy, accuracy, label, fontsize=9)

# Adding titles and labels
plt.title('average energy consumption vs power')
plt.xlabel('avg Energy')
plt.ylabel('Power')
plt.grid(True)
plt.legend(title="avg energy and power", loc='lower right', fontsize=5, title_fontsize='small')

# Show plot
plt.show()

# %%
# Data dictionary
data = avgpower_std
# Extract unique epochs and batch sizes
epochs = sorted(set(e for e, _ in data.keys()))
batch_sizes = sorted(set(b for _, b in data.keys()))

# Colors and labels for different epochs
colors = ['blue', 'green', 'red', 'cyan', 'magenta']  # Blue, Green, Red for epochs 10, 20, 30
labels = ['Epoch 10', 'Epoch 20', 'Epoch 30', 'Epoch 40', 'Epoch 50']

# Create a figure
plt.figure(figsize=(12, 8))

# Plot data with annotations
for i, epoch in enumerate(epochs):
    x = []
    y = []
    yerr = []
    for batch_size in batch_sizes:
        if (epoch, batch_size) in data:
            avg_power, std_dev = data[(epoch, batch_size)]
            x.append(batch_size)
            y.append(float(avg_power))
            yerr.append(float(std_dev))
            
            # Annotate each data point
            plt.text(batch_size, float(avg_power), f'({epoch},{batch_size})')

    # Plot error bars and points
    plt.errorbar(x, y, yerr=yerr, fmt='o-', color=colors[i], capsize=5, label=labels[i])

# Set labels and title
plt.xlabel('Batch Size')
plt.ylabel('Average Power Consumption')
plt.title('Power Consumption vs Batch Size for Different Epochs')
plt.grid(True)
plt.legend()

# Display the plot
plt.show()

# %%
# Data dictionary
data = epochpower_std
# Extract unique epochs and batch sizes
epochs = sorted(set(e for e, _ in data.keys()))
batch_sizes = sorted(set(b for _, b in data.keys()))

# Colors and labels for different epochs
colors = ['blue', 'green', 'red', 'cyan', 'magenta']  # Blue, Green, Red for epochs 10, 20, 30
labels = ['Epoch 10', 'Epoch 20', 'Epoch 30', 'Epoch 40', 'Epoch 50']

# Create a figure
plt.figure(figsize=(12, 8))

# Plot data with annotations
for i, epoch in enumerate(epochs):
    x = []
    y = []
    yerr = []
    for batch_size in batch_sizes:
        if (epoch, batch_size) in data:
            avg_power, std_dev = data[(epoch, batch_size)]
            x.append(batch_size)
            y.append(float(avg_power))
            yerr.append(float(std_dev))
            
            # Annotate each data point
            plt.text(batch_size, float(avg_power), f'({epoch},{batch_size})')

    # Plot error bars and points
    plt.errorbar(x, y, yerr=yerr, fmt='o-', color=colors[i], capsize=5, label=labels[i])

# Set labels and title
plt.xlabel('Batch Size')
plt.ylabel('Average Power Consumption')
plt.title('Power Consumption vs Batch Size for Different Epochs')
plt.grid(True)
plt.legend()

# Display the plot
plt.show()
