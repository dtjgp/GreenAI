# %% [markdown]
# # This code is to find out the different of each epoch and batch size combination

# %%
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Path

# %%
'''find the Model path'''
# find the current path
current_path = os.getcwd()
print('The current path is:', current_path)

# find the parent path
parent_path = Path(current_path).parent
print('The parent path is:', parent_path)

# find the data path
data_path5 = parent_path / 'Data/googlenet_mod5_mod1'
data_path6 = parent_path / 'Data/googlenet_mod6_mod1'
data_path7 = parent_path / 'Data/googlenet_mod7_mod1'
data_path8 = parent_path / 'Data/googlenet_mod8_mod1'
data_path9 = parent_path / 'Data/googlenet_mod9_mod1'
print('The data path is:', data_path5, '\n', 
                           data_path6, '\n', 
                           data_path7, '\n', 
                           data_path8, '\n',
                           data_path9)
# Out:
# The current path is: /root/GreenAI/Cloud/4090/code
# The parent path is: /root/GreenAI/Cloud/4090
# The data path is: /root/GreenAI/Cloud/4090/Data/googlenet_mod5_mod1
#  /root/GreenAI/Cloud/4090/Data/googlenet_mod6_mod1
#  /root/GreenAI/Cloud/4090/Data/googlenet_mod7_mod1
#  /root/GreenAI/Cloud/4090/Data/googlenet_mod8_mod1
#  /root/GreenAI/Cloud/4090/Data/googlenet_mod9_mod1

# %% [markdown]
# ### extract data

# %%
fashion_path = 'fashion_mnist'
cifar_path = 'cifar100'

# %%
batch_sizes = [256]
epochs = [10]
rounds = 1
folder_name = f"E{epochs[0]}_B{batch_sizes[0]}_R{rounds-1}"
print(folder_name)
# Out:
# E10_B256_R0

# %%
f_path = fashion_path + '/' + folder_name
c_path = cifar_path + '/' + folder_name
print(f_path, c_path)
# Out:
# fashion_mnist/E10_B256_R0 cifar100/E10_B256_R0

# %% [markdown]
# #### read all the data from all the folders

# %%
# find the files path
mod5_path_f = data_path5 / f_path
mod6_path_f = data_path6 / f_path
mod7_path_f = data_path7 / f_path
mod8_path_f = data_path8 / f_path
mod9_path_f = data_path9 / f_path
print('The model path is:', mod5_path_f,'\n',
                            mod6_path_f,'\n',
                            mod7_path_f,'\n',
                            mod8_path_f,'\n',
                            mod9_path_f)
print('*'*50)
mod5_path_c = data_path5 / c_path
mod6_path_c = data_path6 / c_path
mod7_path_c = data_path7 / c_path
mod8_path_c = data_path8 / c_path
mod9_path_c = data_path9 / c_path
print('The model path is:', mod5_path_c,'\n',
                            mod6_path_c,'\n',
                            mod7_path_c,'\n',
                            mod8_path_c,'\n',
                            mod9_path_c)
# Out:
# The model path is: /root/GreenAI/Cloud/4090/Data/googlenet_mod5_mod1/fashion_mnist/E10_B256_R0
#  /root/GreenAI/Cloud/4090/Data/googlenet_mod6_mod1/fashion_mnist/E10_B256_R0
#  /root/GreenAI/Cloud/4090/Data/googlenet_mod7_mod1/fashion_mnist/E10_B256_R0
#  /root/GreenAI/Cloud/4090/Data/googlenet_mod8_mod1/fashion_mnist/E10_B256_R0
#  /root/GreenAI/Cloud/4090/Data/googlenet_mod9_mod1/fashion_mnist/E10_B256_R0
# **************************************************
# The model path is: /root/GreenAI/Cloud/4090/Data/googlenet_mod5_mod1/cifar100/E10_B256_R0
#  /root/GreenAI/Cloud/4090/Data/googlenet_mod6_mod1/cifar100/E10_B256_R0
#  /root/GreenAI/Cloud/4090/Data/googlenet_mod7_mod1/cifar100/E10_B256_R0
#  /root/GreenAI/Cloud/4090/Data/googlenet_mod8_mod1/cifar100/E10_B256_R0
#  /root/GreenAI/Cloud/4090/Data/googlenet_mod9_mod1/cifar100/E10_B256_R0

# %%
# for each path, there is fashionMNIST dataset and CIFAR100 dataset, stored in different folders
# find the files in the folder
mod_path_f = [mod5_path_f,mod6_path_f,mod7_path_f,mod8_path_f,mod9_path_f]
mod_path_c = [mod5_path_c,mod6_path_c,mod7_path_c,mod8_path_c,mod9_path_c]
for i in range(4):
    # find the files in the folder
    files_f = os.listdir(mod_path_f[i])
    files_c = os.listdir(mod_path_c[i])
    print(f'The files in the folder {mod_path_f[i]} and folder {mod_path_c[i]} are: {files_f}, {files_c}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 7
#       4 mod_path_c = [mod5_path_c,mod6_path_c,mod7_path_c,mod8_path_c,mod9_path_c]
#       5 for i in range(4):
#       6     # find the files in the folder
# ----> 7     files_f = os.listdir(mod_path_f[i])
#       8     files_c = os.listdir(mod_path_c[i])
#       9     print(f'The files in the folder {mod_path_f[i]} and folder {mod_path_c[i]} are: {files_f}, {files_c}')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/GreenAI/Cloud/4090/Data/googlenet_mod5_mod1/fashion_mnist/E10_B256_R0'

# %% [markdown]
# ## Load files

# %% [markdown]
# ### fashionmnist

# %%
# read all the files in all the folders
# LayersTime
LayersTime_mod5f = np.load(mod_path_f[0] / 'Layers_time.npy', allow_pickle=True)
LayersTime_mod6f = np.load(mod_path_f[1] / 'Layers_time.npy', allow_pickle=True)
LayersTime_mod7f = np.load(mod_path_f[2] / 'Layers_time.npy', allow_pickle=True)
LayersTime_mod8f = np.load(mod_path_f[3] / 'Layers_time.npy', allow_pickle=True)
LayersTime_mod9f = np.load(mod_path_f[4] / 'Layers_time.npy', allow_pickle=True)
# TrainPartTime
TrainPartTime_mod5f = np.load(mod_path_f[0] / 'Train_part_time.npy', allow_pickle=True)
TrainPartTime_mod6f = np.load(mod_path_f[1] / 'Train_part_time.npy', allow_pickle=True)
TrainPartTime_mod7f = np.load(mod_path_f[2] / 'Train_part_time.npy', allow_pickle=True)
TrainPartTime_mod8f = np.load(mod_path_f[3] / 'Train_part_time.npy', allow_pickle=True)
TrainPartTime_mod9f = np.load(mod_path_f[4] / 'Train_part_time.npy', allow_pickle=True)
# EpochTime
EpochTime_mod5f = np.load(mod_path_f[0] / 'Epoch_time.npy', allow_pickle=True)
EpochTime_mod6f = np.load(mod_path_f[1] / 'Epoch_time.npy', allow_pickle=True)
EpochTime_mod7f = np.load(mod_path_f[2] / 'Epoch_time.npy', allow_pickle=True)
EpochTime_mod8f = np.load(mod_path_f[3] / 'Epoch_time.npy', allow_pickle=True)
EpochTime_mod9f = np.load(mod_path_f[4] / 'Epoch_time.npy', allow_pickle=True)
# EpochEnergy
EpochEnergy_mod5f = np.load(mod_path_f[0] / 'Epoch_energy.npy', allow_pickle=True)
EpochEnergy_mod6f = np.load(mod_path_f[1] / 'Epoch_energy.npy', allow_pickle=True)
EpochEnergy_mod7f = np.load(mod_path_f[2] / 'Epoch_energy.npy', allow_pickle=True)
EpochEnergy_mod8f = np.load(mod_path_f[3] / 'Epoch_energy.npy', allow_pickle=True)
EpochEnergy_mod9f = np.load(mod_path_f[4] / 'Epoch_energy.npy', allow_pickle=True)
# print(f'LayersTime_mod1f: {LayersTime_mod1f}','\n',
#       f'LayersTime_mod2f: {LayersTime_mod2f}','\n',
#       f'LayersTime_mod3f: {LayersTime_mod3f}','\n',
#       f'LayersTime_mod4f: {LayersTime_mod4f}')

# %% [markdown]
# #### LayersTime

# %%
LayersName = ['S0_C0', 'S0_R1', 'S0_M2', 'S1_C0', 'S1_R1', 'S1_C2', 'S1_R3', 'S1_M4', 'S2_I0', 'S2_I1', 'S2_M2', 'S3_I0', 'S3_I1', 'S3_I2', 'S3_I3', 'S3_I4', 'S3_M5', 'S4_I0', 'S4_I1', 'S4_A2', 'S4_F3']
LayersName_mod9 = ['S0_C0', 'S0_R1', 'S0_M2', 'S1_C0', 'S1_R1', 'S1_C2', 'S1_R3', 'S1_M4', 'S2_A0', 'S2_F1']
print(f'The lenth of the LayersName is {len(LayersName)}')
print(f'The lenth of the LayersName_mod9 is {len(LayersName_mod9)}')
# Out:
# The lenth of the LayersName is 21
# The lenth of the LayersName_mod9 is 10

# %%
LayersTime_flist = [LayersTime_mod5f,LayersTime_mod6f,LayersTime_mod7f,LayersTime_mod8f,LayersTime_mod9f]

# %%
# set one figure has 5 subplots, and each subplot has the data of mean and std of the time for each layer
fig, axs = plt.subplots(5, 1, figsize=(15, 35))
for i, ax in enumerate(axs.flat):
    if i != 4:
        LayersTimei = LayersTime_flist[i]
        # Calculate the mean and standard deviation for each layer
        layer_means = np.mean(LayersTimei, axis=1)
        layer_stds = np.std(LayersTimei, axis=1)

        # Plot the average time per layer with error bars
        ax.errorbar(LayersName, layer_means, yerr=layer_stds, fmt='-o', ecolor='r', capsize=5)
        ax.set_title(f'Model {i+5}')
        ax.set_xlabel('Layer')
        ax.set_ylabel('Time (seconds)')
        ax.set_xticklabels(LayersName, rotation=45)
        ax.grid(True)
        for i, mean in enumerate(layer_means):
            ax.text(i, mean, f'{mean:.2f}', ha='center', va='bottom', fontsize=8)
    else:
        LayersTimei = LayersTime_mod9f
        # Calculate the mean and standard deviation for each layer
        layer_means = np.mean(LayersTimei, axis=1)
        layer_stds = np.std(LayersTimei, axis=1)

        # Plot the average time per layer with error bars
        ax.errorbar(LayersName_mod9, layer_means, yerr=layer_stds, fmt='-o', ecolor='r', capsize=5)
        ax.set_title(f'Model {9}')
        ax.set_xlabel('Layer')
        ax.set_ylabel('Time (seconds)')
        ax.set_xticklabels(LayersName_mod9, rotation=45)
        ax.grid(True)
        for i, mean in enumerate(layer_means):
            ax.text(i, mean, f'{mean:.2f}', ha='center', va='bottom', fontsize=8)
# Out:
# /var/folders/z9/ym3y50cd7q7gfczkkgdfrbp00000gn/T/ipykernel_72487/3649848523.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(LayersName, rotation=45)
# /var/folders/z9/ym3y50cd7q7gfczkkgdfrbp00000gn/T/ipykernel_72487/3649848523.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(LayersName_mod9, rotation=45)

# %%
IncepBlock = []
IncepBlockIndex = []
for i in LayersName:
    if 'I' in i:
        IncepBlock.append(i)
        IncepBlockIndex.append(LayersName.index(i))
print(f'The inception blocks are {IncepBlock}')
print(f'The inception block indexes are {IncepBlockIndex}')
# Out:
# The inception blocks are ['S2_I0', 'S2_I1', 'S3_I0', 'S3_I1', 'S3_I2', 'S3_I3', 'S3_I4', 'S4_I0', 'S4_I1']
# The inception block indexes are [8, 9, 11, 12, 13, 14, 15, 17, 18]

# %%
IncepNum = len(IncepBlock)
IncepTime_mod5f = np.zeros((IncepNum, epochs[0]))
IncepTime_mod6f = np.zeros((IncepNum, epochs[0]))
IncepTime_mod7f = np.zeros((IncepNum, epochs[0]))
IncepTime_mod8f = np.zeros((IncepNum, epochs[0]))
for i in range(IncepNum):
    IncepTime_mod5f[i,:] = LayersTime_mod5f[IncepBlockIndex[i], :]
    IncepTime_mod6f[i,:] = LayersTime_mod6f[IncepBlockIndex[i], :]
    IncepTime_mod7f[i,:] = LayersTime_mod7f[IncepBlockIndex[i], :]
    IncepTime_mod8f[i,:] = LayersTime_mod8f[IncepBlockIndex[i], :]
# print(f'The inception time of model 1 is {IncepTime_mod1f}','\n',
#       f'The inception time of model 2 is {IncepTime_mod2f}','\n',
#       f'The inception time of model 3 is {IncepTime_mod3f}','\n',
#       f'The inception time of model 4 is {IncepTime_mod4f}')

# %%
IncepTime_flist = [IncepTime_mod5f,IncepTime_mod6f,IncepTime_mod7f,IncepTime_mod8f]

# %%
# set one figure has 4 subplots, and each subplot has the data of mean and std of the time for each layer
fig, axs = plt.subplots(2, 2, figsize=(18, 12))
for i, ax in enumerate(axs.flat):
    IncepTimei = IncepTime_flist[i]
    # Calculate the mean and standard deviation for each layer
    inceplayer_means = np.mean(IncepTimei, axis=1)
    inceplayer_stds = np.std(IncepTimei, axis=1)

    # Plot the average time per layer with error bars
    ax.errorbar(IncepBlock, inceplayer_means, yerr=inceplayer_stds, fmt='-o', ecolor='r', capsize=5)
    ax.set_title(f'Average Time per Layer of Model {i+5}')
    ax.set_xlabel('Inception Layer')
    ax.set_ylabel('Time (seconds)')
    ax.set_xticklabels(IncepBlock, rotation=45)
    ax.grid(True)
    for i, mean in enumerate(inceplayer_means):
        ax.text(i, mean, f'{mean:.2f}', ha='center', va='bottom', fontsize=8)
# Out:
# /var/folders/z9/ym3y50cd7q7gfczkkgdfrbp00000gn/T/ipykernel_72487/3520162601.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(IncepBlock, rotation=45)

# %%
IncepTime_clist = [IncepTime_mod5f,
                   IncepTime_mod6f,
                   IncepTime_mod7f,
                   IncepTime_mod8f]
incepblock_avgvalues = []
for incepblock in IncepTime_clist:
    incepblock_total = np.sum(incepblock, axis=1)
    incepblock_avg = np.sum(incepblock) / epochs[0]
    # print(f'The total time of each inception block is {incepblock_total}')
    # print(f'The average time of each inception block is {incepblock_avg}')
    incepblock_avgvalues.append(incepblock_avg)
print(f'The average time of each inception block is {incepblock_avgvalues}')
for i in range(len(incepblock_avgvalues)-1):
    time_diff = incepblock_avgvalues[i+1] - incepblock_avgvalues[i]
    print(f'The time difference between model {i+5} and model {i+6} is {time_diff}')
# Out:
# The average time of each inception block is [0.708804988861084, 1.555838942527771, 2.503515625, 3.6553991079330443]
# The time difference between model 5 and model 6 is 0.847033953666687
# The time difference between model 6 and model 7 is 0.9476766824722289
# The time difference between model 7 and model 8 is 1.1518834829330444

# %% [markdown]
# #### TrainPartTime

# %%
TrainPartName = ['TimeToDevice', 'Forward', 'Backward', 'Test']

# %%
TrainPartTime_flist = [TrainPartTime_mod5f,TrainPartTime_mod6f,TrainPartTime_mod7f,TrainPartTime_mod8f,TrainPartTime_mod9f]

# %%
# set one figure has 4 subplots, and each subplot has the data of mean and std of the time for each layer
fig, axs = plt.subplots(5, 1, figsize=(15, 30))
for i, ax in enumerate(axs.flat):
    TrainPartTimei = TrainPartTime_flist[i]
    # Calculate the mean and standard deviation for each layer
    TrainPartTimei_means = np.mean(TrainPartTimei, axis=1)
    TrainPartTimei_stds = np.std(TrainPartTimei, axis=1)

    # Plot the average time per layer with error bars
    ax.errorbar(TrainPartName, TrainPartTimei_means, yerr=TrainPartTimei_stds, fmt='-o', ecolor='r', capsize=5)
    ax.set_title(f'Average Time of Training Model in Model {i+5}')
    ax.set_xlabel('Layer')
    ax.set_ylabel('Time (seconds)')
    ax.set_xticklabels(TrainPartName, rotation=45)
    ax.grid(True)
    for i, mean in enumerate(TrainPartTimei_means):
        ax.text(i, mean, f'{mean:.2f}', ha='center', va='bottom', fontsize=8)
# Out:
# /var/folders/z9/ym3y50cd7q7gfczkkgdfrbp00000gn/T/ipykernel_72487/318134570.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(TrainPartName, rotation=45)

# %% [markdown]
# #### EnergyEpoch

# %%
EpochEnergy_flist = [EpochEnergy_mod5f,EpochEnergy_mod6f,EpochEnergy_mod7f,EpochEnergy_mod8f,EpochEnergy_mod9f]
# print(EpochEnergy_flist)
EpochEnergy_f = np.zeros((5, epochs[0]))
avgEpochEnergy_f = np.zeros((5, epochs[0]))
# print(EpochEnergy_f)

# %%
for i in range(len(EpochEnergy_flist)):
    for epoch in range(len(EpochEnergy_flist[i])):
        EpochEnergy_fi = EpochEnergy_flist[i]
        epoch_energy = EpochEnergy_fi[epoch][0]
#         # print(f'The energy of epoch {i} is {epoch_energy}')
        epoch_total_energy = sum(epoch_energy)
        epoch_avg_energy = epoch_total_energy / len(epoch_energy)
#         print(f'The total energy of epoch {epoch} is {epoch_total_energy:.2f}') 
        epoch_total_energy = np.round(epoch_total_energy, 2)
        epoch_avg_energy = np.round(epoch_avg_energy, 2)     
        EpochEnergy_f[i, epoch] = epoch_total_energy
        avgEpochEnergy_f[i, epoch] = epoch_avg_energy
print(f'The total energy of each epoch in the model is {EpochEnergy_f}')
print(f'The average energy of each epoch in the model is {avgEpochEnergy_f}')
# Out:
# The total energy of each epoch in the model is [[4003.9  4147.02 4192.31 4186.35 4235.49 4246.69 4251.82 4109.82 4245.62
#   4225.5 ]
#  [4840.35 5080.82 5114.15 5098.28 5000.93 5122.02 5215.46 5096.43 5220.79
#   5218.88]
#  [6139.67 6431.16 6416.36 6546.4  6442.58 6549.72 6623.38 6606.02 6582.06
#   6650.06]
#  [8660.17 8798.23 8922.76 8952.49 9285.59 8921.84 9111.49 9132.   9151.67
#   9212.62]
#  [3697.85 3789.87 3862.4  3896.61 3914.9  3914.86 3980.21 3940.55 3942.67
#   3971.  ]]
# The average energy of each epoch in the model is [[182.   197.48 199.63 199.35 201.69 202.22 202.47 205.49 202.17 201.21]
#  [201.68 211.7  213.09 212.43 217.43 222.7  217.31 221.58 217.53 217.45]
#  [219.27 229.68 229.16 233.8  238.61 233.92 236.55 235.93 243.78 237.5 ]
#  [240.56 258.77 270.39 271.29 257.93 270.36 267.98 260.91 261.48 263.22]
#  [194.62 199.47 203.28 205.08 206.05 206.05 199.01 207.4  207.51 209.  ]]

# %%
Model_type = ['Model5', 'Model6', 'Model7', 'Model8', 'Model9']

# %%
# Define the function to plot energy consumption
def plot_energy_consumption(EpochEnergy_f, title):
    epoch_means = np.mean(EpochEnergy_f, axis=1)
    epoch_stds = np.std(EpochEnergy_f, axis=1)
    
    plt.errorbar(np.arange(1, 6), epoch_means, yerr=epoch_stds, fmt='-o', ecolor='r', capsize=5)
    plt.title(title)
    plt.xlabel('Model')
    plt.ylabel('Energy Consumption/Joules')
    plt.xticks(np.arange(1, 6), ['Mod5f', 'Mod6f', 'Mod7f', 'Mod8f', 'Mod9f'])
    plt.grid(True)
    
    for i, mean in enumerate(epoch_means):
        plt.text(i + 1, mean, f'{mean:.2f}', ha='center', va='bottom')

# Plot the energy consumption
plt.figure(figsize=(10, 6))
plot_energy_consumption(EpochEnergy_f, 'Total Energy Consumption per Model')
plt.tight_layout()
plt.show()
plt.figure(figsize=(10, 6))
plot_energy_consumption(avgEpochEnergy_f, 'Average Energy Consumption per second per Model')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### cifar100

# %% [markdown]
# #### LayersTime

# %%
# read all the files in all the folders
LayersTime_mod5c = np.load(mod_path_c[0] / 'Layers_time.npy', allow_pickle=True)
LayersTime_mod6c = np.load(mod_path_c[1] / 'Layers_time.npy', allow_pickle=True)
LayersTime_mod7c = np.load(mod_path_c[2] / 'Layers_time.npy', allow_pickle=True)
LayersTime_mod8c = np.load(mod_path_c[3] / 'Layers_time.npy', allow_pickle=True)
LayersTime_mod9c = np.load(mod_path_c[4] / 'Layers_time.npy', allow_pickle=True)
# TrainPartTime
TrainPartTime_mod5c = np.load(mod_path_c[0] / 'Train_part_time.npy', allow_pickle=True)
TrainPartTime_mod6c = np.load(mod_path_c[1] / 'Train_part_time.npy', allow_pickle=True)
TrainPartTime_mod7c = np.load(mod_path_c[2] / 'Train_part_time.npy', allow_pickle=True)
TrainPartTime_mod8c = np.load(mod_path_c[3] / 'Train_part_time.npy', allow_pickle=True)
TrainPartTime_mod9c = np.load(mod_path_c[4] / 'Train_part_time.npy', allow_pickle=True)
# EpochTime
EpochTime_mod5c = np.load(mod_path_c[0] / 'Epoch_time.npy', allow_pickle=True)
EpochTime_mod6c = np.load(mod_path_c[1] / 'Epoch_time.npy', allow_pickle=True)
EpochTime_mod7c = np.load(mod_path_c[2] / 'Epoch_time.npy', allow_pickle=True)
EpochTime_mod8c = np.load(mod_path_c[3] / 'Epoch_time.npy', allow_pickle=True)
EpochTime_mod9c = np.load(mod_path_c[4] / 'Epoch_time.npy', allow_pickle=True)
# EpochEnergy
EpochEnergy_mod5c = np.load(mod_path_c[0] / 'Epoch_energy.npy', allow_pickle=True)
EpochEnergy_mod6c = np.load(mod_path_c[1] / 'Epoch_energy.npy', allow_pickle=True)
EpochEnergy_mod7c = np.load(mod_path_c[2] / 'Epoch_energy.npy', allow_pickle=True)
EpochEnergy_mod8c = np.load(mod_path_c[3] / 'Epoch_energy.npy', allow_pickle=True)
EpochEnergy_mod9c = np.load(mod_path_c[4] / 'Epoch_energy.npy', allow_pickle=True)

# %%
LayersTime_clist = [LayersTime_mod5c,
                    LayersTime_mod6c,
                    LayersTime_mod7c,
                    LayersTime_mod8c,
                    LayersTime_mod9c]

# %%
# set one figure has 5 subplots, and each subplot has the data of mean and std of the time for each layer
fig, axs = plt.subplots(5, 1, figsize=(10, 20))
for i, ax in enumerate(axs.flat):
    if i != 4:
        LayersTimei = LayersTime_clist[i]
        # Calculate the mean and standard deviation for each layer
        layer_means = np.mean(LayersTimei, axis=1)
        layer_stds = np.std(LayersTimei, axis=1)

        # Plot the average time per layer with error bars
        ax.errorbar(LayersName, layer_means, yerr=layer_stds, fmt='-o', ecolor='r', capsize=5)
        ax.set_title(f'Model {i+1}')
        ax.set_xlabel('Layer')
        ax.set_ylabel('Time (seconds)')
        ax.set_xticklabels(LayersName, rotation=45)
        ax.grid(True)
        for i, mean in enumerate(layer_means):
            ax.text(i, mean, f'{mean:.2f}', ha='center', va='bottom', fontsize=8)
    else:
        LayersTimei = LayersTime_mod9c
        # Calculate the mean and standard deviation for each layer
        layer_means = np.mean(LayersTimei, axis=1)
        layer_stds = np.std(LayersTimei, axis=1)

        # Plot the average time per layer with error bars
        ax.errorbar(LayersName_mod9, layer_means, yerr=layer_stds, fmt='-o', ecolor='r', capsize=5)
        ax.set_title(f'Model {i+1}')
        ax.set_xlabel('Layer')
        ax.set_ylabel('Time (seconds)')
        ax.set_xticklabels(LayersName_mod9, rotation=45)
        ax.grid(True)
        for i, mean in enumerate(layer_means):
            ax.text(i, mean, f'{mean:.2f}', ha='center', va='bottom', fontsize=8)
# Out:
# /var/folders/z9/ym3y50cd7q7gfczkkgdfrbp00000gn/T/ipykernel_72487/3056219585.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(LayersName, rotation=45)
# /var/folders/z9/ym3y50cd7q7gfczkkgdfrbp00000gn/T/ipykernel_72487/3056219585.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(LayersName_mod9, rotation=45)

# %%
IncepNum = len(IncepBlock)
IncepTime_mod5c= np.zeros((IncepNum, epochs[0]))
IncepTime_mod6c = np.zeros((IncepNum, epochs[0]))
IncepTime_mod7c = np.zeros((IncepNum, epochs[0]))
IncepTime_mod8c = np.zeros((IncepNum, epochs[0]))
for i in range(IncepNum):
    IncepTime_mod5c[i,:] = LayersTime_mod5c[IncepBlockIndex[i], :]
    IncepTime_mod6c[i,:] = LayersTime_mod6c[IncepBlockIndex[i], :]
    IncepTime_mod7c[i,:] = LayersTime_mod7c[IncepBlockIndex[i], :]
    IncepTime_mod8c[i,:] = LayersTime_mod8c[IncepBlockIndex[i], :]

# %%
IncepTime_clist = [IncepTime_mod5c,
                   IncepTime_mod6c,
                   IncepTime_mod7c,
                   IncepTime_mod8c]

# %%
# set one figure has 4 subplots, and each subplot has the data of mean and std of the time for each layer
fig, axs = plt.subplots(2, 2, figsize=(18, 12))
for i, ax in enumerate(axs.flat):
    IncepTimei = IncepTime_clist[i]
    # Calculate the mean and standard deviation for each layer
    inceplayer_means = np.mean(IncepTimei, axis=1)
    inceplayer_stds = np.std(IncepTimei, axis=1)

    # Plot the average time per layer with error bars
    ax.errorbar(IncepBlock, inceplayer_means, yerr=inceplayer_stds, fmt='-o', ecolor='r', capsize=5)
    ax.set_title(f'Average Time per Layer of Model {i+1}')
    ax.set_xlabel('Inception Layer')
    ax.set_ylabel('Time (seconds)')
    ax.set_xticklabels(IncepBlock, rotation=45)
    ax.grid(True)
    for i, mean in enumerate(inceplayer_means):
        ax.text(i, mean, f'{mean:.2f}', ha='center', va='bottom', fontsize=8)
# Out:
# /var/folders/z9/ym3y50cd7q7gfczkkgdfrbp00000gn/T/ipykernel_72487/2849450503.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(IncepBlock, rotation=45)

# %%
IncepTime_clist = [IncepTime_mod5c,
                   IncepTime_mod6c,
                   IncepTime_mod7c,
                   IncepTime_mod8c]
incepblock_avgvalues = []
for incepblock in IncepTime_clist:
    incepblock_total = np.sum(incepblock, axis=1)
    incepblock_avg = np.sum(incepblock) / epochs[0]
    # print(f'The total time of each inception block is {incepblock_total}')
    # print(f'The average time of each inception block is {incepblock_avg}')
    incepblock_avgvalues.append(incepblock_avg)
print(f'The average time of each inception block is {incepblock_avgvalues}')
for i in range(len(incepblock_avgvalues)-1):
    time_diff = incepblock_avgvalues[i+1] - incepblock_avgvalues[i]
    print(f'The time difference between model {i+5} and model {i+6} is {time_diff}')
# Out:
# The average time of each inception block is [0.5877931833267211, 1.2738942861557008, 2.1119940280914307, 3.0202577114105225]
# The time difference between model 5 and model 6 is 0.6861011028289796
# The time difference between model 6 and model 7 is 0.8380997419357299
# The time difference between model 7 and model 8 is 0.9082636833190918

# %% [markdown]
# #### TrainPartTime

# %%
TrainPartTime_clist = [TrainPartTime_mod5c,
                       TrainPartTime_mod6c,
                       TrainPartTime_mod7c,
                       TrainPartTime_mod8c,
                       TrainPartTime_mod9c]

# %%
# set one figure has 4 subplots, and each subplot has the data of mean and std of the time for each layer
fig, axs = plt.subplots(5, 1, figsize=(15, 30))
for i, ax in enumerate(axs.flat):
    TrainPartTimei = TrainPartTime_clist[i]
    # Calculate the mean and standard deviation for each layer
    TrainPartTimei_means = np.mean(TrainPartTimei, axis=1)
    TrainPartTimei_stds = np.std(TrainPartTimei, axis=1)

    # Plot the average time per layer with error bars
    ax.errorbar(TrainPartName, TrainPartTimei_means, yerr=TrainPartTimei_stds, fmt='-o', ecolor='r', capsize=5)
    ax.set_title(f'Average Time of Training Model in Model {i+5}')
    ax.set_xlabel('Layer')
    ax.set_ylabel('Time (seconds)')
    ax.set_xticklabels(TrainPartName, rotation=45)
    ax.grid(True)
    for i, mean in enumerate(TrainPartTimei_means):
        ax.text(i, mean, f'{mean:.2f}', ha='center', va='bottom', fontsize=8)
# Out:
# /var/folders/z9/ym3y50cd7q7gfczkkgdfrbp00000gn/T/ipykernel_72487/1857678148.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(TrainPartName, rotation=45)

# %% [markdown]
# #### EpochEnergy

# %%
EpochEnergy_clist = [EpochEnergy_mod5c,
                     EpochEnergy_mod6c,
                     EpochEnergy_mod7c,
                     EpochEnergy_mod8c,
                     EpochEnergy_mod9c]
# print(EpochEnergy_flist)
EpochEnergy_c = np.zeros((5, epochs[0]))
avgEpochEnergy_c = np.zeros((5, epochs[0]))

# %%
for i in range(len(EpochEnergy_clist)):
    for epoch in range(len(EpochEnergy_clist[i])):
        EpochEnergy_ci = EpochEnergy_clist[i]
        epoch_energy = EpochEnergy_ci[epoch][0]
#         # print(f'The energy of epoch {i} is {epoch_energy}')
        epoch_total_energy = sum(epoch_energy)
        epoch_avg_energy = epoch_total_energy / len(epoch_energy)
#         print(f'The total energy of epoch {epoch} is {epoch_total_energy:.2f}') 
        epoch_total_energy = np.round(epoch_total_energy, 2)
        epoch_avg_energy = np.round(epoch_avg_energy, 2)
        EpochEnergy_c[i, epoch] = epoch_total_energy
        avgEpochEnergy_c[i, epoch] = epoch_avg_energy
print(f'The total energy of each epoch in the model is {EpochEnergy_c}')
print(f'The average energy of each epoch in the model is {avgEpochEnergy_c}')
# Out:
# The total energy of each epoch in the model is [[4322.74 4398.48 4386.7  4406.85 4307.27 4366.02 4381.47 4393.37 4363.38
#   4388.63]
#  [5080.16 5188.43 5266.33 5318.16 5256.65 5257.31 5247.46 5182.61 5303.16
#   5307.01]
#  [6261.05 6370.11 6376.74 6427.65 6370.27 6379.85 6355.2  6427.22 6433.33
#   6346.84]
#  [8211.58 8437.94 8401.22 8571.12 8543.1  8505.22 8666.8  8586.27 8389.21
#   8509.58]
#  [4110.79 4140.49 4142.82 4257.96 4168.37 4184.57 4304.89 4339.6  4294.08
#   4314.7 ]]
# The average energy of each epoch in the model is [[144.09 146.62 146.22 146.89 148.53 145.53 146.05 146.45 145.45 146.29]
#  [163.88 167.37 164.57 166.19 164.27 164.29 163.98 167.18 165.72 165.84]
#  [178.89 182.   182.19 183.65 182.01 182.28 181.58 183.63 183.81 181.34]
#  [210.55 222.05 221.08 219.77 219.05 223.82 216.67 214.66 220.77 223.94]
#  [152.25 153.35 153.44 152.07 154.38 154.98 148.44 144.65 148.07 148.78]]

# %%
# Define the function to plot energy consumption
def plot_energy_consumption(EpochEnergy_c, title):
    epoch_means = np.mean(EpochEnergy_c, axis=1)
    epoch_stds = np.std(EpochEnergy_c, axis=1)
    
    plt.errorbar(np.arange(1, 6), epoch_means, yerr=epoch_stds, fmt='-o', ecolor='r', capsize=5)
    plt.title(title)
    plt.xlabel('Model')
    plt.ylabel('Energy Consumption')
    plt.xticks(np.arange(1, 6), ['Mod5f', 'Mod6f', 'Mod7f', 'Mod8f', 'Mod9f'])
    plt.grid(True)
    
    for i, mean in enumerate(epoch_means):
        plt.text(i + 1, mean, f'{mean:.2f}', ha='center', va='bottom')

# Plot the energy consumption
plt.figure(figsize=(10, 6))
plot_energy_consumption(EpochEnergy_c, 'Energy Consumption per Model')
plt.tight_layout()
plt.show()
# Plot the energy consumption
plt.figure(figsize=(10, 6))
plot_energy_consumption(avgEpochEnergy_c, 'Energy Consumption per Model')
plt.tight_layout()
plt.show()
