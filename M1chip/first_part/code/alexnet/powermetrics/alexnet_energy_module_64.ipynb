# %% [markdown]
# # 深度卷积神经网络（AlexNet）
# :label:`sec_alexnet`
#
# 在LeNet提出后，卷积神经网络在计算机视觉和机器学习领域中很有名气。但卷积神经网络并没有主导这些领域。这是因为虽然LeNet在小数据集上取得了很好的效果，但是在更大、更真实的数据集上训练卷积神经网络的性能和可行性还有待研究。事实上，在上世纪90年代初到2012年之间的大部分时间里，神经网络往往被其他机器学习方法超越，如支持向量机（support vector machines）。
#
# 在计算机视觉中，直接将神经网络与其他机器学习方法进行比较也许不公平。这是因为，卷积神经网络的输入是由原始像素值或是经过简单预处理（例如居中、缩放）的像素值组成的。但在使用传统机器学习方法时，从业者永远不会将原始像素作为输入。在传统机器学习方法中，计算机视觉流水线是由经过人的手工精心设计的特征流水线组成的。对于这些传统方法，大部分的进展都来自于对特征有了更聪明的想法，并且学习到的算法往往归于事后的解释。
#
# 虽然上世纪90年代就有了一些神经网络加速卡，但仅靠它们还不足以开发出有大量参数的深层多通道多层卷积神经网络。此外，当时的数据集仍然相对较小。除了这些障碍，训练神经网络的一些关键技巧仍然缺失，包括启发式参数初始化、随机梯度下降的变体、非挤压激活函数和有效的正则化技术。
#
# 因此，与训练*端到端*（从像素到分类结果）系统不同，经典机器学习的流水线看起来更像下面这样：
#
# 1. 获取一个有趣的数据集。在早期，收集这些数据集需要昂贵的传感器（在当时最先进的图像也就100万像素）。
# 2. 根据光学、几何学、其他知识以及偶然的发现，手工对特征数据集进行预处理。
# 3. 通过标准的特征提取算法，如SIFT（尺度不变特征变换） :cite:`Lowe.2004`和SURF（加速鲁棒特征） :cite:`Bay.Tuytelaars.Van-Gool.2006`或其他手动调整的流水线来输入数据。
# 4. 将提取的特征送入最喜欢的分类器中（例如线性模型或其它核方法），以训练分类器。
#
# 当人们和机器学习研究人员交谈时，会发现机器学习研究人员相信机器学习既重要又美丽：优雅的理论去证明各种模型的性质。机器学习是一个正在蓬勃发展、严谨且非常有用的领域。然而，当人们和计算机视觉研究人员交谈，会听到一个完全不同的故事。计算机视觉研究人员会告诉一个诡异事实————推动领域进步的是数据特征，而不是学习算法。计算机视觉研究人员相信，从对最终模型精度的影响来说，更大或更干净的数据集、或是稍微改进的特征提取，比任何学习算法带来的进步要大得多。
#
# ## 学习表征
#
# 另一种预测这个领域发展的方法————观察图像特征的提取方法。在2012年前，图像特征都是机械地计算出来的。事实上，设计一套新的特征函数、改进结果，并撰写论文是盛极一时的潮流。SIFT :cite:`Lowe.2004`、SURF :cite:`Bay.Tuytelaars.Van-Gool.2006`、HOG（定向梯度直方图） :cite:`Dalal.Triggs.2005`、[bags of visual words](https://en.wikipedia.org/wiki/Bag-of-words_model_in_computer_vision)和类似的特征提取方法占据了主导地位。
#
# 另一组研究人员，包括Yann LeCun、Geoff Hinton、Yoshua Bengio、Andrew Ng、Shun ichi Amari和Juergen Schmidhuber，想法则与众不同：他们认为特征本身应该被学习。此外，他们还认为，在合理地复杂性前提下，特征应该由多个共同学习的神经网络层组成，每个层都有可学习的参数。在机器视觉中，最底层可能检测边缘、颜色和纹理。事实上，Alex Krizhevsky、Ilya Sutskever和Geoff Hinton提出了一种新的卷积神经网络变体*AlexNet*。在2012年ImageNet挑战赛中取得了轰动一时的成绩。AlexNet以Alex Krizhevsky的名字命名，他是论文 :cite:`Krizhevsky.Sutskever.Hinton.2012`的第一作者。
#
# 有趣的是，在网络的最底层，模型学习到了一些类似于传统滤波器的特征抽取器。 :numref:`fig_filters`是从AlexNet论文 :cite:`Krizhevsky.Sutskever.Hinton.2012`复制的，描述了底层图像特征。
#
# ![AlexNet第一层学习到的特征抽取器。](../img/filters.png)
# :width:`400px`
# :label:`fig_filters`
#
# AlexNet的更高层建立在这些底层表示的基础上，以表示更大的特征，如眼睛、鼻子、草叶等等。而更高的层可以检测整个物体，如人、飞机、狗或飞盘。最终的隐藏神经元可以学习图像的综合表示，从而使属于不同类别的数据易于区分。尽管一直有一群执着的研究者不断钻研，试图学习视觉数据的逐级表征，然而很长一段时间里这些尝试都未有突破。深度卷积神经网络的突破出现在2012年。突破可归因于两个关键因素。
#
# ### 缺少的成分：数据
#
# 包含许多特征的深度模型需要大量的有标签数据，才能显著优于基于凸优化的传统方法（如线性方法和核方法）。
# 然而，限于早期计算机有限的存储和90年代有限的研究预算，大部分研究只基于小的公开数据集。例如，不少研究论文基于加州大学欧文分校（UCI）提供的若干个公开数据集，其中许多数据集只有几百至几千张在非自然环境下以低分辨率拍摄的图像。这一状况在2010年前后兴起的大数据浪潮中得到改善。2009年，ImageNet数据集发布，并发起ImageNet挑战赛：要求研究人员从100万个样本中训练模型，以区分1000个不同类别的对象。ImageNet数据集由斯坦福教授李飞飞小组的研究人员开发，利用谷歌图像搜索（Google Image Search）对每一类图像进行预筛选，并利用亚马逊众包（Amazon Mechanical Turk）来标注每张图片的相关类别。这种规模是前所未有的。这项被称为ImageNet的挑战赛推动了计算机视觉和机器学习研究的发展，挑战研究人员确定哪些模型能够在更大的数据规模下表现最好。
#
# ### 缺少的成分：硬件
#
# 深度学习对计算资源要求很高，训练可能需要数百个迭代轮数，每次迭代都需要通过代价高昂的许多线性代数层传递数据。这也是为什么在20世纪90年代至21世纪初，优化凸目标的简单算法是研究人员的首选。然而，用GPU训练神经网络改变了这一格局。*图形处理器*（Graphics Processing Unit，GPU）早年用来加速图形处理，使电脑游戏玩家受益。GPU可优化高吞吐量的$4 \times 4$矩阵和向量乘法，从而服务于基本的图形任务。幸运的是，这些数学运算与卷积层的计算惊人地相似。由此，英伟达（NVIDIA）和ATI已经开始为通用计算操作优化gpu，甚至把它们作为*通用GPU*（general-purpose GPUs，GPGPU）来销售。
#
# 那么GPU比CPU强在哪里呢？
#
# 首先，我们深度理解一下中央处理器（Central Processing Unit，CPU）的*核心*。
# CPU的每个核心都拥有高时钟频率的运行能力，和高达数MB的三级缓存（L3Cache）。
# 它们非常适合执行各种指令，具有分支预测器、深层流水线和其他使CPU能够运行各种程序的功能。
# 然而，这种明显的优势也是它的致命弱点：通用核心的制造成本非常高。
# 它们需要大量的芯片面积、复杂的支持结构（内存接口、内核之间的缓存逻辑、高速互连等等），而且它们在任何单个任务上的性能都相对较差。
# 现代笔记本电脑最多有4核，即使是高端服务器也很少超过64核，因为它们的性价比不高。
#
# 相比于CPU，GPU由$100 \sim 1000$个小的处理单元组成（NVIDIA、ATI、ARM和其他芯片供应商之间的细节稍有不同），通常被分成更大的组（NVIDIA称之为warps）。
# 虽然每个GPU核心都相对较弱，有时甚至以低于1GHz的时钟频率运行，但庞大的核心数量使GPU比CPU快几个数量级。
# 例如，NVIDIA最近一代的Ampere GPU架构为每个芯片提供了高达312 TFlops的浮点性能，而CPU的浮点性能到目前为止还没有超过1 TFlops。
# 之所以有如此大的差距，原因其实很简单：首先，功耗往往会随时钟频率呈二次方增长。
# 对于一个CPU核心，假设它的运行速度比GPU快4倍，但可以使用16个GPU核代替，那么GPU的综合性能就是CPU的$16 \times 1/4 = 4$倍。
# 其次，GPU内核要简单得多，这使得它们更节能。
# 此外，深度学习中的许多操作需要相对较高的内存带宽，而GPU拥有10倍于CPU的带宽。
#
# 回到2012年的重大突破，当Alex Krizhevsky和Ilya Sutskever实现了可以在GPU硬件上运行的深度卷积神经网络时，一个重大突破出现了。他们意识到卷积神经网络中的计算瓶颈：卷积和矩阵乘法，都是可以在硬件上并行化的操作。
# 于是，他们使用两个显存为3GB的NVIDIA GTX580 GPU实现了快速卷积运算。他们的创新[cuda-convnet](https://code.google.com/archive/p/cuda-convnet/)几年来它一直是行业标准，并推动了深度学习热潮。
#
# ## AlexNet
#
# 2012年，AlexNet横空出世。它首次证明了学习到的特征可以超越手工设计的特征。它一举打破了计算机视觉研究的现状。
# AlexNet使用了8层卷积神经网络，并以很大的优势赢得了2012年ImageNet图像识别挑战赛。
#
# AlexNet和LeNet的架构非常相似，如 :numref:`fig_alexnet`所示。
# 注意，本书在这里提供的是一个稍微精简版本的AlexNet，去除了当年需要两个小型GPU同时运算的设计特点。
#
# ![从LeNet（左）到AlexNet（右）](../img/alexnet.svg)
# :label:`fig_alexnet`
#
# AlexNet和LeNet的设计理念非常相似，但也存在显著差异。
#
# 1. AlexNet比相对较小的LeNet5要深得多。AlexNet由八层组成：五个卷积层、两个全连接隐藏层和一个全连接输出层。
# 2. AlexNet使用ReLU而不是sigmoid作为其激活函数。
#
# 下面的内容将深入研究AlexNet的细节。
#
# ### 模型设计
#
# 在AlexNet的第一层，卷积窗口的形状是$11\times11$。
# 由于ImageNet中大多数图像的宽和高比MNIST图像的多10倍以上，因此，需要一个更大的卷积窗口来捕获目标。
# 第二层中的卷积窗口形状被缩减为$5\times5$，然后是$3\times3$。
# 此外，在第一层、第二层和第五层卷积层之后，加入窗口形状为$3\times3$、步幅为2的最大汇聚层。
# 而且，AlexNet的卷积通道数目是LeNet的10倍。
#
# 在最后一个卷积层后有两个全连接层，分别有4096个输出。
# 这两个巨大的全连接层拥有将近1GB的模型参数。
# 由于早期GPU显存有限，原版的AlexNet采用了双数据流设计，使得每个GPU只负责存储和计算模型的一半参数。
# 幸运的是，现在GPU显存相对充裕，所以现在很少需要跨GPU分解模型（因此，本书的AlexNet模型在这方面与原始论文稍有不同）。
#
# ### 激活函数
#
# 此外，AlexNet将sigmoid激活函数改为更简单的ReLU激活函数。
# 一方面，ReLU激活函数的计算更简单，它不需要如sigmoid激活函数那般复杂的求幂运算。
# 另一方面，当使用不同的参数初始化方法时，ReLU激活函数使训练模型更加容易。
# 当sigmoid激活函数的输出非常接近于0或1时，这些区域的梯度几乎为0，因此反向传播无法继续更新一些模型参数。
# 相反，ReLU激活函数在正区间的梯度总是1。
# 因此，如果模型参数没有正确初始化，sigmoid函数可能在正区间内得到几乎为0的梯度，从而使模型无法得到有效的训练。
#
# ### 容量控制和预处理
#
# AlexNet通过暂退法（ :numref:`sec_dropout`）控制全连接层的模型复杂度，而LeNet只使用了权重衰减。
# 为了进一步扩充数据，AlexNet在训练时增加了大量的图像增强数据，如翻转、裁切和变色。
# 这使得模型更健壮，更大的样本量有效地减少了过拟合。
# 在 :numref:`sec_image_augmentation`中更详细地讨论数据扩增。

# %%
import torch
from torch import nn
from d2l import torch as d2l
import time
import numpy as np

net = nn.Sequential(
    # 这里使用一个11*11的更大窗口来捕捉对象。
    # 同时，步幅为4，以减少输出的高度和宽度。
    # 另外，输出通道的数目远大于LeNet
    nn.Conv2d(1, 96, kernel_size=11, stride=4, padding=1), nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2),
    # 减小卷积窗口，使用填充为2来使得输入与输出的高和宽一致，且增大输出通道数
    nn.Conv2d(96, 256, kernel_size=5, padding=2), nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2),
    # 使用三个连续的卷积层和较小的卷积窗口。
    # 除了最后的卷积层，输出通道的数量进一步增加。
    # 在前两个卷积层之后，汇聚层不用于减少输入的高度和宽度
    nn.Conv2d(256, 384, kernel_size=3, padding=1), nn.ReLU(),
    nn.Conv2d(384, 384, kernel_size=3, padding=1), nn.ReLU(),
    nn.Conv2d(384, 256, kernel_size=3, padding=1), nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2),
    nn.Flatten(),
    # 这里，全连接层的输出数量是LeNet中的好几倍。使用dropout层来减轻过拟合
    nn.Linear(6400, 4096), nn.ReLU(),
    nn.Dropout(p=0.5),
    nn.Linear(4096, 4096), nn.ReLU(),
    nn.Dropout(p=0.5),
    # 最后是输出层。由于这里使用Fashion-MNIST，所以用类别数为10，而非论文中的1000
    nn.Linear(4096, 10))

# %%
# 图片大小为224*224，核大小为11，步幅为4，填充为1，输出通道为96，每次输出的大小为
# (224-11+4*1)/4+1=54，即54*54*96，参数数量为(11*11*1+1)*96=11712
# 接下来输入通道为96，输出通道为256，核大小为5，填充为2，步幅为1，输出大小为
# (54-5+2*2)/1+1=27，即27*27*256，参数数量为(5*5*96+1)*256=614656
# 接下来输入通道为256，输出通道为384，核大小为3，填充为1，步幅为1，输出大小为
# (27-3+2*1)/1+1=27，即27*27*384，参数数量为(3*3*256+1)*384=885120
# 接下来输入通道为384，输出通道为384，核大小为3，填充为1，步幅为1，输出大小为
# (27-3+2*1)/1+1=27，即27*27*384，参数数量为(3*3*384+1)*384=1327488
# 接下来输入通道为384，输出通道为256，核大小为3，填充为1，步幅为1，输出大小为
# (27-3+2*1)/1+1=27，即27*27*256，参数数量为(3*3*384+1)*256=884992
# 卷积层参数数量为11712+614656+885120+1327488+884992=3712968
# 卷积层能源消耗值为2.32957448e+01J

# %% [markdown]
# [**我们构造一个**]高度和宽度都为224的(**单通道数据，来观察每一层输出的形状**)。
# 它与 :numref:`fig_alexnet`中的AlexNet架构相匹配。

# %%
X = torch.randn(1, 1, 224, 224)
for layer in net:
    X=layer(X)
    print(layer.__class__.__name__,'output shape:\t',X.shape)
# Out:
# Conv2d output shape:	 torch.Size([1, 96, 54, 54])
# ReLU output shape:	 torch.Size([1, 96, 54, 54])
# MaxPool2d output shape:	 torch.Size([1, 96, 26, 26])
# Conv2d output shape:	 torch.Size([1, 256, 26, 26])
# ReLU output shape:	 torch.Size([1, 256, 26, 26])
# MaxPool2d output shape:	 torch.Size([1, 256, 12, 12])
# Conv2d output shape:	 torch.Size([1, 384, 12, 12])
# ReLU output shape:	 torch.Size([1, 384, 12, 12])
# Conv2d output shape:	 torch.Size([1, 384, 12, 12])
# ReLU output shape:	 torch.Size([1, 384, 12, 12])
# Conv2d output shape:	 torch.Size([1, 256, 12, 12])
# ReLU output shape:	 torch.Size([1, 256, 12, 12])
# MaxPool2d output shape:	 torch.Size([1, 256, 5, 5])
# Flatten output shape:	 torch.Size([1, 6400])
# Linear output shape:	 torch.Size([1, 4096])
# ReLU output shape:	 torch.Size([1, 4096])
# Dropout output shape:	 torch.Size([1, 4096])
# Linear output shape:	 torch.Size([1, 4096])
# ReLU output shape:	 torch.Size([1, 4096])
# Dropout output shape:	 torch.Size([1, 4096])
# Linear output shape:	 torch.Size([1, 10])

# %% [markdown]
# ## 读取数据集
#
# 尽管原文中AlexNet是在ImageNet上进行训练的，但本书在这里使用的是Fashion-MNIST数据集。因为即使在现代GPU上，训练ImageNet模型，同时使其收敛可能需要数小时或数天的时间。
# 将AlexNet直接应用于Fashion-MNIST的一个问题是，[**Fashion-MNIST图像的分辨率**]（$28 \times 28$像素）(**低于ImageNet图像。**)
# 为了解决这个问题，(**我们将它们增加到$224 \times 224$**)（通常来讲这不是一个明智的做法，但在这里这样做是为了有效使用AlexNet架构）。
# 这里需要使用`d2l.load_data_fashion_mnist`函数中的`resize`参数执行此调整。

# %%
batch_size = 64
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size, resize=224)
# print the shape of the train_iter
list_of_i = []
for i, (X, y) in enumerate(train_iter):
    list_of_i.append(i)

print('the shape of the train_iter is:', np.array(list_of_i).shape)
# print(list_of_i)
# print the first 10 batch of the train_iter
for i, (X, y) in enumerate(train_iter):
    if i < 10:
        print('the shape of the', i, 'batch of the train_iter is:', X.shape)
    else:
        break
# Out:
# the shape of the train_iter is: (938,)
# the shape of the 0 batch of the train_iter is: torch.Size([64, 1, 224, 224])
# the shape of the 1 batch of the train_iter is: torch.Size([64, 1, 224, 224])
# the shape of the 2 batch of the train_iter is: torch.Size([64, 1, 224, 224])
# the shape of the 3 batch of the train_iter is: torch.Size([64, 1, 224, 224])
# the shape of the 4 batch of the train_iter is: torch.Size([64, 1, 224, 224])
# the shape of the 5 batch of the train_iter is: torch.Size([64, 1, 224, 224])
# the shape of the 6 batch of the train_iter is: torch.Size([64, 1, 224, 224])
# the shape of the 7 batch of the train_iter is: torch.Size([64, 1, 224, 224])
# the shape of the 8 batch of the train_iter is: torch.Size([64, 1, 224, 224])
# the shape of the 9 batch of the train_iter is: torch.Size([64, 1, 224, 224])

# %% [markdown]
# ## [**训练AlexNet**]
#
# 现在AlexNet可以开始被训练了。与 :numref:`sec_lenet`中的LeNet相比，这里的主要变化是使用更小的学习速率训练，这是因为网络更深更广、图像分辨率更高，训练卷积神经网络就更昂贵。

# %%
# '''
# 定义一个forwar_hook函数，目标是在运行到该层的时候，进行显示
# 更新：forward_hook函数的参数是固定的，不能随意更改，增加time模块不太好
#     需要改为设定循环来一步步的进行计算
# '''

# def forward_hook(module, input, output):
#     if isinstance(module, nn.Conv2d):
#         print("正在运行卷积层!")
#     elif isinstance(module, nn.MaxPool2d):
#         print("正在运行池化层!")

# %%
def evaluate_accuracy_gpu(net, data_iter, device=None):
    """使用GPU计算模型在数据集上的精度

    Defined in :numref:`sec_lenet`"""
    if isinstance(net, nn.Module):
        net.eval()  # 设置为评估模式
        if not device:
            device = next(iter(net.parameters())).device
    # 正确预测的数量，总预测的数量
    metric = d2l.Accumulator(2)
    with torch.no_grad():
        for X, y in data_iter:
            if isinstance(X, list):
                # BERT微调所需的（之后将介绍）
                X = [x.to(device) for x in X]
            else:
                X = X.to(device)
            y = y.to(device)
            metric.add(d2l.accuracy(net(X), y), d2l.size(y))
    return metric[0] / metric[1]

# %%
def test_loop(data_iter, net, loss_fn, device):
    # Set the model to evaluation mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    net.eval()
    size = len(data_iter.dataset)
    num_batches = len(data_iter)
    test_loss, correct = 0, 0

    # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
    # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
    with torch.no_grad():
        for X, y in data_iter:
            X = X.to(device)
            y = y.to(device)

            acc = d2l.accuracy(net(X), y)
            size = d2l.size(y)
    return acc/size
    #         pred = net(X)
    #         test_loss += loss_fn(pred, y).item()
    #         correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    # test_loss /= num_batches
    # correct /= size
    # print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
# '''
# 这段是将d2l中的train_ch6()函数拷贝过来，然后修改了一下，目的是为了能够显示在进行每一层的前向传播的时候，能够显示出来
# '''
# def train_ch6(net, train_iter, test_iter, num_epochs, lr, device):
#     """用GPU训练模型(在第六章定义)

#     Defined in :numref:`sec_lenet`"""
#     def init_weights(m):
#         if type(m) == nn.Linear or type(m) == nn.Conv2d:
#             nn.init.xavier_uniform_(m.weight)
#     net.apply(init_weights)

#     list_layer_name = ['Conv2d','ReLU', 'MaxPool2d','Linear','Dropout','Flatten']

#     # create a numpy array to store the time and energy, the shape is (num_epochs, len(list_layer_name), 2)
#     # the 2 means time and energy, respectively
#     time_energy_data = np.zeros((num_epochs, len(list_layer_name), 2)) # for epoch = 1, the shape is (6,2)

#     # create another numpy array to store the time and energy for loss, backward and optimizer
#     # the shape is (num_epochs, 3)
#     time_energy_data_loss_backward_optimizer = np.zeros((num_epochs, 3))

#     print('training on', device)
#     net.to(device)
#     optimizer = torch.optim.SGD(net.parameters(), lr=lr)
#     loss = nn.CrossEntropyLoss()
#     animator = d2l.Animator(xlabel='epoch', xlim=[1, num_epochs],
#                             legend=['train loss', 'train acc', 'test acc'])
#     timer, num_batches = d2l.Timer(), len(train_iter)
#     for epoch in range(num_epochs):
#         # 训练损失之和，训练准确率之和，样本数
#         metric = d2l.Accumulator(3)
#         net.train() # 设置为训练模式

#         # 将time_energy_data的第一个维度设置为epoch
#         time_energy_data[epoch,:,:] = epoch

#         # 将time_energy_data_backward_optimizer的第一个维度设置为epoch
#         time_energy_data_loss_backward_optimizer[epoch,:] = epoch

#         for i, (X, y) in enumerate(train_iter):
#             timer.start()
#             optimizer.zero_grad()
#             X, y = X.to(device), y.to(device)

#             # 增加一个time_energy_data_i, 用于记录每一次前向传播的时间和能量
#             time_energy_data_i = np.zeros((len(list_layer_name),2))

#             # 增加一个time_energy_data_backward_optimizer_i, 用于记录每一次backward和optimizer的时间和能量
#             time_energy_data_loss_backward_optimizer_i = np.zeros((3))

#             # 将原本的y_hat = net(X)改为下面的形式，目的是为了让模型逐层运行，并且在这个过程中，记录起运行的时间以及消耗的能量
#             y_hat = X
#             for layer in net:
                
#                 # print(layer.__class__.__name__,'output shape:\t',y_hat.shape)
#                 layer_name = layer.__class__.__name__
#                 # print(layer_name)
#                 # # check if the layer_name is in the list_layer_name，if yes, then act the code below, else, continue
#                 # if layer_name in list_layer_name:
#                 # find out the layer name is in where of the list
#                 layer_index = list_layer_name.index(layer_name)
                
#                 # calculate the energy and time
#                 # 这里的时间和能量都是在每一层的前向传播的时候，进行计算的
#                 time_start_layer = time.time()
#                 '''
#                 energy部分后续加入，先进行测试时间计算
#                 '''
#                 # energy_start = 0
#                 y_hat = layer(y_hat)
#                 time_end_layer = time.time()
#                 time_cost_layer = time_end_layer - time_start_layer
#                 # 将对应的layer_index的时间和能量加入到time_energy_data中
#                 time_energy_data_i[layer_index,0] += time_cost_layer
#                 # time_energy_data_i[layer_index,1] += energy_cost_layer

#                 # print(layer_name, 'time %f sec' % (time_cost_layer))
#                 # print(time_energy_data_i)
            
#             # 将time_energy_data_i加入到time_energy_data中
#             time_energy_data[epoch,:,:] += time_energy_data_i

#             # y_hat = net(X)

#             # loss部分
#             time_start_loss = time.time()
#             l = loss(y_hat, y)
#             time_end_loss = time.time()
#             time_cost_loss = time_end_loss - time_start_loss
#             # 对time_cost_loss数据进行累加
#             time_energy_data_loss_backward_optimizer_i[2] += time_cost_loss

#             # backward部分
#             time_start_backward = time.time()
#             l.backward()
#             time_end_backward = time.time()
#             time_cost_backward = time_end_backward - time_start_backward
#             # 对time_cost_backward数据进行累加
#             time_energy_data_loss_backward_optimizer_i[0] += time_cost_backward

#             # optimizer部分
#             time_start_optimizer = time.time()
#             optimizer.step()
#             time_end_optimizer = time.time()
#             time_cost_optimizer = time_end_optimizer - time_start_optimizer
#             # 对time_cost_optimizer数据进行累加
#             time_energy_data_loss_backward_optimizer_i[1] += time_cost_optimizer

#             # 将time_energy_data_backward_optimizer_i加入到time_energy_data_backward_optimizer中
#             time_energy_data_loss_backward_optimizer[epoch,:] += time_energy_data_loss_backward_optimizer_i
            
#             with torch.no_grad():
#                 metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
#             timer.stop()
#             train_l = metric[0] / metric[2]
#             train_acc = metric[1] / metric[2]
#             if (i + 1) % (num_batches // 5) == 0 or i == num_batches - 1:
#                 animator.add(epoch + (i + 1) / num_batches,
#                              (train_l, train_acc, None))
#         test_acc = evaluate_accuracy_gpu(net, test_iter)
#         animator.add(epoch + 1, (None, None, test_acc))

#         # 输出一下每种层的训练时间
#         print('epoch %d, time %f sec' % (epoch, timer.sum()))
#         for j in range(len(list_layer_name)):
#             print(list_layer_name[j], 'time %f sec' % (time_energy_data[epoch,j,0]))

#         # 输出一下backward和optimizer的时间
#         print('backward time %f sec' % (time_energy_data_loss_backward_optimizer[epoch,0]))
#         print('optimizer time %f sec' % (time_energy_data_loss_backward_optimizer[epoch,1]))
#         print('loss time %f sec' % (time_energy_data_loss_backward_optimizer[epoch,2]))
#     print(f'loss {train_l:.3f}, train acc {train_acc:.3f}, '
#           f'test acc {test_acc:.3f}')
#     print(f'{metric[2] * num_epochs / timer.sum():.1f} examples/sec '
#           f'on {str(device)}')

# %%
# lr, num_epochs = 0.01, 1
# train_ch6(net, train_iter, test_iter, num_epochs, lr, 'mps')

# %%
# '''
# 这段是将d2l中的train_ch6()函数拷贝过来，然后修改了一下，目的是为了能够显示在进行每一层的前向传播的时候，能够显示出来
# 修改了其中的metric部分，对该部分进行了注释，而是调用了简单的optimizer.no_grad()
# '''
# lr, num_epochs = 0.01, 1
# def init_weights(m):
#     if type(m) == nn.Linear or type(m) == nn.Conv2d:
#         nn.init.xavier_uniform_(m.weight)
# net.apply(init_weights)

# list_layer_name = ['Conv2d','ReLU', 'MaxPool2d','Linear','Dropout','Flatten']

# # create a numpy array to store the time and energy, the shape is (num_epochs, len(list_layer_name), 2)
# # the 2 means time and energy, respectively
# time_energy_data = np.zeros((num_epochs, len(list_layer_name), 2)) # for epoch = 1, the shape is (6,2)

# # create another numpy array to store the time and energy for loss, backward and optimizer
# # the shape is (num_epochs, 3)
# time_energy_data_loss_backward_optimizer = np.zeros((num_epochs, 3))

# time_cost_other = 0

# time_avg_cost = 0

# device = 'mps'
# print('training on', 'mps')
# net.to('mps')
# optimizer = torch.optim.SGD(net.parameters(), lr=lr)
# loss = nn.CrossEntropyLoss()
# animator = d2l.Animator(xlabel='epoch', xlim=[1, num_epochs],
#                         legend=['train loss', 'train acc', 'test acc'])
# timer, num_batches = d2l.Timer(), len(train_iter)
# for epoch in range(num_epochs):
#     timer.start() # 开始计时
#     # 训练损失之和，训练准确率之和，样本数
#     metric = d2l.Accumulator(3)
#     net.train() # 设置为训练模式

#     # 将time_energy_data的第一个维度设置为epoch
#     time_energy_data[epoch,:,:] = epoch

#     # 将time_energy_data_backward_optimizer的第一个维度设置为epoch
#     time_energy_data_loss_backward_optimizer[epoch,:] = epoch

#     # initialize a time_to_device_cost to store the time cost of the device
#     time_to_device_cost = 0


#     for i, (X, y) in enumerate(train_iter):

#         if i < 500:

#             time_round = time.time()
#             optimizer.zero_grad()

#             time_to_device = time.time()
#             X, y = X.to(device), y.to(device)
#             time_to_device_end = time.time()
#             time_to_device_cost_i = time_to_device_end - time_to_device
#             time_to_device_cost += time_to_device_cost_i

#             # 增加一个time_energy_data_i, 用于记录每一次前向传播的时间和能量
#             time_energy_data_i = np.zeros((len(list_layer_name),2))

#             # 增加一个time_energy_data_backward_optimizer_i, 用于记录每一次backward和optimizer的时间和能量
#             time_energy_data_loss_backward_optimizer_i = np.zeros((3))

#             time_cost_other_i = 0

#             time_avg_cost_i = 0

#             # 将原本的y_hat = net(X)改为下面的形式，目的是为了让模型逐层运行，并且在这个过程中，记录起运行的时间以及消耗的能量
#             y_hat = X
#             for layer in net:
                
#                 # print(layer.__class__.__name__,'output shape:\t',y_hat.shape)
#                 layer_name = layer.__class__.__name__
#                 # print(layer_name)
#                 # # check if the layer_name is in the list_layer_name，if yes, then act the code below, else, continue
#                 # if layer_name in list_layer_name:
#                 # find out the layer name is in where of the list
#                 layer_index = list_layer_name.index(layer_name)
                
#                 # calculate the energy and time
#                 # 这里的时间和能量都是在每一层的前向传播的时候，进行计算的
#                 time_start_layer = time.time()
#                 '''
#                 energy部分后续加入，先进行测试时间计算
#                 '''
#                 # energy_start = 0
#                 y_hat = layer(y_hat)
#                 time_end_layer = time.time()
#                 time_cost_layer = time_end_layer - time_start_layer

#                 # print the result
#                 print(layer_name, 'time %f sec' % (time_cost_layer))
#                 print('*'*50)


#                 # 将对应的layer_index的时间和能量加入到time_energy_data中
#                 time_energy_data_i[layer_index,0] += time_cost_layer
#                 # time_energy_data_i[layer_index,1] += energy_cost_layer

#                 # print(layer_name, 'time %f sec' % (time_cost_layer))
#                 # print(time_energy_data_i)
            
#             # 将time_energy_data_i加入到time_energy_data中
#             time_energy_data[epoch,:,:] += time_energy_data_i

#             # y_hat = net(X)

#             # loss部分
#             time_start_loss = time.time()
#             l = loss(y_hat, y)
#             time_end_loss = time.time()
#             time_cost_loss = time_end_loss - time_start_loss
#             # 对time_cost_loss数据进行累加
#             time_energy_data_loss_backward_optimizer_i[0] += time_cost_loss

#             # backward部分
#             time_start_backward = time.time()
#             l.backward()
#             time_end_backward = time.time()
#             time_cost_backward = time_end_backward - time_start_backward
#             # 对time_cost_backward数据进行累加
#             time_energy_data_loss_backward_optimizer_i[1] += time_cost_backward

#             # optimizer部分
#             time_start_optimizer = time.time()
#             optimizer.step()
#             time_end_optimizer = time.time()
#             time_cost_optimizer = time_end_optimizer - time_start_optimizer
#             # 对time_cost_optimizer数据进行累加
#             time_energy_data_loss_backward_optimizer_i[2] += time_cost_optimizer

#             # 将time_energy_data_backward_optimizer_i加入到time_energy_data_backward_optimizer中
#             time_energy_data_loss_backward_optimizer[epoch,:] += time_energy_data_loss_backward_optimizer_i
            

#             '''
#             该部分是optimizer.zero_grad()部分，并且计算相对应的时间
#             不计算梯度：torch.no_grad()上下文管理器确保不计算任何梯度。这实际上减少了计算和内存需求，因为它不会保留计算图中的中间状态。从这个角度看，使用torch.no_grad()会节省能源。
#             理论上应该节省能源，但是在计算过程中，该部分消耗的时间是最长的
#             为了进行测试，将李沐原本的torch.no_grad()进行替换，更换为了optimizer.zero_grad()
#             '''
#             # time about torch.no_grad()
#             time_other_start = time.time()
#             optimizer.zero_grad()
#             # with torch.no_grad():
#             #     metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
#             time_other_end = time.time()


#             '''
#             该部分是计算train_l和train_acc的部分，以及其运行过程所需时间的代码
#             '''
#             # time about avg the train_l and train_acc
#             # time_avg_start = time.time()
#             # train_l = metric[0] / metric[2]
#             # train_acc = metric[1] / metric[2]
#             # time_avg_end = time.time()
#             # time_avg_cost_i = time_avg_end - time_avg_start
#             # time_avg_cost += time_avg_cost_i

#             # if (i + 1) % (num_batches // 5) == 0 or i == num_batches - 1:
#             #     animator.add(epoch + (i + 1) / num_batches,
#             #                     (train_l, train_acc, None))
#             # time_other_end = time.time()
#             time_cost_other_i = time_other_end - time_other_start
#             print('other time %f sec' % (time_cost_other_i))
#             time_cost_other += time_cost_other_i

#             time_end_round = time.time()
#             time_cost_round = time_end_round - time_round
#             print('round %d, time %f sec' % (i, time_cost_round))
        
#         else:
#             break

#     time_test_acc_start = time.time()
#     test_acc = evaluate_accuracy_gpu(net, test_iter)
#     time_test_acc_end = time.time()
#     time_test_acc_cost = time_test_acc_end - time_test_acc_start
#     # animator.add(epoch + 1, (None, None, test_acc))
#     timer.stop() # 停止计时 
    
#     print('epoch %d, time %f sec' % (epoch, timer.sum()))
#     # 输出一下每种层的训练时间
#     for j in range(len(list_layer_name)):
#         print(list_layer_name[j], 'time %f sec' % (time_energy_data[epoch,j,0]))
    
#     # 输出一下device的时间
#     print('device time %f sec' % (time_to_device_cost))

#     # 输出一下backward和optimizer的时间
#     print('backward time %f sec' % (time_energy_data_loss_backward_optimizer[epoch,1]))
#     print('optimizer time %f sec' % (time_energy_data_loss_backward_optimizer[epoch,2]))
#     print('loss time %f sec' % (time_energy_data_loss_backward_optimizer[epoch,0]))
# print(f'loss {train_l:.3f}, train acc {train_acc:.3f}, '
#         f'test acc {test_acc:.3f}')
# print(f'{metric[2] * num_epochs / timer.sum():.1f} examples/sec '
#         f'on {str(device)}')

# print(time_energy_data)
# print(time_energy_data_loss_backward_optimizer)
# print('other time %f sec' % (time_cost_other))
# print('time to device %f sec' % (time_to_device_cost))
# # print('time avg %f sec' % (time_avg_cost))
# print('time test acc %f sec' % (time_test_acc_cost))

# %% [markdown]
# ## 修改代码——Test1
#
# 该段代码作为这个jupyter文件的最终运行部分

# %%
import subprocess
import time

def run_powermetrics(file_path):
    """
    Run powermetrics and retrieve the output.

    :param interval: Sampling interval in milliseconds.
    :param count: Number of samples to retrieve.s
    :return: The output from powermetrics.
    """

    # Define the command as a list of arguments
    cmd = ["sudo", "powermetrics",  "-i", "1000", "--samplers", "cpu_power,gpu_power", "-a", "1", "-o", file_path]
    
    process = subprocess.Popen(cmd)
    return process

# %%
def txt_data_process(file_path):
    """
    Read the output file of powermetric and extract the power value

    :param file_path: The path of the output file of powermetric.
    :return: The list of power values.
    """

    list_power = []
    with open(file_path, 'r') as f:
        for line in f:
            if 'Combined Power' in line:
                power_value = line.split(':')[1].strip()
                print(power_value)

                # Remove the unit
                power_value = power_value.replace('mW', '')

                # Convert to integer
                power_value = int(power_value)
                list_power.append(power_value)

    print(list_power)
    print(len(list_power))

    # do the data process
    '''
    The data from list_power is the Conbined Power of each second.
    The data is the Power of each second.
    we need to calculate the energy consumption of the whole process.
    and need to change the J to kWh.
    '''
    # calculate the energy consumption
    energy_consumption = 0
    for i in range(len(list_power)):
       energy_consumption += list_power[i]
    print(energy_consumption)

    # change the mW to W
    energy_consumption = energy_consumption / 1000

    # calculate the energy consumption, the interval is 1 second, and the energy unit is J
    energy_consumption = energy_consumption * 1
    
    # change the J to kWh
    energy_consumption = energy_consumption / 3600000
    print(energy_consumption)
    
    return energy_consumption, list_power

# %%
energy_file = 'energy.txt'

# %%
'''
这段是将d2l中的train_ch6()函数拷贝过来，然后修改了一下，目的是为了能够显示在进行每一层的前向传播的时候，能够显示出来
修改了其中的metric部分，对该部分进行了注释，而是调用了简单的optimizer.no_grad()
得调整一下整体的代码，需要对循环内部的东西全部重写一下，然后再进行测试
'''
lr, num_epochs = 0.01, 1 # learning rate and number of epochs
def init_weights(m): # 初始化权重
    if type(m) == nn.Linear or type(m) == nn.Conv2d:
        nn.init.xavier_uniform_(m.weight)
net.apply(init_weights)

list_layer_name = ['Conv2d','ReLU', 'MaxPool2d','Linear','Dropout','Flatten'] # 该模型中包括的所有的层的名字

# create a numpy array to store the time and energy, the shape is (num_epochs, len(list_layer_name), 2)
# the 2 means time and energy, respectively
# 目标是将每次循环过程中，在运行每一个层的时候的所需时间全部记录下来（第一步测试）
# 如果测试成功，则对后续的能耗进行测试
time_energy_data = np.zeros((num_epochs, len(list_layer_name), 2)) # for epoch = 1, the shape is (6,2)，第一列是时间，第二列是能耗

# create another numpy array to store the time and energy for loss, backward and optimizer
# the shape is (num_epochs, 3)
# # 增加这个的目的是为了记录loss，backward和optimizer的时间，看看整体计算的过程中是否有问题
# time_energy_data_loss_backward_optimizer = np.zeros((num_epochs, 3))
'''将loss, backward and optimizer的时间改为单独计算，先进行测试，看看结果如何'''
time_cost_loss = 0
time_cost_backward = 0
time_cost_optimizer = 0

# initialize a time_to_device_cost to store the time cost of the device
time_to_device_cost = 0

# 记录其他部分的时间，先加上，看看结果
# time_cost_other = 0

# 记录计算平均loss和平均准确度的时间，目前暂时不需要
# time_avg_cost = 0

# 记录计算test_acc的时间
time_test_acc_cost = 0

# 设定运行的设备
device = 'mps'
print('training on', 'mps')
net.to('mps') # 将模型放到对应的设备上

# 初始化optimizer和loss
optimizer = torch.optim.SGD(net.parameters(), lr=lr)
loss_fn = nn.CrossEntropyLoss()

# 对动画部分先进行注释，暂时先不对该部分进行考虑
# animator = d2l.Animator(xlabel='epoch', xlim=[1, num_epochs],
#                         legend=['train loss', 'train acc', 'test acc'])

# 初始化计时器
timer, num_batches = d2l.Timer(), len(train_iter)

for epoch in range(num_epochs):
    timer.start() # 开始计时
    # run powermetrics
    powermetrics_process = run_powermetrics(energy_file)
    # 训练损失之和，训练准确率之和，样本数
    # metric = d2l.Accumulator(3)
    net.train() # 设置为训练模式

    # 将time_energy_data的第一个维度设置为epoch
    time_energy_data[epoch,:,:] = epoch
    # 将time_energy_data_backward_optimizer的第一个维度设置为epoch
    # time_energy_data_loss_backward_optimizer[epoch,:] = epoch
    # 增加一个time_energy_data_backward_optimizer_i, 用于记录每一次backward和optimizer的时间和能量
    # time_energy_data_loss_backward_optimizer_i = np.zeros((3))

    for i, (X, y) in enumerate(train_iter): # 每个循环结束的时候有个100s的睡眠时间，用于较长时间显示一下每一轮的数据
        '''每一轮的运行结束之后，都会有一个100s的睡眠时间，用于显示一下每一轮的数据
        数据包括：
        1. 运行该轮的时间
        2. 在该轮运行中，每一层的运行时间
        3. 在该轮运行中，loss，backward和optimizer的运行时间
        4. 在该轮运行中，将数据放到对应的设备上的时间'''
        if i < 500:
            # 显示是第几轮
            print('round %d' % (i))
            time_round = time.time() # 计算每一轮的时间
            optimizer.zero_grad() # 将optimizer的梯度清零

            # 增加一个time_energy_data_i, 用于记录每一次前向传播的时间和能量
            time_energy_data_i = np.zeros((len(list_layer_name),2))
            sum_time_cost_round = 0 # 用于记录每一轮的时间

            # 计算将数据放到对应的设备上的时间
            time_to_device_cost_i = 0
            time_to_device = time.time()
            X, y = X.to(device), y.to(device)
            time_to_device_end = time.time()
            time_to_device_cost_i = time_to_device_end - time_to_device
            print('time to device %f sec' % (time_to_device_cost_i))
            time_to_device_cost += time_to_device_cost_i

            # initialize a time_cost_other_i to store the time cost of the other part
            time_cost_other_i = 0
            # initialize a time_avg_cost_i to store the time cost of the avg part
            # time_avg_cost_i = 0

            # 将原本的y_hat = net(X)改为下面的形式，目的是为了让模型逐层运行，并且在这个过程中，记录起运行的时间以及消耗的能量
            y_hat = X
            for layer in net:
                # 每次循环开始的时候进行初始化，防止后面计算过程中出现错误
                time_cost_layer = 0
                # print(layer.__class__.__name__,'output shape:\t',y_hat.shape)
                layer_name = layer.__class__.__name__
                # print(layer_name)
                # check if the layer_name is in the list_layer_name，if yes, then act the code below, else, continue
                # if layer_name in list_layer_name:
                # find out the layer name is in where of the list
                layer_index = list_layer_name.index(layer_name)
                
                # calculate the energy and time of each layer
                # 这里的时间和能量都是在每一层的前向传播的时候，进行计算的
                time_start_layer = time.time()
                '''energy部分后续加入，先进行测试时间计算'''
                # energy_start = 0
                y_hat = layer(y_hat)
                time_end_layer = time.time()
                time_cost_layer = time_end_layer - time_start_layer
                # print the result
                # print(layer_name, 'time %f sec' % (time_cost_layer))
                # print('*'*50)
                # 将对应的layer_index的时间和能量加入到time_energy_data中
                time_energy_data_i[layer_index,0] += time_cost_layer
                # time_energy_data_i[layer_index,1] += energy_cost_layer
                # print(time_energy_data_i)

                # 加入一个sleep，用于测试
                # time.sleep(2)

            # 将time_energy_data_i加入到time_energy_data中
            time_energy_data[epoch,:,:] += time_energy_data_i
            # 求time_energy_data_i的和，用于计算每一轮的时间
            sum_time_cost_round_layer = np.sum(time_energy_data_i[:,0])
            print('sum_time_cost_round_layer %f sec' % (sum_time_cost_round_layer))
            # 显示一下time_energy_data
            # print(time_energy_data[epoch,:,:])
            # print("-"*50)
            # time.sleep(3)

            # loss部分
            time_cost_loss_i = 0 # 初始化loss的时间
            time_start_loss = time.time()
            loss = loss_fn(y_hat, y)
            time_end_loss = time.time()
            time_cost_loss_i = time_end_loss - time_start_loss
            print('loss time %f sec' % (time_cost_loss_i))
            time_cost_loss += time_cost_loss_i
            # 对time_cost_loss数据进行累加
            # time_energy_data_loss_backward_optimizer_i[0] += time_cost_loss

            # backward部分
            time_cost_backward_i = 0 # 初始化backward的时间
            time_start_backward = time.time()
            loss.backward()
            time_end_backward = time.time()
            time_cost_backward_i = time_end_backward - time_start_backward
            print('backward time %f sec' % (time_cost_backward_i))
            time_cost_backward += time_cost_backward_i
            # 对time_cost_backward数据进行累加
            # time_energy_data_loss_backward_optimizer_i[1] += time_cost_backward

            # optimizer部分
            time_cost_optimizer_i = 0 # 初始化optimizer的时间
            time_start_optimizer = time.time()
            optimizer.step()
            time_end_optimizer = time.time()
            time_cost_optimizer_i = time_end_optimizer - time_start_optimizer
            print('optimizer time %f sec' % (time_cost_optimizer_i))
            time_cost_optimizer += time_cost_optimizer_i
            # 对time_cost_optimizer数据进行累加
            # time_energy_data_loss_backward_optimizer_i[2] += time_cost_optimizer

            # 将time_energy_data_backward_optimizer_i加入到time_energy_data_backward_optimizer中
            # time_energy_data_loss_backward_optimizer[epoch,:] += time_energy_data_loss_backward_optimizer_i
            
            '''
            该部分是optimizer.zero_grad()部分，并且计算相对应的时间
            不计算梯度：torch.no_grad()上下文管理器确保不计算任何梯度。这实际上减少了计算和内存需求，因为它不会保留计算图中的中间状态。从这个角度看，使用torch.no_grad()会节省能源。
            理论上应该节省能源，但是在计算过程中，该部分消耗的时间是最长的
            为了进行测试，将李沐原本的torch.no_grad()进行替换，更换为了optimizer.zero_grad()
            更新10.17：删除掉该部分的optimizer.zero_grad()，因为在循环开始的部分已经申明了
            '''
            # other time about torch.no_grad()
            # time_cost_other_i = 0 # 初始化other的时间
            # time about torch.no_grad()
            # time_other_start = time.time()
            # with torch.no_grad():
            #     metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            # if i % 100 == 0:
            #     loss, current = l.item(), (i + 1) * len(X)
            #     print(f"loss: {loss:>7f}  [{i:>5d}/{num_batches:>5d}]")
            '''该部分是计算train_l和train_acc的部分，以及其运行过程所需时间的代码'''
            # time about avg the train_l and train_acc
            # time_avg_start = time.time()
            # train_l = metric[0] / metric[2]
            # train_acc = metric[1] / metric[2]
            # time_avg_end = time.time()
            # time_avg_cost_i = time_avg_end - time_avg_start
            # time_avg_cost += time_avg_cost_i
            # if (i + 1) % (num_batches // 5) == 0 or i == num_batches - 1:
            #     animator.add(epoch + (i + 1) / num_batches,
            #                     (train_l, train_acc, None))
            # time_other_end = time.time()
            # time_cost_other_i = time_other_end - time_other_start
            # print('other time %f sec' % (time_cost_other_i))
            # time_cost_other += time_cost_other_i

            time_end_round = time.time()
            time_cost_round = time_end_round - time_round
            print('round %d, time %f sec' % (i, time_cost_round))
            sum_time_cost_round = time_to_device_cost_i + time_cost_loss_i + time_cost_backward_i + time_cost_optimizer_i
            sum_time_cost_round += sum_time_cost_round_layer
            print('the calculation result for the round is: ', sum_time_cost_round)

            # 设定一个time.sleep, 用于测试
            # time.sleep(10)
        else:
            break
        
    time_test_acc_cost_epoch = 0
    time_test_acc_start = time.time()
    # test_acc = evaluate_accuracy_gpu(net, test_iter)
    test_round = test_loop(test_iter, net, loss_fn, device)
    time_test_acc_end = time.time()
    time_test_acc_cost_epoch = time_test_acc_end - time_test_acc_start
    time_test_acc_cost += time_test_acc_cost_epoch
    # animator.add(epoch + 1, (None, None, test_acc))

    powermetrics_process.terminate()
    powermetrics_process.wait()
    
    timer.stop() # 停止计时 
    
    print('epoch %d, time %f sec' % (epoch, timer.sum()))
    # 输出一下每种层的训练时间
    for j in range(len(list_layer_name)):
        print(list_layer_name[j], 'time %f sec' % (time_energy_data[epoch,j,0]))
    
    # # 输出一下device的时间
    # print('device time %f sec' % (time_to_device_cost))

    # 输出一下backward和optimizer的时间
    # print('backward time %f sec' % (time_energy_data_loss_backward_optimizer[epoch,1]))
    # print('optimizer time %f sec' % (time_energy_data_loss_backward_optimizer[epoch,2]))
    # print('loss time %f sec' % (time_energy_data_loss_backward_optimizer[epoch,0]))
# print(f'loss {train_l:.3f}, train acc {train_acc:.3f}, '
#         f'test acc {test_acc:.3f}')
# print(f'{metric[2] * num_epochs / timer.sum():.1f} examples/sec '
#         f'on {str(device)}')

# print('other time %f sec' % (time_cost_other))
print('time to device %f sec' % (time_to_device_cost))
print(time_energy_data)
# print(time_energy_data_loss_backward_optimizer)
print('loss time %f sec' % (time_cost_loss))
print('backward time %f sec' % (time_cost_backward))
print('optimizer time %f sec' % (time_cost_optimizer))
# print('time avg %f sec' % (time_avg_cost))
print('time test acc %f sec' % (time_test_acc_cost))
# 显示总体运行时间
# Out:
# training on mps
# round 0
# time to device 0.002688 sec
# sum_time_cost_round_layer 1.463419 sec
# loss time 0.168790 sec
# backward time 1.671261 sec
# optimizer time 0.487500 sec
# round 0, time 3.795150 sec
# the calculation result for the round is:  3.7936573028564453
# round 1
# time to device 0.024014 sec
# sum_time_cost_round_layer 0.016661 sec
# loss time 0.002979 sec
# backward time 0.008601 sec
# optimizer time 0.003253 sec
# round 1, time 0.055897 sec
# the calculation result for the round is:  0.05550789833068848
# round 2
# time to device 0.299521 sec
# sum_time_cost_round_layer 0.006251 sec
# loss time 0.001084 sec
# backward time 0.011069 sec
# optimizer time 0.002755 sec
# round 2, time 0.321439 sec
# the calculation result for the round is:  0.3206794261932373
# round 3
# time to device 0.290648 sec
# sum_time_cost_round_layer 0.006000 sec
# loss time 0.000881 sec
# backward time 0.009752 sec
# optimizer time 0.003644 sec
# round 3, time 0.311661 sec
# the calculation result for the round is:  0.3109242916107178
# round 4
# time to device 0.289656 sec
# sum_time_cost_round_layer 0.006293 sec
# loss time 0.000883 sec
# backward time 0.009277 sec
# optimizer time 0.003928 sec
# round 4, time 0.310574 sec
# the calculation result for the round is:  0.31003689765930176
# round 5
# time to device 0.292312 sec
# sum_time_cost_round_layer 0.006659 sec
# loss time 0.000885 sec
# backward time 0.008894 sec
# optimizer time 0.003927 sec
# round 5, time 0.313487 sec
# the calculation result for the round is:  0.31267714500427246
# round 6
# time to device 0.290532 sec
# sum_time_cost_round_layer 0.006211 sec
# loss time 0.000996 sec
# backward time 0.009262 sec
# optimizer time 0.003629 sec
# round 6, time 0.311525 sec
# the calculation result for the round is:  0.31062936782836914
# round 7
# time to device 0.290197 sec
# sum_time_cost_round_layer 0.005997 sec
# loss time 0.000869 sec
# backward time 0.010920 sec
# optimizer time 0.003739 sec
# round 7, time 0.312536 sec
# the calculation result for the round is:  0.3117213249206543
# round 8
# time to device 0.289480 sec
# sum_time_cost_round_layer 0.006034 sec
# loss time 0.000875 sec
# backward time 0.009130 sec
# optimizer time 0.003952 sec
# round 8, time 0.310385 sec
# the calculation result for the round is:  0.30947113037109375
# round 9
# time to device 0.293697 sec
# sum_time_cost_round_layer 0.006617 sec
# loss time 0.000876 sec
# backward time 0.008312 sec
# optimizer time 0.001409 sec
# round 9, time 0.311538 sec
# the calculation result for the round is:  0.3109111785888672
# round 10
# time to device 0.293514 sec
# sum_time_cost_round_layer 0.006534 sec
# loss time 0.001072 sec
# backward time 0.009411 sec
# optimizer time 0.003643 sec
# round 10, time 0.314959 sec
# the calculation result for the round is:  0.3141744136810303
# round 11
# time to device 0.289869 sec
# sum_time_cost_round_layer 0.005979 sec
# loss time 0.000870 sec
# backward time 0.010057 sec
# optimizer time 0.003596 sec
# round 11, time 0.311066 sec
# the calculation result for the round is:  0.31037068367004395
# round 12
# time to device 0.293568 sec
# sum_time_cost_round_layer 0.007086 sec
# loss time 0.000870 sec
# backward time 0.013071 sec
# optimizer time 0.001885 sec
# round 12, time 0.317225 sec
# the calculation result for the round is:  0.3164799213409424
# round 13
# time to device 0.290770 sec
# sum_time_cost_round_layer 0.006200 sec
# loss time 0.001626 sec
# backward time 0.011460 sec
# optimizer time 0.002816 sec
# round 13, time 0.314322 sec
# the calculation result for the round is:  0.31287264823913574
# round 14
# time to device 0.293229 sec
# sum_time_cost_round_layer 0.006293 sec
# loss time 0.000915 sec
# backward time 0.012840 sec
# optimizer time 0.004282 sec
# round 14, time 0.318050 sec
# the calculation result for the round is:  0.31755876541137695
# round 15
# time to device 0.290309 sec
# sum_time_cost_round_layer 0.007400 sec
# loss time 0.000913 sec
# backward time 0.013386 sec
# optimizer time 0.003605 sec
# round 15, time 0.316402 sec
# the calculation result for the round is:  0.3156135082244873
# round 16
# time to device 0.289840 sec
# sum_time_cost_round_layer 0.007270 sec
# loss time 0.000932 sec
# backward time 0.012689 sec
# optimizer time 0.002888 sec
# round 16, time 0.314522 sec
# the calculation result for the round is:  0.31361889839172363
# round 17
# time to device 0.293929 sec
# sum_time_cost_round_layer 0.007410 sec
# loss time 0.000943 sec
# backward time 0.012729 sec
# optimizer time 0.002389 sec
# round 17, time 0.318240 sec
# the calculation result for the round is:  0.3173999786376953
# round 18
# time to device 0.289624 sec
# sum_time_cost_round_layer 0.006560 sec
# loss time 0.001059 sec
# backward time 0.010276 sec
# optimizer time 0.003699 sec
# round 18, time 0.311994 sec
# the calculation result for the round is:  0.3112185001373291
# round 19
# time to device 0.294018 sec
# sum_time_cost_round_layer 0.006564 sec
# loss time 0.000915 sec
# backward time 0.011736 sec
# optimizer time 0.003606 sec
# round 19, time 0.317712 sec
# the calculation result for the round is:  0.31683897972106934
# round 20
# time to device 0.311975 sec
# sum_time_cost_round_layer 0.006973 sec
# loss time 0.001102 sec
# backward time 0.011885 sec
# optimizer time 0.004146 sec
# round 20, time 0.336990 sec
# the calculation result for the round is:  0.33608055114746094
# round 21
# time to device 0.292539 sec
# sum_time_cost_round_layer 0.008308 sec
# loss time 0.001176 sec
# backward time 0.010655 sec
# optimizer time 0.004868 sec
# round 21, time 0.318673 sec
# the calculation result for the round is:  0.31754565238952637
# round 22
# time to device 0.299990 sec
# sum_time_cost_round_layer 0.006675 sec
# loss time 0.000958 sec
# backward time 0.011558 sec
# optimizer time 0.002876 sec
# round 22, time 0.322856 sec
# the calculation result for the round is:  0.32205653190612793
# round 23
# time to device 0.294717 sec
# sum_time_cost_round_layer 0.007175 sec
# loss time 0.001043 sec
# backward time 0.010387 sec
# optimizer time 0.003745 sec
# round 23, time 0.317685 sec
# the calculation result for the round is:  0.31706690788269043
# round 24
# time to device 0.291668 sec
# sum_time_cost_round_layer 0.006495 sec
# loss time 0.000927 sec
# backward time 0.010959 sec
# optimizer time 0.003610 sec
# round 24, time 0.314459 sec
# the calculation result for the round is:  0.3136587142944336
# round 25
# time to device 0.292300 sec
# sum_time_cost_round_layer 0.006448 sec
# loss time 0.000953 sec
# backward time 0.010131 sec
# optimizer time 0.003848 sec
# round 25, time 0.314523 sec
# the calculation result for the round is:  0.31367921829223633
# round 26
# time to device 0.292233 sec
# sum_time_cost_round_layer 0.009138 sec
# loss time 0.000935 sec
# backward time 0.011749 sec
# optimizer time 0.001364 sec
# round 26, time 0.316181 sec
# the calculation result for the round is:  0.3154184818267822
# round 27
# time to device 0.294357 sec
# sum_time_cost_round_layer 0.006146 sec
# loss time 0.001366 sec
# backward time 0.012675 sec
# optimizer time 0.001865 sec
# round 27, time 0.317392 sec
# the calculation result for the round is:  0.3164093494415283
# round 28
# time to device 0.294342 sec
# sum_time_cost_round_layer 0.007902 sec
# loss time 0.001059 sec
# backward time 0.011724 sec
# optimizer time 0.001760 sec
# round 28, time 0.317841 sec
# the calculation result for the round is:  0.3167870044708252
# round 29
# time to device 0.292133 sec
# sum_time_cost_round_layer 0.007114 sec
# loss time 0.001034 sec
# backward time 0.011224 sec
# optimizer time 0.002367 sec
# round 29, time 0.314374 sec
# the calculation result for the round is:  0.3138716220855713
# round 30
# time to device 0.296054 sec
# sum_time_cost_round_layer 0.006255 sec
# loss time 0.000894 sec
# backward time 0.013450 sec
# optimizer time 0.002209 sec
# round 30, time 0.319335 sec
# the calculation result for the round is:  0.3188624382019043
# round 31
# time to device 0.293233 sec
# sum_time_cost_round_layer 0.006046 sec
# loss time 0.000871 sec
# backward time 0.013506 sec
# optimizer time 0.003123 sec
# round 31, time 0.317255 sec
# the calculation result for the round is:  0.31677961349487305
# round 32
# time to device 0.302716 sec
# sum_time_cost_round_layer 0.006877 sec
# loss time 0.000952 sec
# backward time 0.011772 sec
# optimizer time 0.003649 sec
# round 32, time 0.326799 sec
# the calculation result for the round is:  0.32596635818481445
# round 33
# time to device 0.293643 sec
# sum_time_cost_round_layer 0.007285 sec
# loss time 0.001654 sec
# backward time 0.012016 sec
# optimizer time 0.003022 sec
# round 33, time 0.318270 sec
# the calculation result for the round is:  0.31761980056762695
# round 34
# time to device 0.301183 sec
# sum_time_cost_round_layer 0.009167 sec
# loss time 0.000913 sec
# backward time 0.009910 sec
# optimizer time 0.001813 sec
# round 34, time 0.323907 sec
# the calculation result for the round is:  0.3229856491088867
# round 35
# time to device 0.294585 sec
# sum_time_cost_round_layer 0.007673 sec
# loss time 0.000980 sec
# backward time 0.009905 sec
# optimizer time 0.003758 sec
# round 35, time 0.317436 sec
# the calculation result for the round is:  0.31690096855163574
# round 36
# time to device 0.294074 sec
# sum_time_cost_round_layer 0.006477 sec
# loss time 0.000973 sec
# backward time 0.008752 sec
# optimizer time 0.003978 sec
# round 36, time 0.315029 sec
# the calculation result for the round is:  0.3142538070678711
# round 37
# time to device 0.290851 sec
# sum_time_cost_round_layer 0.006160 sec
# loss time 0.000952 sec
# backward time 0.010113 sec
# optimizer time 0.003625 sec
# round 37, time 0.312529 sec
# the calculation result for the round is:  0.31170129776000977
# round 38
# time to device 0.290110 sec
# sum_time_cost_round_layer 0.007922 sec
# loss time 0.001194 sec
# backward time 0.010680 sec
# optimizer time 0.003702 sec
# round 38, time 0.314293 sec
# the calculation result for the round is:  0.31360793113708496
# round 39
# time to device 0.322672 sec
# sum_time_cost_round_layer 0.007975 sec
# loss time 0.001134 sec
# backward time 0.025799 sec
# optimizer time 0.004759 sec
# round 39, time 0.362987 sec
# the calculation result for the round is:  0.3623387813568115
# round 40
# time to device 0.299618 sec
# sum_time_cost_round_layer 0.012329 sec
# loss time 0.001385 sec
# backward time 0.011302 sec
# optimizer time 0.001749 sec
# round 40, time 0.328327 sec
# the calculation result for the round is:  0.3263823986053467
# round 41
# time to device 0.307979 sec
# sum_time_cost_round_layer 0.009801 sec
# loss time 0.012988 sec
# backward time 0.011336 sec
# optimizer time 0.003001 sec
# round 41, time 0.346424 sec
# the calculation result for the round is:  0.3451042175292969
# round 42
# time to device 0.311098 sec
# sum_time_cost_round_layer 0.018082 sec
# loss time 0.001795 sec
# backward time 0.007046 sec
# optimizer time 0.001877 sec
# round 42, time 0.341139 sec
# the calculation result for the round is:  0.33989810943603516
# round 43
# time to device 0.301171 sec
# sum_time_cost_round_layer 0.006166 sec
# loss time 0.001545 sec
# backward time 0.003536 sec
# optimizer time 0.001959 sec
# round 43, time 0.315202 sec
# the calculation result for the round is:  0.3143765926361084
# round 44
# time to device 0.298901 sec
# sum_time_cost_round_layer 0.006531 sec
# loss time 0.000910 sec
# backward time 0.009244 sec
# optimizer time 0.004419 sec
# round 44, time 0.320814 sec
# the calculation result for the round is:  0.3200047016143799
# round 45
# time to device 0.293071 sec
# sum_time_cost_round_layer 0.009655 sec
# loss time 0.000964 sec
# backward time 0.025911 sec
# optimizer time 0.001764 sec
# round 45, time 0.332042 sec
# the calculation result for the round is:  0.33136487007141113
# round 46
# time to device 0.285648 sec
# sum_time_cost_round_layer 0.006404 sec
# loss time 0.000869 sec
# backward time 0.010511 sec
# optimizer time 0.003938 sec
# round 46, time 0.308126 sec
# the calculation result for the round is:  0.3073701858520508
# round 47
# time to device 0.290128 sec
# sum_time_cost_round_layer 0.005965 sec
# loss time 0.000904 sec
# backward time 0.009732 sec
# optimizer time 0.003576 sec
# round 47, time 0.311092 sec
# the calculation result for the round is:  0.3103048801422119
# round 48
# time to device 0.291421 sec
# sum_time_cost_round_layer 0.006779 sec
# loss time 0.000923 sec
# backward time 0.009025 sec
# optimizer time 0.004013 sec
# round 48, time 0.312751 sec
# the calculation result for the round is:  0.3121609687805176
# round 49
# time to device 0.291595 sec
# sum_time_cost_round_layer 0.006966 sec
# loss time 0.000884 sec
# backward time 0.008940 sec
# optimizer time 0.004069 sec
# round 49, time 0.313259 sec
# the calculation result for the round is:  0.3124537467956543
# round 50
# time to device 0.289507 sec
# sum_time_cost_round_layer 0.006065 sec
# loss time 0.001046 sec
# backward time 0.009031 sec
# optimizer time 0.003650 sec
# round 50, time 0.310116 sec
# the calculation result for the round is:  0.3092987537384033
# round 51
# time to device 0.292769 sec
# sum_time_cost_round_layer 0.006057 sec
# loss time 0.001162 sec
# backward time 0.009750 sec
# optimizer time 0.003625 sec
# round 51, time 0.314182 sec
# the calculation result for the round is:  0.31336331367492676
# round 52
# time to device 0.289915 sec
# sum_time_cost_round_layer 0.005841 sec
# loss time 0.000866 sec
# backward time 0.009033 sec
# optimizer time 0.004205 sec
# round 52, time 0.310721 sec
# the calculation result for the round is:  0.3098602294921875
# round 53
# time to device 0.289518 sec
# sum_time_cost_round_layer 0.006929 sec
# loss time 0.000876 sec
# backward time 0.009790 sec
# optimizer time 0.003929 sec
# round 53, time 0.311894 sec
# the calculation result for the round is:  0.31104230880737305
# round 54
# time to device 0.292229 sec
# sum_time_cost_round_layer 0.006526 sec
# loss time 0.001075 sec
# backward time 0.009085 sec
# optimizer time 0.003880 sec
# round 54, time 0.313339 sec
# the calculation result for the round is:  0.31279540061950684
# round 55
# time to device 0.290284 sec
# sum_time_cost_round_layer 0.007434 sec
# loss time 0.001063 sec
# backward time 0.010937 sec
# optimizer time 0.004488 sec
# round 55, time 0.315101 sec
# the calculation result for the round is:  0.3142063617706299
# round 56
# time to device 0.289374 sec
# sum_time_cost_round_layer 0.012240 sec
# loss time 0.002516 sec
# backward time 0.014312 sec
# optimizer time 0.001459 sec
# round 56, time 0.320662 sec
# the calculation result for the round is:  0.3199005126953125
# round 57
# time to device 0.282066 sec
# sum_time_cost_round_layer 0.008002 sec
# loss time 0.000882 sec
# backward time 0.015459 sec
# optimizer time 0.004397 sec
# round 57, time 0.311604 sec
# the calculation result for the round is:  0.3108060359954834
# round 58
# time to device 0.283455 sec
# sum_time_cost_round_layer 0.010908 sec
# loss time 0.001172 sec
# backward time 0.010741 sec
# optimizer time 0.001440 sec
# round 58, time 0.309254 sec
# the calculation result for the round is:  0.30771613121032715
# round 59
# time to device 0.290900 sec
# sum_time_cost_round_layer 0.006325 sec
# loss time 0.000968 sec
# backward time 0.010374 sec
# optimizer time 0.003701 sec
# round 59, time 0.313204 sec
# the calculation result for the round is:  0.312267541885376
# round 60
# time to device 0.291831 sec
# sum_time_cost_round_layer 0.009825 sec
# loss time 0.001147 sec
# backward time 0.011195 sec
# optimizer time 0.001425 sec
# round 60, time 0.315983 sec
# the calculation result for the round is:  0.31542325019836426
# round 61
# time to device 0.297813 sec
# sum_time_cost_round_layer 0.003069 sec
# loss time 0.000435 sec
# backward time 0.004345 sec
# optimizer time 0.001941 sec
# round 61, time 0.308065 sec
# the calculation result for the round is:  0.307603120803833
# round 62
# time to device 0.307628 sec
# sum_time_cost_round_layer 0.006045 sec
# loss time 0.000959 sec
# backward time 0.010138 sec
# optimizer time 0.003656 sec
# round 62, time 0.329199 sec
# the calculation result for the round is:  0.3284263610839844
# round 63
# time to device 0.291908 sec
# sum_time_cost_round_layer 0.006114 sec
# loss time 0.000861 sec
# backward time 0.009877 sec
# optimizer time 0.003631 sec
# round 63, time 0.312931 sec
# the calculation result for the round is:  0.3123910427093506
# round 64
# time to device 0.293046 sec
# sum_time_cost_round_layer 0.006592 sec
# loss time 0.001922 sec
# backward time 0.011970 sec
# optimizer time 0.001477 sec
# round 64, time 0.316302 sec
# the calculation result for the round is:  0.31500697135925293
# round 65
# time to device 0.291734 sec
# sum_time_cost_round_layer 0.012440 sec
# loss time 0.002495 sec
# backward time 0.009396 sec
# optimizer time 0.001393 sec
# round 65, time 0.318973 sec
# the calculation result for the round is:  0.3174574375152588
# round 66
# time to device 0.289505 sec
# sum_time_cost_round_layer 0.006158 sec
# loss time 0.000889 sec
# backward time 0.010071 sec
# optimizer time 0.003545 sec
# round 66, time 0.310871 sec
# the calculation result for the round is:  0.3101673126220703
# round 67
# time to device 0.289698 sec
# sum_time_cost_round_layer 0.007795 sec
# loss time 0.000943 sec
# backward time 0.009326 sec
# optimizer time 0.004027 sec
# round 67, time 0.312707 sec
# the calculation result for the round is:  0.31178903579711914
# round 68
# time to device 0.301077 sec
# sum_time_cost_round_layer 0.008666 sec
# loss time 0.002176 sec
# backward time 0.011266 sec
# optimizer time 0.001430 sec
# round 68, time 0.325271 sec
# the calculation result for the round is:  0.3246142864227295
# round 69
# time to device 0.297459 sec
# sum_time_cost_round_layer 0.007907 sec
# loss time 0.000961 sec
# backward time 0.009205 sec
# optimizer time 0.004966 sec
# round 69, time 0.321316 sec
# the calculation result for the round is:  0.3204984664916992
# round 70
# time to device 0.291236 sec
# sum_time_cost_round_layer 0.010184 sec
# loss time 0.001233 sec
# backward time 0.008693 sec
# optimizer time 0.002957 sec
# round 70, time 0.315263 sec
# the calculation result for the round is:  0.3143031597137451
# round 71
# time to device 0.292048 sec
# sum_time_cost_round_layer 0.020142 sec
# loss time 0.007095 sec
# backward time 0.004686 sec
# optimizer time 0.001465 sec
# round 71, time 0.326373 sec
# the calculation result for the round is:  0.3254358768463135
# round 72
# time to device 0.283737 sec
# sum_time_cost_round_layer 0.007307 sec
# loss time 0.000904 sec
# backward time 0.009656 sec
# optimizer time 0.004334 sec
# round 72, time 0.306755 sec
# the calculation result for the round is:  0.305938720703125
# round 73
# time to device 0.295212 sec
# sum_time_cost_round_layer 0.009055 sec
# loss time 0.000898 sec
# backward time 0.010375 sec
# optimizer time 0.001899 sec
# round 73, time 0.318960 sec
# the calculation result for the round is:  0.31743907928466797
# round 74
# time to device 0.295014 sec
# sum_time_cost_round_layer 0.006340 sec
# loss time 0.000880 sec
# backward time 0.010381 sec
# optimizer time 0.003830 sec
# round 74, time 0.316933 sec
# the calculation result for the round is:  0.31644511222839355
# round 75
# time to device 0.295793 sec
# sum_time_cost_round_layer 0.006336 sec
# loss time 0.000956 sec
# backward time 0.010412 sec
# optimizer time 0.003624 sec
# round 75, time 0.317991 sec
# the calculation result for the round is:  0.3171207904815674
# round 76
# time to device 0.291151 sec
# sum_time_cost_round_layer 0.009130 sec
# loss time 0.002558 sec
# backward time 0.011989 sec
# optimizer time 0.001437 sec
# round 76, time 0.316872 sec
# the calculation result for the round is:  0.3162658214569092
# round 77
# time to device 0.287794 sec
# sum_time_cost_round_layer 0.010011 sec
# loss time 0.001227 sec
# backward time 0.009885 sec
# optimizer time 0.001355 sec
# round 77, time 0.311384 sec
# the calculation result for the round is:  0.310272216796875
# round 78
# time to device 0.290691 sec
# sum_time_cost_round_layer 0.007908 sec
# loss time 0.000882 sec
# backward time 0.012283 sec
# optimizer time 0.001445 sec
# round 78, time 0.314045 sec
# the calculation result for the round is:  0.31320881843566895
# round 79
# time to device 0.290660 sec
# sum_time_cost_round_layer 0.006466 sec
# loss time 0.002007 sec
# backward time 0.011145 sec
# optimizer time 0.002520 sec
# round 79, time 0.313666 sec
# the calculation result for the round is:  0.31279826164245605
# round 80
# time to device 0.294057 sec
# sum_time_cost_round_layer 0.007545 sec
# loss time 0.001459 sec
# backward time 0.012518 sec
# optimizer time 0.003216 sec
# round 80, time 0.319822 sec
# the calculation result for the round is:  0.31879448890686035
# round 81
# time to device 0.291653 sec
# sum_time_cost_round_layer 0.007860 sec
# loss time 0.000907 sec
# backward time 0.008947 sec
# optimizer time 0.004519 sec
# round 81, time 0.314522 sec
# the calculation result for the round is:  0.3138852119445801
# round 82
# time to device 0.293239 sec
# sum_time_cost_round_layer 0.006670 sec
# loss time 0.001150 sec
# backward time 0.011270 sec
# optimizer time 0.002349 sec
# round 82, time 0.315273 sec
# the calculation result for the round is:  0.31467723846435547
# round 83
# time to device 0.294494 sec
# sum_time_cost_round_layer 0.008543 sec
# loss time 0.000887 sec
# backward time 0.009699 sec
# optimizer time 0.003838 sec
# round 83, time 0.318327 sec
# the calculation result for the round is:  0.3174607753753662
# round 84
# time to device 0.290727 sec
# sum_time_cost_round_layer 0.007421 sec
# loss time 0.001061 sec
# backward time 0.009471 sec
# optimizer time 0.004455 sec
# round 84, time 0.314031 sec
# the calculation result for the round is:  0.31313490867614746
# round 85
# time to device 0.295532 sec
# sum_time_cost_round_layer 0.006541 sec
# loss time 0.000883 sec
# backward time 0.008938 sec
# optimizer time 0.003984 sec
# round 85, time 0.316660 sec
# the calculation result for the round is:  0.31587767601013184
# round 86
# time to device 0.292129 sec
# sum_time_cost_round_layer 0.007736 sec
# loss time 0.001001 sec
# backward time 0.008976 sec
# optimizer time 0.003598 sec
# round 86, time 0.314335 sec
# the calculation result for the round is:  0.31344032287597656
# round 87
# time to device 0.288931 sec
# sum_time_cost_round_layer 0.006453 sec
# loss time 0.000916 sec
# backward time 0.010819 sec
# optimizer time 0.003967 sec
# round 87, time 0.311998 sec
# the calculation result for the round is:  0.31108593940734863
# round 88
# time to device 0.291986 sec
# sum_time_cost_round_layer 0.005975 sec
# loss time 0.000876 sec
# backward time 0.009966 sec
# optimizer time 0.003674 sec
# round 88, time 0.313241 sec
# the calculation result for the round is:  0.31247758865356445
# round 89
# time to device 0.291955 sec
# sum_time_cost_round_layer 0.006180 sec
# loss time 0.000880 sec
# backward time 0.009478 sec
# optimizer time 0.003563 sec
# round 89, time 0.312880 sec
# the calculation result for the round is:  0.3120558261871338
# round 90
# time to device 0.290323 sec
# sum_time_cost_round_layer 0.006862 sec
# loss time 0.000901 sec
# backward time 0.008807 sec
# optimizer time 0.004147 sec
# round 90, time 0.311968 sec
# the calculation result for the round is:  0.31103992462158203
# round 91
# time to device 0.293146 sec
# sum_time_cost_round_layer 0.008159 sec
# loss time 0.000890 sec
# backward time 0.009262 sec
# optimizer time 0.004733 sec
# round 91, time 0.316946 sec
# the calculation result for the round is:  0.3161895275115967
# round 92
# time to device 0.292864 sec
# sum_time_cost_round_layer 0.007050 sec
# loss time 0.000877 sec
# backward time 0.009229 sec
# optimizer time 0.004137 sec
# round 92, time 0.315002 sec
# the calculation result for the round is:  0.31415700912475586
# round 93
# time to device 0.314403 sec
# sum_time_cost_round_layer 0.005068 sec
# loss time 0.000759 sec
# backward time 0.009333 sec
# optimizer time 0.005680 sec
# round 93, time 0.336173 sec
# the calculation result for the round is:  0.33524298667907715
# round 94
# time to device 0.306057 sec
# sum_time_cost_round_layer 0.007521 sec
# loss time 0.000949 sec
# backward time 0.010126 sec
# optimizer time 0.003665 sec
# round 94, time 0.329440 sec
# the calculation result for the round is:  0.32831764221191406
# round 95
# time to device 0.290407 sec
# sum_time_cost_round_layer 0.006792 sec
# loss time 0.000860 sec
# backward time 0.008960 sec
# optimizer time 0.003915 sec
# round 95, time 0.311724 sec
# the calculation result for the round is:  0.31093430519104004
# round 96
# time to device 0.291953 sec
# sum_time_cost_round_layer 0.006811 sec
# loss time 0.000946 sec
# backward time 0.009485 sec
# optimizer time 0.003960 sec
# round 96, time 0.313976 sec
# the calculation result for the round is:  0.3131551742553711
# round 97
# time to device 0.295244 sec
# sum_time_cost_round_layer 0.010826 sec
# loss time 0.003083 sec
# backward time 0.009823 sec
# optimizer time 0.001584 sec
# round 97, time 0.321561 sec
# the calculation result for the round is:  0.3205599784851074
# round 98
# time to device 0.289680 sec
# sum_time_cost_round_layer 0.016176 sec
# loss time 0.000958 sec
# backward time 0.012115 sec
# optimizer time 0.003933 sec
# round 98, time 0.323553 sec
# the calculation result for the round is:  0.3228621482849121
# round 99
# time to device 0.281336 sec
# sum_time_cost_round_layer 0.006661 sec
# loss time 0.000963 sec
# backward time 0.026730 sec
# optimizer time 0.002648 sec
# round 99, time 0.319111 sec
# the calculation result for the round is:  0.31833839416503906
# round 100
# time to device 0.275102 sec
# sum_time_cost_round_layer 0.006345 sec
# loss time 0.000930 sec
# backward time 0.009962 sec
# optimizer time 0.003731 sec
# round 100, time 0.296572 sec
# the calculation result for the round is:  0.2960700988769531
# round 101
# time to device 0.293639 sec
# sum_time_cost_round_layer 0.008909 sec
# loss time 0.001110 sec
# backward time 0.011234 sec
# optimizer time 0.003904 sec
# round 101, time 0.319636 sec
# the calculation result for the round is:  0.31879639625549316
# round 102
# time to device 0.298150 sec
# sum_time_cost_round_layer 0.009719 sec
# loss time 0.001188 sec
# backward time 0.012496 sec
# optimizer time 0.002502 sec
# round 102, time 0.324613 sec
# the calculation result for the round is:  0.32405567169189453
# round 103
# time to device 0.295241 sec
# sum_time_cost_round_layer 0.007326 sec
# loss time 0.001106 sec
# backward time 0.015911 sec
# optimizer time 0.001375 sec
# round 103, time 0.321835 sec
# the calculation result for the round is:  0.32095932960510254
# round 104
# time to device 0.292602 sec
# sum_time_cost_round_layer 0.006780 sec
# loss time 0.001680 sec
# backward time 0.013101 sec
# optimizer time 0.002241 sec
# round 104, time 0.317324 sec
# the calculation result for the round is:  0.3164036273956299
# round 105
# time to device 0.289124 sec
# sum_time_cost_round_layer 0.006936 sec
# loss time 0.001129 sec
# backward time 0.011090 sec
# optimizer time 0.003680 sec
# round 105, time 0.312474 sec
# the calculation result for the round is:  0.31195926666259766
# round 106
# time to device 0.293863 sec
# sum_time_cost_round_layer 0.006422 sec
# loss time 0.001712 sec
# backward time 0.010407 sec
# optimizer time 0.003867 sec
# round 106, time 0.317395 sec
# the calculation result for the round is:  0.3162710666656494
# round 107
# time to device 0.289423 sec
# sum_time_cost_round_layer 0.006401 sec
# loss time 0.000965 sec
# backward time 0.012605 sec
# optimizer time 0.003520 sec
# round 107, time 0.313745 sec
# the calculation result for the round is:  0.3129143714904785
# round 108
# time to device 0.325706 sec
# sum_time_cost_round_layer 0.006103 sec
# loss time 0.000980 sec
# backward time 0.014940 sec
# optimizer time 0.004346 sec
# round 108, time 0.352553 sec
# the calculation result for the round is:  0.35207486152648926
# round 109
# time to device 0.310540 sec
# sum_time_cost_round_layer 0.012963 sec
# loss time 0.001683 sec
# backward time 0.021926 sec
# optimizer time 0.008332 sec
# round 109, time 0.356777 sec
# the calculation result for the round is:  0.35544371604919434
# round 110
# time to device 0.283580 sec
# sum_time_cost_round_layer 0.002452 sec
# loss time 0.000378 sec
# backward time 0.003136 sec
# optimizer time 0.001396 sec
# round 110, time 0.291231 sec
# the calculation result for the round is:  0.2909419536590576
# round 111
# time to device 0.319174 sec
# sum_time_cost_round_layer 0.006415 sec
# loss time 0.001266 sec
# backward time 0.014453 sec
# optimizer time 0.008485 sec
# round 111, time 0.350383 sec
# the calculation result for the round is:  0.3497927188873291
# round 112
# time to device 0.310911 sec
# sum_time_cost_round_layer 0.002510 sec
# loss time 0.000358 sec
# backward time 0.004080 sec
# optimizer time 0.001814 sec
# round 112, time 0.320064 sec
# the calculation result for the round is:  0.3196723461151123
# round 113
# time to device 0.315614 sec
# sum_time_cost_round_layer 0.002516 sec
# loss time 0.000369 sec
# backward time 0.003408 sec
# optimizer time 0.001398 sec
# round 113, time 0.323798 sec
# the calculation result for the round is:  0.3233051300048828
# round 114
# time to device 0.321673 sec
# sum_time_cost_round_layer 0.004231 sec
# loss time 0.000636 sec
# backward time 0.003984 sec
# optimizer time 0.002137 sec
# round 114, time 0.333168 sec
# the calculation result for the round is:  0.33266139030456543
# round 115
# time to device 0.322818 sec
# sum_time_cost_round_layer 0.002688 sec
# loss time 0.000573 sec
# backward time 0.003560 sec
# optimizer time 0.001652 sec
# round 115, time 0.331755 sec
# the calculation result for the round is:  0.33129143714904785
# round 116
# time to device 0.354777 sec
# sum_time_cost_round_layer 0.003323 sec
# loss time 0.000432 sec
# backward time 0.003370 sec
# optimizer time 0.001560 sec
# round 116, time 0.363863 sec
# the calculation result for the round is:  0.3634622097015381
# round 117
# time to device 0.361666 sec
# sum_time_cost_round_layer 0.002481 sec
# loss time 0.000372 sec
# backward time 0.003472 sec
# optimizer time 0.001754 sec
# round 117, time 0.370195 sec
# the calculation result for the round is:  0.36974525451660156
# round 118
# time to device 0.371753 sec
# sum_time_cost_round_layer 0.003858 sec
# loss time 0.000451 sec
# backward time 0.003640 sec
# optimizer time 0.001820 sec
# round 118, time 0.383706 sec
# the calculation result for the round is:  0.38152194023132324
# round 119
# time to device 0.342147 sec
# sum_time_cost_round_layer 0.002496 sec
# loss time 0.000368 sec
# backward time 0.003178 sec
# optimizer time 0.002254 sec
# round 119, time 0.350725 sec
# the calculation result for the round is:  0.35044360160827637
# round 120
# time to device 0.338476 sec
# sum_time_cost_round_layer 0.002404 sec
# loss time 0.000378 sec
# backward time 0.003198 sec
# optimizer time 0.001361 sec
# round 120, time 0.346044 sec
# the calculation result for the round is:  0.34581756591796875
# round 121
# time to device 0.326093 sec
# sum_time_cost_round_layer 0.004033 sec
# loss time 0.000435 sec
# backward time 0.003981 sec
# optimizer time 0.001975 sec
# round 121, time 0.337036 sec
# the calculation result for the round is:  0.3365168571472168
# round 122
# time to device 0.340003 sec
# sum_time_cost_round_layer 0.002363 sec
# loss time 0.000343 sec
# backward time 0.003118 sec
# optimizer time 0.001534 sec
# round 122, time 0.347678 sec
# the calculation result for the round is:  0.34736108779907227
# round 123
# time to device 0.324061 sec
# sum_time_cost_round_layer 0.002537 sec
# loss time 0.000358 sec
# backward time 0.003581 sec
# optimizer time 0.001935 sec
# round 123, time 0.332743 sec
# the calculation result for the round is:  0.3324720859527588
# round 124
# time to device 0.328790 sec
# sum_time_cost_round_layer 0.002604 sec
# loss time 0.000368 sec
# backward time 0.003006 sec
# optimizer time 0.001343 sec
# round 124, time 0.336547 sec
# the calculation result for the round is:  0.33611130714416504
# round 125
# time to device 0.310227 sec
# sum_time_cost_round_layer 0.002988 sec
# loss time 0.000447 sec
# backward time 0.003649 sec
# optimizer time 0.001882 sec
# round 125, time 0.319758 sec
# the calculation result for the round is:  0.31919288635253906
# round 126
# time to device 0.337748 sec
# sum_time_cost_round_layer 0.002661 sec
# loss time 0.000418 sec
# backward time 0.003323 sec
# optimizer time 0.001349 sec
# round 126, time 0.345748 sec
# the calculation result for the round is:  0.34549832344055176
# round 127
# time to device 0.304896 sec
# sum_time_cost_round_layer 0.002469 sec
# loss time 0.000363 sec
# backward time 0.003262 sec
# optimizer time 0.001452 sec
# round 127, time 0.312689 sec
# the calculation result for the round is:  0.3124423027038574
# round 128
# time to device 0.327393 sec
# sum_time_cost_round_layer 0.002733 sec
# loss time 0.000910 sec
# backward time 0.004565 sec
# optimizer time 0.001566 sec
# round 128, time 0.337651 sec
# the calculation result for the round is:  0.33716726303100586
# round 129
# time to device 0.336510 sec
# sum_time_cost_round_layer 0.002456 sec
# loss time 0.000383 sec
# backward time 0.003947 sec
# optimizer time 0.001698 sec
# round 129, time 0.345491 sec
# the calculation result for the round is:  0.34499311447143555
# round 130
# time to device 0.304861 sec
# sum_time_cost_round_layer 0.002388 sec
# loss time 0.000349 sec
# backward time 0.002992 sec
# optimizer time 0.001440 sec
# round 130, time 0.312308 sec
# the calculation result for the round is:  0.3120293617248535
# round 131
# time to device 0.332416 sec
# sum_time_cost_round_layer 0.002728 sec
# loss time 0.000349 sec
# backward time 0.003363 sec
# optimizer time 0.001370 sec
# round 131, time 0.340495 sec
# the calculation result for the round is:  0.3402261734008789
# round 132
# time to device 0.307358 sec
# sum_time_cost_round_layer 0.007061 sec
# loss time 0.000559 sec
# backward time 0.003361 sec
# optimizer time 0.001800 sec
# round 132, time 0.320624 sec
# the calculation result for the round is:  0.32013821601867676
# round 133
# time to device 0.299519 sec
# sum_time_cost_round_layer 0.002387 sec
# loss time 0.000380 sec
# backward time 0.003504 sec
# optimizer time 0.001494 sec
# round 133, time 0.307665 sec
# the calculation result for the round is:  0.307283878326416
# round 134
# time to device 0.305155 sec
# sum_time_cost_round_layer 0.005671 sec
# loss time 0.000391 sec
# backward time 0.003238 sec
# optimizer time 0.001608 sec
# round 134, time 0.316723 sec
# the calculation result for the round is:  0.31606245040893555
# round 135
# time to device 0.301557 sec
# sum_time_cost_round_layer 0.007713 sec
# loss time 0.000377 sec
# backward time 0.003432 sec
# optimizer time 0.001649 sec
# round 135, time 0.315418 sec
# the calculation result for the round is:  0.3147280216217041
# round 136
# time to device 0.299758 sec
# sum_time_cost_round_layer 0.006241 sec
# loss time 0.000913 sec
# backward time 0.003442 sec
# optimizer time 0.001873 sec
# round 136, time 0.312694 sec
# the calculation result for the round is:  0.3122267723083496
# round 137
# time to device 0.302201 sec
# sum_time_cost_round_layer 0.004492 sec
# loss time 0.000352 sec
# backward time 0.003022 sec
# optimizer time 0.001373 sec
# round 137, time 0.312172 sec
# the calculation result for the round is:  0.31143975257873535
# round 138
# time to device 0.330598 sec
# sum_time_cost_round_layer 0.007005 sec
# loss time 0.000435 sec
# backward time 0.003975 sec
# optimizer time 0.002015 sec
# round 138, time 0.344779 sec
# the calculation result for the round is:  0.3440279960632324
# round 139
# time to device 0.315062 sec
# sum_time_cost_round_layer 0.003285 sec
# loss time 0.000587 sec
# backward time 0.010059 sec
# optimizer time 0.002104 sec
# round 139, time 0.331758 sec
# the calculation result for the round is:  0.3310976028442383
# round 140
# time to device 0.312533 sec
# sum_time_cost_round_layer 0.006009 sec
# loss time 0.001041 sec
# backward time 0.010703 sec
# optimizer time 0.003726 sec
# round 140, time 0.334853 sec
# the calculation result for the round is:  0.3340113162994385
# round 141
# time to device 0.293858 sec
# sum_time_cost_round_layer 0.006126 sec
# loss time 0.000926 sec
# backward time 0.009984 sec
# optimizer time 0.003648 sec
# round 141, time 0.315083 sec
# the calculation result for the round is:  0.314542293548584
# round 142
# time to device 0.299317 sec
# sum_time_cost_round_layer 0.008407 sec
# loss time 0.000922 sec
# backward time 0.010641 sec
# optimizer time 0.001390 sec
# round 142, time 0.321449 sec
# the calculation result for the round is:  0.3206768035888672
# round 143
# time to device 0.293981 sec
# sum_time_cost_round_layer 0.006549 sec
# loss time 0.000939 sec
# backward time 0.008941 sec
# optimizer time 0.003652 sec
# round 143, time 0.314827 sec
# the calculation result for the round is:  0.31406235694885254
# round 144
# time to device 0.291910 sec
# sum_time_cost_round_layer 0.019815 sec
# loss time 0.000373 sec
# backward time 0.004163 sec
# optimizer time 0.001694 sec
# round 144, time 0.318841 sec
# the calculation result for the round is:  0.31795573234558105
# round 145
# time to device 0.292891 sec
# sum_time_cost_round_layer 0.008949 sec
# loss time 0.001162 sec
# backward time 0.009325 sec
# optimizer time 0.004082 sec
# round 145, time 0.317008 sec
# the calculation result for the round is:  0.3164088726043701
# round 146
# time to device 0.288018 sec
# sum_time_cost_round_layer 0.008234 sec
# loss time 0.000986 sec
# backward time 0.011366 sec
# optimizer time 0.002556 sec
# round 146, time 0.312050 sec
# the calculation result for the round is:  0.3111608028411865
# round 147
# time to device 0.290745 sec
# sum_time_cost_round_layer 0.006361 sec
# loss time 0.002166 sec
# backward time 0.011367 sec
# optimizer time 0.002802 sec
# round 147, time 0.314259 sec
# the calculation result for the round is:  0.31344056129455566
# round 148
# time to device 0.303297 sec
# sum_time_cost_round_layer 0.013010 sec
# loss time 0.001007 sec
# backward time 0.008199 sec
# optimizer time 0.002561 sec
# round 148, time 0.328928 sec
# the calculation result for the round is:  0.32807445526123047
# round 149
# time to device 0.310592 sec
# sum_time_cost_round_layer 0.008562 sec
# loss time 0.000985 sec
# backward time 0.013282 sec
# optimizer time 0.002078 sec
# round 149, time 0.336362 sec
# the calculation result for the round is:  0.3354988098144531
# round 150
# time to device 0.295002 sec
# sum_time_cost_round_layer 0.006199 sec
# loss time 0.001233 sec
# backward time 0.009244 sec
# optimizer time 0.003643 sec
# round 150, time 0.315840 sec
# the calculation result for the round is:  0.3153209686279297
# round 151
# time to device 0.292889 sec
# sum_time_cost_round_layer 0.007746 sec
# loss time 0.001371 sec
# backward time 0.012126 sec
# optimizer time 0.002720 sec
# round 151, time 0.317471 sec
# the calculation result for the round is:  0.316852331161499
# round 152
# time to device 0.289779 sec
# sum_time_cost_round_layer 0.006800 sec
# loss time 0.000863 sec
# backward time 0.011865 sec
# optimizer time 0.003979 sec
# round 152, time 0.314049 sec
# the calculation result for the round is:  0.31328630447387695
# round 153
# time to device 0.291139 sec
# sum_time_cost_round_layer 0.007027 sec
# loss time 0.000942 sec
# backward time 0.012777 sec
# optimizer time 0.003713 sec
# round 153, time 0.316393 sec
# the calculation result for the round is:  0.3155977725982666
# round 154
# time to device 0.289922 sec
# sum_time_cost_round_layer 0.009397 sec
# loss time 0.001056 sec
# backward time 0.011350 sec
# optimizer time 0.001419 sec
# round 154, time 0.313836 sec
# the calculation result for the round is:  0.3131437301635742
# round 155
# time to device 0.292542 sec
# sum_time_cost_round_layer 0.009925 sec
# loss time 0.002703 sec
# backward time 0.010946 sec
# optimizer time 0.001486 sec
# round 155, time 0.318723 sec
# the calculation result for the round is:  0.31760263442993164
# round 156
# time to device 0.297555 sec
# sum_time_cost_round_layer 0.007913 sec
# loss time 0.000926 sec
# backward time 0.009157 sec
# optimizer time 0.004497 sec
# round 156, time 0.320863 sec
# the calculation result for the round is:  0.32004761695861816
# round 157
# time to device 0.295887 sec
# sum_time_cost_round_layer 0.009032 sec
# loss time 0.000973 sec
# backward time 0.013133 sec
# optimizer time 0.003866 sec
# round 157, time 0.323526 sec
# the calculation result for the round is:  0.3228907585144043
# round 158
# time to device 0.289568 sec
# sum_time_cost_round_layer 0.009183 sec
# loss time 0.012065 sec
# backward time 0.004480 sec
# optimizer time 0.004308 sec
# round 158, time 0.320348 sec
# the calculation result for the round is:  0.31960415840148926
# round 159
# time to device 0.281598 sec
# sum_time_cost_round_layer 0.008165 sec
# loss time 0.001570 sec
# backward time 0.012053 sec
# optimizer time 0.001386 sec
# round 159, time 0.306449 sec
# the calculation result for the round is:  0.30477213859558105
# round 160
# time to device 0.293945 sec
# sum_time_cost_round_layer 0.007140 sec
# loss time 0.002240 sec
# backward time 0.013008 sec
# optimizer time 0.001449 sec
# round 160, time 0.319096 sec
# the calculation result for the round is:  0.3177812099456787
# round 161
# time to device 0.289544 sec
# sum_time_cost_round_layer 0.008152 sec
# loss time 0.000886 sec
# backward time 0.011580 sec
# optimizer time 0.001362 sec
# round 161, time 0.312194 sec
# the calculation result for the round is:  0.3115239143371582
# round 162
# time to device 0.291921 sec
# sum_time_cost_round_layer 0.006979 sec
# loss time 0.000979 sec
# backward time 0.010716 sec
# optimizer time 0.002301 sec
# round 162, time 0.313473 sec
# the calculation result for the round is:  0.3128960132598877
# round 163
# time to device 0.290586 sec
# sum_time_cost_round_layer 0.006892 sec
# loss time 0.001377 sec
# backward time 0.009448 sec
# optimizer time 0.005479 sec
# round 163, time 0.314640 sec
# the calculation result for the round is:  0.3137819766998291
# round 164
# time to device 0.292099 sec
# sum_time_cost_round_layer 0.007021 sec
# loss time 0.000909 sec
# backward time 0.010097 sec
# optimizer time 0.003198 sec
# round 164, time 0.314111 sec
# the calculation result for the round is:  0.3133242130279541
# round 165
# time to device 0.293862 sec
# sum_time_cost_round_layer 0.009220 sec
# loss time 0.001261 sec
# backward time 0.008975 sec
# optimizer time 0.005005 sec
# round 165, time 0.319218 sec
# the calculation result for the round is:  0.31832265853881836
# round 166
# time to device 0.288273 sec
# sum_time_cost_round_layer 0.006211 sec
# loss time 0.000965 sec
# backward time 0.011240 sec
# optimizer time 0.003351 sec
# round 166, time 0.310899 sec
# the calculation result for the round is:  0.3100399971008301
# round 167
# time to device 0.291983 sec
# sum_time_cost_round_layer 0.005973 sec
# loss time 0.000891 sec
# backward time 0.010826 sec
# optimizer time 0.003721 sec
# round 167, time 0.313877 sec
# the calculation result for the round is:  0.31339383125305176
# round 168
# time to device 0.291929 sec
# sum_time_cost_round_layer 0.006498 sec
# loss time 0.000904 sec
# backward time 0.014582 sec
# optimizer time 0.001827 sec
# round 168, time 0.316591 sec
# the calculation result for the round is:  0.31573915481567383
# round 169
# time to device 0.295014 sec
# sum_time_cost_round_layer 0.006381 sec
# loss time 0.001228 sec
# backward time 0.012279 sec
# optimizer time 0.002039 sec
# round 169, time 0.317915 sec
# the calculation result for the round is:  0.3169403076171875
# round 170
# time to device 0.292586 sec
# sum_time_cost_round_layer 0.006807 sec
# loss time 0.000981 sec
# backward time 0.017096 sec
# optimizer time 0.001623 sec
# round 170, time 0.319609 sec
# the calculation result for the round is:  0.3190934658050537
# round 171
# time to device 0.291407 sec
# sum_time_cost_round_layer 0.007922 sec
# loss time 0.001431 sec
# backward time 0.008557 sec
# optimizer time 0.001377 sec
# round 171, time 0.311514 sec
# the calculation result for the round is:  0.31069421768188477
# round 172
# time to device 0.295165 sec
# sum_time_cost_round_layer 0.006399 sec
# loss time 0.002391 sec
# backward time 0.009781 sec
# optimizer time 0.002746 sec
# round 172, time 0.317434 sec
# the calculation result for the round is:  0.3164815902709961
# round 173
# time to device 0.290230 sec
# sum_time_cost_round_layer 0.008326 sec
# loss time 0.001072 sec
# backward time 0.013774 sec
# optimizer time 0.001585 sec
# round 173, time 0.315579 sec
# the calculation result for the round is:  0.3149871826171875
# round 174
# time to device 0.287142 sec
# sum_time_cost_round_layer 0.006398 sec
# loss time 0.000908 sec
# backward time 0.010839 sec
# optimizer time 0.004101 sec
# round 174, time 0.309996 sec
# the calculation result for the round is:  0.3093886375427246
# round 175
# time to device 0.294874 sec
# sum_time_cost_round_layer 0.006335 sec
# loss time 0.000844 sec
# backward time 0.012421 sec
# optimizer time 0.003670 sec
# round 175, time 0.318932 sec
# the calculation result for the round is:  0.3181450366973877
# round 176
# time to device 0.292103 sec
# sum_time_cost_round_layer 0.005958 sec
# loss time 0.000866 sec
# backward time 0.010075 sec
# optimizer time 0.003742 sec
# round 176, time 0.313500 sec
# the calculation result for the round is:  0.3127434253692627
# round 177
# time to device 0.290973 sec
# sum_time_cost_round_layer 0.009043 sec
# loss time 0.000892 sec
# backward time 0.012326 sec
# optimizer time 0.001385 sec
# round 177, time 0.317299 sec
# the calculation result for the round is:  0.3146195411682129
# round 178
# time to device 0.293423 sec
# sum_time_cost_round_layer 0.006487 sec
# loss time 0.000889 sec
# backward time 0.013263 sec
# optimizer time 0.002991 sec
# round 178, time 0.317656 sec
# the calculation result for the round is:  0.31705331802368164
# round 179
# time to device 0.291226 sec
# sum_time_cost_round_layer 0.005979 sec
# loss time 0.000895 sec
# backward time 0.010260 sec
# optimizer time 0.003634 sec
# round 179, time 0.312727 sec
# the calculation result for the round is:  0.3119931221008301
# round 180
# time to device 0.290645 sec
# sum_time_cost_round_layer 0.006203 sec
# loss time 0.000880 sec
# backward time 0.009544 sec
# optimizer time 0.003948 sec
# round 180, time 0.311817 sec
# the calculation result for the round is:  0.3112199306488037
# round 181
# time to device 0.291669 sec
# sum_time_cost_round_layer 0.006476 sec
# loss time 0.000867 sec
# backward time 0.009651 sec
# optimizer time 0.004108 sec
# round 181, time 0.313548 sec
# the calculation result for the round is:  0.3127708435058594
# round 182
# time to device 0.289161 sec
# sum_time_cost_round_layer 0.006114 sec
# loss time 0.001331 sec
# backward time 0.009342 sec
# optimizer time 0.003615 sec
# round 182, time 0.310462 sec
# the calculation result for the round is:  0.30956339836120605
# round 183
# time to device 0.290597 sec
# sum_time_cost_round_layer 0.006181 sec
# loss time 0.000879 sec
# backward time 0.010077 sec
# optimizer time 0.002802 sec
# round 183, time 0.311308 sec
# the calculation result for the round is:  0.31053638458251953
# round 184
# time to device 0.292184 sec
# sum_time_cost_round_layer 0.006094 sec
# loss time 0.001001 sec
# backward time 0.009818 sec
# optimizer time 0.003595 sec
# round 184, time 0.313282 sec
# the calculation result for the round is:  0.31269240379333496
# round 185
# time to device 0.289748 sec
# sum_time_cost_round_layer 0.006698 sec
# loss time 0.000902 sec
# backward time 0.009268 sec
# optimizer time 0.004779 sec
# round 185, time 0.312261 sec
# the calculation result for the round is:  0.31139492988586426
# round 186
# time to device 0.302329 sec
# sum_time_cost_round_layer 0.006681 sec
# loss time 0.001159 sec
# backward time 0.012244 sec
# optimizer time 0.001946 sec
# round 186, time 0.325458 sec
# the calculation result for the round is:  0.324359655380249
# round 187
# time to device 0.293771 sec
# sum_time_cost_round_layer 0.008798 sec
# loss time 0.001326 sec
# backward time 0.012509 sec
# optimizer time 0.001391 sec
# round 187, time 0.318830 sec
# the calculation result for the round is:  0.3177952766418457
# round 188
# time to device 0.291521 sec
# sum_time_cost_round_layer 0.006625 sec
# loss time 0.001001 sec
# backward time 0.009530 sec
# optimizer time 0.003903 sec
# round 188, time 0.313369 sec
# the calculation result for the round is:  0.3125803470611572
# round 189
# time to device 0.293733 sec
# sum_time_cost_round_layer 0.006134 sec
# loss time 0.001066 sec
# backward time 0.011285 sec
# optimizer time 0.003616 sec
# round 189, time 0.316671 sec
# the calculation result for the round is:  0.31583404541015625
# round 190
# time to device 0.290587 sec
# sum_time_cost_round_layer 0.006341 sec
# loss time 0.000929 sec
# backward time 0.009617 sec
# optimizer time 0.003614 sec
# round 190, time 0.311890 sec
# the calculation result for the round is:  0.31108760833740234
# round 191
# time to device 0.291134 sec
# sum_time_cost_round_layer 0.005889 sec
# loss time 0.000865 sec
# backward time 0.009633 sec
# optimizer time 0.003549 sec
# round 191, time 0.311825 sec
# the calculation result for the round is:  0.31106996536254883
# round 192
# time to device 0.290573 sec
# sum_time_cost_round_layer 0.007653 sec
# loss time 0.000931 sec
# backward time 0.009365 sec
# optimizer time 0.004725 sec
# round 192, time 0.314142 sec
# the calculation result for the round is:  0.3132472038269043
# round 193
# time to device 0.295439 sec
# sum_time_cost_round_layer 0.002847 sec
# loss time 0.000434 sec
# backward time 0.003477 sec
# optimizer time 0.001451 sec
# round 193, time 0.304154 sec
# the calculation result for the round is:  0.3036472797393799
# round 194
# time to device 0.313824 sec
# sum_time_cost_round_layer 0.007471 sec
# loss time 0.001025 sec
# backward time 0.013408 sec
# optimizer time 0.003925 sec
# round 194, time 0.340563 sec
# the calculation result for the round is:  0.33965277671813965
# round 195
# time to device 0.299816 sec
# sum_time_cost_round_layer 0.006466 sec
# loss time 0.000916 sec
# backward time 0.009809 sec
# optimizer time 0.003625 sec
# round 195, time 0.321522 sec
# the calculation result for the round is:  0.3206315040588379
# round 196
# time to device 0.290833 sec
# sum_time_cost_round_layer 0.008008 sec
# loss time 0.001192 sec
# ...
# loss time 0.000588 sec
# backward time 0.004834 sec
# optimizer time 0.001879 sec
# round 438, time 0.326080 sec
# the calculation result for the round is:  0.32559680938720703
# round 439
# time to device 0.334275 sec
# sum_time_cost_round_layer 0.007747 sec
# loss time 0.000703 sec
# backward time 0.006473 sec
# optimizer time 0.002221 sec
# round 439, time 0.352238 sec
# the calculation result for the round is:  0.35141897201538086
# round 440
# time to device 0.350651 sec
# sum_time_cost_round_layer 0.007302 sec
# loss time 0.000910 sec
# backward time 0.003358 sec
# optimizer time 0.001670 sec
# round 440, time 0.364654 sec
# the calculation result for the round is:  0.3638908863067627
# round 441
# time to device 0.320977 sec
# sum_time_cost_round_layer 0.006790 sec
# loss time 0.000883 sec
# backward time 0.003564 sec
# optimizer time 0.001701 sec
# round 441, time 0.334690 sec
# the calculation result for the round is:  0.33391499519348145
# round 442
# time to device 0.323264 sec
# sum_time_cost_round_layer 0.006122 sec
# loss time 0.000893 sec
# backward time 0.004106 sec
# optimizer time 0.002137 sec
# round 442, time 0.337261 sec
# the calculation result for the round is:  0.33652186393737793
# round 443
# time to device 0.318911 sec
# sum_time_cost_round_layer 0.007462 sec
# loss time 0.000776 sec
# backward time 0.003599 sec
# optimizer time 0.001675 sec
# round 443, time 0.332981 sec
# the calculation result for the round is:  0.33242249488830566
# round 444
# time to device 0.368620 sec
# sum_time_cost_round_layer 0.009043 sec
# loss time 0.000883 sec
# backward time 0.010621 sec
# optimizer time 0.003218 sec
# round 444, time 0.393010 sec
# the calculation result for the round is:  0.39238429069519043
# round 445
# time to device 0.331918 sec
# sum_time_cost_round_layer 0.006742 sec
# loss time 0.001026 sec
# backward time 0.010352 sec
# optimizer time 0.004037 sec
# round 445, time 0.354986 sec
# the calculation result for the round is:  0.35407519340515137
# round 446
# time to device 0.291223 sec
# sum_time_cost_round_layer 0.006552 sec
# loss time 0.001126 sec
# backward time 0.009932 sec
# optimizer time 0.003948 sec
# round 446, time 0.313706 sec
# the calculation result for the round is:  0.31278133392333984
# round 447
# time to device 0.301063 sec
# sum_time_cost_round_layer 0.008031 sec
# loss time 0.000954 sec
# backward time 0.010254 sec
# optimizer time 0.003078 sec
# round 447, time 0.323968 sec
# the calculation result for the round is:  0.3233804702758789
# round 448
# time to device 0.294546 sec
# sum_time_cost_round_layer 0.006257 sec
# loss time 0.000881 sec
# backward time 0.011025 sec
# optimizer time 0.003788 sec
# round 448, time 0.317066 sec
# the calculation result for the round is:  0.3164973258972168
# round 449
# time to device 0.311534 sec
# sum_time_cost_round_layer 0.006206 sec
# loss time 0.000951 sec
# backward time 0.014449 sec
# optimizer time 0.003985 sec
# round 449, time 0.337668 sec
# the calculation result for the round is:  0.3371248245239258
# round 450
# time to device 0.330679 sec
# sum_time_cost_round_layer 0.007404 sec
# loss time 0.001647 sec
# backward time 0.010680 sec
# optimizer time 0.003543 sec
# round 450, time 0.355385 sec
# the calculation result for the round is:  0.35395312309265137
# round 451
# time to device 0.313133 sec
# sum_time_cost_round_layer 0.006791 sec
# loss time 0.000950 sec
# backward time 0.010687 sec
# optimizer time 0.003971 sec
# round 451, time 0.336508 sec
# the calculation result for the round is:  0.33553171157836914
# round 452
# time to device 0.289816 sec
# sum_time_cost_round_layer 0.008743 sec
# loss time 0.001250 sec
# backward time 0.012450 sec
# optimizer time 0.003337 sec
# round 452, time 0.316641 sec
# the calculation result for the round is:  0.315596342086792
# round 453
# time to device 0.319564 sec
# sum_time_cost_round_layer 0.006192 sec
# loss time 0.000954 sec
# backward time 0.009108 sec
# optimizer time 0.003764 sec
# round 453, time 0.340425 sec
# the calculation result for the round is:  0.3395822048187256
# round 454
# time to device 0.291559 sec
# sum_time_cost_round_layer 0.007440 sec
# loss time 0.001488 sec
# backward time 0.011454 sec
# optimizer time 0.001344 sec
# round 454, time 0.314507 sec
# the calculation result for the round is:  0.31328535079956055
# round 455
# time to device 0.303083 sec
# sum_time_cost_round_layer 0.003089 sec
# loss time 0.000428 sec
# backward time 0.003184 sec
# optimizer time 0.001382 sec
# round 455, time 0.311481 sec
# the calculation result for the round is:  0.31116604804992676
# round 456
# time to device 0.321693 sec
# sum_time_cost_round_layer 0.007646 sec
# loss time 0.000927 sec
# backward time 0.011119 sec
# optimizer time 0.003224 sec
# round 456, time 0.345524 sec
# the calculation result for the round is:  0.3446085453033447
# round 457
# time to device 0.301145 sec
# sum_time_cost_round_layer 0.006447 sec
# loss time 0.000985 sec
# backward time 0.009708 sec
# optimizer time 0.004025 sec
# round 457, time 0.322841 sec
# the calculation result for the round is:  0.3223104476928711
# round 458
# time to device 0.290501 sec
# sum_time_cost_round_layer 0.006082 sec
# loss time 0.000884 sec
# backward time 0.009655 sec
# optimizer time 0.003704 sec
# round 458, time 0.311618 sec
# the calculation result for the round is:  0.31082582473754883
# round 459
# time to device 0.290935 sec
# sum_time_cost_round_layer 0.006828 sec
# loss time 0.001750 sec
# backward time 0.012430 sec
# optimizer time 0.001796 sec
# round 459, time 0.314643 sec
# the calculation result for the round is:  0.3137388229370117
# round 460
# time to device 0.289639 sec
# sum_time_cost_round_layer 0.007006 sec
# loss time 0.000907 sec
# backward time 0.009851 sec
# optimizer time 0.004521 sec
# round 460, time 0.312744 sec
# the calculation result for the round is:  0.31192469596862793
# round 461
# time to device 0.310180 sec
# sum_time_cost_round_layer 0.008443 sec
# loss time 0.000910 sec
# backward time 0.009908 sec
# optimizer time 0.003267 sec
# round 461, time 0.333508 sec
# the calculation result for the round is:  0.33270788192749023
# round 462
# time to device 0.297998 sec
# sum_time_cost_round_layer 0.006114 sec
# loss time 0.000984 sec
# backward time 0.010034 sec
# optimizer time 0.003669 sec
# round 462, time 0.319608 sec
# the calculation result for the round is:  0.3187987804412842
# round 463
# time to device 0.311419 sec
# sum_time_cost_round_layer 0.009375 sec
# loss time 0.001690 sec
# backward time 0.015302 sec
# optimizer time 0.003492 sec
# round 463, time 0.342029 sec
# the calculation result for the round is:  0.3412778377532959
# round 464
# time to device 0.307628 sec
# sum_time_cost_round_layer 0.006261 sec
# loss time 0.000869 sec
# backward time 0.008914 sec
# optimizer time 0.003599 sec
# round 464, time 0.328068 sec
# the calculation result for the round is:  0.3272709846496582
# round 465
# time to device 0.306925 sec
# sum_time_cost_round_layer 0.006751 sec
# loss time 0.000896 sec
# backward time 0.010901 sec
# optimizer time 0.003726 sec
# round 465, time 0.329813 sec
# the calculation result for the round is:  0.32919859886169434
# round 466
# time to device 0.314568 sec
# sum_time_cost_round_layer 0.006523 sec
# loss time 0.000867 sec
# backward time 0.008790 sec
# optimizer time 0.003665 sec
# round 466, time 0.335240 sec
# the calculation result for the round is:  0.3344128131866455
# round 467
# time to device 0.290682 sec
# sum_time_cost_round_layer 0.006421 sec
# loss time 0.000942 sec
# backward time 0.011176 sec
# optimizer time 0.003981 sec
# round 467, time 0.314067 sec
# the calculation result for the round is:  0.3132021427154541
# round 468
# time to device 0.296041 sec
# sum_time_cost_round_layer 0.013984 sec
# loss time 0.001020 sec
# backward time 0.008184 sec
# optimizer time 0.001380 sec
# round 468, time 0.321348 sec
# the calculation result for the round is:  0.32060909271240234
# round 469
# time to device 0.288101 sec
# sum_time_cost_round_layer 0.006045 sec
# loss time 0.001004 sec
# backward time 0.008881 sec
# optimizer time 0.003484 sec
# round 469, time 0.308329 sec
# the calculation result for the round is:  0.30751466751098633
# round 470
# time to device 0.291663 sec
# sum_time_cost_round_layer 0.006020 sec
# loss time 0.000864 sec
# backward time 0.010035 sec
# optimizer time 0.003681 sec
# round 470, time 0.313022 sec
# the calculation result for the round is:  0.31226229667663574
# round 471
# time to device 0.290608 sec
# sum_time_cost_round_layer 0.006413 sec
# loss time 0.000870 sec
# backward time 0.010059 sec
# optimizer time 0.004121 sec
# round 471, time 0.312674 sec
# the calculation result for the round is:  0.3120706081390381
# round 472
# time to device 0.310943 sec
# sum_time_cost_round_layer 0.007122 sec
# loss time 0.001069 sec
# backward time 0.010350 sec
# optimizer time 0.003896 sec
# round 472, time 0.334376 sec
# the calculation result for the round is:  0.33337974548339844
# round 473
# time to device 0.309317 sec
# sum_time_cost_round_layer 0.006763 sec
# loss time 0.000872 sec
# backward time 0.009672 sec
# optimizer time 0.003544 sec
# round 473, time 0.331004 sec
# the calculation result for the round is:  0.3301680088043213
# round 474
# time to device 0.290597 sec
# sum_time_cost_round_layer 0.008100 sec
# loss time 0.000929 sec
# backward time 0.009362 sec
# optimizer time 0.003889 sec
# round 474, time 0.313791 sec
# the calculation result for the round is:  0.31287646293640137
# round 475
# time to device 0.294049 sec
# sum_time_cost_round_layer 0.006420 sec
# loss time 0.000904 sec
# backward time 0.009474 sec
# optimizer time 0.004013 sec
# round 475, time 0.315420 sec
# the calculation result for the round is:  0.31486058235168457
# round 476
# time to device 0.300580 sec
# sum_time_cost_round_layer 0.007609 sec
# loss time 0.001742 sec
# backward time 0.013154 sec
# optimizer time 0.003521 sec
# round 476, time 0.329270 sec
# the calculation result for the round is:  0.32660555839538574
# round 477
# time to device 0.291865 sec
# sum_time_cost_round_layer 0.006748 sec
# loss time 0.000883 sec
# backward time 0.008932 sec
# optimizer time 0.003887 sec
# round 477, time 0.313208 sec
# the calculation result for the round is:  0.3123149871826172
# round 478
# time to device 0.294946 sec
# sum_time_cost_round_layer 0.008036 sec
# loss time 0.000881 sec
# backward time 0.008653 sec
# optimizer time 0.004286 sec
# round 478, time 0.317662 sec
# the calculation result for the round is:  0.3168020248413086
# round 479
# time to device 0.305153 sec
# sum_time_cost_round_layer 0.006112 sec
# loss time 0.000967 sec
# backward time 0.010109 sec
# optimizer time 0.003644 sec
# round 479, time 0.326525 sec
# the calculation result for the round is:  0.3259847164154053
# round 480
# time to device 0.304750 sec
# sum_time_cost_round_layer 0.007605 sec
# loss time 0.000954 sec
# backward time 0.012137 sec
# optimizer time 0.003505 sec
# round 480, time 0.329934 sec
# the calculation result for the round is:  0.3289504051208496
# round 481
# time to device 0.293250 sec
# sum_time_cost_round_layer 0.006025 sec
# loss time 0.000889 sec
# backward time 0.010645 sec
# optimizer time 0.003640 sec
# round 481, time 0.315198 sec
# the calculation result for the round is:  0.31444883346557617
# round 482
# time to device 0.289417 sec
# sum_time_cost_round_layer 0.006203 sec
# loss time 0.000910 sec
# backward time 0.009994 sec
# optimizer time 0.003781 sec
# round 482, time 0.311173 sec
# the calculation result for the round is:  0.3103055953979492
# round 483
# time to device 0.291543 sec
# sum_time_cost_round_layer 0.006731 sec
# loss time 0.001096 sec
# backward time 0.011526 sec
# optimizer time 0.002690 sec
# round 483, time 0.314523 sec
# the calculation result for the round is:  0.3135859966278076
# round 484
# time to device 0.298352 sec
# sum_time_cost_round_layer 0.006102 sec
# loss time 0.000943 sec
# backward time 0.010470 sec
# optimizer time 0.003590 sec
# round 484, time 0.320205 sec
# the calculation result for the round is:  0.3194572925567627
# round 485
# time to device 0.290423 sec
# sum_time_cost_round_layer 0.006402 sec
# loss time 0.001008 sec
# backward time 0.009932 sec
# optimizer time 0.003590 sec
# round 485, time 0.311963 sec
# the calculation result for the round is:  0.3113553524017334
# round 486
# time to device 0.291435 sec
# sum_time_cost_round_layer 0.007015 sec
# loss time 0.001072 sec
# backward time 0.009978 sec
# optimizer time 0.004134 sec
# round 486, time 0.314183 sec
# the calculation result for the round is:  0.31363344192504883
# round 487
# time to device 0.288131 sec
# sum_time_cost_round_layer 0.006493 sec
# loss time 0.001364 sec
# backward time 0.009114 sec
# optimizer time 0.003481 sec
# round 487, time 0.309118 sec
# the calculation result for the round is:  0.30858325958251953
# round 488
# time to device 0.291024 sec
# sum_time_cost_round_layer 0.006444 sec
# loss time 0.000882 sec
# backward time 0.010258 sec
# optimizer time 0.003684 sec
# round 488, time 0.312857 sec
# the calculation result for the round is:  0.31229138374328613
# round 489
# time to device 0.289675 sec
# sum_time_cost_round_layer 0.006365 sec
# loss time 0.000916 sec
# backward time 0.009433 sec
# optimizer time 0.003938 sec
# round 489, time 0.310855 sec
# the calculation result for the round is:  0.31032752990722656
# round 490
# time to device 0.290051 sec
# sum_time_cost_round_layer 0.006660 sec
# loss time 0.000880 sec
# backward time 0.008953 sec
# optimizer time 0.004364 sec
# round 490, time 0.311690 sec
# the calculation result for the round is:  0.31090807914733887
# round 491
# time to device 0.289002 sec
# sum_time_cost_round_layer 0.006104 sec
# loss time 0.000894 sec
# backward time 0.010226 sec
# optimizer time 0.003682 sec
# round 491, time 0.310719 sec
# the calculation result for the round is:  0.3099086284637451
# round 492
# time to device 0.292207 sec
# sum_time_cost_round_layer 0.010450 sec
# loss time 0.004118 sec
# backward time 0.008564 sec
# optimizer time 0.001857 sec
# round 492, time 0.322117 sec
# the calculation result for the round is:  0.3171956539154053
# round 493
# time to device 0.286107 sec
# sum_time_cost_round_layer 0.006545 sec
# loss time 0.001178 sec
# backward time 0.010304 sec
# optimizer time 0.003749 sec
# round 493, time 0.308447 sec
# the calculation result for the round is:  0.30788254737854004
# round 494
# time to device 0.290158 sec
# sum_time_cost_round_layer 0.007318 sec
# loss time 0.001131 sec
# backward time 0.013083 sec
# optimizer time 0.001361 sec
# round 494, time 0.313995 sec
# the calculation result for the round is:  0.3130505084991455
# round 495
# time to device 0.290930 sec
# sum_time_cost_round_layer 0.007651 sec
# loss time 0.000945 sec
# backward time 0.012256 sec
# optimizer time 0.001942 sec
# round 495, time 0.314549 sec
# the calculation result for the round is:  0.3137233257293701
# round 496
# time to device 0.289804 sec
# sum_time_cost_round_layer 0.006324 sec
# loss time 0.000920 sec
# backward time 0.009995 sec
# optimizer time 0.003813 sec
# round 496, time 0.311635 sec
# the calculation result for the round is:  0.3108558654785156
# round 497
# time to device 0.289505 sec
# sum_time_cost_round_layer 0.007240 sec
# loss time 0.000897 sec
# backward time 0.009112 sec
# optimizer time 0.004044 sec
# round 497, time 0.311698 sec
# the calculation result for the round is:  0.31079864501953125
# round 498
# time to device 0.289125 sec
# sum_time_cost_round_layer 0.006483 sec
# loss time 0.001009 sec
# backward time 0.009842 sec
# optimizer time 0.003616 sec
# round 498, time 0.310898 sec
# the calculation result for the round is:  0.3100745677947998
# round 499
# time to device 0.291191 sec
# sum_time_cost_round_layer 0.006078 sec
# loss time 0.000881 sec
# backward time 0.010212 sec
# optimizer time 0.003965 sec
# round 499, time 0.312925 sec
# the calculation result for the round is:  0.31232762336730957
# /Users/dtjgp/miniconda3/envs/d2l/lib/python3.8/site-packages/d2l/torch.py:3507: UserWarning: MPS: no support for int64 reduction ops, casting it to int32 (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/ReduceOps.mm:144.)
#   reduce_sum = lambda x, *args, **kwargs: x.sum(*args, **kwargs)
# epoch 0, time 182.064882 sec
# Conv2d time 1.327891 sec
# ReLU time 0.935971 sec
# MaxPool2d time 0.511844 sec
# Linear time 0.666149 sec
# Dropout time 1.330922 sec
# Flatten time 0.015139 sec
# time to device 148.798239 sec
# [[[1.32789063 0.        ]
#   [0.93597102 0.        ]
#   [0.51184368 0.        ]
#   [0.66614938 0.        ]
#   [1.33092213 0.        ]
#   [0.01513886 0.        ]]]
# loss time 0.678633 sec
# backward time 6.255894 sec
# optimizer time 1.951277 sec
# time test acc 16.795516 sec

# %%
time_energy_data_sum = np.sum(time_energy_data[:,:,0])
print('the sum of time_energy_data is %f sec' % (time_energy_data_sum))

sum_total = time_to_device_cost + time_energy_data_sum + time_cost_loss + time_cost_backward + time_cost_optimizer + time_test_acc_cost
print('the sum of total is %f sec' % (sum_total))
# Out:
# the sum of time_energy_data is 4.787916 sec
# the sum of total is 179.267476 sec

# %%
energy_consumption, power_list_model = txt_data_process(energy_file)
total_training_time = len(power_list_model)
print('the total training time is %d sec' % (total_training_time))
# Out:
# 8173 mW
# 7972 mW
# 9475 mW
# 9458 mW
# 14329 mW
# 14089 mW
# 14338 mW
# 14338 mW
# 14201 mW
# 14671 mW
# 14365 mW
# 14311 mW
# 14262 mW
# 14400 mW
# 14446 mW
# 17000 mW
# 21556 mW
# 21792 mW
# 17381 mW
# 14330 mW
# 14473 mW
# 14672 mW
# 15899 mW
# 16207 mW
# 14968 mW
# 14351 mW
# 14905 mW
# 14694 mW
# 14596 mW
# 15403 mW
# 14331 mW
# 14581 mW
# 15052 mW
# 14718 mW
# 14531 mW
# 14544 mW
# 14285 mW
# 14840 mW
# 16801 mW
# 15398 mW
# 18696 mW
# 16707 mW
# 16243 mW
# 15203 mW
# 15529 mW
# 15200 mW
# 14465 mW
# 15794 mW
# 15545 mW
# 14524 mW
# 15827 mW
# 14611 mW
# 15559 mW
# 16511 mW
# 15112 mW
# 14517 mW
# 14720 mW
# 14656 mW
# 15512 mW
# 14639 mW
# 14728 mW
# 14590 mW
# 15011 mW
# 15149 mW
# 15497 mW
# 15659 mW
# 15468 mW
# 15171 mW
# 15248 mW
# 15294 mW
# 14640 mW
# 14864 mW
# 14684 mW
# 14635 mW
# 15074 mW
# 14376 mW
# 15013 mW
# 14776 mW
# 14722 mW
# 14795 mW
# 14770 mW
# 15173 mW
# 16434 mW
# 15006 mW
# 15006 mW
# 14892 mW
# 15004 mW
# 14747 mW
# 14788 mW
# 15482 mW
# 14755 mW
# 14609 mW
# 15294 mW
# 15081 mW
# 14511 mW
# 14629 mW
# 15100 mW
# 15213 mW
# 14801 mW
# 14637 mW
# 14538 mW
# 14817 mW
# 14911 mW
# 14692 mW
# 14822 mW
# 14729 mW
# 14890 mW
# 14483 mW
# 14412 mW
# 14813 mW
# 14609 mW
# 14447 mW
# 16471 mW
# 15082 mW
# 14765 mW
# 14694 mW
# 15776 mW
# 15822 mW
# 15129 mW
# 14864 mW
# 16312 mW
# 15996 mW
# 15659 mW
# 16032 mW
# 15865 mW
# 15587 mW
# 15865 mW
# 16131 mW
# 15579 mW
# 15021 mW
# 14660 mW
# 14509 mW
# 15037 mW
# 16620 mW
# 16640 mW
# 16601 mW
# 16243 mW
# 16249 mW
# 16191 mW
# 16442 mW
# 15895 mW
# 15761 mW
# 16245 mW
# 15771 mW
# 15487 mW
# 15088 mW
# 16520 mW
# 15489 mW
# 15181 mW
# 15747 mW
# 16393 mW
# 15520 mW
# 14789 mW
# 15015 mW
# 14995 mW
# 15432 mW
# 15060 mW
# 14493 mW
# 14649 mW
# 14890 mW
# 14792 mW
# 15225 mW
# 11737 mW
# 11606 mW
# 15091 mW
# 15249 mW
# 15315 mW
# 16653 mW
# 14634 mW
# 14992 mW
# 15144 mW
# 15687 mW
# 15407 mW
# 16700 mW
# 16285 mW
# 16518 mW
# 16113 mW
# 13639 mW
# [8173, 7972, 9475, 9458, 14329, 14089, 14338, 14338, 14201, 14671, 14365, 14311, 14262, 14400, 14446, 17000, 21556, 21792, 17381, 14330, 14473, 14672, 15899, 16207, 14968, 14351, 14905, 14694, 14596, 15403, 14331, 14581, 15052, 14718, 14531, 14544, 14285, 14840, 16801, 15398, 18696, 16707, 16243, 15203, 15529, 15200, 14465, 15794, 15545, 14524, 15827, 14611, 15559, 16511, 15112, 14517, 14720, 14656, 15512, 14639, 14728, 14590, 15011, 15149, 15497, 15659, 15468, 15171, 15248, 15294, 14640, 14864, 14684, 14635, 15074, 14376, 15013, 14776, 14722, 14795, 14770, 15173, 16434, 15006, 15006, 14892, 15004, 14747, 14788, 15482, 14755, 14609, 15294, 15081, 14511, 14629, 15100, 15213, 14801, 14637, 14538, 14817, 14911, 14692, 14822, 14729, 14890, 14483, 14412, 14813, 14609, 14447, 16471, 15082, 14765, 14694, 15776, 15822, 15129, 14864, 16312, 15996, 15659, 16032, 15865, 15587, 15865, 16131, 15579, 15021, 14660, 14509, 15037, 16620, 16640, 16601, 16243, 16249, 16191, 16442, 15895, 15761, 16245, 15771, 15487, 15088, 16520, 15489, 15181, 15747, 16393, 15520, 14789, 15015, 14995, 15432, 15060, 14493, 14649, 14890, 14792, 15225, 11737, 11606, 15091, 15249, 15315, 16653, 14634, 14992, 15144, 15687, 15407, 16700, 16285, 16518, 16113, 13639]
# 178
# 2688244
# 0.0007467344444444444
# the total training time is 178 sec

# %%
# power_list_model
energy_consumption_J = energy_consumption * 3600000
energy_consumption_J
# Out:
# 2688.244

# %%
avg_energy_cost_persec = energy_consumption_J / total_training_time
avg_energy_cost_persec
# Out:
# 15.102494382022472

# %%
# change time_energy_data to np array
time_energy_data_np = np.array(time_energy_data)
time_energy_data_np
# Out:
# array([[[1.32789063, 0.        ],
#         [0.93597102, 0.        ],
#         [0.51184368, 0.        ],
#         [0.66614938, 0.        ],
#         [1.33092213, 0.        ],
#         [0.01513886, 0.        ]]])

# %%
import matplotlib.pyplot as plt

# %%
# calculate the energy consumption of each type of layer
for i in range(len(time_energy_data_np[epoch,:,0])):
    time_energy_data_np[epoch, i, 1] = time_energy_data_np[epoch, i, 0] * avg_energy_cost_persec

print(time_energy_data_np)
# Out:
# [[[1.32789063e+00 2.00544608e+01]
#   [9.35971022e-01 1.41354971e+01]
#   [5.11843681e-01 7.73011632e+00]
#   [6.66149378e-01 1.00605172e+01]
#   [1.33092213e+00 2.01002439e+01]
#   [1.51388645e-02 2.28634616e-01]]]

# %%
# calculate the energy consumption of loss and backward and optimizer
loss_energy_consumption = time_cost_loss * avg_energy_cost_persec
backward_energy_consumption = time_cost_backward * avg_energy_cost_persec
optimizer_energy_consumption = time_cost_optimizer * avg_energy_cost_persec
# Out:
# 10.249057888154233
# 94.47960677008683
# 29.469153796688897

# %%
# plot the results
# x axis is the list_layer_name and the 
x = list_layer_name
# print(x)
# y axis
y = time_energy_data_np[epoch,:,1]
# print(y)
# plot the bar chart using different colors
plt.figure(figsize=(20,10))
# plt.bar(x, y, label='energy consumption of each layer')
plt.bar(x, y, label='energy consumption of each layer', color=['b','g','r','c','m','y'])
plt.xlabel('layer name')
plt.ylabel('energy consumption (J)')
plt.legend()
plt.show()

# %%
# calculate the total sumation of the energy consumption
total_energy_consumption_forward = np.sum(time_energy_data_np[epoch,:,1])
print('the total energy consumption of forward is %f J' % (total_energy_consumption_forward))
# Out:
# the total energy consumption of forward is 72.309470 J

# %%
print(loss_energy_consumption)
print(backward_energy_consumption)
print(optimizer_energy_consumption)
print(total_energy_consumption_forward)
# Out:
# 10.249057888154233
# 94.47960677008683
# 29.469153796688897
# 72.309470061045

# %%
# plot the results of forward, loss, backward and optimizer
x = ['forward', 'loss', 'backward', 'optimizer']
y = [total_energy_consumption_forward, loss_energy_consumption, backward_energy_consumption, optimizer_energy_consumption]
plt.figure(figsize=(20,10))
plt.bar(x, y, label='energy consumption of each part', color=['b','g','r','c'])
plt.xlabel('part name')
plt.ylabel('energy consumption (J)')
plt.legend()
plt.show()
