# %% [markdown]
# # 深度卷积神经网络（AlexNet）
# :label:`sec_alexnet`
#
# 在LeNet提出后，卷积神经网络在计算机视觉和机器学习领域中很有名气。但卷积神经网络并没有主导这些领域。这是因为虽然LeNet在小数据集上取得了很好的效果，但是在更大、更真实的数据集上训练卷积神经网络的性能和可行性还有待研究。事实上，在上世纪90年代初到2012年之间的大部分时间里，神经网络往往被其他机器学习方法超越，如支持向量机（support vector machines）。
#
# 在计算机视觉中，直接将神经网络与其他机器学习方法进行比较也许不公平。这是因为，卷积神经网络的输入是由原始像素值或是经过简单预处理（例如居中、缩放）的像素值组成的。但在使用传统机器学习方法时，从业者永远不会将原始像素作为输入。在传统机器学习方法中，计算机视觉流水线是由经过人的手工精心设计的特征流水线组成的。对于这些传统方法，大部分的进展都来自于对特征有了更聪明的想法，并且学习到的算法往往归于事后的解释。
#
# 虽然上世纪90年代就有了一些神经网络加速卡，但仅靠它们还不足以开发出有大量参数的深层多通道多层卷积神经网络。此外，当时的数据集仍然相对较小。除了这些障碍，训练神经网络的一些关键技巧仍然缺失，包括启发式参数初始化、随机梯度下降的变体、非挤压激活函数和有效的正则化技术。
#
# 因此，与训练*端到端*（从像素到分类结果）系统不同，经典机器学习的流水线看起来更像下面这样：
#
# 1. 获取一个有趣的数据集。在早期，收集这些数据集需要昂贵的传感器（在当时最先进的图像也就100万像素）。
# 2. 根据光学、几何学、其他知识以及偶然的发现，手工对特征数据集进行预处理。
# 3. 通过标准的特征提取算法，如SIFT（尺度不变特征变换） :cite:`Lowe.2004`和SURF（加速鲁棒特征） :cite:`Bay.Tuytelaars.Van-Gool.2006`或其他手动调整的流水线来输入数据。
# 4. 将提取的特征送入最喜欢的分类器中（例如线性模型或其它核方法），以训练分类器。
#
# 当人们和机器学习研究人员交谈时，会发现机器学习研究人员相信机器学习既重要又美丽：优雅的理论去证明各种模型的性质。机器学习是一个正在蓬勃发展、严谨且非常有用的领域。然而，当人们和计算机视觉研究人员交谈，会听到一个完全不同的故事。计算机视觉研究人员会告诉一个诡异事实————推动领域进步的是数据特征，而不是学习算法。计算机视觉研究人员相信，从对最终模型精度的影响来说，更大或更干净的数据集、或是稍微改进的特征提取，比任何学习算法带来的进步要大得多。
#
# ## 学习表征
#
# 另一种预测这个领域发展的方法————观察图像特征的提取方法。在2012年前，图像特征都是机械地计算出来的。事实上，设计一套新的特征函数、改进结果，并撰写论文是盛极一时的潮流。SIFT :cite:`Lowe.2004`、SURF :cite:`Bay.Tuytelaars.Van-Gool.2006`、HOG（定向梯度直方图） :cite:`Dalal.Triggs.2005`、[bags of visual words](https://en.wikipedia.org/wiki/Bag-of-words_model_in_computer_vision)和类似的特征提取方法占据了主导地位。
#
# 另一组研究人员，包括Yann LeCun、Geoff Hinton、Yoshua Bengio、Andrew Ng、Shun ichi Amari和Juergen Schmidhuber，想法则与众不同：他们认为特征本身应该被学习。此外，他们还认为，在合理地复杂性前提下，特征应该由多个共同学习的神经网络层组成，每个层都有可学习的参数。在机器视觉中，最底层可能检测边缘、颜色和纹理。事实上，Alex Krizhevsky、Ilya Sutskever和Geoff Hinton提出了一种新的卷积神经网络变体*AlexNet*。在2012年ImageNet挑战赛中取得了轰动一时的成绩。AlexNet以Alex Krizhevsky的名字命名，他是论文 :cite:`Krizhevsky.Sutskever.Hinton.2012`的第一作者。
#
# 有趣的是，在网络的最底层，模型学习到了一些类似于传统滤波器的特征抽取器。 :numref:`fig_filters`是从AlexNet论文 :cite:`Krizhevsky.Sutskever.Hinton.2012`复制的，描述了底层图像特征。
#
# ![AlexNet第一层学习到的特征抽取器。](../img/filters.png)
# :width:`400px`
# :label:`fig_filters`
#
# AlexNet的更高层建立在这些底层表示的基础上，以表示更大的特征，如眼睛、鼻子、草叶等等。而更高的层可以检测整个物体，如人、飞机、狗或飞盘。最终的隐藏神经元可以学习图像的综合表示，从而使属于不同类别的数据易于区分。尽管一直有一群执着的研究者不断钻研，试图学习视觉数据的逐级表征，然而很长一段时间里这些尝试都未有突破。深度卷积神经网络的突破出现在2012年。突破可归因于两个关键因素。
#
# ### 缺少的成分：数据
#
# 包含许多特征的深度模型需要大量的有标签数据，才能显著优于基于凸优化的传统方法（如线性方法和核方法）。
# 然而，限于早期计算机有限的存储和90年代有限的研究预算，大部分研究只基于小的公开数据集。例如，不少研究论文基于加州大学欧文分校（UCI）提供的若干个公开数据集，其中许多数据集只有几百至几千张在非自然环境下以低分辨率拍摄的图像。这一状况在2010年前后兴起的大数据浪潮中得到改善。2009年，ImageNet数据集发布，并发起ImageNet挑战赛：要求研究人员从100万个样本中训练模型，以区分1000个不同类别的对象。ImageNet数据集由斯坦福教授李飞飞小组的研究人员开发，利用谷歌图像搜索（Google Image Search）对每一类图像进行预筛选，并利用亚马逊众包（Amazon Mechanical Turk）来标注每张图片的相关类别。这种规模是前所未有的。这项被称为ImageNet的挑战赛推动了计算机视觉和机器学习研究的发展，挑战研究人员确定哪些模型能够在更大的数据规模下表现最好。
#
# ### 缺少的成分：硬件
#
# 深度学习对计算资源要求很高，训练可能需要数百个迭代轮数，每次迭代都需要通过代价高昂的许多线性代数层传递数据。这也是为什么在20世纪90年代至21世纪初，优化凸目标的简单算法是研究人员的首选。然而，用GPU训练神经网络改变了这一格局。*图形处理器*（Graphics Processing Unit，GPU）早年用来加速图形处理，使电脑游戏玩家受益。GPU可优化高吞吐量的$4 \times 4$矩阵和向量乘法，从而服务于基本的图形任务。幸运的是，这些数学运算与卷积层的计算惊人地相似。由此，英伟达（NVIDIA）和ATI已经开始为通用计算操作优化gpu，甚至把它们作为*通用GPU*（general-purpose GPUs，GPGPU）来销售。
#
# 那么GPU比CPU强在哪里呢？
#
# 首先，我们深度理解一下中央处理器（Central Processing Unit，CPU）的*核心*。
# CPU的每个核心都拥有高时钟频率的运行能力，和高达数MB的三级缓存（L3Cache）。
# 它们非常适合执行各种指令，具有分支预测器、深层流水线和其他使CPU能够运行各种程序的功能。
# 然而，这种明显的优势也是它的致命弱点：通用核心的制造成本非常高。
# 它们需要大量的芯片面积、复杂的支持结构（内存接口、内核之间的缓存逻辑、高速互连等等），而且它们在任何单个任务上的性能都相对较差。
# 现代笔记本电脑最多有4核，即使是高端服务器也很少超过64核，因为它们的性价比不高。
#
# 相比于CPU，GPU由$100 \sim 1000$个小的处理单元组成（NVIDIA、ATI、ARM和其他芯片供应商之间的细节稍有不同），通常被分成更大的组（NVIDIA称之为warps）。
# 虽然每个GPU核心都相对较弱，有时甚至以低于1GHz的时钟频率运行，但庞大的核心数量使GPU比CPU快几个数量级。
# 例如，NVIDIA最近一代的Ampere GPU架构为每个芯片提供了高达312 TFlops的浮点性能，而CPU的浮点性能到目前为止还没有超过1 TFlops。
# 之所以有如此大的差距，原因其实很简单：首先，功耗往往会随时钟频率呈二次方增长。
# 对于一个CPU核心，假设它的运行速度比GPU快4倍，但可以使用16个GPU核代替，那么GPU的综合性能就是CPU的$16 \times 1/4 = 4$倍。
# 其次，GPU内核要简单得多，这使得它们更节能。
# 此外，深度学习中的许多操作需要相对较高的内存带宽，而GPU拥有10倍于CPU的带宽。
#
# 回到2012年的重大突破，当Alex Krizhevsky和Ilya Sutskever实现了可以在GPU硬件上运行的深度卷积神经网络时，一个重大突破出现了。他们意识到卷积神经网络中的计算瓶颈：卷积和矩阵乘法，都是可以在硬件上并行化的操作。
# 于是，他们使用两个显存为3GB的NVIDIA GTX580 GPU实现了快速卷积运算。他们的创新[cuda-convnet](https://code.google.com/archive/p/cuda-convnet/)几年来它一直是行业标准，并推动了深度学习热潮。
#
# ## AlexNet
#
# 2012年，AlexNet横空出世。它首次证明了学习到的特征可以超越手工设计的特征。它一举打破了计算机视觉研究的现状。
# AlexNet使用了8层卷积神经网络，并以很大的优势赢得了2012年ImageNet图像识别挑战赛。
#
# AlexNet和LeNet的架构非常相似，如 :numref:`fig_alexnet`所示。
# 注意，本书在这里提供的是一个稍微精简版本的AlexNet，去除了当年需要两个小型GPU同时运算的设计特点。
#
# ![从LeNet（左）到AlexNet（右）](../img/alexnet.svg)
# :label:`fig_alexnet`
#
# AlexNet和LeNet的设计理念非常相似，但也存在显著差异。
#
# 1. AlexNet比相对较小的LeNet5要深得多。AlexNet由八层组成：五个卷积层、两个全连接隐藏层和一个全连接输出层。
# 2. AlexNet使用ReLU而不是sigmoid作为其激活函数。
#
# 下面的内容将深入研究AlexNet的细节。
#
# ### 模型设计
#
# 在AlexNet的第一层，卷积窗口的形状是$11\times11$。
# 由于ImageNet中大多数图像的宽和高比MNIST图像的多10倍以上，因此，需要一个更大的卷积窗口来捕获目标。
# 第二层中的卷积窗口形状被缩减为$5\times5$，然后是$3\times3$。
# 此外，在第一层、第二层和第五层卷积层之后，加入窗口形状为$3\times3$、步幅为2的最大汇聚层。
# 而且，AlexNet的卷积通道数目是LeNet的10倍。
#
# 在最后一个卷积层后有两个全连接层，分别有4096个输出。
# 这两个巨大的全连接层拥有将近1GB的模型参数。
# 由于早期GPU显存有限，原版的AlexNet采用了双数据流设计，使得每个GPU只负责存储和计算模型的一半参数。
# 幸运的是，现在GPU显存相对充裕，所以现在很少需要跨GPU分解模型（因此，本书的AlexNet模型在这方面与原始论文稍有不同）。
#
# ### 激活函数
#
# 此外，AlexNet将sigmoid激活函数改为更简单的ReLU激活函数。
# 一方面，ReLU激活函数的计算更简单，它不需要如sigmoid激活函数那般复杂的求幂运算。
# 另一方面，当使用不同的参数初始化方法时，ReLU激活函数使训练模型更加容易。
# 当sigmoid激活函数的输出非常接近于0或1时，这些区域的梯度几乎为0，因此反向传播无法继续更新一些模型参数。
# 相反，ReLU激活函数在正区间的梯度总是1。
# 因此，如果模型参数没有正确初始化，sigmoid函数可能在正区间内得到几乎为0的梯度，从而使模型无法得到有效的训练。
#
# ### 容量控制和预处理
#
# AlexNet通过暂退法（ :numref:`sec_dropout`）控制全连接层的模型复杂度，而LeNet只使用了权重衰减。
# 为了进一步扩充数据，AlexNet在训练时增加了大量的图像增强数据，如翻转、裁切和变色。
# 这使得模型更健壮，更大的样本量有效地减少了过拟合。
# 在 :numref:`sec_image_augmentation`中更详细地讨论数据扩增。

# %%
import torch
from torch import nn
from d2l import torch as d2l
import time
import numpy as np
import subprocess
import time

net = nn.Sequential(
    # 这里使用一个11*11的更大窗口来捕捉对象。
    # 同时，步幅为4，以减少输出的高度和宽度。
    # 另外，输出通道的数目远大于LeNet
    nn.Conv2d(1, 96, kernel_size=11, stride=4, padding=1), nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2),
    # 减小卷积窗口，使用填充为2来使得输入与输出的高和宽一致，且增大输出通道数
    nn.Conv2d(96, 256, kernel_size=5, padding=2), nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2),
    # 使用三个连续的卷积层和较小的卷积窗口。
    # 除了最后的卷积层，输出通道的数量进一步增加。
    # 在前两个卷积层之后，汇聚层不用于减少输入的高度和宽度
    nn.Conv2d(256, 384, kernel_size=3, padding=1), nn.ReLU(),
    nn.Conv2d(384, 384, kernel_size=3, padding=1), nn.ReLU(),
    nn.Conv2d(384, 256, kernel_size=3, padding=1), nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2),
    nn.Flatten(),
    # 这里，全连接层的输出数量是LeNet中的好几倍。使用dropout层来减轻过拟合
    nn.Linear(6400, 4096), nn.ReLU(),
    nn.Dropout(p=0.5),
    nn.Linear(4096, 4096), nn.ReLU(),
    nn.Dropout(p=0.5),
    # 最后是输出层。由于这里使用Fashion-MNIST，所以用类别数为10，而非论文中的1000
    nn.Linear(4096, 10))

# %% [markdown]
# [**我们构造一个**]高度和宽度都为224的(**单通道数据，来观察每一层输出的形状**)。
# 它与 :numref:`fig_alexnet`中的AlexNet架构相匹配。

# %%
X = torch.randn(1, 1, 224, 224)
for layer in net:
    X=layer(X)
    print(layer.__class__.__name__,'output shape:\t',X.shape)
# Out:
# Conv2d output shape:	 torch.Size([1, 96, 54, 54])
# ReLU output shape:	 torch.Size([1, 96, 54, 54])
# MaxPool2d output shape:	 torch.Size([1, 96, 26, 26])
# Conv2d output shape:	 torch.Size([1, 256, 26, 26])
# ReLU output shape:	 torch.Size([1, 256, 26, 26])
# MaxPool2d output shape:	 torch.Size([1, 256, 12, 12])
# Conv2d output shape:	 torch.Size([1, 384, 12, 12])
# ReLU output shape:	 torch.Size([1, 384, 12, 12])
# Conv2d output shape:	 torch.Size([1, 384, 12, 12])
# ReLU output shape:	 torch.Size([1, 384, 12, 12])
# Conv2d output shape:	 torch.Size([1, 256, 12, 12])
# ReLU output shape:	 torch.Size([1, 256, 12, 12])
# MaxPool2d output shape:	 torch.Size([1, 256, 5, 5])
# Flatten output shape:	 torch.Size([1, 6400])
# Linear output shape:	 torch.Size([1, 4096])
# ReLU output shape:	 torch.Size([1, 4096])
# Dropout output shape:	 torch.Size([1, 4096])
# Linear output shape:	 torch.Size([1, 4096])
# ReLU output shape:	 torch.Size([1, 4096])
# Dropout output shape:	 torch.Size([1, 4096])
# Linear output shape:	 torch.Size([1, 10])

# %% [markdown]
# ## 读取数据集
#
# 尽管原文中AlexNet是在ImageNet上进行训练的，但本书在这里使用的是Fashion-MNIST数据集。因为即使在现代GPU上，训练ImageNet模型，同时使其收敛可能需要数小时或数天的时间。
# 将AlexNet直接应用于Fashion-MNIST的一个问题是，[**Fashion-MNIST图像的分辨率**]（$28 \times 28$像素）(**低于ImageNet图像。**)
# 为了解决这个问题，(**我们将它们增加到$224 \times 224$**)（通常来讲这不是一个明智的做法，但在这里这样做是为了有效使用AlexNet架构）。
# 这里需要使用`d2l.load_data_fashion_mnist`函数中的`resize`参数执行此调整。

# %%
batch_size = 128
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size, resize=224)
# print the shape of the train_iter
list_of_i = []
for i, (X, y) in enumerate(train_iter):
    list_of_i.append(i)

print('the shape of the train_iter is:', np.array(list_of_i).shape)
# print(list_of_i)
# print the first 10 batch of the train_iter
for i, (X, y) in enumerate(train_iter):
    if i < 10:
        print('the shape of the', i, 'batch of the train_iter is:', X.shape)
    else:
        break
# Out:
# the shape of the train_iter is: (469,)
# the shape of the 0 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 1 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 2 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 3 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 4 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 5 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 6 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 7 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 8 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 9 batch of the train_iter is: torch.Size([128, 1, 224, 224])

# %% [markdown]
# ## [**训练AlexNet**]
#
# 现在AlexNet可以开始被训练了。与 :numref:`sec_lenet`中的LeNet相比，这里的主要变化是使用更小的学习速率训练，这是因为网络更深更广、图像分辨率更高，训练卷积神经网络就更昂贵。

# %%
def run_powermetrics(file_path):
    """
    Run powermetrics and retrieve the output.
    :param interval: Sampling interval in milliseconds.
    :param count: Number of samples to retrieve.s
    :return: The output from powermetrics.
    """
    # Define the command as a list of arguments
    cmd = ["sudo", "powermetrics",  "-i", "1000", "--samplers", "cpu_power,gpu_power", "-a", "1", "-o", file_path]
    process = subprocess.Popen(cmd)
    return process

# %%
def txt_data_process(file_path):
    """
    Read the output file of powermetric and extract the power value
    :param file_path: The path of the output file of powermetric.
    :return: The list of power values.
    """
    list_power = []
    with open(file_path, 'r') as f:
        for line in f:
            if 'Combined Power' in line:
                power_value = line.split(':')[1].strip()
                # print(power_value)
                # Remove the unit
                power_value = power_value.replace('mW', '')
                # Convert to integer
                power_value = int(power_value)
                list_power.append(power_value)
    '''
    The data from list_power is the Conbined Power of each second.
    The data is the Power of each second.
    we need to calculate the energy consumption of the whole process.
    and need to change the J to kWh.
    '''
    # calculate the energy consumption
    energy_consumption = 0
    for i in range(len(list_power)):
       energy_consumption += list_power[i]
    # change the mW to W
    energy_consumption = energy_consumption / 1000
    # calculate the energy consumption, the interval is 1 second, and the energy unit is J
    energy_consumption = energy_consumption * 1
    # change the J to kWh
    energy_consumption = energy_consumption / 3600000
    return energy_consumption, list_power

# %%
energy_file = 'energy_alexnet.txt'

# %%
'''
对train_ch6()函数进行修改，使得能够在每一层的前向传播的时候，记录下时间, 
能耗部分不好进行具体统计，因为每个层的能耗有区别，并且时间过短，所以采用的方式为计算总能耗和总时长，最后通过平均值来计算估算的能耗
'''
def train_ch6self(net, train_iter, test_iter, num_epochs, lr, device, energy_file):
    def init_weights(m): # 初始化权重
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            nn.init.xavier_uniform_(m.weight)
    net.apply(init_weights)
    # set a list of layer name
    list_layer_name = ['Conv2d','ReLU','MaxPool2d','Linear','Dropout','Flatten'] # 该模型中包括的所有的层的名字
    # create a numpy array to store the time and energy consumption, the shape is (num_epochs, len(list_layer_name), 2)
    # for each epoch, the shape is (6,2), contains the total time and the energy consumption of each layer
    timeenergy_data_forward = np.zeros((num_epochs, len(list_layer_name), 2)) 
    # for each epoch, the shape is (6,2), contains the total time of each part in a round, which is to_device, forward, loss, backward, optimizer，test_round
    # and the 2 means time and energy consumption, respectively
    timeenergy_data_round = np.zeros((num_epochs, 6, 2)) 
    # create another numpy array to store the data of each epoch, 1 column is training loss, 2 column is training accuracy, 3 column is test accuracy
    acc_data = []
    # create a numpy array to store the train loss and train accuracy
    train_l = []
    train_acc = []
    # create a numpy array to store the epoch and running time
    time_data_epoch = np.zeros((num_epochs, 2))
    # create a numpy array to store the energy consumption of each epoch
    energy_data_epoch = np.zeros((num_epochs, 1), dtype=object)
    # print the training device
    print('training on', device)
    net.to(device) # 将模型放到对应的设备上
    # 初始化optimizer和loss
    optimizer = torch.optim.SGD(net.parameters(), lr=lr)
    loss_fn = nn.CrossEntropyLoss()
    # 初始化计时器
    timer, num_batches = d2l.Timer(), len(train_iter)   
    # 开始训练
    for epoch in range(num_epochs):
        print('epoch %d' % (epoch + 1))
        # each epoch, set a timer to record the time
        timer.start()
        powermetrics_process = run_powermetrics(energy_file)
        net.train() # 设置为训练模式
        # 初始化每个epoch的统计时间的变量
        time_to_device_cost, time_forward, time_cost_loss = 0,0,0
        time_cost_backward, time_cost_optimizer, time_test_acc_cost = 0,0,0
        train_l_epoch = []
        train_acc_epoch = []
        metric = d2l.Accumulator(3)
        for i, (X, y) in enumerate(train_iter):
            print('round %d' % (i))
            time_round_start = time.time() # 计算每一轮的时间s
            optimizer.zero_grad() # 将optimizer的梯度清零s
        ##################################################################################
            # 计算将数据放到对应的设备上的时间
            time_to_device_cost_i = 0
            time_to_device = time.time()
            X, y = X.to(device), y.to(device)
            time_to_device_end = time.time()
            time_to_device_cost_i = time_to_device_end - time_to_device
            print('time to device %f sec' % (time_to_device_cost_i))
            time_to_device_cost += time_to_device_cost_i
        ##################################################################################
            # 将原本的模型进行修改，使得能够逐层进行运行，并且在这个过程中，记录下时间和能量
            y_hat = X
            for layer in net:
                time_cost_layer = 0
                layer_name = layer.__class__.__name__ # 获取层的名字
                # find out the layer name is in where of the list
                layer_index = list_layer_name.index(layer_name)
                # calculate the time
                time_start_layer = time.time()
                y_hat = layer(y_hat)
                time_end_layer = time.time()
                time_cost_layer = time_end_layer - time_start_layer
                timeenergy_data_forward[epoch,layer_index,0] += time_cost_layer
                if torch.isinf(y_hat).any() or torch.isnan(y_hat).any():
                    print("Inf or NaN detected in y_hat")
            # 计算前向的时间
            time_forward = np.sum(timeenergy_data_forward[epoch,:,0])
            print('time forward %f sec' % (time_forward))
        ##################################################################################
            # 计算loss
            time_cost_loss_i = 0 # 初始化loss的时间
            time_start_loss = time.time()
            loss = loss_fn(y_hat, y)
            # print(loss)
            time_end_loss = time.time()
            time_cost_loss_i = time_end_loss - time_start_loss
            print('loss time %f sec' % (time_cost_loss_i))
            time_cost_loss += time_cost_loss_i
        ##################################################################################
            # 计算backward
            time_cost_backward_i = 0 # 初始化backward的时间
            time_start_backward = time.time()
            loss.backward()
            time_end_backward = time.time()
            time_cost_backward_i = time_end_backward - time_start_backward
            print('backward time %f sec' % (time_cost_backward_i))
            time_cost_backward += time_cost_backward_i
        ##################################################################################
            # 计算optimizer
            time_cost_optimizer_i = 0 # 初始化optimizer的时间
            time_start_optimizer = time.time()
            optimizer.step()
            time_end_optimizer = time.time()
            time_cost_optimizer_i = time_end_optimizer - time_start_optimizer
            print('optimizer time %f sec' % (time_cost_optimizer_i))
            time_cost_optimizer += time_cost_optimizer_i
        ##################################################################################
            time_round_end = time.time()
            time_round_cost = time_round_end - time_round_start
            print(f'training time in round {i} cost {time_round_cost} sec')
        ##################################################################################
            with torch.no_grad():
                metric.add(loss * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            train_l_i = metric[0] / metric[2]
            train_acc_i = metric[1] / metric[2]
            train_l_epoch.append(train_l_i)
            train_acc_epoch.append(train_acc_i)
            print('loss %f, train acc %f' % (train_l_i, train_acc_i))
        train_l.append(train_l_epoch)
        train_acc.append(train_acc_epoch)
        ##################################################################################
        # 进行模型的test部分运行
        time_test_acc_cost_epoch = 0
        time_test_acc_start = time.time()
        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter, device)
        time_test_acc_end = time.time()
        time_test_acc_cost_epoch = time_test_acc_end - time_test_acc_start
        time_test_acc_cost += time_test_acc_cost_epoch
        print('test acc is %f' % (test_acc))
        acc_data.append(test_acc)
        ##################################################################################
        # 将每一轮的每个部分的时间加入到time_data_round中
        timeenergy_data_round[epoch,0,0] = time_to_device_cost
        timeenergy_data_round[epoch,1,0] = time_forward
        timeenergy_data_round[epoch,2,0] = time_cost_loss
        timeenergy_data_round[epoch,3,0] = time_cost_backward
        timeenergy_data_round[epoch,4,0] = time_cost_optimizer
        timeenergy_data_round[epoch,5,0] = time_test_acc_cost
        ##################################################################################
        # stop the powermetrics
        powermetrics_process.terminate()
        powermetrics_process.wait()
        timer.stop() # 停止计时 
        time_data_epoch[epoch,0] = epoch + 1
        time_data_epoch[epoch,1] = timer.sum()
        print('epoch %d, time %f sec' % (epoch, timer.sum()))
        ##################################################################################
        # calculate the energy consumption of each layer
        energy_consumption, power_list_model = txt_data_process(energy_file)
        training_time_epoch_record = len(power_list_model)
        energy_consumption_J = energy_consumption * 3600000
        avg_energy_cost_persec = energy_consumption_J / training_time_epoch_record  # 计算每秒的平均能耗
        ##################################################################################
        # 将每一轮的每个部分的能耗加入到time_data_forward中
        for l in range(len(timeenergy_data_forward[epoch,:,0])):
            timeenergy_data_forward[epoch, l, 1] = timeenergy_data_forward[epoch, l, 0] * avg_energy_cost_persec
        # 将每一轮的每个部分的能耗加入到time_data_round中
        for m in range(len(timeenergy_data_round[epoch,:,0])):
            timeenergy_data_round[epoch, m, 1] = timeenergy_data_round[epoch, m, 0] * avg_energy_cost_persec
        ##################################################################################
        # 对采集到的能耗数据进行保存
        energy_data_epoch[epoch,0] = power_list_model
        
    return timeenergy_data_forward, timeenergy_data_round, acc_data, train_l, train_acc, time_data_epoch, energy_data_epoch

# %%
lr, num_epochs = 0.01, 5
device = 'mps'
timeenergy_data_forward, timeenergy_data_round, acc_data, train_l, train_acc, time_data_epoch, energy_data_epoch = train_ch6self(net, train_iter, test_iter, num_epochs, lr, device, energy_file)
# Out:
# training on mps
# epoch 1
# round 0
# time to device 0.028906 sec
# time forward 0.012344 sec
# loss time 0.003480 sec
# backward time 0.012015 sec
# optimizer time 0.025672 sec
# training time in round 0 cost 0.6497738361358643 sec
# loss 2.296861, train acc 0.093750
# round 1
# time to device 0.006469 sec
# time forward 0.021033 sec
# loss time 0.001253 sec
# backward time 0.010496 sec
# optimizer time 0.005014 sec
# training time in round 1 cost 0.3584587574005127 sec
# loss 2.302377, train acc 0.089844
# round 2
# time to device 0.006367 sec
# time forward 0.030478 sec
# loss time 0.001165 sec
# backward time 0.008455 sec
# optimizer time 0.003313 sec
# training time in round 2 cost 0.34894800186157227 sec
# loss 2.303509, train acc 0.080729
# round 3
# time to device 0.007598 sec
# time forward 0.039437 sec
# loss time 0.001051 sec
# backward time 0.009034 sec
# optimizer time 0.003480 sec
# training time in round 3 cost 0.35110974311828613 sec
# loss 2.304757, train acc 0.076172
# round 4
# time to device 0.007897 sec
# time forward 0.047074 sec
# loss time 0.000899 sec
# backward time 0.008463 sec
# optimizer time 0.003720 sec
# training time in round 4 cost 0.351593017578125 sec
# loss 2.304895, train acc 0.078125
# round 5
# time to device 0.007720 sec
# time forward 0.055071 sec
# loss time 0.000889 sec
# backward time 0.008316 sec
# optimizer time 0.003041 sec
# training time in round 5 cost 0.3446648120880127 sec
# loss 2.305434, train acc 0.078125
# round 6
# time to device 0.007411 sec
# time forward 0.063581 sec
# loss time 0.001035 sec
# backward time 0.011262 sec
# optimizer time 0.003769 sec
# training time in round 6 cost 0.35236501693725586 sec
# loss 2.305103, train acc 0.080357
# round 7
# time to device 0.007258 sec
# time forward 0.072018 sec
# loss time 0.001046 sec
# backward time 0.008341 sec
# optimizer time 0.003421 sec
# training time in round 7 cost 0.34598827362060547 sec
# loss 2.304285, train acc 0.085938
# round 8
# time to device 0.007624 sec
# time forward 0.081889 sec
# loss time 0.001061 sec
# backward time 0.008878 sec
# optimizer time 0.003857 sec
# training time in round 8 cost 0.356813907623291 sec
# loss 2.303726, train acc 0.087674
# round 9
# time to device 0.006497 sec
# time forward 0.091164 sec
# loss time 0.001326 sec
# backward time 0.010462 sec
# optimizer time 0.003853 sec
# training time in round 9 cost 0.3541996479034424 sec
# loss 2.303408, train acc 0.089063
# round 10
# time to device 0.006403 sec
# time forward 0.099859 sec
# loss time 0.001042 sec
# backward time 0.009818 sec
# optimizer time 0.003590 sec
# training time in round 10 cost 0.34903621673583984 sec
# loss 2.303008, train acc 0.092330
# round 11
# time to device 0.002558 sec
# time forward 0.108509 sec
# loss time 0.001051 sec
# backward time 0.009516 sec
# optimizer time 0.003523 sec
# training time in round 11 cost 0.344012975692749 sec
# loss 2.302953, train acc 0.092448
# round 12
# time to device 0.002650 sec
# time forward 0.116435 sec
# loss time 0.000876 sec
# backward time 0.008239 sec
# optimizer time 0.003033 sec
# training time in round 12 cost 0.3417637348175049 sec
# loss 2.302541, train acc 0.092548
# round 13
# time to device 0.002718 sec
# time forward 0.125552 sec
# loss time 0.001091 sec
# backward time 0.009541 sec
# optimizer time 0.003657 sec
# training time in round 13 cost 0.3508331775665283 sec
# loss 2.302416, train acc 0.094308
# round 14
# time to device 0.004132 sec
# time forward 0.133799 sec
# loss time 0.001048 sec
# backward time 0.008440 sec
# optimizer time 0.003478 sec
# training time in round 14 cost 0.3433818817138672 sec
# loss 2.302337, train acc 0.094271
# round 15
# time to device 0.003177 sec
# time forward 0.144068 sec
# loss time 0.001061 sec
# backward time 0.010059 sec
# optimizer time 0.003500 sec
# training time in round 15 cost 0.3514559268951416 sec
# loss 2.302012, train acc 0.095703
# round 16
# time to device 0.002901 sec
# time forward 0.152478 sec
# loss time 0.001038 sec
# backward time 0.009958 sec
# optimizer time 0.003887 sec
# training time in round 16 cost 0.34233903884887695 sec
# loss 2.301760, train acc 0.097886
# round 17
# time to device 0.002595 sec
# time forward 0.161451 sec
# loss time 0.001033 sec
# backward time 0.009816 sec
# optimizer time 0.003451 sec
# training time in round 17 cost 0.3443889617919922 sec
# loss 2.301594, train acc 0.099392
# round 18
# time to device 0.002484 sec
# time forward 0.170878 sec
# loss time 0.001253 sec
# backward time 0.014441 sec
# optimizer time 0.003687 sec
# training time in round 18 cost 0.3541569709777832 sec
# loss 2.301412, train acc 0.102385
# round 19
# time to device 0.003183 sec
# time forward 0.180739 sec
# loss time 0.001035 sec
# backward time 0.008525 sec
# optimizer time 0.003530 sec
# training time in round 19 cost 0.3484349250793457 sec
# loss 2.301513, train acc 0.100781
# round 20
# time to device 0.003865 sec
# time forward 0.190267 sec
# loss time 0.001124 sec
# backward time 0.009275 sec
# optimizer time 0.003669 sec
# training time in round 20 cost 0.35250401496887207 sec
# loss 2.301401, train acc 0.100818
# round 21
# time to device 0.003074 sec
# time forward 0.198060 sec
# loss time 0.000692 sec
# backward time 0.006566 sec
# optimizer time 0.002566 sec
# training time in round 21 cost 0.3342001438140869 sec
# loss 2.301221, train acc 0.100497
# round 22
# time to device 0.003292 sec
# time forward 0.206572 sec
# loss time 0.001044 sec
# backward time 0.009747 sec
# optimizer time 0.003527 sec
# training time in round 22 cost 0.3428642749786377 sec
# loss 2.300868, train acc 0.102242
# round 23
# time to device 0.002612 sec
# time forward 0.215940 sec
# loss time 0.001036 sec
# backward time 0.008678 sec
# optimizer time 0.003391 sec
# training time in round 23 cost 0.34442806243896484 sec
# loss 2.300791, train acc 0.101562
# round 24
# time to device 0.003176 sec
# time forward 0.225765 sec
# loss time 0.001032 sec
# backward time 0.009568 sec
# optimizer time 0.003454 sec
# training time in round 24 cost 0.34943103790283203 sec
# loss 2.300600, train acc 0.103125
# round 25
# time to device 0.002742 sec
# time forward 0.234835 sec
# loss time 0.001248 sec
# backward time 0.009133 sec
# optimizer time 0.003498 sec
# training time in round 25 cost 0.34827637672424316 sec
# loss 2.300494, train acc 0.102764
# round 26
# time to device 0.003254 sec
# time forward 0.243839 sec
# loss time 0.001060 sec
# backward time 0.009742 sec
# optimizer time 0.003544 sec
# training time in round 26 cost 0.3482401371002197 sec
# loss 2.300579, train acc 0.103588
# round 27
# time to device 0.003099 sec
# time forward 0.250884 sec
# loss time 0.001436 sec
# backward time 0.005364 sec
# optimizer time 0.004278 sec
# training time in round 27 cost 0.33866214752197266 sec
# loss 2.300422, train acc 0.105190
# round 28
# time to device 0.002907 sec
# time forward 0.259651 sec
# loss time 0.000459 sec
# backward time 0.004289 sec
# optimizer time 0.001841 sec
# training time in round 28 cost 0.33173680305480957 sec
# loss 2.300082, train acc 0.106950
# round 29
# time to device 0.003940 sec
# time forward 0.268613 sec
# loss time 0.001064 sec
# backward time 0.009172 sec
# optimizer time 0.003466 sec
# training time in round 29 cost 0.347275972366333 sec
# loss 2.300141, train acc 0.106771
# round 30
# time to device 0.002247 sec
# time forward 0.277025 sec
# loss time 0.001064 sec
# backward time 0.008784 sec
# optimizer time 0.003482 sec
# training time in round 30 cost 0.34400296211242676 sec
# loss 2.299931, train acc 0.108619
# round 31
# time to device 0.002990 sec
# time forward 0.285453 sec
# loss time 0.001044 sec
# backward time 0.008908 sec
# optimizer time 0.003622 sec
# training time in round 31 cost 0.3446331024169922 sec
# loss 2.299945, train acc 0.109619
# round 32
# time to device 0.003217 sec
# time forward 0.294572 sec
# loss time 0.001047 sec
# backward time 0.009686 sec
# optimizer time 0.003593 sec
# training time in round 32 cost 0.34538698196411133 sec
# loss 2.300207, train acc 0.107955
# round 33
# time to device 0.002893 sec
# time forward 0.304205 sec
# loss time 0.001243 sec
# backward time 0.009683 sec
# optimizer time 0.003524 sec
# training time in round 33 cost 0.34923481941223145 sec
# loss 2.300217, train acc 0.109145
# round 34
# time to device 0.002750 sec
# time forward 0.312529 sec
# loss time 0.001027 sec
# backward time 0.009763 sec
# optimizer time 0.003485 sec
# training time in round 34 cost 0.34581923484802246 sec
# loss 2.299958, train acc 0.110714
# round 35
# time to device 0.004610 sec
# time forward 0.321319 sec
# loss time 0.001110 sec
# backward time 0.009289 sec
# optimizer time 0.003634 sec
# training time in round 35 cost 0.3463127613067627 sec
# loss 2.299877, train acc 0.111979
# round 36
# time to device 0.004254 sec
# time forward 0.330786 sec
# loss time 0.001048 sec
# backward time 0.008395 sec
# optimizer time 0.003506 sec
# training time in round 36 cost 0.35297417640686035 sec
# loss 2.299692, train acc 0.112331
# round 37
# time to device 0.002698 sec
# time forward 0.339796 sec
# loss time 0.001048 sec
# backward time 0.009552 sec
# optimizer time 0.003446 sec
# training time in round 37 cost 0.3472881317138672 sec
# loss 2.299621, train acc 0.111842
# round 38
# time to device 0.003176 sec
# time forward 0.348483 sec
# loss time 0.001038 sec
# backward time 0.009965 sec
# optimizer time 0.003783 sec
# training time in round 38 cost 0.3466029167175293 sec
# loss 2.299563, train acc 0.111579
# round 39
# time to device 0.003550 sec
# time forward 0.356887 sec
# loss time 0.001046 sec
# backward time 0.009059 sec
# optimizer time 0.003516 sec
# training time in round 39 cost 0.3447139263153076 sec
# loss 2.299445, train acc 0.113086
# round 40
# time to device 0.003159 sec
# time forward 0.365880 sec
# loss time 0.001047 sec
# backward time 0.009614 sec
# optimizer time 0.003537 sec
# training time in round 40 cost 0.3448948860168457 sec
# loss 2.299412, train acc 0.114139
# round 41
# time to device 0.003528 sec
# time forward 0.376018 sec
# loss time 0.001059 sec
# backward time 0.009046 sec
# optimizer time 0.003519 sec
# training time in round 41 cost 0.3534867763519287 sec
# loss 2.299360, train acc 0.113653
# round 42
# time to device 0.003262 sec
# time forward 0.387249 sec
# loss time 0.001140 sec
# backward time 0.009590 sec
# optimizer time 0.003632 sec
# training time in round 42 cost 0.35658907890319824 sec
# loss 2.299323, train acc 0.114281
# round 43
# time to device 0.004928 sec
# time forward 0.396568 sec
# loss time 0.001101 sec
# backward time 0.008944 sec
# optimizer time 0.003578 sec
# training time in round 43 cost 0.34848904609680176 sec
# loss 2.299262, train acc 0.115057
# round 44
# time to device 0.002674 sec
# time forward 0.404803 sec
# loss time 0.001071 sec
# backward time 0.008474 sec
# optimizer time 0.003448 sec
# training time in round 44 cost 0.3390820026397705 sec
# loss 2.299078, train acc 0.115972
# round 45
# time to device 0.002597 sec
# time forward 0.413165 sec
# loss time 0.001083 sec
# backward time 0.009698 sec
# optimizer time 0.003543 sec
# training time in round 45 cost 0.34653210639953613 sec
# loss 2.298912, train acc 0.116848
# round 46
# time to device 0.002810 sec
# time forward 0.421866 sec
# loss time 0.001040 sec
# backward time 0.009383 sec
# optimizer time 0.003556 sec
# training time in round 46 cost 0.34500718116760254 sec
# loss 2.298797, train acc 0.117520
# round 47
# time to device 0.003259 sec
# time forward 0.431302 sec
# loss time 0.001048 sec
# backward time 0.009041 sec
# optimizer time 0.003506 sec
# training time in round 47 cost 0.3488578796386719 sec
# loss 2.298652, train acc 0.118815
# round 48
# time to device 0.003434 sec
# time forward 0.442310 sec
# loss time 0.001039 sec
# backward time 0.009049 sec
# optimizer time 0.003572 sec
# training time in round 48 cost 0.3551039695739746 sec
# loss 2.298600, train acc 0.119579
# round 49
# time to device 0.002983 sec
# time forward 0.452479 sec
# loss time 0.001050 sec
# backward time 0.010180 sec
# optimizer time 0.003564 sec
# training time in round 49 cost 0.355694055557251 sec
# loss 2.298359, train acc 0.121094
# round 50
# time to device 0.002968 sec
# time forward 0.461915 sec
# loss time 0.001107 sec
# backward time 0.009298 sec
# optimizer time 0.003585 sec
# training time in round 50 cost 0.3505740165710449 sec
# loss 2.298323, train acc 0.121170
# round 51
# time to device 0.002848 sec
# time forward 0.470417 sec
# loss time 0.001095 sec
# backward time 0.009796 sec
# optimizer time 0.003469 sec
# training time in round 51 cost 0.34433889389038086 sec
# loss 2.298228, train acc 0.121244
# round 52
# time to device 0.002587 sec
# time forward 0.476980 sec
# loss time 0.000698 sec
# backward time 0.005972 sec
# optimizer time 0.002520 sec
# training time in round 52 cost 0.32850098609924316 sec
# loss 2.298164, train acc 0.120725
# round 53
# time to device 0.002619 sec
# time forward 0.485794 sec
# loss time 0.001253 sec
# backward time 0.009390 sec
# optimizer time 0.003503 sec
# training time in round 53 cost 0.3449878692626953 sec
# loss 2.298029, train acc 0.121094
# round 54
# time to device 0.003965 sec
# time forward 0.494807 sec
# loss time 0.001102 sec
# backward time 0.009967 sec
# optimizer time 0.003623 sec
# training time in round 54 cost 0.3465731143951416 sec
# loss 2.297891, train acc 0.122017
# round 55
# time to device 0.003066 sec
# time forward 0.504946 sec
# loss time 0.001049 sec
# backward time 0.010003 sec
# optimizer time 0.003584 sec
# training time in round 55 cost 0.3539140224456787 sec
# loss 2.297799, train acc 0.122489
# round 56
# time to device 0.003035 sec
# time forward 0.512233 sec
# loss time 0.000518 sec
# backward time 0.005050 sec
# optimizer time 0.002428 sec
# training time in round 56 cost 0.36606383323669434 sec
# loss 2.297680, train acc 0.123629
# round 57
# time to device 0.003012 sec
# time forward 0.521188 sec
# loss time 0.000892 sec
# backward time 0.008484 sec
# optimizer time 0.003356 sec
# training time in round 57 cost 0.3452799320220947 sec
# loss 2.297549, train acc 0.124192
# round 58
# time to device 0.002902 sec
# time forward 0.529977 sec
# loss time 0.001051 sec
# backward time 0.009673 sec
# optimizer time 0.003532 sec
# training time in round 58 cost 0.3566398620605469 sec
# loss 2.297435, train acc 0.125397
# round 59
# time to device 0.002703 sec
# time forward 0.536749 sec
# loss time 0.000775 sec
# backward time 0.006790 sec
# optimizer time 0.002825 sec
# training time in round 59 cost 0.32718801498413086 sec
# loss 2.297374, train acc 0.125651
# round 60
# time to device 0.002926 sec
# time forward 0.545715 sec
# loss time 0.001043 sec
# backward time 0.008993 sec
# optimizer time 0.003508 sec
# training time in round 60 cost 0.34736204147338867 sec
# loss 2.297288, train acc 0.126665
# round 61
# time to device 0.003035 sec
# time forward 0.553643 sec
# loss time 0.001026 sec
# backward time 0.008420 sec
# optimizer time 0.003497 sec
# training time in round 61 cost 0.3405952453613281 sec
# loss 2.297122, train acc 0.127646
# round 62
# time to device 0.002903 sec
# time forward 0.561905 sec
# loss time 0.001072 sec
# backward time 0.009132 sec
# optimizer time 0.003549 sec
# training time in round 62 cost 0.3445858955383301 sec
# loss 2.296995, train acc 0.128224
# round 63
# time to device 0.003048 sec
# time forward 0.570460 sec
# loss time 0.001045 sec
# backward time 0.009501 sec
# optimizer time 0.003512 sec
# training time in round 63 cost 0.343980073928833 sec
# loss 2.296987, train acc 0.127563
# round 64
# time to device 0.003312 sec
# time forward 0.579714 sec
# loss time 0.001016 sec
# backward time 0.008612 sec
# optimizer time 0.003613 sec
# training time in round 64 cost 0.3471229076385498 sec
# loss 2.296874, train acc 0.127885
# round 65
# time to device 0.003576 sec
# time forward 0.589537 sec
# loss time 0.001037 sec
# backward time 0.009904 sec
# optimizer time 0.003804 sec
# training time in round 65 cost 0.3546171188354492 sec
# loss 2.296938, train acc 0.128196
# round 66
# time to device 0.002966 sec
# time forward 0.598871 sec
# loss time 0.001019 sec
# backward time 0.008616 sec
# optimizer time 0.003570 sec
# training time in round 66 cost 0.3524501323699951 sec
# loss 2.296839, train acc 0.128498
# round 67
# time to device 0.002824 sec
# time forward 0.608017 sec
# loss time 0.001055 sec
# backward time 0.009214 sec
# optimizer time 0.003529 sec
# training time in round 67 cost 0.349254846572876 sec
# loss 2.296721, train acc 0.128562
# round 68
# time to device 0.002914 sec
# time forward 0.615898 sec
# loss time 0.001059 sec
# backward time 0.008567 sec
# optimizer time 0.003567 sec
# training time in round 68 cost 0.3389101028442383 sec
# loss 2.296488, train acc 0.128963
# round 69
# time to device 0.002787 sec
# time forward 0.624532 sec
# loss time 0.001068 sec
# backward time 0.009936 sec
# optimizer time 0.003556 sec
# training time in round 69 cost 0.3452329635620117 sec
# loss 2.296461, train acc 0.129464
# round 70
# time to device 0.003460 sec
# time forward 0.633412 sec
# loss time 0.001063 sec
# backward time 0.009568 sec
# optimizer time 0.003581 sec
# training time in round 70 cost 0.3455491065979004 sec
# loss 2.296286, train acc 0.130392
# round 71
# time to device 0.004477 sec
# time forward 0.642606 sec
# loss time 0.001112 sec
# backward time 0.009059 sec
# optimizer time 0.003571 sec
# training time in round 71 cost 0.349931001663208 sec
# loss 2.296162, train acc 0.131076
# round 72
# time to device 0.003412 sec
# time forward 0.652376 sec
# loss time 0.001067 sec
# backward time 0.008921 sec
# optimizer time 0.003564 sec
# training time in round 72 cost 0.3546738624572754 sec
# loss 2.295993, train acc 0.132170
# round 73
# time to device 0.003634 sec
# time forward 0.661258 sec
# loss time 0.001058 sec
# backward time 0.009446 sec
# optimizer time 0.003588 sec
# training time in round 73 cost 0.3484210968017578 sec
# loss 2.295887, train acc 0.131968
# round 74
# time to device 0.002793 sec
# time forward 0.669438 sec
# loss time 0.001030 sec
# backward time 0.006151 sec
# optimizer time 0.002496 sec
# training time in round 74 cost 0.3376278877258301 sec
# loss 2.295706, train acc 0.132292
# round 75
# time to device 0.002947 sec
# time forward 0.678117 sec
# loss time 0.001071 sec
# backward time 0.009851 sec
# optimizer time 0.003626 sec
# training time in round 75 cost 0.34615397453308105 sec
# loss 2.295509, train acc 0.133326
# round 76
# time to device 0.002071 sec
# time forward 0.684948 sec
# loss time 0.000577 sec
# backward time 0.005532 sec
# optimizer time 0.002093 sec
# training time in round 76 cost 0.36373305320739746 sec
# loss 2.295387, train acc 0.133929
# round 77
# time to device 0.003304 sec
# time forward 0.693755 sec
# loss time 0.001059 sec
# backward time 0.010152 sec
# optimizer time 0.003668 sec
# training time in round 77 cost 0.34654903411865234 sec
# loss 2.295193, train acc 0.135417
# round 78
# time to device 0.002810 sec
# time forward 0.702941 sec
# loss time 0.001028 sec
# backward time 0.008890 sec
# optimizer time 0.003580 sec
# training time in round 78 cost 0.34683990478515625 sec
# loss 2.295019, train acc 0.135680
# round 79
# time to device 0.003574 sec
# time forward 0.712205 sec
# loss time 0.001052 sec
# backward time 0.008968 sec
# optimizer time 0.004159 sec
# training time in round 79 cost 0.3457772731781006 sec
# loss 2.294854, train acc 0.137109
# round 80
# time to device 0.003533 sec
# time forward 0.722599 sec
# loss time 0.001049 sec
# backward time 0.008667 sec
# optimizer time 0.003549 sec
# training time in round 80 cost 0.3558950424194336 sec
# loss 2.294674, train acc 0.137539
# round 81
# time to device 0.002701 sec
# time forward 0.731385 sec
# loss time 0.001052 sec
# backward time 0.009379 sec
# optimizer time 0.003669 sec
# training time in round 81 cost 0.346160888671875 sec
# loss 2.294588, train acc 0.137576
# round 82
# time to device 0.002862 sec
# time forward 0.739919 sec
# loss time 0.001045 sec
# backward time 0.010271 sec
# optimizer time 0.003700 sec
# training time in round 82 cost 0.34534382820129395 sec
# loss 2.294432, train acc 0.139025
# round 83
# time to device 0.003410 sec
# time forward 0.748321 sec
# loss time 0.001059 sec
# backward time 0.009297 sec
# optimizer time 0.003574 sec
# training time in round 83 cost 0.3432638645172119 sec
# loss 2.294194, train acc 0.140160
# round 84
# time to device 0.002624 sec
# time forward 0.757038 sec
# loss time 0.001189 sec
# backward time 0.009600 sec
# optimizer time 0.003521 sec
# training time in round 84 cost 0.34523582458496094 sec
# loss 2.293916, train acc 0.141728
# round 85
# time to device 0.004294 sec
# time forward 0.766395 sec
# loss time 0.001040 sec
# backward time 0.010038 sec
# optimizer time 0.003685 sec
# training time in round 85 cost 0.3490729331970215 sec
# loss 2.293783, train acc 0.142078
# round 86
# time to device 0.006547 sec
# time forward 0.773295 sec
# loss time 0.000684 sec
# backward time 0.006446 sec
# optimizer time 0.002543 sec
# training time in round 86 cost 0.3344919681549072 sec
# loss 2.293533, train acc 0.143050
# round 87
# time to device 0.002596 sec
# time forward 0.781907 sec
# loss time 0.001048 sec
# backward time 0.009307 sec
# optimizer time 0.003827 sec
# training time in round 87 cost 0.3441910743713379 sec
# loss 2.293508, train acc 0.142933
# round 88
# time to device 0.003498 sec
# time forward 0.790724 sec
# loss time 0.001200 sec
# backward time 0.009484 sec
# optimizer time 0.003522 sec
# training time in round 88 cost 0.3481919765472412 sec
# loss 2.293304, train acc 0.143522
# round 89
# time to device 0.003990 sec
# time forward 0.800345 sec
# loss time 0.000994 sec
# backward time 0.009083 sec
# optimizer time 0.003334 sec
# training time in round 89 cost 0.3560349941253662 sec
# loss 2.293164, train acc 0.144184
# round 90
# time to device 0.003178 sec
# time forward 0.809124 sec
# loss time 0.001098 sec
# backward time 0.009444 sec
# optimizer time 0.003605 sec
# training time in round 90 cost 0.3461000919342041 sec
# loss 2.292933, train acc 0.144746
# round 91
# time to device 0.003247 sec
# time forward 0.818216 sec
# loss time 0.001064 sec
# backward time 0.009805 sec
# optimizer time 0.003638 sec
# training time in round 91 cost 0.34653472900390625 sec
# loss 2.292749, train acc 0.145635
# round 92
# time to device 0.004498 sec
# time forward 0.825577 sec
# loss time 0.000455 sec
# backward time 0.007370 sec
# optimizer time 0.004078 sec
# training time in round 92 cost 0.33751893043518066 sec
# loss 2.292552, train acc 0.146421
# round 93
# time to device 0.002961 sec
# time forward 0.834717 sec
# loss time 0.001082 sec
# backward time 0.009180 sec
# optimizer time 0.003905 sec
# training time in round 93 cost 0.3672912120819092 sec
# loss 2.292379, train acc 0.147274
# round 94
# time to device 0.002724 sec
# time forward 0.843469 sec
# loss time 0.001064 sec
# backward time 0.008820 sec
# optimizer time 0.003600 sec
# training time in round 94 cost 0.34456491470336914 sec
# loss 2.292211, train acc 0.147615
# round 95
# time to device 0.003585 sec
# time forward 0.852777 sec
# loss time 0.001089 sec
# backward time 0.008918 sec
# optimizer time 0.003561 sec
# training time in round 95 cost 0.34573912620544434 sec
# loss 2.291996, train acc 0.148193
# round 96
# time to device 0.003223 sec
# time forward 0.861801 sec
# loss time 0.001062 sec
# backward time 0.009367 sec
# optimizer time 0.003610 sec
# training time in round 96 cost 0.34822511672973633 sec
# loss 2.291788, train acc 0.148679
# round 97
# time to device 0.003012 sec
# time forward 0.870818 sec
# loss time 0.001049 sec
# backward time 0.009999 sec
# optimizer time 0.003656 sec
# training time in round 97 cost 0.3472261428833008 sec
# loss 2.291564, train acc 0.149394
# round 98
# time to device 0.002617 sec
# time forward 0.879568 sec
# loss time 0.001065 sec
# backward time 0.010336 sec
# optimizer time 0.003859 sec
# training time in round 98 cost 0.3455650806427002 sec
# loss 2.291371, train acc 0.150174
# round 99
# time to device 0.002682 sec
# time forward 0.888154 sec
# loss time 0.001050 sec
# backward time 0.008715 sec
# optimizer time 0.003403 sec
# training time in round 99 cost 0.33933401107788086 sec
# loss 2.291118, train acc 0.150781
# round 100
# time to device 0.002491 sec
# time forward 0.897306 sec
# loss time 0.001055 sec
# backward time 0.009480 sec
# optimizer time 0.003576 sec
# training time in round 100 cost 0.35474300384521484 sec
# loss 2.290953, train acc 0.151222
# round 101
# time to device 0.002830 sec
# time forward 0.907193 sec
# loss time 0.001149 sec
# backward time 0.009998 sec
# optimizer time 0.001899 sec
# training time in round 101 cost 0.35035109519958496 sec
# loss 2.290765, train acc 0.151578
# round 102
# time to device 0.003215 sec
# time forward 0.917421 sec
# loss time 0.001080 sec
# backward time 0.009793 sec
# optimizer time 0.004117 sec
# training time in round 102 cost 0.36429286003112793 sec
# loss 2.290565, train acc 0.152382
# round 103
# time to device 0.003322 sec
# time forward 0.924937 sec
# loss time 0.000798 sec
# backward time 0.007505 sec
# optimizer time 0.003057 sec
# training time in round 103 cost 0.33484911918640137 sec
# loss 2.290318, train acc 0.153471
# round 104
# time to device 0.002644 sec
# time forward 0.935261 sec
# loss time 0.001079 sec
# backward time 0.010115 sec
# optimizer time 0.003631 sec
# training time in round 104 cost 0.3548710346221924 sec
# loss 2.290131, train acc 0.154092
# round 105
# time to device 0.002617 sec
# time forward 0.943609 sec
# loss time 0.000826 sec
# backward time 0.006683 sec
# optimizer time 0.002947 sec
# training time in round 105 cost 0.3387448787689209 sec
# loss 2.289983, train acc 0.154260
# round 106
# time to device 0.002970 sec
# time forward 0.952724 sec
# loss time 0.001068 sec
# backward time 0.010101 sec
# optimizer time 0.003623 sec
# training time in round 106 cost 0.34738993644714355 sec
# loss 2.289721, train acc 0.155228
# round 107
# time to device 0.005801 sec
# time forward 0.961724 sec
# loss time 0.001113 sec
# backward time 0.009273 sec
# optimizer time 0.003500 sec
# training time in round 107 cost 0.350247859954834 sec
# loss 2.289525, train acc 0.155237
# round 108
# time to device 0.003092 sec
# time forward 0.971460 sec
# loss time 0.001071 sec
# backward time 0.009312 sec
# optimizer time 0.003581 sec
# training time in round 108 cost 0.353269100189209 sec
# loss 2.289367, train acc 0.155318
# round 109
# time to device 0.003221 sec
# time forward 0.981269 sec
# loss time 0.000951 sec
# backward time 0.008555 sec
# optimizer time 0.003171 sec
# training time in round 109 cost 0.3463280200958252 sec
# loss 2.289100, train acc 0.156037
# round 110
# time to device 0.002654 sec
# time forward 0.989878 sec
# loss time 0.001036 sec
# backward time 0.008850 sec
# optimizer time 0.003579 sec
# training time in round 110 cost 0.34508800506591797 sec
# loss 2.288849, train acc 0.156461
# round 111
# time to device 0.003488 sec
# time forward 0.998579 sec
# loss time 0.001061 sec
# backward time 0.008906 sec
# optimizer time 0.003457 sec
# training time in round 111 cost 0.34279513359069824 sec
# loss 2.288576, train acc 0.157227
# round 112
# time to device 0.002725 sec
# time forward 1.007344 sec
# loss time 0.001053 sec
# backward time 0.009487 sec
# optimizer time 0.003582 sec
# training time in round 112 cost 0.3469998836517334 sec
# loss 2.288290, train acc 0.157425
# round 113
# time to device 0.003285 sec
# time forward 1.016686 sec
# loss time 0.001067 sec
# backward time 0.008869 sec
# optimizer time 0.003503 sec
# training time in round 113 cost 0.3505887985229492 sec
# loss 2.287980, train acc 0.158169
# round 114
# time to device 0.003244 sec
# time forward 1.025968 sec
# loss time 0.001143 sec
# backward time 0.009528 sec
# optimizer time 0.003707 sec
# training time in round 114 cost 0.34766483306884766 sec
# loss 2.287706, train acc 0.158832
# round 115
# time to device 0.003543 sec
# time forward 1.035774 sec
# loss time 0.001335 sec
# backward time 0.010776 sec
# optimizer time 0.004456 sec
# training time in round 115 cost 0.35384202003479004 sec
# loss 2.287357, train acc 0.159348
# round 116
# time to device 0.003319 sec
# time forward 1.045862 sec
# loss time 0.001057 sec
# backward time 0.009646 sec
# optimizer time 0.003614 sec
# training time in round 116 cost 0.3511650562286377 sec
# loss 2.287085, train acc 0.159856
# round 117
# time to device 0.002645 sec
# time forward 1.053319 sec
# loss time 0.000863 sec
# backward time 0.007351 sec
# optimizer time 0.003068 sec
# training time in round 117 cost 0.33844614028930664 sec
# loss 2.286686, train acc 0.160818
# round 118
# time to device 0.002854 sec
# time forward 1.061611 sec
# loss time 0.001053 sec
# backward time 0.009088 sec
# optimizer time 0.003541 sec
# training time in round 118 cost 0.34310126304626465 sec
# loss 2.286454, train acc 0.160846
# round 119
# time to device 0.002948 sec
# time forward 1.067744 sec
# loss time 0.000456 sec
# backward time 0.004114 sec
# optimizer time 0.001891 sec
# training time in round 119 cost 0.32486486434936523 sec
# loss 2.286034, train acc 0.161914
# round 120
# time to device 0.003095 sec
# time forward 1.075833 sec
# loss time 0.001067 sec
# backward time 0.008748 sec
# optimizer time 0.003656 sec
# training time in round 120 cost 0.3410990238189697 sec
# loss 2.285685, train acc 0.162255
# round 121
# time to device 0.002988 sec
# time forward 1.084301 sec
# loss time 0.001083 sec
# backward time 0.011519 sec
# optimizer time 0.003712 sec
# training time in round 121 cost 0.34699487686157227 sec
# loss 2.285339, train acc 0.162654
# round 122
# time to device 0.002819 sec
# time forward 1.093153 sec
# loss time 0.001068 sec
# backward time 0.009376 sec
# optimizer time 0.003708 sec
# training time in round 122 cost 0.3439469337463379 sec
# loss 2.285015, train acc 0.163110
# round 123
# time to device 0.002802 sec
# time forward 1.103197 sec
# loss time 0.001038 sec
# backward time 0.009264 sec
# optimizer time 0.003560 sec
# training time in round 123 cost 0.3512387275695801 sec
# loss 2.284666, train acc 0.163936
# round 124
# time to device 0.003503 sec
# time forward 1.111963 sec
# loss time 0.000981 sec
# backward time 0.008584 sec
# optimizer time 0.003124 sec
# training time in round 124 cost 0.3553950786590576 sec
# loss 2.284173, train acc 0.164875
# round 125
# time to device 0.003102 sec
# time forward 1.118749 sec
# loss time 0.000630 sec
# backward time 0.005265 sec
# optimizer time 0.002393 sec
# training time in round 125 cost 0.3403010368347168 sec
# loss 2.283754, train acc 0.165551
# round 126
# time to device 0.002714 sec
# time forward 1.127459 sec
# loss time 0.001033 sec
# backward time 0.011079 sec
# optimizer time 0.003583 sec
# training time in round 126 cost 0.34354090690612793 sec
# loss 2.283384, train acc 0.165846
# round 127
# time to device 0.002884 sec
# time forward 1.136391 sec
# loss time 0.001078 sec
# backward time 0.009930 sec
# optimizer time 0.003739 sec
# training time in round 127 cost 0.34529995918273926 sec
# loss 2.282892, train acc 0.166748
# round 128
# time to device 0.002676 sec
# time forward 1.145203 sec
# loss time 0.001039 sec
# backward time 0.009963 sec
# optimizer time 0.003557 sec
# training time in round 128 cost 0.3462951183319092 sec
# loss 2.282423, train acc 0.166606
# round 129
# time to device 0.003325 sec
# time forward 1.154074 sec
# loss time 0.001082 sec
# backward time 0.009233 sec
# optimizer time 0.003638 sec
# training time in round 129 cost 0.3464210033416748 sec
# loss 2.281977, train acc 0.167308
# round 130
# time to device 0.005424 sec
# time forward 1.164678 sec
# loss time 0.001122 sec
# backward time 0.009444 sec
# optimizer time 0.003477 sec
# training time in round 130 cost 0.3557610511779785 sec
# loss 2.281478, train acc 0.167760
# round 131
# time to device 0.003089 sec
# time forward 1.174235 sec
# loss time 0.001045 sec
# backward time 0.009653 sec
# optimizer time 0.003570 sec
# training time in round 131 cost 0.34787487983703613 sec
# loss 2.280917, train acc 0.168620
# round 132
# time to device 0.003026 sec
# time forward 1.183070 sec
# loss time 0.001060 sec
# backward time 0.014133 sec
# optimizer time 0.003864 sec
# training time in round 132 cost 0.3501307964324951 sec
# loss 2.280358, train acc 0.169232
# round 133
# time to device 0.002805 sec
# time forward 1.191683 sec
# loss time 0.001049 sec
# backward time 0.009160 sec
# optimizer time 0.003504 sec
# training time in round 133 cost 0.34615135192871094 sec
# loss 2.279824, train acc 0.169660
# round 134
# time to device 0.003226 sec
# time forward 1.199894 sec
# loss time 0.000867 sec
# backward time 0.008421 sec
# optimizer time 0.003138 sec
# training time in round 134 cost 0.3402848243713379 sec
# loss 2.279265, train acc 0.170139
# round 135
# time to device 0.002720 sec
# time forward 1.208265 sec
# loss time 0.001060 sec
# backward time 0.008981 sec
# optimizer time 0.003525 sec
# training time in round 135 cost 0.34343910217285156 sec
# loss 2.278681, train acc 0.170784
# round 136
# time to device 0.002772 sec
# time forward 1.216411 sec
# loss time 0.000892 sec
# backward time 0.008400 sec
# optimizer time 0.003139 sec
# training time in round 136 cost 0.33875513076782227 sec
# loss 2.277962, train acc 0.171533
# round 137
# time to device 0.002642 sec
# time forward 1.224727 sec
# loss time 0.001114 sec
# backward time 0.008691 sec
# optimizer time 0.003366 sec
# training time in round 137 cost 0.34168314933776855 sec
# loss 2.277246, train acc 0.172611
# round 138
# time to device 0.003010 sec
# time forward 1.233469 sec
# loss time 0.001062 sec
# backward time 0.009103 sec
# optimizer time 0.003555 sec
# training time in round 138 cost 0.34157609939575195 sec
# loss 2.276443, train acc 0.173561
# round 139
# time to device 0.003148 sec
# time forward 1.243252 sec
# loss time 0.001201 sec
# backward time 0.008517 sec
# optimizer time 0.003433 sec
# training time in round 139 cost 0.35212111473083496 sec
# loss 2.275656, train acc 0.174107
# round 140
# time to device 0.003091 sec
# time forward 1.251760 sec
# loss time 0.001043 sec
# backward time 0.009500 sec
# optimizer time 0.003670 sec
# training time in round 140 cost 0.3459768295288086 sec
# loss 2.274664, train acc 0.175255
# round 141
# time to device 0.002859 sec
# time forward 1.259684 sec
# loss time 0.000535 sec
# backward time 0.004918 sec
# optimizer time 0.001818 sec
# training time in round 141 cost 0.3256242275238037 sec
# loss 2.273883, train acc 0.175891
# round 142
# time to device 0.002694 sec
# time forward 1.268182 sec
# loss time 0.000893 sec
# backward time 0.008485 sec
# optimizer time 0.003471 sec
# training time in round 142 cost 0.3444511890411377 sec
# loss 2.272871, train acc 0.176573
# round 143
# time to device 0.002575 sec
# time forward 1.274968 sec
# loss time 0.000514 sec
# backward time 0.004875 sec
# optimizer time 0.001958 sec
# training time in round 143 cost 0.3362729549407959 sec
# loss 2.272032, train acc 0.177300
# round 144
# time to device 0.002785 sec
# time forward 1.284047 sec
# loss time 0.001069 sec
# backward time 0.009290 sec
# optimizer time 0.003578 sec
# training time in round 144 cost 0.34650492668151855 sec
# loss 2.271064, train acc 0.178448
# round 145
# time to device 0.003061 sec
# time forward 1.292306 sec
# loss time 0.001048 sec
# backward time 0.010179 sec
# optimizer time 0.003620 sec
# training time in round 145 cost 0.3435022830963135 sec
# loss 2.270024, train acc 0.178992
# round 146
# time to device 0.003038 sec
# time forward 1.300670 sec
# loss time 0.001085 sec
# backward time 0.009298 sec
# optimizer time 0.003459 sec
# training time in round 146 cost 0.34698915481567383 sec
# loss 2.269023, train acc 0.179688
# round 147
# time to device 0.002616 sec
# time forward 1.309072 sec
# loss time 0.001037 sec
# backward time 0.009443 sec
# optimizer time 0.003559 sec
# training time in round 147 cost 0.34385204315185547 sec
# loss 2.267835, train acc 0.180532
# round 148
# time to device 0.003524 sec
# time forward 1.317879 sec
# loss time 0.001017 sec
# backward time 0.008821 sec
# optimizer time 0.003461 sec
# training time in round 148 cost 0.3446037769317627 sec
# loss 2.266708, train acc 0.180998
# round 149
# time to device 0.004146 sec
# time forward 1.328256 sec
# loss time 0.001067 sec
# backward time 0.009897 sec
# optimizer time 0.003580 sec
# training time in round 149 cost 0.35386204719543457 sec
# loss 2.265342, train acc 0.182292
# round 150
# time to device 0.003400 sec
# time forward 1.337582 sec
# loss time 0.001215 sec
# backward time 0.009058 sec
# optimizer time 0.003650 sec
# training time in round 150 cost 0.34866905212402344 sec
# loss 2.263744, train acc 0.183620
# round 151
# time to device 0.002398 sec
# time forward 1.344677 sec
# loss time 0.000864 sec
# backward time 0.008351 sec
# optimizer time 0.003357 sec
# training time in round 151 cost 0.33526015281677246 sec
# loss 2.262173, train acc 0.184673
# round 152
# time to device 0.002707 sec
# time forward 1.352072 sec
# loss time 0.000903 sec
# backward time 0.008241 sec
# optimizer time 0.003089 sec
# training time in round 152 cost 0.33529019355773926 sec
# loss 2.260794, train acc 0.185611
# round 153
# time to device 0.003117 sec
# time forward 1.360662 sec
# loss time 0.000858 sec
# backward time 0.008462 sec
# optimizer time 0.003073 sec
# training time in round 153 cost 0.3422679901123047 sec
# loss 2.259191, train acc 0.186638
# round 154
# time to device 0.002987 sec
# time forward 1.369780 sec
# loss time 0.000878 sec
# backward time 0.008376 sec
# optimizer time 0.003011 sec
# training time in round 154 cost 0.3485739231109619 sec
# loss 2.257376, train acc 0.187500
# round 155
# time to device 0.003065 sec
# time forward 1.379257 sec
# loss time 0.001046 sec
# backward time 0.009918 sec
# optimizer time 0.003612 sec
# training time in round 155 cost 0.3545680046081543 sec
# loss 2.255099, train acc 0.188852
# round 156
# time to device 0.002800 sec
# time forward 1.387999 sec
# loss time 0.001272 sec
# backward time 0.009925 sec
# optimizer time 0.003578 sec
# training time in round 156 cost 0.34371280670166016 sec
# loss 2.253245, train acc 0.189789
# round 157
# time to device 0.002544 sec
# time forward 1.395954 sec
# loss time 0.001034 sec
# backward time 0.008740 sec
# optimizer time 0.003366 sec
# training time in round 157 cost 0.3389267921447754 sec
# loss 2.250863, train acc 0.190912
# round 158
# time to device 0.003299 sec
# time forward 1.404777 sec
# loss time 0.001242 sec
# backward time 0.009250 sec
# optimizer time 0.003484 sec
# training time in round 158 cost 0.3439819812774658 sec
# loss 2.248449, train acc 0.192217
# round 159
# time to device 0.002631 sec
# time forward 1.413853 sec
# loss time 0.000910 sec
# backward time 0.008520 sec
# optimizer time 0.003267 sec
# training time in round 159 cost 0.3457679748535156 sec
# loss 2.245418, train acc 0.193555
# round 160
# time to device 0.002921 sec
# time forward 1.422772 sec
# loss time 0.001053 sec
# backward time 0.010447 sec
# optimizer time 0.003558 sec
# training time in round 160 cost 0.3503589630126953 sec
# loss 2.242484, train acc 0.194730
# round 161
# time to device 0.003027 sec
# time forward 1.430823 sec
# loss time 0.001071 sec
# backward time 0.009222 sec
# optimizer time 0.003499 sec
# training time in round 161 cost 0.3400743007659912 sec
# loss 2.239232, train acc 0.195891
# round 162
# time to device 0.002729 sec
# time forward 1.439208 sec
# loss time 0.000889 sec
# backward time 0.007821 sec
# optimizer time 0.003070 sec
# training time in round 162 cost 0.339627742767334 sec
# loss 2.236382, train acc 0.196894
# round 163
# time to device 0.003106 sec
# time forward 1.447421 sec
# loss time 0.001059 sec
# backward time 0.009371 sec
# optimizer time 0.003489 sec
# training time in round 163 cost 0.3412289619445801 sec
# loss 2.232905, train acc 0.198409
# round 164
# time to device 0.003083 sec
# time forward 1.458500 sec
# loss time 0.001052 sec
# backward time 0.008602 sec
# optimizer time 0.003534 sec
# training time in round 164 cost 0.35468602180480957 sec
# loss 2.230005, train acc 0.199242
# round 165
# time to device 0.003135 sec
# time forward 1.467886 sec
# loss time 0.001030 sec
# backward time 0.010288 sec
# optimizer time 0.003973 sec
# training time in round 165 cost 0.34738802909851074 sec
# loss 2.227232, train acc 0.200019
# round 166
# time to device 0.003388 sec
# time forward 1.476376 sec
# loss time 0.001124 sec
# backward time 0.009551 sec
# optimizer time 0.003560 sec
# training time in round 166 cost 0.34355783462524414 sec
# loss 2.223877, train acc 0.201067
# round 167
# time to device 0.003093 sec
# time forward 1.484722 sec
# loss time 0.000877 sec
# backward time 0.008396 sec
# optimizer time 0.003213 sec
# training time in round 167 cost 0.34250712394714355 sec
# loss 2.220909, train acc 0.201823
# round 168
# time to device 0.002593 sec
# time forward 1.492497 sec
# loss time 0.000891 sec
# backward time 0.008413 sec
# optimizer time 0.003249 sec
# training time in round 168 cost 0.33725905418395996 sec
# loss 2.217241, train acc 0.202940
# round 169
# time to device 0.002543 sec
# time forward 1.501067 sec
# loss time 0.001115 sec
# backward time 0.009099 sec
# optimizer time 0.003575 sec
# training time in round 169 cost 0.34331417083740234 sec
# loss 2.213124, train acc 0.204504
# round 170
# time to device 0.002842 sec
# time forward 1.508565 sec
# loss time 0.000883 sec
# backward time 0.007452 sec
# optimizer time 0.003076 sec
# training time in round 170 cost 0.3356971740722656 sec
# loss 2.209438, train acc 0.205592
# round 171
# time to device 0.002794 sec
# time forward 1.516200 sec
# loss time 0.000856 sec
# backward time 0.008452 sec
# optimizer time 0.003059 sec
# training time in round 171 cost 0.33679890632629395 sec
# loss 2.206530, train acc 0.206668
# round 172
# time to device 0.002965 sec
# time forward 1.524875 sec
# loss time 0.001028 sec
# backward time 0.009280 sec
# optimizer time 0.003512 sec
# training time in round 172 cost 0.34270405769348145 sec
# loss 2.203202, train acc 0.207776
# round 173
# time to device 0.003086 sec
# time forward 1.534586 sec
# loss time 0.001031 sec
# backward time 0.009304 sec
# optimizer time 0.003581 sec
# training time in round 173 cost 0.35431885719299316 sec
# loss 2.199696, train acc 0.208917
# round 174
# time to device 0.003055 sec
# time forward 1.544031 sec
# loss time 0.001119 sec
# backward time 0.009349 sec
# optimizer time 0.003534 sec
# training time in round 174 cost 0.3488030433654785 sec
# loss 2.196182, train acc 0.210134
# round 175
# time to device 0.003181 sec
# time forward 1.553298 sec
# loss time 0.001064 sec
# backward time 0.010147 sec
# optimizer time 0.003504 sec
# training time in round 175 cost 0.35051798820495605 sec
# loss 2.192278, train acc 0.211559
# round 176
# time to device 0.002877 sec
# time forward 1.561295 sec
# loss time 0.000922 sec
# backward time 0.008836 sec
# optimizer time 0.003093 sec
# training time in round 176 cost 0.3405759334564209 sec
# loss 2.187913, train acc 0.212924
# round 177
# time to device 0.002596 sec
# time forward 1.569451 sec
# loss time 0.000875 sec
# backward time 0.008385 sec
# optimizer time 0.003351 sec
# training time in round 177 cost 0.3379781246185303 sec
# loss 2.184446, train acc 0.214229
# round 178
# time to device 0.003334 sec
# time forward 1.578201 sec
# loss time 0.001043 sec
# backward time 0.009391 sec
# optimizer time 0.003463 sec
# training time in round 178 cost 0.34440112113952637 sec
# loss 2.181018, train acc 0.215302
# round 179
# time to device 0.003216 sec
# time forward 1.586253 sec
# loss time 0.000436 sec
# backward time 0.008083 sec
# optimizer time 0.001774 sec
# training time in round 179 cost 0.3390390872955322 sec
# loss 2.177322, train acc 0.216319
# round 180
# time to device 0.003498 sec
# time forward 1.596048 sec
# loss time 0.001054 sec
# backward time 0.010104 sec
# optimizer time 0.003477 sec
# training time in round 180 cost 0.3507421016693115 sec
# loss 2.173362, train acc 0.217628
# round 181
# time to device 0.002890 sec
# time forward 1.603245 sec
# loss time 0.001055 sec
# backward time 0.009868 sec
# optimizer time 0.003591 sec
# training time in round 181 cost 0.3375227451324463 sec
# loss 2.169276, train acc 0.219050
# round 182
# time to device 0.002759 sec
# time forward 1.611863 sec
# loss time 0.001113 sec
# backward time 0.009175 sec
# optimizer time 0.003449 sec
# training time in round 182 cost 0.3432738780975342 sec
# loss 2.165143, train acc 0.220458
# round 183
# time to device 0.003171 sec
# time forward 1.620064 sec
# loss time 0.001063 sec
# backward time 0.009139 sec
# optimizer time 0.003716 sec
# training time in round 183 cost 0.3411087989807129 sec
# loss 2.161244, train acc 0.221850
# round 184
# time to device 0.002678 sec
# time forward 1.628304 sec
# loss time 0.000861 sec
# backward time 0.008035 sec
# optimizer time 0.003123 sec
# training time in round 184 cost 0.3393850326538086 sec
# loss 2.157347, train acc 0.223057
# round 185
# time to device 0.002639 sec
# time forward 1.635834 sec
# loss time 0.000875 sec
# backward time 0.008370 sec
# optimizer time 0.003166 sec
# training time in round 185 cost 0.33509373664855957 sec
# loss 2.152315, train acc 0.224756
# round 186
# time to device 0.002707 sec
# time forward 1.643890 sec
# loss time 0.000865 sec
# backward time 0.008324 sec
# optimizer time 0.003421 sec
# training time in round 186 cost 0.3415541648864746 sec
# loss 2.148314, train acc 0.225810
# round 187
# time to device 0.003518 sec
# time forward 1.652550 sec
# loss time 0.001024 sec
# backward time 0.009302 sec
# optimizer time 0.003534 sec
# training time in round 187 cost 0.3439629077911377 sec
# loss 2.143517, train acc 0.227601
# round 188
# time to device 0.002743 sec
# time forward 1.661129 sec
# loss time 0.001064 sec
# backward time 0.013666 sec
# optimizer time 0.003441 sec
# training time in round 188 cost 0.3496897220611572 sec
# loss 2.139424, train acc 0.228753
# round 189
# time to device 0.003005 sec
# time forward 1.668952 sec
# loss time 0.000854 sec
# backward time 0.008408 sec
# optimizer time 0.003176 sec
# training time in round 189 cost 0.3368377685546875 sec
# loss 2.135561, train acc 0.230058
# round 190
# time to device 0.003308 sec
# time forward 1.676989 sec
# loss time 0.001035 sec
# backward time 0.008549 sec
# optimizer time 0.003345 sec
# training time in round 190 cost 0.35048985481262207 sec
# loss 2.131998, train acc 0.230898
# round 191
# time to device 0.004131 sec
# time forward 1.685575 sec
# loss time 0.001028 sec
# backward time 0.008958 sec
# optimizer time 0.003460 sec
# training time in round 191 cost 0.34799695014953613 sec
# loss 2.128052, train acc 0.232300
# round 192
# time to device 0.003813 sec
# time forward 1.694053 sec
# loss time 0.001021 sec
# backward time 0.009095 sec
# optimizer time 0.003446 sec
# training time in round 192 cost 0.34794092178344727 sec
# loss 2.124306, train acc 0.233687
# round 193
# time to device 0.002955 sec
# time forward 1.702454 sec
# loss time 0.001023 sec
# backward time 0.008964 sec
# optimizer time 0.003440 sec
# training time in round 193 cost 0.34980297088623047 sec
# loss 2.120044, train acc 0.235140
# round 194
# time to device 0.003479 sec
# time forward 1.711589 sec
# loss time 0.001045 sec
# backward time 0.008952 sec
# optimizer time 0.003433 sec
# training time in round 194 cost 0.3504929542541504 sec
# loss 2.115492, train acc 0.236739
# round 195
# time to device 0.003707 sec
# time forward 1.721487 sec
# loss time 0.001097 sec
# backward time 0.010220 sec
# optimizer time 0.003503 sec
# training time in round 195 cost 0.3611941337585449 sec
# loss 2.111973, train acc 0.237683
# round 196
# time to device 0.003563 sec
# time forward 1.730820 sec
# loss time 0.001325 sec
# backward time 0.010809 sec
# optimizer time 0.004093 sec
# training time in round 196 cost 0.3560662269592285 sec
# loss 2.107740, train acc 0.239253
# round 197
# time to device 0.004766 sec
# time forward 1.738904 sec
# loss time 0.001162 sec
# backward time 0.009247 sec
# optimizer time 0.003515 sec
# training time in round 197 cost 0.3460259437561035 sec
# loss 2.103987, train acc 0.240372
# round 198
# time to device 0.002859 sec
# time forward 1.746963 sec
# loss time 0.000926 sec
# backward time 0.008522 sec
# optimizer time 0.003051 sec
# training time in round 198 cost 0.34643983840942383 sec
# loss 2.099945, train acc 0.241991
# round 199
# time to device 0.002853 sec
# time forward 1.755322 sec
# loss time 0.000926 sec
# backward time 0.008661 sec
# optimizer time 0.003086 sec
# training time in round 199 cost 0.34571170806884766 sec
# loss 2.095894, train acc 0.243320
# round 200
# time to device 0.003312 sec
# time forward 1.763995 sec
# loss time 0.001029 sec
# backward time 0.008916 sec
# optimizer time 0.003419 sec
# training time in round 200 cost 0.3482091426849365 sec
# loss 2.091856, train acc 0.244753
# round 201
# time to device 0.004075 sec
# time forward 1.773264 sec
# loss time 0.001388 sec
# backward time 0.006821 sec
# optimizer time 0.004412 sec
# training time in round 201 cost 0.361907958984375 sec
# loss 2.087729, train acc 0.246210
# round 202
# time to device 0.004564 sec
# time forward 1.782300 sec
# loss time 0.001028 sec
# backward time 0.009094 sec
# optimizer time 0.003503 sec
# training time in round 202 cost 0.35230374336242676 sec
# loss 2.083400, train acc 0.247768
# round 203
# time to device 0.003514 sec
# time forward 1.791067 sec
# loss time 0.001042 sec
# backward time 0.011758 sec
# optimizer time 0.003736 sec
# training time in round 203 cost 0.35161900520324707 sec
# loss 2.079021, train acc 0.249311
# round 204
# time to device 0.003659 sec
# time forward 1.799586 sec
# loss time 0.001225 sec
# backward time 0.009703 sec
# optimizer time 0.003620 sec
# training time in round 204 cost 0.3499870300292969 sec
# loss 2.074099, train acc 0.251067
# round 205
# time to device 0.002897 sec
# time forward 1.808260 sec
# loss time 0.001057 sec
# backward time 0.009910 sec
# optimizer time 0.003596 sec
# training time in round 205 cost 0.35032129287719727 sec
# loss 2.070643, train acc 0.252086
# round 206
# time to device 0.003713 sec
# time forward 1.813314 sec
# loss time 0.000495 sec
# backward time 0.004440 sec
# optimizer time 0.001952 sec
# training time in round 206 cost 0.3233520984649658 sec
# loss 2.067510, train acc 0.253095
# round 207
# time to device 0.002990 sec
# time forward 1.820249 sec
# loss time 0.000897 sec
# backward time 0.008117 sec
# optimizer time 0.002986 sec
# training time in round 207 cost 0.3361659049987793 sec
# loss 2.062958, train acc 0.254770
# round 208
# time to device 0.003116 sec
# time forward 1.827063 sec
# ...
# time forward 3.452091 sec
# loss time 0.001312 sec
# backward time 0.010565 sec
# optimizer time 0.003503 sec
# training time in round 400 cost 0.35510921478271484 sec
# loss 0.428461, train acc 0.843360
# round 401
# time to device 0.004011 sec
# time forward 3.460722 sec
# loss time 0.001180 sec
# backward time 0.010647 sec
# optimizer time 0.003508 sec
# training time in round 401 cost 0.349837064743042 sec
# loss 0.428686, train acc 0.843206
# round 402
# time to device 0.003928 sec
# time forward 3.470215 sec
# loss time 0.001296 sec
# backward time 0.011322 sec
# optimizer time 0.004142 sec
# training time in round 402 cost 0.3543410301208496 sec
# loss 0.429020, train acc 0.843110
# round 403
# time to device 0.003164 sec
# time forward 3.476357 sec
# loss time 0.000598 sec
# backward time 0.005609 sec
# optimizer time 0.002244 sec
# training time in round 403 cost 0.34162211418151855 sec
# loss 0.428745, train acc 0.843151
# round 404
# time to device 0.005428 sec
# time forward 3.487023 sec
# loss time 0.001289 sec
# backward time 0.010797 sec
# optimizer time 0.003625 sec
# training time in round 404 cost 0.3584620952606201 sec
# loss 0.428988, train acc 0.843017
# round 405
# time to device 0.003744 sec
# time forward 3.497043 sec
# loss time 0.001316 sec
# backward time 0.009692 sec
# optimizer time 0.003412 sec
# training time in round 405 cost 0.3536210060119629 sec
# loss 0.429081, train acc 0.842961
# round 406
# time to device 0.003635 sec
# time forward 3.507220 sec
# loss time 0.001115 sec
# backward time 0.009790 sec
# optimizer time 0.003463 sec
# training time in round 406 cost 0.3516578674316406 sec
# loss 0.428939, train acc 0.842925
# round 407
# time to device 0.003370 sec
# time forward 3.518800 sec
# loss time 0.001348 sec
# backward time 0.010597 sec
# optimizer time 0.004003 sec
# training time in round 407 cost 0.3616631031036377 sec
# loss 0.428851, train acc 0.842965
# round 408
# time to device 0.003732 sec
# time forward 3.527010 sec
# loss time 0.000539 sec
# backward time 0.005412 sec
# optimizer time 0.002364 sec
# training time in round 408 cost 0.34357523918151855 sec
# loss 0.429062, train acc 0.842871
# round 409
# time to device 0.005517 sec
# time forward 3.536390 sec
# loss time 0.001306 sec
# backward time 0.010445 sec
# optimizer time 0.003457 sec
# training time in round 409 cost 0.351165771484375 sec
# loss 0.428932, train acc 0.842893
# round 410
# time to device 0.003267 sec
# time forward 3.545051 sec
# loss time 0.001023 sec
# backward time 0.008747 sec
# optimizer time 0.003389 sec
# training time in round 410 cost 0.34407591819763184 sec
# loss 0.428931, train acc 0.842895
# round 411
# time to device 0.005801 sec
# time forward 3.553830 sec
# loss time 0.001032 sec
# backward time 0.008694 sec
# optimizer time 0.003420 sec
# training time in round 411 cost 0.34528493881225586 sec
# loss 0.428841, train acc 0.842973
# round 412
# time to device 0.003566 sec
# time forward 3.564001 sec
# loss time 0.001276 sec
# backward time 0.010077 sec
# optimizer time 0.003424 sec
# training time in round 412 cost 0.3534693717956543 sec
# loss 0.428953, train acc 0.842974
# round 413
# time to device 0.003549 sec
# time forward 3.573510 sec
# loss time 0.001045 sec
# backward time 0.007843 sec
# optimizer time 0.003004 sec
# training time in round 413 cost 0.3507258892059326 sec
# loss 0.428999, train acc 0.842901
# round 414
# time to device 0.003341 sec
# time forward 3.581114 sec
# loss time 0.000690 sec
# backward time 0.006404 sec
# optimizer time 0.002513 sec
# training time in round 414 cost 0.3377048969268799 sec
# loss 0.429075, train acc 0.842941
# round 415
# time to device 0.003691 sec
# time forward 3.589833 sec
# loss time 0.001065 sec
# backward time 0.009050 sec
# optimizer time 0.003463 sec
# training time in round 415 cost 0.34882497787475586 sec
# loss 0.429152, train acc 0.842905
# round 416
# time to device 0.004416 sec
# time forward 3.597637 sec
# loss time 0.001028 sec
# backward time 0.008752 sec
# optimizer time 0.003169 sec
# training time in round 416 cost 0.35463404655456543 sec
# loss 0.429007, train acc 0.842963
# round 417
# time to device 0.003161 sec
# time forward 3.606690 sec
# loss time 0.001030 sec
# backward time 0.008947 sec
# optimizer time 0.003371 sec
# training time in round 417 cost 0.3449869155883789 sec
# loss 0.428798, train acc 0.843077
# round 418
# time to device 0.003665 sec
# time forward 3.615218 sec
# loss time 0.001387 sec
# backward time 0.005620 sec
# optimizer time 0.001841 sec
# training time in round 418 cost 0.3597886562347412 sec
# loss 0.428576, train acc 0.843116
# round 419
# time to device 0.003810 sec
# time forward 3.626497 sec
# loss time 0.001460 sec
# backward time 0.009893 sec
# optimizer time 0.003451 sec
# training time in round 419 cost 0.3605358600616455 sec
# loss 0.428694, train acc 0.843155
# round 420
# time to device 0.003975 sec
# time forward 3.638214 sec
# loss time 0.001046 sec
# backward time 0.009473 sec
# optimizer time 0.003514 sec
# training time in round 420 cost 0.36748385429382324 sec
# loss 0.428971, train acc 0.842933
# round 421
# time to device 0.004395 sec
# time forward 3.648241 sec
# loss time 0.001070 sec
# backward time 0.008933 sec
# optimizer time 0.003444 sec
# training time in round 421 cost 0.35214781761169434 sec
# loss 0.429135, train acc 0.842843
# round 422
# time to device 0.006183 sec
# time forward 3.656924 sec
# loss time 0.001058 sec
# backward time 0.010023 sec
# optimizer time 0.003638 sec
# training time in round 422 cost 0.35031604766845703 sec
# loss 0.429095, train acc 0.842845
# round 423
# time to device 0.004092 sec
# time forward 3.663441 sec
# loss time 0.000396 sec
# backward time 0.003885 sec
# optimizer time 0.001674 sec
# training time in round 423 cost 0.33190107345581055 sec
# loss 0.429295, train acc 0.842847
# round 424
# time to device 0.003124 sec
# time forward 3.673927 sec
# loss time 0.001278 sec
# backward time 0.010492 sec
# optimizer time 0.003494 sec
# training time in round 424 cost 0.35495591163635254 sec
# loss 0.429186, train acc 0.842849
# round 425
# time to device 0.003618 sec
# time forward 3.685435 sec
# loss time 0.001070 sec
# backward time 0.009039 sec
# optimizer time 0.003264 sec
# training time in round 425 cost 0.35572314262390137 sec
# loss 0.428894, train acc 0.842961
# round 426
# time to device 0.003698 sec
# time forward 3.696859 sec
# loss time 0.001494 sec
# backward time 0.009687 sec
# optimizer time 0.003448 sec
# training time in round 426 cost 0.35947227478027344 sec
# loss 0.429069, train acc 0.842872
# round 427
# time to device 0.003366 sec
# time forward 3.709699 sec
# loss time 0.001332 sec
# backward time 0.011447 sec
# optimizer time 0.003801 sec
# training time in round 427 cost 0.36999964714050293 sec
# loss 0.428858, train acc 0.842856
# round 428
# time to device 0.003380 sec
# time forward 3.716374 sec
# loss time 0.000878 sec
# backward time 0.008017 sec
# optimizer time 0.003006 sec
# training time in round 428 cost 0.3370089530944824 sec
# loss 0.428805, train acc 0.842785
# round 429
# time to device 0.003751 sec
# time forward 3.726283 sec
# loss time 0.001304 sec
# backward time 0.010661 sec
# optimizer time 0.004222 sec
# training time in round 429 cost 0.3573780059814453 sec
# loss 0.428916, train acc 0.842696
# round 430
# time to device 0.004325 sec
# time forward 3.734600 sec
# loss time 0.001022 sec
# backward time 0.009114 sec
# optimizer time 0.003177 sec
# training time in round 430 cost 0.34584689140319824 sec
# loss 0.428900, train acc 0.842644
# round 431
# time to device 0.003680 sec
# time forward 3.743756 sec
# loss time 0.000742 sec
# backward time 0.006353 sec
# optimizer time 0.003124 sec
# training time in round 431 cost 0.3527109622955322 sec
# loss 0.428897, train acc 0.842683
# round 432
# time to device 0.004274 sec
# time forward 3.754418 sec
# loss time 0.001223 sec
# backward time 0.009938 sec
# optimizer time 0.003450 sec
# training time in round 432 cost 0.3554222583770752 sec
# loss 0.428787, train acc 0.842740
# round 433
# time to device 0.003709 sec
# time forward 3.763526 sec
# loss time 0.000870 sec
# backward time 0.007937 sec
# optimizer time 0.003017 sec
# training time in round 433 cost 0.35265517234802246 sec
# loss 0.429039, train acc 0.842670
# round 434
# time to device 0.005044 sec
# time forward 3.769866 sec
# loss time 0.000693 sec
# backward time 0.006449 sec
# optimizer time 0.002754 sec
# training time in round 434 cost 0.33307766914367676 sec
# loss 0.428866, train acc 0.842690
# round 435
# time to device 0.004870 sec
# time forward 3.780364 sec
# loss time 0.000579 sec
# backward time 0.005865 sec
# optimizer time 0.002508 sec
# training time in round 435 cost 0.40854597091674805 sec
# loss 0.428823, train acc 0.842729
# round 436
# time to device 0.008743 sec
# time forward 3.798403 sec
# loss time 0.002919 sec
# backward time 0.017455 sec
# optimizer time 0.003894 sec
# training time in round 436 cost 0.46216487884521484 sec
# loss 0.428639, train acc 0.842785
# round 437
# time to device 0.007114 sec
# time forward 3.816591 sec
# loss time 0.002604 sec
# backward time 0.016985 sec
# optimizer time 0.003048 sec
# training time in round 437 cost 0.44167137145996094 sec
# loss 0.428567, train acc 0.842698
# round 438
# time to device 0.010751 sec
# time forward 3.832871 sec
# loss time 0.002039 sec
# backward time 0.016431 sec
# optimizer time 0.005649 sec
# training time in round 438 cost 0.40775489807128906 sec
# loss 0.428573, train acc 0.842664
# round 439
# time to device 0.010591 sec
# time forward 3.850448 sec
# loss time 0.003046 sec
# backward time 0.012932 sec
# optimizer time 0.004865 sec
# training time in round 439 cost 0.4006061553955078 sec
# loss 0.428439, train acc 0.842738
# round 440
# time to device 0.011711 sec
# time forward 3.857529 sec
# loss time 0.000756 sec
# backward time 0.006367 sec
# optimizer time 0.002303 sec
# training time in round 440 cost 0.3811969757080078 sec
# loss 0.428641, train acc 0.842652
# round 441
# time to device 0.007183 sec
# time forward 3.864686 sec
# loss time 0.000466 sec
# backward time 0.004370 sec
# optimizer time 0.001964 sec
# training time in round 441 cost 0.42444324493408203 sec
# loss 0.428404, train acc 0.842778
# round 442
# time to device 0.007258 sec
# time forward 3.870941 sec
# loss time 0.000764 sec
# backward time 0.006895 sec
# optimizer time 0.002745 sec
# training time in round 442 cost 0.3361537456512451 sec
# loss 0.428528, train acc 0.842745
# round 443
# time to device 0.007103 sec
# time forward 3.879296 sec
# loss time 0.000934 sec
# backward time 0.008569 sec
# optimizer time 0.003097 sec
# training time in round 443 cost 0.3523383140563965 sec
# loss 0.428723, train acc 0.842694
# round 444
# time to device 0.004954 sec
# time forward 3.886158 sec
# loss time 0.000571 sec
# backward time 0.005354 sec
# optimizer time 0.002730 sec
# training time in round 444 cost 0.3869450092315674 sec
# loss 0.428520, train acc 0.842855
# round 445
# time to device 0.007330 sec
# time forward 3.895029 sec
# loss time 0.001270 sec
# backward time 0.006905 sec
# optimizer time 0.002782 sec
# training time in round 445 cost 0.360400915145874 sec
# loss 0.428645, train acc 0.842787
# round 446
# time to device 0.006253 sec
# time forward 3.908038 sec
# loss time 0.001038 sec
# backward time 0.009033 sec
# optimizer time 0.003660 sec
# training time in round 446 cost 0.37979602813720703 sec
# loss 0.428405, train acc 0.842911
# round 447
# time to device 0.014337 sec
# time forward 3.914739 sec
# loss time 0.000680 sec
# backward time 0.005182 sec
# optimizer time 0.002451 sec
# training time in round 447 cost 0.37421584129333496 sec
# loss 0.428438, train acc 0.842826
# round 448
# time to device 0.004975 sec
# time forward 3.920455 sec
# loss time 0.000485 sec
# backward time 0.005333 sec
# optimizer time 0.002278 sec
# training time in round 448 cost 0.342426061630249 sec
# loss 0.428493, train acc 0.842741
# round 449
# time to device 0.005764 sec
# time forward 3.927389 sec
# loss time 0.000442 sec
# backward time 0.004202 sec
# optimizer time 0.001935 sec
# training time in round 449 cost 0.36955690383911133 sec
# loss 0.428579, train acc 0.842622
# round 450
# time to device 0.007365 sec
# time forward 3.935321 sec
# loss time 0.001081 sec
# backward time 0.009850 sec
# optimizer time 0.003681 sec
# training time in round 450 cost 0.34874796867370605 sec
# loss 0.428628, train acc 0.842520
# round 451
# time to device 0.006503 sec
# time forward 3.942314 sec
# loss time 0.000586 sec
# backward time 0.005445 sec
# optimizer time 0.002315 sec
# training time in round 451 cost 0.33667707443237305 sec
# loss 0.428640, train acc 0.842488
# round 452
# time to device 0.007946 sec
# time forward 3.950226 sec
# loss time 0.000867 sec
# backward time 0.007726 sec
# optimizer time 0.003056 sec
# training time in round 452 cost 0.3463609218597412 sec
# loss 0.428651, train acc 0.842439
# round 453
# time to device 0.006941 sec
# time forward 3.958226 sec
# loss time 0.000658 sec
# backward time 0.004745 sec
# optimizer time 0.002191 sec
# training time in round 453 cost 0.3733639717102051 sec
# loss 0.428475, train acc 0.842511
# round 454
# time to device 0.012948 sec
# time forward 3.968259 sec
# loss time 0.000480 sec
# backward time 0.003997 sec
# optimizer time 0.002200 sec
# training time in round 454 cost 0.41887998580932617 sec
# loss 0.428372, train acc 0.842548
# round 455
# time to device 0.008452 sec
# time forward 3.975260 sec
# loss time 0.000678 sec
# backward time 0.006642 sec
# optimizer time 0.002907 sec
# training time in round 455 cost 0.37966203689575195 sec
# loss 0.428611, train acc 0.842414
# round 456
# time to device 0.009114 sec
# time forward 3.990106 sec
# loss time 0.002600 sec
# backward time 0.017846 sec
# optimizer time 0.004539 sec
# training time in round 456 cost 0.44052600860595703 sec
# loss 0.428540, train acc 0.842365
# round 457
# time to device 0.014527 sec
# time forward 4.005151 sec
# loss time 0.001251 sec
# backward time 0.015049 sec
# optimizer time 0.004102 sec
# training time in round 457 cost 0.4351978302001953 sec
# loss 0.428629, train acc 0.842232
# round 458
# time to device 0.009214 sec
# time forward 4.021265 sec
# loss time 0.001797 sec
# backward time 0.014870 sec
# optimizer time 0.003557 sec
# training time in round 458 cost 0.41206884384155273 sec
# loss 0.428346, train acc 0.842405
# round 459
# time to device 0.009165 sec
# time forward 4.034702 sec
# loss time 0.001291 sec
# backward time 0.013372 sec
# optimizer time 0.004962 sec
# training time in round 459 cost 0.37978601455688477 sec
# loss 0.428363, train acc 0.842408
# round 460
# time to device 0.007264 sec
# time forward 4.049503 sec
# loss time 0.001086 sec
# backward time 0.014355 sec
# optimizer time 0.003996 sec
# training time in round 460 cost 0.45273900032043457 sec
# loss 0.428456, train acc 0.842411
# round 461
# time to device 0.006926 sec
# time forward 4.063963 sec
# loss time 0.001232 sec
# backward time 0.014029 sec
# optimizer time 0.005067 sec
# training time in round 461 cost 0.3999180793762207 sec
# loss 0.428070, train acc 0.842566
# round 462
# time to device 0.008009 sec
# time forward 4.082934 sec
# loss time 0.001606 sec
# backward time 0.015237 sec
# optimizer time 0.006162 sec
# training time in round 462 cost 0.4116179943084717 sec
# loss 0.427929, train acc 0.842603
# round 463
# time to device 0.008150 sec
# time forward 4.096315 sec
# loss time 0.001634 sec
# backward time 0.015289 sec
# optimizer time 0.005828 sec
# training time in round 463 cost 0.3974590301513672 sec
# loss 0.428114, train acc 0.842588
# round 464
# time to device 0.006408 sec
# time forward 4.115577 sec
# loss time 0.001394 sec
# backward time 0.015294 sec
# optimizer time 0.005793 sec
# training time in round 464 cost 0.4107630252838135 sec
# loss 0.427872, train acc 0.842675
# round 465
# time to device 0.006740 sec
# time forward 4.130142 sec
# loss time 0.001366 sec
# backward time 0.009912 sec
# optimizer time 0.002042 sec
# training time in round 465 cost 0.38337016105651855 sec
# loss 0.427863, train acc 0.842560
# round 466
# time to device 0.004015 sec
# time forward 4.147936 sec
# loss time 0.001456 sec
# backward time 0.014692 sec
# optimizer time 0.006863 sec
# training time in round 466 cost 0.3925771713256836 sec
# loss 0.427864, train acc 0.842512
# round 467
# time to device 0.003872 sec
# time forward 4.167080 sec
# loss time 0.002181 sec
# backward time 0.015702 sec
# optimizer time 0.006244 sec
# training time in round 467 cost 0.3999321460723877 sec
# loss 0.427738, train acc 0.842515
# round 468
# time to device 0.002236 sec
# time forward 4.190096 sec
# loss time 0.002079 sec
# backward time 0.017630 sec
# optimizer time 0.003547 sec
# training time in round 468 cost 0.3864169120788574 sec
# loss 0.427877, train acc 0.842450
# test acc is 0.850000
# epoch 4, time 1936.197223 sec

# %%
import os

working_dir = os.getcwd()
print(working_dir)

# get the parent directory
parent_dir = os.path.dirname(working_dir)
print(parent_dir)

# get the data directory
data_dir = os.path.join(parent_dir, 'data/5epochs')
print(data_dir)
# Out:
# /Users/dtjgp/Learning/Thesis/GreenAI/M1chip/Third_part/FL_code
# /Users/dtjgp/Learning/Thesis/GreenAI/M1chip/Third_part
# /Users/dtjgp/Learning/Thesis/GreenAI/M1chip/Third_part/data/5epochs

# %%
# save the parameters in the data directory
data_dir_selected = os.path.join(data_dir, 'net1')
torch.save(net, os.path.join(data_dir_selected,'net_alexnet.pth'))
torch.save(net.state_dict(), os.path.join(data_dir_selected, 'net_state_dict_alexnet.pth'))

# %%
# timeenergy_data_forward

# %%
# timeenergy_data_round

# %%
# acc_data

# %%
# train_l

# %%
# train_acc

# %%
# time_data_epoch

# %%
# energy_data_epoch

# %%
# import os
# working_dir = os.getcwd()
# working_dir

# %%
# # find the second_part folder
info_dir = os.path.join(data_dir_selected, 'info')
print(info_dir)
# Out:
# /Users/dtjgp/Learning/Thesis/GreenAI/M1chip/Third_part/data/5epochs/net1/info

# %%
# save the data as .npy file
np.save(os.path.join(info_dir, 'timeenergy_data_forward.npy'), timeenergy_data_forward)
np.save(os.path.join(info_dir, 'timeenergy_data_round.npy'), timeenergy_data_round)
np.save(os.path.join(info_dir, 'acc_data.npy'), acc_data)
np.save(os.path.join(info_dir, 'train_acc.npy'), train_acc)
np.save(os.path.join(info_dir, 'train_l.npy'), train_l)
np.save(os.path.join(info_dir, 'time_data_epoch.npy'), time_data_epoch)
np.save(os.path.join(info_dir, 'energy_data_epoch.npy'), energy_data_epoch)
