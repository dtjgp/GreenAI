# %% [markdown]
# # This code is to gather the information of the energy consumption of the whole training process of different models.

# %% [markdown]
# ## import the required libraries

# %%
import torch
from torch import nn
from torch.nn import functional as F
import torchvision
import torchvision.transforms as transforms
from d2l import torch as d2l
import numpy as np
import pandas as pd
from ptflops import get_model_complexity_info
from pathlib import Path
import os
import time
import pynvml
import threading
import queue# type: ignore
from torch.cuda.amp import GradScaler

os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

# %% [markdown]
# ## find the path

# %%
'''find the Model path'''
# find the current path
from pathlib import Path

# find the current path
current_path = Path.cwd()
print('The current path is:', current_path)

# find the data path
data_path = Path(current_path / 'ModelsData')
print('The data path is:', data_path)
# Out:
# The current path is: /home/zzq/Projects/GreenAI/4070
# The data path is: /home/zzq/Projects/GreenAI/4070/ModelsData

# %% [markdown]
# ## Models

# %% [markdown]
# ### generate the data paths

# %%
models_name = ['alexnet', 
               'vgg11', 'vgg13', 'vgg16', 
               'resnet18', 'resnet34', 'resnet50',
               'googlenet_origin', 'googlenet_mod1', 'googlenet_mod2', 'googlenet_mod3',
               'googlenet_mod4', 'googlenet_mod5', 'googlenet_mod6', 'googlenet_mod7', 
               'googlenet_mod8', 'googlenet_mod9',
               'mobilenetv1', 'mobilenetv2']

# %%
DataList = [Path(f"{data_path}/{i}") for i in models_name]
print(DataList)
# Out:
# [PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/alexnet'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/vgg11'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/vgg13'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/vgg16'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/resnet18'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/resnet34'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/resnet50'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/googlenet_origin'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/googlenet_mod1'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/googlenet_mod2'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/googlenet_mod3'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/googlenet_mod4'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/googlenet_mod5'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/googlenet_mod6'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/googlenet_mod7'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/googlenet_mod8'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/googlenet_mod9'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/mobilenetv1'), PosixPath('/home/zzq/Projects/GreenAI/4070/ModelsData/mobilenetv2')]

# %% [markdown]
# ### create the models

# %% [markdown]
# #### AlexNet Model

# %%
def alexnet(img_channel, num_labels):
    net = nn.Sequential(
        # 这里使用一个11*11的更大窗口来捕捉对象。
        # 同时，步幅为4，以减少输出的高度和宽度。
        # 另外，输出通道的数目远大于LeNet
        nn.Conv2d(img_channel, 64, kernel_size=11, stride=4, padding=2), nn.ReLU(),
        nn.MaxPool2d(kernel_size=3, stride=2),
        # 减小卷积窗口，使用填充为2来使得输入与输出的高和宽一致，且增大输出通道数
        nn.Conv2d(64, 192, kernel_size=5, padding=2), nn.ReLU(),
        nn.MaxPool2d(kernel_size=3, stride=2),
        # 使用三个连续的卷积层和较小的卷积窗口。
        # 除了最后的卷积层，输出通道的数量进一步增加。
        # 在前两个卷积层之后，汇聚层不用于减少输入的高度和宽度
        nn.Conv2d(192, 384, kernel_size=3, padding=1), nn.ReLU(),
        nn.Conv2d(384, 256, kernel_size=3, padding=1), nn.ReLU(),
        nn.Conv2d(256, 256, kernel_size=3, padding=1), nn.ReLU(),
        nn.MaxPool2d(kernel_size=3, stride=2),
        nn.AdaptiveAvgPool2d((6, 6)),   # 使用全局平均池化对每个通道中所有元素求平均并直接将结果传递到全连接层
        nn.Flatten(),
        # 这里，全连接层的输出数量是LeNet中的好几倍。使用dropout层来减轻过拟合
        nn.Linear(256 * 6 * 6, 4096), nn.ReLU(),
        nn.Dropout(p=0.5),
        nn.Linear(4096, 4096), nn.ReLU(),
        nn.Dropout(p=0.5),
        # 最后是输出层。由于这里使用Fashion-MNIST，所以用类别数为10，而非论文中的1000
        nn.Linear(4096, num_labels))
    return net

# %% [markdown]
# #### VGG Models

# %% [markdown]
# ##### VGG11 Model

# %%
def vgg11_block(num_convs, in_channels, out_channels):
    layers = []
    for _ in range(num_convs):
        layers.append(nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1))
        layers.append(nn.ReLU())
        in_channels = out_channels
    layers.append(nn.MaxPool2d(kernel_size=2, stride=2))
    return nn.Sequential(*layers)

def vgg11(input_channels, output_channels):
    conv_arch = [(1, 64), (1, 128), (2, 256), (2, 512), (2, 512)]
    conv_arch = [(1, 64), (1, 128), (2, 256), (2, 512), (2, 512)]
    in_channels = input_channels  # For RGB images
    # Create convolutional layers
    conv_layers = []
    for num_convs, out_channels in conv_arch:
        conv_layers.append(vgg11_block(num_convs, in_channels, out_channels))
        in_channels = out_channels

    return nn.Sequential(
        *conv_layers, nn.Flatten(),
        nn.Linear(out_channels * 7 * 7, 4096), nn.ReLU(), nn.Dropout(0.5),
        nn.Linear(4096, 4096), nn.ReLU(), nn.Dropout(0.5),
        nn.Linear(4096, output_channels)  # Output layer for 1000 classes
    )

# %% [markdown]
# ##### VGG13 Model

# %%
def vgg13_block(num_convs, in_channels, out_channels):
    layers = []
    for _ in range(num_convs):
        layers.append(nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1))
        layers.append(nn.ReLU())
        in_channels = out_channels
    layers.append(nn.MaxPool2d(kernel_size=2, stride=2))
    return nn.Sequential(*layers)

def vgg13(input_channels, output_channels):
    # VGG-13 architecture
    conv_arch = [(2, 64), (2, 128), (2, 256), (2, 512), (2, 512)]
    in_channels = input_channels  # For RGB images
    # Create convolutional layers
    conv_layers = []
    for num_convs, out_channels in conv_arch:
        conv_layers.append(vgg13_block(num_convs, in_channels, out_channels))
        in_channels = out_channels

    return nn.Sequential(
        *conv_layers, nn.Flatten(),
        nn.Linear(out_channels * 7 * 7, 4096), nn.ReLU(), nn.Dropout(0.5),
        nn.Linear(4096, 4096), nn.ReLU(), nn.Dropout(0.5),
        nn.Linear(4096, output_channels)  # Output layer for 1000 classes
    )

# %% [markdown]
# ##### VGG16 Model

# %%
def vgg16_block(num_convs, in_channels, out_channels):
    layers = []
    for _ in range(num_convs):
        layers.append(nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1))
        layers.append(nn.ReLU())
        in_channels = out_channels
    layers.append(nn.MaxPool2d(kernel_size=2, stride=2))
    return nn.Sequential(*layers)

def vgg16(input_channels, output_channels):
    conv_arch = [(2, 64), (2, 128), (3, 256), (3, 512), (3, 512)]
    in_channels = input_channels  # For RGB images
    # Create convolutional layers
    conv_layers = []
    for num_convs, out_channels in conv_arch:
        conv_layers.append(vgg16_block(num_convs, in_channels, out_channels))
        in_channels = out_channels

    return nn.Sequential(
        *conv_layers, nn.Flatten(),
        nn.Linear(out_channels * 7 * 7, 4096), nn.ReLU(), nn.Dropout(0.5),
        nn.Linear(4096, 4096), nn.ReLU(), nn.Dropout(0.5),
        nn.Linear(4096, output_channels)  # Output layer for 1000 classes
    )

# %% [markdown]
# #### ResNet Models

# %% [markdown]
# ##### ResNet18 Model

# %%
class Residual18(nn.Module):  #@save
    def __init__(self, input_channels, num_channels,
                 use_1x1conv=False, strides=1):
        super().__init__()
        self.conv1 = nn.Conv2d(input_channels, num_channels,
                               kernel_size=3, padding=1, stride=strides)
        self.conv2 = nn.Conv2d(num_channels, num_channels,
                               kernel_size=3, padding=1)
        if use_1x1conv:
            self.conv3 = nn.Conv2d(input_channels, num_channels,
                                   kernel_size=1, stride=strides)
        else:
            self.conv3 = None
        self.bn1 = nn.BatchNorm2d(num_channels)
        self.bn2 = nn.BatchNorm2d(num_channels)

    def forward(self, X):
        Y = F.relu(self.bn1(self.conv1(X)))
        Y = self.bn2(self.conv2(Y))
        if self.conv3:
            X = self.conv3(X)
        Y += X
        return F.relu(Y)
    
    
def resnet18(img_channel, num_labels):
    # blk = Residual(3,6, use_1x1conv=True, strides=2)

    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                    nn.BatchNorm2d(64), nn.ReLU(),
                    nn.MaxPool2d(kernel_size=3, stride=2, padding=1))

    def resnet_block(input_channels, num_channels, num_residuals,
                    first_block=False):
        blk = []
        for i in range(num_residuals):
            if i == 0 and not first_block:
                blk.append(Residual18(input_channels, num_channels,
                                    use_1x1conv=True, strides=2))
            else:
                blk.append(Residual18(num_channels, num_channels))
        return blk

    b2 = nn.Sequential(*resnet_block(64, 64, 2, first_block=True))
    b3 = nn.Sequential(*resnet_block(64, 128, 2))
    b4 = nn.Sequential(*resnet_block(128, 256, 2))
    b5 = nn.Sequential(*resnet_block(256, 512, 2))

    net = nn.Sequential(b1, b2, b3, b4, b5,
                        nn.AdaptiveAvgPool2d((1,1)),
                        nn.Flatten(), nn.Linear(512, num_labels))
    return net

# %% [markdown]
# ##### ResNet34 Model

# %%
class Residual34(nn.Module):  #@save
    def __init__(self, input_channels, num_channels,
                 use_1x1conv=False, strides=1):
        super().__init__()
        self.conv1 = nn.Conv2d(input_channels, num_channels,
                               kernel_size=3, padding=1, stride=strides)
        self.conv2 = nn.Conv2d(num_channels, num_channels,
                               kernel_size=3, padding=1)
        if use_1x1conv:
            self.conv3 = nn.Conv2d(input_channels, num_channels,
                                   kernel_size=1, stride=strides)
        else:
            self.conv3 = None
        self.bn1 = nn.BatchNorm2d(num_channels)
        self.bn2 = nn.BatchNorm2d(num_channels)

    def forward(self, X):
        Y = F.relu(self.bn1(self.conv1(X)))
        Y = self.bn2(self.conv2(Y))
        if self.conv3:
            X = self.conv3(X)
        Y += X
        return F.relu(Y)
    
    
def resnet34(img_channel, num_labels):
    # blk = Residual(3,6, use_1x1conv=True, strides=2)

    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                    nn.BatchNorm2d(64), nn.ReLU(),
                    nn.MaxPool2d(kernel_size=3, stride=2, padding=1))

    def resnet_block(input_channels, num_channels, num_residuals,
                    first_block=False):
        blk = []
        for i in range(num_residuals):
            if i == 0 and not first_block:
                blk.append(Residual34(input_channels, num_channels,
                                    use_1x1conv=True, strides=2))
            else:
                blk.append(Residual34(num_channels, num_channels))
        return blk

    b2 = nn.Sequential(*resnet_block(64, 64, 3, first_block=True))
    b3 = nn.Sequential(*resnet_block(64, 128, 4))
    b4 = nn.Sequential(*resnet_block(128, 256, 6))
    b5 = nn.Sequential(*resnet_block(256, 512, 3))

    net = nn.Sequential(b1, b2, b3, b4, b5,
                        nn.AdaptiveAvgPool2d((1,1)),
                        nn.Flatten(), nn.Linear(512, num_labels))
    return net

# %% [markdown]
# ##### ResNet50 Model

# %%
class Residual50(nn.Module):
    def __init__(self, input_channels, num_channels, use_1x1conv=False, strides=1):
        super().__init__()
        self.conv1 = nn.Conv2d(input_channels, num_channels , kernel_size=1, stride=strides, bias=False)
        self.bn1 = nn.BatchNorm2d(num_channels )
        self.conv2 = nn.Conv2d(num_channels , num_channels , kernel_size=3, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(num_channels )
        self.conv3 = nn.Conv2d(num_channels , num_channels, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(num_channels)
        
        if use_1x1conv or strides != 1:
            self.downsample = nn.Sequential(
                nn.Conv2d(input_channels, num_channels, kernel_size=1, stride=strides, bias=False),
                nn.BatchNorm2d(num_channels)
            )
        else:
            self.downsample = None

    def forward(self, X):
        Y = F.relu(self.bn1(self.conv1(X)))
        Y = F.relu(self.bn2(self.conv2(Y)))
        Y = self.bn3(self.conv3(Y))
        if self.downsample:
            X = self.downsample(X)
        Y += X
        return F.relu(Y)

def resnet50(img_channel, num_labels):
    b1 = nn.Sequential(
        nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
        nn.BatchNorm2d(64), nn.ReLU(),
        nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
    )

    def resnet_block(input_channels, num_channels, num_residuals, first_block=False):
        blk = []
        for i in range(num_residuals):
            if i == 0 and not first_block:
                blk.append(Residual50(input_channels, num_channels, use_1x1conv=True, strides=2))
            else:
                blk.append(Residual50(num_channels, num_channels))
        return blk

    b2 = nn.Sequential(*resnet_block(64, 64, 3, first_block=True))
    b3 = nn.Sequential(*resnet_block(64, 128, 4))
    b4 = nn.Sequential(*resnet_block(128, 256, 6))
    b5 = nn.Sequential(*resnet_block(256, 512, 3))

    net = nn.Sequential(
        b1, b2, b3, b4, b5,
        nn.AdaptiveAvgPool2d((1, 1)),
        nn.Flatten(), nn.Linear(512, num_labels)
    )
    return net

# %% [markdown]
# #### GoogleNet Models

# %% [markdown]
# ##### GoogleNet Model(orinigal)

# %%
class Inception(nn.Module):
    # c1--c4是每条路径的输出通道数
    def __init__(self, in_channels, c1, c2, c3, c4, **kwargs):
        super(Inception, self).__init__(**kwargs)
        # 线路1，单1x1卷积层
        self.p1_1 = nn.Conv2d(in_channels, c1, kernel_size=1)
        # 线路2，1x1卷积层后接3x3卷积层
        self.p2_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.p2_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
        # 线路3，1x1卷积层后接5x5卷积层
        self.p3_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        self.p3_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 线路4，3x3最大汇聚层后接1x1卷积层
        self.p4_1 = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        self.p4_2 = nn.Conv2d(in_channels, c4, kernel_size=1)

    def forward(self, x):
        p1 = F.relu(self.p1_1(x))
        p2 = F.relu(self.p2_2(F.relu(self.p2_1(x))))
        p3 = F.relu(self.p3_2(F.relu(self.p3_1(x))))
        p4 = F.relu(self.p4_2(self.p4_1(x)))
        # 在通道维度上连结输出
        return torch.cat((p1, p2, p3, p4), dim=1)
    
def Googlenet(img_channel, num_labels):
    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b2 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=1),
                   nn.ReLU(),
                   nn.Conv2d(64, 192, kernel_size=3, padding=1),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b3 = nn.Sequential(Inception(192, 64, (96, 128), (16, 32), 32),
                   Inception(256, 128, (128, 192), (32, 96), 64),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b4 = nn.Sequential(Inception(480, 192, (96, 208), (16, 48), 64),
                   Inception(512, 160, (112, 224), (24, 64), 64),
                   Inception(512, 128, (128, 256), (24, 64), 64),
                   Inception(512, 112, (144, 288), (32, 64), 64),
                   Inception(528, 256, (160, 320), (32, 128), 128),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b5 = nn.Sequential(Inception(832, 256, (160, 320), (32, 128), 128),
                   Inception(832, 384, (192, 384), (48, 128), 128),
                   nn.AdaptiveAvgPool2d((1,1)),
                   nn.Flatten())

    net = nn.Sequential(b1, b2, b3, b4, b5, nn.Linear(1024, num_labels))
    return net

# %% [markdown]
# ##### GoogleNet modified version1 Model

# %%
class Inception_mod1(nn.Module):
    # c1--c4是每条路径的输出通道数
    def __init__(self, in_channels, c1, c2, c3, c4, **kwargs):
        super(Inception_mod1, self).__init__(**kwargs)
        # 线路1，单1x1卷积层
        # self.p1_1 = nn.Conv2d(in_channels, c1, kernel_size=1)
        # 线路2，1x1卷积层后接3x3卷积层
        self.p2_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.p2_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
        # 线路3，1x1卷积层后接5x5卷积层
        self.p3_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        self.p3_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 线路4，3x3最大汇聚层后接1x1卷积层
        self.p4_1 = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        self.p4_2 = nn.Conv2d(in_channels, c4, kernel_size=1)

    def forward(self, x):
        # p1 = F.relu(self.p1_1(x))
        p2 = F.relu(self.p2_2(F.relu(self.p2_1(x))))
        p3 = F.relu(self.p3_2(F.relu(self.p3_1(x))))
        p4 = F.relu(self.p4_2(self.p4_1(x)))
        # 在通道维度上连结输出
        return torch.cat((p2, p3, p4), dim=1)
    
def Googlenet_mod1(img_channel, num_labels):
    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b2 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=1),
                   nn.ReLU(),
                   nn.Conv2d(64, 192, kernel_size=3, padding=1),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b3 = nn.Sequential(Inception_mod1(192, 64, (96, 128), (16, 32), 32),
                   Inception_mod1(256-64, 128, (128, 192), (32, 96), 64),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b4 = nn.Sequential(Inception_mod1(480-128, 192, (96, 208), (16, 48), 64),
                   Inception_mod1(512-192, 160, (112, 224), (24, 64), 64),
                   Inception_mod1(512-160, 128, (128, 256), (24, 64), 64),
                   Inception_mod1(512-128, 112, (144, 288), (32, 64), 64),
                   Inception_mod1(528-112, 256, (160, 320), (32, 128), 128),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b5 = nn.Sequential(Inception_mod1(832-256, 256, (160, 320), (32, 128), 128),
                   Inception_mod1(832-256, 384, (192, 384), (48, 128), 128),
                   nn.AdaptiveAvgPool2d((1,1)),
                   nn.Flatten())

    net = nn.Sequential(b1, b2, b3, b4, b5, nn.Linear(1024-384, num_labels))
    return net

# %% [markdown]
# ##### GoogleNet modified version2 Model

# %%
class Inception_mod2(nn.Module):
    # c1--c4是每条路径的输出通道数
    def __init__(self, in_channels, c1, c2, c3, c4, **kwargs):
        super(Inception_mod2, self).__init__(**kwargs)
        # 线路1，单1x1卷积层
        self.p1_1 = nn.Conv2d(in_channels, c1, kernel_size=1)
        # 线路2，1x1卷积层后接3x3卷积层
        self.p2_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.p2_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
        # 线路3，1x1卷积层后接5x5卷积层
        self.p3_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        self.p3_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 线路4，3x3最大汇聚层后接1x1卷积层
        self.p4_1 = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        self.p4_2 = nn.Conv2d(in_channels, c4, kernel_size=1)

    def forward(self, x):
        p1 = F.relu(self.p1_1(x))
        # p2 = F.relu(self.p2_2(F.relu(self.p2_1(x))))
        p3 = F.relu(self.p3_2(F.relu(self.p3_1(x))))
        p4 = F.relu(self.p4_2(self.p4_1(x)))
        # 在通道维度上连结输出
        return torch.cat((p1, p3, p4), dim=1)
    
def Googlenet_mod2(img_channel, num_labels):
    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b2 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=1),
                   nn.ReLU(),
                   nn.Conv2d(64, 192, kernel_size=3, padding=1),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b3 = nn.Sequential(Inception_mod2(192, 64, (96, 128), (16, 32), 32),
                   Inception_mod2(256-128, 128, (128, 192), (32, 96), 64),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b4 = nn.Sequential(Inception_mod2(480-192, 192, (96, 208), (16, 48), 64),
                   Inception_mod2(512-208, 160, (112, 224), (24, 64), 64),
                   Inception_mod2(512-224, 128, (128, 256), (24, 64), 64),
                   Inception_mod2(512-256, 112, (144, 288), (32, 64), 64),
                   Inception_mod2(528-288, 256, (160, 320), (32, 128), 128),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b5 = nn.Sequential(Inception_mod2(832-320, 256, (160, 320), (32, 128), 128),
                   Inception_mod2(832-320, 384, (192, 384), (48, 128), 128),
                   nn.AdaptiveAvgPool2d((1,1)),
                   nn.Flatten())

    net = nn.Sequential(b1, b2, b3, b4, b5, nn.Linear(1024-384, num_labels))
    return net

# %% [markdown]
# ##### GoogleNet modified version3 Model

# %%
class Inception_mod3(nn.Module):
    # c1--c4是每条路径的输出通道数
    def __init__(self, in_channels, c1, c2, c3, c4, **kwargs):
        super(Inception_mod3, self).__init__(**kwargs)
        # 线路1，单1x1卷积层
        self.p1_1 = nn.Conv2d(in_channels, c1, kernel_size=1)
        # 线路2，1x1卷积层后接3x3卷积层
        self.p2_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.p2_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
        # 线路3，1x1卷积层后接5x5卷积层
        # self.p3_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        # self.p3_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 线路4，3x3最大汇聚层后接1x1卷积层
        self.p4_1 = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        self.p4_2 = nn.Conv2d(in_channels, c4, kernel_size=1)

    def forward(self, x):
        p1 = F.relu(self.p1_1(x))
        p2 = F.relu(self.p2_2(F.relu(self.p2_1(x))))
        # p3 = F.relu(self.p3_2(F.relu(self.p3_1(x))))
        p4 = F.relu(self.p4_2(self.p4_1(x)))
        # 在通道维度上连结输出
        return torch.cat((p1, p2, p4), dim=1)
    
def Googlenet_mod3(img_channel, num_labels):
    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b2 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=1),
                   nn.ReLU(),
                   nn.Conv2d(64, 192, kernel_size=3, padding=1),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b3 = nn.Sequential(Inception_mod3(192, 64, (96, 128), (16, 32), 32),
                   Inception_mod3(256-32, 128, (128, 192), (32, 96), 64),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b4 = nn.Sequential(Inception_mod3(480-96, 192, (96, 208), (16, 48), 64),
                   Inception_mod3(512-48, 160, (112, 224), (24, 64), 64),
                   Inception_mod3(512-64, 128, (128, 256), (24, 64), 64),
                   Inception_mod3(512-64, 112, (144, 288), (32, 64), 64),
                   Inception_mod3(528-64, 256, (160, 320), (32, 128), 128),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b5 = nn.Sequential(Inception_mod3(832-128, 256, (160, 320), (32, 128), 128),
                   Inception_mod3(832-128, 384, (192, 384), (48, 128), 128),
                   nn.AdaptiveAvgPool2d((1,1)),
                   nn.Flatten())

    net = nn.Sequential(b1, b2, b3, b4, b5, nn.Linear(1024-128, num_labels))
    return net

# %% [markdown]
# ##### GoogleNet modified version4 Model

# %%
class Inception_mod4(nn.Module):
    # c1--c4是每条路径的输出通道数
    def __init__(self, in_channels, c1, c2, c3, c4, **kwargs):
        super(Inception_mod4, self).__init__(**kwargs)
        # 线路1，单1x1卷积层
        self.p1_1 = nn.Conv2d(in_channels, c1, kernel_size=1)
        # 线路2，1x1卷积层后接3x3卷积层
        self.p2_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.p2_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
        # 线路3，1x1卷积层后接5x5卷积层
        self.p3_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        self.p3_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 线路4，3x3最大汇聚层后接1x1卷积层
        # self.p4_1 = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        # self.p4_2 = nn.Conv2d(in_channels, c4, kernel_size=1)

    def forward(self, x):
        p1 = F.relu(self.p1_1(x))
        p2 = F.relu(self.p2_2(F.relu(self.p2_1(x))))
        p3 = F.relu(self.p3_2(F.relu(self.p3_1(x))))
        # p4 = F.relu(self.p4_2(self.p4_1(x)))
        # 在通道维度上连结输出
        return torch.cat((p1, p2, p3), dim=1)
    
def Googlenet_mod4(img_channel, num_labels):
    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b2 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=1),
                   nn.ReLU(),
                   nn.Conv2d(64, 192, kernel_size=3, padding=1),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b3 = nn.Sequential(Inception_mod4(192, 64, (96, 128), (16, 32), 32),
                   Inception_mod4(256-32, 128, (128, 192), (32, 96), 64),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b4 = nn.Sequential(Inception_mod4(480-64, 192, (96, 208), (16, 48), 64),
                   Inception_mod4(512-64, 160, (112, 224), (24, 64), 64),
                   Inception_mod4(512-64, 128, (128, 256), (24, 64), 64),
                   Inception_mod4(512-64, 112, (144, 288), (32, 64), 64),
                   Inception_mod4(528-64, 256, (160, 320), (32, 128), 128),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b5 = nn.Sequential(Inception_mod4(832-128, 256, (160, 320), (32, 128), 128),
                   Inception_mod4(832-128, 384, (192, 384), (48, 128), 128),
                   nn.AdaptiveAvgPool2d((1,1)),
                   nn.Flatten())

    net = nn.Sequential(b1, b2, b3, b4, b5, nn.Linear(1024-128, num_labels))
    return net

# %% [markdown]
# ##### GoogleNet modified version5 Model

# %%
class Inception_mod5(nn.Module):
    # c1--c4是每条路径的输出通道数
    def __init__(self, in_channels, c2, **kwargs):
        super(Inception_mod5, self).__init__(**kwargs)
        # 线路1，单1x1卷积层
        # self.p1_1 = nn.Conv2d(in_channels, c1, kernel_size=1)
        # 线路2，1x1卷积层后接3x3卷积层
        self.p2_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.p2_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
        # 线路3，1x1卷积层后接5x5卷积层
        # self.p3_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        # self.p3_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 线路4，3x3最大汇聚层后接1x1卷积层
        # self.p4_1 = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        # self.p4_2 = nn.Conv2d(in_channels, c4, kernel_size=1)

    def forward(self, x):
        # p1 = F.relu(self.p1_1(x))
        p2 = F.relu(self.p2_2(F.relu(self.p2_1(x))))
        # p3 = F.relu(self.p3_2(F.relu(self.p3_1(x))))
        # p4 = F.relu(self.p4_2(self.p4_1(x)))
        # 在通道维度上连结输出
        return torch.cat([p2], dim=1)
    
def Googlenet_mod5(img_channel, num_labels):
    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b2 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=1),
                   nn.ReLU(),
                   nn.Conv2d(64, 192, kernel_size=3, padding=1),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b3 = nn.Sequential(Inception_mod5(192, (96, 128)),
                   Inception_mod5(128, (128, 192)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b4 = nn.Sequential(Inception_mod5(192, (96, 208)),
                   Inception_mod5(208, (112, 224)),
                   Inception_mod5(224, (128, 256)),
                   Inception_mod5(256, (144, 288)),
                   Inception_mod5(288, (160, 320)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b5 = nn.Sequential(Inception_mod5(320, (160, 320)),
                   Inception_mod5(320, (192, 384)),
                   nn.AdaptiveAvgPool2d((1,1)),
                   nn.Flatten())

    net = nn.Sequential(b1, b2, b3, b4, b5, nn.Linear(384, num_labels))
    return net

# %% [markdown]
# ##### GoogleNet modified version6 Model

# %%
class Inception_mod6(nn.Module):
    # c1--c4是每条路径的输出通道数
    def __init__(self, in_channels, c2, **kwargs):
        super(Inception_mod6, self).__init__(**kwargs)
        # 线路1，单1x1卷积层
        # self.p1_1 = nn.Conv2d(in_channels, c1, kernel_size=1)
        # 线路2，1x1卷积层后接3x3卷积层
        self.p2_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.p2_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
        # 线路3，1x1卷积层后接5x5卷积层
        self.p3_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.p3_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
        # 线路4，3x3最大汇聚层后接1x1卷积层
        # self.p4_1 = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        # self.p4_2 = nn.Conv2d(in_channels, c4, kernel_size=1)

    def forward(self, x):
        # p1 = F.relu(self.p1_1(x))
        p2 = F.relu(self.p2_2(F.relu(self.p2_1(x))))
        p3 = F.relu(self.p3_2(F.relu(self.p3_1(x))))
        # p4 = F.relu(self.p4_2(self.p4_1(x)))
        # 在通道维度上连结输出
        return torch.cat((p2, p3), dim=1)
    
def Googlenet_mod6(img_channel, num_labels):
    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b2 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=1),
                   nn.ReLU(),
                   nn.Conv2d(64, 192, kernel_size=3, padding=1),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b3 = nn.Sequential(Inception_mod6(192, (96, 128)),
                   Inception_mod6(128*2, (128, 192)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b4 = nn.Sequential(Inception_mod6(192*2, (96, 208)),
                   Inception_mod6(208*2, (112, 224)),
                   Inception_mod6(224*2, (128, 256)),
                   Inception_mod6(256*2, (144, 288)),
                   Inception_mod6(288*2, (160, 320)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b5 = nn.Sequential(Inception_mod6(320*2, (160, 320)),
                   Inception_mod6(320*2, (192, 384)),
                   nn.AdaptiveAvgPool2d((1,1)),
                   nn.Flatten())

    net = nn.Sequential(b1, b2, b3, b4, b5, nn.Linear(384*2, num_labels))
    return net

# %% [markdown]
# ##### GoogleNet modified version7 Model

# %%
class Inception_mod7(nn.Module):
    # c1--c4是每条路径的输出通道数
    def __init__(self, in_channels, c2, **kwargs):
        super(Inception_mod7, self).__init__(**kwargs)
        # 线路1，单1x1卷积层
        # self.p1_1 = nn.Conv2d(in_channels, c1, kernel_size=1)
        # 线路2，1x1卷积层后接3x3卷积层
        self.p2_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.p2_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
        # 线路3，1x1卷积层后接5x5卷积层
        self.p3_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.p3_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
        # 线路4，3x3最大汇聚层后接1x1卷积层
        self.p4_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.p4_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)

    def forward(self, x):
        # p1 = F.relu(self.p1_1(x))
        p2 = F.relu(self.p2_2(F.relu(self.p2_1(x))))
        p3 = F.relu(self.p3_2(F.relu(self.p3_1(x))))
        p4 = F.relu(self.p4_2(F.relu(self.p4_1(x))))
        # 在通道维度上连结输出
        return torch.cat((p2, p3, p4), dim=1)
    
def Googlenet_mod7(img_channel, num_labels):
    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b2 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=1),
                   nn.ReLU(),
                   nn.Conv2d(64, 192, kernel_size=3, padding=1),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b3 = nn.Sequential(Inception_mod7(192, (96, 128)),
                   Inception_mod7(128*3, (128, 192)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b4 = nn.Sequential(Inception_mod7(192*3, (96, 208)),
                   Inception_mod7(208*3, (112, 224)),
                   Inception_mod7(224*3, (128, 256)),
                   Inception_mod7(256*3, (144, 288)),
                   Inception_mod7(288*3, (160, 320)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b5 = nn.Sequential(Inception_mod7(320*3, (160, 320)),
                   Inception_mod7(320*3, (192, 384)),
                   nn.AdaptiveAvgPool2d((1,1)),
                   nn.Flatten())

    net = nn.Sequential(b1, b2, b3, b4, b5, nn.Linear(384*3, num_labels))
    return net

# %% [markdown]
# ##### GoogleNet modified version8 Model

# %%
class Inception_mod8(nn.Module):
    # c1--c4是每条路径的输出通道数
    def __init__(self, in_channels, c2, **kwargs):
        super(Inception_mod8, self).__init__(**kwargs)
        # 线路1，单1x1卷积层
        self.p1_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.p1_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
        # 线路2，1x1卷积层后接3x3卷积层
        self.p2_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.p2_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
        # 线路3，1x1卷积层后接5x5卷积层
        self.p3_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.p3_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
        # 线路4，3x3最大汇聚层后接1x1卷积层
        self.p4_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.p4_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)

    def forward(self, x):
        p1 = F.relu(self.p1_2(F.relu(self.p1_1(x))))
        p2 = F.relu(self.p2_2(F.relu(self.p2_1(x))))
        p3 = F.relu(self.p3_2(F.relu(self.p3_1(x))))
        p4 = F.relu(self.p4_2(F.relu(self.p4_1(x))))
        # 在通道维度上连结输出
        return torch.cat((p1, p2, p3, p4), dim=1)
    
def Googlenet_mod8(img_channel, num_labels):
    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b2 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=1),
                   nn.ReLU(),
                   nn.Conv2d(64, 192, kernel_size=3, padding=1),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b3 = nn.Sequential(Inception_mod8(192, (96, 128)),
                   Inception_mod8(128*4, (128, 192)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b4 = nn.Sequential(Inception_mod8(192*4, (96, 208)),
                   Inception_mod8(208*4, (112, 224)),
                   Inception_mod8(224*4, (128, 256)),
                   Inception_mod8(256*4, (144, 288)),
                   Inception_mod8(288*4, (160, 320)),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b5 = nn.Sequential(Inception_mod8(320*4, (160, 320)),
                   Inception_mod8(320*4, (192, 384)),
                   nn.AdaptiveAvgPool2d((1,1)),
                   nn.Flatten())

    net = nn.Sequential(b1, b2, b3, b4, b5, nn.Linear(384*4, num_labels))
    return net

# %% [markdown]
# ##### GoogleNet modified version9 Model

# %%
# class Inception_mod8(nn.Module):
#     # c1--c4是每条路径的输出通道数
#     def __init__(self, in_channels, c2, **kwargs):
#         super(Inception_mod8, self).__init__(**kwargs)
#         # 线路1，单1x1卷积层
#         self.p1_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
#         self.p1_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
#         # 线路2，1x1卷积层后接3x3卷积层
#         self.p2_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
#         self.p2_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
#         # 线路3，1x1卷积层后接5x5卷积层
#         self.p3_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
#         self.p3_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
#         # 线路4，3x3最大汇聚层后接1x1卷积层
#         self.p4_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
#         self.p4_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)

#     def forward(self, x):
#         p1 = F.relu(self.p1_2(F.relu(self.p1_1(x))))
#         p2 = F.relu(self.p2_2(F.relu(self.p2_1(x))))
#         p3 = F.relu(self.p3_2(F.relu(self.p3_1(x))))
#         p4 = F.relu(self.p4_2(F.relu(self.p4_1(x))))
#         # 在通道维度上连结输出
#         return torch.cat((p1, p2, p3, p4), dim=1)
    
def Googlenet_mod9(img_channel, num_labels):
    b1 = nn.Sequential(nn.Conv2d(img_channel, 64, kernel_size=7, stride=2, padding=3),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    b2 = nn.Sequential(nn.Conv2d(64, 64, kernel_size=1),
                   nn.ReLU(),
                   nn.Conv2d(64, 192, kernel_size=3, padding=1),
                   nn.ReLU(),
                   nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    # b3 = nn.Sequential(Inception_mod8(192, (96, 128)),
    #                Inception_mod8(128*4, (128, 192)),
    #                nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    # b4 = nn.Sequential(Inception_mod8(192*4, (96, 208)),
    #                Inception_mod8(208*4, (112, 224)),
    #                Inception_mod8(224*4, (128, 256)),
    #                Inception_mod8(256*4, (144, 288)),
    #                Inception_mod8(288*4, (160, 320)),
    #                nn.MaxPool2d(kernel_size=3, stride=2, padding=1))
    
    # b5 = nn.Sequential(Inception_mod8(320*4, (160, 320)),
    #                Inception_mod8(320*4, (192, 384)),
    #                nn.AdaptiveAvgPool2d((1,1)),
    #                nn.Flatten())
    
    b5 = nn.Sequential(
                   nn.AdaptiveAvgPool2d((1,1)),
                   nn.Flatten())

    net = nn.Sequential(b1, b2, b5, nn.Linear(192, num_labels))
    return net

# %% [markdown]
# #### MobileNet Models

# %% [markdown]
# ##### MobileNetV1 Model

# %%
class DepthwiseSeparableConv(nn.Module):
    def __init__(self, in_channels, out_channels, stride):
        super(DepthwiseSeparableConv, self).__init__()
        self.depthwise = nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=stride, padding=1, groups=in_channels)
        self.pointwise = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        x = self.depthwise(x)
        x = self.pointwise(x)
        return x

class MobileNet(nn.Module):
    def __init__(self, input_channels, output_channels):
        super(MobileNet, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(input_channels, 32, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),

            DepthwiseSeparableConv(32, 64, 1),
            DepthwiseSeparableConv(64, 128, 2),
            DepthwiseSeparableConv(128, 128, 1),
            DepthwiseSeparableConv(128, 256, 2),
            DepthwiseSeparableConv(256, 256, 1),
            DepthwiseSeparableConv(256, 512, 2),

            # Typically, 5 Depthwise Separable Convolutions are repeated here, each with stride 1
            *[DepthwiseSeparableConv(512, 512, 1) for _ in range(5)],

            DepthwiseSeparableConv(512, 1024, 2),
            DepthwiseSeparableConv(1024, 1024, 1),

            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(1024, output_channels)
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ##### MobileNetV2 Model

# %%
class InvertedResidual(nn.Module):
    def __init__(self, in_channels, out_channels, stride, expand_ratio):
        super(InvertedResidual, self).__init__()
        self.stride = stride
        hidden_dim = in_channels * expand_ratio
        self.use_residual = self.stride == 1 and in_channels == out_channels

        self.layers = nn.Sequential(
            # expand
            nn.Conv2d(in_channels, hidden_dim, 1, 1, 0, bias=False),
            nn.BatchNorm2d(hidden_dim),
            nn.ReLU6(inplace=True),

            # depthwise
            nn.Conv2d(hidden_dim, hidden_dim, 3, stride, 1, groups=hidden_dim, bias=False),
            nn.BatchNorm2d(hidden_dim),
            nn.ReLU6(inplace=True),

            # project
            nn.Conv2d(hidden_dim, out_channels, 1, 1, 0, bias=False),
            nn.BatchNorm2d(out_channels)
        )

    def forward(self, x):
        if self.use_residual:
            return x + self.layers(x)
        else:
            return self.layers(x)

class MobileNetV2(nn.Module):
    def __init__(self, input_channels, output_channels):
        super(MobileNetV2, self).__init__()
        self.first_layer = nn.Sequential(
            nn.Conv2d(input_channels, 32, 3, 2, 1, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU6(inplace=True)
        )

        self.inverted_residual_blocks = nn.Sequential(
            InvertedResidual(32, 16, 1, 1),
            InvertedResidual(16, 24, 2, 6),
            InvertedResidual(24, 24, 1, 6),
            InvertedResidual(24, 32, 2, 6),
            InvertedResidual(32, 32, 1, 6),
            InvertedResidual(32, 32, 1, 6),
            InvertedResidual(32, 64, 2, 6),
            InvertedResidual(64, 64, 1, 6),
            InvertedResidual(64, 64, 1, 6),
            InvertedResidual(64, 64, 1, 6),
            InvertedResidual(64, 96, 1, 6),
            InvertedResidual(96, 96, 1, 6),
            InvertedResidual(96, 96, 1, 6),
            InvertedResidual(96, 160, 2, 6),
            InvertedResidual(160, 160, 1, 6),
            InvertedResidual(160, 160, 1, 6),
            InvertedResidual(160, 320, 1, 6)
        )

        self.last_layers = nn.Sequential(
            nn.Conv2d(320, 1280, 1, 1, 0, bias=False),
            nn.BatchNorm2d(1280),
            nn.ReLU6(inplace=True),
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(1280, output_channels)
        )

    def forward(self, x):
        x = self.first_layer(x)
        x = self.inverted_residual_blocks(x)
        x = self.last_layers(x)
        return x

# %% [markdown]
# ## Call the Models

# %% [markdown]
# ### usea function to call the models

# %%
# create a function for all the models to run
# image channel for fashion mnist 
channel_f = 1
# image channel for cifar100 and cifar10
channel_c = 3

# number of labels for fashion mnist
num_labels_f = 10
# number of labels for cifar100 
num_labels_c100 = 100
# number of labels for cifar10
num_labels_c10 = 10

def get_model_info(model, img_channel, num_labels):
    net = model(img_channel, num_labels)
    with torch.cuda.device(0):
        macs, params = get_model_complexity_info(net, (img_channel, 224, 224), as_strings=True,
                                                print_per_layer_stat=True, verbose=True)
        print('{:<30}  {:<8}'.format('Computational complexity: ', macs))
        print('{:<30}  {:<8}'.format('Number of parameters: ', params))
    return net, macs, params

# %% [markdown]
# ### ALEXNET

# %%
alexnet_f, macs_alexnet_f, paras_alexnet_f = get_model_info(alexnet, channel_f, num_labels_f)
print('-'*50)
alexnet_c100, macs_alexnet_c100, paras_alexnet_c100 = get_model_info(alexnet, channel_c, num_labels_c100)
print('-'*50)
alexnet_c10, macs_alexnet_c10, paras_alexnet_c10 = get_model_info(alexnet, channel_c, num_labels_c10)
# Out:
# Warning: module Flatten is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Sequential(
#   57.03 M, 100.000% Params, 664.65 MMac, 99.868% MACs,
#   (0): Conv2d(7.81 k, 0.014% Params, 23.62 MMac, 3.549% MACs, 1, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#   (1): ReLU(0, 0.000% Params, 193.6 KMac, 0.029% MACs, )
#   (2): MaxPool2d(0, 0.000% Params, 193.6 KMac, 0.029% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): Conv2d(307.39 k, 0.539% Params, 224.09 MMac, 33.671% MACs, 64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (4): ReLU(0, 0.000% Params, 139.97 KMac, 0.021% MACs, )
#   (5): MaxPool2d(0, 0.000% Params, 139.97 KMac, 0.021% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (6): Conv2d(663.94 k, 1.164% Params, 112.21 MMac, 16.859% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU(0, 0.000% Params, 64.9 KMac, 0.010% MACs, )
#   (8): Conv2d(884.99 k, 1.552% Params, 149.56 MMac, 22.473% MACs, 384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU(0, 0.000% Params, 43.26 KMac, 0.007% MACs, )
#   (10): Conv2d(590.08 k, 1.035% Params, 99.72 MMac, 14.984% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(0, 0.000% Params, 43.26 KMac, 0.007% MACs, )
#   (12): MaxPool2d(0, 0.000% Params, 43.26 KMac, 0.007% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (13): AdaptiveAvgPool2d(0, 0.000% Params, 9.22 KMac, 0.001% MACs, output_size=(6, 6))
#   (14): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (15): Linear(37.75 M, 66.199% Params, 37.75 MMac, 5.673% MACs, in_features=9216, out_features=4096, bias=True)
#   (16): ReLU(0, 0.000% Params, 4.1 KMac, 0.001% MACs, )
#   (17): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (18): Linear(16.78 M, 29.426% Params, 16.78 MMac, 2.521% MACs, in_features=4096, out_features=4096, bias=True)
#   (19): ReLU(0, 0.000% Params, 4.1 KMac, 0.001% MACs, )
#   (20): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (21): Linear(40.97 k, 0.072% Params, 40.97 KMac, 0.006% MACs, in_features=4096, out_features=10, bias=True)
# )
# Computational complexity:       665.53 MMac
# Number of parameters:           57.03 M
# --------------------------------------------------
# Warning: module Flatten is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Sequential(
#   57.41 M, 100.000% Params, 711.87 MMac, 99.877% MACs,
#   (0): Conv2d(23.3 k, 0.041% Params, 70.47 MMac, 9.887% MACs, 3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#   (1): ReLU(0, 0.000% Params, 193.6 KMac, 0.027% MACs, )
#   (2): MaxPool2d(0, 0.000% Params, 193.6 KMac, 0.027% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): Conv2d(307.39 k, 0.535% Params, 224.09 MMac, 31.440% MACs, 64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (4): ReLU(0, 0.000% Params, 139.97 KMac, 0.020% MACs, )
#   (5): MaxPool2d(0, 0.000% Params, 139.97 KMac, 0.020% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (6): Conv2d(663.94 k, 1.156% Params, 112.21 MMac, 15.742% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU(0, 0.000% Params, 64.9 KMac, 0.009% MACs, )
#   (8): Conv2d(884.99 k, 1.541% Params, 149.56 MMac, 20.984% MACs, 384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU(0, 0.000% Params, 43.26 KMac, 0.006% MACs, )
#   (10): Conv2d(590.08 k, 1.028% Params, 99.72 MMac, 13.991% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(0, 0.000% Params, 43.26 KMac, 0.006% MACs, )
#   (12): MaxPool2d(0, 0.000% Params, 43.26 KMac, 0.006% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (13): AdaptiveAvgPool2d(0, 0.000% Params, 9.22 KMac, 0.001% MACs, output_size=(6, 6))
#   (14): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (15): Linear(37.75 M, 65.756% Params, 37.75 MMac, 5.297% MACs, in_features=9216, out_features=4096, bias=True)
#   (16): ReLU(0, 0.000% Params, 4.1 KMac, 0.001% MACs, )
#   (17): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (18): Linear(16.78 M, 29.229% Params, 16.78 MMac, 2.354% MACs, in_features=4096, out_features=4096, bias=True)
#   (19): ReLU(0, 0.000% Params, 4.1 KMac, 0.001% MACs, )
#   (20): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (21): Linear(409.7 k, 0.714% Params, 409.7 KMac, 0.057% MACs, in_features=4096, out_features=100, bias=True)
# )
# Computational complexity:       712.75 MMac
# Number of parameters:           57.41 M
# --------------------------------------------------
# Warning: module Flatten is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Sequential(
#   57.04 M, 100.000% Params, 711.51 MMac, 99.877% MACs,
#   (0): Conv2d(23.3 k, 0.041% Params, 70.47 MMac, 9.892% MACs, 3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#   (1): ReLU(0, 0.000% Params, 193.6 KMac, 0.027% MACs, )
#   (2): MaxPool2d(0, 0.000% Params, 193.6 KMac, 0.027% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): Conv2d(307.39 k, 0.539% Params, 224.09 MMac, 31.456% MACs, 64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (4): ReLU(0, 0.000% Params, 139.97 KMac, 0.020% MACs, )
#   (5): MaxPool2d(0, 0.000% Params, 139.97 KMac, 0.020% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (6): Conv2d(663.94 k, 1.164% Params, 112.21 MMac, 15.751% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU(0, 0.000% Params, 64.9 KMac, 0.009% MACs, )
#   (8): Conv2d(884.99 k, 1.551% Params, 149.56 MMac, 20.995% MACs, 384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU(0, 0.000% Params, 43.26 KMac, 0.006% MACs, )
#   (10): Conv2d(590.08 k, 1.034% Params, 99.72 MMac, 13.999% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(0, 0.000% Params, 43.26 KMac, 0.006% MACs, )
#   (12): MaxPool2d(0, 0.000% Params, 43.26 KMac, 0.006% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (13): AdaptiveAvgPool2d(0, 0.000% Params, 9.22 KMac, 0.001% MACs, output_size=(6, 6))
#   (14): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (15): Linear(37.75 M, 66.181% Params, 37.75 MMac, 5.299% MACs, in_features=9216, out_features=4096, bias=True)
#   (16): ReLU(0, 0.000% Params, 4.1 KMac, 0.001% MACs, )
#   (17): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (18): Linear(16.78 M, 29.418% Params, 16.78 MMac, 2.356% MACs, in_features=4096, out_features=4096, bias=True)
#   (19): ReLU(0, 0.000% Params, 4.1 KMac, 0.001% MACs, )
#   (20): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (21): Linear(40.97 k, 0.072% Params, 40.97 KMac, 0.006% MACs, in_features=4096, out_features=10, bias=True)
# )
# Computational complexity:       712.39 MMac
# Number of parameters:           57.04 M

# %% [markdown]
# ### ResNet

# %% [markdown]
# #### ResNet18

# %%
resnet18_f, macs_resnet18_f, paras_resnet18_f = get_model_info(resnet18, channel_f, num_labels_f)
print('-'*50)
resnet18_c100, macs_resnet18_c100, paras_resnet18_c100 = get_model_info(resnet18, channel_c, num_labels_c100)
print('-'*50)
resnet18_c10, macs_resnet18_c10, paras_resnet18_c10 = get_model_info(resnet18, channel_c, num_labels_c10)
# Out:
# Warning: module Residual18 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   11.18 M, 100.000% Params, 1.74 GMac, 99.820% MACs,
#   (0): Sequential(
#     3.33 k, 0.030% Params, 43.35 MMac, 2.482% MACs,
#     (0): Conv2d(3.2 k, 0.029% Params, 40.14 MMac, 2.298% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): BatchNorm2d(128, 0.001% Params, 1.61 MMac, 0.092% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0, 0.000% Params, 802.82 KMac, 0.046% MACs, )
#     (3): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.046% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     148.22 k, 1.326% Params, 464.83 MMac, 26.611% MACs,
#     (0): Residual18(
#       74.11 k, 0.663% Params, 232.42 MMac, 13.306% MACs,
#       (conv1): Conv2d(36.93 k, 0.330% Params, 115.81 MMac, 6.630% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(36.93 k, 0.330% Params, 115.81 MMac, 6.630% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.023% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.023% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual18(
#       74.11 k, 0.663% Params, 232.42 MMac, 13.306% MACs,
#       (conv1): Conv2d(36.93 k, 0.330% Params, 115.81 MMac, 6.630% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(36.93 k, 0.330% Params, 115.81 MMac, 6.630% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.023% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.023% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (2): Sequential(
#     525.95 k, 4.705% Params, 412.35 MMac, 23.606% MACs,
#     (0): Residual18(
#       230.27 k, 2.060% Params, 180.53 MMac, 10.335% MACs,
#       (conv1): Conv2d(73.86 k, 0.661% Params, 57.9 MMac, 3.315% MACs, 64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 1.320% Params, 115.71 MMac, 6.624% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(8.32 k, 0.074% Params, 6.52 MMac, 0.373% MACs, 64, 128, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual18(
#       295.68 k, 2.645% Params, 231.81 MMac, 13.271% MACs,
#       (conv1): Conv2d(147.58 k, 1.320% Params, 115.71 MMac, 6.624% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 1.320% Params, 115.71 MMac, 6.624% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (3): Sequential(
#     2.1 M, 18.791% Params, 411.69 MMac, 23.569% MACs,
#     (0): Residual18(
#       919.3 k, 8.224% Params, 180.18 MMac, 10.315% MACs,
#       (conv1): Conv2d(295.17 k, 2.641% Params, 57.85 MMac, 3.312% MACs, 128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 5.279% Params, 115.66 MMac, 6.621% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(33.02 k, 0.295% Params, 6.47 MMac, 0.371% MACs, 128, 256, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(512, 0.005% Params, 100.35 KMac, 0.006% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.005% Params, 100.35 KMac, 0.006% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual18(
#       1.18 M, 10.567% Params, 231.51 MMac, 13.254% MACs,
#       (conv1): Conv2d(590.08 k, 5.279% Params, 115.66 MMac, 6.621% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 5.279% Params, 115.66 MMac, 6.621% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.005% Params, 100.35 KMac, 0.006% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.005% Params, 100.35 KMac, 0.006% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (4): Sequential(
#     8.4 M, 75.103% Params, 411.37 MMac, 23.550% MACs,
#     (0): Residual18(
#       3.67 M, 32.863% Params, 180.01 MMac, 10.305% MACs,
#       (conv1): Conv2d(1.18 M, 10.558% Params, 57.83 MMac, 3.311% MACs, 256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(2.36 M, 21.110% Params, 115.63 MMac, 6.620% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(131.58 k, 1.177% Params, 6.45 MMac, 0.369% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual18(
#       4.72 M, 42.239% Params, 231.36 MMac, 13.245% MACs,
#       (conv1): Conv2d(2.36 M, 21.110% Params, 115.63 MMac, 6.620% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(2.36 M, 21.110% Params, 115.63 MMac, 6.620% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): AdaptiveAvgPool2d(0, 0.000% Params, 25.09 KMac, 0.001% MACs, output_size=(1, 1))
#   (6): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (7): Linear(5.13 k, 0.046% Params, 5.13 KMac, 0.000% MACs, in_features=512, out_features=10, bias=True)
# )
# Computational complexity:       1.75 GMac
# Number of parameters:           11.18 M
# --------------------------------------------------
# Warning: module Residual18 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   11.23 M, 100.000% Params, 1.82 GMac, 99.828% MACs,
#   (0): Sequential(
#     9.6 k, 0.085% Params, 122.03 MMac, 6.685% MACs,
#     (0): Conv2d(9.47 k, 0.084% Params, 118.82 MMac, 6.509% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): BatchNorm2d(128, 0.001% Params, 1.61 MMac, 0.088% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0, 0.000% Params, 802.82 KMac, 0.044% MACs, )
#     (3): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.044% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     148.22 k, 1.320% Params, 464.83 MMac, 25.463% MACs,
#     (0): Residual18(
#       74.11 k, 0.660% Params, 232.42 MMac, 12.732% MACs,
#       (conv1): Conv2d(36.93 k, 0.329% Params, 115.81 MMac, 6.344% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(36.93 k, 0.329% Params, 115.81 MMac, 6.344% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.022% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.022% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual18(
#       74.11 k, 0.660% Params, 232.42 MMac, 12.732% MACs,
#       (conv1): Conv2d(36.93 k, 0.329% Params, 115.81 MMac, 6.344% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(36.93 k, 0.329% Params, 115.81 MMac, 6.344% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.022% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.022% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (2): Sequential(
#     525.95 k, 4.683% Params, 412.35 MMac, 22.588% MACs,
#     (0): Residual18(
#       230.27 k, 2.050% Params, 180.53 MMac, 9.890% MACs,
#       (conv1): Conv2d(73.86 k, 0.658% Params, 57.9 MMac, 3.172% MACs, 64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 1.314% Params, 115.71 MMac, 6.338% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(8.32 k, 0.074% Params, 6.52 MMac, 0.357% MACs, 64, 128, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual18(
#       295.68 k, 2.633% Params, 231.81 MMac, 12.699% MACs,
#       (conv1): Conv2d(147.58 k, 1.314% Params, 115.71 MMac, 6.338% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 1.314% Params, 115.71 MMac, 6.338% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (3): Sequential(
#     2.1 M, 18.703% Params, 411.69 MMac, 22.553% MACs,
#     (0): Residual18(
#       919.3 k, 8.185% Params, 180.18 MMac, 9.870% MACs,
#       (conv1): Conv2d(295.17 k, 2.628% Params, 57.85 MMac, 3.169% MACs, 128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 5.254% Params, 115.66 MMac, 6.336% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(33.02 k, 0.294% Params, 6.47 MMac, 0.355% MACs, 128, 256, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(512, 0.005% Params, 100.35 KMac, 0.005% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.005% Params, 100.35 KMac, 0.005% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual18(
#       1.18 M, 10.517% Params, 231.51 MMac, 12.682% MACs,
#       (conv1): Conv2d(590.08 k, 5.254% Params, 115.66 MMac, 6.336% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 5.254% Params, 115.66 MMac, 6.336% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.005% Params, 100.35 KMac, 0.005% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.005% Params, 100.35 KMac, 0.005% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (4): Sequential(
#     8.4 M, 74.752% Params, 411.37 MMac, 22.535% MACs,
#     (0): Residual18(
#       3.67 M, 32.710% Params, 180.01 MMac, 9.861% MACs,
#       (conv1): Conv2d(1.18 M, 10.508% Params, 57.83 MMac, 3.168% MACs, 256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(2.36 M, 21.012% Params, 115.63 MMac, 6.334% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(131.58 k, 1.172% Params, 6.45 MMac, 0.353% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual18(
#       4.72 M, 42.042% Params, 231.36 MMac, 12.674% MACs,
#       (conv1): Conv2d(2.36 M, 21.012% Params, 115.63 MMac, 6.334% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(2.36 M, 21.012% Params, 115.63 MMac, 6.334% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): AdaptiveAvgPool2d(0, 0.000% Params, 25.09 KMac, 0.001% MACs, output_size=(1, 1))
#   (6): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (7): Linear(51.3 k, 0.457% Params, 51.3 KMac, 0.003% MACs, in_features=512, out_features=100, bias=True)
# )
# Computational complexity:       1.83 GMac
# Number of parameters:           11.23 M
# --------------------------------------------------
# Warning: module Residual18 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   11.18 M, 100.000% Params, 1.82 GMac, 99.828% MACs,
#   (0): Sequential(
#     9.6 k, 0.086% Params, 122.03 MMac, 6.685% MACs,
#     (0): Conv2d(9.47 k, 0.085% Params, 118.82 MMac, 6.509% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): BatchNorm2d(128, 0.001% Params, 1.61 MMac, 0.088% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0, 0.000% Params, 802.82 KMac, 0.044% MACs, )
#     (3): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.044% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     148.22 k, 1.325% Params, 464.83 MMac, 25.464% MACs,
#     (0): Residual18(
#       74.11 k, 0.663% Params, 232.42 MMac, 12.732% MACs,
#       (conv1): Conv2d(36.93 k, 0.330% Params, 115.81 MMac, 6.344% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(36.93 k, 0.330% Params, 115.81 MMac, 6.344% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.022% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.022% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual18(
#       74.11 k, 0.663% Params, 232.42 MMac, 12.732% MACs,
#       (conv1): Conv2d(36.93 k, 0.330% Params, 115.81 MMac, 6.344% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(36.93 k, 0.330% Params, 115.81 MMac, 6.344% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.022% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.022% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (2): Sequential(
#     525.95 k, 4.702% Params, 412.35 MMac, 22.589% MACs,
#     (0): Residual18(
#       230.27 k, 2.059% Params, 180.53 MMac, 9.890% MACs,
#       (conv1): Conv2d(73.86 k, 0.660% Params, 57.9 MMac, 3.172% MACs, 64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 1.320% Params, 115.71 MMac, 6.339% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(8.32 k, 0.074% Params, 6.52 MMac, 0.357% MACs, 64, 128, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual18(
#       295.68 k, 2.644% Params, 231.81 MMac, 12.699% MACs,
#       (conv1): Conv2d(147.58 k, 1.320% Params, 115.71 MMac, 6.339% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 1.320% Params, 115.71 MMac, 6.339% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (3): Sequential(
#     2.1 M, 18.780% Params, 411.69 MMac, 22.553% MACs,
#     (0): Residual18(
#       919.3 k, 8.219% Params, 180.18 MMac, 9.871% MACs,
#       (conv1): Conv2d(295.17 k, 2.639% Params, 57.85 MMac, 3.169% MACs, 128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 5.276% Params, 115.66 MMac, 6.336% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(33.02 k, 0.295% Params, 6.47 MMac, 0.355% MACs, 128, 256, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(512, 0.005% Params, 100.35 KMac, 0.005% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.005% Params, 100.35 KMac, 0.005% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual18(
#       1.18 M, 10.561% Params, 231.51 MMac, 12.683% MACs,
#       (conv1): Conv2d(590.08 k, 5.276% Params, 115.66 MMac, 6.336% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 5.276% Params, 115.66 MMac, 6.336% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.005% Params, 100.35 KMac, 0.005% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.005% Params, 100.35 KMac, 0.005% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (4): Sequential(
#     8.4 M, 75.061% Params, 411.37 MMac, 22.535% MACs,
#     (0): Residual18(
#       3.67 M, 32.845% Params, 180.01 MMac, 9.861% MACs,
#       (conv1): Conv2d(1.18 M, 10.552% Params, 57.83 MMac, 3.168% MACs, 256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(2.36 M, 21.099% Params, 115.63 MMac, 6.334% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(131.58 k, 1.176% Params, 6.45 MMac, 0.353% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual18(
#       4.72 M, 42.216% Params, 231.36 MMac, 12.674% MACs,
#       (conv1): Conv2d(2.36 M, 21.099% Params, 115.63 MMac, 6.334% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(2.36 M, 21.099% Params, 115.63 MMac, 6.334% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): AdaptiveAvgPool2d(0, 0.000% Params, 25.09 KMac, 0.001% MACs, output_size=(1, 1))
#   (6): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (7): Linear(5.13 k, 0.046% Params, 5.13 KMac, 0.000% MACs, in_features=512, out_features=10, bias=True)
# )
# Computational complexity:       1.83 GMac
# Number of parameters:           11.18 M

# %% [markdown]
# #### ResNet34

# %%
resnet34_f, macs_resnet34_f, paras_resnet34_f = get_model_info(resnet34, channel_f, num_labels_f)
print('-'*50)
resnet34_c100, macs_resnet34_c100, paras_resnet34_c100 = get_model_info(resnet34, channel_c, num_labels_c100)
print('-'*50)
resnet34_c10, macs_resnet34_c10, paras_resnet34_c10 = get_model_info(resnet34, channel_c, num_labels_c10)
# Out:
# Warning: module Residual34 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   21.29 M, 100.000% Params, 3.6 GMac, 99.878% MACs,
#   (0): Sequential(
#     3.33 k, 0.016% Params, 43.35 MMac, 1.204% MACs,
#     (0): Conv2d(3.2 k, 0.015% Params, 40.14 MMac, 1.115% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): BatchNorm2d(128, 0.001% Params, 1.61 MMac, 0.045% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0, 0.000% Params, 802.82 KMac, 0.022% MACs, )
#     (3): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.022% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     222.34 k, 1.044% Params, 697.25 MMac, 19.360% MACs,
#     (0): Residual34(
#       74.11 k, 0.348% Params, 232.42 MMac, 6.453% MACs,
#       (conv1): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.216% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.216% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual34(
#       74.11 k, 0.348% Params, 232.42 MMac, 6.453% MACs,
#       (conv1): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.216% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.216% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual34(
#       74.11 k, 0.348% Params, 232.42 MMac, 6.453% MACs,
#       (conv1): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.216% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.216% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (2): Sequential(
#     1.12 M, 5.248% Params, 875.97 MMac, 24.323% MACs,
#     (0): Residual34(
#       230.27 k, 1.082% Params, 180.53 MMac, 5.013% MACs,
#       (conv1): Conv2d(73.86 k, 0.347% Params, 57.9 MMac, 1.608% MACs, 64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 0.693% Params, 115.71 MMac, 3.213% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(8.32 k, 0.039% Params, 6.52 MMac, 0.181% MACs, 64, 128, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.006% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.006% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual34(
#       295.68 k, 1.389% Params, 231.81 MMac, 6.437% MACs,
#       (conv1): Conv2d(147.58 k, 0.693% Params, 115.71 MMac, 3.213% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 0.693% Params, 115.71 MMac, 3.213% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.006% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.006% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual34(
#       295.68 k, 1.389% Params, 231.81 MMac, 6.437% MACs,
#       (conv1): Conv2d(147.58 k, 0.693% Params, 115.71 MMac, 3.213% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 0.693% Params, 115.71 MMac, 3.213% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.006% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.006% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Residual34(
#       295.68 k, 1.389% Params, 231.81 MMac, 6.437% MACs,
#       (conv1): Conv2d(147.58 k, 0.693% Params, 115.71 MMac, 3.213% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 0.693% Params, 115.71 MMac, 3.213% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.006% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.006% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (3): Sequential(
#     6.83 M, 32.058% Params, 1.34 GMac, 37.144% MACs,
#     (0): Residual34(
#       919.3 k, 4.318% Params, 180.18 MMac, 5.003% MACs,
#       (conv1): Conv2d(295.17 k, 1.386% Params, 57.85 MMac, 1.606% MACs, 128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.772% Params, 115.66 MMac, 3.211% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(33.02 k, 0.155% Params, 6.47 MMac, 0.180% MACs, 128, 256, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual34(
#       1.18 M, 5.548% Params, 231.51 MMac, 6.428% MACs,
#       (conv1): Conv2d(590.08 k, 2.772% Params, 115.66 MMac, 3.211% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.772% Params, 115.66 MMac, 3.211% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual34(
#       1.18 M, 5.548% Params, 231.51 MMac, 6.428% MACs,
#       (conv1): Conv2d(590.08 k, 2.772% Params, 115.66 MMac, 3.211% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.772% Params, 115.66 MMac, 3.211% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Residual34(
#       1.18 M, 5.548% Params, 231.51 MMac, 6.428% MACs,
#       (conv1): Conv2d(590.08 k, 2.772% Params, 115.66 MMac, 3.211% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.772% Params, 115.66 MMac, 3.211% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): Residual34(
#       1.18 M, 5.548% Params, 231.51 MMac, 6.428% MACs,
#       (conv1): Conv2d(590.08 k, 2.772% Params, 115.66 MMac, 3.211% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.772% Params, 115.66 MMac, 3.211% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): Residual34(
#       1.18 M, 5.548% Params, 231.51 MMac, 6.428% MACs,
#       (conv1): Conv2d(590.08 k, 2.772% Params, 115.66 MMac, 3.211% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.772% Params, 115.66 MMac, 3.211% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (4): Sequential(
#     13.12 M, 61.610% Params, 642.73 MMac, 17.846% MACs,
#     (0): Residual34(
#       3.67 M, 17.255% Params, 180.01 MMac, 4.998% MACs,
#       (conv1): Conv2d(1.18 M, 5.543% Params, 57.83 MMac, 1.606% MACs, 256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(2.36 M, 11.084% Params, 115.63 MMac, 3.211% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(131.58 k, 0.618% Params, 6.45 MMac, 0.179% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual34(
#       4.72 M, 22.178% Params, 231.36 MMac, 6.424% MACs,
#       (conv1): Conv2d(2.36 M, 11.084% Params, 115.63 MMac, 3.211% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(2.36 M, 11.084% Params, 115.63 MMac, 3.211% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual34(
#       4.72 M, 22.178% Params, 231.36 MMac, 6.424% MACs,
#       (conv1): Conv2d(2.36 M, 11.084% Params, 115.63 MMac, 3.211% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(2.36 M, 11.084% Params, 115.63 MMac, 3.211% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): AdaptiveAvgPool2d(0, 0.000% Params, 25.09 KMac, 0.001% MACs, output_size=(1, 1))
#   (6): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (7): Linear(5.13 k, 0.024% Params, 5.13 KMac, 0.000% MACs, in_features=512, out_features=10, bias=True)
# )
# Computational complexity:       3.6 GMac
# Number of parameters:           21.29 M
# --------------------------------------------------
# Warning: module Residual34 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   21.34 M, 100.000% Params, 3.68 GMac, 99.881% MACs,
#   (0): Sequential(
#     9.6 k, 0.045% Params, 122.03 MMac, 3.316% MACs,
#     (0): Conv2d(9.47 k, 0.044% Params, 118.82 MMac, 3.229% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): BatchNorm2d(128, 0.001% Params, 1.61 MMac, 0.044% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0, 0.000% Params, 802.82 KMac, 0.022% MACs, )
#     (3): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.022% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     222.34 k, 1.042% Params, 697.25 MMac, 18.946% MACs,
#     (0): Residual34(
#       74.11 k, 0.347% Params, 232.42 MMac, 6.315% MACs,
#       (conv1): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.147% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.147% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual34(
#       74.11 k, 0.347% Params, 232.42 MMac, 6.315% MACs,
#       (conv1): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.147% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.147% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual34(
#       74.11 k, 0.347% Params, 232.42 MMac, 6.315% MACs,
#       (conv1): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.147% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.147% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (2): Sequential(
#     1.12 M, 5.235% Params, 875.97 MMac, 23.802% MACs,
#     (0): Residual34(
#       230.27 k, 1.079% Params, 180.53 MMac, 4.906% MACs,
#       (conv1): Conv2d(73.86 k, 0.346% Params, 57.9 MMac, 1.573% MACs, 64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 0.691% Params, 115.71 MMac, 3.144% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(8.32 k, 0.039% Params, 6.52 MMac, 0.177% MACs, 64, 128, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual34(
#       295.68 k, 1.385% Params, 231.81 MMac, 6.299% MACs,
#       (conv1): Conv2d(147.58 k, 0.691% Params, 115.71 MMac, 3.144% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 0.691% Params, 115.71 MMac, 3.144% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual34(
#       295.68 k, 1.385% Params, 231.81 MMac, 6.299% MACs,
#       (conv1): Conv2d(147.58 k, 0.691% Params, 115.71 MMac, 3.144% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 0.691% Params, 115.71 MMac, 3.144% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Residual34(
#       295.68 k, 1.385% Params, 231.81 MMac, 6.299% MACs,
#       (conv1): Conv2d(147.58 k, 0.691% Params, 115.71 MMac, 3.144% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 0.691% Params, 115.71 MMac, 3.144% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (3): Sequential(
#     6.83 M, 31.979% Params, 1.34 GMac, 36.350% MACs,
#     (0): Residual34(
#       919.3 k, 4.307% Params, 180.18 MMac, 4.896% MACs,
#       (conv1): Conv2d(295.17 k, 1.383% Params, 57.85 MMac, 1.572% MACs, 128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.765% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(33.02 k, 0.155% Params, 6.47 MMac, 0.176% MACs, 128, 256, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual34(
#       1.18 M, 5.534% Params, 231.51 MMac, 6.291% MACs,
#       (conv1): Conv2d(590.08 k, 2.765% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.765% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual34(
#       1.18 M, 5.534% Params, 231.51 MMac, 6.291% MACs,
#       (conv1): Conv2d(590.08 k, 2.765% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.765% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Residual34(
#       1.18 M, 5.534% Params, 231.51 MMac, 6.291% MACs,
#       (conv1): Conv2d(590.08 k, 2.765% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.765% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): Residual34(
#       1.18 M, 5.534% Params, 231.51 MMac, 6.291% MACs,
#       (conv1): Conv2d(590.08 k, 2.765% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.765% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): Residual34(
#       1.18 M, 5.534% Params, 231.51 MMac, 6.291% MACs,
#       (conv1): Conv2d(590.08 k, 2.765% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.765% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (4): Sequential(
#     13.12 M, 61.459% Params, 642.73 MMac, 17.465% MACs,
#     (0): Residual34(
#       3.67 M, 17.212% Params, 180.01 MMac, 4.891% MACs,
#       (conv1): Conv2d(1.18 M, 5.530% Params, 57.83 MMac, 1.571% MACs, 256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(2.36 M, 11.057% Params, 115.63 MMac, 3.142% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(131.58 k, 0.617% Params, 6.45 MMac, 0.175% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual34(
#       4.72 M, 22.123% Params, 231.36 MMac, 6.287% MACs,
#       (conv1): Conv2d(2.36 M, 11.057% Params, 115.63 MMac, 3.142% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(2.36 M, 11.057% Params, 115.63 MMac, 3.142% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual34(
#       4.72 M, 22.123% Params, 231.36 MMac, 6.287% MACs,
#       (conv1): Conv2d(2.36 M, 11.057% Params, 115.63 MMac, 3.142% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(2.36 M, 11.057% Params, 115.63 MMac, 3.142% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): AdaptiveAvgPool2d(0, 0.000% Params, 25.09 KMac, 0.001% MACs, output_size=(1, 1))
#   (6): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (7): Linear(51.3 k, 0.240% Params, 51.3 KMac, 0.001% MACs, in_features=512, out_features=100, bias=True)
# )
# Computational complexity:       3.68 GMac
# Number of parameters:           21.34 M
# --------------------------------------------------
# Warning: module Residual34 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   21.3 M, 100.000% Params, 3.68 GMac, 99.881% MACs,
#   (0): Sequential(
#     9.6 k, 0.045% Params, 122.03 MMac, 3.316% MACs,
#     (0): Conv2d(9.47 k, 0.044% Params, 118.82 MMac, 3.229% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): BatchNorm2d(128, 0.001% Params, 1.61 MMac, 0.044% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0, 0.000% Params, 802.82 KMac, 0.022% MACs, )
#     (3): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.022% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     222.34 k, 1.044% Params, 697.25 MMac, 18.946% MACs,
#     (0): Residual34(
#       74.11 k, 0.348% Params, 232.42 MMac, 6.315% MACs,
#       (conv1): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.147% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.147% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual34(
#       74.11 k, 0.348% Params, 232.42 MMac, 6.315% MACs,
#       (conv1): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.147% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.147% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual34(
#       74.11 k, 0.348% Params, 232.42 MMac, 6.315% MACs,
#       (conv1): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.147% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(36.93 k, 0.173% Params, 115.81 MMac, 3.147% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.011% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (2): Sequential(
#     1.12 M, 5.246% Params, 875.97 MMac, 23.803% MACs,
#     (0): Residual34(
#       230.27 k, 1.081% Params, 180.53 MMac, 4.906% MACs,
#       (conv1): Conv2d(73.86 k, 0.347% Params, 57.9 MMac, 1.573% MACs, 64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 0.693% Params, 115.71 MMac, 3.144% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(8.32 k, 0.039% Params, 6.52 MMac, 0.177% MACs, 64, 128, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual34(
#       295.68 k, 1.388% Params, 231.81 MMac, 6.299% MACs,
#       (conv1): Conv2d(147.58 k, 0.693% Params, 115.71 MMac, 3.144% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 0.693% Params, 115.71 MMac, 3.144% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual34(
#       295.68 k, 1.388% Params, 231.81 MMac, 6.299% MACs,
#       (conv1): Conv2d(147.58 k, 0.693% Params, 115.71 MMac, 3.144% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 0.693% Params, 115.71 MMac, 3.144% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Residual34(
#       295.68 k, 1.388% Params, 231.81 MMac, 6.299% MACs,
#       (conv1): Conv2d(147.58 k, 0.693% Params, 115.71 MMac, 3.144% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(147.58 k, 0.693% Params, 115.71 MMac, 3.144% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (3): Sequential(
#     6.83 M, 32.049% Params, 1.34 GMac, 36.350% MACs,
#     (0): Residual34(
#       919.3 k, 4.317% Params, 180.18 MMac, 4.896% MACs,
#       (conv1): Conv2d(295.17 k, 1.386% Params, 57.85 MMac, 1.572% MACs, 128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.771% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(33.02 k, 0.155% Params, 6.47 MMac, 0.176% MACs, 128, 256, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual34(
#       1.18 M, 5.546% Params, 231.51 MMac, 6.291% MACs,
#       (conv1): Conv2d(590.08 k, 2.771% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.771% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual34(
#       1.18 M, 5.546% Params, 231.51 MMac, 6.291% MACs,
#       (conv1): Conv2d(590.08 k, 2.771% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.771% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Residual34(
#       1.18 M, 5.546% Params, 231.51 MMac, 6.291% MACs,
#       (conv1): Conv2d(590.08 k, 2.771% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.771% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): Residual34(
#       1.18 M, 5.546% Params, 231.51 MMac, 6.291% MACs,
#       (conv1): Conv2d(590.08 k, 2.771% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.771% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): Residual34(
#       1.18 M, 5.546% Params, 231.51 MMac, 6.291% MACs,
#       (conv1): Conv2d(590.08 k, 2.771% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(590.08 k, 2.771% Params, 115.66 MMac, 3.143% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (4): Sequential(
#     13.12 M, 61.592% Params, 642.73 MMac, 17.465% MACs,
#     (0): Residual34(
#       3.67 M, 17.250% Params, 180.01 MMac, 4.891% MACs,
#       (conv1): Conv2d(1.18 M, 5.542% Params, 57.83 MMac, 1.571% MACs, 256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (conv2): Conv2d(2.36 M, 11.081% Params, 115.63 MMac, 3.142% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv3): Conv2d(131.58 k, 0.618% Params, 6.45 MMac, 0.175% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2))
#       (bn1): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual34(
#       4.72 M, 22.171% Params, 231.36 MMac, 6.287% MACs,
#       (conv1): Conv2d(2.36 M, 11.081% Params, 115.63 MMac, 3.142% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(2.36 M, 11.081% Params, 115.63 MMac, 3.142% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual34(
#       4.72 M, 22.171% Params, 231.36 MMac, 6.287% MACs,
#       (conv1): Conv2d(2.36 M, 11.081% Params, 115.63 MMac, 3.142% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv2): Conv2d(2.36 M, 11.081% Params, 115.63 MMac, 3.142% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (bn1): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1.02 k, 0.005% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): AdaptiveAvgPool2d(0, 0.000% Params, 25.09 KMac, 0.001% MACs, output_size=(1, 1))
#   (6): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (7): Linear(5.13 k, 0.024% Params, 5.13 KMac, 0.000% MACs, in_features=512, out_features=10, bias=True)
# )
# Computational complexity:       3.68 GMac
# Number of parameters:           21.3 M

# %% [markdown]
# #### ResNet50

# %%
resnet50_f, macs_resnet50_f, paras_resnet50_f = get_model_info(resnet50, channel_f, num_labels_f)
print('-'*50)
resnet50_c100, macs_resnet50_c100, paras_resnet50_c100 = get_model_info(resnet50, channel_c, num_labels_c100)
print('-'*50)
resnet50_c10, macs_resnet50_c10, paras_resnet50_c10 = get_model_info(resnet50, channel_c, num_labels_c10)
# Out:
# Warning: module Residual50 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   13.87 M, 100.000% Params, 2.31 GMac, 99.751% MACs,
#   (0): Sequential(
#     3.33 k, 0.024% Params, 43.35 MMac, 1.870% MACs,
#     (0): Conv2d(3.2 k, 0.023% Params, 40.14 MMac, 1.731% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): BatchNorm2d(128, 0.001% Params, 1.61 MMac, 0.069% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0, 0.000% Params, 802.82 KMac, 0.035% MACs, )
#     (3): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.035% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     136.32 k, 0.983% Params, 427.5 MMac, 18.439% MACs,
#     (0): Residual50(
#       45.44 k, 0.328% Params, 142.5 MMac, 6.146% MACs,
#       (conv1): Conv2d(4.1 k, 0.030% Params, 12.85 MMac, 0.554% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36.86 k, 0.266% Params, 115.61 MMac, 4.986% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(4.1 k, 0.030% Params, 12.85 MMac, 0.554% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual50(
#       45.44 k, 0.328% Params, 142.5 MMac, 6.146% MACs,
#       (conv1): Conv2d(4.1 k, 0.030% Params, 12.85 MMac, 0.554% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36.86 k, 0.266% Params, 115.61 MMac, 4.986% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(4.1 k, 0.030% Params, 12.85 MMac, 0.554% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual50(
#       45.44 k, 0.328% Params, 142.5 MMac, 6.146% MACs,
#       (conv1): Conv2d(4.1 k, 0.030% Params, 12.85 MMac, 0.554% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36.86 k, 0.266% Params, 115.61 MMac, 4.986% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(4.1 k, 0.030% Params, 12.85 MMac, 0.554% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (2): Sequential(
#     724.22 k, 5.223% Params, 567.79 MMac, 24.489% MACs,
#     (0): Residual50(
#       181.25 k, 1.307% Params, 142.1 MMac, 6.129% MACs,
#       (conv1): Conv2d(8.19 k, 0.059% Params, 6.42 MMac, 0.277% MACs, 64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.009% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 1.064% Params, 115.61 MMac, 4.986% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.009% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.554% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.009% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         8.45 k, 0.061% Params, 6.62 MMac, 0.286% MACs,
#         (0): Conv2d(8.19 k, 0.059% Params, 6.42 MMac, 0.277% MACs, 64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.009% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Residual50(
#       180.99 k, 1.305% Params, 141.9 MMac, 6.120% MACs,
#       (conv1): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.554% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.009% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 1.064% Params, 115.61 MMac, 4.986% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.009% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.554% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.009% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual50(
#       180.99 k, 1.305% Params, 141.9 MMac, 6.120% MACs,
#       (conv1): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.554% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.009% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 1.064% Params, 115.61 MMac, 4.986% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.009% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.554% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.009% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Residual50(
#       180.99 k, 1.305% Params, 141.9 MMac, 6.120% MACs,
#       (conv1): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.554% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.009% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 1.064% Params, 115.61 MMac, 4.986% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.009% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.554% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.009% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (3): Sequential(
#     4.34 M, 31.266% Params, 849.68 MMac, 36.648% MACs,
#     (0): Residual50(
#       722.94 k, 5.214% Params, 141.7 MMac, 6.112% MACs,
#       (conv1): Conv2d(32.77 k, 0.236% Params, 6.42 MMac, 0.277% MACs, 128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.254% Params, 115.61 MMac, 4.986% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.473% Params, 12.85 MMac, 0.554% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         33.28 k, 0.240% Params, 6.52 MMac, 0.281% MACs,
#         (0): Conv2d(32.77 k, 0.236% Params, 6.42 MMac, 0.277% MACs, 128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Residual50(
#       722.43 k, 5.210% Params, 141.6 MMac, 6.107% MACs,
#       (conv1): Conv2d(65.54 k, 0.473% Params, 12.85 MMac, 0.554% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.254% Params, 115.61 MMac, 4.986% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.473% Params, 12.85 MMac, 0.554% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual50(
#       722.43 k, 5.210% Params, 141.6 MMac, 6.107% MACs,
#       (conv1): Conv2d(65.54 k, 0.473% Params, 12.85 MMac, 0.554% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.254% Params, 115.61 MMac, 4.986% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.473% Params, 12.85 MMac, 0.554% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Residual50(
#       722.43 k, 5.210% Params, 141.6 MMac, 6.107% MACs,
#       (conv1): Conv2d(65.54 k, 0.473% Params, 12.85 MMac, 0.554% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.254% Params, 115.61 MMac, 4.986% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.473% Params, 12.85 MMac, 0.554% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): Residual50(
#       722.43 k, 5.210% Params, 141.6 MMac, 6.107% MACs,
#       (conv1): Conv2d(65.54 k, 0.473% Params, 12.85 MMac, 0.554% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.254% Params, 115.61 MMac, 4.986% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.473% Params, 12.85 MMac, 0.554% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): Residual50(
#       722.43 k, 5.210% Params, 141.6 MMac, 6.107% MACs,
#       (conv1): Conv2d(65.54 k, 0.473% Params, 12.85 MMac, 0.554% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.254% Params, 115.61 MMac, 4.986% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.473% Params, 12.85 MMac, 0.554% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (4): Sequential(
#     8.66 M, 62.466% Params, 424.39 MMac, 18.304% MACs,
#     (0): Residual50(
#       2.89 M, 20.827% Params, 141.5 MMac, 6.103% MACs,
#       (conv1): Conv2d(131.07 k, 0.945% Params, 6.42 MMac, 0.277% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(2.36 M, 17.016% Params, 115.61 MMac, 4.986% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(262.14 k, 1.891% Params, 12.85 MMac, 0.554% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         132.1 k, 0.953% Params, 6.47 MMac, 0.279% MACs,
#         (0): Conv2d(131.07 k, 0.945% Params, 6.42 MMac, 0.277% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Residual50(
#       2.89 M, 20.820% Params, 141.45 MMac, 6.101% MACs,
#       (conv1): Conv2d(262.14 k, 1.891% Params, 12.85 MMac, 0.554% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(2.36 M, 17.016% Params, 115.61 MMac, 4.986% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(262.14 k, 1.891% Params, 12.85 MMac, 0.554% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual50(
#       2.89 M, 20.820% Params, 141.45 MMac, 6.101% MACs,
#       (conv1): Conv2d(262.14 k, 1.891% Params, 12.85 MMac, 0.554% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(2.36 M, 17.016% Params, 115.61 MMac, 4.986% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(262.14 k, 1.891% Params, 12.85 MMac, 0.554% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): AdaptiveAvgPool2d(0, 0.000% Params, 25.09 KMac, 0.001% MACs, output_size=(1, 1))
#   (6): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (7): Linear(5.13 k, 0.037% Params, 5.13 KMac, 0.000% MACs, in_features=512, out_features=10, bias=True)
# )
# Computational complexity:       2.32 GMac
# Number of parameters:           13.87 M
# --------------------------------------------------
# Warning: module Residual50 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   13.92 M, 100.000% Params, 2.39 GMac, 99.759% MACs,
#   (0): Sequential(
#     9.6 k, 0.069% Params, 122.03 MMac, 5.090% MACs,
#     (0): Conv2d(9.47 k, 0.068% Params, 118.82 MMac, 4.956% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): BatchNorm2d(128, 0.001% Params, 1.61 MMac, 0.067% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0, 0.000% Params, 802.82 KMac, 0.033% MACs, )
#     (3): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.033% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     136.32 k, 0.979% Params, 427.5 MMac, 17.833% MACs,
#     (0): Residual50(
#       45.44 k, 0.326% Params, 142.5 MMac, 5.944% MACs,
#       (conv1): Conv2d(4.1 k, 0.029% Params, 12.85 MMac, 0.536% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36.86 k, 0.265% Params, 115.61 MMac, 4.822% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(4.1 k, 0.029% Params, 12.85 MMac, 0.536% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual50(
#       45.44 k, 0.326% Params, 142.5 MMac, 5.944% MACs,
#       (conv1): Conv2d(4.1 k, 0.029% Params, 12.85 MMac, 0.536% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36.86 k, 0.265% Params, 115.61 MMac, 4.822% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(4.1 k, 0.029% Params, 12.85 MMac, 0.536% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual50(
#       45.44 k, 0.326% Params, 142.5 MMac, 5.944% MACs,
#       (conv1): Conv2d(4.1 k, 0.029% Params, 12.85 MMac, 0.536% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36.86 k, 0.265% Params, 115.61 MMac, 4.822% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(4.1 k, 0.029% Params, 12.85 MMac, 0.536% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (2): Sequential(
#     724.22 k, 5.204% Params, 567.79 MMac, 23.685% MACs,
#     (0): Residual50(
#       181.25 k, 1.302% Params, 142.1 MMac, 5.928% MACs,
#       (conv1): Conv2d(8.19 k, 0.059% Params, 6.42 MMac, 0.268% MACs, 64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 1.059% Params, 115.61 MMac, 4.822% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.536% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         8.45 k, 0.061% Params, 6.62 MMac, 0.276% MACs,
#         (0): Conv2d(8.19 k, 0.059% Params, 6.42 MMac, 0.268% MACs, 64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Residual50(
#       180.99 k, 1.300% Params, 141.9 MMac, 5.919% MACs,
#       (conv1): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.536% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 1.059% Params, 115.61 MMac, 4.822% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.536% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual50(
#       180.99 k, 1.300% Params, 141.9 MMac, 5.919% MACs,
#       (conv1): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.536% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 1.059% Params, 115.61 MMac, 4.822% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.536% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Residual50(
#       180.99 k, 1.300% Params, 141.9 MMac, 5.919% MACs,
#       (conv1): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.536% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 1.059% Params, 115.61 MMac, 4.822% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.536% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (3): Sequential(
#     4.34 M, 31.148% Params, 849.68 MMac, 35.444% MACs,
#     (0): Residual50(
#       722.94 k, 5.194% Params, 141.7 MMac, 5.911% MACs,
#       (conv1): Conv2d(32.77 k, 0.235% Params, 6.42 MMac, 0.268% MACs, 128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.238% Params, 115.61 MMac, 4.822% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.471% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         33.28 k, 0.239% Params, 6.52 MMac, 0.272% MACs,
#         (0): Conv2d(32.77 k, 0.235% Params, 6.42 MMac, 0.268% MACs, 128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Residual50(
#       722.43 k, 5.191% Params, 141.6 MMac, 5.907% MACs,
#       (conv1): Conv2d(65.54 k, 0.471% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.238% Params, 115.61 MMac, 4.822% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.471% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual50(
#       722.43 k, 5.191% Params, 141.6 MMac, 5.907% MACs,
#       (conv1): Conv2d(65.54 k, 0.471% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.238% Params, 115.61 MMac, 4.822% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.471% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Residual50(
#       722.43 k, 5.191% Params, 141.6 MMac, 5.907% MACs,
#       (conv1): Conv2d(65.54 k, 0.471% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.238% Params, 115.61 MMac, 4.822% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.471% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): Residual50(
#       722.43 k, 5.191% Params, 141.6 MMac, 5.907% MACs,
#       (conv1): Conv2d(65.54 k, 0.471% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.238% Params, 115.61 MMac, 4.822% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.471% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): Residual50(
#       722.43 k, 5.191% Params, 141.6 MMac, 5.907% MACs,
#       (conv1): Conv2d(65.54 k, 0.471% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.238% Params, 115.61 MMac, 4.822% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.471% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (4): Sequential(
#     8.66 M, 62.231% Params, 424.39 MMac, 17.703% MACs,
#     (0): Residual50(
#       2.89 M, 20.748% Params, 141.5 MMac, 5.902% MACs,
#       (conv1): Conv2d(131.07 k, 0.942% Params, 6.42 MMac, 0.268% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(2.36 M, 16.952% Params, 115.61 MMac, 4.822% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(262.14 k, 1.884% Params, 12.85 MMac, 0.536% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         132.1 k, 0.949% Params, 6.47 MMac, 0.270% MACs,
#         (0): Conv2d(131.07 k, 0.942% Params, 6.42 MMac, 0.268% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Residual50(
#       2.89 M, 20.741% Params, 141.45 MMac, 5.900% MACs,
#       (conv1): Conv2d(262.14 k, 1.884% Params, 12.85 MMac, 0.536% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(2.36 M, 16.952% Params, 115.61 MMac, 4.822% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(262.14 k, 1.884% Params, 12.85 MMac, 0.536% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual50(
#       2.89 M, 20.741% Params, 141.45 MMac, 5.900% MACs,
#       (conv1): Conv2d(262.14 k, 1.884% Params, 12.85 MMac, 0.536% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(2.36 M, 16.952% Params, 115.61 MMac, 4.822% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(262.14 k, 1.884% Params, 12.85 MMac, 0.536% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): AdaptiveAvgPool2d(0, 0.000% Params, 25.09 KMac, 0.001% MACs, output_size=(1, 1))
#   (6): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (7): Linear(51.3 k, 0.369% Params, 51.3 KMac, 0.002% MACs, in_features=512, out_features=100, bias=True)
# )
# Computational complexity:       2.4 GMac
# Number of parameters:           13.92 M
# --------------------------------------------------
# Warning: module Residual50 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   13.87 M, 100.000% Params, 2.39 GMac, 99.759% MACs,
#   (0): Sequential(
#     9.6 k, 0.069% Params, 122.03 MMac, 5.090% MACs,
#     (0): Conv2d(9.47 k, 0.068% Params, 118.82 MMac, 4.957% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): BatchNorm2d(128, 0.001% Params, 1.61 MMac, 0.067% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0, 0.000% Params, 802.82 KMac, 0.033% MACs, )
#     (3): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.033% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     136.32 k, 0.983% Params, 427.5 MMac, 17.833% MACs,
#     (0): Residual50(
#       45.44 k, 0.328% Params, 142.5 MMac, 5.944% MACs,
#       (conv1): Conv2d(4.1 k, 0.030% Params, 12.85 MMac, 0.536% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36.86 k, 0.266% Params, 115.61 MMac, 4.823% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(4.1 k, 0.030% Params, 12.85 MMac, 0.536% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Residual50(
#       45.44 k, 0.328% Params, 142.5 MMac, 5.944% MACs,
#       (conv1): Conv2d(4.1 k, 0.030% Params, 12.85 MMac, 0.536% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36.86 k, 0.266% Params, 115.61 MMac, 4.823% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(4.1 k, 0.030% Params, 12.85 MMac, 0.536% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual50(
#       45.44 k, 0.328% Params, 142.5 MMac, 5.944% MACs,
#       (conv1): Conv2d(4.1 k, 0.030% Params, 12.85 MMac, 0.536% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36.86 k, 0.266% Params, 115.61 MMac, 4.823% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(4.1 k, 0.030% Params, 12.85 MMac, 0.536% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.017% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (2): Sequential(
#     724.22 k, 5.221% Params, 567.79 MMac, 23.686% MACs,
#     (0): Residual50(
#       181.25 k, 1.307% Params, 142.1 MMac, 5.928% MACs,
#       (conv1): Conv2d(8.19 k, 0.059% Params, 6.42 MMac, 0.268% MACs, 64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 1.063% Params, 115.61 MMac, 4.823% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.536% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         8.45 k, 0.061% Params, 6.62 MMac, 0.276% MACs,
#         (0): Conv2d(8.19 k, 0.059% Params, 6.42 MMac, 0.268% MACs, 64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Residual50(
#       180.99 k, 1.305% Params, 141.9 MMac, 5.919% MACs,
#       (conv1): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.536% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 1.063% Params, 115.61 MMac, 4.823% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.536% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual50(
#       180.99 k, 1.305% Params, 141.9 MMac, 5.919% MACs,
#       (conv1): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.536% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 1.063% Params, 115.61 MMac, 4.823% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.536% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Residual50(
#       180.99 k, 1.305% Params, 141.9 MMac, 5.919% MACs,
#       (conv1): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.536% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 1.063% Params, 115.61 MMac, 4.823% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16.38 k, 0.118% Params, 12.85 MMac, 0.536% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.008% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (3): Sequential(
#     4.34 M, 31.252% Params, 849.68 MMac, 35.445% MACs,
#     (0): Residual50(
#       722.94 k, 5.212% Params, 141.7 MMac, 5.911% MACs,
#       (conv1): Conv2d(32.77 k, 0.236% Params, 6.42 MMac, 0.268% MACs, 128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.252% Params, 115.61 MMac, 4.823% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.472% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         33.28 k, 0.240% Params, 6.52 MMac, 0.272% MACs,
#         (0): Conv2d(32.77 k, 0.236% Params, 6.42 MMac, 0.268% MACs, 128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Residual50(
#       722.43 k, 5.208% Params, 141.6 MMac, 5.907% MACs,
#       (conv1): Conv2d(65.54 k, 0.472% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.252% Params, 115.61 MMac, 4.823% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.472% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual50(
#       722.43 k, 5.208% Params, 141.6 MMac, 5.907% MACs,
#       (conv1): Conv2d(65.54 k, 0.472% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.252% Params, 115.61 MMac, 4.823% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.472% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Residual50(
#       722.43 k, 5.208% Params, 141.6 MMac, 5.907% MACs,
#       (conv1): Conv2d(65.54 k, 0.472% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.252% Params, 115.61 MMac, 4.823% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.472% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): Residual50(
#       722.43 k, 5.208% Params, 141.6 MMac, 5.907% MACs,
#       (conv1): Conv2d(65.54 k, 0.472% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.252% Params, 115.61 MMac, 4.823% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.472% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): Residual50(
#       722.43 k, 5.208% Params, 141.6 MMac, 5.907% MACs,
#       (conv1): Conv2d(65.54 k, 0.472% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 4.252% Params, 115.61 MMac, 4.823% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.472% Params, 12.85 MMac, 0.536% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.004% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (4): Sequential(
#     8.66 M, 62.438% Params, 424.39 MMac, 17.704% MACs,
#     (0): Residual50(
#       2.89 M, 20.818% Params, 141.5 MMac, 5.903% MACs,
#       (conv1): Conv2d(131.07 k, 0.945% Params, 6.42 MMac, 0.268% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(2.36 M, 17.008% Params, 115.61 MMac, 4.823% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(262.14 k, 1.890% Params, 12.85 MMac, 0.536% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         132.1 k, 0.952% Params, 6.47 MMac, 0.270% MACs,
#         (0): Conv2d(131.07 k, 0.945% Params, 6.42 MMac, 0.268% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Residual50(
#       2.89 M, 20.810% Params, 141.45 MMac, 5.901% MACs,
#       (conv1): Conv2d(262.14 k, 1.890% Params, 12.85 MMac, 0.536% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(2.36 M, 17.008% Params, 115.61 MMac, 4.823% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(262.14 k, 1.890% Params, 12.85 MMac, 0.536% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Residual50(
#       2.89 M, 20.810% Params, 141.45 MMac, 5.901% MACs,
#       (conv1): Conv2d(262.14 k, 1.890% Params, 12.85 MMac, 0.536% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(2.36 M, 17.008% Params, 115.61 MMac, 4.823% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(262.14 k, 1.890% Params, 12.85 MMac, 0.536% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.007% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): AdaptiveAvgPool2d(0, 0.000% Params, 25.09 KMac, 0.001% MACs, output_size=(1, 1))
#   (6): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (7): Linear(5.13 k, 0.037% Params, 5.13 KMac, 0.000% MACs, in_features=512, out_features=10, bias=True)
# )
# Computational complexity:       2.4 GMac
# Number of parameters:           13.87 M

# %% [markdown]
# ### VGG

# %% [markdown]
# #### VGG11

# %%
vgg11_f, macs_vgg11_f, paras_vgg11_f = get_model_info(vgg11, channel_f, num_labels_f)
print('-'*50)
vgg11_c100, macs_vgg11_c100, paras_vgg11_c100 = get_model_info(vgg11, channel_c, num_labels_c100)
print('-'*50)
vgg11_c10, macs_vgg11_c10, paras_vgg11_c10 = get_model_info(vgg11, channel_c, num_labels_c10)
# Out:
# Warning: module Flatten is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Sequential(
#   128.81 M, 100.000% Params, 7.57 GMac, 99.821% MACs,
#   (0): Sequential(
#     640, 0.000% Params, 38.54 MMac, 0.508% MACs,
#     (0): Conv2d(640, 0.000% Params, 32.11 MMac, 0.424% MACs, 1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 3.21 MMac, 0.042% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 3.21 MMac, 0.042% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     73.86 k, 0.057% Params, 929.66 MMac, 12.262% MACs,
#     (0): Conv2d(73.86 k, 0.057% Params, 926.45 MMac, 12.219% MACs, 64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 1.61 MMac, 0.021% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 1.61 MMac, 0.021% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     885.25 k, 0.687% Params, 2.78 GMac, 36.648% MACs,
#     (0): Conv2d(295.17 k, 0.229% Params, 925.65 MMac, 12.209% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.011% MACs, )
#     (2): Conv2d(590.08 k, 0.458% Params, 1.85 GMac, 24.407% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 802.82 KMac, 0.011% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.011% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     3.54 M, 2.748% Params, 2.78 GMac, 36.621% MACs,
#     (0): Conv2d(1.18 M, 0.916% Params, 925.25 MMac, 12.204% MACs, 256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 401.41 KMac, 0.005% MACs, )
#     (2): Conv2d(2.36 M, 1.832% Params, 1.85 GMac, 24.402% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 401.41 KMac, 0.005% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 401.41 KMac, 0.005% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     4.72 M, 3.664% Params, 925.35 MMac, 12.205% MACs,
#     (0): Conv2d(2.36 M, 1.832% Params, 462.52 MMac, 6.100% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (2): Conv2d(2.36 M, 1.832% Params, 462.52 MMac, 6.100% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.001% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (5): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (6): Linear(102.76 M, 79.782% Params, 102.76 MMac, 1.355% MACs, in_features=25088, out_features=4096, bias=True)
#   (7): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (8): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (9): Linear(16.78 M, 13.028% Params, 16.78 MMac, 0.221% MACs, in_features=4096, out_features=4096, bias=True)
#   (10): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (11): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (12): Linear(40.97 k, 0.032% Params, 40.97 KMac, 0.001% MACs, in_features=4096, out_features=10, bias=True)
# )
# Computational complexity:       7.58 GMac
# Number of parameters:           128.81 M
# --------------------------------------------------
# Warning: module Flatten is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Sequential(
#   129.18 M, 100.000% Params, 7.63 GMac, 99.823% MACs,
#   (0): Sequential(
#     1.79 k, 0.001% Params, 96.34 MMac, 1.261% MACs,
#     (0): Conv2d(1.79 k, 0.001% Params, 89.92 MMac, 1.177% MACs, 3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 3.21 MMac, 0.042% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 3.21 MMac, 0.042% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     73.86 k, 0.057% Params, 929.66 MMac, 12.168% MACs,
#     (0): Conv2d(73.86 k, 0.057% Params, 926.45 MMac, 12.126% MACs, 64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 1.61 MMac, 0.021% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 1.61 MMac, 0.021% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     885.25 k, 0.685% Params, 2.78 GMac, 36.369% MACs,
#     (0): Conv2d(295.17 k, 0.229% Params, 925.65 MMac, 12.116% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.011% MACs, )
#     (2): Conv2d(590.08 k, 0.457% Params, 1.85 GMac, 24.221% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 802.82 KMac, 0.011% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.011% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     3.54 M, 2.740% Params, 2.78 GMac, 36.342% MACs,
#     (0): Conv2d(1.18 M, 0.914% Params, 925.25 MMac, 12.111% MACs, 256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 401.41 KMac, 0.005% MACs, )
#     (2): Conv2d(2.36 M, 1.827% Params, 1.85 GMac, 24.216% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 401.41 KMac, 0.005% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 401.41 KMac, 0.005% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     4.72 M, 3.654% Params, 925.35 MMac, 12.112% MACs,
#     (0): Conv2d(2.36 M, 1.827% Params, 462.52 MMac, 6.054% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (2): Conv2d(2.36 M, 1.827% Params, 462.52 MMac, 6.054% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.001% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (5): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (6): Linear(102.76 M, 79.554% Params, 102.76 MMac, 1.345% MACs, in_features=25088, out_features=4096, bias=True)
#   (7): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (8): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (9): Linear(16.78 M, 12.991% Params, 16.78 MMac, 0.220% MACs, in_features=4096, out_features=4096, bias=True)
#   (10): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (11): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (12): Linear(409.7 k, 0.317% Params, 409.7 KMac, 0.005% MACs, in_features=4096, out_features=100, bias=True)
# )
# Computational complexity:       7.64 GMac
# Number of parameters:           129.18 M
# --------------------------------------------------
# Warning: module Flatten is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Sequential(
#   128.81 M, 100.000% Params, 7.63 GMac, 99.823% MACs,
#   (0): Sequential(
#     1.79 k, 0.001% Params, 96.34 MMac, 1.261% MACs,
#     (0): Conv2d(1.79 k, 0.001% Params, 89.92 MMac, 1.177% MACs, 3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 3.21 MMac, 0.042% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 3.21 MMac, 0.042% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     73.86 k, 0.057% Params, 929.66 MMac, 12.169% MACs,
#     (0): Conv2d(73.86 k, 0.057% Params, 926.45 MMac, 12.127% MACs, 64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 1.61 MMac, 0.021% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 1.61 MMac, 0.021% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     885.25 k, 0.687% Params, 2.78 GMac, 36.370% MACs,
#     (0): Conv2d(295.17 k, 0.229% Params, 925.65 MMac, 12.116% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.011% MACs, )
#     (2): Conv2d(590.08 k, 0.458% Params, 1.85 GMac, 24.222% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 802.82 KMac, 0.011% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.011% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     3.54 M, 2.748% Params, 2.78 GMac, 36.344% MACs,
#     (0): Conv2d(1.18 M, 0.916% Params, 925.25 MMac, 12.111% MACs, 256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 401.41 KMac, 0.005% MACs, )
#     (2): Conv2d(2.36 M, 1.832% Params, 1.85 GMac, 24.217% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 401.41 KMac, 0.005% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 401.41 KMac, 0.005% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     4.72 M, 3.664% Params, 925.35 MMac, 12.113% MACs,
#     (0): Conv2d(2.36 M, 1.832% Params, 462.52 MMac, 6.054% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (2): Conv2d(2.36 M, 1.832% Params, 462.52 MMac, 6.054% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.001% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (5): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (6): Linear(102.76 M, 79.782% Params, 102.76 MMac, 1.345% MACs, in_features=25088, out_features=4096, bias=True)
#   (7): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (8): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (9): Linear(16.78 M, 13.028% Params, 16.78 MMac, 0.220% MACs, in_features=4096, out_features=4096, bias=True)
#   (10): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (11): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (12): Linear(40.97 k, 0.032% Params, 40.97 KMac, 0.001% MACs, in_features=4096, out_features=10, bias=True)
# )
# Computational complexity:       7.64 GMac
# Number of parameters:           128.81 M

# %% [markdown]
# #### VGG13

# %%
vgg13_f, macs_vgg13_f, paras_vgg13_f = get_model_info(vgg13, channel_f, num_labels_f)
print('-'*50)
vgg13_c100, macs_vgg13_c100, paras_vgg13_c100 = get_model_info(vgg13, channel_c, num_labels_c100)
print('-'*50)
vgg13_c10, macs_vgg13_c10, paras_vgg13_c10 = get_model_info(vgg13, channel_c, num_labels_c10)
# Out:
# Warning: module Flatten is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Sequential(
#   128.99 M, 100.000% Params, 11.28 GMac, 99.837% MACs,
#   (0): Sequential(
#     37.57 k, 0.029% Params, 1.89 GMac, 16.773% MACs,
#     (0): Conv2d(640, 0.000% Params, 32.11 MMac, 0.284% MACs, 1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 3.21 MMac, 0.028% MACs, )
#     (2): Conv2d(36.93 k, 0.029% Params, 1.85 GMac, 16.404% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 3.21 MMac, 0.028% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 3.21 MMac, 0.028% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     221.44 k, 0.172% Params, 2.78 GMac, 24.634% MACs,
#     (0): Conv2d(73.86 k, 0.057% Params, 926.45 MMac, 8.202% MACs, 64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 1.61 MMac, 0.014% MACs, )
#     (2): Conv2d(147.58 k, 0.114% Params, 1.85 GMac, 16.390% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 1.61 MMac, 0.014% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 1.61 MMac, 0.014% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     885.25 k, 0.686% Params, 2.78 GMac, 24.598% MACs,
#     (0): Conv2d(295.17 k, 0.229% Params, 925.65 MMac, 8.195% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.007% MACs, )
#     (2): Conv2d(590.08 k, 0.457% Params, 1.85 GMac, 16.382% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 802.82 KMac, 0.007% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.007% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     3.54 M, 2.744% Params, 2.78 GMac, 24.581% MACs,
#     (0): Conv2d(1.18 M, 0.915% Params, 925.25 MMac, 8.191% MACs, 256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 401.41 KMac, 0.004% MACs, )
#     (2): Conv2d(2.36 M, 1.829% Params, 1.85 GMac, 16.379% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 401.41 KMac, 0.004% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 401.41 KMac, 0.004% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     4.72 M, 3.659% Params, 925.35 MMac, 8.192% MACs,
#     (0): Conv2d(2.36 M, 1.829% Params, 462.52 MMac, 4.095% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (2): Conv2d(2.36 M, 1.829% Params, 462.52 MMac, 4.095% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.001% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (5): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (6): Linear(102.76 M, 79.668% Params, 102.76 MMac, 0.910% MACs, in_features=25088, out_features=4096, bias=True)
#   (7): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (8): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (9): Linear(16.78 M, 13.010% Params, 16.78 MMac, 0.149% MACs, in_features=4096, out_features=4096, bias=True)
#   (10): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (11): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (12): Linear(40.97 k, 0.032% Params, 40.97 KMac, 0.000% MACs, in_features=4096, out_features=10, bias=True)
# )
# Computational complexity:       11.3 GMac
# Number of parameters:           128.99 M
# --------------------------------------------------
# Warning: module Flatten is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Sequential(
#   129.36 M, 100.000% Params, 11.34 GMac, 99.838% MACs,
#   (0): Sequential(
#     38.72 k, 0.030% Params, 1.95 GMac, 17.196% MACs,
#     (0): Conv2d(1.79 k, 0.001% Params, 89.92 MMac, 0.792% MACs, 3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 3.21 MMac, 0.028% MACs, )
#     (2): Conv2d(36.93 k, 0.029% Params, 1.85 GMac, 16.320% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 3.21 MMac, 0.028% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 3.21 MMac, 0.028% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     221.44 k, 0.171% Params, 2.78 GMac, 24.508% MACs,
#     (0): Conv2d(73.86 k, 0.057% Params, 926.45 MMac, 8.160% MACs, 64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 1.61 MMac, 0.014% MACs, )
#     (2): Conv2d(147.58 k, 0.114% Params, 1.85 GMac, 16.306% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 1.61 MMac, 0.014% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 1.61 MMac, 0.014% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     885.25 k, 0.684% Params, 2.78 GMac, 24.472% MACs,
#     (0): Conv2d(295.17 k, 0.228% Params, 925.65 MMac, 8.153% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.007% MACs, )
#     (2): Conv2d(590.08 k, 0.456% Params, 1.85 GMac, 16.298% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 802.82 KMac, 0.007% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.007% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     3.54 M, 2.737% Params, 2.78 GMac, 24.455% MACs,
#     (0): Conv2d(1.18 M, 0.912% Params, 925.25 MMac, 8.149% MACs, 256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 401.41 KMac, 0.004% MACs, )
#     (2): Conv2d(2.36 M, 1.824% Params, 1.85 GMac, 16.295% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 401.41 KMac, 0.004% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 401.41 KMac, 0.004% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     4.72 M, 3.648% Params, 925.35 MMac, 8.150% MACs,
#     (0): Conv2d(2.36 M, 1.824% Params, 462.52 MMac, 4.074% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (2): Conv2d(2.36 M, 1.824% Params, 462.52 MMac, 4.074% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.001% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (5): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (6): Linear(102.76 M, 79.440% Params, 102.76 MMac, 0.905% MACs, in_features=25088, out_features=4096, bias=True)
#   (7): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (8): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (9): Linear(16.78 M, 12.973% Params, 16.78 MMac, 0.148% MACs, in_features=4096, out_features=4096, bias=True)
#   (10): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (11): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (12): Linear(409.7 k, 0.317% Params, 409.7 KMac, 0.004% MACs, in_features=4096, out_features=100, bias=True)
# )
# Computational complexity:       11.35 GMac
# Number of parameters:           129.36 M
# --------------------------------------------------
# Warning: module Flatten is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Sequential(
#   128.99 M, 100.000% Params, 11.34 GMac, 99.838% MACs,
#   (0): Sequential(
#     38.72 k, 0.030% Params, 1.95 GMac, 17.197% MACs,
#     (0): Conv2d(1.79 k, 0.001% Params, 89.92 MMac, 0.792% MACs, 3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 3.21 MMac, 0.028% MACs, )
#     (2): Conv2d(36.93 k, 0.029% Params, 1.85 GMac, 16.320% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 3.21 MMac, 0.028% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 3.21 MMac, 0.028% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     221.44 k, 0.172% Params, 2.78 GMac, 24.509% MACs,
#     (0): Conv2d(73.86 k, 0.057% Params, 926.45 MMac, 8.160% MACs, 64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 1.61 MMac, 0.014% MACs, )
#     (2): Conv2d(147.58 k, 0.114% Params, 1.85 GMac, 16.306% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 1.61 MMac, 0.014% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 1.61 MMac, 0.014% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     885.25 k, 0.686% Params, 2.78 GMac, 24.473% MACs,
#     (0): Conv2d(295.17 k, 0.229% Params, 925.65 MMac, 8.153% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.007% MACs, )
#     (2): Conv2d(590.08 k, 0.457% Params, 1.85 GMac, 16.299% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 802.82 KMac, 0.007% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.007% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     3.54 M, 2.744% Params, 2.78 GMac, 24.456% MACs,
#     (0): Conv2d(1.18 M, 0.915% Params, 925.25 MMac, 8.149% MACs, 256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 401.41 KMac, 0.004% MACs, )
#     (2): Conv2d(2.36 M, 1.829% Params, 1.85 GMac, 16.295% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 401.41 KMac, 0.004% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 401.41 KMac, 0.004% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     4.72 M, 3.659% Params, 925.35 MMac, 8.150% MACs,
#     (0): Conv2d(2.36 M, 1.829% Params, 462.52 MMac, 4.074% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (2): Conv2d(2.36 M, 1.829% Params, 462.52 MMac, 4.074% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.001% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (5): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (6): Linear(102.76 M, 79.667% Params, 102.76 MMac, 0.905% MACs, in_features=25088, out_features=4096, bias=True)
#   (7): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (8): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (9): Linear(16.78 M, 13.010% Params, 16.78 MMac, 0.148% MACs, in_features=4096, out_features=4096, bias=True)
#   (10): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (11): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (12): Linear(40.97 k, 0.032% Params, 40.97 KMac, 0.000% MACs, in_features=4096, out_features=10, bias=True)
# )
# Computational complexity:       11.35 GMac
# Number of parameters:           128.99 M

# %% [markdown]
# #### VGG16

# %%
vgg16_f, macs_vgg16_f, paras_vgg16_f = get_model_info(vgg16, channel_f, num_labels_f)
print('-'*50)
vgg16_c100, macs_vgg16_c100, paras_vgg16_c100 = get_model_info(vgg16, channel_c, num_labels_c100)
print('-'*50)
vgg16_c10, macs_vgg16_c10, paras_vgg16_c10 = get_model_info(vgg16, channel_c, num_labels_c10)
# Out:
# Warning: module Flatten is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Sequential(
#   134.3 M, 100.000% Params, 15.44 GMac, 99.873% MACs,
#   (0): Sequential(
#     37.57 k, 0.028% Params, 1.89 GMac, 12.254% MACs,
#     (0): Conv2d(640, 0.000% Params, 32.11 MMac, 0.208% MACs, 1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 3.21 MMac, 0.021% MACs, )
#     (2): Conv2d(36.93 k, 0.027% Params, 1.85 GMac, 11.984% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 3.21 MMac, 0.021% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 3.21 MMac, 0.021% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     221.44 k, 0.165% Params, 2.78 GMac, 17.997% MACs,
#     (0): Conv2d(73.86 k, 0.055% Params, 926.45 MMac, 5.992% MACs, 64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 1.61 MMac, 0.010% MACs, )
#     (2): Conv2d(147.58 k, 0.110% Params, 1.85 GMac, 11.974% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 1.61 MMac, 0.010% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 1.61 MMac, 0.010% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     1.48 M, 1.099% Params, 4.63 GMac, 29.945% MACs,
#     (0): Conv2d(295.17 k, 0.220% Params, 925.65 MMac, 5.987% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.005% MACs, )
#     (2): Conv2d(590.08 k, 0.439% Params, 1.85 GMac, 11.969% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 802.82 KMac, 0.005% MACs, )
#     (4): Conv2d(590.08 k, 0.439% Params, 1.85 GMac, 11.969% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU(0, 0.000% Params, 802.82 KMac, 0.005% MACs, )
#     (6): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.005% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     5.9 M, 4.393% Params, 4.63 GMac, 29.926% MACs,
#     (0): Conv2d(1.18 M, 0.879% Params, 925.25 MMac, 5.984% MACs, 256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 401.41 KMac, 0.003% MACs, )
#     (2): Conv2d(2.36 M, 1.757% Params, 1.85 GMac, 11.966% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 401.41 KMac, 0.003% MACs, )
#     (4): Conv2d(2.36 M, 1.757% Params, 1.85 GMac, 11.966% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU(0, 0.000% Params, 401.41 KMac, 0.003% MACs, )
#     (6): MaxPool2d(0, 0.000% Params, 401.41 KMac, 0.003% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     7.08 M, 5.271% Params, 1.39 GMac, 8.977% MACs,
#     (0): Conv2d(2.36 M, 1.757% Params, 462.52 MMac, 2.991% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (2): Conv2d(2.36 M, 1.757% Params, 462.52 MMac, 2.991% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (4): Conv2d(2.36 M, 1.757% Params, 462.52 MMac, 2.991% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (6): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.001% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (5): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (6): Linear(102.76 M, 76.518% Params, 102.76 MMac, 0.665% MACs, in_features=25088, out_features=4096, bias=True)
#   (7): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (8): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (9): Linear(16.78 M, 12.495% Params, 16.78 MMac, 0.109% MACs, in_features=4096, out_features=4096, bias=True)
#   (10): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (11): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (12): Linear(40.97 k, 0.031% Params, 40.97 KMac, 0.000% MACs, in_features=4096, out_features=10, bias=True)
# )
# Computational complexity:       15.46 GMac
# Number of parameters:           134.3 M
# --------------------------------------------------
# Warning: module Flatten is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Sequential(
#   134.67 M, 100.000% Params, 15.5 GMac, 99.873% MACs,
#   (0): Sequential(
#     38.72 k, 0.029% Params, 1.95 GMac, 12.581% MACs,
#     (0): Conv2d(1.79 k, 0.001% Params, 89.92 MMac, 0.579% MACs, 3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 3.21 MMac, 0.021% MACs, )
#     (2): Conv2d(36.93 k, 0.027% Params, 1.85 GMac, 11.939% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 3.21 MMac, 0.021% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 3.21 MMac, 0.021% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     221.44 k, 0.164% Params, 2.78 GMac, 17.929% MACs,
#     (0): Conv2d(73.86 k, 0.055% Params, 926.45 MMac, 5.970% MACs, 64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 1.61 MMac, 0.010% MACs, )
#     (2): Conv2d(147.58 k, 0.110% Params, 1.85 GMac, 11.929% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 1.61 MMac, 0.010% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 1.61 MMac, 0.010% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     1.48 M, 1.096% Params, 4.63 GMac, 29.832% MACs,
#     (0): Conv2d(295.17 k, 0.219% Params, 925.65 MMac, 5.964% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.005% MACs, )
#     (2): Conv2d(590.08 k, 0.438% Params, 1.85 GMac, 11.924% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 802.82 KMac, 0.005% MACs, )
#     (4): Conv2d(590.08 k, 0.438% Params, 1.85 GMac, 11.924% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU(0, 0.000% Params, 802.82 KMac, 0.005% MACs, )
#     (6): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.005% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     5.9 M, 4.381% Params, 4.63 GMac, 29.814% MACs,
#     (0): Conv2d(1.18 M, 0.876% Params, 925.25 MMac, 5.962% MACs, 256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 401.41 KMac, 0.003% MACs, )
#     (2): Conv2d(2.36 M, 1.752% Params, 1.85 GMac, 11.921% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 401.41 KMac, 0.003% MACs, )
#     (4): Conv2d(2.36 M, 1.752% Params, 1.85 GMac, 11.921% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU(0, 0.000% Params, 401.41 KMac, 0.003% MACs, )
#     (6): MaxPool2d(0, 0.000% Params, 401.41 KMac, 0.003% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     7.08 M, 5.257% Params, 1.39 GMac, 8.943% MACs,
#     (0): Conv2d(2.36 M, 1.752% Params, 462.52 MMac, 2.980% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (2): Conv2d(2.36 M, 1.752% Params, 462.52 MMac, 2.980% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (4): Conv2d(2.36 M, 1.752% Params, 462.52 MMac, 2.980% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (6): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.001% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (5): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (6): Linear(102.76 M, 76.308% Params, 102.76 MMac, 0.662% MACs, in_features=25088, out_features=4096, bias=True)
#   (7): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (8): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (9): Linear(16.78 M, 12.461% Params, 16.78 MMac, 0.108% MACs, in_features=4096, out_features=4096, bias=True)
#   (10): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (11): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (12): Linear(409.7 k, 0.304% Params, 409.7 KMac, 0.003% MACs, in_features=4096, out_features=100, bias=True)
# )
# Computational complexity:       15.52 GMac
# Number of parameters:           134.67 M
# --------------------------------------------------
# Warning: module Flatten is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Sequential(
#   134.3 M, 100.000% Params, 15.5 GMac, 99.873% MACs,
#   (0): Sequential(
#     38.72 k, 0.029% Params, 1.95 GMac, 12.581% MACs,
#     (0): Conv2d(1.79 k, 0.001% Params, 89.92 MMac, 0.579% MACs, 3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 3.21 MMac, 0.021% MACs, )
#     (2): Conv2d(36.93 k, 0.027% Params, 1.85 GMac, 11.939% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 3.21 MMac, 0.021% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 3.21 MMac, 0.021% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     221.44 k, 0.165% Params, 2.78 GMac, 17.930% MACs,
#     (0): Conv2d(73.86 k, 0.055% Params, 926.45 MMac, 5.970% MACs, 64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 1.61 MMac, 0.010% MACs, )
#     (2): Conv2d(147.58 k, 0.110% Params, 1.85 GMac, 11.929% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 1.61 MMac, 0.010% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 1.61 MMac, 0.010% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     1.48 M, 1.099% Params, 4.63 GMac, 29.833% MACs,
#     (0): Conv2d(295.17 k, 0.220% Params, 925.65 MMac, 5.965% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.005% MACs, )
#     (2): Conv2d(590.08 k, 0.439% Params, 1.85 GMac, 11.924% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 802.82 KMac, 0.005% MACs, )
#     (4): Conv2d(590.08 k, 0.439% Params, 1.85 GMac, 11.924% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU(0, 0.000% Params, 802.82 KMac, 0.005% MACs, )
#     (6): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.005% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     5.9 M, 4.393% Params, 4.63 GMac, 29.815% MACs,
#     (0): Conv2d(1.18 M, 0.879% Params, 925.25 MMac, 5.962% MACs, 256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 401.41 KMac, 0.003% MACs, )
#     (2): Conv2d(2.36 M, 1.757% Params, 1.85 GMac, 11.921% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 401.41 KMac, 0.003% MACs, )
#     (4): Conv2d(2.36 M, 1.757% Params, 1.85 GMac, 11.921% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU(0, 0.000% Params, 401.41 KMac, 0.003% MACs, )
#     (6): MaxPool2d(0, 0.000% Params, 401.41 KMac, 0.003% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     7.08 M, 5.271% Params, 1.39 GMac, 8.944% MACs,
#     (0): Conv2d(2.36 M, 1.757% Params, 462.52 MMac, 2.980% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (2): Conv2d(2.36 M, 1.757% Params, 462.52 MMac, 2.980% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (4): Conv2d(2.36 M, 1.757% Params, 462.52 MMac, 2.980% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, )
#     (6): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.001% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (5): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   (6): Linear(102.76 M, 76.518% Params, 102.76 MMac, 0.662% MACs, in_features=25088, out_features=4096, bias=True)
#   (7): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (8): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (9): Linear(16.78 M, 12.495% Params, 16.78 MMac, 0.108% MACs, in_features=4096, out_features=4096, bias=True)
#   (10): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, )
#   (11): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (12): Linear(40.97 k, 0.031% Params, 40.97 KMac, 0.000% MACs, in_features=4096, out_features=10, bias=True)
# )
# Computational complexity:       15.52 GMac
# Number of parameters:           134.3 M

# %% [markdown]
# ### MobileNet

# %% [markdown]
# #### MobileNetV1

# %%
mobilenetv1_f, macs_mobilenetv1_f, paras_mobilenetv1_f = get_model_info(MobileNet, channel_f, num_labels_f)
print('-'*50)
mobilenetv1_c100, macs_mobilenetv1_c100, paras_mobilenetv1_c100 = get_model_info(MobileNet, channel_c, num_labels_c100)
print('-'*50)
mobilenetv1_c10, macs_mobilenetv1_c10, paras_mobilenetv1_c10 = get_model_info(MobileNet, channel_c, num_labels_c10)
# Out:
# Warning: module DepthwiseSeparableConv is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Warning: module MobileNet is treated as a zero-op.
# MobileNet(
#   3.21 M, 100.000% Params, 566.8 MMac, 99.920% MACs,
#   (model): Sequential(
#     3.21 M, 100.000% Params, 566.8 MMac, 99.920% MACs,
#     (0): Conv2d(320, 0.010% Params, 4.01 MMac, 0.708% MACs, 1, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(64, 0.002% Params, 802.82 KMac, 0.142% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0, 0.000% Params, 401.41 KMac, 0.071% MACs, )
#     (3): DepthwiseSeparableConv(
#       2.43 k, 0.076% Params, 30.51 MMac, 5.378% MACs,
#       (depthwise): Conv2d(320, 0.010% Params, 4.01 MMac, 0.708% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#       (pointwise): Conv2d(2.11 k, 0.066% Params, 26.49 MMac, 4.670% MACs, 32, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): DepthwiseSeparableConv(
#       8.96 k, 0.279% Params, 28.1 MMac, 4.953% MACs,
#       (depthwise): Conv2d(640, 0.020% Params, 2.01 MMac, 0.354% MACs, 64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64)
#       (pointwise): Conv2d(8.32 k, 0.260% Params, 26.09 MMac, 4.600% MACs, 64, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): DepthwiseSeparableConv(
#       17.79 k, 0.555% Params, 55.8 MMac, 9.836% MACs,
#       (depthwise): Conv2d(1.28 k, 0.040% Params, 4.01 MMac, 0.708% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#       (pointwise): Conv2d(16.51 k, 0.515% Params, 51.78 MMac, 9.129% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (6): DepthwiseSeparableConv(
#       34.3 k, 1.070% Params, 26.89 MMac, 4.741% MACs,
#       (depthwise): Conv2d(1.28 k, 0.040% Params, 1.0 MMac, 0.177% MACs, 128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128)
#       (pointwise): Conv2d(33.02 k, 1.030% Params, 25.89 MMac, 4.564% MACs, 128, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (7): DepthwiseSeparableConv(
#       68.35 k, 2.132% Params, 53.59 MMac, 9.447% MACs,
#       (depthwise): Conv2d(2.56 k, 0.080% Params, 2.01 MMac, 0.354% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#       (pointwise): Conv2d(65.79 k, 2.052% Params, 51.58 MMac, 9.093% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (8): DepthwiseSeparableConv(
#       134.14 k, 4.184% Params, 26.29 MMac, 4.635% MACs,
#       (depthwise): Conv2d(2.56 k, 0.080% Params, 501.76 KMac, 0.088% MACs, 256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256)
#       (pointwise): Conv2d(131.58 k, 4.105% Params, 25.79 MMac, 4.547% MACs, 256, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (9): DepthwiseSeparableConv(
#       267.78 k, 8.353% Params, 52.48 MMac, 9.252% MACs,
#       (depthwise): Conv2d(5.12 k, 0.160% Params, 1.0 MMac, 0.177% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(262.66 k, 8.193% Params, 51.48 MMac, 9.075% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (10): DepthwiseSeparableConv(
#       267.78 k, 8.353% Params, 52.48 MMac, 9.252% MACs,
#       (depthwise): Conv2d(5.12 k, 0.160% Params, 1.0 MMac, 0.177% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(262.66 k, 8.193% Params, 51.48 MMac, 9.075% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (11): DepthwiseSeparableConv(
#       267.78 k, 8.353% Params, 52.48 MMac, 9.252% MACs,
#       (depthwise): Conv2d(5.12 k, 0.160% Params, 1.0 MMac, 0.177% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(262.66 k, 8.193% Params, 51.48 MMac, 9.075% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (12): DepthwiseSeparableConv(
#       267.78 k, 8.353% Params, 52.48 MMac, 9.252% MACs,
#       (depthwise): Conv2d(5.12 k, 0.160% Params, 1.0 MMac, 0.177% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(262.66 k, 8.193% Params, 51.48 MMac, 9.075% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (13): DepthwiseSeparableConv(
#       267.78 k, 8.353% Params, 52.48 MMac, 9.252% MACs,
#       (depthwise): Conv2d(5.12 k, 0.160% Params, 1.0 MMac, 0.177% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(262.66 k, 8.193% Params, 51.48 MMac, 9.075% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (14): DepthwiseSeparableConv(
#       530.43 k, 16.546% Params, 25.99 MMac, 4.582% MACs,
#       (depthwise): Conv2d(5.12 k, 0.160% Params, 250.88 KMac, 0.044% MACs, 512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(525.31 k, 16.386% Params, 25.74 MMac, 4.538% MACs, 512, 1024, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (15): DepthwiseSeparableConv(
#       1.06 M, 33.060% Params, 51.93 MMac, 9.155% MACs,
#       (depthwise): Conv2d(10.24 k, 0.319% Params, 501.76 KMac, 0.088% MACs, 1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024)
#       (pointwise): Conv2d(1.05 M, 32.741% Params, 51.43 MMac, 9.067% MACs, 1024, 1024, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (16): AdaptiveAvgPool2d(0, 0.000% Params, 50.18 KMac, 0.009% MACs, output_size=1)
#     (17): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#     (18): Linear(10.25 k, 0.320% Params, 10.25 KMac, 0.002% MACs, in_features=1024, out_features=10, bias=True)
#   )
# )
# Computational complexity:       567.25 MMac
# Number of parameters:           3.21 M
# --------------------------------------------------
# Warning: module DepthwiseSeparableConv is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Warning: module MobileNet is treated as a zero-op.
# MobileNet(
#   3.3 M, 100.000% Params, 574.12 MMac, 99.921% MACs,
#   (model): Sequential(
#     3.3 M, 100.000% Params, 574.12 MMac, 99.921% MACs,
#     (0): Conv2d(896, 0.027% Params, 11.24 MMac, 1.956% MACs, 3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(64, 0.002% Params, 802.82 KMac, 0.140% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0, 0.000% Params, 401.41 KMac, 0.070% MACs, )
#     (3): DepthwiseSeparableConv(
#       2.43 k, 0.074% Params, 30.51 MMac, 5.310% MACs,
#       (depthwise): Conv2d(320, 0.010% Params, 4.01 MMac, 0.699% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#       (pointwise): Conv2d(2.11 k, 0.064% Params, 26.49 MMac, 4.611% MACs, 32, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): DepthwiseSeparableConv(
#       8.96 k, 0.272% Params, 28.1 MMac, 4.890% MACs,
#       (depthwise): Conv2d(640, 0.019% Params, 2.01 MMac, 0.349% MACs, 64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64)
#       (pointwise): Conv2d(8.32 k, 0.252% Params, 26.09 MMac, 4.541% MACs, 64, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): DepthwiseSeparableConv(
#       17.79 k, 0.539% Params, 55.8 MMac, 9.711% MACs,
#       (depthwise): Conv2d(1.28 k, 0.039% Params, 4.01 MMac, 0.699% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#       (pointwise): Conv2d(16.51 k, 0.501% Params, 51.78 MMac, 9.012% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (6): DepthwiseSeparableConv(
#       34.3 k, 1.040% Params, 26.89 MMac, 4.681% MACs,
#       (depthwise): Conv2d(1.28 k, 0.039% Params, 1.0 MMac, 0.175% MACs, 128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128)
#       (pointwise): Conv2d(33.02 k, 1.001% Params, 25.89 MMac, 4.506% MACs, 128, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (7): DepthwiseSeparableConv(
#       68.35 k, 2.072% Params, 53.59 MMac, 9.327% MACs,
#       (depthwise): Conv2d(2.56 k, 0.078% Params, 2.01 MMac, 0.349% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#       (pointwise): Conv2d(65.79 k, 1.995% Params, 51.58 MMac, 8.977% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (8): DepthwiseSeparableConv(
#       134.14 k, 4.067% Params, 26.29 MMac, 4.576% MACs,
#       (depthwise): Conv2d(2.56 k, 0.078% Params, 501.76 KMac, 0.087% MACs, 256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256)
#       (pointwise): Conv2d(131.58 k, 3.989% Params, 25.79 MMac, 4.489% MACs, 256, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (9): DepthwiseSeparableConv(
#       267.78 k, 8.118% Params, 52.48 MMac, 9.135% MACs,
#       (depthwise): Conv2d(5.12 k, 0.155% Params, 1.0 MMac, 0.175% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(262.66 k, 7.963% Params, 51.48 MMac, 8.960% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (10): DepthwiseSeparableConv(
#       267.78 k, 8.118% Params, 52.48 MMac, 9.135% MACs,
#       (depthwise): Conv2d(5.12 k, 0.155% Params, 1.0 MMac, 0.175% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(262.66 k, 7.963% Params, 51.48 MMac, 8.960% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (11): DepthwiseSeparableConv(
#       267.78 k, 8.118% Params, 52.48 MMac, 9.135% MACs,
#       (depthwise): Conv2d(5.12 k, 0.155% Params, 1.0 MMac, 0.175% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(262.66 k, 7.963% Params, 51.48 MMac, 8.960% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (12): DepthwiseSeparableConv(
#       267.78 k, 8.118% Params, 52.48 MMac, 9.135% MACs,
#       (depthwise): Conv2d(5.12 k, 0.155% Params, 1.0 MMac, 0.175% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(262.66 k, 7.963% Params, 51.48 MMac, 8.960% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (13): DepthwiseSeparableConv(
#       267.78 k, 8.118% Params, 52.48 MMac, 9.135% MACs,
#       (depthwise): Conv2d(5.12 k, 0.155% Params, 1.0 MMac, 0.175% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(262.66 k, 7.963% Params, 51.48 MMac, 8.960% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (14): DepthwiseSeparableConv(
#       530.43 k, 16.081% Params, 25.99 MMac, 4.524% MACs,
#       (depthwise): Conv2d(5.12 k, 0.155% Params, 250.88 KMac, 0.044% MACs, 512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(525.31 k, 15.925% Params, 25.74 MMac, 4.480% MACs, 512, 1024, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (15): DepthwiseSeparableConv(
#       1.06 M, 32.130% Params, 51.93 MMac, 9.038% MACs,
#       (depthwise): Conv2d(10.24 k, 0.310% Params, 501.76 KMac, 0.087% MACs, 1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024)
#       (pointwise): Conv2d(1.05 M, 31.820% Params, 51.43 MMac, 8.951% MACs, 1024, 1024, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (16): AdaptiveAvgPool2d(0, 0.000% Params, 50.18 KMac, 0.009% MACs, output_size=1)
#     (17): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#     (18): Linear(102.5 k, 3.107% Params, 102.5 KMac, 0.018% MACs, in_features=1024, out_features=100, bias=True)
#   )
# )
# Computational complexity:       574.57 MMac
# Number of parameters:           3.3 M
# --------------------------------------------------
# Warning: module DepthwiseSeparableConv is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Warning: module MobileNet is treated as a zero-op.
# MobileNet(
#   3.21 M, 100.000% Params, 574.02 MMac, 99.921% MACs,
#   (model): Sequential(
#     3.21 M, 100.000% Params, 574.02 MMac, 99.921% MACs,
#     (0): Conv2d(896, 0.028% Params, 11.24 MMac, 1.956% MACs, 3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(64, 0.002% Params, 802.82 KMac, 0.140% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0, 0.000% Params, 401.41 KMac, 0.070% MACs, )
#     (3): DepthwiseSeparableConv(
#       2.43 k, 0.076% Params, 30.51 MMac, 5.310% MACs,
#       (depthwise): Conv2d(320, 0.010% Params, 4.01 MMac, 0.699% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#       (pointwise): Conv2d(2.11 k, 0.066% Params, 26.49 MMac, 4.612% MACs, 32, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): DepthwiseSeparableConv(
#       8.96 k, 0.279% Params, 28.1 MMac, 4.891% MACs,
#       (depthwise): Conv2d(640, 0.020% Params, 2.01 MMac, 0.349% MACs, 64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64)
#       (pointwise): Conv2d(8.32 k, 0.259% Params, 26.09 MMac, 4.542% MACs, 64, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): DepthwiseSeparableConv(
#       17.79 k, 0.555% Params, 55.8 MMac, 9.712% MACs,
#       (depthwise): Conv2d(1.28 k, 0.040% Params, 4.01 MMac, 0.699% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#       (pointwise): Conv2d(16.51 k, 0.515% Params, 51.78 MMac, 9.014% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (6): DepthwiseSeparableConv(
#       34.3 k, 1.070% Params, 26.89 MMac, 4.682% MACs,
#       (depthwise): Conv2d(1.28 k, 0.040% Params, 1.0 MMac, 0.175% MACs, 128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128)
#       (pointwise): Conv2d(33.02 k, 1.030% Params, 25.89 MMac, 4.507% MACs, 128, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (7): DepthwiseSeparableConv(
#       68.35 k, 2.132% Params, 53.59 MMac, 9.328% MACs,
#       (depthwise): Conv2d(2.56 k, 0.080% Params, 2.01 MMac, 0.349% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256)
#       (pointwise): Conv2d(65.79 k, 2.052% Params, 51.58 MMac, 8.979% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (8): DepthwiseSeparableConv(
#       134.14 k, 4.184% Params, 26.29 MMac, 4.577% MACs,
#       (depthwise): Conv2d(2.56 k, 0.080% Params, 501.76 KMac, 0.087% MACs, 256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256)
#       (pointwise): Conv2d(131.58 k, 4.104% Params, 25.79 MMac, 4.489% MACs, 256, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (9): DepthwiseSeparableConv(
#       267.78 k, 8.351% Params, 52.48 MMac, 9.136% MACs,
#       (depthwise): Conv2d(5.12 k, 0.160% Params, 1.0 MMac, 0.175% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(262.66 k, 8.192% Params, 51.48 MMac, 8.961% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (10): DepthwiseSeparableConv(
#       267.78 k, 8.351% Params, 52.48 MMac, 9.136% MACs,
#       (depthwise): Conv2d(5.12 k, 0.160% Params, 1.0 MMac, 0.175% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(262.66 k, 8.192% Params, 51.48 MMac, 8.961% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (11): DepthwiseSeparableConv(
#       267.78 k, 8.351% Params, 52.48 MMac, 9.136% MACs,
#       (depthwise): Conv2d(5.12 k, 0.160% Params, 1.0 MMac, 0.175% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(262.66 k, 8.192% Params, 51.48 MMac, 8.961% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (12): DepthwiseSeparableConv(
#       267.78 k, 8.351% Params, 52.48 MMac, 9.136% MACs,
#       (depthwise): Conv2d(5.12 k, 0.160% Params, 1.0 MMac, 0.175% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(262.66 k, 8.192% Params, 51.48 MMac, 8.961% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (13): DepthwiseSeparableConv(
#       267.78 k, 8.351% Params, 52.48 MMac, 9.136% MACs,
#       (depthwise): Conv2d(5.12 k, 0.160% Params, 1.0 MMac, 0.175% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(262.66 k, 8.192% Params, 51.48 MMac, 8.961% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (14): DepthwiseSeparableConv(
#       530.43 k, 16.543% Params, 25.99 MMac, 4.524% MACs,
#       (depthwise): Conv2d(5.12 k, 0.160% Params, 250.88 KMac, 0.044% MACs, 512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=512)
#       (pointwise): Conv2d(525.31 k, 16.384% Params, 25.74 MMac, 4.481% MACs, 512, 1024, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (15): DepthwiseSeparableConv(
#       1.06 M, 33.054% Params, 51.93 MMac, 9.040% MACs,
#       (depthwise): Conv2d(10.24 k, 0.319% Params, 501.76 KMac, 0.087% MACs, 1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024)
#       (pointwise): Conv2d(1.05 M, 32.735% Params, 51.43 MMac, 8.953% MACs, 1024, 1024, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (16): AdaptiveAvgPool2d(0, 0.000% Params, 50.18 KMac, 0.009% MACs, output_size=1)
#     (17): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#     (18): Linear(10.25 k, 0.320% Params, 10.25 KMac, 0.002% MACs, in_features=1024, out_features=10, bias=True)
#   )
# )
# Computational complexity:       574.48 MMac
# Number of parameters:           3.21 M

# %% [markdown]
# #### MobileNetV2

# %%
mobilenetv2_f, macs_mobilenetv2_f, paras_mobilenetv2_f = get_model_info(MobileNetV2, channel_f, num_labels_f)
print('-'*50)
mobilenetv2_c100, macs_mobilenetv2_c100, paras_mobilenetv2_c100 = get_model_info(MobileNetV2, channel_c, num_labels_c100)
print('-'*50)
mobilenetv2_c10, macs_mobilenetv2_c10, paras_mobilenetv2_c10 = get_model_info(MobileNetV2, channel_c, num_labels_c10)
# Out:
# Warning: module InvertedResidual is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Warning: module MobileNetV2 is treated as a zero-op.
# MobileNetV2(
#   2.24 M, 100.000% Params, 325.86 MMac, 99.981% MACs,
#   (first_layer): Sequential(
#     352, 0.016% Params, 4.82 MMac, 1.478% MACs,
#     (0): Conv2d(288, 0.013% Params, 3.61 MMac, 1.108% MACs, 1, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, 0.003% Params, 802.82 KMac, 0.246% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(0, 0.000% Params, 401.41 KMac, 0.123% MACs, inplace=True)
#   )
#   (inverted_residual_blocks): Sequential(
#     1.81 M, 80.989% Params, 300.7 MMac, 92.264% MACs,
#     (0): InvertedResidual(
#       1.98 k, 0.089% Params, 25.69 MMac, 7.882% MACs,
#       (layers): Sequential(
#         1.98 k, 0.089% Params, 25.69 MMac, 7.882% MACs,
#         (0): Conv2d(1.02 k, 0.046% Params, 12.85 MMac, 3.941% MACs, 32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, 0.003% Params, 802.82 KMac, 0.246% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 401.41 KMac, 0.123% MACs, inplace=True)
#         (3): Conv2d(288, 0.013% Params, 3.61 MMac, 1.108% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (4): BatchNorm2d(64, 0.003% Params, 802.82 KMac, 0.246% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 401.41 KMac, 0.123% MACs, inplace=True)
#         (6): Conv2d(512, 0.023% Params, 6.42 MMac, 1.971% MACs, 32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(32, 0.001% Params, 401.41 KMac, 0.123% MACs, 16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): InvertedResidual(
#       5.14 k, 0.230% Params, 33.87 MMac, 10.392% MACs,
#       (layers): Sequential(
#         5.14 k, 0.230% Params, 33.87 MMac, 10.392% MACs,
#         (0): Conv2d(1.54 k, 0.069% Params, 19.27 MMac, 5.912% MACs, 16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(192, 0.009% Params, 2.41 MMac, 0.739% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 1.2 MMac, 0.369% MACs, inplace=True)
#         (3): Conv2d(864, 0.039% Params, 2.71 MMac, 0.831% MACs, 96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (4): BatchNorm2d(192, 0.009% Params, 602.11 KMac, 0.185% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 301.06 KMac, 0.092% MACs, inplace=True)
#         (6): Conv2d(2.3 k, 0.103% Params, 7.23 MMac, 2.217% MACs, 96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(48, 0.002% Params, 150.53 KMac, 0.046% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       8.83 k, 0.395% Params, 28.6 MMac, 8.775% MACs,
#       (layers): Sequential(
#         8.83 k, 0.395% Params, 28.6 MMac, 8.775% MACs,
#         (0): Conv2d(3.46 k, 0.154% Params, 10.84 MMac, 3.325% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(288, 0.013% Params, 903.17 KMac, 0.277% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 451.58 KMac, 0.139% MACs, inplace=True)
#         (3): Conv2d(1.3 k, 0.058% Params, 4.06 MMac, 1.247% MACs, 144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (4): BatchNorm2d(288, 0.013% Params, 903.17 KMac, 0.277% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 451.58 KMac, 0.139% MACs, inplace=True)
#         (6): Conv2d(3.46 k, 0.154% Params, 10.84 MMac, 3.325% MACs, 144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(48, 0.002% Params, 150.53 KMac, 0.046% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       10.0 k, 0.447% Params, 17.21 MMac, 5.281% MACs,
#       (layers): Sequential(
#         10.0 k, 0.447% Params, 17.21 MMac, 5.281% MACs,
#         (0): Conv2d(3.46 k, 0.154% Params, 10.84 MMac, 3.325% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(288, 0.013% Params, 903.17 KMac, 0.277% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 451.58 KMac, 0.139% MACs, inplace=True)
#         (3): Conv2d(1.3 k, 0.058% Params, 1.02 MMac, 0.312% MACs, 144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#         (4): BatchNorm2d(288, 0.013% Params, 225.79 KMac, 0.069% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         (6): Conv2d(4.61 k, 0.206% Params, 3.61 MMac, 1.108% MACs, 144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(64, 0.003% Params, 50.18 KMac, 0.015% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       14.85 k, 0.664% Params, 11.94 MMac, 3.664% MACs,
#       (layers): Sequential(
#         14.85 k, 0.664% Params, 11.94 MMac, 3.664% MACs,
#         (0): Conv2d(6.14 k, 0.275% Params, 4.82 MMac, 1.478% MACs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, 0.017% Params, 301.06 KMac, 0.092% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.046% MACs, inplace=True)
#         (3): Conv2d(1.73 k, 0.077% Params, 1.35 MMac, 0.416% MACs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (4): BatchNorm2d(384, 0.017% Params, 301.06 KMac, 0.092% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 150.53 KMac, 0.046% MACs, inplace=True)
#         (6): Conv2d(6.14 k, 0.275% Params, 4.82 MMac, 1.478% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(64, 0.003% Params, 50.18 KMac, 0.015% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       14.85 k, 0.664% Params, 11.94 MMac, 3.664% MACs,
#       (layers): Sequential(
#         14.85 k, 0.664% Params, 11.94 MMac, 3.664% MACs,
#         (0): Conv2d(6.14 k, 0.275% Params, 4.82 MMac, 1.478% MACs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, 0.017% Params, 301.06 KMac, 0.092% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.046% MACs, inplace=True)
#         (3): Conv2d(1.73 k, 0.077% Params, 1.35 MMac, 0.416% MACs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (4): BatchNorm2d(384, 0.017% Params, 301.06 KMac, 0.092% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 150.53 KMac, 0.046% MACs, inplace=True)
#         (6): Conv2d(6.14 k, 0.275% Params, 4.82 MMac, 1.478% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(64, 0.003% Params, 50.18 KMac, 0.015% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       21.06 k, 0.941% Params, 8.15 MMac, 2.502% MACs,
#       (layers): Sequential(
#         21.06 k, 0.941% Params, 8.15 MMac, 2.502% MACs,
#         (0): Conv2d(6.14 k, 0.275% Params, 4.82 MMac, 1.478% MACs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, 0.017% Params, 301.06 KMac, 0.092% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.046% MACs, inplace=True)
#         (3): Conv2d(1.73 k, 0.077% Params, 338.69 KMac, 0.104% MACs, 192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#         (4): BatchNorm2d(384, 0.017% Params, 75.26 KMac, 0.023% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 37.63 KMac, 0.012% MACs, inplace=True)
#         (6): Conv2d(12.29 k, 0.549% Params, 2.41 MMac, 0.739% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(128, 0.006% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       54.27 k, 2.426% Params, 10.79 MMac, 3.310% MACs,
#       (layers): Sequential(
#         54.27 k, 2.426% Params, 10.79 MMac, 3.310% MACs,
#         (0): Conv2d(24.58 k, 1.099% Params, 4.82 MMac, 1.478% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.046% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (3): Conv2d(3.46 k, 0.154% Params, 677.38 KMac, 0.208% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.046% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (6): Conv2d(24.58 k, 1.099% Params, 4.82 MMac, 1.478% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(128, 0.006% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       54.27 k, 2.426% Params, 10.79 MMac, 3.310% MACs,
#       (layers): Sequential(
#         54.27 k, 2.426% Params, 10.79 MMac, 3.310% MACs,
#         (0): Conv2d(24.58 k, 1.099% Params, 4.82 MMac, 1.478% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.046% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (3): Conv2d(3.46 k, 0.154% Params, 677.38 KMac, 0.208% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.046% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (6): Conv2d(24.58 k, 1.099% Params, 4.82 MMac, 1.478% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(128, 0.006% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       54.27 k, 2.426% Params, 10.79 MMac, 3.310% MACs,
#       (layers): Sequential(
#         54.27 k, 2.426% Params, 10.79 MMac, 3.310% MACs,
#         (0): Conv2d(24.58 k, 1.099% Params, 4.82 MMac, 1.478% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.046% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (3): Conv2d(3.46 k, 0.154% Params, 677.38 KMac, 0.208% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.046% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (6): Conv2d(24.58 k, 1.099% Params, 4.82 MMac, 1.478% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(128, 0.006% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       66.62 k, 2.978% Params, 13.21 MMac, 4.053% MACs,
#       (layers): Sequential(
#         66.62 k, 2.978% Params, 13.21 MMac, 4.053% MACs,
#         (0): Conv2d(24.58 k, 1.099% Params, 4.82 MMac, 1.478% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.046% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (3): Conv2d(3.46 k, 0.154% Params, 677.38 KMac, 0.208% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.046% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (6): Conv2d(36.86 k, 1.648% Params, 7.23 MMac, 2.217% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(192, 0.009% Params, 37.63 KMac, 0.012% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       118.27 k, 5.287% Params, 23.41 MMac, 7.182% MACs,
#       (layers): Sequential(
#         118.27 k, 5.287% Params, 23.41 MMac, 7.182% MACs,
#         (0): Conv2d(55.3 k, 2.472% Params, 10.84 MMac, 3.325% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.15 k, 0.051% Params, 225.79 KMac, 0.069% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         (3): Conv2d(5.18 k, 0.232% Params, 1.02 MMac, 0.312% MACs, 576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (4): BatchNorm2d(1.15 k, 0.051% Params, 225.79 KMac, 0.069% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         (6): Conv2d(55.3 k, 2.472% Params, 10.84 MMac, 3.325% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(192, 0.009% Params, 37.63 KMac, 0.012% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       118.27 k, 5.287% Params, 23.41 MMac, 7.182% MACs,
#       (layers): Sequential(
#         118.27 k, 5.287% Params, 23.41 MMac, 7.182% MACs,
#         (0): Conv2d(55.3 k, 2.472% Params, 10.84 MMac, 3.325% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.15 k, 0.051% Params, 225.79 KMac, 0.069% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         (3): Conv2d(5.18 k, 0.232% Params, 1.02 MMac, 0.312% MACs, 576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (4): BatchNorm2d(1.15 k, 0.051% Params, 225.79 KMac, 0.069% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         (6): Conv2d(55.3 k, 2.472% Params, 10.84 MMac, 3.325% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(192, 0.009% Params, 37.63 KMac, 0.012% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       155.26 k, 6.940% Params, 16.05 MMac, 4.924% MACs,
#       (layers): Sequential(
#         155.26 k, 6.940% Params, 16.05 MMac, 4.924% MACs,
#         (0): Conv2d(55.3 k, 2.472% Params, 10.84 MMac, 3.325% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.15 k, 0.051% Params, 225.79 KMac, 0.069% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         (3): Conv2d(5.18 k, 0.232% Params, 254.02 KMac, 0.078% MACs, 576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#         (4): BatchNorm2d(1.15 k, 0.051% Params, 56.45 KMac, 0.017% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 28.22 KMac, 0.009% MACs, inplace=True)
#         (6): Conv2d(92.16 k, 4.119% Params, 4.52 MMac, 1.386% MACs, 576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(320, 0.014% Params, 15.68 KMac, 0.005% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       320.0 k, 14.304% Params, 15.77 MMac, 4.840% MACs,
#       (layers): Sequential(
#         320.0 k, 14.304% Params, 15.77 MMac, 4.840% MACs,
#         (0): Conv2d(153.6 k, 6.866% Params, 7.53 MMac, 2.309% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.92 k, 0.086% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (3): Conv2d(8.64 k, 0.386% Params, 423.36 KMac, 0.130% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (4): BatchNorm2d(1.92 k, 0.086% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (6): Conv2d(153.6 k, 6.866% Params, 7.53 MMac, 2.309% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(320, 0.014% Params, 15.68 KMac, 0.005% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       320.0 k, 14.304% Params, 15.77 MMac, 4.840% MACs,
#       (layers): Sequential(
#         320.0 k, 14.304% Params, 15.77 MMac, 4.840% MACs,
#         (0): Conv2d(153.6 k, 6.866% Params, 7.53 MMac, 2.309% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.92 k, 0.086% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (3): Conv2d(8.64 k, 0.386% Params, 423.36 KMac, 0.130% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (4): BatchNorm2d(1.92 k, 0.086% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (6): Conv2d(153.6 k, 6.866% Params, 7.53 MMac, 2.309% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(320, 0.014% Params, 15.68 KMac, 0.005% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       473.92 k, 21.184% Params, 23.32 MMac, 7.154% MACs,
#       (layers): Sequential(
#         473.92 k, 21.184% Params, 23.32 MMac, 7.154% MACs,
#         (0): Conv2d(153.6 k, 6.866% Params, 7.53 MMac, 2.309% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.92 k, 0.086% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (3): Conv2d(8.64 k, 0.386% Params, 423.36 KMac, 0.130% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (4): BatchNorm2d(1.92 k, 0.086% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (6): Conv2d(307.2 k, 13.731% Params, 15.05 MMac, 4.619% MACs, 960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(640, 0.029% Params, 31.36 KMac, 0.010% MACs, 320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (last_layers): Sequential(
#     424.97 k, 18.996% Params, 20.33 MMac, 6.239% MACs,
#     (0): Conv2d(409.6 k, 18.309% Params, 20.07 MMac, 6.158% MACs, 320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(2.56 k, 0.114% Params, 125.44 KMac, 0.038% MACs, 1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(0, 0.000% Params, 62.72 KMac, 0.019% MACs, inplace=True)
#     (3): AdaptiveAvgPool2d(0, 0.000% Params, 62.72 KMac, 0.019% MACs, output_size=1)
#     (4): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#     (5): Linear(12.81 k, 0.573% Params, 12.81 KMac, 0.004% MACs, in_features=1280, out_features=10, bias=True)
#   )
# )
# Computational complexity:       325.92 MMac
# Number of parameters:           2.24 M
# --------------------------------------------------
# Warning: module InvertedResidual is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Warning: module MobileNetV2 is treated as a zero-op.
# MobileNetV2(
#   2.35 M, 100.000% Params, 333.2 MMac, 99.981% MACs,
#   (first_layer): Sequential(
#     928, 0.039% Params, 12.04 MMac, 3.613% MACs,
#     (0): Conv2d(864, 0.037% Params, 10.84 MMac, 3.252% MACs, 3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, 0.003% Params, 802.82 KMac, 0.241% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(0, 0.000% Params, 401.41 KMac, 0.120% MACs, inplace=True)
#   )
#   (inverted_residual_blocks): Sequential(
#     1.81 M, 77.001% Params, 300.7 MMac, 90.232% MACs,
#     (0): InvertedResidual(
#       1.98 k, 0.084% Params, 25.69 MMac, 7.709% MACs,
#       (layers): Sequential(
#         1.98 k, 0.084% Params, 25.69 MMac, 7.709% MACs,
#         (0): Conv2d(1.02 k, 0.044% Params, 12.85 MMac, 3.854% MACs, 32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, 0.003% Params, 802.82 KMac, 0.241% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 401.41 KMac, 0.120% MACs, inplace=True)
#         (3): Conv2d(288, 0.012% Params, 3.61 MMac, 1.084% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (4): BatchNorm2d(64, 0.003% Params, 802.82 KMac, 0.241% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 401.41 KMac, 0.120% MACs, inplace=True)
#         (6): Conv2d(512, 0.022% Params, 6.42 MMac, 1.927% MACs, 32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(32, 0.001% Params, 401.41 KMac, 0.120% MACs, 16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): InvertedResidual(
#       5.14 k, 0.218% Params, 33.87 MMac, 10.163% MACs,
#       (layers): Sequential(
#         5.14 k, 0.218% Params, 33.87 MMac, 10.163% MACs,
#         (0): Conv2d(1.54 k, 0.065% Params, 19.27 MMac, 5.782% MACs, 16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(192, 0.008% Params, 2.41 MMac, 0.723% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 1.2 MMac, 0.361% MACs, inplace=True)
#         (3): Conv2d(864, 0.037% Params, 2.71 MMac, 0.813% MACs, 96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (4): BatchNorm2d(192, 0.008% Params, 602.11 KMac, 0.181% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 301.06 KMac, 0.090% MACs, inplace=True)
#         (6): Conv2d(2.3 k, 0.098% Params, 7.23 MMac, 2.168% MACs, 96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(48, 0.002% Params, 150.53 KMac, 0.045% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       8.83 k, 0.375% Params, 28.6 MMac, 8.582% MACs,
#       (layers): Sequential(
#         8.83 k, 0.375% Params, 28.6 MMac, 8.582% MACs,
#         (0): Conv2d(3.46 k, 0.147% Params, 10.84 MMac, 3.252% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(288, 0.012% Params, 903.17 KMac, 0.271% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 451.58 KMac, 0.136% MACs, inplace=True)
#         (3): Conv2d(1.3 k, 0.055% Params, 4.06 MMac, 1.220% MACs, 144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (4): BatchNorm2d(288, 0.012% Params, 903.17 KMac, 0.271% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 451.58 KMac, 0.136% MACs, inplace=True)
#         (6): Conv2d(3.46 k, 0.147% Params, 10.84 MMac, 3.252% MACs, 144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(48, 0.002% Params, 150.53 KMac, 0.045% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       10.0 k, 0.425% Params, 17.21 MMac, 5.164% MACs,
#       (layers): Sequential(
#         10.0 k, 0.425% Params, 17.21 MMac, 5.164% MACs,
#         (0): Conv2d(3.46 k, 0.147% Params, 10.84 MMac, 3.252% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(288, 0.012% Params, 903.17 KMac, 0.271% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 451.58 KMac, 0.136% MACs, inplace=True)
#         (3): Conv2d(1.3 k, 0.055% Params, 1.02 MMac, 0.305% MACs, 144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#         (4): BatchNorm2d(288, 0.012% Params, 225.79 KMac, 0.068% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 112.9 KMac, 0.034% MACs, inplace=True)
#         (6): Conv2d(4.61 k, 0.196% Params, 3.61 MMac, 1.084% MACs, 144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(64, 0.003% Params, 50.18 KMac, 0.015% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       14.85 k, 0.631% Params, 11.94 MMac, 3.583% MACs,
#       (layers): Sequential(
#         14.85 k, 0.631% Params, 11.94 MMac, 3.583% MACs,
#         (0): Conv2d(6.14 k, 0.261% Params, 4.82 MMac, 1.445% MACs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, 0.016% Params, 301.06 KMac, 0.090% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.045% MACs, inplace=True)
#         (3): Conv2d(1.73 k, 0.073% Params, 1.35 MMac, 0.407% MACs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (4): BatchNorm2d(384, 0.016% Params, 301.06 KMac, 0.090% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 150.53 KMac, 0.045% MACs, inplace=True)
#         (6): Conv2d(6.14 k, 0.261% Params, 4.82 MMac, 1.445% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(64, 0.003% Params, 50.18 KMac, 0.015% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       14.85 k, 0.631% Params, 11.94 MMac, 3.583% MACs,
#       (layers): Sequential(
#         14.85 k, 0.631% Params, 11.94 MMac, 3.583% MACs,
#         (0): Conv2d(6.14 k, 0.261% Params, 4.82 MMac, 1.445% MACs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, 0.016% Params, 301.06 KMac, 0.090% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.045% MACs, inplace=True)
#         (3): Conv2d(1.73 k, 0.073% Params, 1.35 MMac, 0.407% MACs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (4): BatchNorm2d(384, 0.016% Params, 301.06 KMac, 0.090% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 150.53 KMac, 0.045% MACs, inplace=True)
#         (6): Conv2d(6.14 k, 0.261% Params, 4.82 MMac, 1.445% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(64, 0.003% Params, 50.18 KMac, 0.015% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       21.06 k, 0.895% Params, 8.15 MMac, 2.447% MACs,
#       (layers): Sequential(
#         21.06 k, 0.895% Params, 8.15 MMac, 2.447% MACs,
#         (0): Conv2d(6.14 k, 0.261% Params, 4.82 MMac, 1.445% MACs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, 0.016% Params, 301.06 KMac, 0.090% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.045% MACs, inplace=True)
#         (3): Conv2d(1.73 k, 0.073% Params, 338.69 KMac, 0.102% MACs, 192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#         (4): BatchNorm2d(384, 0.016% Params, 75.26 KMac, 0.023% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 37.63 KMac, 0.011% MACs, inplace=True)
#         (6): Conv2d(12.29 k, 0.522% Params, 2.41 MMac, 0.723% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(128, 0.005% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       54.27 k, 2.306% Params, 10.79 MMac, 3.237% MACs,
#       (layers): Sequential(
#         54.27 k, 2.306% Params, 10.79 MMac, 3.237% MACs,
#         (0): Conv2d(24.58 k, 1.044% Params, 4.82 MMac, 1.445% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(768, 0.033% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (3): Conv2d(3.46 k, 0.147% Params, 677.38 KMac, 0.203% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(768, 0.033% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (6): Conv2d(24.58 k, 1.044% Params, 4.82 MMac, 1.445% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(128, 0.005% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       54.27 k, 2.306% Params, 10.79 MMac, 3.237% MACs,
#       (layers): Sequential(
#         54.27 k, 2.306% Params, 10.79 MMac, 3.237% MACs,
#         (0): Conv2d(24.58 k, 1.044% Params, 4.82 MMac, 1.445% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(768, 0.033% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (3): Conv2d(3.46 k, 0.147% Params, 677.38 KMac, 0.203% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(768, 0.033% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (6): Conv2d(24.58 k, 1.044% Params, 4.82 MMac, 1.445% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(128, 0.005% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       54.27 k, 2.306% Params, 10.79 MMac, 3.237% MACs,
#       (layers): Sequential(
#         54.27 k, 2.306% Params, 10.79 MMac, 3.237% MACs,
#         (0): Conv2d(24.58 k, 1.044% Params, 4.82 MMac, 1.445% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(768, 0.033% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (3): Conv2d(3.46 k, 0.147% Params, 677.38 KMac, 0.203% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(768, 0.033% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (6): Conv2d(24.58 k, 1.044% Params, 4.82 MMac, 1.445% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(128, 0.005% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       66.62 k, 2.831% Params, 13.21 MMac, 3.964% MACs,
#       (layers): Sequential(
#         66.62 k, 2.831% Params, 13.21 MMac, 3.964% MACs,
#         (0): Conv2d(24.58 k, 1.044% Params, 4.82 MMac, 1.445% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(768, 0.033% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (3): Conv2d(3.46 k, 0.147% Params, 677.38 KMac, 0.203% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(768, 0.033% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (6): Conv2d(36.86 k, 1.567% Params, 7.23 MMac, 2.168% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(192, 0.008% Params, 37.63 KMac, 0.011% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       118.27 k, 5.026% Params, 23.41 MMac, 7.024% MACs,
#       (layers): Sequential(
#         118.27 k, 5.026% Params, 23.41 MMac, 7.024% MACs,
#         (0): Conv2d(55.3 k, 2.350% Params, 10.84 MMac, 3.252% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.15 k, 0.049% Params, 225.79 KMac, 0.068% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.034% MACs, inplace=True)
#         (3): Conv2d(5.18 k, 0.220% Params, 1.02 MMac, 0.305% MACs, 576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (4): BatchNorm2d(1.15 k, 0.049% Params, 225.79 KMac, 0.068% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 112.9 KMac, 0.034% MACs, inplace=True)
#         (6): Conv2d(55.3 k, 2.350% Params, 10.84 MMac, 3.252% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(192, 0.008% Params, 37.63 KMac, 0.011% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       118.27 k, 5.026% Params, 23.41 MMac, 7.024% MACs,
#       (layers): Sequential(
#         118.27 k, 5.026% Params, 23.41 MMac, 7.024% MACs,
#         (0): Conv2d(55.3 k, 2.350% Params, 10.84 MMac, 3.252% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.15 k, 0.049% Params, 225.79 KMac, 0.068% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.034% MACs, inplace=True)
#         (3): Conv2d(5.18 k, 0.220% Params, 1.02 MMac, 0.305% MACs, 576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (4): BatchNorm2d(1.15 k, 0.049% Params, 225.79 KMac, 0.068% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 112.9 KMac, 0.034% MACs, inplace=True)
#         (6): Conv2d(55.3 k, 2.350% Params, 10.84 MMac, 3.252% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(192, 0.008% Params, 37.63 KMac, 0.011% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       155.26 k, 6.598% Params, 16.05 MMac, 4.815% MACs,
#       (layers): Sequential(
#         155.26 k, 6.598% Params, 16.05 MMac, 4.815% MACs,
#         (0): Conv2d(55.3 k, 2.350% Params, 10.84 MMac, 3.252% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.15 k, 0.049% Params, 225.79 KMac, 0.068% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.034% MACs, inplace=True)
#         (3): Conv2d(5.18 k, 0.220% Params, 254.02 KMac, 0.076% MACs, 576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#         (4): BatchNorm2d(1.15 k, 0.049% Params, 56.45 KMac, 0.017% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 28.22 KMac, 0.008% MACs, inplace=True)
#         (6): Conv2d(92.16 k, 3.917% Params, 4.52 MMac, 1.355% MACs, 576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(320, 0.014% Params, 15.68 KMac, 0.005% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       320.0 k, 13.599% Params, 15.77 MMac, 4.733% MACs,
#       (layers): Sequential(
#         320.0 k, 13.599% Params, 15.77 MMac, 4.733% MACs,
#         (0): Conv2d(153.6 k, 6.528% Params, 7.53 MMac, 2.258% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.92 k, 0.082% Params, 94.08 KMac, 0.028% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (3): Conv2d(8.64 k, 0.367% Params, 423.36 KMac, 0.127% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (4): BatchNorm2d(1.92 k, 0.082% Params, 94.08 KMac, 0.028% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (6): Conv2d(153.6 k, 6.528% Params, 7.53 MMac, 2.258% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(320, 0.014% Params, 15.68 KMac, 0.005% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       320.0 k, 13.599% Params, 15.77 MMac, 4.733% MACs,
#       (layers): Sequential(
#         320.0 k, 13.599% Params, 15.77 MMac, 4.733% MACs,
#         (0): Conv2d(153.6 k, 6.528% Params, 7.53 MMac, 2.258% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.92 k, 0.082% Params, 94.08 KMac, 0.028% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (3): Conv2d(8.64 k, 0.367% Params, 423.36 KMac, 0.127% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (4): BatchNorm2d(1.92 k, 0.082% Params, 94.08 KMac, 0.028% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (6): Conv2d(153.6 k, 6.528% Params, 7.53 MMac, 2.258% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(320, 0.014% Params, 15.68 KMac, 0.005% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       473.92 k, 20.141% Params, 23.32 MMac, 6.996% MACs,
#       (layers): Sequential(
#         473.92 k, 20.141% Params, 23.32 MMac, 6.996% MACs,
#         (0): Conv2d(153.6 k, 6.528% Params, 7.53 MMac, 2.258% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.92 k, 0.082% Params, 94.08 KMac, 0.028% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (3): Conv2d(8.64 k, 0.367% Params, 423.36 KMac, 0.127% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (4): BatchNorm2d(1.92 k, 0.082% Params, 94.08 KMac, 0.028% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (6): Conv2d(307.2 k, 13.055% Params, 15.05 MMac, 4.517% MACs, 960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(640, 0.027% Params, 31.36 KMac, 0.009% MACs, 320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (last_layers): Sequential(
#     540.26 k, 22.960% Params, 20.45 MMac, 6.136% MACs,
#     (0): Conv2d(409.6 k, 17.407% Params, 20.07 MMac, 6.022% MACs, 320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(2.56 k, 0.109% Params, 125.44 KMac, 0.038% MACs, 1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(0, 0.000% Params, 62.72 KMac, 0.019% MACs, inplace=True)
#     (3): AdaptiveAvgPool2d(0, 0.000% Params, 62.72 KMac, 0.019% MACs, output_size=1)
#     (4): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#     (5): Linear(128.1 k, 5.444% Params, 128.1 KMac, 0.038% MACs, in_features=1280, out_features=100, bias=True)
#   )
# )
# Computational complexity:       333.26 MMac
# Number of parameters:           2.35 M
# --------------------------------------------------
# Warning: module InvertedResidual is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Warning: module MobileNetV2 is treated as a zero-op.
# MobileNetV2(
#   2.24 M, 100.000% Params, 333.08 MMac, 99.981% MACs,
#   (first_layer): Sequential(
#     928, 0.041% Params, 12.04 MMac, 3.615% MACs,
#     (0): Conv2d(864, 0.039% Params, 10.84 MMac, 3.253% MACs, 3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, 0.003% Params, 802.82 KMac, 0.241% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(0, 0.000% Params, 401.41 KMac, 0.120% MACs, inplace=True)
#   )
#   (inverted_residual_blocks): Sequential(
#     1.81 M, 80.968% Params, 300.7 MMac, 90.263% MACs,
#     (0): InvertedResidual(
#       1.98 k, 0.089% Params, 25.69 MMac, 7.711% MACs,
#       (layers): Sequential(
#         1.98 k, 0.089% Params, 25.69 MMac, 7.711% MACs,
#         (0): Conv2d(1.02 k, 0.046% Params, 12.85 MMac, 3.856% MACs, 32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(64, 0.003% Params, 802.82 KMac, 0.241% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 401.41 KMac, 0.120% MACs, inplace=True)
#         (3): Conv2d(288, 0.013% Params, 3.61 MMac, 1.084% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (4): BatchNorm2d(64, 0.003% Params, 802.82 KMac, 0.241% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 401.41 KMac, 0.120% MACs, inplace=True)
#         (6): Conv2d(512, 0.023% Params, 6.42 MMac, 1.928% MACs, 32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(32, 0.001% Params, 401.41 KMac, 0.120% MACs, 16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): InvertedResidual(
#       5.14 k, 0.230% Params, 33.87 MMac, 10.166% MACs,
#       (layers): Sequential(
#         5.14 k, 0.230% Params, 33.87 MMac, 10.166% MACs,
#         (0): Conv2d(1.54 k, 0.069% Params, 19.27 MMac, 5.784% MACs, 16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(192, 0.009% Params, 2.41 MMac, 0.723% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 1.2 MMac, 0.361% MACs, inplace=True)
#         (3): Conv2d(864, 0.039% Params, 2.71 MMac, 0.813% MACs, 96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (4): BatchNorm2d(192, 0.009% Params, 602.11 KMac, 0.181% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 301.06 KMac, 0.090% MACs, inplace=True)
#         (6): Conv2d(2.3 k, 0.103% Params, 7.23 MMac, 2.169% MACs, 96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(48, 0.002% Params, 150.53 KMac, 0.045% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       8.83 k, 0.395% Params, 28.6 MMac, 8.585% MACs,
#       (layers): Sequential(
#         8.83 k, 0.395% Params, 28.6 MMac, 8.585% MACs,
#         (0): Conv2d(3.46 k, 0.154% Params, 10.84 MMac, 3.253% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(288, 0.013% Params, 903.17 KMac, 0.271% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 451.58 KMac, 0.136% MACs, inplace=True)
#         (3): Conv2d(1.3 k, 0.058% Params, 4.06 MMac, 1.220% MACs, 144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (4): BatchNorm2d(288, 0.013% Params, 903.17 KMac, 0.271% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 451.58 KMac, 0.136% MACs, inplace=True)
#         (6): Conv2d(3.46 k, 0.154% Params, 10.84 MMac, 3.253% MACs, 144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(48, 0.002% Params, 150.53 KMac, 0.045% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       10.0 k, 0.447% Params, 17.21 MMac, 5.166% MACs,
#       (layers): Sequential(
#         10.0 k, 0.447% Params, 17.21 MMac, 5.166% MACs,
#         (0): Conv2d(3.46 k, 0.154% Params, 10.84 MMac, 3.253% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(288, 0.013% Params, 903.17 KMac, 0.271% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 451.58 KMac, 0.136% MACs, inplace=True)
#         (3): Conv2d(1.3 k, 0.058% Params, 1.02 MMac, 0.305% MACs, 144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#         (4): BatchNorm2d(288, 0.013% Params, 225.79 KMac, 0.068% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 112.9 KMac, 0.034% MACs, inplace=True)
#         (6): Conv2d(4.61 k, 0.206% Params, 3.61 MMac, 1.084% MACs, 144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(64, 0.003% Params, 50.18 KMac, 0.015% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       14.85 k, 0.664% Params, 11.94 MMac, 3.585% MACs,
#       (layers): Sequential(
#         14.85 k, 0.664% Params, 11.94 MMac, 3.585% MACs,
#         (0): Conv2d(6.14 k, 0.275% Params, 4.82 MMac, 1.446% MACs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, 0.017% Params, 301.06 KMac, 0.090% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.045% MACs, inplace=True)
#         (3): Conv2d(1.73 k, 0.077% Params, 1.35 MMac, 0.407% MACs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (4): BatchNorm2d(384, 0.017% Params, 301.06 KMac, 0.090% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 150.53 KMac, 0.045% MACs, inplace=True)
#         (6): Conv2d(6.14 k, 0.275% Params, 4.82 MMac, 1.446% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(64, 0.003% Params, 50.18 KMac, 0.015% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       14.85 k, 0.664% Params, 11.94 MMac, 3.585% MACs,
#       (layers): Sequential(
#         14.85 k, 0.664% Params, 11.94 MMac, 3.585% MACs,
#         (0): Conv2d(6.14 k, 0.275% Params, 4.82 MMac, 1.446% MACs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, 0.017% Params, 301.06 KMac, 0.090% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.045% MACs, inplace=True)
#         (3): Conv2d(1.73 k, 0.077% Params, 1.35 MMac, 0.407% MACs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (4): BatchNorm2d(384, 0.017% Params, 301.06 KMac, 0.090% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 150.53 KMac, 0.045% MACs, inplace=True)
#         (6): Conv2d(6.14 k, 0.275% Params, 4.82 MMac, 1.446% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(64, 0.003% Params, 50.18 KMac, 0.015% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       21.06 k, 0.941% Params, 8.15 MMac, 2.447% MACs,
#       (layers): Sequential(
#         21.06 k, 0.941% Params, 8.15 MMac, 2.447% MACs,
#         (0): Conv2d(6.14 k, 0.275% Params, 4.82 MMac, 1.446% MACs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, 0.017% Params, 301.06 KMac, 0.090% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.045% MACs, inplace=True)
#         (3): Conv2d(1.73 k, 0.077% Params, 338.69 KMac, 0.102% MACs, 192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#         (4): BatchNorm2d(384, 0.017% Params, 75.26 KMac, 0.023% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 37.63 KMac, 0.011% MACs, inplace=True)
#         (6): Conv2d(12.29 k, 0.549% Params, 2.41 MMac, 0.723% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(128, 0.006% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       54.27 k, 2.425% Params, 10.79 MMac, 3.238% MACs,
#       (layers): Sequential(
#         54.27 k, 2.425% Params, 10.79 MMac, 3.238% MACs,
#         (0): Conv2d(24.58 k, 1.098% Params, 4.82 MMac, 1.446% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (3): Conv2d(3.46 k, 0.154% Params, 677.38 KMac, 0.203% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (6): Conv2d(24.58 k, 1.098% Params, 4.82 MMac, 1.446% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(128, 0.006% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       54.27 k, 2.425% Params, 10.79 MMac, 3.238% MACs,
#       (layers): Sequential(
#         54.27 k, 2.425% Params, 10.79 MMac, 3.238% MACs,
#         (0): Conv2d(24.58 k, 1.098% Params, 4.82 MMac, 1.446% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (3): Conv2d(3.46 k, 0.154% Params, 677.38 KMac, 0.203% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (6): Conv2d(24.58 k, 1.098% Params, 4.82 MMac, 1.446% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(128, 0.006% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       54.27 k, 2.425% Params, 10.79 MMac, 3.238% MACs,
#       (layers): Sequential(
#         54.27 k, 2.425% Params, 10.79 MMac, 3.238% MACs,
#         (0): Conv2d(24.58 k, 1.098% Params, 4.82 MMac, 1.446% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (3): Conv2d(3.46 k, 0.154% Params, 677.38 KMac, 0.203% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (6): Conv2d(24.58 k, 1.098% Params, 4.82 MMac, 1.446% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(128, 0.006% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       66.62 k, 2.977% Params, 13.21 MMac, 3.965% MACs,
#       (layers): Sequential(
#         66.62 k, 2.977% Params, 13.21 MMac, 3.965% MACs,
#         (0): Conv2d(24.58 k, 1.098% Params, 4.82 MMac, 1.446% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (3): Conv2d(3.46 k, 0.154% Params, 677.38 KMac, 0.203% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(768, 0.034% Params, 150.53 KMac, 0.045% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         (6): Conv2d(36.86 k, 1.647% Params, 7.23 MMac, 2.169% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(192, 0.009% Params, 37.63 KMac, 0.011% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       118.27 k, 5.285% Params, 23.41 MMac, 7.026% MACs,
#       (layers): Sequential(
#         118.27 k, 5.285% Params, 23.41 MMac, 7.026% MACs,
#         (0): Conv2d(55.3 k, 2.471% Params, 10.84 MMac, 3.253% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.15 k, 0.051% Params, 225.79 KMac, 0.068% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.034% MACs, inplace=True)
#         (3): Conv2d(5.18 k, 0.232% Params, 1.02 MMac, 0.305% MACs, 576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (4): BatchNorm2d(1.15 k, 0.051% Params, 225.79 KMac, 0.068% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 112.9 KMac, 0.034% MACs, inplace=True)
#         (6): Conv2d(55.3 k, 2.471% Params, 10.84 MMac, 3.253% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(192, 0.009% Params, 37.63 KMac, 0.011% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       118.27 k, 5.285% Params, 23.41 MMac, 7.026% MACs,
#       (layers): Sequential(
#         118.27 k, 5.285% Params, 23.41 MMac, 7.026% MACs,
#         (0): Conv2d(55.3 k, 2.471% Params, 10.84 MMac, 3.253% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.15 k, 0.051% Params, 225.79 KMac, 0.068% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.034% MACs, inplace=True)
#         (3): Conv2d(5.18 k, 0.232% Params, 1.02 MMac, 0.305% MACs, 576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (4): BatchNorm2d(1.15 k, 0.051% Params, 225.79 KMac, 0.068% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 112.9 KMac, 0.034% MACs, inplace=True)
#         (6): Conv2d(55.3 k, 2.471% Params, 10.84 MMac, 3.253% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(192, 0.009% Params, 37.63 KMac, 0.011% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       155.26 k, 6.938% Params, 16.05 MMac, 4.817% MACs,
#       (layers): Sequential(
#         155.26 k, 6.938% Params, 16.05 MMac, 4.817% MACs,
#         (0): Conv2d(55.3 k, 2.471% Params, 10.84 MMac, 3.253% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.15 k, 0.051% Params, 225.79 KMac, 0.068% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.034% MACs, inplace=True)
#         (3): Conv2d(5.18 k, 0.232% Params, 254.02 KMac, 0.076% MACs, 576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#         (4): BatchNorm2d(1.15 k, 0.051% Params, 56.45 KMac, 0.017% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 28.22 KMac, 0.008% MACs, inplace=True)
#         (6): Conv2d(92.16 k, 4.118% Params, 4.52 MMac, 1.356% MACs, 576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(320, 0.014% Params, 15.68 KMac, 0.005% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       320.0 k, 14.300% Params, 15.77 MMac, 4.735% MACs,
#       (layers): Sequential(
#         320.0 k, 14.300% Params, 15.77 MMac, 4.735% MACs,
#         (0): Conv2d(153.6 k, 6.864% Params, 7.53 MMac, 2.259% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.92 k, 0.086% Params, 94.08 KMac, 0.028% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (3): Conv2d(8.64 k, 0.386% Params, 423.36 KMac, 0.127% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (4): BatchNorm2d(1.92 k, 0.086% Params, 94.08 KMac, 0.028% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (6): Conv2d(153.6 k, 6.864% Params, 7.53 MMac, 2.259% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(320, 0.014% Params, 15.68 KMac, 0.005% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       320.0 k, 14.300% Params, 15.77 MMac, 4.735% MACs,
#       (layers): Sequential(
#         320.0 k, 14.300% Params, 15.77 MMac, 4.735% MACs,
#         (0): Conv2d(153.6 k, 6.864% Params, 7.53 MMac, 2.259% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.92 k, 0.086% Params, 94.08 KMac, 0.028% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (3): Conv2d(8.64 k, 0.386% Params, 423.36 KMac, 0.127% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (4): BatchNorm2d(1.92 k, 0.086% Params, 94.08 KMac, 0.028% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (6): Conv2d(153.6 k, 6.864% Params, 7.53 MMac, 2.259% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(320, 0.014% Params, 15.68 KMac, 0.005% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       473.92 k, 21.178% Params, 23.32 MMac, 6.999% MACs,
#       (layers): Sequential(
#         473.92 k, 21.178% Params, 23.32 MMac, 6.999% MACs,
#         (0): Conv2d(153.6 k, 6.864% Params, 7.53 MMac, 2.259% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1.92 k, 0.086% Params, 94.08 KMac, 0.028% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (3): Conv2d(8.64 k, 0.386% Params, 423.36 KMac, 0.127% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (4): BatchNorm2d(1.92 k, 0.086% Params, 94.08 KMac, 0.028% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(0, 0.000% Params, 47.04 KMac, 0.014% MACs, inplace=True)
#         (6): Conv2d(307.2 k, 13.728% Params, 15.05 MMac, 4.518% MACs, 960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(640, 0.029% Params, 31.36 KMac, 0.009% MACs, 320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (last_layers): Sequential(
#     424.97 k, 18.991% Params, 20.33 MMac, 6.104% MACs,
#     (0): Conv2d(409.6 k, 18.304% Params, 20.07 MMac, 6.025% MACs, 320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(2.56 k, 0.114% Params, 125.44 KMac, 0.038% MACs, 1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(0, 0.000% Params, 62.72 KMac, 0.019% MACs, inplace=True)
#     (3): AdaptiveAvgPool2d(0, 0.000% Params, 62.72 KMac, 0.019% MACs, output_size=1)
#     (4): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#     (5): Linear(12.81 k, 0.572% Params, 12.81 KMac, 0.004% MACs, in_features=1280, out_features=10, bias=True)
#   )
# )
# Computational complexity:       333.14 MMac
# Number of parameters:           2.24 M

# %% [markdown]
# ### GoogleNet

# %% [markdown]
# #### GoogleNet_origin

# %%
googlenet_f, macs_googlenet_f, paras_googlenet_f = get_model_info(Googlenet, channel_f, num_labels_f)
print('-'*50)
googlenet_c100, macs_googlenet_c100, paras_googlenet_c100 = get_model_info(Googlenet, channel_c, num_labels_c100)
print('-'*50)
googlenet_c10, macs_googlenet_c10, paras_googlenet_c10 = get_model_info(Googlenet, channel_c, num_labels_c10)
# Out:
# Warning: module Inception is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   5.98 M, 100.000% Params, 1.51 GMac, 99.594% MACs,
#   (0): Sequential(
#     3.2 k, 0.054% Params, 41.75 MMac, 2.752% MACs,
#     (0): Conv2d(3.2 k, 0.054% Params, 40.14 MMac, 2.646% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.053% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.053% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 1.923% Params, 361.87 MMac, 23.856% MACs,
#     (0): Conv2d(4.16 k, 0.070% Params, 13.05 MMac, 0.860% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.013% MACs, )
#     (2): Conv2d(110.78 k, 1.853% Params, 347.42 MMac, 22.903% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.040% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.040% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     552.43 k, 9.242% Params, 433.83 MMac, 28.600% MACs,
#     (0): Inception(
#       163.7 k, 2.739% Params, 128.49 MMac, 8.470% MACs,
#       (p1_1): Conv2d(12.35 k, 0.207% Params, 9.68 MMac, 0.638% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(18.53 k, 0.310% Params, 14.53 MMac, 0.958% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 1.852% Params, 86.8 MMac, 5.723% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(3.09 k, 0.052% Params, 2.42 MMac, 0.160% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.215% Params, 10.06 MMac, 0.663% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.010% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(6.18 k, 0.103% Params, 4.84 MMac, 0.319% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception(
#       388.74 k, 6.503% Params, 304.97 MMac, 20.105% MACs,
#       (p1_1): Conv2d(32.9 k, 0.550% Params, 25.79 MMac, 1.700% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(32.9 k, 0.550% Params, 25.79 MMac, 1.700% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 3.703% Params, 173.56 MMac, 11.442% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(8.22 k, 0.138% Params, 6.45 MMac, 0.425% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 1.286% Params, 60.29 MMac, 3.974% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 200.7 KMac, 0.013% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(16.45 k, 0.275% Params, 12.9 MMac, 0.850% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 376.32 KMac, 0.025% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     2.81 M, 46.995% Params, 551.26 MMac, 36.341% MACs,
#     (0): Inception(
#       376.18 k, 6.293% Params, 73.82 MMac, 4.867% MACs,
#       (p1_1): Conv2d(92.35 k, 1.545% Params, 18.1 MMac, 1.193% MACs, 480, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(46.18 k, 0.772% Params, 9.05 MMac, 0.597% MACs, 480, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 3.010% Params, 35.26 MMac, 2.325% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(7.7 k, 0.129% Params, 1.51 MMac, 0.099% MACs, 480, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 0.322% Params, 3.77 MMac, 0.249% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 94.08 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(30.78 k, 0.515% Params, 6.03 MMac, 0.398% MACs, 480, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception(
#       449.16 k, 7.514% Params, 88.14 MMac, 5.810% MACs,
#       (p1_1): Conv2d(82.08 k, 1.373% Params, 16.09 MMac, 1.061% MACs, 512, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(57.46 k, 0.961% Params, 11.26 MMac, 0.742% MACs, 512, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 3.781% Params, 44.3 MMac, 2.920% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(12.31 k, 0.206% Params, 2.41 MMac, 0.159% MACs, 512, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.643% Params, 7.54 MMac, 0.497% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(32.83 k, 0.549% Params, 6.44 MMac, 0.424% MACs, 512, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Inception(
#       510.1 k, 8.534% Params, 100.08 MMac, 6.598% MACs,
#       (p1_1): Conv2d(65.66 k, 1.099% Params, 12.87 MMac, 0.848% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(65.66 k, 1.099% Params, 12.87 MMac, 0.848% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 4.938% Params, 57.85 MMac, 3.814% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(12.31 k, 0.206% Params, 2.41 MMac, 0.159% MACs, 512, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.643% Params, 7.54 MMac, 0.497% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(32.83 k, 0.549% Params, 6.44 MMac, 0.424% MACs, 512, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Inception(
#       605.38 k, 10.128% Params, 118.75 MMac, 7.829% MACs,
#       (p1_1): Conv2d(57.46 k, 0.961% Params, 11.26 MMac, 0.742% MACs, 512, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(73.87 k, 1.236% Params, 14.48 MMac, 0.955% MACs, 512, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 6.249% Params, 73.21 MMac, 4.827% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(16.42 k, 0.275% Params, 3.22 MMac, 0.212% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 0.858% Params, 10.05 MMac, 0.662% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(32.83 k, 0.549% Params, 6.44 MMac, 0.424% MACs, 512, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Inception(
#       868.35 k, 14.527% Params, 170.3 MMac, 11.227% MACs,
#       (p1_1): Conv2d(135.42 k, 2.266% Params, 26.54 MMac, 1.750% MACs, 528, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(84.64 k, 1.416% Params, 16.59 MMac, 1.094% MACs, 528, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 7.714% Params, 90.38 MMac, 5.958% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(16.93 k, 0.283% Params, 3.32 MMac, 0.219% MACs, 528, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 1.715% Params, 20.1 MMac, 1.325% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 103.49 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(67.71 k, 1.133% Params, 13.27 MMac, 0.875% MACs, 528, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 163.07 KMac, 0.011% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     2.49 M, 41.615% Params, 122.02 MMac, 8.044% MACs,
#     (0): Inception(
#       1.04 M, 17.456% Params, 51.17 MMac, 3.373% MACs,
#       (p1_1): Conv2d(213.25 k, 3.567% Params, 10.45 MMac, 0.689% MACs, 832, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(133.28 k, 2.230% Params, 6.53 MMac, 0.431% MACs, 832, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 7.714% Params, 22.59 MMac, 1.490% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(26.66 k, 0.446% Params, 1.31 MMac, 0.086% MACs, 832, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 1.715% Params, 5.02 MMac, 0.331% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 40.77 KMac, 0.003% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(106.62 k, 1.784% Params, 5.22 MMac, 0.344% MACs, 832, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception(
#       1.44 M, 24.158% Params, 70.8 MMac, 4.667% MACs,
#       (p1_1): Conv2d(319.87 k, 5.351% Params, 15.67 MMac, 1.033% MACs, 832, 384, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(159.94 k, 2.676% Params, 7.84 MMac, 0.517% MACs, 832, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 11.107% Params, 32.53 MMac, 2.145% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(39.98 k, 0.669% Params, 1.96 MMac, 0.129% MACs, 832, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 2.572% Params, 7.53 MMac, 0.497% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 40.77 KMac, 0.003% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(106.62 k, 1.784% Params, 5.22 MMac, 0.344% MACs, 832, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 50.18 KMac, 0.003% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(10.25 k, 0.171% Params, 10.25 KMac, 0.001% MACs, in_features=1024, out_features=10, bias=True)
# )
# Computational complexity:       1.52 GMac
# Number of parameters:           5.98 M
# --------------------------------------------------
# Warning: module Inception is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   6.08 M, 100.000% Params, 1.59 GMac, 99.614% MACs,
#   (0): Sequential(
#     9.47 k, 0.156% Params, 120.42 MMac, 7.547% MACs,
#     (0): Conv2d(9.47 k, 0.156% Params, 118.82 MMac, 7.446% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.050% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.050% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 1.892% Params, 361.87 MMac, 22.678% MACs,
#     (0): Conv2d(4.16 k, 0.068% Params, 13.05 MMac, 0.818% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.013% MACs, )
#     (2): Conv2d(110.78 k, 1.823% Params, 347.42 MMac, 21.773% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.038% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.038% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     552.43 k, 9.092% Params, 433.83 MMac, 27.188% MACs,
#     (0): Inception(
#       163.7 k, 2.694% Params, 128.49 MMac, 8.052% MACs,
#       (p1_1): Conv2d(12.35 k, 0.203% Params, 9.68 MMac, 0.607% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(18.53 k, 0.305% Params, 14.53 MMac, 0.910% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 1.822% Params, 86.8 MMac, 5.440% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(3.09 k, 0.051% Params, 2.42 MMac, 0.152% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.211% Params, 10.06 MMac, 0.630% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.009% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(6.18 k, 0.102% Params, 4.84 MMac, 0.303% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception(
#       388.74 k, 6.398% Params, 304.97 MMac, 19.112% MACs,
#       (p1_1): Conv2d(32.9 k, 0.541% Params, 25.79 MMac, 1.616% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(32.9 k, 0.541% Params, 25.79 MMac, 1.616% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 3.643% Params, 173.56 MMac, 10.877% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(8.22 k, 0.135% Params, 6.45 MMac, 0.404% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 1.266% Params, 60.29 MMac, 3.778% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 200.7 KMac, 0.013% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(16.45 k, 0.271% Params, 12.9 MMac, 0.808% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 376.32 KMac, 0.024% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     2.81 M, 46.233% Params, 551.26 MMac, 34.547% MACs,
#     (0): Inception(
#       376.18 k, 6.191% Params, 73.82 MMac, 4.627% MACs,
#       (p1_1): Conv2d(92.35 k, 1.520% Params, 18.1 MMac, 1.134% MACs, 480, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(46.18 k, 0.760% Params, 9.05 MMac, 0.567% MACs, 480, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 2.961% Params, 35.26 MMac, 2.210% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(7.7 k, 0.127% Params, 1.51 MMac, 0.095% MACs, 480, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 0.317% Params, 3.77 MMac, 0.236% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 94.08 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(30.78 k, 0.507% Params, 6.03 MMac, 0.378% MACs, 480, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception(
#       449.16 k, 7.392% Params, 88.14 MMac, 5.523% MACs,
#       (p1_1): Conv2d(82.08 k, 1.351% Params, 16.09 MMac, 1.008% MACs, 512, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(57.46 k, 0.946% Params, 11.26 MMac, 0.706% MACs, 512, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 3.720% Params, 44.3 MMac, 2.776% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(12.31 k, 0.203% Params, 2.41 MMac, 0.151% MACs, 512, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.633% Params, 7.54 MMac, 0.472% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(32.83 k, 0.540% Params, 6.44 MMac, 0.403% MACs, 512, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Inception(
#       510.1 k, 8.395% Params, 100.08 MMac, 6.272% MACs,
#       (p1_1): Conv2d(65.66 k, 1.081% Params, 12.87 MMac, 0.807% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(65.66 k, 1.081% Params, 12.87 MMac, 0.807% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 4.858% Params, 57.85 MMac, 3.626% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(12.31 k, 0.203% Params, 2.41 MMac, 0.151% MACs, 512, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.633% Params, 7.54 MMac, 0.472% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(32.83 k, 0.540% Params, 6.44 MMac, 0.403% MACs, 512, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Inception(
#       605.38 k, 9.963% Params, 118.75 MMac, 7.442% MACs,
#       (p1_1): Conv2d(57.46 k, 0.946% Params, 11.26 MMac, 0.706% MACs, 512, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(73.87 k, 1.216% Params, 14.48 MMac, 0.907% MACs, 512, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 6.148% Params, 73.21 MMac, 4.588% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(16.42 k, 0.270% Params, 3.22 MMac, 0.202% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 0.844% Params, 10.05 MMac, 0.630% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(32.83 k, 0.540% Params, 6.44 MMac, 0.403% MACs, 512, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Inception(
#       868.35 k, 14.291% Params, 170.3 MMac, 10.673% MACs,
#       (p1_1): Conv2d(135.42 k, 2.229% Params, 26.54 MMac, 1.663% MACs, 528, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(84.64 k, 1.393% Params, 16.59 MMac, 1.040% MACs, 528, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 7.589% Params, 90.38 MMac, 5.664% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(16.93 k, 0.279% Params, 3.32 MMac, 0.208% MACs, 528, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 1.687% Params, 20.1 MMac, 1.259% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 103.49 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(67.71 k, 1.114% Params, 13.27 MMac, 0.832% MACs, 528, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 163.07 KMac, 0.010% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     2.49 M, 40.940% Params, 122.02 MMac, 7.647% MACs,
#     (0): Inception(
#       1.04 M, 17.173% Params, 51.17 MMac, 3.207% MACs,
#       (p1_1): Conv2d(213.25 k, 3.510% Params, 10.45 MMac, 0.655% MACs, 832, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(133.28 k, 2.194% Params, 6.53 MMac, 0.409% MACs, 832, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 7.589% Params, 22.59 MMac, 1.416% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(26.66 k, 0.439% Params, 1.31 MMac, 0.082% MACs, 832, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 1.687% Params, 5.02 MMac, 0.315% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 40.77 KMac, 0.003% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(106.62 k, 1.755% Params, 5.22 MMac, 0.327% MACs, 832, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception(
#       1.44 M, 23.767% Params, 70.8 MMac, 4.437% MACs,
#       (p1_1): Conv2d(319.87 k, 5.264% Params, 15.67 MMac, 0.982% MACs, 832, 384, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(159.94 k, 2.632% Params, 7.84 MMac, 0.491% MACs, 832, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 10.927% Params, 32.53 MMac, 2.039% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(39.98 k, 0.658% Params, 1.96 MMac, 0.123% MACs, 832, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 2.530% Params, 7.53 MMac, 0.472% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 40.77 KMac, 0.003% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(106.62 k, 1.755% Params, 5.22 MMac, 0.327% MACs, 832, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 50.18 KMac, 0.003% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(102.5 k, 1.687% Params, 102.5 KMac, 0.006% MACs, in_features=1024, out_features=100, bias=True)
# )
# Computational complexity:       1.6 GMac
# Number of parameters:           6.08 M
# --------------------------------------------------
# Warning: module Inception is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   5.98 M, 100.000% Params, 1.59 GMac, 99.614% MACs,
#   (0): Sequential(
#     9.47 k, 0.158% Params, 120.42 MMac, 7.547% MACs,
#     (0): Conv2d(9.47 k, 0.158% Params, 118.82 MMac, 7.447% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.050% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.050% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 1.921% Params, 361.87 MMac, 22.680% MACs,
#     (0): Conv2d(4.16 k, 0.070% Params, 13.05 MMac, 0.818% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.013% MACs, )
#     (2): Conv2d(110.78 k, 1.851% Params, 347.42 MMac, 21.774% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.038% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.038% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     552.43 k, 9.232% Params, 433.83 MMac, 27.190% MACs,
#     (0): Inception(
#       163.7 k, 2.736% Params, 128.49 MMac, 8.053% MACs,
#       (p1_1): Conv2d(12.35 k, 0.206% Params, 9.68 MMac, 0.607% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(18.53 k, 0.310% Params, 14.53 MMac, 0.910% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 1.850% Params, 86.8 MMac, 5.440% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(3.09 k, 0.052% Params, 2.42 MMac, 0.152% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.214% Params, 10.06 MMac, 0.631% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.009% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(6.18 k, 0.103% Params, 4.84 MMac, 0.303% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception(
#       388.74 k, 6.496% Params, 304.97 MMac, 19.114% MACs,
#       (p1_1): Conv2d(32.9 k, 0.550% Params, 25.79 MMac, 1.616% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(32.9 k, 0.550% Params, 25.79 MMac, 1.616% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 3.700% Params, 173.56 MMac, 10.878% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(8.22 k, 0.137% Params, 6.45 MMac, 0.404% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 1.285% Params, 60.29 MMac, 3.778% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 200.7 KMac, 0.013% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(16.45 k, 0.275% Params, 12.9 MMac, 0.808% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 376.32 KMac, 0.024% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     2.81 M, 46.946% Params, 551.26 MMac, 34.549% MACs,
#     (0): Inception(
#       376.18 k, 6.287% Params, 73.82 MMac, 4.627% MACs,
#       (p1_1): Conv2d(92.35 k, 1.543% Params, 18.1 MMac, 1.134% MACs, 480, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(46.18 k, 0.772% Params, 9.05 MMac, 0.567% MACs, 480, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 3.007% Params, 35.26 MMac, 2.210% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(7.7 k, 0.129% Params, 1.51 MMac, 0.095% MACs, 480, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 0.322% Params, 3.77 MMac, 0.236% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 94.08 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(30.78 k, 0.514% Params, 6.03 MMac, 0.378% MACs, 480, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception(
#       449.16 k, 7.506% Params, 88.14 MMac, 5.524% MACs,
#       (p1_1): Conv2d(82.08 k, 1.372% Params, 16.09 MMac, 1.008% MACs, 512, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(57.46 k, 0.960% Params, 11.26 MMac, 0.706% MACs, 512, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 3.777% Params, 44.3 MMac, 2.776% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(12.31 k, 0.206% Params, 2.41 MMac, 0.151% MACs, 512, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.643% Params, 7.54 MMac, 0.472% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(32.83 k, 0.549% Params, 6.44 MMac, 0.403% MACs, 512, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Inception(
#       510.1 k, 8.525% Params, 100.08 MMac, 6.272% MACs,
#       (p1_1): Conv2d(65.66 k, 1.097% Params, 12.87 MMac, 0.807% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(65.66 k, 1.097% Params, 12.87 MMac, 0.807% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 4.933% Params, 57.85 MMac, 3.626% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(12.31 k, 0.206% Params, 2.41 MMac, 0.151% MACs, 512, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.643% Params, 7.54 MMac, 0.472% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(32.83 k, 0.549% Params, 6.44 MMac, 0.403% MACs, 512, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Inception(
#       605.38 k, 10.117% Params, 118.75 MMac, 7.443% MACs,
#       (p1_1): Conv2d(57.46 k, 0.960% Params, 11.26 MMac, 0.706% MACs, 512, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(73.87 k, 1.235% Params, 14.48 MMac, 0.907% MACs, 512, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 6.242% Params, 73.21 MMac, 4.589% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(16.42 k, 0.274% Params, 3.22 MMac, 0.202% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 0.857% Params, 10.05 MMac, 0.630% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(32.83 k, 0.549% Params, 6.44 MMac, 0.403% MACs, 512, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Inception(
#       868.35 k, 14.512% Params, 170.3 MMac, 10.673% MACs,
#       (p1_1): Conv2d(135.42 k, 2.263% Params, 26.54 MMac, 1.664% MACs, 528, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(84.64 k, 1.414% Params, 16.59 MMac, 1.040% MACs, 528, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 7.706% Params, 90.38 MMac, 5.664% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(16.93 k, 0.283% Params, 3.32 MMac, 0.208% MACs, 528, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 1.713% Params, 20.1 MMac, 1.259% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 103.49 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(67.71 k, 1.132% Params, 13.27 MMac, 0.832% MACs, 528, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 163.07 KMac, 0.010% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     2.49 M, 41.571% Params, 122.02 MMac, 7.647% MACs,
#     (0): Inception(
#       1.04 M, 17.438% Params, 51.17 MMac, 3.207% MACs,
#       (p1_1): Conv2d(213.25 k, 3.564% Params, 10.45 MMac, 0.655% MACs, 832, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(133.28 k, 2.227% Params, 6.53 MMac, 0.409% MACs, 832, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 7.706% Params, 22.59 MMac, 1.416% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(26.66 k, 0.445% Params, 1.31 MMac, 0.082% MACs, 832, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 1.713% Params, 5.02 MMac, 0.315% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 40.77 KMac, 0.003% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(106.62 k, 1.782% Params, 5.22 MMac, 0.327% MACs, 832, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception(
#       1.44 M, 24.133% Params, 70.8 MMac, 4.437% MACs,
#       (p1_1): Conv2d(319.87 k, 5.346% Params, 15.67 MMac, 0.982% MACs, 832, 384, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(159.94 k, 2.673% Params, 7.84 MMac, 0.491% MACs, 832, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 11.096% Params, 32.53 MMac, 2.039% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(39.98 k, 0.668% Params, 1.96 MMac, 0.123% MACs, 832, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 2.569% Params, 7.53 MMac, 0.472% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 40.77 KMac, 0.003% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(106.62 k, 1.782% Params, 5.22 MMac, 0.327% MACs, 832, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 50.18 KMac, 0.003% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(10.25 k, 0.171% Params, 10.25 KMac, 0.001% MACs, in_features=1024, out_features=10, bias=True)
# )
# Computational complexity:       1.6 GMac
# Number of parameters:           5.98 M

# %% [markdown]
# #### GoogleNet_mod1

# %%
googlenet_mod1_f, macs_googlenet_mod1_f, paras_googlenet_mod1_f = get_model_info(Googlenet_mod1, channel_f, num_labels_f)
print('-'*50)
googlenet_mod1_c100, macs_googlenet_mod1_c100, paras_googlenet_mod1_c100 = get_model_info(Googlenet_mod1, channel_c, num_labels_c100)
print('-'*50)
googlenet_mod1_c10, macs_googlenet_mod1_c10, paras_googlenet_mod1_c10 = get_model_info(Googlenet_mod1, channel_c, num_labels_c10)
# Out:
# Warning: module Inception_mod1 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   4.61 M, 100.000% Params, 1.31 GMac, 99.589% MACs,
#   (0): Sequential(
#     3.2 k, 0.069% Params, 41.75 MMac, 3.168% MACs,
#     (0): Conv2d(3.2 k, 0.069% Params, 40.14 MMac, 3.046% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.061% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.061% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 2.493% Params, 361.87 MMac, 27.463% MACs,
#     (0): Conv2d(4.16 k, 0.090% Params, 13.05 MMac, 0.990% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.015% MACs, )
#     (2): Conv2d(110.78 k, 2.403% Params, 347.42 MMac, 26.366% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.046% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.046% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     492.85 k, 10.691% Params, 386.97 MMac, 29.368% MACs,
#     (0): Inception_mod1(
#       151.34 k, 3.283% Params, 118.8 MMac, 9.016% MACs,
#       (p2_1): Conv2d(18.53 k, 0.402% Params, 14.53 MMac, 1.102% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 2.402% Params, 86.8 MMac, 6.588% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(3.09 k, 0.067% Params, 2.42 MMac, 0.184% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.278% Params, 10.06 MMac, 0.763% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.011% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(6.18 k, 0.134% Params, 4.84 MMac, 0.367% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod1(
#       341.5 k, 7.408% Params, 267.89 MMac, 20.330% MACs,
#       (p2_1): Conv2d(24.7 k, 0.536% Params, 19.37 MMac, 1.470% MACs, 192, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 4.802% Params, 173.56 MMac, 13.172% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(6.18 k, 0.134% Params, 4.84 MMac, 0.367% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 1.668% Params, 60.29 MMac, 4.575% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.011% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(12.35 k, 0.268% Params, 9.68 MMac, 0.735% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 275.97 KMac, 0.021% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     2.21 M, 48.031% Params, 434.44 MMac, 32.970% MACs,
#     (0): Inception_mod1(
#       261.3 k, 5.668% Params, 51.28 MMac, 3.892% MACs,
#       (p2_1): Conv2d(33.89 k, 0.735% Params, 6.64 MMac, 0.504% MACs, 352, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 3.903% Params, 35.26 MMac, 2.676% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(5.65 k, 0.123% Params, 1.11 MMac, 0.084% MACs, 352, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 0.418% Params, 3.77 MMac, 0.286% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 68.99 KMac, 0.005% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(22.59 k, 0.490% Params, 4.43 MMac, 0.336% MACs, 352, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod1(
#       328.68 k, 7.130% Params, 64.48 MMac, 4.894% MACs,
#       (p2_1): Conv2d(35.95 k, 0.780% Params, 7.05 MMac, 0.535% MACs, 320, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 4.903% Params, 44.3 MMac, 3.362% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(7.7 k, 0.167% Params, 1.51 MMac, 0.115% MACs, 320, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.834% Params, 7.54 MMac, 0.572% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 62.72 KMac, 0.005% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(20.54 k, 0.446% Params, 4.03 MMac, 0.306% MACs, 320, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Inception_mod1(
#       409.88 k, 8.891% Params, 80.41 MMac, 6.102% MACs,
#       (p2_1): Conv2d(45.18 k, 0.980% Params, 8.86 MMac, 0.672% MACs, 352, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 6.403% Params, 57.85 MMac, 4.391% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(8.47 k, 0.184% Params, 1.66 MMac, 0.126% MACs, 352, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.834% Params, 7.54 MMac, 0.572% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 68.99 KMac, 0.005% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(22.59 k, 0.490% Params, 4.43 MMac, 0.336% MACs, 352, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Inception_mod1(
#       517.2 k, 11.219% Params, 101.45 MMac, 7.699% MACs,
#       (p2_1): Conv2d(55.44 k, 1.203% Params, 10.87 MMac, 0.825% MACs, 384, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 8.103% Params, 73.21 MMac, 5.556% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(12.32 k, 0.267% Params, 2.41 MMac, 0.183% MACs, 384, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 1.112% Params, 10.05 MMac, 0.763% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 75.26 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(24.64 k, 0.535% Params, 4.83 MMac, 0.367% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Inception_mod1(
#       697.09 k, 15.122% Params, 136.71 MMac, 10.375% MACs,
#       (p2_1): Conv2d(66.72 k, 1.447% Params, 13.08 MMac, 0.992% MACs, 416, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 10.003% Params, 90.38 MMac, 6.859% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(13.34 k, 0.289% Params, 2.62 MMac, 0.198% MACs, 416, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 2.224% Params, 20.1 MMac, 1.525% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 81.54 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(53.38 k, 1.158% Params, 10.46 MMac, 0.794% MACs, 416, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 112.9 KMac, 0.009% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     1.78 M, 38.576% Params, 87.22 MMac, 6.620% MACs,
#     (0): Inception_mod1(
#       748.29 k, 16.232% Params, 36.69 MMac, 2.785% MACs,
#       (p2_1): Conv2d(92.32 k, 2.003% Params, 4.52 MMac, 0.343% MACs, 576, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 10.003% Params, 22.59 MMac, 1.715% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(18.46 k, 0.401% Params, 904.74 KMac, 0.069% MACs, 576, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 2.224% Params, 5.02 MMac, 0.381% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 28.22 KMac, 0.002% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(73.86 k, 1.602% Params, 3.62 MMac, 0.275% MACs, 576, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod1(
#       1.03 M, 22.344% Params, 50.5 MMac, 3.832% MACs,
#       (p2_1): Conv2d(110.78 k, 2.403% Params, 5.43 MMac, 0.412% MACs, 576, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 14.403% Params, 32.53 MMac, 2.469% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(27.7 k, 0.601% Params, 1.36 MMac, 0.103% MACs, 576, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 3.335% Params, 7.53 MMac, 0.572% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 28.22 KMac, 0.002% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(73.86 k, 1.602% Params, 3.62 MMac, 0.275% MACs, 576, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 31.36 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(6.41 k, 0.139% Params, 6.41 KMac, 0.000% MACs, in_features=640, out_features=10, bias=True)
# )
# Computational complexity:       1.32 GMac
# Number of parameters:           4.61 M
# --------------------------------------------------
# Warning: module Inception_mod1 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   4.67 M, 100.000% Params, 1.39 GMac, 99.612% MACs,
#   (0): Sequential(
#     9.47 k, 0.203% Params, 120.42 MMac, 8.624% MACs,
#     (0): Conv2d(9.47 k, 0.203% Params, 118.82 MMac, 8.509% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.057% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.057% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 2.459% Params, 361.87 MMac, 25.914% MACs,
#     (0): Conv2d(4.16 k, 0.089% Params, 13.05 MMac, 0.934% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.014% MACs, )
#     (2): Conv2d(110.78 k, 2.370% Params, 347.42 MMac, 24.879% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.043% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.043% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     492.85 k, 10.545% Params, 386.97 MMac, 27.712% MACs,
#     (0): Inception_mod1(
#       151.34 k, 3.238% Params, 118.8 MMac, 8.508% MACs,
#       (p2_1): Conv2d(18.53 k, 0.396% Params, 14.53 MMac, 1.040% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 2.369% Params, 86.8 MMac, 6.216% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(3.09 k, 0.066% Params, 2.42 MMac, 0.173% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.275% Params, 10.06 MMac, 0.720% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.011% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(6.18 k, 0.132% Params, 4.84 MMac, 0.347% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod1(
#       341.5 k, 7.307% Params, 267.89 MMac, 19.184% MACs,
#       (p2_1): Conv2d(24.7 k, 0.529% Params, 19.37 MMac, 1.387% MACs, 192, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 4.737% Params, 173.56 MMac, 12.429% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(6.18 k, 0.132% Params, 4.84 MMac, 0.347% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 1.645% Params, 60.29 MMac, 4.317% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.011% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(12.35 k, 0.264% Params, 9.68 MMac, 0.693% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 275.97 KMac, 0.020% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     2.21 M, 47.374% Params, 434.44 MMac, 31.111% MACs,
#     (0): Inception_mod1(
#       261.3 k, 5.591% Params, 51.28 MMac, 3.672% MACs,
#       (p2_1): Conv2d(33.89 k, 0.725% Params, 6.64 MMac, 0.476% MACs, 352, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 3.850% Params, 35.26 MMac, 2.525% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(5.65 k, 0.121% Params, 1.11 MMac, 0.079% MACs, 352, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 0.412% Params, 3.77 MMac, 0.270% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 68.99 KMac, 0.005% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(22.59 k, 0.483% Params, 4.43 MMac, 0.317% MACs, 352, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod1(
#       328.68 k, 7.032% Params, 64.48 MMac, 4.618% MACs,
#       (p2_1): Conv2d(35.95 k, 0.769% Params, 7.05 MMac, 0.505% MACs, 320, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 4.836% Params, 44.3 MMac, 3.172% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(7.7 k, 0.165% Params, 1.51 MMac, 0.108% MACs, 320, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.823% Params, 7.54 MMac, 0.540% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 62.72 KMac, 0.004% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(20.54 k, 0.440% Params, 4.03 MMac, 0.288% MACs, 320, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Inception_mod1(
#       409.88 k, 8.770% Params, 80.41 MMac, 5.758% MACs,
#       (p2_1): Conv2d(45.18 k, 0.967% Params, 8.86 MMac, 0.634% MACs, 352, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 6.315% Params, 57.85 MMac, 4.143% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(8.47 k, 0.181% Params, 1.66 MMac, 0.119% MACs, 352, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.823% Params, 7.54 MMac, 0.540% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 68.99 KMac, 0.005% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(22.59 k, 0.483% Params, 4.43 MMac, 0.317% MACs, 352, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Inception_mod1(
#       517.2 k, 11.066% Params, 101.45 MMac, 7.265% MACs,
#       (p2_1): Conv2d(55.44 k, 1.186% Params, 10.87 MMac, 0.778% MACs, 384, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 7.992% Params, 73.21 MMac, 5.243% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(12.32 k, 0.264% Params, 2.41 MMac, 0.173% MACs, 384, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 1.097% Params, 10.05 MMac, 0.720% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 75.26 KMac, 0.005% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(24.64 k, 0.527% Params, 4.83 MMac, 0.346% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Inception_mod1(
#       697.09 k, 14.915% Params, 136.71 MMac, 9.790% MACs,
#       (p2_1): Conv2d(66.72 k, 1.428% Params, 13.08 MMac, 0.936% MACs, 416, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.866% Params, 90.38 MMac, 6.472% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(13.34 k, 0.286% Params, 2.62 MMac, 0.187% MACs, 416, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 2.194% Params, 20.1 MMac, 1.439% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 81.54 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(53.38 k, 1.142% Params, 10.46 MMac, 0.749% MACs, 416, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 112.9 KMac, 0.008% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     1.78 M, 38.048% Params, 87.22 MMac, 6.246% MACs,
#     (0): Inception_mod1(
#       748.29 k, 16.010% Params, 36.69 MMac, 2.628% MACs,
#       (p2_1): Conv2d(92.32 k, 1.975% Params, 4.52 MMac, 0.324% MACs, 576, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.866% Params, 22.59 MMac, 1.618% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(18.46 k, 0.395% Params, 904.74 KMac, 0.065% MACs, 576, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 2.194% Params, 5.02 MMac, 0.360% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 28.22 KMac, 0.002% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(73.86 k, 1.580% Params, 3.62 MMac, 0.259% MACs, 576, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod1(
#       1.03 M, 22.038% Params, 50.5 MMac, 3.616% MACs,
#       (p2_1): Conv2d(110.78 k, 2.370% Params, 5.43 MMac, 0.389% MACs, 576, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 14.205% Params, 32.53 MMac, 2.330% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(27.7 k, 0.593% Params, 1.36 MMac, 0.097% MACs, 576, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 3.289% Params, 7.53 MMac, 0.539% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 28.22 KMac, 0.002% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(73.86 k, 1.580% Params, 3.62 MMac, 0.259% MACs, 576, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 31.36 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(64.1 k, 1.371% Params, 64.1 KMac, 0.005% MACs, in_features=640, out_features=100, bias=True)
# )
# Computational complexity:       1.4 GMac
# Number of parameters:           4.67 M
# --------------------------------------------------
# Warning: module Inception_mod1 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   4.62 M, 100.000% Params, 1.39 GMac, 99.612% MACs,
#   (0): Sequential(
#     9.47 k, 0.205% Params, 120.42 MMac, 8.624% MACs,
#     (0): Conv2d(9.47 k, 0.205% Params, 118.82 MMac, 8.509% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.057% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.057% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 2.490% Params, 361.87 MMac, 25.915% MACs,
#     (0): Conv2d(4.16 k, 0.090% Params, 13.05 MMac, 0.934% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.014% MACs, )
#     (2): Conv2d(110.78 k, 2.400% Params, 347.42 MMac, 24.880% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.043% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.043% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     492.85 k, 10.677% Params, 386.97 MMac, 27.713% MACs,
#     (0): Inception_mod1(
#       151.34 k, 3.279% Params, 118.8 MMac, 8.508% MACs,
#       (p2_1): Conv2d(18.53 k, 0.401% Params, 14.53 MMac, 1.040% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 2.399% Params, 86.8 MMac, 6.217% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(3.09 k, 0.067% Params, 2.42 MMac, 0.173% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.278% Params, 10.06 MMac, 0.720% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.011% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(6.18 k, 0.134% Params, 4.84 MMac, 0.347% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod1(
#       341.5 k, 7.398% Params, 267.89 MMac, 19.185% MACs,
#       (p2_1): Conv2d(24.7 k, 0.535% Params, 19.37 MMac, 1.387% MACs, 192, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 4.796% Params, 173.56 MMac, 12.429% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(6.18 k, 0.134% Params, 4.84 MMac, 0.347% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 1.666% Params, 60.29 MMac, 4.317% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.011% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(12.35 k, 0.268% Params, 9.68 MMac, 0.694% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 275.97 KMac, 0.020% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     2.21 M, 47.966% Params, 434.44 MMac, 31.113% MACs,
#     (0): Inception_mod1(
#       261.3 k, 5.661% Params, 51.28 MMac, 3.673% MACs,
#       (p2_1): Conv2d(33.89 k, 0.734% Params, 6.64 MMac, 0.476% MACs, 352, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 3.898% Params, 35.26 MMac, 2.525% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(5.65 k, 0.122% Params, 1.11 MMac, 0.079% MACs, 352, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 0.417% Params, 3.77 MMac, 0.270% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 68.99 KMac, 0.005% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(22.59 k, 0.489% Params, 4.43 MMac, 0.317% MACs, 352, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod1(
#       328.68 k, 7.120% Params, 64.48 MMac, 4.618% MACs,
#       (p2_1): Conv2d(35.95 k, 0.779% Params, 7.05 MMac, 0.505% MACs, 320, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 4.896% Params, 44.3 MMac, 3.172% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(7.7 k, 0.167% Params, 1.51 MMac, 0.108% MACs, 320, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.833% Params, 7.54 MMac, 0.540% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 62.72 KMac, 0.004% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(20.54 k, 0.445% Params, 4.03 MMac, 0.288% MACs, 320, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Inception_mod1(
#       409.88 k, 8.879% Params, 80.41 MMac, 5.758% MACs,
#       (p2_1): Conv2d(45.18 k, 0.979% Params, 8.86 MMac, 0.634% MACs, 352, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 6.394% Params, 57.85 MMac, 4.143% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(8.47 k, 0.184% Params, 1.66 MMac, 0.119% MACs, 352, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.833% Params, 7.54 MMac, 0.540% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 68.99 KMac, 0.005% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(22.59 k, 0.489% Params, 4.43 MMac, 0.317% MACs, 352, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Inception_mod1(
#       517.2 k, 11.204% Params, 101.45 MMac, 7.265% MACs,
#       (p2_1): Conv2d(55.44 k, 1.201% Params, 10.87 MMac, 0.778% MACs, 384, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 8.092% Params, 73.21 MMac, 5.243% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(12.32 k, 0.267% Params, 2.41 MMac, 0.173% MACs, 384, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 1.111% Params, 10.05 MMac, 0.720% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 75.26 KMac, 0.005% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(24.64 k, 0.534% Params, 4.83 MMac, 0.346% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Inception_mod1(
#       697.09 k, 15.101% Params, 136.71 MMac, 9.791% MACs,
#       (p2_1): Conv2d(66.72 k, 1.445% Params, 13.08 MMac, 0.937% MACs, 416, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.989% Params, 90.38 MMac, 6.473% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(13.34 k, 0.289% Params, 2.62 MMac, 0.187% MACs, 416, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 2.221% Params, 20.1 MMac, 1.439% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 81.54 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(53.38 k, 1.156% Params, 10.46 MMac, 0.749% MACs, 416, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 112.9 KMac, 0.008% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     1.78 M, 38.524% Params, 87.22 MMac, 6.247% MACs,
#     (0): Inception_mod1(
#       748.29 k, 16.210% Params, 36.69 MMac, 2.628% MACs,
#       (p2_1): Conv2d(92.32 k, 2.000% Params, 4.52 MMac, 0.324% MACs, 576, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.989% Params, 22.59 MMac, 1.618% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(18.46 k, 0.400% Params, 904.74 KMac, 0.065% MACs, 576, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 2.221% Params, 5.02 MMac, 0.360% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 28.22 KMac, 0.002% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(73.86 k, 1.600% Params, 3.62 MMac, 0.259% MACs, 576, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod1(
#       1.03 M, 22.313% Params, 50.5 MMac, 3.616% MACs,
#       (p2_1): Conv2d(110.78 k, 2.400% Params, 5.43 MMac, 0.389% MACs, 576, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 14.383% Params, 32.53 MMac, 2.330% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(27.7 k, 0.600% Params, 1.36 MMac, 0.097% MACs, 576, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 3.330% Params, 7.53 MMac, 0.539% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 28.22 KMac, 0.002% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(73.86 k, 1.600% Params, 3.62 MMac, 0.259% MACs, 576, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 31.36 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(6.41 k, 0.139% Params, 6.41 KMac, 0.000% MACs, in_features=640, out_features=10, bias=True)
# )
# Computational complexity:       1.4 GMac
# Number of parameters:           4.62 M

# %% [markdown]
# #### GoogleNet_mod2

# %%
googlenet_mod2_f, macs_googlenet_mod2_f, paras_googlenet_mod2_f = get_model_info(Googlenet_mod2, channel_f, num_labels_f)
print('-'*50)
googlenet_mod2_c100, macs_googlenet_mod2_c100, paras_googlenet_mod2_c100 = get_model_info(Googlenet_mod2, channel_c, num_labels_c100)
print('-'*50)
googlenet_mod2_c10, macs_googlenet_mod2_c10, paras_googlenet_mod2_c10 = get_model_info(Googlenet_mod2, channel_c, num_labels_c10)
# Out:
# Warning: module Inception_mod2 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   5.03 M, 100.000% Params, 673.18 MMac, 99.306% MACs,
#   (0): Sequential(
#     3.2 k, 0.064% Params, 41.75 MMac, 6.158% MACs,
#     (0): Conv2d(3.2 k, 0.064% Params, 40.14 MMac, 5.922% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.118% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.118% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 2.287% Params, 361.87 MMac, 53.383% MACs,
#     (0): Conv2d(4.16 k, 0.083% Params, 13.05 MMac, 1.924% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.030% MACs, )
#     (2): Conv2d(110.78 k, 2.205% Params, 347.42 MMac, 51.251% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.089% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.089% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     507.38 k, 10.097% Params, 110.42 MMac, 16.290% MACs,
#     (0): Inception_mod2(
#       163.7 k, 3.258% Params, 27.16 MMac, 4.006% MACs,
#       (p1_1): Conv2d(12.35 k, 0.246% Params, 9.68 MMac, 1.429% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(18.53 k, 0.369% Params, 0.0 Mac, 0.000% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 2.203% Params, 0.0 Mac, 0.000% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(3.09 k, 0.061% Params, 2.42 MMac, 0.357% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.255% Params, 10.06 MMac, 1.484% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.022% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(6.18 k, 0.123% Params, 4.84 MMac, 0.714% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod2(
#       343.68 k, 6.839% Params, 83.04 MMac, 12.250% MACs,
#       (p1_1): Conv2d(16.51 k, 0.329% Params, 12.95 MMac, 1.910% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(16.51 k, 0.329% Params, 0.0 Mac, 0.000% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 4.405% Params, 0.0 Mac, 0.000% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(4.13 k, 0.082% Params, 3.24 MMac, 0.477% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 1.530% Params, 60.29 MMac, 8.893% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.015% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(8.26 k, 0.164% Params, 6.47 MMac, 0.955% MACs, 128, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 225.79 KMac, 0.033% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     2.33 M, 46.379% Params, 121.96 MMac, 17.991% MACs,
#     (0): Inception_mod2(
#       305.52 k, 6.080% Params, 19.24 MMac, 2.838% MACs,
#       (p1_1): Conv2d(55.49 k, 1.104% Params, 10.88 MMac, 1.604% MACs, 288, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(27.74 k, 0.552% Params, 0.0 Mac, 0.000% MACs, 288, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 3.580% Params, 0.0 Mac, 0.000% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(4.62 k, 0.092% Params, 906.3 KMac, 0.134% MACs, 288, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 0.383% Params, 3.77 MMac, 0.557% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 56.45 KMac, 0.008% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(18.5 k, 0.368% Params, 3.63 MMac, 0.535% MACs, 288, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod2(
#       374.28 k, 7.448% Params, 22.42 MMac, 3.308% MACs,
#       (p1_1): Conv2d(48.8 k, 0.971% Params, 9.56 MMac, 1.411% MACs, 304, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(34.16 k, 0.680% Params, 0.0 Mac, 0.000% MACs, 304, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 4.498% Params, 0.0 Mac, 0.000% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(7.32 k, 0.146% Params, 1.43 MMac, 0.212% MACs, 304, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.765% Params, 7.54 MMac, 1.112% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 59.58 KMac, 0.009% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(19.52 k, 0.388% Params, 3.83 MMac, 0.564% MACs, 304, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Inception_mod2(
#       433.05 k, 8.618% Params, 19.83 MMac, 2.925% MACs,
#       (p1_1): Conv2d(36.99 k, 0.736% Params, 7.25 MMac, 1.070% MACs, 288, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(36.99 k, 0.736% Params, 0.0 Mac, 0.000% MACs, 288, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 5.874% Params, 0.0 Mac, 0.000% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(6.94 k, 0.138% Params, 1.36 MMac, 0.201% MACs, 288, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.765% Params, 7.54 MMac, 1.112% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 56.45 KMac, 0.008% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(18.5 k, 0.368% Params, 3.63 MMac, 0.535% MACs, 288, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Inception_mod2(
#       515.26 k, 10.254% Params, 20.58 MMac, 3.035% MACs,
#       (p1_1): Conv2d(28.78 k, 0.573% Params, 5.64 MMac, 0.832% MACs, 256, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(37.01 k, 0.736% Params, 0.0 Mac, 0.000% MACs, 256, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 7.433% Params, 0.0 Mac, 0.000% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(8.22 k, 0.164% Params, 1.61 MMac, 0.238% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 1.020% Params, 10.05 MMac, 1.482% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 50.18 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(16.45 k, 0.327% Params, 3.22 MMac, 0.476% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Inception_mod2(
#       702.46 k, 13.979% Params, 39.79 MMac, 5.870% MACs,
#       (p1_1): Conv2d(61.7 k, 1.228% Params, 12.09 MMac, 1.784% MACs, 240, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(38.56 k, 0.767% Params, 0.0 Mac, 0.000% MACs, 240, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.176% Params, 0.0 Mac, 0.000% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(7.71 k, 0.153% Params, 1.51 MMac, 0.223% MACs, 240, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 2.040% Params, 20.1 MMac, 2.964% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 47.04 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(30.85 k, 0.614% Params, 6.05 MMac, 0.892% MACs, 240, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.015% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     2.06 M, 41.046% Params, 37.17 MMac, 5.484% MACs,
#     (0): Inception_mod2(
#       859.14 k, 17.097% Params, 15.51 MMac, 2.287% MACs,
#       (p1_1): Conv2d(131.33 k, 2.613% Params, 6.44 MMac, 0.949% MACs, 512, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(82.08 k, 1.633% Params, 0.0 Mac, 0.000% MACs, 512, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.176% Params, 0.0 Mac, 0.000% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(16.42 k, 0.327% Params, 804.38 KMac, 0.119% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 2.040% Params, 5.02 MMac, 0.741% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 25.09 KMac, 0.004% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(65.66 k, 1.307% Params, 3.22 MMac, 0.475% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod2(
#       1.2 M, 23.949% Params, 21.63 MMac, 3.191% MACs,
#       (p1_1): Conv2d(196.99 k, 3.920% Params, 9.65 MMac, 1.424% MACs, 512, 384, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(98.5 k, 1.960% Params, 0.0 Mac, 0.000% MACs, 512, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 13.212% Params, 0.0 Mac, 0.000% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(24.62 k, 0.490% Params, 1.21 MMac, 0.178% MACs, 512, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 3.059% Params, 7.53 MMac, 1.111% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 25.09 KMac, 0.004% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(65.66 k, 1.307% Params, 3.22 MMac, 0.475% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 31.36 KMac, 0.005% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(6.41 k, 0.128% Params, 6.41 KMac, 0.001% MACs, in_features=640, out_features=10, bias=True)
# )
# Computational complexity:       677.88 MMac
# Number of parameters:           5.03 M
# --------------------------------------------------
# Warning: module Inception_mod2 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   5.09 M, 100.000% Params, 751.91 MMac, 99.379% MACs,
#   (0): Sequential(
#     9.47 k, 0.186% Params, 120.42 MMac, 15.916% MACs,
#     (0): Conv2d(9.47 k, 0.186% Params, 118.82 MMac, 15.704% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.106% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.106% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 2.259% Params, 361.87 MMac, 47.828% MACs,
#     (0): Conv2d(4.16 k, 0.082% Params, 13.05 MMac, 1.724% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.027% MACs, )
#     (2): Conv2d(110.78 k, 2.177% Params, 347.42 MMac, 45.918% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.080% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.080% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     507.38 k, 9.970% Params, 110.42 MMac, 14.595% MACs,
#     (0): Inception_mod2(
#       163.7 k, 3.217% Params, 27.16 MMac, 3.589% MACs,
#       (p1_1): Conv2d(12.35 k, 0.243% Params, 9.68 MMac, 1.280% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(18.53 k, 0.364% Params, 0.0 Mac, 0.000% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 2.176% Params, 0.0 Mac, 0.000% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(3.09 k, 0.061% Params, 2.42 MMac, 0.320% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.252% Params, 10.06 MMac, 1.330% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.020% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(6.18 k, 0.121% Params, 4.84 MMac, 0.640% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod2(
#       343.68 k, 6.753% Params, 83.04 MMac, 10.975% MACs,
#       (p1_1): Conv2d(16.51 k, 0.324% Params, 12.95 MMac, 1.711% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(16.51 k, 0.324% Params, 0.0 Mac, 0.000% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 4.350% Params, 0.0 Mac, 0.000% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(4.13 k, 0.081% Params, 3.24 MMac, 0.428% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 1.511% Params, 60.29 MMac, 7.968% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.013% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(8.26 k, 0.162% Params, 6.47 MMac, 0.855% MACs, 128, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 225.79 KMac, 0.030% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     2.33 M, 45.796% Params, 121.96 MMac, 16.119% MACs,
#     (0): Inception_mod2(
#       305.52 k, 6.003% Params, 19.24 MMac, 2.542% MACs,
#       (p1_1): Conv2d(55.49 k, 1.090% Params, 10.88 MMac, 1.437% MACs, 288, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(27.74 k, 0.545% Params, 0.0 Mac, 0.000% MACs, 288, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 3.535% Params, 0.0 Mac, 0.000% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(4.62 k, 0.091% Params, 906.3 KMac, 0.120% MACs, 288, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 0.378% Params, 3.77 MMac, 0.499% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 56.45 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(18.5 k, 0.363% Params, 3.63 MMac, 0.479% MACs, 288, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod2(
#       374.28 k, 7.355% Params, 22.42 MMac, 2.964% MACs,
#       (p1_1): Conv2d(48.8 k, 0.959% Params, 9.56 MMac, 1.264% MACs, 304, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(34.16 k, 0.671% Params, 0.0 Mac, 0.000% MACs, 304, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 4.441% Params, 0.0 Mac, 0.000% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(7.32 k, 0.144% Params, 1.43 MMac, 0.190% MACs, 304, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.756% Params, 7.54 MMac, 0.996% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 59.58 KMac, 0.008% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(19.52 k, 0.384% Params, 3.83 MMac, 0.506% MACs, 304, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Inception_mod2(
#       433.05 k, 8.509% Params, 19.83 MMac, 2.621% MACs,
#       (p1_1): Conv2d(36.99 k, 0.727% Params, 7.25 MMac, 0.958% MACs, 288, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(36.99 k, 0.727% Params, 0.0 Mac, 0.000% MACs, 288, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 5.800% Params, 0.0 Mac, 0.000% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(6.94 k, 0.136% Params, 1.36 MMac, 0.180% MACs, 288, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.756% Params, 7.54 MMac, 0.996% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 56.45 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(18.5 k, 0.363% Params, 3.63 MMac, 0.479% MACs, 288, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Inception_mod2(
#       515.26 k, 10.125% Params, 20.58 MMac, 2.719% MACs,
#       (p1_1): Conv2d(28.78 k, 0.566% Params, 5.64 MMac, 0.746% MACs, 256, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(37.01 k, 0.727% Params, 0.0 Mac, 0.000% MACs, 256, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 7.340% Params, 0.0 Mac, 0.000% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(8.22 k, 0.162% Params, 1.61 MMac, 0.213% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 1.007% Params, 10.05 MMac, 1.328% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 50.18 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(16.45 k, 0.323% Params, 3.22 MMac, 0.426% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Inception_mod2(
#       702.46 k, 13.803% Params, 39.79 MMac, 5.259% MACs,
#       (p1_1): Conv2d(61.7 k, 1.212% Params, 12.09 MMac, 1.598% MACs, 240, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(38.56 k, 0.758% Params, 0.0 Mac, 0.000% MACs, 240, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.061% Params, 0.0 Mac, 0.000% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(7.71 k, 0.152% Params, 1.51 MMac, 0.200% MACs, 240, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 2.015% Params, 20.1 MMac, 2.656% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 47.04 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(30.85 k, 0.606% Params, 6.05 MMac, 0.799% MACs, 240, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.013% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     2.06 M, 40.530% Params, 37.17 MMac, 4.913% MACs,
#     (0): Inception_mod2(
#       859.14 k, 16.882% Params, 15.51 MMac, 2.049% MACs,
#       (p1_1): Conv2d(131.33 k, 2.581% Params, 6.44 MMac, 0.851% MACs, 512, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(82.08 k, 1.613% Params, 0.0 Mac, 0.000% MACs, 512, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.061% Params, 0.0 Mac, 0.000% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(16.42 k, 0.323% Params, 804.38 KMac, 0.106% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 2.015% Params, 5.02 MMac, 0.664% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 25.09 KMac, 0.003% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(65.66 k, 1.290% Params, 3.22 MMac, 0.425% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod2(
#       1.2 M, 23.648% Params, 21.63 MMac, 2.859% MACs,
#       (p1_1): Conv2d(196.99 k, 3.871% Params, 9.65 MMac, 1.276% MACs, 512, 384, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(98.5 k, 1.935% Params, 0.0 Mac, 0.000% MACs, 512, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 13.046% Params, 0.0 Mac, 0.000% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(24.62 k, 0.484% Params, 1.21 MMac, 0.159% MACs, 512, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 3.021% Params, 7.53 MMac, 0.996% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 25.09 KMac, 0.003% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(65.66 k, 1.290% Params, 3.22 MMac, 0.425% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 31.36 KMac, 0.004% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(64.1 k, 1.260% Params, 64.1 KMac, 0.008% MACs, in_features=640, out_features=100, bias=True)
# )
# Computational complexity:       756.61 MMac
# Number of parameters:           5.09 M
# --------------------------------------------------
# Warning: module Inception_mod2 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   5.03 M, 100.000% Params, 751.85 MMac, 99.379% MACs,
#   (0): Sequential(
#     9.47 k, 0.188% Params, 120.42 MMac, 15.917% MACs,
#     (0): Conv2d(9.47 k, 0.188% Params, 118.82 MMac, 15.705% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.106% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.106% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 2.285% Params, 361.87 MMac, 47.831% MACs,
#     (0): Conv2d(4.16 k, 0.083% Params, 13.05 MMac, 1.724% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.027% MACs, )
#     (2): Conv2d(110.78 k, 2.202% Params, 347.42 MMac, 45.921% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.080% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.080% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     507.38 k, 10.084% Params, 110.42 MMac, 14.596% MACs,
#     (0): Inception_mod2(
#       163.7 k, 3.254% Params, 27.16 MMac, 3.590% MACs,
#       (p1_1): Conv2d(12.35 k, 0.246% Params, 9.68 MMac, 1.280% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(18.53 k, 0.368% Params, 0.0 Mac, 0.000% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 2.201% Params, 0.0 Mac, 0.000% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(3.09 k, 0.061% Params, 2.42 MMac, 0.320% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.255% Params, 10.06 MMac, 1.330% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.020% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(6.18 k, 0.123% Params, 4.84 MMac, 0.640% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod2(
#       343.68 k, 6.831% Params, 83.04 MMac, 10.976% MACs,
#       (p1_1): Conv2d(16.51 k, 0.328% Params, 12.95 MMac, 1.711% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(16.51 k, 0.328% Params, 0.0 Mac, 0.000% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 4.400% Params, 0.0 Mac, 0.000% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(4.13 k, 0.082% Params, 3.24 MMac, 0.428% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 1.528% Params, 60.29 MMac, 7.969% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.013% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(8.26 k, 0.164% Params, 6.47 MMac, 0.856% MACs, 128, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 225.79 KMac, 0.030% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     2.33 M, 46.321% Params, 121.96 MMac, 16.120% MACs,
#     (0): Inception_mod2(
#       305.52 k, 6.072% Params, 19.24 MMac, 2.543% MACs,
#       (p1_1): Conv2d(55.49 k, 1.103% Params, 10.88 MMac, 1.438% MACs, 288, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(27.74 k, 0.551% Params, 0.0 Mac, 0.000% MACs, 288, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 3.576% Params, 0.0 Mac, 0.000% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(4.62 k, 0.092% Params, 906.3 KMac, 0.120% MACs, 288, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 0.383% Params, 3.77 MMac, 0.499% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 56.45 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(18.5 k, 0.368% Params, 3.63 MMac, 0.479% MACs, 288, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod2(
#       374.28 k, 7.439% Params, 22.42 MMac, 2.964% MACs,
#       (p1_1): Conv2d(48.8 k, 0.970% Params, 9.56 MMac, 1.264% MACs, 304, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(34.16 k, 0.679% Params, 0.0 Mac, 0.000% MACs, 304, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 4.492% Params, 0.0 Mac, 0.000% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(7.32 k, 0.145% Params, 1.43 MMac, 0.190% MACs, 304, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.764% Params, 7.54 MMac, 0.996% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 59.58 KMac, 0.008% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(19.52 k, 0.388% Params, 3.83 MMac, 0.506% MACs, 304, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Inception_mod2(
#       433.05 k, 8.607% Params, 19.83 MMac, 2.621% MACs,
#       (p1_1): Conv2d(36.99 k, 0.735% Params, 7.25 MMac, 0.958% MACs, 288, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(36.99 k, 0.735% Params, 0.0 Mac, 0.000% MACs, 288, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 5.867% Params, 0.0 Mac, 0.000% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(6.94 k, 0.138% Params, 1.36 MMac, 0.180% MACs, 288, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.764% Params, 7.54 MMac, 0.996% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 56.45 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(18.5 k, 0.368% Params, 3.63 MMac, 0.479% MACs, 288, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Inception_mod2(
#       515.26 k, 10.241% Params, 20.58 MMac, 2.720% MACs,
#       (p1_1): Conv2d(28.78 k, 0.572% Params, 5.64 MMac, 0.746% MACs, 256, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(37.01 k, 0.736% Params, 0.0 Mac, 0.000% MACs, 256, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 7.424% Params, 0.0 Mac, 0.000% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(8.22 k, 0.163% Params, 1.61 MMac, 0.213% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 1.019% Params, 10.05 MMac, 1.328% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 50.18 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(16.45 k, 0.327% Params, 3.22 MMac, 0.426% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Inception_mod2(
#       702.46 k, 13.962% Params, 39.79 MMac, 5.260% MACs,
#       (p1_1): Conv2d(61.7 k, 1.226% Params, 12.09 MMac, 1.598% MACs, 240, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(38.56 k, 0.766% Params, 0.0 Mac, 0.000% MACs, 240, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.165% Params, 0.0 Mac, 0.000% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(7.71 k, 0.153% Params, 1.51 MMac, 0.200% MACs, 240, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 2.038% Params, 20.1 MMac, 2.656% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 47.04 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(30.85 k, 0.613% Params, 6.05 MMac, 0.799% MACs, 240, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.013% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     2.06 M, 40.994% Params, 37.17 MMac, 4.913% MACs,
#     (0): Inception_mod2(
#       859.14 k, 17.076% Params, 15.51 MMac, 2.050% MACs,
#       (p1_1): Conv2d(131.33 k, 2.610% Params, 6.44 MMac, 0.851% MACs, 512, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(82.08 k, 1.631% Params, 0.0 Mac, 0.000% MACs, 512, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.165% Params, 0.0 Mac, 0.000% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(16.42 k, 0.326% Params, 804.38 KMac, 0.106% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 2.038% Params, 5.02 MMac, 0.664% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 25.09 KMac, 0.003% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(65.66 k, 1.305% Params, 3.22 MMac, 0.425% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod2(
#       1.2 M, 23.919% Params, 21.63 MMac, 2.860% MACs,
#       (p1_1): Conv2d(196.99 k, 3.915% Params, 9.65 MMac, 1.276% MACs, 512, 384, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(98.5 k, 1.958% Params, 0.0 Mac, 0.000% MACs, 512, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 13.196% Params, 0.0 Mac, 0.000% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(24.62 k, 0.489% Params, 1.21 MMac, 0.159% MACs, 512, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 3.055% Params, 7.53 MMac, 0.996% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (p4_1): MaxPool2d(0, 0.000% Params, 25.09 KMac, 0.003% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(65.66 k, 1.305% Params, 3.22 MMac, 0.425% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 31.36 KMac, 0.004% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(6.41 k, 0.127% Params, 6.41 KMac, 0.001% MACs, in_features=640, out_features=10, bias=True)
# )
# Computational complexity:       756.56 MMac
# Number of parameters:           5.03 M

# %% [markdown]
# #### GoogleNet_mod3

# %%
googlenet_mod3_f, macs_googlenet_mod3_f, paras_googlenet_mod3_f = get_model_info(Googlenet_mod3, channel_f, num_labels_f)
print('-'*50)
googlenet_mod3_c100, macs_googlenet_mod3_c100, paras_googlenet_mod3_c100 = get_model_info(Googlenet_mod3, channel_c, num_labels_c100)
print('-'*50)
googlenet_mod3_c10, macs_googlenet_mod3_c10, paras_googlenet_mod3_c10 = get_model_info(Googlenet_mod3, channel_c, num_labels_c10)
# Out:
# Warning: module Inception_mod3 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   4.94 M, 100.000% Params, 1.31 GMac, 99.569% MACs,
#   (0): Sequential(
#     3.2 k, 0.065% Params, 41.75 MMac, 3.165% MACs,
#     (0): Conv2d(3.2 k, 0.065% Params, 40.14 MMac, 3.044% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.061% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.061% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 2.326% Params, 361.87 MMac, 27.439% MACs,
#     (0): Conv2d(4.16 k, 0.084% Params, 13.05 MMac, 0.989% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.015% MACs, )
#     (2): Conv2d(110.78 k, 2.242% Params, 347.42 MMac, 26.343% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.046% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.046% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     441.15 k, 8.928% Params, 346.49 MMac, 26.273% MACs,
#     (0): Inception_mod3(
#       147.78 k, 2.991% Params, 116.01 MMac, 8.796% MACs,
#       (p1_1): Conv2d(12.35 k, 0.250% Params, 9.68 MMac, 0.734% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(18.53 k, 0.375% Params, 14.53 MMac, 1.101% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 2.241% Params, 86.8 MMac, 6.582% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.011% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(6.18 k, 0.125% Params, 4.84 MMac, 0.367% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod3(
#       293.38 k, 5.938% Params, 230.18 MMac, 17.454% MACs,
#       (p1_1): Conv2d(28.8 k, 0.583% Params, 22.58 MMac, 1.712% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(28.8 k, 0.583% Params, 22.58 MMac, 1.712% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 4.480% Params, 173.56 MMac, 13.160% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 175.62 KMac, 0.013% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(14.4 k, 0.291% Params, 11.29 MMac, 0.856% MACs, 224, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 301.06 KMac, 0.023% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     2.37 M, 47.922% Params, 464.67 MMac, 35.233% MACs,
#     (0): Inception_mod3(
#       315.44 k, 6.384% Params, 61.9 MMac, 4.694% MACs,
#       (p1_1): Conv2d(73.92 k, 1.496% Params, 14.49 MMac, 1.099% MACs, 384, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(36.96 k, 0.748% Params, 7.24 MMac, 0.549% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 3.641% Params, 35.26 MMac, 2.674% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 75.26 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(24.64 k, 0.499% Params, 4.83 MMac, 0.366% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod3(
#       382.26 k, 7.736% Params, 75.01 MMac, 5.688% MACs,
#       (p1_1): Conv2d(74.4 k, 1.506% Params, 14.58 MMac, 1.106% MACs, 464, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(52.08 k, 1.054% Params, 10.21 MMac, 0.774% MACs, 464, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 4.574% Params, 44.3 MMac, 3.359% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 90.94 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(29.76 k, 0.602% Params, 5.83 MMac, 0.442% MACs, 464, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Inception_mod3(
#       438.85 k, 8.882% Params, 86.1 MMac, 6.529% MACs,
#       (p1_1): Conv2d(57.47 k, 1.163% Params, 11.26 MMac, 0.854% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(57.47 k, 1.163% Params, 11.26 MMac, 0.854% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 5.974% Params, 57.85 MMac, 4.387% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 87.81 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(28.74 k, 0.582% Params, 5.63 MMac, 0.427% MACs, 448, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Inception_mod3(
#       517.22 k, 10.468% Params, 101.46 MMac, 7.693% MACs,
#       (p1_1): Conv2d(50.29 k, 1.018% Params, 9.86 MMac, 0.747% MACs, 448, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(64.66 k, 1.309% Params, 12.67 MMac, 0.961% MACs, 448, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 7.560% Params, 73.21 MMac, 5.551% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 87.81 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(28.74 k, 0.582% Params, 5.63 MMac, 0.427% MACs, 448, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Inception_mod3(
#       714.08 k, 14.452% Params, 140.05 MMac, 10.619% MACs,
#       (p1_1): Conv2d(119.04 k, 2.409% Params, 23.33 MMac, 1.769% MACs, 464, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(74.4 k, 1.506% Params, 14.58 MMac, 1.106% MACs, 464, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.333% Params, 90.38 MMac, 6.853% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 90.94 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(59.52 k, 1.205% Params, 11.67 MMac, 0.885% MACs, 464, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 137.98 KMac, 0.010% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     2.0 M, 40.577% Params, 98.35 MMac, 7.458% MACs,
#     (0): Inception_mod3(
#       844.64 k, 17.095% Params, 41.42 MMac, 3.141% MACs,
#       (p1_1): Conv2d(180.48 k, 3.653% Params, 8.84 MMac, 0.671% MACs, 704, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(112.8 k, 2.283% Params, 5.53 MMac, 0.419% MACs, 704, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.333% Params, 22.59 MMac, 1.713% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 34.5 KMac, 0.003% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(90.24 k, 1.826% Params, 4.42 MMac, 0.335% MACs, 704, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod3(
#       1.16 M, 23.482% Params, 56.89 MMac, 4.313% MACs,
#       (p1_1): Conv2d(270.72 k, 5.479% Params, 13.27 MMac, 1.006% MACs, 704, 384, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(135.36 k, 2.740% Params, 6.63 MMac, 0.503% MACs, 704, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 13.437% Params, 32.53 MMac, 2.467% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 34.5 KMac, 0.003% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(90.24 k, 1.826% Params, 4.42 MMac, 0.335% MACs, 704, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 43.9 KMac, 0.003% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(8.97 k, 0.182% Params, 8.97 KMac, 0.001% MACs, in_features=896, out_features=10, bias=True)
# )
# Computational complexity:       1.32 GMac
# Number of parameters:           4.94 M
# --------------------------------------------------
# Warning: module Inception_mod3 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   5.03 M, 100.000% Params, 1.39 GMac, 99.593% MACs,
#   (0): Sequential(
#     9.47 k, 0.188% Params, 120.42 MMac, 8.616% MACs,
#     (0): Conv2d(9.47 k, 0.188% Params, 118.82 MMac, 8.502% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.057% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.057% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 2.286% Params, 361.87 MMac, 25.893% MACs,
#     (0): Conv2d(4.16 k, 0.083% Params, 13.05 MMac, 0.933% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.014% MACs, )
#     (2): Conv2d(110.78 k, 2.203% Params, 347.42 MMac, 24.859% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.043% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.043% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     441.15 k, 8.774% Params, 346.49 MMac, 24.792% MACs,
#     (0): Inception_mod3(
#       147.78 k, 2.939% Params, 116.01 MMac, 8.301% MACs,
#       (p1_1): Conv2d(12.35 k, 0.246% Params, 9.68 MMac, 0.693% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(18.53 k, 0.368% Params, 14.53 MMac, 1.039% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 2.202% Params, 86.8 MMac, 6.211% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.011% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(6.18 k, 0.123% Params, 4.84 MMac, 0.346% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod3(
#       293.38 k, 5.835% Params, 230.18 MMac, 16.470% MACs,
#       (p1_1): Conv2d(28.8 k, 0.573% Params, 22.58 MMac, 1.616% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(28.8 k, 0.573% Params, 22.58 MMac, 1.616% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 4.403% Params, 173.56 MMac, 12.419% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 175.62 KMac, 0.013% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(14.4 k, 0.286% Params, 11.29 MMac, 0.808% MACs, 224, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 301.06 KMac, 0.022% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     2.37 M, 47.093% Params, 464.67 MMac, 33.248% MACs,
#     (0): Inception_mod3(
#       315.44 k, 6.274% Params, 61.9 MMac, 4.429% MACs,
#       (p1_1): Conv2d(73.92 k, 1.470% Params, 14.49 MMac, 1.037% MACs, 384, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(36.96 k, 0.735% Params, 7.24 MMac, 0.518% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 3.578% Params, 35.26 MMac, 2.523% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 75.26 KMac, 0.005% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(24.64 k, 0.490% Params, 4.83 MMac, 0.346% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod3(
#       382.26 k, 7.603% Params, 75.01 MMac, 5.367% MACs,
#       (p1_1): Conv2d(74.4 k, 1.480% Params, 14.58 MMac, 1.043% MACs, 464, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(52.08 k, 1.036% Params, 10.21 MMac, 0.730% MACs, 464, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 4.495% Params, 44.3 MMac, 3.170% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 90.94 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(29.76 k, 0.592% Params, 5.83 MMac, 0.417% MACs, 464, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Inception_mod3(
#       438.85 k, 8.728% Params, 86.1 MMac, 6.161% MACs,
#       (p1_1): Conv2d(57.47 k, 1.143% Params, 11.26 MMac, 0.806% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(57.47 k, 1.143% Params, 11.26 MMac, 0.806% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 5.870% Params, 57.85 MMac, 4.140% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 87.81 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(28.74 k, 0.572% Params, 5.63 MMac, 0.403% MACs, 448, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Inception_mod3(
#       517.22 k, 10.287% Params, 101.46 MMac, 7.260% MACs,
#       (p1_1): Conv2d(50.29 k, 1.000% Params, 9.86 MMac, 0.705% MACs, 448, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(64.66 k, 1.286% Params, 12.67 MMac, 0.907% MACs, 448, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 7.429% Params, 73.21 MMac, 5.239% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 87.81 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(28.74 k, 0.572% Params, 5.63 MMac, 0.403% MACs, 448, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Inception_mod3(
#       714.08 k, 14.202% Params, 140.05 MMac, 10.021% MACs,
#       (p1_1): Conv2d(119.04 k, 2.368% Params, 23.33 MMac, 1.669% MACs, 464, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(74.4 k, 1.480% Params, 14.58 MMac, 1.043% MACs, 464, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.171% Params, 90.38 MMac, 6.467% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 90.94 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(59.52 k, 1.184% Params, 11.67 MMac, 0.835% MACs, 464, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 137.98 KMac, 0.010% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     2.0 M, 39.875% Params, 98.35 MMac, 7.037% MACs,
#     (0): Inception_mod3(
#       844.64 k, 16.799% Params, 41.42 MMac, 2.964% MACs,
#       (p1_1): Conv2d(180.48 k, 3.589% Params, 8.84 MMac, 0.633% MACs, 704, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(112.8 k, 2.243% Params, 5.53 MMac, 0.395% MACs, 704, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.171% Params, 22.59 MMac, 1.617% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 34.5 KMac, 0.002% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(90.24 k, 1.795% Params, 4.42 MMac, 0.316% MACs, 704, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod3(
#       1.16 M, 23.076% Params, 56.89 MMac, 4.070% MACs,
#       (p1_1): Conv2d(270.72 k, 5.384% Params, 13.27 MMac, 0.949% MACs, 704, 384, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(135.36 k, 2.692% Params, 6.63 MMac, 0.475% MACs, 704, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 13.205% Params, 32.53 MMac, 2.328% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 34.5 KMac, 0.002% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(90.24 k, 1.795% Params, 4.42 MMac, 0.316% MACs, 704, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 43.9 KMac, 0.003% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(89.7 k, 1.784% Params, 89.7 KMac, 0.006% MACs, in_features=896, out_features=100, bias=True)
# )
# Computational complexity:       1.4 GMac
# Number of parameters:           5.03 M
# --------------------------------------------------
# Warning: module Inception_mod3 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   4.95 M, 100.000% Params, 1.39 GMac, 99.593% MACs,
#   (0): Sequential(
#     9.47 k, 0.191% Params, 120.42 MMac, 8.617% MACs,
#     (0): Conv2d(9.47 k, 0.191% Params, 118.82 MMac, 8.502% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.057% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.057% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 2.323% Params, 361.87 MMac, 25.894% MACs,
#     (0): Conv2d(4.16 k, 0.084% Params, 13.05 MMac, 0.934% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.014% MACs, )
#     (2): Conv2d(110.78 k, 2.239% Params, 347.42 MMac, 24.860% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.043% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.043% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     441.15 k, 8.917% Params, 346.49 MMac, 24.794% MACs,
#     (0): Inception_mod3(
#       147.78 k, 2.987% Params, 116.01 MMac, 8.301% MACs,
#       (p1_1): Conv2d(12.35 k, 0.250% Params, 9.68 MMac, 0.693% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(18.53 k, 0.375% Params, 14.53 MMac, 1.039% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 2.238% Params, 86.8 MMac, 6.211% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.011% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(6.18 k, 0.125% Params, 4.84 MMac, 0.346% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod3(
#       293.38 k, 5.930% Params, 230.18 MMac, 16.471% MACs,
#       (p1_1): Conv2d(28.8 k, 0.582% Params, 22.58 MMac, 1.616% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(28.8 k, 0.582% Params, 22.58 MMac, 1.616% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 4.475% Params, 173.56 MMac, 12.419% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 175.62 KMac, 0.013% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(14.4 k, 0.291% Params, 11.29 MMac, 0.808% MACs, 224, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 301.06 KMac, 0.022% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     2.37 M, 47.862% Params, 464.67 MMac, 33.250% MACs,
#     (0): Inception_mod3(
#       315.44 k, 6.376% Params, 61.9 MMac, 4.429% MACs,
#       (p1_1): Conv2d(73.92 k, 1.494% Params, 14.49 MMac, 1.037% MACs, 384, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(36.96 k, 0.747% Params, 7.24 MMac, 0.518% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 3.637% Params, 35.26 MMac, 2.523% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 75.26 KMac, 0.005% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(24.64 k, 0.498% Params, 4.83 MMac, 0.346% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod3(
#       382.26 k, 7.727% Params, 75.01 MMac, 5.368% MACs,
#       (p1_1): Conv2d(74.4 k, 1.504% Params, 14.58 MMac, 1.043% MACs, 464, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(52.08 k, 1.053% Params, 10.21 MMac, 0.730% MACs, 464, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 4.568% Params, 44.3 MMac, 3.170% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 90.94 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(29.76 k, 0.602% Params, 5.83 MMac, 0.417% MACs, 464, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Inception_mod3(
#       438.85 k, 8.871% Params, 86.1 MMac, 6.161% MACs,
#       (p1_1): Conv2d(57.47 k, 1.162% Params, 11.26 MMac, 0.806% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(57.47 k, 1.162% Params, 11.26 MMac, 0.806% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 5.966% Params, 57.85 MMac, 4.140% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 87.81 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(28.74 k, 0.581% Params, 5.63 MMac, 0.403% MACs, 448, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Inception_mod3(
#       517.22 k, 10.455% Params, 101.46 MMac, 7.260% MACs,
#       (p1_1): Conv2d(50.29 k, 1.016% Params, 9.86 MMac, 0.705% MACs, 448, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(64.66 k, 1.307% Params, 12.67 MMac, 0.907% MACs, 448, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 7.550% Params, 73.21 MMac, 5.239% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 87.81 KMac, 0.006% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(28.74 k, 0.581% Params, 5.63 MMac, 0.403% MACs, 448, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Inception_mod3(
#       714.08 k, 14.434% Params, 140.05 MMac, 10.022% MACs,
#       (p1_1): Conv2d(119.04 k, 2.406% Params, 23.33 MMac, 1.670% MACs, 464, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(74.4 k, 1.504% Params, 14.58 MMac, 1.043% MACs, 464, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.321% Params, 90.38 MMac, 6.467% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 90.94 KMac, 0.007% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(59.52 k, 1.203% Params, 11.67 MMac, 0.835% MACs, 464, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 137.98 KMac, 0.010% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     2.0 M, 40.525% Params, 98.35 MMac, 7.038% MACs,
#     (0): Inception_mod3(
#       844.64 k, 17.073% Params, 41.42 MMac, 2.964% MACs,
#       (p1_1): Conv2d(180.48 k, 3.648% Params, 8.84 MMac, 0.633% MACs, 704, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(112.8 k, 2.280% Params, 5.53 MMac, 0.396% MACs, 704, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 9.321% Params, 22.59 MMac, 1.617% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 34.5 KMac, 0.002% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(90.24 k, 1.824% Params, 4.42 MMac, 0.316% MACs, 704, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception_mod3(
#       1.16 M, 23.452% Params, 56.89 MMac, 4.071% MACs,
#       (p1_1): Conv2d(270.72 k, 5.472% Params, 13.27 MMac, 0.949% MACs, 704, 384, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(135.36 k, 2.736% Params, 6.63 MMac, 0.475% MACs, 704, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 13.420% Params, 32.53 MMac, 2.328% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): MaxPool2d(0, 0.000% Params, 34.5 KMac, 0.002% MACs, kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (p4_2): Conv2d(90.24 k, 1.824% Params, 4.42 MMac, 0.316% MACs, 704, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 43.9 KMac, 0.003% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(8.97 k, 0.181% Params, 8.97 KMac, 0.001% MACs, in_features=896, out_features=10, bias=True)
# )
# Computational complexity:       1.4 GMac
# Number of parameters:           4.95 M

# %% [markdown]
# #### GoogleNet_mod4

# %%
googlenet_mod4_f, macs_googlenet_mod4_f, paras_googlenet_mod4_f = get_model_info(Googlenet_mod4, channel_f, num_labels_f)
print('-'*50)
googlenet_mod4_c100, macs_googlenet_mod4_c100, paras_googlenet_mod4_c100 = get_model_info(Googlenet_mod4, channel_c, num_labels_c100)
print('-'*50)
googlenet_mod4_c10, macs_googlenet_mod4_c10, paras_googlenet_mod4_c10 = get_model_info(Googlenet_mod4, channel_c, num_labels_c10)
# Out:
# Warning: module Inception_mod4 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   5.29 M, 100.000% Params, 1.41 GMac, 99.648% MACs,
#   (0): Sequential(
#     3.2 k, 0.060% Params, 41.75 MMac, 2.953% MACs,
#     (0): Conv2d(3.2 k, 0.060% Params, 40.14 MMac, 2.839% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.057% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.057% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 2.171% Params, 361.87 MMac, 25.598% MACs,
#     (0): Conv2d(4.16 k, 0.079% Params, 13.05 MMac, 0.923% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.014% MACs, )
#     (2): Conv2d(110.78 k, 2.093% Params, 347.42 MMac, 24.575% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.043% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.043% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     520.59 k, 9.834% Params, 408.47 MMac, 28.894% MACs,
#     (0): Inception_mod4(
#       157.52 k, 2.976% Params, 123.5 MMac, 8.736% MACs,
#       (p1_1): Conv2d(12.35 k, 0.233% Params, 9.68 MMac, 0.685% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(18.53 k, 0.350% Params, 14.53 MMac, 1.028% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 2.092% Params, 86.8 MMac, 6.140% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(3.09 k, 0.058% Params, 2.42 MMac, 0.171% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.242% Params, 10.06 MMac, 0.712% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod4(
#       363.07 k, 6.859% Params, 284.65 MMac, 20.135% MACs,
#       (p1_1): Conv2d(28.8 k, 0.544% Params, 22.58 MMac, 1.597% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(28.8 k, 0.544% Params, 22.58 MMac, 1.597% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 4.182% Params, 173.56 MMac, 12.277% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(7.2 k, 0.136% Params, 5.64 MMac, 0.399% MACs, 224, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 1.453% Params, 60.29 MMac, 4.264% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 326.14 KMac, 0.023% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     2.51 M, 47.393% Params, 491.85 MMac, 34.792% MACs,
#     (0): Inception_mod4(
#       325.94 k, 6.157% Params, 63.88 MMac, 4.519% MACs,
#       (p1_1): Conv2d(80.06 k, 1.512% Params, 15.69 MMac, 1.110% MACs, 416, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(40.03 k, 0.756% Params, 7.85 MMac, 0.555% MACs, 416, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 3.399% Params, 35.26 MMac, 2.494% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(6.67 k, 0.126% Params, 1.31 MMac, 0.093% MACs, 416, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 0.364% Params, 3.77 MMac, 0.267% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod4(
#       397.38 k, 7.507% Params, 77.89 MMac, 5.510% MACs,
#       (p1_1): Conv2d(71.84 k, 1.357% Params, 14.08 MMac, 0.996% MACs, 448, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(50.29 k, 0.950% Params, 9.86 MMac, 0.697% MACs, 448, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 4.270% Params, 44.3 MMac, 3.134% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(10.78 k, 0.204% Params, 2.11 MMac, 0.149% MACs, 448, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.727% Params, 7.54 MMac, 0.533% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): Inception_mod4(
#       459.35 k, 8.678% Params, 90.03 MMac, 6.369% MACs,
#       (p1_1): Conv2d(57.47 k, 1.086% Params, 11.26 MMac, 0.797% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(57.47 k, 1.086% Params, 11.26 MMac, 0.797% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 5.576% Params, 57.85 MMac, 4.092% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(10.78 k, 0.204% Params, 2.11 MMac, 0.149% MACs, 448, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.727% Params, 7.54 MMac, 0.533% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (3): Inception_mod4(
#       554.11 k, 10.468% Params, 108.61 MMac, 7.682% MACs,
#       (p1_1): Conv2d(50.29 k, 0.950% Params, 9.86 MMac, 0.697% MACs, 448, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(64.66 k, 1.221% Params, 12.67 MMac, 0.896% MACs, 448, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 7.056% Params, 73.21 MMac, 5.179% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(14.37 k, 0.271% Params, 2.82 MMac, 0.199% MACs, 448, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 0.968% Params, 10.05 MMac, 0.711% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (4): Inception_mod4(
#       771.97 k, 14.583% Params, 151.31 MMac, 10.703% MACs,
#       (p1_1): Conv2d(119.04 k, 2.249% Params, 23.33 MMac, 1.650% MACs, 464, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(74.4 k, 1.405% Params, 14.58 MMac, 1.032% MACs, 464, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 8.711% Params, 90.38 MMac, 6.393% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(14.88 k, 0.281% Params, 2.92 MMac, 0.206% MACs, 464, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 1.937% Params, 20.1 MMac, 1.421% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 137.98 KMac, 0.010% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     2.14 M, 40.371% Params, 104.76 MMac, 7.410% MACs,
#     (0): Inception_mod4(
#       879.49 k, 16.614% Params, 43.09 MMac, 3.048% MACs,
#       (p1_1): Conv2d(180.48 k, 3.409% Params, 8.84 MMac, 0.626% MACs, 704, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(112.8 k, 2.131% Params, 5.53 MMac, 0.391% MACs, 704, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 8.711% Params, 22.59 MMac, 1.598% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(22.56 k, 0.426% Params, 1.11 MMac, 0.078% MACs, 704, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 1.937% Params, 5.02 MMac, 0.355% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod4(
#       1.26 M, 23.757% Params, 61.62 MMac, 4.359% MACs,
#       (p1_1): Conv2d(270.72 k, 5.114% Params, 13.27 MMac, 0.938% MACs, 704, 384, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(135.36 k, 2.557% Params, 6.63 MMac, 0.469% MACs, 704, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 12.542% Params, 32.53 MMac, 2.301% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(33.84 k, 0.639% Params, 1.66 MMac, 0.117% MACs, 704, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 2.904% Params, 7.53 MMac, 0.533% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 43.9 KMac, 0.003% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(8.97 k, 0.169% Params, 8.97 KMac, 0.001% MACs, in_features=896, out_features=10, bias=True)
# )
# Computational complexity:       1.41 GMac
# Number of parameters:           5.29 M
# --------------------------------------------------
# Warning: module Inception_mod4 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   5.38 M, 100.000% Params, 1.49 GMac, 99.667% MACs,
#   (0): Sequential(
#     9.47 k, 0.176% Params, 120.42 MMac, 8.069% MACs,
#     (0): Conv2d(9.47 k, 0.176% Params, 118.82 MMac, 7.961% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.054% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.054% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 2.136% Params, 361.87 MMac, 24.247% MACs,
#     (0): Conv2d(4.16 k, 0.077% Params, 13.05 MMac, 0.874% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.013% MACs, )
#     (2): Conv2d(110.78 k, 2.059% Params, 347.42 MMac, 23.279% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.040% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.040% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     520.59 k, 9.675% Params, 408.47 MMac, 27.369% MACs,
#     (0): Inception_mod4(
#       157.52 k, 2.928% Params, 123.5 MMac, 8.275% MACs,
#       (p1_1): Conv2d(12.35 k, 0.230% Params, 9.68 MMac, 0.649% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(18.53 k, 0.344% Params, 14.53 MMac, 0.973% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 2.058% Params, 86.8 MMac, 5.816% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(3.09 k, 0.057% Params, 2.42 MMac, 0.162% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.238% Params, 10.06 MMac, 0.674% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod4(
#       363.07 k, 6.748% Params, 284.65 MMac, 19.073% MACs,
#       (p1_1): Conv2d(28.8 k, 0.535% Params, 22.58 MMac, 1.513% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(28.8 k, 0.535% Params, 22.58 MMac, 1.513% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 4.114% Params, 173.56 MMac, 11.629% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(7.2 k, 0.134% Params, 5.64 MMac, 0.378% MACs, 224, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 1.429% Params, 60.29 MMac, 4.039% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 326.14 KMac, 0.022% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     2.51 M, 46.626% Params, 491.85 MMac, 32.956% MACs,
#     (0): Inception_mod4(
#       325.94 k, 6.058% Params, 63.88 MMac, 4.280% MACs,
#       (p1_1): Conv2d(80.06 k, 1.488% Params, 15.69 MMac, 1.051% MACs, 416, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(40.03 k, 0.744% Params, 7.85 MMac, 0.526% MACs, 416, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 3.344% Params, 35.26 MMac, 2.363% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(6.67 k, 0.124% Params, 1.31 MMac, 0.088% MACs, 416, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 0.358% Params, 3.77 MMac, 0.253% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod4(
#       397.38 k, 7.386% Params, 77.89 MMac, 5.219% MACs,
#       (p1_1): Conv2d(71.84 k, 1.335% Params, 14.08 MMac, 0.943% MACs, 448, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(50.29 k, 0.935% Params, 9.86 MMac, 0.660% MACs, 448, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 4.201% Params, 44.3 MMac, 2.968% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(10.78 k, 0.200% Params, 2.11 MMac, 0.142% MACs, 448, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.715% Params, 7.54 MMac, 0.505% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): Inception_mod4(
#       459.35 k, 8.537% Params, 90.03 MMac, 6.033% MACs,
#       (p1_1): Conv2d(57.47 k, 1.068% Params, 11.26 MMac, 0.755% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(57.47 k, 1.068% Params, 11.26 MMac, 0.755% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 5.486% Params, 57.85 MMac, 3.876% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(10.78 k, 0.200% Params, 2.11 MMac, 0.142% MACs, 448, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.715% Params, 7.54 MMac, 0.505% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (3): Inception_mod4(
#       554.11 k, 10.298% Params, 108.61 MMac, 7.277% MACs,
#       (p1_1): Conv2d(50.29 k, 0.935% Params, 9.86 MMac, 0.660% MACs, 448, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(64.66 k, 1.202% Params, 12.67 MMac, 0.849% MACs, 448, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 6.942% Params, 73.21 MMac, 4.906% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(14.37 k, 0.267% Params, 2.82 MMac, 0.189% MACs, 448, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 0.953% Params, 10.05 MMac, 0.673% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (4): Inception_mod4(
#       771.97 k, 14.347% Params, 151.31 MMac, 10.138% MACs,
#       (p1_1): Conv2d(119.04 k, 2.212% Params, 23.33 MMac, 1.563% MACs, 464, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(74.4 k, 1.383% Params, 14.58 MMac, 0.977% MACs, 464, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 8.570% Params, 90.38 MMac, 6.056% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(14.88 k, 0.277% Params, 2.92 MMac, 0.195% MACs, 464, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 1.906% Params, 20.1 MMac, 1.346% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 137.98 KMac, 0.009% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     2.14 M, 39.719% Params, 104.76 MMac, 7.019% MACs,
#     (0): Inception_mod4(
#       879.49 k, 16.346% Params, 43.09 MMac, 2.888% MACs,
#       (p1_1): Conv2d(180.48 k, 3.354% Params, 8.84 MMac, 0.593% MACs, 704, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(112.8 k, 2.096% Params, 5.53 MMac, 0.370% MACs, 704, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 8.570% Params, 22.59 MMac, 1.514% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(22.56 k, 0.419% Params, 1.11 MMac, 0.074% MACs, 704, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 1.906% Params, 5.02 MMac, 0.337% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod4(
#       1.26 M, 23.373% Params, 61.62 MMac, 4.129% MACs,
#       (p1_1): Conv2d(270.72 k, 5.031% Params, 13.27 MMac, 0.889% MACs, 704, 384, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(135.36 k, 2.516% Params, 6.63 MMac, 0.444% MACs, 704, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 12.340% Params, 32.53 MMac, 2.180% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(33.84 k, 0.629% Params, 1.66 MMac, 0.111% MACs, 704, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 2.857% Params, 7.53 MMac, 0.505% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 43.9 KMac, 0.003% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(89.7 k, 1.667% Params, 89.7 KMac, 0.006% MACs, in_features=896, out_features=100, bias=True)
# )
# Computational complexity:       1.49 GMac
# Number of parameters:           5.38 M
# --------------------------------------------------
# Warning: module Inception_mod4 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   5.3 M, 100.000% Params, 1.49 GMac, 99.667% MACs,
#   (0): Sequential(
#     9.47 k, 0.179% Params, 120.42 MMac, 8.069% MACs,
#     (0): Conv2d(9.47 k, 0.179% Params, 118.82 MMac, 7.962% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.054% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.054% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 2.169% Params, 361.87 MMac, 24.248% MACs,
#     (0): Conv2d(4.16 k, 0.078% Params, 13.05 MMac, 0.874% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.013% MACs, )
#     (2): Conv2d(110.78 k, 2.090% Params, 347.42 MMac, 23.280% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.040% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.040% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     520.59 k, 9.823% Params, 408.47 MMac, 27.371% MACs,
#     (0): Inception_mod4(
#       157.52 k, 2.972% Params, 123.5 MMac, 8.275% MACs,
#       (p1_1): Conv2d(12.35 k, 0.233% Params, 9.68 MMac, 0.649% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(18.53 k, 0.350% Params, 14.53 MMac, 0.973% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 2.089% Params, 86.8 MMac, 5.817% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(3.09 k, 0.058% Params, 2.42 MMac, 0.162% MACs, 192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(12.83 k, 0.242% Params, 10.06 MMac, 0.674% MACs, 16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod4(
#       363.07 k, 6.851% Params, 284.65 MMac, 19.074% MACs,
#       (p1_1): Conv2d(28.8 k, 0.543% Params, 22.58 MMac, 1.513% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(28.8 k, 0.543% Params, 22.58 MMac, 1.513% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 4.177% Params, 173.56 MMac, 11.630% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(7.2 k, 0.136% Params, 5.64 MMac, 0.378% MACs, 224, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(76.9 k, 1.451% Params, 60.29 MMac, 4.040% MACs, 32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 326.14 KMac, 0.022% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     2.51 M, 47.337% Params, 491.85 MMac, 32.958% MACs,
#     (0): Inception_mod4(
#       325.94 k, 6.150% Params, 63.88 MMac, 4.281% MACs,
#       (p1_1): Conv2d(80.06 k, 1.511% Params, 15.69 MMac, 1.052% MACs, 416, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(40.03 k, 0.755% Params, 7.85 MMac, 0.526% MACs, 416, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 3.395% Params, 35.26 MMac, 2.363% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(6.67 k, 0.126% Params, 1.31 MMac, 0.088% MACs, 416, 16, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(19.25 k, 0.363% Params, 3.77 MMac, 0.253% MACs, 16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod4(
#       397.38 k, 7.498% Params, 77.89 MMac, 5.219% MACs,
#       (p1_1): Conv2d(71.84 k, 1.356% Params, 14.08 MMac, 0.944% MACs, 448, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(50.29 k, 0.949% Params, 9.86 MMac, 0.660% MACs, 448, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 4.265% Params, 44.3 MMac, 2.968% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(10.78 k, 0.203% Params, 2.11 MMac, 0.142% MACs, 448, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.726% Params, 7.54 MMac, 0.505% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): Inception_mod4(
#       459.35 k, 8.667% Params, 90.03 MMac, 6.033% MACs,
#       (p1_1): Conv2d(57.47 k, 1.084% Params, 11.26 MMac, 0.755% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(57.47 k, 1.084% Params, 11.26 MMac, 0.755% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 5.569% Params, 57.85 MMac, 3.877% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(10.78 k, 0.203% Params, 2.11 MMac, 0.142% MACs, 448, 24, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(38.46 k, 0.726% Params, 7.54 MMac, 0.505% MACs, 24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (3): Inception_mod4(
#       554.11 k, 10.455% Params, 108.61 MMac, 7.277% MACs,
#       (p1_1): Conv2d(50.29 k, 0.949% Params, 9.86 MMac, 0.660% MACs, 448, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(64.66 k, 1.220% Params, 12.67 MMac, 0.849% MACs, 448, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 7.048% Params, 73.21 MMac, 4.906% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(14.37 k, 0.271% Params, 2.82 MMac, 0.189% MACs, 448, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(51.26 k, 0.967% Params, 10.05 MMac, 0.673% MACs, 32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (4): Inception_mod4(
#       771.97 k, 14.566% Params, 151.31 MMac, 10.139% MACs,
#       (p1_1): Conv2d(119.04 k, 2.246% Params, 23.33 MMac, 1.563% MACs, 464, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(74.4 k, 1.404% Params, 14.58 MMac, 0.977% MACs, 464, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 8.701% Params, 90.38 MMac, 6.056% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(14.88 k, 0.281% Params, 2.92 MMac, 0.195% MACs, 464, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 1.935% Params, 20.1 MMac, 1.347% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 137.98 KMac, 0.009% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     2.14 M, 40.324% Params, 104.76 MMac, 7.020% MACs,
#     (0): Inception_mod4(
#       879.49 k, 16.595% Params, 43.09 MMac, 2.888% MACs,
#       (p1_1): Conv2d(180.48 k, 3.405% Params, 8.84 MMac, 0.593% MACs, 704, 256, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(112.8 k, 2.128% Params, 5.53 MMac, 0.370% MACs, 704, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 8.701% Params, 22.59 MMac, 1.514% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(22.56 k, 0.426% Params, 1.11 MMac, 0.074% MACs, 704, 32, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(102.53 k, 1.935% Params, 5.02 MMac, 0.337% MACs, 32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (1): Inception_mod4(
#       1.26 M, 23.729% Params, 61.62 MMac, 4.129% MACs,
#       (p1_1): Conv2d(270.72 k, 5.108% Params, 13.27 MMac, 0.889% MACs, 704, 384, kernel_size=(1, 1), stride=(1, 1))
#       (p2_1): Conv2d(135.36 k, 2.554% Params, 6.63 MMac, 0.444% MACs, 704, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 12.528% Params, 32.53 MMac, 2.180% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(33.84 k, 0.639% Params, 1.66 MMac, 0.111% MACs, 704, 48, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(153.73 k, 2.901% Params, 7.53 MMac, 0.505% MACs, 48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 43.9 KMac, 0.003% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(8.97 k, 0.169% Params, 8.97 KMac, 0.001% MACs, in_features=896, out_features=10, bias=True)
# )
# Computational complexity:       1.49 GMac
# Number of parameters:           5.3 M

# %% [markdown]
# #### GoogleNet_mod5

# %%
googlenet_mod5_f, macs_googlenet_mod5_f, paras_googlenet_mod5_f = get_model_info(Googlenet_mod5, channel_f, num_labels_f)
print('-'*50)
googlenet_mod5_c100, macs_googlenet_mod5_c100, paras_googlenet_mod5_c100 = get_model_info(Googlenet_mod5, channel_c, num_labels_c100)
print('-'*50)
googlenet_mod5_c10, macs_googlenet_mod5_c10, paras_googlenet_mod5_c10 = get_model_info(Googlenet_mod5, channel_c, num_labels_c10)
# Out:
# Warning: module Inception_mod5 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   3.42 M, 100.000% Params, 1.08 GMac, 99.623% MACs,
#   (0): Sequential(
#     3.2 k, 0.094% Params, 41.75 MMac, 3.838% MACs,
#     (0): Conv2d(3.2 k, 0.094% Params, 40.14 MMac, 3.691% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.074% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.074% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 3.364% Params, 361.87 MMac, 33.271% MACs,
#     (0): Conv2d(4.16 k, 0.122% Params, 13.05 MMac, 1.199% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.018% MACs, )
#     (2): Conv2d(110.78 k, 3.242% Params, 347.42 MMac, 31.942% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.055% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.055% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     367.14 k, 10.745% Params, 287.99 MMac, 26.478% MACs,
#     (0): Inception_mod5(
#       129.25 k, 3.783% Params, 101.33 MMac, 9.317% MACs,
#       (p2_1): Conv2d(18.53 k, 0.542% Params, 14.53 MMac, 1.336% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 3.240% Params, 86.8 MMac, 7.981% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod5(
#       237.89 k, 6.962% Params, 186.5 MMac, 17.148% MACs,
#       (p2_1): Conv2d(16.51 k, 0.483% Params, 12.95 MMac, 1.190% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 6.479% Params, 173.56 MMac, 15.957% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.014% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     1.69 M, 49.452% Params, 331.25 MMac, 30.456% MACs,
#     (0): Inception_mod5(
#       198.45 k, 5.808% Params, 38.9 MMac, 3.576% MACs,
#       (p2_1): Conv2d(18.53 k, 0.542% Params, 3.63 MMac, 0.334% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 5.266% Params, 35.26 MMac, 3.242% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod5(
#       249.42 k, 7.300% Params, 48.89 MMac, 4.495% MACs,
#       (p2_1): Conv2d(23.41 k, 0.685% Params, 4.59 MMac, 0.422% MACs, 208, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 6.615% Params, 44.3 MMac, 4.073% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): Inception_mod5(
#       323.97 k, 9.481% Params, 63.5 MMac, 5.838% MACs,
#       (p2_1): Conv2d(28.8 k, 0.843% Params, 5.64 MMac, 0.519% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 8.638% Params, 57.85 MMac, 5.319% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (3): Inception_mod5(
#       410.54 k, 12.015% Params, 80.47 MMac, 7.398% MACs,
#       (p2_1): Conv2d(37.01 k, 1.083% Params, 7.25 MMac, 0.667% MACs, 256, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 10.932% Params, 73.21 MMac, 6.731% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (4): Inception_mod5(
#       507.36 k, 14.848% Params, 99.44 MMac, 9.143% MACs,
#       (p2_1): Conv2d(46.24 k, 1.353% Params, 9.06 MMac, 0.833% MACs, 288, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 13.495% Params, 90.38 MMac, 8.310% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 62.72 KMac, 0.006% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     1.24 M, 36.233% Params, 60.68 MMac, 5.579% MACs,
#     (0): Inception_mod5(
#       512.48 k, 14.998% Params, 25.11 MMac, 2.309% MACs,
#       (p2_1): Conv2d(51.36 k, 1.503% Params, 2.52 MMac, 0.231% MACs, 320, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 13.495% Params, 22.59 MMac, 2.077% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod5(
#       725.57 k, 21.235% Params, 35.55 MMac, 3.269% MACs,
#       (p2_1): Conv2d(61.63 k, 1.804% Params, 3.02 MMac, 0.278% MACs, 320, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 19.431% Params, 32.53 MMac, 2.991% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 18.82 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(3.85 k, 0.113% Params, 3.85 KMac, 0.000% MACs, in_features=384, out_features=10, bias=True)
# )
# Computational complexity:       1.09 GMac
# Number of parameters:           3.42 M
# --------------------------------------------------
# Warning: module Inception_mod5 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   3.46 M, 100.000% Params, 1.16 GMac, 99.648% MACs,
#   (0): Sequential(
#     9.47 k, 0.274% Params, 120.42 MMac, 10.325% MACs,
#     (0): Conv2d(9.47 k, 0.274% Params, 118.82 MMac, 10.187% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.069% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.069% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 3.324% Params, 361.87 MMac, 31.026% MACs,
#     (0): Conv2d(4.16 k, 0.120% Params, 13.05 MMac, 1.119% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.017% MACs, )
#     (2): Conv2d(110.78 k, 3.204% Params, 347.42 MMac, 29.787% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.052% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.052% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     367.14 k, 10.617% Params, 287.99 MMac, 24.691% MACs,
#     (0): Inception_mod5(
#       129.25 k, 3.738% Params, 101.33 MMac, 8.688% MACs,
#       (p2_1): Conv2d(18.53 k, 0.536% Params, 14.53 MMac, 1.245% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 3.202% Params, 86.8 MMac, 7.442% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod5(
#       237.89 k, 6.880% Params, 186.5 MMac, 15.990% MACs,
#       (p2_1): Conv2d(16.51 k, 0.478% Params, 12.95 MMac, 1.110% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 6.402% Params, 173.56 MMac, 14.880% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.013% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     1.69 M, 48.867% Params, 331.25 MMac, 28.401% MACs,
#     (0): Inception_mod5(
#       198.45 k, 5.739% Params, 38.9 MMac, 3.335% MACs,
#       (p2_1): Conv2d(18.53 k, 0.536% Params, 3.63 MMac, 0.311% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 5.203% Params, 35.26 MMac, 3.023% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod5(
#       249.42 k, 7.213% Params, 48.89 MMac, 4.191% MACs,
#       (p2_1): Conv2d(23.41 k, 0.677% Params, 4.59 MMac, 0.393% MACs, 208, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 6.536% Params, 44.3 MMac, 3.798% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): Inception_mod5(
#       323.97 k, 9.369% Params, 63.5 MMac, 5.444% MACs,
#       (p2_1): Conv2d(28.8 k, 0.833% Params, 5.64 MMac, 0.484% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 8.536% Params, 57.85 MMac, 4.960% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (3): Inception_mod5(
#       410.54 k, 11.873% Params, 80.47 MMac, 6.899% MACs,
#       (p2_1): Conv2d(37.01 k, 1.070% Params, 7.25 MMac, 0.622% MACs, 256, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 10.803% Params, 73.21 MMac, 6.277% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (4): Inception_mod5(
#       507.36 k, 14.673% Params, 99.44 MMac, 8.526% MACs,
#       (p2_1): Conv2d(46.24 k, 1.337% Params, 9.06 MMac, 0.777% MACs, 288, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 13.335% Params, 90.38 MMac, 7.749% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 62.72 KMac, 0.005% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     1.24 M, 35.804% Params, 60.68 MMac, 5.203% MACs,
#     (0): Inception_mod5(
#       512.48 k, 14.821% Params, 25.11 MMac, 2.153% MACs,
#       (p2_1): Conv2d(51.36 k, 1.485% Params, 2.52 MMac, 0.216% MACs, 320, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 13.335% Params, 22.59 MMac, 1.937% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod5(
#       725.57 k, 20.983% Params, 35.55 MMac, 3.048% MACs,
#       (p2_1): Conv2d(61.63 k, 1.782% Params, 3.02 MMac, 0.259% MACs, 320, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 19.201% Params, 32.53 MMac, 2.789% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 18.82 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(38.5 k, 1.113% Params, 38.5 KMac, 0.003% MACs, in_features=384, out_features=100, bias=True)
# )
# Computational complexity:       1.17 GMac
# Number of parameters:           3.46 M
# --------------------------------------------------
# Warning: module Inception_mod5 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   3.42 M, 100.000% Params, 1.16 GMac, 99.648% MACs,
#   (0): Sequential(
#     9.47 k, 0.277% Params, 120.42 MMac, 10.325% MACs,
#     (0): Conv2d(9.47 k, 0.277% Params, 118.82 MMac, 10.187% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.069% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.069% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 3.358% Params, 361.87 MMac, 31.027% MACs,
#     (0): Conv2d(4.16 k, 0.122% Params, 13.05 MMac, 1.119% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.017% MACs, )
#     (2): Conv2d(110.78 k, 3.236% Params, 347.42 MMac, 29.788% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.052% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.052% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     367.14 k, 10.725% Params, 287.99 MMac, 24.692% MACs,
#     (0): Inception_mod5(
#       129.25 k, 3.776% Params, 101.33 MMac, 8.688% MACs,
#       (p2_1): Conv2d(18.53 k, 0.541% Params, 14.53 MMac, 1.245% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 3.234% Params, 86.8 MMac, 7.443% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod5(
#       237.89 k, 6.949% Params, 186.5 MMac, 15.991% MACs,
#       (p2_1): Conv2d(16.51 k, 0.482% Params, 12.95 MMac, 1.110% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 6.467% Params, 173.56 MMac, 14.881% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 150.53 KMac, 0.013% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     1.69 M, 49.362% Params, 331.25 MMac, 28.402% MACs,
#     (0): Inception_mod5(
#       198.45 k, 5.797% Params, 38.9 MMac, 3.335% MACs,
#       (p2_1): Conv2d(18.53 k, 0.541% Params, 3.63 MMac, 0.311% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 5.256% Params, 35.26 MMac, 3.024% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod5(
#       249.42 k, 7.286% Params, 48.89 MMac, 4.192% MACs,
#       (p2_1): Conv2d(23.41 k, 0.684% Params, 4.59 MMac, 0.393% MACs, 208, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 6.602% Params, 44.3 MMac, 3.798% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): Inception_mod5(
#       323.97 k, 9.464% Params, 63.5 MMac, 5.444% MACs,
#       (p2_1): Conv2d(28.8 k, 0.841% Params, 5.64 MMac, 0.484% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 8.623% Params, 57.85 MMac, 4.960% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (3): Inception_mod5(
#       410.54 k, 11.993% Params, 80.47 MMac, 6.899% MACs,
#       (p2_1): Conv2d(37.01 k, 1.081% Params, 7.25 MMac, 0.622% MACs, 256, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 10.912% Params, 73.21 MMac, 6.277% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (4): Inception_mod5(
#       507.36 k, 14.821% Params, 99.44 MMac, 8.526% MACs,
#       (p2_1): Conv2d(46.24 k, 1.351% Params, 9.06 MMac, 0.777% MACs, 288, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 13.470% Params, 90.38 MMac, 7.749% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 62.72 KMac, 0.005% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     1.24 M, 36.166% Params, 60.68 MMac, 5.203% MACs,
#     (0): Inception_mod5(
#       512.48 k, 14.971% Params, 25.11 MMac, 2.153% MACs,
#       (p2_1): Conv2d(51.36 k, 1.500% Params, 2.52 MMac, 0.216% MACs, 320, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 13.470% Params, 22.59 MMac, 1.937% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod5(
#       725.57 k, 21.196% Params, 35.55 MMac, 3.048% MACs,
#       (p2_1): Conv2d(61.63 k, 1.800% Params, 3.02 MMac, 0.259% MACs, 320, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 19.395% Params, 32.53 MMac, 2.789% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 18.82 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(3.85 k, 0.112% Params, 3.85 KMac, 0.000% MACs, in_features=384, out_features=10, bias=True)
# )
# Computational complexity:       1.17 GMac
# Number of parameters:           3.42 M

# %% [markdown]
# #### GoogleNet_mod6

# %%
googlenet_mod6_f, macs_googlenet_mod6_f, paras_googlenet_mod6_f = get_model_info(Googlenet_mod6, channel_f, num_labels_f)
print('-'*50)
googlenet_mod6_c100, macs_googlenet_mod6_c100, paras_googlenet_mod6_c100 = get_model_info(Googlenet_mod6, channel_c, num_labels_c100)
print('-'*50)
googlenet_mod6_c10, macs_googlenet_mod6_c10, paras_googlenet_mod6_c10 = get_model_info(Googlenet_mod6, channel_c, num_labels_c10)
# Out:
# Warning: module Inception_mod6 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   7.28 M, 100.000% Params, 1.86 GMac, 99.722% MACs,
#   (0): Sequential(
#     3.2 k, 0.044% Params, 41.75 MMac, 2.238% MACs,
#     (0): Conv2d(3.2 k, 0.044% Params, 40.14 MMac, 2.152% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.043% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.043% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 1.579% Params, 361.87 MMac, 19.398% MACs,
#     (0): Conv2d(4.16 k, 0.057% Params, 13.05 MMac, 0.699% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.011% MACs, )
#     (2): Conv2d(110.78 k, 1.522% Params, 347.42 MMac, 18.623% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.032% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.032% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     767.04 k, 10.536% Params, 601.66 MMac, 32.252% MACs,
#     (0): Inception_mod6(
#       258.5 k, 3.551% Params, 202.66 MMac, 10.864% MACs,
#       (p2_1): Conv2d(18.53 k, 0.254% Params, 14.53 MMac, 0.779% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 1.521% Params, 86.8 MMac, 4.653% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(18.53 k, 0.254% Params, 14.53 MMac, 0.779% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(110.72 k, 1.521% Params, 86.8 MMac, 4.653% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod6(
#       508.54 k, 6.985% Params, 398.7 MMac, 21.372% MACs,
#       (p2_1): Conv2d(32.9 k, 0.452% Params, 25.79 MMac, 1.382% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 3.041% Params, 173.56 MMac, 9.304% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(32.9 k, 0.452% Params, 25.79 MMac, 1.382% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(221.38 k, 3.041% Params, 173.56 MMac, 9.304% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 301.06 KMac, 0.016% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     3.69 M, 50.631% Params, 722.62 MMac, 38.736% MACs,
#     (0): Inception_mod6(
#       433.76 k, 5.958% Params, 85.02 MMac, 4.557% MACs,
#       (p2_1): Conv2d(36.96 k, 0.508% Params, 7.24 MMac, 0.388% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 2.471% Params, 35.26 MMac, 1.890% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(36.96 k, 0.508% Params, 7.24 MMac, 0.388% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(179.92 k, 2.471% Params, 35.26 MMac, 1.890% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod6(
#       545.44 k, 7.492% Params, 106.91 MMac, 5.731% MACs,
#       (p2_1): Conv2d(46.7 k, 0.642% Params, 9.15 MMac, 0.491% MACs, 416, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 3.104% Params, 44.3 MMac, 2.375% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(46.7 k, 0.642% Params, 9.15 MMac, 0.491% MACs, 416, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(226.02 k, 3.104% Params, 44.3 MMac, 2.375% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): Inception_mod6(
#       705.28 k, 9.687% Params, 138.23 MMac, 7.410% MACs,
#       (p2_1): Conv2d(57.47 k, 0.789% Params, 11.26 MMac, 0.604% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 4.054% Params, 57.85 MMac, 3.101% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(57.47 k, 0.789% Params, 11.26 MMac, 0.604% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(295.17 k, 4.054% Params, 57.85 MMac, 3.101% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (3): Inception_mod6(
#       894.82 k, 12.291% Params, 175.38 MMac, 9.401% MACs,
#       (p2_1): Conv2d(73.87 k, 1.015% Params, 14.48 MMac, 0.776% MACs, 512, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 5.131% Params, 73.21 MMac, 3.925% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(73.87 k, 1.015% Params, 14.48 MMac, 0.776% MACs, 512, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(373.54 k, 5.131% Params, 73.21 MMac, 3.925% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (4): Inception_mod6(
#       1.11 M, 15.204% Params, 216.95 MMac, 11.630% MACs,
#       (p2_1): Conv2d(92.32 k, 1.268% Params, 18.09 MMac, 0.970% MACs, 576, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 6.334% Params, 90.38 MMac, 4.845% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(92.32 k, 1.268% Params, 18.09 MMac, 0.970% MACs, 576, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 6.334% Params, 90.38 MMac, 4.845% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 125.44 KMac, 0.007% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     2.7 M, 37.105% Params, 132.41 MMac, 7.098% MACs,
#     (0): Inception_mod6(
#       1.13 M, 15.485% Params, 55.24 MMac, 2.961% MACs,
#       (p2_1): Conv2d(102.56 k, 1.409% Params, 5.03 MMac, 0.269% MACs, 640, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 6.334% Params, 22.59 MMac, 1.211% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(102.56 k, 1.409% Params, 5.03 MMac, 0.269% MACs, 640, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 6.334% Params, 22.59 MMac, 1.211% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod6(
#       1.57 M, 21.620% Params, 77.13 MMac, 4.134% MACs,
#       (p2_1): Conv2d(123.07 k, 1.690% Params, 6.03 MMac, 0.323% MACs, 640, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 9.119% Params, 32.53 MMac, 1.744% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(123.07 k, 1.690% Params, 6.03 MMac, 0.323% MACs, 640, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(663.94 k, 9.119% Params, 32.53 MMac, 1.744% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 37.63 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(7.69 k, 0.106% Params, 7.69 KMac, 0.000% MACs, in_features=768, out_features=10, bias=True)
# )
# Computational complexity:       1.87 GMac
# Number of parameters:           7.28 M
# --------------------------------------------------
# Warning: module Inception_mod6 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   7.36 M, 100.000% Params, 1.94 GMac, 99.733% MACs,
#   (0): Sequential(
#     9.47 k, 0.129% Params, 120.42 MMac, 6.194% MACs,
#     (0): Conv2d(9.47 k, 0.129% Params, 118.82 MMac, 6.111% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.041% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.041% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 1.563% Params, 361.87 MMac, 18.612% MACs,
#     (0): Conv2d(4.16 k, 0.057% Params, 13.05 MMac, 0.671% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.010% MACs, )
#     (2): Conv2d(110.78 k, 1.506% Params, 347.42 MMac, 17.869% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.031% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.031% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     767.04 k, 10.428% Params, 601.66 MMac, 30.946% MACs,
#     (0): Inception_mod6(
#       258.5 k, 3.514% Params, 202.66 MMac, 10.424% MACs,
#       (p2_1): Conv2d(18.53 k, 0.252% Params, 14.53 MMac, 0.747% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 1.505% Params, 86.8 MMac, 4.465% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(18.53 k, 0.252% Params, 14.53 MMac, 0.747% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(110.72 k, 1.505% Params, 86.8 MMac, 4.465% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod6(
#       508.54 k, 6.913% Params, 398.7 MMac, 20.507% MACs,
#       (p2_1): Conv2d(32.9 k, 0.447% Params, 25.79 MMac, 1.327% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 3.009% Params, 173.56 MMac, 8.927% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(32.9 k, 0.447% Params, 25.79 MMac, 1.327% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(221.38 k, 3.009% Params, 173.56 MMac, 8.927% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 301.06 KMac, 0.015% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     3.69 M, 50.112% Params, 722.62 MMac, 37.167% MACs,
#     (0): Inception_mod6(
#       433.76 k, 5.897% Params, 85.02 MMac, 4.373% MACs,
#       (p2_1): Conv2d(36.96 k, 0.502% Params, 7.24 MMac, 0.373% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 2.446% Params, 35.26 MMac, 1.814% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(36.96 k, 0.502% Params, 7.24 MMac, 0.373% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(179.92 k, 2.446% Params, 35.26 MMac, 1.814% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod6(
#       545.44 k, 7.415% Params, 106.91 MMac, 5.499% MACs,
#       (p2_1): Conv2d(46.7 k, 0.635% Params, 9.15 MMac, 0.471% MACs, 416, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 3.073% Params, 44.3 MMac, 2.278% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(46.7 k, 0.635% Params, 9.15 MMac, 0.471% MACs, 416, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(226.02 k, 3.073% Params, 44.3 MMac, 2.278% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): Inception_mod6(
#       705.28 k, 9.588% Params, 138.23 MMac, 7.110% MACs,
#       (p2_1): Conv2d(57.47 k, 0.781% Params, 11.26 MMac, 0.579% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 4.013% Params, 57.85 MMac, 2.976% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(57.47 k, 0.781% Params, 11.26 MMac, 0.579% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(295.17 k, 4.013% Params, 57.85 MMac, 2.976% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (3): Inception_mod6(
#       894.82 k, 12.165% Params, 175.38 MMac, 9.021% MACs,
#       (p2_1): Conv2d(73.87 k, 1.004% Params, 14.48 MMac, 0.745% MACs, 512, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 5.078% Params, 73.21 MMac, 3.766% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(73.87 k, 1.004% Params, 14.48 MMac, 0.745% MACs, 512, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(373.54 k, 5.078% Params, 73.21 MMac, 3.766% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (4): Inception_mod6(
#       1.11 M, 15.047% Params, 216.95 MMac, 11.159% MACs,
#       (p2_1): Conv2d(92.32 k, 1.255% Params, 18.09 MMac, 0.931% MACs, 576, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 6.269% Params, 90.38 MMac, 4.649% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(92.32 k, 1.255% Params, 18.09 MMac, 0.931% MACs, 576, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 6.269% Params, 90.38 MMac, 4.649% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 125.44 KMac, 0.006% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     2.7 M, 36.724% Params, 132.41 MMac, 6.810% MACs,
#     (0): Inception_mod6(
#       1.13 M, 15.326% Params, 55.24 MMac, 2.841% MACs,
#       (p2_1): Conv2d(102.56 k, 1.394% Params, 5.03 MMac, 0.258% MACs, 640, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 6.269% Params, 22.59 MMac, 1.162% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(102.56 k, 1.394% Params, 5.03 MMac, 0.258% MACs, 640, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 6.269% Params, 22.59 MMac, 1.162% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod6(
#       1.57 M, 21.398% Params, 77.13 MMac, 3.967% MACs,
#       (p2_1): Conv2d(123.07 k, 1.673% Params, 6.03 MMac, 0.310% MACs, 640, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 9.026% Params, 32.53 MMac, 1.673% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(123.07 k, 1.673% Params, 6.03 MMac, 0.310% MACs, 640, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(663.94 k, 9.026% Params, 32.53 MMac, 1.673% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 37.63 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(76.9 k, 1.045% Params, 76.9 KMac, 0.004% MACs, in_features=768, out_features=100, bias=True)
# )
# Computational complexity:       1.94 GMac
# Number of parameters:           7.36 M
# --------------------------------------------------
# Warning: module Inception_mod6 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   7.29 M, 100.000% Params, 1.94 GMac, 99.733% MACs,
#   (0): Sequential(
#     9.47 k, 0.130% Params, 120.42 MMac, 6.194% MACs,
#     (0): Conv2d(9.47 k, 0.130% Params, 118.82 MMac, 6.111% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.041% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.041% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 1.577% Params, 361.87 MMac, 18.613% MACs,
#     (0): Conv2d(4.16 k, 0.057% Params, 13.05 MMac, 0.671% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.010% MACs, )
#     (2): Conv2d(110.78 k, 1.520% Params, 347.42 MMac, 17.870% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.031% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.031% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     767.04 k, 10.527% Params, 601.66 MMac, 30.947% MACs,
#     (0): Inception_mod6(
#       258.5 k, 3.548% Params, 202.66 MMac, 10.424% MACs,
#       (p2_1): Conv2d(18.53 k, 0.254% Params, 14.53 MMac, 0.747% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 1.519% Params, 86.8 MMac, 4.465% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(18.53 k, 0.254% Params, 14.53 MMac, 0.747% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(110.72 k, 1.519% Params, 86.8 MMac, 4.465% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod6(
#       508.54 k, 6.979% Params, 398.7 MMac, 20.507% MACs,
#       (p2_1): Conv2d(32.9 k, 0.451% Params, 25.79 MMac, 1.327% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 3.038% Params, 173.56 MMac, 8.927% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(32.9 k, 0.451% Params, 25.79 MMac, 1.327% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(221.38 k, 3.038% Params, 173.56 MMac, 8.927% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 301.06 KMac, 0.015% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     3.69 M, 50.588% Params, 722.62 MMac, 37.168% MACs,
#     (0): Inception_mod6(
#       433.76 k, 5.953% Params, 85.02 MMac, 4.373% MACs,
#       (p2_1): Conv2d(36.96 k, 0.507% Params, 7.24 MMac, 0.373% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 2.469% Params, 35.26 MMac, 1.814% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(36.96 k, 0.507% Params, 7.24 MMac, 0.373% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(179.92 k, 2.469% Params, 35.26 MMac, 1.814% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod6(
#       545.44 k, 7.485% Params, 106.91 MMac, 5.499% MACs,
#       (p2_1): Conv2d(46.7 k, 0.641% Params, 9.15 MMac, 0.471% MACs, 416, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 3.102% Params, 44.3 MMac, 2.279% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(46.7 k, 0.641% Params, 9.15 MMac, 0.471% MACs, 416, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(226.02 k, 3.102% Params, 44.3 MMac, 2.279% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): Inception_mod6(
#       705.28 k, 9.679% Params, 138.23 MMac, 7.110% MACs,
#       (p2_1): Conv2d(57.47 k, 0.789% Params, 11.26 MMac, 0.579% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 4.051% Params, 57.85 MMac, 2.976% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(57.47 k, 0.789% Params, 11.26 MMac, 0.579% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(295.17 k, 4.051% Params, 57.85 MMac, 2.976% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (3): Inception_mod6(
#       894.82 k, 12.280% Params, 175.38 MMac, 9.021% MACs,
#       (p2_1): Conv2d(73.87 k, 1.014% Params, 14.48 MMac, 0.745% MACs, 512, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 5.126% Params, 73.21 MMac, 3.766% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(73.87 k, 1.014% Params, 14.48 MMac, 0.745% MACs, 512, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(373.54 k, 5.126% Params, 73.21 MMac, 3.766% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (4): Inception_mod6(
#       1.11 M, 15.190% Params, 216.95 MMac, 11.159% MACs,
#       (p2_1): Conv2d(92.32 k, 1.267% Params, 18.09 MMac, 0.931% MACs, 576, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 6.328% Params, 90.38 MMac, 4.649% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(92.32 k, 1.267% Params, 18.09 MMac, 0.931% MACs, 576, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 6.328% Params, 90.38 MMac, 4.649% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 125.44 KMac, 0.006% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     2.7 M, 37.073% Params, 132.41 MMac, 6.810% MACs,
#     (0): Inception_mod6(
#       1.13 M, 15.471% Params, 55.24 MMac, 2.841% MACs,
#       (p2_1): Conv2d(102.56 k, 1.407% Params, 5.03 MMac, 0.258% MACs, 640, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 6.328% Params, 22.59 MMac, 1.162% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(102.56 k, 1.407% Params, 5.03 MMac, 0.258% MACs, 640, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 6.328% Params, 22.59 MMac, 1.162% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod6(
#       1.57 M, 21.601% Params, 77.13 MMac, 3.967% MACs,
#       (p2_1): Conv2d(123.07 k, 1.689% Params, 6.03 MMac, 0.310% MACs, 640, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 9.112% Params, 32.53 MMac, 1.673% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(123.07 k, 1.689% Params, 6.03 MMac, 0.310% MACs, 640, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(663.94 k, 9.112% Params, 32.53 MMac, 1.673% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 37.63 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(7.69 k, 0.106% Params, 7.69 KMac, 0.000% MACs, in_features=768, out_features=10, bias=True)
# )
# Computational complexity:       1.94 GMac
# Number of parameters:           7.29 M

# %% [markdown]
# #### GoogleNet_mod7

# %%
googlenet_mod7_f, macs_googlenet_mod7_f, paras_googlenet_mod7_f = get_model_info(Googlenet_mod7, channel_f, num_labels_f)
print('-'*50)
googlenet_mod7_c100, macs_googlenet_mod7_c100, paras_googlenet_mod7_c100 = get_model_info(Googlenet_mod7, channel_c, num_labels_c100)
print('-'*50)
googlenet_mod7_c10, macs_googlenet_mod7_c10, paras_googlenet_mod7_c10 = get_model_info(Googlenet_mod7, channel_c, num_labels_c10)
# Out:
# Warning: module Inception_mod7 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   11.71 M, 100.000% Params, 2.73 GMac, 99.771% MACs,
#   (0): Sequential(
#     3.2 k, 0.027% Params, 41.75 MMac, 1.523% MACs,
#     (0): Conv2d(3.2 k, 0.027% Params, 40.14 MMac, 1.465% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.029% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.029% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 0.982% Params, 361.87 MMac, 13.206% MACs,
#     (0): Conv2d(4.16 k, 0.036% Params, 13.05 MMac, 0.476% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.007% MACs, )
#     (2): Conv2d(110.78 k, 0.946% Params, 347.42 MMac, 12.679% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.022% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.022% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     1.2 M, 10.246% Params, 941.03 MMac, 34.342% MACs,
#     (0): Inception_mod7(
#       387.74 k, 3.312% Params, 303.99 MMac, 11.094% MACs,
#       (p2_1): Conv2d(18.53 k, 0.158% Params, 14.53 MMac, 0.530% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 0.946% Params, 86.8 MMac, 3.168% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(18.53 k, 0.158% Params, 14.53 MMac, 0.530% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(110.72 k, 0.946% Params, 86.8 MMac, 3.168% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(18.53 k, 0.158% Params, 14.53 MMac, 0.530% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(110.72 k, 0.946% Params, 86.8 MMac, 3.168% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod7(
#       811.97 k, 6.935% Params, 636.58 MMac, 23.231% MACs,
#       (p2_1): Conv2d(49.28 k, 0.421% Params, 38.64 MMac, 1.410% MACs, 384, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 1.891% Params, 173.56 MMac, 6.334% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(49.28 k, 0.421% Params, 38.64 MMac, 1.410% MACs, 384, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(221.38 k, 1.891% Params, 173.56 MMac, 6.334% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(49.28 k, 0.421% Params, 38.64 MMac, 1.410% MACs, 384, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(221.38 k, 1.891% Params, 173.56 MMac, 6.334% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 451.58 KMac, 0.016% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     5.99 M, 51.153% Params, 1.17 GMac, 42.847% MACs,
#     (0): Inception_mod7(
#       705.94 k, 6.029% Params, 138.36 MMac, 5.049% MACs,
#       (p2_1): Conv2d(55.39 k, 0.473% Params, 10.86 MMac, 0.396% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 1.537% Params, 35.26 MMac, 1.287% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(55.39 k, 0.473% Params, 10.86 MMac, 0.396% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(179.92 k, 1.537% Params, 35.26 MMac, 1.287% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(55.39 k, 0.473% Params, 10.86 MMac, 0.396% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(179.92 k, 1.537% Params, 35.26 MMac, 1.287% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod7(
#       888.05 k, 7.585% Params, 174.06 MMac, 6.352% MACs,
#       (p2_1): Conv2d(70.0 k, 0.598% Params, 13.72 MMac, 0.501% MACs, 624, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 1.930% Params, 44.3 MMac, 1.617% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(70.0 k, 0.598% Params, 13.72 MMac, 0.501% MACs, 624, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(226.02 k, 1.930% Params, 44.3 MMac, 1.617% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(70.0 k, 0.598% Params, 13.72 MMac, 0.501% MACs, 624, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(226.02 k, 1.930% Params, 44.3 MMac, 1.617% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): Inception_mod7(
#       1.14 M, 9.770% Params, 224.21 MMac, 8.182% MACs,
#       (p2_1): Conv2d(86.14 k, 0.736% Params, 16.88 MMac, 0.616% MACs, 672, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 2.521% Params, 57.85 MMac, 2.111% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(86.14 k, 0.736% Params, 16.88 MMac, 0.616% MACs, 672, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(295.17 k, 2.521% Params, 57.85 MMac, 2.111% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(86.14 k, 0.736% Params, 16.88 MMac, 0.616% MACs, 672, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(295.17 k, 2.521% Params, 57.85 MMac, 2.111% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (3): Inception_mod7(
#       1.45 M, 12.408% Params, 284.75 MMac, 10.392% MACs,
#       (p2_1): Conv2d(110.74 k, 0.946% Params, 21.7 MMac, 0.792% MACs, 768, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 3.190% Params, 73.21 MMac, 2.672% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(110.74 k, 0.946% Params, 21.7 MMac, 0.792% MACs, 768, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(373.54 k, 3.190% Params, 73.21 MMac, 2.672% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(110.74 k, 0.946% Params, 21.7 MMac, 0.792% MACs, 768, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(373.54 k, 3.190% Params, 73.21 MMac, 2.672% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (4): Inception_mod7(
#       1.8 M, 15.361% Params, 352.52 MMac, 12.865% MACs,
#       (p2_1): Conv2d(138.4 k, 1.182% Params, 27.13 MMac, 0.990% MACs, 864, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 3.938% Params, 90.38 MMac, 3.298% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(138.4 k, 1.182% Params, 27.13 MMac, 0.990% MACs, 864, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 3.938% Params, 90.38 MMac, 3.298% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(138.4 k, 1.182% Params, 27.13 MMac, 0.990% MACs, 864, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(461.12 k, 3.938% Params, 90.38 MMac, 3.298% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 188.16 KMac, 0.007% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     4.39 M, 37.493% Params, 215.17 MMac, 7.852% MACs,
#     (0): Inception_mod7(
#       1.84 M, 15.754% Params, 90.39 MMac, 3.299% MACs,
#       (p2_1): Conv2d(153.76 k, 1.313% Params, 7.53 MMac, 0.275% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 3.938% Params, 22.59 MMac, 0.825% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(153.76 k, 1.313% Params, 7.53 MMac, 0.275% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 3.938% Params, 22.59 MMac, 0.825% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(153.76 k, 1.313% Params, 7.53 MMac, 0.275% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(461.12 k, 3.938% Params, 22.59 MMac, 0.825% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod7(
#       2.55 M, 21.739% Params, 124.72 MMac, 4.552% MACs,
#       (p2_1): Conv2d(184.51 k, 1.576% Params, 9.04 MMac, 0.330% MACs, 960, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 5.670% Params, 32.53 MMac, 1.187% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(184.51 k, 1.576% Params, 9.04 MMac, 0.330% MACs, 960, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(663.94 k, 5.670% Params, 32.53 MMac, 1.187% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(184.51 k, 1.576% Params, 9.04 MMac, 0.330% MACs, 960, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(663.94 k, 5.670% Params, 32.53 MMac, 1.187% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 56.45 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(11.53 k, 0.098% Params, 11.53 KMac, 0.000% MACs, in_features=1152, out_features=10, bias=True)
# )
# Computational complexity:       2.74 GMac
# Number of parameters:           11.71 M
# --------------------------------------------------
# Warning: module Inception_mod7 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   11.82 M, 100.000% Params, 2.81 GMac, 99.777% MACs,
#   (0): Sequential(
#     9.47 k, 0.080% Params, 120.42 MMac, 4.272% MACs,
#     (0): Conv2d(9.47 k, 0.080% Params, 118.82 MMac, 4.215% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.028% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.028% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 0.973% Params, 361.87 MMac, 12.837% MACs,
#     (0): Conv2d(4.16 k, 0.035% Params, 13.05 MMac, 0.463% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.007% MACs, )
#     (2): Conv2d(110.78 k, 0.937% Params, 347.42 MMac, 12.324% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.021% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.021% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     1.2 M, 10.151% Params, 941.03 MMac, 33.382% MACs,
#     (0): Inception_mod7(
#       387.74 k, 3.281% Params, 303.99 MMac, 10.784% MACs,
#       (p2_1): Conv2d(18.53 k, 0.157% Params, 14.53 MMac, 0.515% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 0.937% Params, 86.8 MMac, 3.079% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(18.53 k, 0.157% Params, 14.53 MMac, 0.515% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(110.72 k, 0.937% Params, 86.8 MMac, 3.079% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(18.53 k, 0.157% Params, 14.53 MMac, 0.515% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(110.72 k, 0.937% Params, 86.8 MMac, 3.079% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod7(
#       811.97 k, 6.870% Params, 636.58 MMac, 22.582% MACs,
#       (p2_1): Conv2d(49.28 k, 0.417% Params, 38.64 MMac, 1.371% MACs, 384, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 1.873% Params, 173.56 MMac, 6.157% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(49.28 k, 0.417% Params, 38.64 MMac, 1.371% MACs, 384, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(221.38 k, 1.873% Params, 173.56 MMac, 6.157% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(49.28 k, 0.417% Params, 38.64 MMac, 1.371% MACs, 384, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(221.38 k, 1.873% Params, 173.56 MMac, 6.157% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 451.58 KMac, 0.016% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     5.99 M, 50.676% Params, 1.17 GMac, 41.650% MACs,
#     (0): Inception_mod7(
#       705.94 k, 5.973% Params, 138.36 MMac, 4.908% MACs,
#       (p2_1): Conv2d(55.39 k, 0.469% Params, 10.86 MMac, 0.385% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 1.522% Params, 35.26 MMac, 1.251% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(55.39 k, 0.469% Params, 10.86 MMac, 0.385% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(179.92 k, 1.522% Params, 35.26 MMac, 1.251% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(55.39 k, 0.469% Params, 10.86 MMac, 0.385% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(179.92 k, 1.522% Params, 35.26 MMac, 1.251% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod7(
#       888.05 k, 7.514% Params, 174.06 MMac, 6.175% MACs,
#       (p2_1): Conv2d(70.0 k, 0.592% Params, 13.72 MMac, 0.487% MACs, 624, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 1.912% Params, 44.3 MMac, 1.571% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(70.0 k, 0.592% Params, 13.72 MMac, 0.487% MACs, 624, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(226.02 k, 1.912% Params, 44.3 MMac, 1.571% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(70.0 k, 0.592% Params, 13.72 MMac, 0.487% MACs, 624, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(226.02 k, 1.912% Params, 44.3 MMac, 1.571% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): Inception_mod7(
#       1.14 M, 9.679% Params, 224.21 MMac, 7.954% MACs,
#       (p2_1): Conv2d(86.14 k, 0.729% Params, 16.88 MMac, 0.599% MACs, 672, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 2.497% Params, 57.85 MMac, 2.052% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(86.14 k, 0.729% Params, 16.88 MMac, 0.599% MACs, 672, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(295.17 k, 2.497% Params, 57.85 MMac, 2.052% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(86.14 k, 0.729% Params, 16.88 MMac, 0.599% MACs, 672, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(295.17 k, 2.497% Params, 57.85 MMac, 2.052% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (3): Inception_mod7(
#       1.45 M, 12.293% Params, 284.75 MMac, 10.101% MACs,
#       (p2_1): Conv2d(110.74 k, 0.937% Params, 21.7 MMac, 0.770% MACs, 768, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 3.161% Params, 73.21 MMac, 2.597% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(110.74 k, 0.937% Params, 21.7 MMac, 0.770% MACs, 768, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(373.54 k, 3.161% Params, 73.21 MMac, 2.597% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(110.74 k, 0.937% Params, 21.7 MMac, 0.770% MACs, 768, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(373.54 k, 3.161% Params, 73.21 MMac, 2.597% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (4): Inception_mod7(
#       1.8 M, 15.218% Params, 352.52 MMac, 12.505% MACs,
#       (p2_1): Conv2d(138.4 k, 1.171% Params, 27.13 MMac, 0.962% MACs, 864, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 3.902% Params, 90.38 MMac, 3.206% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(138.4 k, 1.171% Params, 27.13 MMac, 0.962% MACs, 864, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 3.902% Params, 90.38 MMac, 3.206% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(138.4 k, 1.171% Params, 27.13 MMac, 0.962% MACs, 864, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(461.12 k, 3.902% Params, 90.38 MMac, 3.206% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 188.16 KMac, 0.007% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     4.39 M, 37.144% Params, 215.17 MMac, 7.633% MACs,
#     (0): Inception_mod7(
#       1.84 M, 15.608% Params, 90.39 MMac, 3.206% MACs,
#       (p2_1): Conv2d(153.76 k, 1.301% Params, 7.53 MMac, 0.267% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 3.902% Params, 22.59 MMac, 0.802% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(153.76 k, 1.301% Params, 7.53 MMac, 0.267% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 3.902% Params, 22.59 MMac, 0.802% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(153.76 k, 1.301% Params, 7.53 MMac, 0.267% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(461.12 k, 3.902% Params, 22.59 MMac, 0.802% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod7(
#       2.55 M, 21.537% Params, 124.72 MMac, 4.424% MACs,
#       (p2_1): Conv2d(184.51 k, 1.561% Params, 9.04 MMac, 0.321% MACs, 960, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 5.618% Params, 32.53 MMac, 1.154% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(184.51 k, 1.561% Params, 9.04 MMac, 0.321% MACs, 960, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(663.94 k, 5.618% Params, 32.53 MMac, 1.154% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(184.51 k, 1.561% Params, 9.04 MMac, 0.321% MACs, 960, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(663.94 k, 5.618% Params, 32.53 MMac, 1.154% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 56.45 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(115.3 k, 0.976% Params, 115.3 KMac, 0.004% MACs, in_features=1152, out_features=100, bias=True)
# )
# Computational complexity:       2.82 GMac
# Number of parameters:           11.82 M
# --------------------------------------------------
# Warning: module Inception_mod7 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   11.71 M, 100.000% Params, 2.81 GMac, 99.777% MACs,
#   (0): Sequential(
#     9.47 k, 0.081% Params, 120.42 MMac, 4.272% MACs,
#     (0): Conv2d(9.47 k, 0.081% Params, 118.82 MMac, 4.215% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.028% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.028% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 0.981% Params, 361.87 MMac, 12.837% MACs,
#     (0): Conv2d(4.16 k, 0.036% Params, 13.05 MMac, 0.463% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.007% MACs, )
#     (2): Conv2d(110.78 k, 0.946% Params, 347.42 MMac, 12.325% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.021% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.021% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     1.2 M, 10.241% Params, 941.03 MMac, 33.383% MACs,
#     (0): Inception_mod7(
#       387.74 k, 3.310% Params, 303.99 MMac, 10.784% MACs,
#       (p2_1): Conv2d(18.53 k, 0.158% Params, 14.53 MMac, 0.515% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 0.945% Params, 86.8 MMac, 3.079% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(18.53 k, 0.158% Params, 14.53 MMac, 0.515% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(110.72 k, 0.945% Params, 86.8 MMac, 3.079% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(18.53 k, 0.158% Params, 14.53 MMac, 0.515% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(110.72 k, 0.945% Params, 86.8 MMac, 3.079% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod7(
#       811.97 k, 6.931% Params, 636.58 MMac, 22.583% MACs,
#       (p2_1): Conv2d(49.28 k, 0.421% Params, 38.64 MMac, 1.371% MACs, 384, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 1.890% Params, 173.56 MMac, 6.157% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(49.28 k, 0.421% Params, 38.64 MMac, 1.371% MACs, 384, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(221.38 k, 1.890% Params, 173.56 MMac, 6.157% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(49.28 k, 0.421% Params, 38.64 MMac, 1.371% MACs, 384, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(221.38 k, 1.890% Params, 173.56 MMac, 6.157% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 451.58 KMac, 0.016% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     5.99 M, 51.125% Params, 1.17 GMac, 41.651% MACs,
#     (0): Inception_mod7(
#       705.94 k, 6.026% Params, 138.36 MMac, 4.908% MACs,
#       (p2_1): Conv2d(55.39 k, 0.473% Params, 10.86 MMac, 0.385% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 1.536% Params, 35.26 MMac, 1.251% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(55.39 k, 0.473% Params, 10.86 MMac, 0.385% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(179.92 k, 1.536% Params, 35.26 MMac, 1.251% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(55.39 k, 0.473% Params, 10.86 MMac, 0.385% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(179.92 k, 1.536% Params, 35.26 MMac, 1.251% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod7(
#       888.05 k, 7.580% Params, 174.06 MMac, 6.175% MACs,
#       (p2_1): Conv2d(70.0 k, 0.598% Params, 13.72 MMac, 0.487% MACs, 624, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 1.929% Params, 44.3 MMac, 1.572% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(70.0 k, 0.598% Params, 13.72 MMac, 0.487% MACs, 624, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(226.02 k, 1.929% Params, 44.3 MMac, 1.572% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(70.0 k, 0.598% Params, 13.72 MMac, 0.487% MACs, 624, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(226.02 k, 1.929% Params, 44.3 MMac, 1.572% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): Inception_mod7(
#       1.14 M, 9.765% Params, 224.21 MMac, 7.954% MACs,
#       (p2_1): Conv2d(86.14 k, 0.735% Params, 16.88 MMac, 0.599% MACs, 672, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 2.520% Params, 57.85 MMac, 2.052% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(86.14 k, 0.735% Params, 16.88 MMac, 0.599% MACs, 672, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(295.17 k, 2.520% Params, 57.85 MMac, 2.052% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(86.14 k, 0.735% Params, 16.88 MMac, 0.599% MACs, 672, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(295.17 k, 2.520% Params, 57.85 MMac, 2.052% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (3): Inception_mod7(
#       1.45 M, 12.401% Params, 284.75 MMac, 10.102% MACs,
#       (p2_1): Conv2d(110.74 k, 0.945% Params, 21.7 MMac, 0.770% MACs, 768, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 3.189% Params, 73.21 MMac, 2.597% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(110.74 k, 0.945% Params, 21.7 MMac, 0.770% MACs, 768, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(373.54 k, 3.189% Params, 73.21 MMac, 2.597% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(110.74 k, 0.945% Params, 21.7 MMac, 0.770% MACs, 768, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(373.54 k, 3.189% Params, 73.21 MMac, 2.597% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (4): Inception_mod7(
#       1.8 M, 15.353% Params, 352.52 MMac, 12.506% MACs,
#       (p2_1): Conv2d(138.4 k, 1.181% Params, 27.13 MMac, 0.962% MACs, 864, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 3.936% Params, 90.38 MMac, 3.206% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(138.4 k, 1.181% Params, 27.13 MMac, 0.962% MACs, 864, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 3.936% Params, 90.38 MMac, 3.206% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(138.4 k, 1.181% Params, 27.13 MMac, 0.962% MACs, 864, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(461.12 k, 3.936% Params, 90.38 MMac, 3.206% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 188.16 KMac, 0.007% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     4.39 M, 37.473% Params, 215.17 MMac, 7.633% MACs,
#     (0): Inception_mod7(
#       1.84 M, 15.746% Params, 90.39 MMac, 3.207% MACs,
#       (p2_1): Conv2d(153.76 k, 1.313% Params, 7.53 MMac, 0.267% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 3.936% Params, 22.59 MMac, 0.802% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(153.76 k, 1.313% Params, 7.53 MMac, 0.267% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 3.936% Params, 22.59 MMac, 0.802% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(153.76 k, 1.313% Params, 7.53 MMac, 0.267% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(461.12 k, 3.936% Params, 22.59 MMac, 0.802% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod7(
#       2.55 M, 21.727% Params, 124.72 MMac, 4.425% MACs,
#       (p2_1): Conv2d(184.51 k, 1.575% Params, 9.04 MMac, 0.321% MACs, 960, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 5.667% Params, 32.53 MMac, 1.154% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(184.51 k, 1.575% Params, 9.04 MMac, 0.321% MACs, 960, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(663.94 k, 5.667% Params, 32.53 MMac, 1.154% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(184.51 k, 1.575% Params, 9.04 MMac, 0.321% MACs, 960, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(663.94 k, 5.667% Params, 32.53 MMac, 1.154% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 56.45 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(11.53 k, 0.098% Params, 11.53 KMac, 0.000% MACs, in_features=1152, out_features=10, bias=True)
# )
# Computational complexity:       2.82 GMac
# Number of parameters:           11.71 M

# %% [markdown]
# #### GoogleNet_mod8

# %%
googlenet_mod8_f, macs_googlenet_mod8_f, paras_googlenet_mod8_f = get_model_info(Googlenet_mod8, channel_f, num_labels_f)
print('-'*50)
googlenet_mod8_c100, macs_googlenet_mod8_c100, paras_googlenet_mod8_c100 = get_model_info(Googlenet_mod8, channel_c, num_labels_c100)
print('-'*50)
googlenet_mod8_c10, macs_googlenet_mod8_c10, paras_googlenet_mod8_c10 = get_model_info(Googlenet_mod8, channel_c, num_labels_c10)
# Out:
# Warning: module Inception_mod8 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   16.7 M, 100.000% Params, 3.7 GMac, 99.801% MACs,
#   (0): Sequential(
#     3.2 k, 0.019% Params, 41.75 MMac, 1.125% MACs,
#     (0): Conv2d(3.2 k, 0.019% Params, 40.14 MMac, 1.081% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.022% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.022% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 0.688% Params, 361.87 MMac, 9.749% MACs,
#     (0): Conv2d(4.16 k, 0.025% Params, 13.05 MMac, 0.351% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, )
#     (2): Conv2d(110.78 k, 0.663% Params, 347.42 MMac, 9.360% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.016% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.016% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     1.67 M, 9.970% Params, 1.31 GMac, 35.188% MACs,
#     (0): Inception_mod8(
#       516.99 k, 3.095% Params, 405.32 MMac, 10.920% MACs,
#       (p1_1): Conv2d(18.53 k, 0.111% Params, 14.53 MMac, 0.391% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(110.72 k, 0.663% Params, 86.8 MMac, 2.339% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(18.53 k, 0.111% Params, 14.53 MMac, 0.391% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 0.663% Params, 86.8 MMac, 2.339% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(18.53 k, 0.111% Params, 14.53 MMac, 0.391% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(110.72 k, 0.663% Params, 86.8 MMac, 2.339% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(18.53 k, 0.111% Params, 14.53 MMac, 0.391% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(110.72 k, 0.663% Params, 86.8 MMac, 2.339% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod8(
#       1.15 M, 6.875% Params, 900.16 MMac, 24.252% MACs,
#       (p1_1): Conv2d(65.66 k, 0.393% Params, 51.48 MMac, 1.387% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(221.38 k, 1.325% Params, 173.56 MMac, 4.676% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(65.66 k, 0.393% Params, 51.48 MMac, 1.387% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 1.325% Params, 173.56 MMac, 4.676% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(65.66 k, 0.393% Params, 51.48 MMac, 1.387% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(221.38 k, 1.325% Params, 173.56 MMac, 4.676% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(65.66 k, 0.393% Params, 51.48 MMac, 1.387% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(221.38 k, 1.325% Params, 173.56 MMac, 4.676% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.016% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     8.6 M, 51.487% Params, 1.69 GMac, 45.415% MACs,
#     (0): Inception_mod8(
#       1.01 M, 6.077% Params, 198.94 MMac, 5.360% MACs,
#       (p1_1): Conv2d(73.82 k, 0.442% Params, 14.47 MMac, 0.390% MACs, 768, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(179.92 k, 1.077% Params, 35.26 MMac, 0.950% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(73.82 k, 0.442% Params, 14.47 MMac, 0.390% MACs, 768, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 1.077% Params, 35.26 MMac, 0.950% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(73.82 k, 0.442% Params, 14.47 MMac, 0.390% MACs, 768, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(179.92 k, 1.077% Params, 35.26 MMac, 0.950% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(73.82 k, 0.442% Params, 14.47 MMac, 0.390% MACs, 768, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(179.92 k, 1.077% Params, 35.26 MMac, 0.950% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod8(
#       1.28 M, 7.647% Params, 250.34 MMac, 6.745% MACs,
#       (p1_1): Conv2d(93.3 k, 0.559% Params, 18.29 MMac, 0.493% MACs, 832, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(226.02 k, 1.353% Params, 44.3 MMac, 1.193% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(93.3 k, 0.559% Params, 18.29 MMac, 0.493% MACs, 832, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 1.353% Params, 44.3 MMac, 1.193% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(93.3 k, 0.559% Params, 18.29 MMac, 0.493% MACs, 832, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(226.02 k, 1.353% Params, 44.3 MMac, 1.193% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(93.3 k, 0.559% Params, 18.29 MMac, 0.493% MACs, 832, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(226.02 k, 1.353% Params, 44.3 MMac, 1.193% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): Inception_mod8(
#       1.64 M, 9.819% Params, 321.43 MMac, 8.660% MACs,
#       (p1_1): Conv2d(114.82 k, 0.687% Params, 22.5 MMac, 0.606% MACs, 896, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(295.17 k, 1.767% Params, 57.85 MMac, 1.559% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(114.82 k, 0.687% Params, 22.5 MMac, 0.606% MACs, 896, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 1.767% Params, 57.85 MMac, 1.559% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(114.82 k, 0.687% Params, 22.5 MMac, 0.606% MACs, 896, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(295.17 k, 1.767% Params, 57.85 MMac, 1.559% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(114.82 k, 0.687% Params, 22.5 MMac, 0.606% MACs, 896, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(295.17 k, 1.767% Params, 57.85 MMac, 1.559% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (3): Inception_mod8(
#       2.08 M, 12.481% Params, 408.57 MMac, 11.008% MACs,
#       (p1_1): Conv2d(147.6 k, 0.884% Params, 28.93 MMac, 0.779% MACs, 1024, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(373.54 k, 2.237% Params, 73.21 MMac, 1.972% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(147.6 k, 0.884% Params, 28.93 MMac, 0.779% MACs, 1024, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 2.237% Params, 73.21 MMac, 1.972% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(147.6 k, 0.884% Params, 28.93 MMac, 0.779% MACs, 1024, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(373.54 k, 2.237% Params, 73.21 MMac, 1.972% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(147.6 k, 0.884% Params, 28.93 MMac, 0.779% MACs, 1024, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(373.54 k, 2.237% Params, 73.21 MMac, 1.972% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (4): Inception_mod8(
#       2.58 M, 15.462% Params, 506.15 MMac, 13.637% MACs,
#       (p1_1): Conv2d(184.48 k, 1.105% Params, 36.16 MMac, 0.974% MACs, 1152, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(461.12 k, 2.761% Params, 90.38 MMac, 2.435% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(184.48 k, 1.105% Params, 36.16 MMac, 0.974% MACs, 1152, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 2.761% Params, 90.38 MMac, 2.435% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(184.48 k, 1.105% Params, 36.16 MMac, 0.974% MACs, 1152, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 2.761% Params, 90.38 MMac, 2.435% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(184.48 k, 1.105% Params, 36.16 MMac, 0.974% MACs, 1152, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(461.12 k, 2.761% Params, 90.38 MMac, 2.435% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 250.88 KMac, 0.007% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     6.3 M, 37.744% Params, 308.96 MMac, 8.324% MACs,
#     (0): Inception_mod8(
#       2.66 M, 15.952% Params, 130.55 MMac, 3.517% MACs,
#       (p1_1): Conv2d(204.96 k, 1.227% Params, 10.04 MMac, 0.271% MACs, 1280, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(461.12 k, 2.761% Params, 22.59 MMac, 0.609% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(204.96 k, 1.227% Params, 10.04 MMac, 0.271% MACs, 1280, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 2.761% Params, 22.59 MMac, 0.609% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(204.96 k, 1.227% Params, 10.04 MMac, 0.271% MACs, 1280, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 2.761% Params, 22.59 MMac, 0.609% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(204.96 k, 1.227% Params, 10.04 MMac, 0.271% MACs, 1280, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(461.12 k, 2.761% Params, 22.59 MMac, 0.609% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod8(
#       3.64 M, 21.792% Params, 178.34 MMac, 4.805% MACs,
#       (p1_1): Conv2d(245.95 k, 1.473% Params, 12.05 MMac, 0.325% MACs, 1280, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(663.94 k, 3.975% Params, 32.53 MMac, 0.876% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(245.95 k, 1.473% Params, 12.05 MMac, 0.325% MACs, 1280, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 3.975% Params, 32.53 MMac, 0.876% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(245.95 k, 1.473% Params, 12.05 MMac, 0.325% MACs, 1280, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(663.94 k, 3.975% Params, 32.53 MMac, 0.876% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(245.95 k, 1.473% Params, 12.05 MMac, 0.325% MACs, 1280, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(663.94 k, 3.975% Params, 32.53 MMac, 0.876% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 75.26 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(15.37 k, 0.092% Params, 15.37 KMac, 0.000% MACs, in_features=1536, out_features=10, bias=True)
# )
# Computational complexity:       3.71 GMac
# Number of parameters:           16.7 M
# --------------------------------------------------
# Warning: module Inception_mod8 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   16.85 M, 100.000% Params, 3.78 GMac, 99.806% MACs,
#   (0): Sequential(
#     9.47 k, 0.056% Params, 120.42 MMac, 3.177% MACs,
#     (0): Conv2d(9.47 k, 0.056% Params, 118.82 MMac, 3.135% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.021% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.021% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 0.682% Params, 361.87 MMac, 9.547% MACs,
#     (0): Conv2d(4.16 k, 0.025% Params, 13.05 MMac, 0.344% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, )
#     (2): Conv2d(110.78 k, 0.658% Params, 347.42 MMac, 9.165% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.016% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.016% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     1.67 M, 9.884% Params, 1.31 GMac, 34.456% MACs,
#     (0): Inception_mod8(
#       516.99 k, 3.069% Params, 405.32 MMac, 10.693% MACs,
#       (p1_1): Conv2d(18.53 k, 0.110% Params, 14.53 MMac, 0.383% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(110.72 k, 0.657% Params, 86.8 MMac, 2.290% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(18.53 k, 0.110% Params, 14.53 MMac, 0.383% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 0.657% Params, 86.8 MMac, 2.290% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(18.53 k, 0.110% Params, 14.53 MMac, 0.383% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(110.72 k, 0.657% Params, 86.8 MMac, 2.290% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(18.53 k, 0.110% Params, 14.53 MMac, 0.383% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(110.72 k, 0.657% Params, 86.8 MMac, 2.290% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod8(
#       1.15 M, 6.816% Params, 900.16 MMac, 23.747% MACs,
#       (p1_1): Conv2d(65.66 k, 0.390% Params, 51.48 MMac, 1.358% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(221.38 k, 1.314% Params, 173.56 MMac, 4.579% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(65.66 k, 0.390% Params, 51.48 MMac, 1.358% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 1.314% Params, 173.56 MMac, 4.579% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(65.66 k, 0.390% Params, 51.48 MMac, 1.358% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(221.38 k, 1.314% Params, 173.56 MMac, 4.579% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(65.66 k, 0.390% Params, 51.48 MMac, 1.358% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(221.38 k, 1.314% Params, 173.56 MMac, 4.579% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.016% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     8.6 M, 51.045% Params, 1.69 GMac, 44.471% MACs,
#     (0): Inception_mod8(
#       1.01 M, 6.025% Params, 198.94 MMac, 5.248% MACs,
#       (p1_1): Conv2d(73.82 k, 0.438% Params, 14.47 MMac, 0.382% MACs, 768, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(179.92 k, 1.068% Params, 35.26 MMac, 0.930% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(73.82 k, 0.438% Params, 14.47 MMac, 0.382% MACs, 768, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 1.068% Params, 35.26 MMac, 0.930% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(73.82 k, 0.438% Params, 14.47 MMac, 0.382% MACs, 768, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(179.92 k, 1.068% Params, 35.26 MMac, 0.930% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(73.82 k, 0.438% Params, 14.47 MMac, 0.382% MACs, 768, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(179.92 k, 1.068% Params, 35.26 MMac, 0.930% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod8(
#       1.28 M, 7.582% Params, 250.34 MMac, 6.604% MACs,
#       (p1_1): Conv2d(93.3 k, 0.554% Params, 18.29 MMac, 0.482% MACs, 832, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(226.02 k, 1.342% Params, 44.3 MMac, 1.169% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(93.3 k, 0.554% Params, 18.29 MMac, 0.482% MACs, 832, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 1.342% Params, 44.3 MMac, 1.169% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(93.3 k, 0.554% Params, 18.29 MMac, 0.482% MACs, 832, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(226.02 k, 1.342% Params, 44.3 MMac, 1.169% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(93.3 k, 0.554% Params, 18.29 MMac, 0.482% MACs, 832, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(226.02 k, 1.342% Params, 44.3 MMac, 1.169% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): Inception_mod8(
#       1.64 M, 9.735% Params, 321.43 MMac, 8.480% MACs,
#       (p1_1): Conv2d(114.82 k, 0.682% Params, 22.5 MMac, 0.594% MACs, 896, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(295.17 k, 1.752% Params, 57.85 MMac, 1.526% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(114.82 k, 0.682% Params, 22.5 MMac, 0.594% MACs, 896, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 1.752% Params, 57.85 MMac, 1.526% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(114.82 k, 0.682% Params, 22.5 MMac, 0.594% MACs, 896, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(295.17 k, 1.752% Params, 57.85 MMac, 1.526% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(114.82 k, 0.682% Params, 22.5 MMac, 0.594% MACs, 896, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(295.17 k, 1.752% Params, 57.85 MMac, 1.526% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (3): Inception_mod8(
#       2.08 M, 12.374% Params, 408.57 MMac, 10.779% MACs,
#       (p1_1): Conv2d(147.6 k, 0.876% Params, 28.93 MMac, 0.763% MACs, 1024, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(373.54 k, 2.217% Params, 73.21 MMac, 1.931% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(147.6 k, 0.876% Params, 28.93 MMac, 0.763% MACs, 1024, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 2.217% Params, 73.21 MMac, 1.931% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(147.6 k, 0.876% Params, 28.93 MMac, 0.763% MACs, 1024, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(373.54 k, 2.217% Params, 73.21 MMac, 1.931% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(147.6 k, 0.876% Params, 28.93 MMac, 0.763% MACs, 1024, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(373.54 k, 2.217% Params, 73.21 MMac, 1.931% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (4): Inception_mod8(
#       2.58 M, 15.329% Params, 506.15 MMac, 13.353% MACs,
#       (p1_1): Conv2d(184.48 k, 1.095% Params, 36.16 MMac, 0.954% MACs, 1152, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(461.12 k, 2.737% Params, 90.38 MMac, 2.384% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(184.48 k, 1.095% Params, 36.16 MMac, 0.954% MACs, 1152, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 2.737% Params, 90.38 MMac, 2.384% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(184.48 k, 1.095% Params, 36.16 MMac, 0.954% MACs, 1152, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 2.737% Params, 90.38 MMac, 2.384% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(184.48 k, 1.095% Params, 36.16 MMac, 0.954% MACs, 1152, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(461.12 k, 2.737% Params, 90.38 MMac, 2.384% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 250.88 KMac, 0.007% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     6.3 M, 37.420% Params, 308.96 MMac, 8.151% MACs,
#     (0): Inception_mod8(
#       2.66 M, 15.816% Params, 130.55 MMac, 3.444% MACs,
#       (p1_1): Conv2d(204.96 k, 1.217% Params, 10.04 MMac, 0.265% MACs, 1280, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(461.12 k, 2.737% Params, 22.59 MMac, 0.596% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(204.96 k, 1.217% Params, 10.04 MMac, 0.265% MACs, 1280, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 2.737% Params, 22.59 MMac, 0.596% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(204.96 k, 1.217% Params, 10.04 MMac, 0.265% MACs, 1280, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 2.737% Params, 22.59 MMac, 0.596% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(204.96 k, 1.217% Params, 10.04 MMac, 0.265% MACs, 1280, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(461.12 k, 2.737% Params, 22.59 MMac, 0.596% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod8(
#       3.64 M, 21.605% Params, 178.34 MMac, 4.705% MACs,
#       (p1_1): Conv2d(245.95 k, 1.460% Params, 12.05 MMac, 0.318% MACs, 1280, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(663.94 k, 3.941% Params, 32.53 MMac, 0.858% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(245.95 k, 1.460% Params, 12.05 MMac, 0.318% MACs, 1280, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 3.941% Params, 32.53 MMac, 0.858% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(245.95 k, 1.460% Params, 12.05 MMac, 0.318% MACs, 1280, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(663.94 k, 3.941% Params, 32.53 MMac, 0.858% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(245.95 k, 1.460% Params, 12.05 MMac, 0.318% MACs, 1280, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(663.94 k, 3.941% Params, 32.53 MMac, 0.858% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 75.26 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(153.7 k, 0.912% Params, 153.7 KMac, 0.004% MACs, in_features=1536, out_features=100, bias=True)
# )
# Computational complexity:       3.79 GMac
# Number of parameters:           16.85 M
# --------------------------------------------------
# Warning: module Inception_mod8 is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   16.71 M, 100.000% Params, 3.78 GMac, 99.806% MACs,
#   (0): Sequential(
#     9.47 k, 0.057% Params, 120.42 MMac, 3.177% MACs,
#     (0): Conv2d(9.47 k, 0.057% Params, 118.82 MMac, 3.135% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.021% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.021% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 0.688% Params, 361.87 MMac, 9.547% MACs,
#     (0): Conv2d(4.16 k, 0.025% Params, 13.05 MMac, 0.344% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, )
#     (2): Conv2d(110.78 k, 0.663% Params, 347.42 MMac, 9.166% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.016% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.016% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     1.67 M, 9.966% Params, 1.31 GMac, 34.458% MACs,
#     (0): Inception_mod8(
#       516.99 k, 3.094% Params, 405.32 MMac, 10.693% MACs,
#       (p1_1): Conv2d(18.53 k, 0.111% Params, 14.53 MMac, 0.383% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(110.72 k, 0.663% Params, 86.8 MMac, 2.290% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(18.53 k, 0.111% Params, 14.53 MMac, 0.383% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(110.72 k, 0.663% Params, 86.8 MMac, 2.290% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(18.53 k, 0.111% Params, 14.53 MMac, 0.383% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(110.72 k, 0.663% Params, 86.8 MMac, 2.290% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(18.53 k, 0.111% Params, 14.53 MMac, 0.383% MACs, 192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(110.72 k, 0.663% Params, 86.8 MMac, 2.290% MACs, 96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod8(
#       1.15 M, 6.872% Params, 900.16 MMac, 23.748% MACs,
#       (p1_1): Conv2d(65.66 k, 0.393% Params, 51.48 MMac, 1.358% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(221.38 k, 1.325% Params, 173.56 MMac, 4.579% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(65.66 k, 0.393% Params, 51.48 MMac, 1.358% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(221.38 k, 1.325% Params, 173.56 MMac, 4.579% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(65.66 k, 0.393% Params, 51.48 MMac, 1.358% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(221.38 k, 1.325% Params, 173.56 MMac, 4.579% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(65.66 k, 0.393% Params, 51.48 MMac, 1.358% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(221.38 k, 1.325% Params, 173.56 MMac, 4.579% MACs, 128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.016% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     8.6 M, 51.467% Params, 1.69 GMac, 44.472% MACs,
#     (0): Inception_mod8(
#       1.01 M, 6.075% Params, 198.94 MMac, 5.248% MACs,
#       (p1_1): Conv2d(73.82 k, 0.442% Params, 14.47 MMac, 0.382% MACs, 768, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(179.92 k, 1.077% Params, 35.26 MMac, 0.930% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(73.82 k, 0.442% Params, 14.47 MMac, 0.382% MACs, 768, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(179.92 k, 1.077% Params, 35.26 MMac, 0.930% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(73.82 k, 0.442% Params, 14.47 MMac, 0.382% MACs, 768, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(179.92 k, 1.077% Params, 35.26 MMac, 0.930% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(73.82 k, 0.442% Params, 14.47 MMac, 0.382% MACs, 768, 96, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(179.92 k, 1.077% Params, 35.26 MMac, 0.930% MACs, 96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod8(
#       1.28 M, 7.645% Params, 250.34 MMac, 6.605% MACs,
#       (p1_1): Conv2d(93.3 k, 0.558% Params, 18.29 MMac, 0.482% MACs, 832, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(226.02 k, 1.353% Params, 44.3 MMac, 1.169% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(93.3 k, 0.558% Params, 18.29 MMac, 0.482% MACs, 832, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(226.02 k, 1.353% Params, 44.3 MMac, 1.169% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(93.3 k, 0.558% Params, 18.29 MMac, 0.482% MACs, 832, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(226.02 k, 1.353% Params, 44.3 MMac, 1.169% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(93.3 k, 0.558% Params, 18.29 MMac, 0.482% MACs, 832, 112, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(226.02 k, 1.353% Params, 44.3 MMac, 1.169% MACs, 112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): Inception_mod8(
#       1.64 M, 9.815% Params, 321.43 MMac, 8.480% MACs,
#       (p1_1): Conv2d(114.82 k, 0.687% Params, 22.5 MMac, 0.594% MACs, 896, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(295.17 k, 1.767% Params, 57.85 MMac, 1.526% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(114.82 k, 0.687% Params, 22.5 MMac, 0.594% MACs, 896, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(295.17 k, 1.767% Params, 57.85 MMac, 1.526% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(114.82 k, 0.687% Params, 22.5 MMac, 0.594% MACs, 896, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(295.17 k, 1.767% Params, 57.85 MMac, 1.526% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(114.82 k, 0.687% Params, 22.5 MMac, 0.594% MACs, 896, 128, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(295.17 k, 1.767% Params, 57.85 MMac, 1.526% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (3): Inception_mod8(
#       2.08 M, 12.476% Params, 408.57 MMac, 10.779% MACs,
#       (p1_1): Conv2d(147.6 k, 0.883% Params, 28.93 MMac, 0.763% MACs, 1024, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(373.54 k, 2.236% Params, 73.21 MMac, 1.932% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(147.6 k, 0.883% Params, 28.93 MMac, 0.763% MACs, 1024, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(373.54 k, 2.236% Params, 73.21 MMac, 1.932% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(147.6 k, 0.883% Params, 28.93 MMac, 0.763% MACs, 1024, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(373.54 k, 2.236% Params, 73.21 MMac, 1.932% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(147.6 k, 0.883% Params, 28.93 MMac, 0.763% MACs, 1024, 144, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(373.54 k, 2.236% Params, 73.21 MMac, 1.932% MACs, 144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (4): Inception_mod8(
#       2.58 M, 15.456% Params, 506.15 MMac, 13.353% MACs,
#       (p1_1): Conv2d(184.48 k, 1.104% Params, 36.16 MMac, 0.954% MACs, 1152, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(461.12 k, 2.760% Params, 90.38 MMac, 2.384% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(184.48 k, 1.104% Params, 36.16 MMac, 0.954% MACs, 1152, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 2.760% Params, 90.38 MMac, 2.384% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(184.48 k, 1.104% Params, 36.16 MMac, 0.954% MACs, 1152, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 2.760% Params, 90.38 MMac, 2.384% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(184.48 k, 1.104% Params, 36.16 MMac, 0.954% MACs, 1152, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(461.12 k, 2.760% Params, 90.38 MMac, 2.384% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (5): MaxPool2d(0, 0.000% Params, 250.88 KMac, 0.007% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     6.3 M, 37.730% Params, 308.96 MMac, 8.151% MACs,
#     (0): Inception_mod8(
#       2.66 M, 15.946% Params, 130.55 MMac, 3.444% MACs,
#       (p1_1): Conv2d(204.96 k, 1.227% Params, 10.04 MMac, 0.265% MACs, 1280, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(461.12 k, 2.760% Params, 22.59 MMac, 0.596% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(204.96 k, 1.227% Params, 10.04 MMac, 0.265% MACs, 1280, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(461.12 k, 2.760% Params, 22.59 MMac, 0.596% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(204.96 k, 1.227% Params, 10.04 MMac, 0.265% MACs, 1280, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(461.12 k, 2.760% Params, 22.59 MMac, 0.596% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(204.96 k, 1.227% Params, 10.04 MMac, 0.265% MACs, 1280, 160, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(461.12 k, 2.760% Params, 22.59 MMac, 0.596% MACs, 160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1): Inception_mod8(
#       3.64 M, 21.783% Params, 178.34 MMac, 4.705% MACs,
#       (p1_1): Conv2d(245.95 k, 1.472% Params, 12.05 MMac, 0.318% MACs, 1280, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p1_2): Conv2d(663.94 k, 3.974% Params, 32.53 MMac, 0.858% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p2_1): Conv2d(245.95 k, 1.472% Params, 12.05 MMac, 0.318% MACs, 1280, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p2_2): Conv2d(663.94 k, 3.974% Params, 32.53 MMac, 0.858% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p3_1): Conv2d(245.95 k, 1.472% Params, 12.05 MMac, 0.318% MACs, 1280, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p3_2): Conv2d(663.94 k, 3.974% Params, 32.53 MMac, 0.858% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (p4_1): Conv2d(245.95 k, 1.472% Params, 12.05 MMac, 0.318% MACs, 1280, 192, kernel_size=(1, 1), stride=(1, 1))
#       (p4_2): Conv2d(663.94 k, 3.974% Params, 32.53 MMac, 0.858% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(0, 0.000% Params, 75.26 KMac, 0.002% MACs, output_size=(1, 1))
#     (3): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (5): Linear(15.37 k, 0.092% Params, 15.37 KMac, 0.000% MACs, in_features=1536, out_features=10, bias=True)
# )
# Computational complexity:       3.79 GMac
# Number of parameters:           16.71 M

# %% [markdown]
# #### GoogleNet_mod9

# %%
googlenet_mod9_f, macs_googlenet_mod9_f, paras_googlenet_mod9_f = get_model_info(Googlenet_mod9, channel_f, num_labels_f)
print('-'*50)
googlenet_mod9_c100, macs_googlenet_mod9_c100, paras_googlenet_mod9_c100 = get_model_info(Googlenet_mod9, channel_c, num_labels_c100)
print('-'*50)
googlenet_mod9_c10, macs_googlenet_mod9_c10, paras_googlenet_mod9_c10 = get_model_info(Googlenet_mod9, channel_c, num_labels_c10)
# Out:
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   120.07 k, 100.000% Params, 403.77 MMac, 99.223% MACs,
#   (0): Sequential(
#     3.2 k, 2.665% Params, 41.75 MMac, 10.259% MACs,
#     (0): Conv2d(3.2 k, 2.665% Params, 40.14 MMac, 9.864% MACs, 1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.197% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.197% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 95.728% Params, 361.87 MMac, 88.927% MACs,
#     (0): Conv2d(4.16 k, 3.465% Params, 13.05 MMac, 3.206% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.049% MACs, )
#     (2): Conv2d(110.78 k, 92.263% Params, 347.42 MMac, 85.376% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.148% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.148% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     0, 0.000% Params, 150.53 KMac, 0.037% MACs,
#     (0): AdaptiveAvgPool2d(0, 0.000% Params, 150.53 KMac, 0.037% MACs, output_size=(1, 1))
#     (1): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (3): Linear(1.93 k, 1.607% Params, 1.93 KMac, 0.000% MACs, in_features=192, out_features=10, bias=True)
# )
# Computational complexity:       406.93 MMac
# Number of parameters:           120.07 k
# --------------------------------------------------
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   143.72 k, 100.000% Params, 482.46 MMac, 99.349% MACs,
#   (0): Sequential(
#     9.47 k, 6.591% Params, 120.42 MMac, 24.798% MACs,
#     (0): Conv2d(9.47 k, 6.591% Params, 118.82 MMac, 24.467% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.165% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.165% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 79.980% Params, 361.87 MMac, 74.517% MACs,
#     (0): Conv2d(4.16 k, 2.895% Params, 13.05 MMac, 2.686% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.041% MACs, )
#     (2): Conv2d(110.78 k, 77.085% Params, 347.42 MMac, 71.541% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.124% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.124% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     0, 0.000% Params, 150.53 KMac, 0.031% MACs,
#     (0): AdaptiveAvgPool2d(0, 0.000% Params, 150.53 KMac, 0.031% MACs, output_size=(1, 1))
#     (1): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (3): Linear(19.3 k, 13.429% Params, 19.3 KMac, 0.004% MACs, in_features=192, out_features=100, bias=True)
# )
# Computational complexity:       485.62 MMac
# Number of parameters:           143.72 k
# --------------------------------------------------
# Warning: module Flatten is treated as a zero-op.
# Sequential(
#   126.35 k, 100.000% Params, 482.44 MMac, 99.349% MACs,
#   (0): Sequential(
#     9.47 k, 7.497% Params, 120.42 MMac, 24.798% MACs,
#     (0): Conv2d(9.47 k, 7.497% Params, 118.82 MMac, 24.468% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(0, 0.000% Params, 802.82 KMac, 0.165% MACs, )
#     (2): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.165% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     114.94 k, 90.976% Params, 361.87 MMac, 74.519% MACs,
#     (0): Conv2d(4.16 k, 3.293% Params, 13.05 MMac, 2.686% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU(0, 0.000% Params, 200.7 KMac, 0.041% MACs, )
#     (2): Conv2d(110.78 k, 87.683% Params, 347.42 MMac, 71.543% MACs, 64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 602.11 KMac, 0.124% MACs, )
#     (4): MaxPool2d(0, 0.000% Params, 602.11 KMac, 0.124% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     0, 0.000% Params, 150.53 KMac, 0.031% MACs,
#     (0): AdaptiveAvgPool2d(0, 0.000% Params, 150.53 KMac, 0.031% MACs, output_size=(1, 1))
#     (1): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#   )
#   (3): Linear(1.93 k, 1.528% Params, 1.93 KMac, 0.000% MACs, in_features=192, out_features=10, bias=True)
# )
# Computational complexity:       485.61 MMac
# Number of parameters:           126.35 k

# %% [markdown]
# ## Import the Datasets for training

# %% [markdown]
# ### show the output size of each layers after the picture is passed through the model

# %%
print(models_name)
# Out:
# ['alexnet', 'vgg11', 'vgg13', 'vgg16', 'resnet18', 'resnet34', 'resnet50', 'googlenet_origin', 'googlenet_mod1', 'googlenet_mod2', 'googlenet_mod3', 'googlenet_mod4', 'googlenet_mod5', 'googlenet_mod6', 'googlenet_mod7', 'googlenet_mod8', 'googlenet_mod9', 'mobilenetv1', 'mobilenetv2']

# %%
# create model list according to models_name order
models_f_list = [alexnet_f, 
                vgg11_f, vgg13_f, vgg16_f,
                resnet18_f, resnet34_f, resnet50_f,
                googlenet_f, googlenet_mod1_f, googlenet_mod2_f, googlenet_mod3_f, 
                googlenet_mod4_f, googlenet_mod5_f, googlenet_mod6_f, googlenet_mod7_f,
                googlenet_mod8_f, googlenet_mod9_f,
                mobilenetv1_f, mobilenetv2_f]

models_c100_list = [alexnet_c100,
                vgg11_c100, vgg13_c100, vgg16_c100,
                resnet18_c100, resnet34_c100, resnet50_c100,
                googlenet_c100, googlenet_mod1_c100, googlenet_mod2_c100, googlenet_mod3_c100, 
                googlenet_mod4_c100, googlenet_mod5_c100, googlenet_mod6_c100, googlenet_mod7_c100,
                googlenet_mod8_c100, googlenet_mod9_c100,
                mobilenetv1_c100, mobilenetv2_c100]

models_c10_list = [alexnet_c10,
                vgg11_c10, vgg13_c10, vgg16_c10,
                resnet18_c10, resnet34_c10, resnet50_c10,
                googlenet_c10, googlenet_mod1_c10, googlenet_mod2_c10, googlenet_mod3_c10, 
                googlenet_mod4_c10, googlenet_mod5_c10, googlenet_mod6_c10, googlenet_mod7_c10,
                googlenet_mod8_c10, googlenet_mod9_c10,
                mobilenetv1_c10, mobilenetv2_c10]

# %%
# X_f = torch.randn(size=(1, 1, 224, 224), dtype=torch.float32) # fashion mnist

# for model in models_f_list:
#     print(model)
#     for layer in model:
#         X_f=layer(X_f)
#         print(layer.__class__.__name__,'output shape:\t',X_f.shape)

# %% [markdown]
# ### load all the datas:
#     1. FashionMNIST
#     2. CIFAR100
#     3. CIFAR10

# %%
# load the data
# fashion mnist
def get_dataloader_workers():
    """Use 4 processes to read the data.

    Defined in :numref:`sec_utils`"""
    return 4

def load_data_fashion_mnist(batch_size, resize=None):
    """下载Fashion-MNIST数据集, 然后将其加载到内存中

    Defined in :numref:`sec_fashion_mnist`"""
    trans = [transforms.ToTensor()]
    if resize:
        trans.insert(0, transforms.Resize(resize))
    trans = transforms.Compose(trans)
    mnist_train = torchvision.datasets.FashionMNIST(
        root="../data", train=True, transform=trans, download=True)
    mnist_test = torchvision.datasets.FashionMNIST(
        root="../data", train=False, transform=trans, download=True)
    return (torch.utils.data.DataLoader(mnist_train, batch_size, shuffle=True,
                            num_workers=get_dataloader_workers()),
            torch.utils.data.DataLoader(mnist_test, batch_size, shuffle=False,
                            num_workers=get_dataloader_workers()))

def load_data_cifar100(batch_size, resize=None):
    """Download the Fashion-MNIST dataset and then load it into memory.

    Defined in :numref:`sec_utils`"""
    trans = [transforms.ToTensor()]
    if resize:
        trans.insert(0, transforms.Resize(resize))
    trans = transforms.Compose(trans)
    # import the cifar100 dataset
    cifar_train = torchvision.datasets.CIFAR100(
        root="../data", train=True, transform=trans, download=True)
    cifar_test = torchvision.datasets.CIFAR100(
        root="../data", train=False, transform=trans, download=True)
    return (torch.utils.data.DataLoader(cifar_train, batch_size, shuffle=True,
                                        num_workers=get_dataloader_workers()),
            torch.utils.data.DataLoader(cifar_test, batch_size, shuffle=False,
                                        num_workers=get_dataloader_workers()))
    
def load_data_cifar10(batch_size, resize=None):
    """Download the Fashion-MNIST dataset and then load it into memory.

    Defined in :numref:`sec_utils`"""
    trans = [transforms.ToTensor()]
    if resize:
        trans.insert(0, transforms.Resize(resize))
    trans = transforms.Compose(trans)
    # import the cifar100 dataset
    cifar_train = torchvision.datasets.CIFAR10(
        root="../data", train=True, transform=trans, download=True)
    cifar_test = torchvision.datasets.CIFAR10(
        root="../data", train=False, transform=trans, download=True)
    return (torch.utils.data.DataLoader(cifar_train, batch_size, shuffle=True,
                                        num_workers=get_dataloader_workers()),
            torch.utils.data.DataLoader(cifar_test, batch_size, shuffle=False,
                                        num_workers=get_dataloader_workers()))

# %% [markdown]
# ### set the training parameters

# %%
batch_size = [128]
epochs = [5]
rounds = 1

# %% [markdown]
# ## Train Function

# %% [markdown]
# #### set the learning rate

# %%
lr = 0.02
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('The device is:', device)
# Out:
# The device is: cuda

# %% [markdown]
# #### using pynvml to get the GPU power consumption

# %%
def nvml_sampling_thread(handle, filename, stop_event, sampling_interval):
    """
    在单独的线程中定期调用 NVML, 获取功耗数据并存储到 data_queue 中。
    参数：
    - handle: nvmlDeviceGetHandleByIndex(0) 得到的 GPU 句柄
    - data_queue: 用于存放 (timestamp, power_in_watts) 数据的队列
    - stop_event: 当此事件被设置时，线程应结束循环
    - sampling_interval: 采样间隔（秒）
    """
    with open(filename/'energy_consumption_file.csv', 'a') as f:  # 追加模式
        # 写入列名
        f.write("timestamp,power_in_watts\n")
        while not stop_event.is_set():
            try:
                # 采集功率和时间戳
                current_time = time.time()
                current_power = pynvml.nvmlDeviceGetPowerUsage(handle) / 1000.0  # 转换 mW -> W
                # 写入文件
                f.write(f"{current_time},{current_power}\n")
                # 等待下一次采样
                time.sleep(sampling_interval)
            except pynvml.NVMLError as e:
                print(f"NVML Error: {e}")
                break

# %% [markdown]
# #### set the interval of the power consumption

# %%
def integrate_power_over_interval(samples, start_time, end_time):
    # 假定 samples是按时间升序排序的 (t, p)
    # 若未排序，请先排序:
    # samples = sorted(samples, key=lambda x: x[0])
    
    def interpolate(samples, target_time):
        # 在 samples 中找到 target_time 左右最近的两个点，并进行线性插值
        # 若 target_time 恰好等于某个样本点时间，直接返回该点功率
        # 若无法找到两侧点（如 target_time在样本时间轴外），根据情况返回None或边界点
        n = len(samples)
        if n == 0:
            return None
        # 若 target_time 小于第一个样本点时间，无法向左插值，这里直接返回第一个点的功率值(或None)
        if target_time <= samples[0][0]:
            # 简化处理：返回最早样本点的功率（或None）
            return samples[0][1]
        # 若 target_time 大于最后一个样本点时间，无法向右插值，返回最后一个点的功率（或None）
        if target_time >= samples[-1][0]:
            return samples[-1][1]

        # 否则，在中间插值
        # 使用二分查找快速定位
        import bisect
        times = [t for t, _ in samples]
        pos = bisect.bisect_left(times, target_time)
        # pos是使times保持有序插入target_time的位置
        # 因为target_time不在已有样本点中，pos不会越界且pos>0且pos<n
        t1, p1 = samples[pos-1]
        t2, p2 = samples[pos]
        # 线性插值： p = p1 + (p2 - p1)*((target_time - t1)/(t2 - t1))
        ratio = (target_time - t1) / (t2 - t1)
        p = p1 + (p2 - p1)*ratio
        return p

    # 从原始 samples 中筛选出位于[start_time, end_time]内的点
    filtered = [(t, p) for t, p in samples if start_time <= t <= end_time]

    # 如果不足2个点，则尝试使用插值
    if len(filtered) < 2:
        # 无论如何都需要在边界处插值出两个点(起码start和end)
        start_power = interpolate(samples, start_time)
        end_power = interpolate(samples, end_time)

        # 如果从样本中无法插值出任何有意义的点（比如samples为空或无法插值），返回0.0
        if start_power is None or end_power is None:
            return 0.0

        # 将插值的边界点加入到 filtered
        # 注意：如果filtered中有一个点在区间内，我们也需要确保边界有两点以上
        # 例如filtered只有一个点在中间，则需要在start和end插值点全部加入。
        # 若filtered为空，则只用start/end两点插值点求积分
        new_filtered = [(start_time, start_power)] + filtered + [(end_time, end_power)]
        # 确保按时间排序
        new_filtered.sort(key=lambda x: x[0])
        filtered = new_filtered

    # 正常积分计算
    if len(filtered) < 2:
        # 经过插值仍不够，返回0
        return 0.0

    total_energy = 0.0
    for i in range(len(filtered)-1):
        t1, p1 = filtered[i]
        t2, p2 = filtered[i+1]
        dt = t2 - t1
        avg_p = (p1 + p2)/2.0
        total_energy += avg_p * dt

    return total_energy

# %% [markdown]
# #### set the training process

# %%
def train_func(net, train_iter, test_iter, num_epochs, lr, device, filename, sampling_interval):
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            nn.init.xavier_uniform_(m.weight)
    net.apply(init_weights)
    print('training on', device)
    net.to(device)
    optimizer = torch.optim.SGD(net.parameters(), lr=lr)
    loss_fn = nn.CrossEntropyLoss()

    # Initialize GradScaler for mixed precision
    scaler = torch.cuda.amp.GradScaler()

    # save all epochs time data using list
    to_device_intervals_total = []
    forward_intervals_total = []
    loss_intervals_total = []
    backward_intervals_total = []
    optimize_intervals_total = []
    test_intervals_total = []

    # create a list to store the epoch time data
    epoch_intervals_total = []
    
    # Initialize NVML and sampling thread
    pynvml.nvmlInit()
    handle = pynvml.nvmlDeviceGetHandleByIndex(0)
    stop_event = threading.Event()
    sampler_thread = threading.Thread(target=nvml_sampling_thread, args=(handle, filename, stop_event, sampling_interval))
    sampler_thread.start()

    for epoch in range(num_epochs):
        print('The epoch is:', epoch+1)
        metric = d2l.Accumulator(3)  # train_loss, train_acc, num_examples
        to_device_intervals_epoch = []  # 用来记录本epoch每个batch的to_device时间段
        forward_intervals_epoch = []  # 用来记录本epoch每个batch的forward时间段
        loss_intervals_epoch = []  # 用来记录本epoch每个batch的loss时间段
        backward_intervals_epoch = [] 
        optimize_intervals_epoch = []
        test_intervals_epoch = []   
        epoch_intervals_epoch = []  # 用来记录本epoch的时间段

        epoch_start_time = time.time()

        net.train()
        for i, (X, y) in enumerate(train_iter):
            print('The batch is:', i+1)
            optimizer.zero_grad()
            torch.cuda.synchronize()

            # 记录to_device前后的时间戳
            start_ttd_time = time.time()
            X, y = X.to(device), y.to(device)
            torch.cuda.synchronize()
            end_ttd_time = time.time()
            to_device_intervals_epoch.append((start_ttd_time, end_ttd_time))

            # forward with autocast
            start_forward_time = time.time()
            with torch.cuda.amp.autocast():
                y_hat = net(X)
                l = loss_fn(y_hat, y)  # loss inside autocast
            torch.cuda.synchronize()
            end_forward_time = time.time()
            forward_intervals_epoch.append((start_forward_time, end_forward_time))

            # backward with scaler
            start_backward_time = time.time()
            scaler.scale(l).backward()
            torch.cuda.synchronize()
            end_backward_time = time.time()
            backward_intervals_epoch.append((start_backward_time, end_backward_time))

            # optimize with scaler
            start_optimize_time = time.time()
            scaler.step(optimizer)
            scaler.update()
            torch.cuda.synchronize()
            end_optimize_time = time.time()
            optimize_intervals_epoch.append((start_optimize_time, end_optimize_time))

            with torch.no_grad():
                metric.add(l.item() * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            train_acc = metric[1] / metric[2]

            # Free memory for the batch
            del X, y, y_hat, l
            torch.cuda.empty_cache()

        # Evaluation (test)
        start_test_time = time.time()
        with torch.no_grad():
            test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        end_test_time = time.time()
        print(f'train acc {train_acc:.3f}, test acc {test_acc:.3f}')
        test_intervals_epoch.append((start_test_time, end_test_time))

        epoch_end_time = time.time()
        epoch_intervals_epoch.append((epoch_start_time, epoch_end_time))

        # data need to be saved
        # add the intervals_epoch to intervals_total
        to_device_intervals_total.append(to_device_intervals_epoch)
        forward_intervals_total.append(forward_intervals_epoch)
        loss_intervals_total.append(loss_intervals_epoch)
        backward_intervals_total.append(backward_intervals_epoch)
        optimize_intervals_total.append(optimize_intervals_epoch)
        test_intervals_total.append(test_intervals_epoch)
        epoch_intervals_total.append(epoch_intervals_epoch)

    # End training and close thread
    stop_event.set()
    sampler_thread.join()
    pynvml.nvmlShutdown()

    return to_device_intervals_total, forward_intervals_total, loss_intervals_total, backward_intervals_total, optimize_intervals_total, test_intervals_total, epoch_intervals_total

# %%
# def train_func(net, train_iter, test_iter, num_epochs, lr, device, filename, sampling_interval):
#     def init_weights(m):
#         if type(m) == nn.Linear or type(m) == nn.Conv2d:
#             nn.init.xavier_uniform_(m.weight)
#     net.apply(init_weights)
#     print('training on', device)
#     net.to(device)
#     # print(f'The name of the layers are: {alexlayer}')
#     optimizer = torch.optim.SGD(net.parameters(), lr=lr)
#     loss_fn = nn.CrossEntropyLoss()

#     scaler = torch.cuda.amp.GradScaler()

#     # save all epochs time data using list
#     to_device_intervals_total = []
#     forward_intervals_total = []
#     loss_intervals_total = []
#     backward_intervals_total = []
#     optimize_intervals_total = []
#     test_intervals_total = []

#     # create a list to store the epoch time data
#     epoch_intervals_total = []
    
#     # 初始化NVML和采样线程
#     pynvml.nvmlInit()
#     handle = pynvml.nvmlDeviceGetHandleByIndex(0)
#     stop_event = threading.Event()
#     sampler_thread = threading.Thread(target=nvml_sampling_thread, args=(handle, filename, stop_event, sampling_interval))
#     sampler_thread.start()

#     for epoch in range(num_epochs):
#         print('The epoch is:', epoch+1)
#         metric = d2l.Accumulator(3)  # train_loss, train_acc, num_examples
#         to_device_intervals_epoch = []  # 用来记录本epoch每个batch的to_device时间段
#         forward_intervals_epoch = []  # 用来记录本epoch每个batch的forward时间段
#         loss_intervals_epoch = []  # 用来记录本epoch每个batch的loss时间段
#         backward_intervals_epoch = [] 
#         optimize_intervals_epoch = []
#         test_intervals_epoch = []   
#         epoch_intervals_epoch = []  # 用来记录本epoch的时间段

#         epoch_start_time = time.time()

#         net.train()
#         for i, (X, y) in enumerate(train_iter):
#             print('The batch is:', i+1)
#             optimizer.zero_grad()
#             torch.cuda.synchronize()

#             # 记录to_device前后的时间戳
#             start_ttd_time = time.time()
#             X, y = X.to(device), y.to(device)
#             torch.cuda.synchronize()
#             end_ttd_time = time.time()
#             to_device_intervals_epoch.append((start_ttd_time, end_ttd_time))

#             # forward
#             start_forward_time = time.time()
#             y_hat = net(X)
#             torch.cuda.synchronize()
#             end_forward_time = time.time()
#             forward_intervals_epoch.append((start_forward_time, end_forward_time))

#             # loss
#             start_loss_time = time.time()
#             l = loss_fn(y_hat, y)
#             torch.cuda.synchronize()
#             end_loss_time = time.time()
#             loss_intervals_epoch.append((start_loss_time, end_loss_time))

#             # backward
#             start_backward_time = time.time()
#             l.backward()
#             torch.cuda.synchronize()
#             end_backward_time = time.time()
#             backward_intervals_epoch.append((start_backward_time, end_backward_time))

#             # optimize
#             start_optimize_time = time.time()
#             optimizer.step()
#             torch.cuda.synchronize()
#             end_optimize_time = time.time()
#             optimize_intervals_epoch.append((start_optimize_time, end_optimize_time))

#             with torch.no_grad():
#                 metric.add(l*X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
#             train_acc = metric[1] / metric[2]

#             del X, y, y_hat, l
#             torch.cuda.empty_cache()

#         start_test_time = time.time()
#         test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
#         end_test_time = time.time()
#         print(f'train acc {train_acc:.3f}, test acc {test_acc:.3f}')
#         test_intervals_epoch.append((start_test_time, end_test_time))

#         epoch_end_time = time.time()
#         epoch_intervals_epoch.append((epoch_start_time, epoch_end_time))

#         # data need to be saved
#         # add the intervals_epoch to intervals_total
#         to_device_intervals_total.append(to_device_intervals_epoch)
#         forward_intervals_total.append(forward_intervals_epoch)
#         loss_intervals_total.append(loss_intervals_epoch)
#         backward_intervals_total.append(backward_intervals_epoch)
#         optimize_intervals_total.append(optimize_intervals_epoch)
#         test_intervals_total.append(test_intervals_epoch)
#         epoch_intervals_total.append(epoch_intervals_epoch)


#     # 训练结束后关闭线程
#     stop_event.set()
#     sampler_thread.join()

#     pynvml.nvmlShutdown()

#     return to_device_intervals_total, forward_intervals_total, loss_intervals_total, backward_intervals_total, optimize_intervals_total, test_intervals_total, epoch_intervals_total

# %% [markdown]
# ## Start to train the model

# %% [markdown]
# ### set a function to train the model with FashionMNIST datasets

# %%
def train_model_f(main_folder, batch_size, num_epochs, round, lr, device, sample_interval, net):
    print(f'The epoch is set: {num_epochs}, batch is set: {batch_size}, is in {round+1}th running')
    # create the folder to store the data
    # epoch_batch_folder = main_folder/f'E{num_epochs}_B{batch_size}_R{round}'
    sr_number = int(sample_interval*1000)
    epoch_batch_folder = f'E{num_epochs}_B{batch_size}_R{round}_SR{sr_number}'
    dataset_dir = 'fashion_mnist'

    # the folder path is main_folder/epoch_batch_folder
    folder_path = main_folder/epoch_batch_folder/dataset_dir
    print(f'The folder path is: {folder_path}')
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    else:
        pass
    
    train_iter, test_iter = load_data_fashion_mnist(batch_size, resize=224)
    # show the shape of the data
    list_of_i = []
    for i, (X, y) in enumerate(train_iter):
        if i < 3:
            print('the shape of the', i, 'batch of the train_iter is:', X.shape)
        else:
            pass
        list_of_i.append(i)
    print(f'The number of batches is: {np.array(list_of_i).shape}')
    to_device_intervals_total, forward_intervals_total, loss_intervals_total,\
          backward_intervals_total, optimize_intervals_total, test_intervals_total, epoch_intervals_total = train_func(net, train_iter, test_iter, num_epochs, lr, device, folder_path, sample_interval)

    # transfer the data to the numpy array
    to_device_data = np.array(to_device_intervals_total)
    forward_time = np.array(forward_intervals_total)
    loss_time = np.array(loss_intervals_total)
    backward_time = np.array(backward_intervals_total)
    optimize_time = np.array(optimize_intervals_total)
    test_time = np.array(test_intervals_total)
    epoch_time = np.array(epoch_intervals_total)

    # save the data
    np.save(folder_path/'to_device.npy', to_device_data, allow_pickle=True)
    np.save(folder_path/'forward.npy', forward_time, allow_pickle=True)
    np.save(folder_path/'loss.npy', loss_time, allow_pickle=True)
    np.save(folder_path/'backward.npy', backward_time, allow_pickle=True)
    np.save(folder_path/'optimize.npy', optimize_time, allow_pickle=True)
    np.save(folder_path/'test.npy', test_time, allow_pickle=True)
    np.save(folder_path/'epoch.npy', epoch_time, allow_pickle=True)

# %% [markdown]
# ### run the model

# %%
sampling_interval = 0.002 # 2ms
# create the folder to store the data
# datasets = ['fashion_mnist', 'cifar100', 'cifar10']

for i in range(len(models_f_list)):
    # for each start, clear the cache in the gpu 
    torch.cuda.empty_cache()
    # for each start, clear the memory in the gpu using the torch
    net = models_f_list[i]
    main_folder = DataList[i]
    # main_folder = os.path.join(main_folder, datasets[0])  
    # main_folder = os.path.join(main_folder, datasets[1])  
    # main_folder = os.path.join(main_folder, datasets[2])  

    print('The folder is:', main_folder)
    main_folder = Path(main_folder)
    if main_folder.exists():
        print("文件存在。")
    else:
        os.makedirs(main_folder)
        print("文件不存在，已创建。")
        print("文件创建于：", main_folder)
    for epoch in epochs:
        for batch in batch_size:
            for round in range(rounds):
                train_model_f(main_folder, batch, epoch, round, lr, device, sampling_interval, net)
# Out:
# The folder is: /home/zzq/Projects/GreenAI/4070/ModelsData/alexnet/fashion_mnist
# 文件不存在，已创建。
# 文件创建于： /home/zzq/Projects/GreenAI/4070/ModelsData/alexnet/fashion_mnist
# The epoch is set: 5, batch is set: 128, is in 1th running
# The folder path is: /home/zzq/Projects/GreenAI/4070/ModelsData/alexnet/fashion_mnist/E5_B128_R0_SR2/fashion_mnist
# the shape of the 0 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 1 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 2 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# The number of batches is: (469,)
# training on cuda
# The epoch is: 1
# /tmp/ipykernel_9032/2728429223.py:12: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# The batch is: 1
# /tmp/ipykernel_9032/2728429223.py:60: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# The batch is: 392
# The batch is: 393
# The batch is: 394
# The batch is: 395
# The batch is: 396
# The batch is: 397
# The batch is: 398
# The batch is: 399
# The batch is: 400
# The batch is: 401
# The batch is: 402
# The batch is: 403
# The batch is: 404
# The batch is: 405
# The batch is: 406
# The batch is: 407
# The batch is: 408
# The batch is: 409
# The batch is: 410
# The batch is: 411
# The batch is: 412
# The batch is: 413
# The batch is: 414
# The batch is: 415
# The batch is: 416
# The batch is: 417
# The batch is: 418
# The batch is: 419
# The batch is: 420
# The batch is: 421
# The batch is: 422
# The batch is: 423
# The batch is: 424
# The batch is: 425
# The batch is: 426
# The batch is: 427
# The batch is: 428
# The batch is: 429
# The batch is: 430
# The batch is: 431
# The batch is: 432
# The batch is: 433
# The batch is: 434
# The batch is: 435
# The batch is: 436
# The batch is: 437
# The batch is: 438
# The batch is: 439
# The batch is: 440
# The batch is: 441
# The batch is: 442
# The batch is: 443
# The batch is: 444
# The batch is: 445
# The batch is: 446
# The batch is: 447
# The batch is: 448
# The batch is: 449
# The batch is: 450
# The batch is: 451
# The batch is: 452
# The batch is: 453
# The batch is: 454
# The batch is: 455
# The batch is: 456
# The batch is: 457
# The batch is: 458
# The batch is: 459
# The batch is: 460
# The batch is: 461
# The batch is: 462
# The batch is: 463
# The batch is: 464
# The batch is: 465
# The batch is: 466
# The batch is: 467
# The batch is: 468
# The batch is: 469
# train acc 0.611, test acc 0.802
# The epoch is: 2
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# The batch is: 392
# The batch is: 393
# The batch is: 394
# The batch is: 395
# The batch is: 396
# The batch is: 397
# The batch is: 398
# The batch is: 399
# The batch is: 400
# The batch is: 401
# The batch is: 402
# The batch is: 403
# The batch is: 404
# The batch is: 405
# The batch is: 406
# The batch is: 407
# The batch is: 408
# The batch is: 409
# The batch is: 410
# The batch is: 411
# The batch is: 412
# The batch is: 413
# The batch is: 414
# The batch is: 415
# The batch is: 416
# The batch is: 417
# The batch is: 418
# The batch is: 419
# The batch is: 420
# The batch is: 421
# The batch is: 422
# The batch is: 423
# The batch is: 424
# The batch is: 425
# The batch is: 426
# The batch is: 427
# The batch is: 428
# The batch is: 429
# The batch is: 430
# The batch is: 431
# The batch is: 432
# The batch is: 433
# The batch is: 434
# The batch is: 435
# The batch is: 436
# The batch is: 437
# The batch is: 438
# The batch is: 439
# The batch is: 440
# The batch is: 441
# The batch is: 442
# The batch is: 443
# The batch is: 444
# The batch is: 445
# The batch is: 446
# The batch is: 447
# The batch is: 448
# The batch is: 449
# The batch is: 450
# The batch is: 451
# The batch is: 452
# The batch is: 453
# The batch is: 454
# The batch is: 455
# The batch is: 456
# The batch is: 457
# The batch is: 458
# The batch is: 459
# The batch is: 460
# The batch is: 461
# The batch is: 462
# The batch is: 463
# The batch is: 464
# The batch is: 465
# The batch is: 466
# The batch is: 467
# The batch is: 468
# The batch is: 469
# train acc 0.809, test acc 0.844
# The epoch is: 3
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# The batch is: 392
# The batch is: 393
# The batch is: 394
# The batch is: 395
# The batch is: 396
# The batch is: 397
# The batch is: 398
# The batch is: 399
# The batch is: 400
# The batch is: 401
# The batch is: 402
# The batch is: 403
# The batch is: 404
# The batch is: 405
# The batch is: 406
# The batch is: 407
# The batch is: 408
# The batch is: 409
# The batch is: 410
# The batch is: 411
# The batch is: 412
# The batch is: 413
# The batch is: 414
# The batch is: 415
# The batch is: 416
# The batch is: 417
# The batch is: 418
# The batch is: 419
# The batch is: 420
# The batch is: 421
# The batch is: 422
# The batch is: 423
# The batch is: 424
# The batch is: 425
# The batch is: 426
# The batch is: 427
# The batch is: 428
# The batch is: 429
# The batch is: 430
# The batch is: 431
# The batch is: 432
# The batch is: 433
# The batch is: 434
# The batch is: 435
# The batch is: 436
# The batch is: 437
# The batch is: 438
# The batch is: 439
# The batch is: 440
# The batch is: 441
# The batch is: 442
# The batch is: 443
# The batch is: 444
# The batch is: 445
# The batch is: 446
# The batch is: 447
# The batch is: 448
# The batch is: 449
# The batch is: 450
# The batch is: 451
# The batch is: 452
# The batch is: 453
# The batch is: 454
# The batch is: 455
# The batch is: 456
# The batch is: 457
# The batch is: 458
# The batch is: 459
# The batch is: 460
# The batch is: 461
# The batch is: 462
# The batch is: 463
# The batch is: 464
# The batch is: 465
# The batch is: 466
# The batch is: 467
# The batch is: 468
# The batch is: 469
# train acc 0.846, test acc 0.846
# The epoch is: 4
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# The batch is: 392
# The batch is: 393
# The batch is: 394
# The batch is: 395
# The batch is: 396
# The batch is: 397
# The batch is: 398
# The batch is: 399
# The batch is: 400
# The batch is: 401
# The batch is: 402
# The batch is: 403
# The batch is: 404
# The batch is: 405
# The batch is: 406
# The batch is: 407
# The batch is: 408
# The batch is: 409
# The batch is: 410
# The batch is: 411
# The batch is: 412
# The batch is: 413
# The batch is: 414
# The batch is: 415
# The batch is: 416
# The batch is: 417
# The batch is: 418
# The batch is: 419
# The batch is: 420
# The batch is: 421
# The batch is: 422
# The batch is: 423
# The batch is: 424
# The batch is: 425
# The batch is: 426
# The batch is: 427
# The batch is: 428
# The batch is: 429
# The batch is: 430
# The batch is: 431
# The batch is: 432
# The batch is: 433
# The batch is: 434
# The batch is: 435
# The batch is: 436
# The batch is: 437
# The batch is: 438
# The batch is: 439
# The batch is: 440
# The batch is: 441
# The batch is: 442
# The batch is: 443
# The batch is: 444
# The batch is: 445
# The batch is: 446
# The batch is: 447
# The batch is: 448
# The batch is: 449
# The batch is: 450
# The batch is: 451
# The batch is: 452
# The batch is: 453
# The batch is: 454
# The batch is: 455
# The batch is: 456
# The batch is: 457
# The batch is: 458
# The batch is: 459
# The batch is: 460
# The batch is: 461
# The batch is: 462
# The batch is: 463
# The batch is: 464
# The batch is: 465
# The batch is: 466
# The batch is: 467
# The batch is: 468
# The batch is: 469
# train acc 0.864, test acc 0.872
# The epoch is: 5
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# The batch is: 392
# The batch is: 393
# The batch is: 394
# The batch is: 395
# The batch is: 396
# The batch is: 397
# The batch is: 398
# The batch is: 399
# The batch is: 400
# The batch is: 401
# The batch is: 402
# The batch is: 403
# The batch is: 404
# The batch is: 405
# The batch is: 406
# The batch is: 407
# The batch is: 408
# The batch is: 409
# The batch is: 410
# The batch is: 411
# The batch is: 412
# The batch is: 413
# The batch is: 414
# The batch is: 415
# The batch is: 416
# The batch is: 417
# The batch is: 418
# The batch is: 419
# The batch is: 420
# The batch is: 421
# The batch is: 422
# The batch is: 423
# The batch is: 424
# The batch is: 425
# The batch is: 426
# The batch is: 427
# The batch is: 428
# The batch is: 429
# The batch is: 430
# The batch is: 431
# The batch is: 432
# The batch is: 433
# The batch is: 434
# The batch is: 435
# The batch is: 436
# The batch is: 437
# The batch is: 438
# The batch is: 439
# The batch is: 440
# The batch is: 441
# The batch is: 442
# The batch is: 443
# The batch is: 444
# The batch is: 445
# The batch is: 446
# The batch is: 447
# The batch is: 448
# The batch is: 449
# The batch is: 450
# The batch is: 451
# The batch is: 452
# The batch is: 453
# The batch is: 454
# The batch is: 455
# The batch is: 456
# The batch is: 457
# The batch is: 458
# The batch is: 459
# The batch is: 460
# The batch is: 461
# The batch is: 462
# The batch is: 463
# The batch is: 464
# The batch is: 465
# The batch is: 466
# The batch is: 467
# The batch is: 468
# The batch is: 469
# train acc 0.875, test acc 0.880
# The folder is: /home/zzq/Projects/GreenAI/4070/ModelsData/vgg11/fashion_mnist
# 文件不存在，已创建。
# 文件创建于： /home/zzq/Projects/GreenAI/4070/ModelsData/vgg11/fashion_mnist
# The epoch is set: 5, batch is set: 128, is in 1th running
# The folder path is: /home/zzq/Projects/GreenAI/4070/ModelsData/vgg11/fashion_mnist/E5_B128_R0_SR2/fashion_mnist
# the shape of the 0 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 1 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 2 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# The number of batches is: (469,)
# training on cuda
# The epoch is: 1
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# ...
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# The batch is: 392
# The batch is: 393
# The batch is: 394
# The batch is: 395
# The batch is: 396
# The batch is: 397
# The batch is: 398
# The batch is: 399
# The batch is: 400
# The batch is: 401
# The batch is: 402
# The batch is: 403
# The batch is: 404
# The batch is: 405
# The batch is: 406
# The batch is: 407
# The batch is: 408
# The batch is: 409
# The batch is: 410
# The batch is: 411
# The batch is: 412
# The batch is: 413
# The batch is: 414
# The batch is: 415
# The batch is: 416
# The batch is: 417
# The batch is: 418
# The batch is: 419
# The batch is: 420
# The batch is: 421
# The batch is: 422
# The batch is: 423
# The batch is: 424
# The batch is: 425
# The batch is: 426
# The batch is: 427
# The batch is: 428
# The batch is: 429
# The batch is: 430
# The batch is: 431
# The batch is: 432
# The batch is: 433
# The batch is: 434
# The batch is: 435
# The batch is: 436
# The batch is: 437
# The batch is: 438
# The batch is: 439
# The batch is: 440
# The batch is: 441
# The batch is: 442
# The batch is: 443
# The batch is: 444
# The batch is: 445
# The batch is: 446
# The batch is: 447
# The batch is: 448
# The batch is: 449
# The batch is: 450
# The batch is: 451
# The batch is: 452
# The batch is: 453
# The batch is: 454
# The batch is: 455
# The batch is: 456
# The batch is: 457
# The batch is: 458
# The batch is: 459
# The batch is: 460
# The batch is: 461
# The batch is: 462
# The batch is: 463
# The batch is: 464
# The batch is: 465
# The batch is: 466
# The batch is: 467
# The batch is: 468
# The batch is: 469
# train acc 0.919, test acc 0.909
# The epoch is: 5
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# The batch is: 392
# The batch is: 393
# The batch is: 394
# The batch is: 395
# The batch is: 396
# The batch is: 397
# The batch is: 398
# The batch is: 399
# The batch is: 400
# The batch is: 401
# The batch is: 402
# The batch is: 403
# The batch is: 404
# The batch is: 405
# The batch is: 406
# The batch is: 407
# The batch is: 408
# The batch is: 409
# The batch is: 410
# The batch is: 411
# The batch is: 412
# The batch is: 413
# The batch is: 414
# The batch is: 415
# The batch is: 416
# The batch is: 417
# The batch is: 418
# The batch is: 419
# The batch is: 420
# The batch is: 421
# The batch is: 422
# The batch is: 423
# The batch is: 424
# The batch is: 425
# The batch is: 426
# The batch is: 427
# The batch is: 428
# The batch is: 429
# The batch is: 430
# The batch is: 431
# The batch is: 432
# The batch is: 433
# The batch is: 434
# The batch is: 435
# The batch is: 436
# The batch is: 437
# The batch is: 438
# The batch is: 439
# The batch is: 440
# The batch is: 441
# The batch is: 442
# The batch is: 443
# The batch is: 444
# The batch is: 445
# The batch is: 446
# The batch is: 447
# The batch is: 448
# The batch is: 449
# The batch is: 450
# The batch is: 451
# The batch is: 452
# The batch is: 453
# The batch is: 454
# The batch is: 455
# The batch is: 456
# The batch is: 457
# The batch is: 458
# The batch is: 459
# The batch is: 460
# The batch is: 461
# The batch is: 462
# The batch is: 463
# The batch is: 464
# The batch is: 465
# The batch is: 466
# The batch is: 467
# The batch is: 468
# The batch is: 469
# train acc 0.927, test acc 0.915

# %%
# sampling_interval = 0.002 # 2ms
# # # create the folder to store the data

# # for i in range(len(models_f_list)):
# # 2024.12.18-yj: 由于之前的运行 gpu 内存爆了,需要继续后续训练
# # 2024.12.19-yj: mobilenetv2 持续爆内存,需要继续后续训练
# torch.cuda.reset_peak_memory_stats()
# torch.cuda.empty_cache()
# # for each start, clear the memory in the gpu using the torch
# # print(models_f_list[-1])
# net = mobilenetv2_f
# main_folder = DataList[-1]  
# print('The folder is:', main_folder)
# if main_folder.exists():
#     print("文件存在。")
# else:
#     os.makedirs(main_folder)
#     print("文件不存在，已创建。")
#     print("文件创建于：", main_folder)
# for epoch in epochs:
#     for batch in batch_size:
#         for round in range(rounds):
#             train_model_f(main_folder, batch, epoch, round, lr, device, sampling_interval, net)
# Out:
# The folder is: /root/autodl-tmp/GreenAI/3080/ModelsData/mobilenetv2_path
# 文件存在。
# The epoch is set: 5, batch is set: 256, is in 1th running
# The folder path is: /root/autodl-tmp/GreenAI/3080/ModelsData/mobilenetv2_path/E5_B256_R0_SR2
# the shape of the 0 batch of the train_iter is: torch.Size([256, 1, 224, 224])
# the shape of the 1 batch of the train_iter is: torch.Size([256, 1, 224, 224])
# the shape of the 2 batch of the train_iter is: torch.Size([256, 1, 224, 224])
# The number of batches is: (235,)
# training on cuda
# The epoch is: 1
# /tmp/ipykernel_5606/2728429223.py:12: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# The batch is: 1
# /tmp/ipykernel_5606/2728429223.py:60: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# train acc 0.624, test acc 0.771
# The epoch is: 2
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# train acc 0.823, test acc 0.786
# The epoch is: 3
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# train acc 0.861, test acc 0.796
# The epoch is: 4
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# train acc 0.881, test acc 0.807
# The epoch is: 5
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# train acc 0.895, test acc 0.827
