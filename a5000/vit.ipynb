# %%
import torch
from torch import nn
from torch.nn import functional as F
import torchvision
import torchvision.transforms as transforms
from d2l import torch as d2l
import numpy as np
import pandas as pd
from ptflops import get_model_complexity_info
from pathlib import Path
import os
import time
import pynvml
import threading
import queue# type: ignore
from torch.cuda.amp import GradScaler
from vit_code import ViT
from CNN_info import *

# %%
'''find the Model path'''
# find the current path
from pathlib import Path

# find the current path
current_path = Path.cwd()
print('The current path is:', current_path)

# # find the data path
# data_path = Path(current_path / 'ModelsData')
# print('The data path is:', data_path)
# Out:
# The current path is: /home/GreenAI/a5000

# %%
# create a function for all the models to run
# image channel for fashion mnist 
channel_f = 1
# image channel for cifar100 and cifar10
channel_c = 3

# number of labels for fashion mnist
num_labels_f = 10
# number of labels for cifar100 
num_labels_c100 = 100
# number of labels for cifar10
num_labels_c10 = 10

# %%
vit_f = ViT(num_classes = num_labels_f,
            channels = channel_f)
vit_c100 = ViT(num_classes = num_labels_c100,
            channels = channel_c)
vit_c10 = ViT(num_classes = num_labels_c10,
            channels = channel_c)
with torch.cuda.device(0):
    macs_f, params_f = get_model_complexity_info(vit_f, (channel_f, 224, 224), as_strings=True,
                                            print_per_layer_stat=True, verbose=True)
    macs_c100, params_c100 = get_model_complexity_info(vit_c100, (channel_c, 224, 224), as_strings=True,
                                                        print_per_layer_stat=True, verbose=True)
    macs_c10, params_c10 = get_model_complexity_info(vit_c10, (channel_c, 224, 224), as_strings=True,
                                                        print_per_layer_stat=True, verbose=True)
    print('{:<30}  {:<8}'.format('Computational complexity of ViT-F: ', macs_f))
    print('{:<30}  {:<8}'.format('Number of parameters of ViT-F: ', params_f))
    print('{:<30}  {:<8}'.format('Computational complexity of ViT-C100: ', macs_c100))
    print('{:<30}  {:<8}'.format('Number of parameters of ViT-C100: ', params_c100))
    print('{:<30}  {:<8}'.format('Computational complexity of ViT-C10: ', macs_c10))
    print('{:<30}  {:<8}'.format('Number of parameters of ViT-C10: ', params_c10))
# Out:
# Warning: module Rearrange is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Warning: module Softmax is treated as a zero-op.
# Warning: module Attention is treated as a zero-op.
# Warning: module FeedForward is treated as a zero-op.
# Warning: module Transformer is treated as a zero-op.
# Warning: module Identity is treated as a zero-op.
# Warning: module ViT is treated as a zero-op.
# ViT(
#   51.45 M, 99.899% Params, 2.57 GMac, 98.787% MACs,
#   (to_patch_embedding): Sequential(
#     1.05 M, 2.046% Params, 51.53 MMac, 1.980% MACs,
#     (0): Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1=32, p2=32)
#     (1): LayerNorm(2.05 k, 0.004% Params, 50.18 KMac, 0.002% MACs, (1024,), eps=1e-05, elementwise_affine=True)
#     (2): Linear(1.05 M, 2.038% Params, 51.43 MMac, 1.976% MACs, in_features=1024, out_features=1024, bias=True)
#     (3): LayerNorm(2.05 k, 0.004% Params, 50.18 KMac, 0.002% MACs, (1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#   (transformer): Transformer(
#     50.38 M, 97.833% Params, 2.52 GMac, 96.806% MACs,
#     (norm): LayerNorm(2.05 k, 0.004% Params, 51.2 KMac, 0.002% MACs, (1024,), eps=1e-05, elementwise_affine=True)
#     (layers): ModuleList(
#       (0-5): 6 x ModuleList(
#         (0): Attention(
#           4.2 M, 8.150% Params, 209.82 MMac, 8.063% MACs,
#           (norm): LayerNorm(2.05 k, 0.004% Params, 51.2 KMac, 0.002% MACs, (1024,), eps=1e-05, elementwise_affine=True)
#           (attend): Softmax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, dim=-1)
#           (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#           (to_qkv): Linear(3.15 M, 6.108% Params, 157.29 MMac, 6.044% MACs, in_features=1024, out_features=3072, bias=False)
#           (to_out): Sequential(
#             1.05 M, 2.038% Params, 52.48 MMac, 2.017% MACs,
#             (0): Linear(1.05 M, 2.038% Params, 52.48 MMac, 2.017% MACs, in_features=1024, out_features=1024, bias=True)
#             (1): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#           )
#         )
#         (1): FeedForward(
#           4.2 M, 8.154% Params, 210.02 MMac, 8.071% MACs,
#           (net): Sequential(
#             4.2 M, 8.154% Params, 210.02 MMac, 8.071% MACs,
#             (0): LayerNorm(2.05 k, 0.004% Params, 51.2 KMac, 0.002% MACs, (1024,), eps=1e-05, elementwise_affine=True)
#             (1): Linear(2.1 M, 4.076% Params, 104.96 MMac, 4.033% MACs, in_features=1024, out_features=2048, bias=True)
#             (2): GELU(0, 0.000% Params, 102.4 KMac, 0.004% MACs, approximate='none')
#             (3): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#             (4): Linear(2.1 M, 4.074% Params, 104.91 MMac, 4.032% MACs, in_features=2048, out_features=1024, bias=True)
#             (5): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (to_latent): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#   (mlp_head): Linear(10.25 k, 0.020% Params, 10.25 KMac, 0.000% MACs, in_features=1024, out_features=10, bias=True)
# )
# Warning: module Rearrange is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Warning: module Softmax is treated as a zero-op.
# Warning: module Attention is treated as a zero-op.
# Warning: module FeedForward is treated as a zero-op.
# Warning: module Transformer is treated as a zero-op.
# Warning: module Identity is treated as a zero-op.
# Warning: module ViT is treated as a zero-op.
# ViT(
#   53.64 M, 99.903% Params, 2.67 GMac, 98.833% MACs,
#   (to_patch_embedding): Sequential(
#     3.15 M, 5.876% Params, 154.39 MMac, 5.707% MACs,
#     (0): Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1=32, p2=32)
#     (1): LayerNorm(6.14 k, 0.011% Params, 150.53 KMac, 0.006% MACs, (3072,), eps=1e-05, elementwise_affine=True)
#     (2): Linear(3.15 M, 5.861% Params, 154.19 MMac, 5.700% MACs, in_features=3072, out_features=1024, bias=True)
#     (3): LayerNorm(2.05 k, 0.004% Params, 50.18 KMac, 0.002% MACs, (1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#   (transformer): Transformer(
#     50.38 M, 93.836% Params, 2.52 GMac, 93.122% MACs,
#     (norm): LayerNorm(2.05 k, 0.004% Params, 51.2 KMac, 0.002% MACs, (1024,), eps=1e-05, elementwise_affine=True)
#     (layers): ModuleList(
#       (0-5): 6 x ModuleList(
#         (0): Attention(
#           4.2 M, 7.817% Params, 209.82 MMac, 7.756% MACs,
#           (norm): LayerNorm(2.05 k, 0.004% Params, 51.2 KMac, 0.002% MACs, (1024,), eps=1e-05, elementwise_affine=True)
#           (attend): Softmax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, dim=-1)
#           (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#           (to_qkv): Linear(3.15 M, 5.859% Params, 157.29 MMac, 5.814% MACs, in_features=1024, out_features=3072, bias=False)
#           (to_out): Sequential(
#             1.05 M, 1.955% Params, 52.48 MMac, 1.940% MACs,
#             (0): Linear(1.05 M, 1.955% Params, 52.48 MMac, 1.940% MACs, in_features=1024, out_features=1024, bias=True)
#             (1): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#           )
#         )
#         (1): FeedForward(
#           4.2 M, 7.821% Params, 210.02 MMac, 7.764% MACs,
#           (net): Sequential(
#             4.2 M, 7.821% Params, 210.02 MMac, 7.764% MACs,
#             (0): LayerNorm(2.05 k, 0.004% Params, 51.2 KMac, 0.002% MACs, (1024,), eps=1e-05, elementwise_affine=True)
#             (1): Linear(2.1 M, 3.910% Params, 104.96 MMac, 3.880% MACs, in_features=1024, out_features=2048, bias=True)
#             (2): GELU(0, 0.000% Params, 102.4 KMac, 0.004% MACs, approximate='none')
#             (3): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#             (4): Linear(2.1 M, 3.908% Params, 104.91 MMac, 3.878% MACs, in_features=2048, out_features=1024, bias=True)
#             (5): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (to_latent): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#   (mlp_head): Linear(102.5 k, 0.191% Params, 102.5 KMac, 0.004% MACs, in_features=1024, out_features=100, bias=True)
# )
# Warning: module Rearrange is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Warning: module Softmax is treated as a zero-op.
# Warning: module Attention is treated as a zero-op.
# Warning: module FeedForward is treated as a zero-op.
# Warning: module Transformer is treated as a zero-op.
# Warning: module Identity is treated as a zero-op.
# Warning: module ViT is treated as a zero-op.
# ViT(
#   53.55 M, 99.903% Params, 2.67 GMac, 98.833% MACs,
#   (to_patch_embedding): Sequential(
#     3.15 M, 5.886% Params, 154.39 MMac, 5.707% MACs,
#     (0): Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1=32, p2=32)
#     (1): LayerNorm(6.14 k, 0.011% Params, 150.53 KMac, 0.006% MACs, (3072,), eps=1e-05, elementwise_affine=True)
#     (2): Linear(3.15 M, 5.871% Params, 154.19 MMac, 5.700% MACs, in_features=3072, out_features=1024, bias=True)
#     (3): LayerNorm(2.05 k, 0.004% Params, 50.18 KMac, 0.002% MACs, (1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#   (transformer): Transformer(
#     50.38 M, 93.997% Params, 2.52 GMac, 93.125% MACs,
#     (norm): LayerNorm(2.05 k, 0.004% Params, 51.2 KMac, 0.002% MACs, (1024,), eps=1e-05, elementwise_affine=True)
#     (layers): ModuleList(
#       (0-5): 6 x ModuleList(
#         (0): Attention(
#           4.2 M, 7.831% Params, 209.82 MMac, 7.756% MACs,
#           (norm): LayerNorm(2.05 k, 0.004% Params, 51.2 KMac, 0.002% MACs, (1024,), eps=1e-05, elementwise_affine=True)
#           (attend): Softmax(0, 0.000% Params, 0.0 Mac, 0.000% MACs, dim=-1)
#           (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#           (to_qkv): Linear(3.15 M, 5.869% Params, 157.29 MMac, 5.815% MACs, in_features=1024, out_features=3072, bias=False)
#           (to_out): Sequential(
#             1.05 M, 1.958% Params, 52.48 MMac, 1.940% MACs,
#             (0): Linear(1.05 M, 1.958% Params, 52.48 MMac, 1.940% MACs, in_features=1024, out_features=1024, bias=True)
#             (1): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#           )
#         )
#         (1): FeedForward(
#           4.2 M, 7.835% Params, 210.02 MMac, 7.764% MACs,
#           (net): Sequential(
#             4.2 M, 7.835% Params, 210.02 MMac, 7.764% MACs,
#             (0): LayerNorm(2.05 k, 0.004% Params, 51.2 KMac, 0.002% MACs, (1024,), eps=1e-05, elementwise_affine=True)
#             (1): Linear(2.1 M, 3.916% Params, 104.96 MMac, 3.880% MACs, in_features=1024, out_features=2048, bias=True)
#             (2): GELU(0, 0.000% Params, 102.4 KMac, 0.004% MACs, approximate='none')
#             (3): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#             (4): Linear(2.1 M, 3.914% Params, 104.91 MMac, 3.878% MACs, in_features=2048, out_features=1024, bias=True)
#             (5): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (to_latent): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#   (mlp_head): Linear(10.25 k, 0.019% Params, 10.25 KMac, 0.000% MACs, in_features=1024, out_features=10, bias=True)
# )
# Computational complexity of ViT-F:   2.6 GMac
# Number of parameters of ViT-F:   51.5 M
# Computational complexity of ViT-C100:   2.71 GMac
# Number of parameters of ViT-C100:   53.69 M
# Computational complexity of ViT-C10:   2.71 GMac
# Number of parameters of ViT-C10:   53.6 M

# %%
batch_size = [128]
epochs = [5]
rounds = 1

# %%
lr = 0.01
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('The device is:', device)
# Out:
# The device is: cuda

# %%
sampling_interval = 0.002 # 2ms

# %%
datasets = ['fashion_mnist', 'cifar100', 'cifar10']

# %%
# create model list according to models_name order
models_f_list = [vit_f]

models_c100_list = [vit_c100]

models_c10_list = [vit_c10]

# %%
# for i in range(len(models_f_list)):
#     # for each start, clear the cache in the gpu 
#     torch.cuda.empty_cache()
#     # for each start, clear the memory in the gpu using the torch
#     net = models_f_list[i]
#     main_folder = os.path.join(current_path, datasets[0])  
#     # main_folder = os.path.join(main_folder, datasets[1])  
#     # main_folder = os.path.join(main_folder, datasets[2])  

#     # transfer the main_folder to Path
#     main_folder = Path(main_folder)

#     print('The folder is:', main_folder)
#     if main_folder.exists():
#         print("文件存在。")
#     else:
#         os.makedirs(main_folder)
#         print("文件不存在，已创建。")
#         print("文件创建于：", main_folder)
#     for epoch in epochs:
#         for batch in batch_size:
#             for round in range(rounds):
#                 train_model(main_folder, batch, epoch, round, lr, device, sampling_interval, net, datasets[0])

# %%
for i in range(len(models_c100_list)):
    # for each start, clear the cache in the gpu 
    torch.cuda.empty_cache()
    # for each start, clear the memory in the gpu using the torch
    net = models_c100_list[i]
    main_folder = os.path.join(current_path, datasets[1])  
    # main_folder = os.path.join(main_folder, datasets[1])  
    # main_folder = os.path.join(main_folder, datasets[2])  

    # transfer the main_folder to Path
    main_folder = Path(main_folder)

    print('The folder is:', main_folder)
    if main_folder.exists():
        print("文件存在。")
    else:
        os.makedirs(main_folder)
        print("文件不存在，已创建。")
        print("文件创建于：", main_folder)
    for epoch in epochs:
        for batch in batch_size:
            for round in range(rounds):
                train_model(main_folder, batch, epoch, round, lr, device, sampling_interval, net, datasets[1])
# Out:
# The folder is: /home/GreenAI/a5000/cifar100
# 文件存在。
# The epoch is set: 5, batch is set: 128, is in 1th running
# The folder path is: /home/GreenAI/a5000/cifar100/E5_B128_R0_SR2
# 100.0%
# the shape of the 0 batch of the train_iter is: torch.Size([128, 3, 224, 224])
# the shape of the 1 batch of the train_iter is: torch.Size([128, 3, 224, 224])
# the shape of the 2 batch of the train_iter is: torch.Size([128, 3, 224, 224])
# The number of batches is: (391,)
# training on cuda
# The epoch is: 1
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# train acc 0.040, test acc 0.063
# The epoch is: 2
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# train acc 0.068, test acc 0.091
# The epoch is: 3
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# train acc 0.097, test acc 0.124
# The epoch is: 4
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# train acc 0.126, test acc 0.148
# The epoch is: 5
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# train acc 0.157, test acc 0.188

# %%
for i in range(len(models_c10_list)):
    # for each start, clear the cache in the gpu 
    torch.cuda.empty_cache()
    # for each start, clear the memory in the gpu using the torch
    net = models_c10_list[i]
    main_folder = os.path.join(current_path, datasets[2])  
    # main_folder = os.path.join(main_folder, datasets[1])  
    # main_folder = os.path.join(main_folder, datasets[2])  

    # transfer the main_folder to Path
    main_folder = Path(main_folder)

    print('The folder is:', main_folder)
    if main_folder.exists():
        print("文件存在。")
    else:
        os.makedirs(main_folder)
        print("文件不存在，已创建。")
        print("文件创建于：", main_folder)
    for epoch in epochs:
        for batch in batch_size:
            for round in range(rounds):
                train_model(main_folder, batch, epoch, round, lr, device, sampling_interval, net, datasets[2])
# Out:
# The folder is: /home/GreenAI/a5000/cifar10
# 文件存在。
# The epoch is set: 5, batch is set: 128, is in 1th running
# The folder path is: /home/GreenAI/a5000/cifar10/E5_B128_R0_SR2
# 100.0%
# the shape of the 0 batch of the train_iter is: torch.Size([128, 3, 224, 224])
# the shape of the 1 batch of the train_iter is: torch.Size([128, 3, 224, 224])
# the shape of the 2 batch of the train_iter is: torch.Size([128, 3, 224, 224])
# The number of batches is: (391,)
# training on cuda
# The epoch is: 1
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# train acc 0.236, test acc 0.293
# The epoch is: 2
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# train acc 0.315, test acc 0.318
# The epoch is: 3
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# train acc 0.377, test acc 0.406
# The epoch is: 4
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# train acc 0.427, test acc 0.460
# The epoch is: 5
# The batch is: 1
# The batch is: 2
# The batch is: 3
# The batch is: 4
# The batch is: 5
# The batch is: 6
# The batch is: 7
# The batch is: 8
# The batch is: 9
# The batch is: 10
# The batch is: 11
# The batch is: 12
# The batch is: 13
# The batch is: 14
# The batch is: 15
# The batch is: 16
# The batch is: 17
# The batch is: 18
# The batch is: 19
# The batch is: 20
# The batch is: 21
# The batch is: 22
# The batch is: 23
# The batch is: 24
# The batch is: 25
# The batch is: 26
# The batch is: 27
# The batch is: 28
# The batch is: 29
# The batch is: 30
# The batch is: 31
# The batch is: 32
# The batch is: 33
# The batch is: 34
# The batch is: 35
# The batch is: 36
# The batch is: 37
# The batch is: 38
# The batch is: 39
# The batch is: 40
# The batch is: 41
# The batch is: 42
# The batch is: 43
# The batch is: 44
# The batch is: 45
# The batch is: 46
# The batch is: 47
# The batch is: 48
# The batch is: 49
# The batch is: 50
# The batch is: 51
# The batch is: 52
# The batch is: 53
# The batch is: 54
# The batch is: 55
# The batch is: 56
# The batch is: 57
# The batch is: 58
# The batch is: 59
# The batch is: 60
# The batch is: 61
# The batch is: 62
# The batch is: 63
# The batch is: 64
# The batch is: 65
# The batch is: 66
# The batch is: 67
# The batch is: 68
# The batch is: 69
# The batch is: 70
# The batch is: 71
# The batch is: 72
# The batch is: 73
# The batch is: 74
# The batch is: 75
# The batch is: 76
# The batch is: 77
# The batch is: 78
# The batch is: 79
# The batch is: 80
# The batch is: 81
# The batch is: 82
# The batch is: 83
# The batch is: 84
# The batch is: 85
# The batch is: 86
# The batch is: 87
# The batch is: 88
# The batch is: 89
# The batch is: 90
# The batch is: 91
# The batch is: 92
# The batch is: 93
# The batch is: 94
# The batch is: 95
# The batch is: 96
# The batch is: 97
# The batch is: 98
# The batch is: 99
# The batch is: 100
# The batch is: 101
# The batch is: 102
# The batch is: 103
# The batch is: 104
# The batch is: 105
# The batch is: 106
# The batch is: 107
# The batch is: 108
# The batch is: 109
# The batch is: 110
# The batch is: 111
# The batch is: 112
# The batch is: 113
# The batch is: 114
# The batch is: 115
# The batch is: 116
# The batch is: 117
# The batch is: 118
# The batch is: 119
# The batch is: 120
# The batch is: 121
# The batch is: 122
# The batch is: 123
# The batch is: 124
# The batch is: 125
# The batch is: 126
# The batch is: 127
# The batch is: 128
# The batch is: 129
# The batch is: 130
# The batch is: 131
# The batch is: 132
# The batch is: 133
# The batch is: 134
# The batch is: 135
# The batch is: 136
# The batch is: 137
# The batch is: 138
# The batch is: 139
# The batch is: 140
# The batch is: 141
# The batch is: 142
# The batch is: 143
# The batch is: 144
# The batch is: 145
# The batch is: 146
# The batch is: 147
# The batch is: 148
# The batch is: 149
# The batch is: 150
# The batch is: 151
# The batch is: 152
# The batch is: 153
# The batch is: 154
# The batch is: 155
# The batch is: 156
# The batch is: 157
# The batch is: 158
# The batch is: 159
# The batch is: 160
# The batch is: 161
# The batch is: 162
# The batch is: 163
# The batch is: 164
# The batch is: 165
# The batch is: 166
# The batch is: 167
# The batch is: 168
# The batch is: 169
# The batch is: 170
# The batch is: 171
# The batch is: 172
# The batch is: 173
# The batch is: 174
# The batch is: 175
# The batch is: 176
# The batch is: 177
# The batch is: 178
# The batch is: 179
# The batch is: 180
# The batch is: 181
# The batch is: 182
# The batch is: 183
# The batch is: 184
# The batch is: 185
# The batch is: 186
# The batch is: 187
# The batch is: 188
# The batch is: 189
# The batch is: 190
# The batch is: 191
# The batch is: 192
# The batch is: 193
# The batch is: 194
# The batch is: 195
# The batch is: 196
# The batch is: 197
# The batch is: 198
# The batch is: 199
# The batch is: 200
# The batch is: 201
# The batch is: 202
# The batch is: 203
# The batch is: 204
# The batch is: 205
# The batch is: 206
# The batch is: 207
# The batch is: 208
# The batch is: 209
# The batch is: 210
# The batch is: 211
# The batch is: 212
# The batch is: 213
# The batch is: 214
# The batch is: 215
# The batch is: 216
# The batch is: 217
# The batch is: 218
# The batch is: 219
# The batch is: 220
# The batch is: 221
# The batch is: 222
# The batch is: 223
# The batch is: 224
# The batch is: 225
# The batch is: 226
# The batch is: 227
# The batch is: 228
# The batch is: 229
# The batch is: 230
# The batch is: 231
# The batch is: 232
# The batch is: 233
# The batch is: 234
# The batch is: 235
# The batch is: 236
# The batch is: 237
# The batch is: 238
# The batch is: 239
# The batch is: 240
# The batch is: 241
# The batch is: 242
# The batch is: 243
# The batch is: 244
# The batch is: 245
# The batch is: 246
# The batch is: 247
# The batch is: 248
# The batch is: 249
# The batch is: 250
# The batch is: 251
# The batch is: 252
# The batch is: 253
# The batch is: 254
# The batch is: 255
# The batch is: 256
# The batch is: 257
# The batch is: 258
# The batch is: 259
# The batch is: 260
# The batch is: 261
# The batch is: 262
# The batch is: 263
# The batch is: 264
# The batch is: 265
# The batch is: 266
# The batch is: 267
# The batch is: 268
# The batch is: 269
# The batch is: 270
# The batch is: 271
# The batch is: 272
# The batch is: 273
# The batch is: 274
# The batch is: 275
# The batch is: 276
# The batch is: 277
# The batch is: 278
# The batch is: 279
# The batch is: 280
# The batch is: 281
# The batch is: 282
# The batch is: 283
# The batch is: 284
# The batch is: 285
# The batch is: 286
# The batch is: 287
# The batch is: 288
# The batch is: 289
# The batch is: 290
# The batch is: 291
# The batch is: 292
# The batch is: 293
# The batch is: 294
# The batch is: 295
# The batch is: 296
# The batch is: 297
# The batch is: 298
# The batch is: 299
# The batch is: 300
# The batch is: 301
# The batch is: 302
# The batch is: 303
# The batch is: 304
# The batch is: 305
# The batch is: 306
# The batch is: 307
# The batch is: 308
# The batch is: 309
# The batch is: 310
# The batch is: 311
# The batch is: 312
# The batch is: 313
# The batch is: 314
# The batch is: 315
# The batch is: 316
# The batch is: 317
# The batch is: 318
# The batch is: 319
# The batch is: 320
# The batch is: 321
# The batch is: 322
# The batch is: 323
# The batch is: 324
# The batch is: 325
# The batch is: 326
# The batch is: 327
# The batch is: 328
# The batch is: 329
# The batch is: 330
# The batch is: 331
# The batch is: 332
# The batch is: 333
# The batch is: 334
# The batch is: 335
# The batch is: 336
# The batch is: 337
# The batch is: 338
# The batch is: 339
# The batch is: 340
# The batch is: 341
# The batch is: 342
# The batch is: 343
# The batch is: 344
# The batch is: 345
# The batch is: 346
# The batch is: 347
# The batch is: 348
# The batch is: 349
# The batch is: 350
# The batch is: 351
# The batch is: 352
# The batch is: 353
# The batch is: 354
# The batch is: 355
# The batch is: 356
# The batch is: 357
# The batch is: 358
# The batch is: 359
# The batch is: 360
# The batch is: 361
# The batch is: 362
# The batch is: 363
# The batch is: 364
# The batch is: 365
# The batch is: 366
# The batch is: 367
# The batch is: 368
# The batch is: 369
# The batch is: 370
# The batch is: 371
# The batch is: 372
# The batch is: 373
# The batch is: 374
# The batch is: 375
# The batch is: 376
# The batch is: 377
# The batch is: 378
# The batch is: 379
# The batch is: 380
# The batch is: 381
# The batch is: 382
# The batch is: 383
# The batch is: 384
# The batch is: 385
# The batch is: 386
# The batch is: 387
# The batch is: 388
# The batch is: 389
# The batch is: 390
# The batch is: 391
# train acc 0.465, test acc 0.471
