# %% [markdown]
# # 深度卷积神经网络（AlexNet）
# :label:`sec_alexnet`
#
# 在LeNet提出后，卷积神经网络在计算机视觉和机器学习领域中很有名气。但卷积神经网络并没有主导这些领域。这是因为虽然LeNet在小数据集上取得了很好的效果，但是在更大、更真实的数据集上训练卷积神经网络的性能和可行性还有待研究。事实上，在上世纪90年代初到2012年之间的大部分时间里，神经网络往往被其他机器学习方法超越，如支持向量机（support vector machines）。
#
# 在计算机视觉中，直接将神经网络与其他机器学习方法进行比较也许不公平。这是因为，卷积神经网络的输入是由原始像素值或是经过简单预处理（例如居中、缩放）的像素值组成的。但在使用传统机器学习方法时，从业者永远不会将原始像素作为输入。在传统机器学习方法中，计算机视觉流水线是由经过人的手工精心设计的特征流水线组成的。对于这些传统方法，大部分的进展都来自于对特征有了更聪明的想法，并且学习到的算法往往归于事后的解释。
#
# 虽然上世纪90年代就有了一些神经网络加速卡，但仅靠它们还不足以开发出有大量参数的深层多通道多层卷积神经网络。此外，当时的数据集仍然相对较小。除了这些障碍，训练神经网络的一些关键技巧仍然缺失，包括启发式参数初始化、随机梯度下降的变体、非挤压激活函数和有效的正则化技术。
#
# 因此，与训练*端到端*（从像素到分类结果）系统不同，经典机器学习的流水线看起来更像下面这样：
#
# 1. 获取一个有趣的数据集。在早期，收集这些数据集需要昂贵的传感器（在当时最先进的图像也就100万像素）。
# 2. 根据光学、几何学、其他知识以及偶然的发现，手工对特征数据集进行预处理。
# 3. 通过标准的特征提取算法，如SIFT（尺度不变特征变换） :cite:`Lowe.2004`和SURF（加速鲁棒特征） :cite:`Bay.Tuytelaars.Van-Gool.2006`或其他手动调整的流水线来输入数据。
# 4. 将提取的特征送入最喜欢的分类器中（例如线性模型或其它核方法），以训练分类器。
#
# 当人们和机器学习研究人员交谈时，会发现机器学习研究人员相信机器学习既重要又美丽：优雅的理论去证明各种模型的性质。机器学习是一个正在蓬勃发展、严谨且非常有用的领域。然而，当人们和计算机视觉研究人员交谈，会听到一个完全不同的故事。计算机视觉研究人员会告诉一个诡异事实————推动领域进步的是数据特征，而不是学习算法。计算机视觉研究人员相信，从对最终模型精度的影响来说，更大或更干净的数据集、或是稍微改进的特征提取，比任何学习算法带来的进步要大得多。
#
# ## 学习表征
#
# 另一种预测这个领域发展的方法————观察图像特征的提取方法。在2012年前，图像特征都是机械地计算出来的。事实上，设计一套新的特征函数、改进结果，并撰写论文是盛极一时的潮流。SIFT :cite:`Lowe.2004`、SURF :cite:`Bay.Tuytelaars.Van-Gool.2006`、HOG（定向梯度直方图） :cite:`Dalal.Triggs.2005`、[bags of visual words](https://en.wikipedia.org/wiki/Bag-of-words_model_in_computer_vision)和类似的特征提取方法占据了主导地位。
#
# 另一组研究人员，包括Yann LeCun、Geoff Hinton、Yoshua Bengio、Andrew Ng、Shun ichi Amari和Juergen Schmidhuber，想法则与众不同：他们认为特征本身应该被学习。此外，他们还认为，在合理地复杂性前提下，特征应该由多个共同学习的神经网络层组成，每个层都有可学习的参数。在机器视觉中，最底层可能检测边缘、颜色和纹理。事实上，Alex Krizhevsky、Ilya Sutskever和Geoff Hinton提出了一种新的卷积神经网络变体*AlexNet*。在2012年ImageNet挑战赛中取得了轰动一时的成绩。AlexNet以Alex Krizhevsky的名字命名，他是论文 :cite:`Krizhevsky.Sutskever.Hinton.2012`的第一作者。
#
# 有趣的是，在网络的最底层，模型学习到了一些类似于传统滤波器的特征抽取器。 :numref:`fig_filters`是从AlexNet论文 :cite:`Krizhevsky.Sutskever.Hinton.2012`复制的，描述了底层图像特征。
#
# ![AlexNet第一层学习到的特征抽取器。](../img/filters.png)
# :width:`400px`
# :label:`fig_filters`
#
# AlexNet的更高层建立在这些底层表示的基础上，以表示更大的特征，如眼睛、鼻子、草叶等等。而更高的层可以检测整个物体，如人、飞机、狗或飞盘。最终的隐藏神经元可以学习图像的综合表示，从而使属于不同类别的数据易于区分。尽管一直有一群执着的研究者不断钻研，试图学习视觉数据的逐级表征，然而很长一段时间里这些尝试都未有突破。深度卷积神经网络的突破出现在2012年。突破可归因于两个关键因素。
#
# ### 缺少的成分：数据
#
# 包含许多特征的深度模型需要大量的有标签数据，才能显著优于基于凸优化的传统方法（如线性方法和核方法）。
# 然而，限于早期计算机有限的存储和90年代有限的研究预算，大部分研究只基于小的公开数据集。例如，不少研究论文基于加州大学欧文分校（UCI）提供的若干个公开数据集，其中许多数据集只有几百至几千张在非自然环境下以低分辨率拍摄的图像。这一状况在2010年前后兴起的大数据浪潮中得到改善。2009年，ImageNet数据集发布，并发起ImageNet挑战赛：要求研究人员从100万个样本中训练模型，以区分1000个不同类别的对象。ImageNet数据集由斯坦福教授李飞飞小组的研究人员开发，利用谷歌图像搜索（Google Image Search）对每一类图像进行预筛选，并利用亚马逊众包（Amazon Mechanical Turk）来标注每张图片的相关类别。这种规模是前所未有的。这项被称为ImageNet的挑战赛推动了计算机视觉和机器学习研究的发展，挑战研究人员确定哪些模型能够在更大的数据规模下表现最好。
#
# ### 缺少的成分：硬件
#
# 深度学习对计算资源要求很高，训练可能需要数百个迭代轮数，每次迭代都需要通过代价高昂的许多线性代数层传递数据。这也是为什么在20世纪90年代至21世纪初，优化凸目标的简单算法是研究人员的首选。然而，用GPU训练神经网络改变了这一格局。*图形处理器*（Graphics Processing Unit，GPU）早年用来加速图形处理，使电脑游戏玩家受益。GPU可优化高吞吐量的$4 \times 4$矩阵和向量乘法，从而服务于基本的图形任务。幸运的是，这些数学运算与卷积层的计算惊人地相似。由此，英伟达（NVIDIA）和ATI已经开始为通用计算操作优化gpu，甚至把它们作为*通用GPU*（general-purpose GPUs，GPGPU）来销售。
#
# 那么GPU比CPU强在哪里呢？
#
# 首先，我们深度理解一下中央处理器（Central Processing Unit，CPU）的*核心*。
# CPU的每个核心都拥有高时钟频率的运行能力，和高达数MB的三级缓存（L3Cache）。
# 它们非常适合执行各种指令，具有分支预测器、深层流水线和其他使CPU能够运行各种程序的功能。
# 然而，这种明显的优势也是它的致命弱点：通用核心的制造成本非常高。
# 它们需要大量的芯片面积、复杂的支持结构（内存接口、内核之间的缓存逻辑、高速互连等等），而且它们在任何单个任务上的性能都相对较差。
# 现代笔记本电脑最多有4核，即使是高端服务器也很少超过64核，因为它们的性价比不高。
#
# 相比于CPU，GPU由$100 \sim 1000$个小的处理单元组成（NVIDIA、ATI、ARM和其他芯片供应商之间的细节稍有不同），通常被分成更大的组（NVIDIA称之为warps）。
# 虽然每个GPU核心都相对较弱，有时甚至以低于1GHz的时钟频率运行，但庞大的核心数量使GPU比CPU快几个数量级。
# 例如，NVIDIA最近一代的Ampere GPU架构为每个芯片提供了高达312 TFlops的浮点性能，而CPU的浮点性能到目前为止还没有超过1 TFlops。
# 之所以有如此大的差距，原因其实很简单：首先，功耗往往会随时钟频率呈二次方增长。
# 对于一个CPU核心，假设它的运行速度比GPU快4倍，但可以使用16个GPU核代替，那么GPU的综合性能就是CPU的$16 \times 1/4 = 4$倍。
# 其次，GPU内核要简单得多，这使得它们更节能。
# 此外，深度学习中的许多操作需要相对较高的内存带宽，而GPU拥有10倍于CPU的带宽。
#
# 回到2012年的重大突破，当Alex Krizhevsky和Ilya Sutskever实现了可以在GPU硬件上运行的深度卷积神经网络时，一个重大突破出现了。他们意识到卷积神经网络中的计算瓶颈：卷积和矩阵乘法，都是可以在硬件上并行化的操作。
# 于是，他们使用两个显存为3GB的NVIDIA GTX580 GPU实现了快速卷积运算。他们的创新[cuda-convnet](https://code.google.com/archive/p/cuda-convnet/)几年来它一直是行业标准，并推动了深度学习热潮。
#
# ## AlexNet
#
# 2012年，AlexNet横空出世。它首次证明了学习到的特征可以超越手工设计的特征。它一举打破了计算机视觉研究的现状。
# AlexNet使用了8层卷积神经网络，并以很大的优势赢得了2012年ImageNet图像识别挑战赛。
#
# AlexNet和LeNet的架构非常相似，如 :numref:`fig_alexnet`所示。
# 注意，本书在这里提供的是一个稍微精简版本的AlexNet，去除了当年需要两个小型GPU同时运算的设计特点。
#
# ![从LeNet（左）到AlexNet（右）](../img/alexnet.svg)
# :label:`fig_alexnet`
#
# AlexNet和LeNet的设计理念非常相似，但也存在显著差异。
#
# 1. AlexNet比相对较小的LeNet5要深得多。AlexNet由八层组成：五个卷积层、两个全连接隐藏层和一个全连接输出层。
# 2. AlexNet使用ReLU而不是sigmoid作为其激活函数。
#
# 下面的内容将深入研究AlexNet的细节。
#
# ### 模型设计
#
# 在AlexNet的第一层，卷积窗口的形状是$11\times11$。
# 由于ImageNet中大多数图像的宽和高比MNIST图像的多10倍以上，因此，需要一个更大的卷积窗口来捕获目标。
# 第二层中的卷积窗口形状被缩减为$5\times5$，然后是$3\times3$。
# 此外，在第一层、第二层和第五层卷积层之后，加入窗口形状为$3\times3$、步幅为2的最大汇聚层。
# 而且，AlexNet的卷积通道数目是LeNet的10倍。
#
# 在最后一个卷积层后有两个全连接层，分别有4096个输出。
# 这两个巨大的全连接层拥有将近1GB的模型参数。
# 由于早期GPU显存有限，原版的AlexNet采用了双数据流设计，使得每个GPU只负责存储和计算模型的一半参数。
# 幸运的是，现在GPU显存相对充裕，所以现在很少需要跨GPU分解模型（因此，本书的AlexNet模型在这方面与原始论文稍有不同）。
#
# ### 激活函数
#
# 此外，AlexNet将sigmoid激活函数改为更简单的ReLU激活函数。
# 一方面，ReLU激活函数的计算更简单，它不需要如sigmoid激活函数那般复杂的求幂运算。
# 另一方面，当使用不同的参数初始化方法时，ReLU激活函数使训练模型更加容易。
# 当sigmoid激活函数的输出非常接近于0或1时，这些区域的梯度几乎为0，因此反向传播无法继续更新一些模型参数。
# 相反，ReLU激活函数在正区间的梯度总是1。
# 因此，如果模型参数没有正确初始化，sigmoid函数可能在正区间内得到几乎为0的梯度，从而使模型无法得到有效的训练。
#
# ### 容量控制和预处理
#
# AlexNet通过暂退法（ :numref:`sec_dropout`）控制全连接层的模型复杂度，而LeNet只使用了权重衰减。
# 为了进一步扩充数据，AlexNet在训练时增加了大量的图像增强数据，如翻转、裁切和变色。
# 这使得模型更健壮，更大的样本量有效地减少了过拟合。
# 在 :numref:`sec_image_augmentation`中更详细地讨论数据扩增。

# %%
import torch
from torch import nn
from d2l import torch as d2l
import time
import numpy as np
import subprocess
import time
import pandas as pd
import psutil

net = nn.Sequential(
    # 这里使用一个11*11的更大窗口来捕捉对象。
    # 同时，步幅为4，以减少输出的高度和宽度。
    # 另外，输出通道的数目远大于LeNet
    nn.Conv2d(1, 96, kernel_size=11, stride=4, padding=1), nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2),
    # 减小卷积窗口，使用填充为2来使得输入与输出的高和宽一致，且增大输出通道数
    nn.Conv2d(96, 256, kernel_size=5, padding=2), nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2),
    # 使用三个连续的卷积层和较小的卷积窗口。
    # 除了最后的卷积层，输出通道的数量进一步增加。
    # 在前两个卷积层之后，汇聚层不用于减少输入的高度和宽度
    nn.Conv2d(256, 384, kernel_size=3, padding=1), nn.ReLU(),
    nn.Conv2d(384, 384, kernel_size=3, padding=1), nn.ReLU(),
    nn.Conv2d(384, 256, kernel_size=3, padding=1), nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2),
    nn.Flatten(),
    # 这里，全连接层的输出数量是LeNet中的好几倍。使用dropout层来减轻过拟合
    nn.Linear(6400, 4096), nn.ReLU(),
    nn.Dropout(p=0.5),
    nn.Linear(4096, 4096), nn.ReLU(),
    nn.Dropout(p=0.5),
    # 最后是输出层。由于这里使用Fashion-MNIST，所以用类别数为10，而非论文中的1000
    nn.Linear(4096, 10))

# %% [markdown]
# [**我们构造一个**]高度和宽度都为224的(**单通道数据，来观察每一层输出的形状**)。
# 它与 :numref:`fig_alexnet`中的AlexNet架构相匹配。

# %%
X = torch.randn(1, 1, 224, 224)
for layer in net:
    X=layer(X)
    print(layer.__class__.__name__,'output shape:\t',X.shape)
# Out:
# Conv2d output shape:	 torch.Size([1, 96, 54, 54])
# ReLU output shape:	 torch.Size([1, 96, 54, 54])
# MaxPool2d output shape:	 torch.Size([1, 96, 26, 26])
# Conv2d output shape:	 torch.Size([1, 256, 26, 26])
# ReLU output shape:	 torch.Size([1, 256, 26, 26])
# MaxPool2d output shape:	 torch.Size([1, 256, 12, 12])
# Conv2d output shape:	 torch.Size([1, 384, 12, 12])
# ReLU output shape:	 torch.Size([1, 384, 12, 12])
# Conv2d output shape:	 torch.Size([1, 384, 12, 12])
# ReLU output shape:	 torch.Size([1, 384, 12, 12])
# Conv2d output shape:	 torch.Size([1, 256, 12, 12])
# ReLU output shape:	 torch.Size([1, 256, 12, 12])
# MaxPool2d output shape:	 torch.Size([1, 256, 5, 5])
# Flatten output shape:	 torch.Size([1, 6400])
# Linear output shape:	 torch.Size([1, 4096])
# ReLU output shape:	 torch.Size([1, 4096])
# Dropout output shape:	 torch.Size([1, 4096])
# Linear output shape:	 torch.Size([1, 4096])
# ReLU output shape:	 torch.Size([1, 4096])
# Dropout output shape:	 torch.Size([1, 4096])
# Linear output shape:	 torch.Size([1, 10])

# %% [markdown]
# ## 读取数据集
#
# 尽管原文中AlexNet是在ImageNet上进行训练的，但本书在这里使用的是Fashion-MNIST数据集。因为即使在现代GPU上，训练ImageNet模型，同时使其收敛可能需要数小时或数天的时间。
# 将AlexNet直接应用于Fashion-MNIST的一个问题是，[**Fashion-MNIST图像的分辨率**]（$28 \times 28$像素）(**低于ImageNet图像。**)
# 为了解决这个问题，(**我们将它们增加到$224 \times 224$**)（通常来讲这不是一个明智的做法，但在这里这样做是为了有效使用AlexNet架构）。
# 这里需要使用`d2l.load_data_fashion_mnist`函数中的`resize`参数执行此调整。

# %%
batch_size = 128
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size, resize=224)
# print the shape of the train_iter
list_of_i = []
for i, (X, y) in enumerate(train_iter):
    list_of_i.append(i)

print('the shape of the train_iter is:', np.array(list_of_i).shape)
# print(list_of_i)
# print the first 10 batch of the train_iter
for i, (X, y) in enumerate(train_iter):
    if i < 10:
        print('the shape of the', i, 'batch of the train_iter is:', X.shape)
    else:
        break
# Out:
# the shape of the train_iter is: (469,)
# the shape of the 0 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 1 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 2 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 3 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 4 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 5 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 6 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 7 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 8 batch of the train_iter is: torch.Size([128, 1, 224, 224])
# the shape of the 9 batch of the train_iter is: torch.Size([128, 1, 224, 224])

# %% [markdown]
# ## [**训练AlexNet**]
#
# 现在AlexNet可以开始被训练了。与 :numref:`sec_lenet`中的LeNet相比，这里的主要变化是使用更小的学习速率训练，这是因为网络更深更广、图像分辨率更高，训练卷积神经网络就更昂贵。

# %%
'''
对train_ch6()函数进行修改，使得能够在每一层的前向传播的时候，记录下时间, 
能耗部分不好进行具体统计，因为每个层的能耗有区别，并且时间过短，所以采用的方式为计算总能耗和总时长，最后通过平均值来计算估算的能耗
'''
def train_ch6self(net, train_iter, test_iter, num_epochs, lr, device):
    def init_weights(m): # 初始化权重
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            nn.init.xavier_uniform_(m.weight)
    net.apply(init_weights)
    # set a list of layer name
    list_layer_name = ['Conv2d','ReLU','MaxPool2d','Linear','Dropout','Flatten'] # 该模型中包括的所有的层的名字
    # create a numpy array to store the time and energy consumption, the shape is (num_epochs, len(list_layer_name), 2)
    # for each epoch, the shape is (6,2), contains the total time and the energy consumption of each layer
    timeenergy_data_forward = np.zeros((num_epochs, len(list_layer_name), 2)) 
    # for each epoch, the shape is (6,2), contains the total time of each part in a round, which is to_device, forward, loss, backward, optimizer，test_round
    # and the 2 means time and energy consumption, respectively
    timeenergy_data_round = np.zeros((num_epochs, 6, 2)) 
    # create another numpy array to store the data of each epoch, 1 column is training loss, 2 column is training accuracy, 3 column is test accuracy
    acc_data = []
    # create a numpy array to store the train loss and train accuracy
    train_l = []
    train_acc = []
    # create a numpy array to store the epoch and running time
    time_data_epoch = np.zeros((num_epochs, 2))
    # create a numpy array to store the energy consumption of each epoch
    energy_data_epoch = np.zeros((num_epochs, 1), dtype=object)
    # print the training device
    print('training on', device)
    net.to(device) # 将模型放到对应的设备上
    # 初始化optimizer和loss
    # set the optimizer to be Adam
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)
    loss_fn = nn.CrossEntropyLoss()
    # 初始化计时器
    timer, num_batches = d2l.Timer(), len(train_iter)   
    # 开始训练
    for epoch in range(num_epochs):
        print('epoch %d' % (epoch + 1))
        # each epoch, set a timer to record the time
        timer.start()
        ##############################################################################################################
        # start the nvidia-smi command
        with open('gpu_power_usage.csv', 'w') as file:
            # Start the nvidia-smi command
            nvidia_smi_process = subprocess.Popen(
                ["nvidia-smi", "--query-gpu=power.draw", "--format=csv", "--loop-ms=1000"],
                stdout=file,  # Redirect the output directly to the file
                stderr=subprocess.PIPE,
                text=True
            )
        ##############################################################################################################
        net.train() # 设置为训练模式
        # 初始化每个epoch的统计时间的变量
        time_to_device_cost, time_forward, time_cost_loss = 0,0,0
        time_cost_backward, time_cost_optimizer, time_test_acc_cost = 0,0,0
        train_l_epoch = []
        train_acc_epoch = []
        metric = d2l.Accumulator(3)
        for i, (X, y) in enumerate(train_iter):
            print('round %d' % (i))
            time_round_start = time.time() # 计算每一轮的时间s
            optimizer.zero_grad() # 将optimizer的梯度清零s
            time_forward_epoch = np.zeros((len(list_layer_name), 1))
        ##################################################################################
            # 计算将数据放到对应的设备上的时间
            time_to_device_cost_i = 0
            time_to_device = time.time()
            X, y = X.to(device, non_blocking=True), y.to(device, non_blocking=True)
            time_to_device_end = time.time()
            time_to_device_cost_i = time_to_device_end - time_to_device
            print('time to device %f sec' % (time_to_device_cost_i))
            time_to_device_cost += time_to_device_cost_i
        ##################################################################################
            # 将原本的模型进行修改，使得能够逐层进行运行，并且在这个过程中，记录下时间和能量
            y_hat = X
            for layer in net:
                time_cost_layer = 0
                layer_name = layer.__class__.__name__ # 获取层的名字
                # find out the layer name is in where of the list
                layer_index = list_layer_name.index(layer_name)
                # calculate the time
                time_start_layer = time.time()
                y_hat = layer(y_hat)
                time_end_layer = time.time()
                time_cost_layer = time_end_layer - time_start_layer
                time_forward_epoch[layer_index,0] += time_cost_layer
                timeenergy_data_forward[epoch,layer_index,0] += time_cost_layer
                if torch.isinf(y_hat).any() or torch.isnan(y_hat).any():
                    print("Inf or NaN detected in y_hat")
            # 计算前向的时间
            time_forward = np.sum(timeenergy_data_forward[epoch,:,0])
            print('time forward %f sec' % (np.sum(time_forward_epoch)))
        ##################################################################################
            # 计算loss
            time_cost_loss_i = 0 # 初始化loss的时间
            time_start_loss = time.time()
            loss = loss_fn(y_hat, y)
            # print(loss)
            time_end_loss = time.time()
            time_cost_loss_i = time_end_loss - time_start_loss
            print('loss time %f sec' % (time_cost_loss_i))
            time_cost_loss += time_cost_loss_i
        ##################################################################################
            # 计算backward
            time_cost_backward_i = 0 # 初始化backward的时间
            time_start_backward = time.time()
            loss.backward()
            time_end_backward = time.time()
            time_cost_backward_i = time_end_backward - time_start_backward
            print('backward time %f sec' % (time_cost_backward_i))
            time_cost_backward += time_cost_backward_i
        ##################################################################################
            # 计算optimizer
            time_cost_optimizer_i = 0 # 初始化optimizer的时间
            time_start_optimizer = time.time()
            optimizer.step()
            time_end_optimizer = time.time()
            time_cost_optimizer_i = time_end_optimizer - time_start_optimizer
            print('optimizer time %f sec' % (time_cost_optimizer_i))
            time_cost_optimizer += time_cost_optimizer_i
        ##################################################################################
            time_round_end = time.time()
            time_round_cost = time_round_end - time_round_start
            print(f'training time in round {i} cost {time_round_cost} sec')
        ##################################################################################
            with torch.no_grad():
                metric.add(loss * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            train_l_i = metric[0] / metric[2]
            train_acc_i = metric[1] / metric[2]
            train_l_epoch.append(train_l_i)
            train_acc_epoch.append(train_acc_i)
            print('loss %f, train acc %f' % (train_l_i, train_acc_i))
        train_l.append(train_l_epoch)
        train_acc.append(train_acc_epoch)
        ##################################################################################
        # 进行模型的test部分运行
        time_test_acc_cost_epoch = 0
        time_test_acc_start = time.time()
        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter, device)
        time_test_acc_end = time.time()
        time_test_acc_cost_epoch = time_test_acc_end - time_test_acc_start
        time_test_acc_cost += time_test_acc_cost_epoch
        print('test acc is %f' % (test_acc))
        acc_data.append(test_acc)
        ##################################################################################
        # 将每一轮的每个部分的时间加入到time_data_round中
        timeenergy_data_round[epoch,0,0] = time_to_device_cost
        timeenergy_data_round[epoch,1,0] = time_forward
        timeenergy_data_round[epoch,2,0] = time_cost_loss
        timeenergy_data_round[epoch,3,0] = time_cost_backward
        timeenergy_data_round[epoch,4,0] = time_cost_optimizer
        timeenergy_data_round[epoch,5,0] = time_test_acc_cost
        ##################################################################################
        # stop the nvidia-smi command
        nvidia_smi_process.terminate()
        timer.stop() # 停止计时 
        time_data_epoch[epoch,0] = epoch + 1
        time_data_epoch[epoch,1] = timer.sum()
        ##############################################################################################################
        # calculate the energy consumption of each epoch
        energy_datal = pd.read_csv('gpu_power_usage.csv')
        for l in range(len(energy_datal)):
            energy_datal.iloc[l,0] = energy_datal.iloc[l,0].replace(' W','')
        energy_datal = energy_datal.astype(float)  
        energy_datal = energy_datal.sum()
        energy_data_epoch[epoch,0] = energy_datal
        # print('epoch %d, time %f sec' % (epoch, timer.sum()))
    return timeenergy_data_forward, timeenergy_data_round, acc_data, train_l, train_acc, time_data_epoch, energy_data_epoch

# %%
lr, num_epochs = 0.001, 20
device = d2l.try_gpu()
timeenergy_data_forward, timeenergy_data_round, acc_data, train_l, train_acc, time_data_epoch, energy_data_epoch = train_ch6self(net, train_iter, test_iter, num_epochs, lr, device)
# Out:
# training on cuda:0
# epoch 1
# round 0
# time to device 0.007105 sec
# time forward 0.170539 sec
# loss time 0.019248 sec
# backward time 0.107969 sec
# optimizer time 0.064251 sec
# training time in round 0 cost 0.4174082279205322 sec
# loss 2.305230, train acc 0.078125
# round 1
# time to device 0.004219 sec
# time forward 0.001656 sec
# loss time 0.000087 sec
# backward time 0.002280 sec
# optimizer time 0.000604 sec
# training time in round 1 cost 0.04928278923034668 sec
# loss 2.932651, train acc 0.085938
# round 2
# time to device 0.004052 sec
# time forward 0.001175 sec
# loss time 0.000084 sec
# backward time 0.001396 sec
# optimizer time 0.001020 sec
# training time in round 2 cost 0.04433560371398926 sec
# loss 2.725458, train acc 0.104167
# round 3
# time to device 0.004159 sec
# time forward 0.001209 sec
# loss time 0.000086 sec
# backward time 0.001253 sec
# optimizer time 0.000550 sec
# training time in round 3 cost 0.04348945617675781 sec
# loss 2.617175, train acc 0.117188
# round 4
# time to device 0.004058 sec
# time forward 0.001183 sec
# loss time 0.000084 sec
# backward time 0.001222 sec
# optimizer time 0.000509 sec
# training time in round 4 cost 0.04393482208251953 sec
# loss 2.554964, train acc 0.106250
# round 5
# time to device 0.004174 sec
# time forward 0.001223 sec
# loss time 0.000089 sec
# backward time 0.001269 sec
# optimizer time 0.000525 sec
# training time in round 5 cost 0.04348897933959961 sec
# loss 2.513046, train acc 0.109375
# round 6
# time to device 0.004148 sec
# time forward 0.001330 sec
# loss time 0.000087 sec
# backward time 0.001241 sec
# optimizer time 0.000533 sec
# training time in round 6 cost 0.043427467346191406 sec
# loss 2.479628, train acc 0.106027
# round 7
# time to device 0.004044 sec
# time forward 0.001189 sec
# loss time 0.000090 sec
# backward time 0.001261 sec
# optimizer time 0.000526 sec
# training time in round 7 cost 0.04377293586730957 sec
# loss 2.452430, train acc 0.112305
# round 8
# time to device 0.004018 sec
# time forward 0.001152 sec
# loss time 0.000083 sec
# backward time 0.001222 sec
# optimizer time 0.000780 sec
# training time in round 8 cost 0.042986154556274414 sec
# loss 2.423027, train acc 0.131076
# round 9
# time to device 0.004026 sec
# time forward 0.001119 sec
# loss time 0.000084 sec
# backward time 0.001182 sec
# optimizer time 0.000513 sec
# training time in round 9 cost 0.043625831604003906 sec
# loss 2.390095, train acc 0.138281
# round 10
# time to device 0.004063 sec
# time forward 0.001117 sec
# loss time 0.000084 sec
# backward time 0.001210 sec
# optimizer time 0.000495 sec
# training time in round 10 cost 0.04281878471374512 sec
# loss 2.340547, train acc 0.159801
# round 11
# time to device 0.004131 sec
# time forward 0.001224 sec
# loss time 0.000085 sec
# backward time 0.001228 sec
# optimizer time 0.000500 sec
# training time in round 11 cost 0.04335761070251465 sec
# loss 2.300026, train acc 0.171224
# round 12
# time to device 0.004023 sec
# time forward 0.001157 sec
# loss time 0.000085 sec
# backward time 0.001179 sec
# optimizer time 0.000474 sec
# training time in round 12 cost 0.04322075843811035 sec
# loss 2.270892, train acc 0.177885
# round 13
# time to device 0.004058 sec
# time forward 0.001166 sec
# loss time 0.000082 sec
# backward time 0.001281 sec
# optimizer time 0.000517 sec
# training time in round 13 cost 0.04276609420776367 sec
# loss 2.234283, train acc 0.189732
# round 14
# time to device 0.004031 sec
# time forward 0.001065 sec
# loss time 0.000085 sec
# backward time 0.001222 sec
# optimizer time 0.000503 sec
# training time in round 14 cost 0.04231548309326172 sec
# loss 2.192529, train acc 0.211458
# round 15
# time to device 0.004144 sec
# time forward 0.001185 sec
# loss time 0.000097 sec
# backward time 0.001203 sec
# optimizer time 0.000495 sec
# training time in round 15 cost 0.04268050193786621 sec
# loss 2.159520, train acc 0.225098
# round 16
# time to device 0.004003 sec
# time forward 0.001060 sec
# loss time 0.000084 sec
# backward time 0.001272 sec
# optimizer time 0.000526 sec
# training time in round 16 cost 0.04265594482421875 sec
# loss 2.117164, train acc 0.242647
# round 17
# time to device 0.004050 sec
# time forward 0.001093 sec
# loss time 0.000086 sec
# backward time 0.001196 sec
# optimizer time 0.000484 sec
# training time in round 17 cost 0.04290294647216797 sec
# loss 2.075187, train acc 0.253906
# round 18
# time to device 0.004000 sec
# time forward 0.001121 sec
# loss time 0.000084 sec
# backward time 0.001223 sec
# optimizer time 0.000485 sec
# training time in round 18 cost 0.042505502700805664 sec
# loss 2.032387, train acc 0.268503
# round 19
# time to device 0.004000 sec
# time forward 0.001107 sec
# loss time 0.000081 sec
# backward time 0.001617 sec
# optimizer time 0.001220 sec
# training time in round 19 cost 0.04428219795227051 sec
# loss 1.997550, train acc 0.276172
# round 20
# time to device 0.004231 sec
# time forward 0.001083 sec
# loss time 0.000084 sec
# backward time 0.001319 sec
# optimizer time 0.000751 sec
# training time in round 20 cost 0.04352116584777832 sec
# loss 1.956175, train acc 0.289435
# round 21
# time to device 0.004104 sec
# time forward 0.001101 sec
# loss time 0.000093 sec
# backward time 0.001150 sec
# optimizer time 0.000517 sec
# training time in round 21 cost 0.04308176040649414 sec
# loss 1.917660, train acc 0.302202
# round 22
# time to device 0.004032 sec
# time forward 0.001148 sec
# loss time 0.000094 sec
# backward time 0.001561 sec
# optimizer time 0.001127 sec
# training time in round 22 cost 0.04422879219055176 sec
# loss 1.880136, train acc 0.310802
# round 23
# time to device 0.004089 sec
# time forward 0.001156 sec
# loss time 0.000084 sec
# backward time 0.001236 sec
# optimizer time 0.000515 sec
# training time in round 23 cost 0.04349470138549805 sec
# loss 1.855006, train acc 0.319661
# round 24
# time to device 0.003988 sec
# time forward 0.001041 sec
# loss time 0.000086 sec
# backward time 0.001225 sec
# optimizer time 0.000495 sec
# training time in round 24 cost 0.04302072525024414 sec
# loss 1.829715, train acc 0.328125
# round 25
# time to device 0.004063 sec
# time forward 0.001190 sec
# loss time 0.000083 sec
# backward time 0.001205 sec
# optimizer time 0.000482 sec
# training time in round 25 cost 0.04290342330932617 sec
# loss 1.796666, train acc 0.336839
# round 26
# time to device 0.004000 sec
# time forward 0.001038 sec
# loss time 0.000083 sec
# backward time 0.001394 sec
# optimizer time 0.000529 sec
# training time in round 26 cost 0.04337573051452637 sec
# loss 1.776684, train acc 0.343750
# round 27
# time to device 0.004305 sec
# time forward 0.001122 sec
# loss time 0.000086 sec
# backward time 0.001195 sec
# optimizer time 0.000657 sec
# training time in round 27 cost 0.04356980323791504 sec
# loss 1.750671, train acc 0.353795
# round 28
# time to device 0.003999 sec
# time forward 0.001030 sec
# loss time 0.000082 sec
# backward time 0.001204 sec
# optimizer time 0.000952 sec
# training time in round 28 cost 0.0434267520904541 sec
# loss 1.729526, train acc 0.360183
# round 29
# time to device 0.004062 sec
# time forward 0.001052 sec
# loss time 0.000104 sec
# backward time 0.001220 sec
# optimizer time 0.000494 sec
# training time in round 29 cost 0.04275202751159668 sec
# loss 1.707555, train acc 0.365625
# round 30
# time to device 0.004250 sec
# time forward 0.001089 sec
# loss time 0.000086 sec
# backward time 0.001190 sec
# optimizer time 0.000558 sec
# training time in round 30 cost 0.04347419738769531 sec
# loss 1.685250, train acc 0.371976
# round 31
# time to device 0.004064 sec
# time forward 0.001110 sec
# loss time 0.000086 sec
# backward time 0.001245 sec
# optimizer time 0.000495 sec
# training time in round 31 cost 0.04272270202636719 sec
# loss 1.663345, train acc 0.379395
# round 32
# time to device 0.004037 sec
# time forward 0.001032 sec
# loss time 0.000084 sec
# backward time 0.001235 sec
# optimizer time 0.000561 sec
# training time in round 32 cost 0.04252982139587402 sec
# loss 1.645459, train acc 0.384706
# round 33
# time to device 0.004055 sec
# time forward 0.001068 sec
# loss time 0.000085 sec
# backward time 0.001177 sec
# optimizer time 0.000505 sec
# training time in round 33 cost 0.04309344291687012 sec
# loss 1.625546, train acc 0.391774
# round 34
# time to device 0.004018 sec
# time forward 0.001042 sec
# loss time 0.000083 sec
# backward time 0.001776 sec
# optimizer time 0.001084 sec
# training time in round 34 cost 0.04368925094604492 sec
# loss 1.605173, train acc 0.398884
# round 35
# time to device 0.004091 sec
# time forward 0.001056 sec
# loss time 0.000087 sec
# backward time 0.001167 sec
# optimizer time 0.000509 sec
# training time in round 35 cost 0.04324674606323242 sec
# loss 1.586275, train acc 0.404297
# round 36
# time to device 0.003985 sec
# time forward 0.001051 sec
# loss time 0.000082 sec
# backward time 0.001213 sec
# optimizer time 0.000500 sec
# training time in round 36 cost 0.04283332824707031 sec
# loss 1.569691, train acc 0.409206
# round 37
# time to device 0.004079 sec
# time forward 0.001142 sec
# loss time 0.000086 sec
# backward time 0.001178 sec
# optimizer time 0.000487 sec
# training time in round 37 cost 0.043233394622802734 sec
# loss 1.553541, train acc 0.414474
# round 38
# time to device 0.003986 sec
# time forward 0.001042 sec
# loss time 0.000084 sec
# backward time 0.001226 sec
# optimizer time 0.000938 sec
# training time in round 38 cost 0.043581485748291016 sec
# loss 1.540149, train acc 0.419671
# round 39
# time to device 0.004024 sec
# time forward 0.001062 sec
# loss time 0.000087 sec
# backward time 0.001516 sec
# optimizer time 0.000791 sec
# training time in round 39 cost 0.04298114776611328 sec
# loss 1.527964, train acc 0.424609
# round 40
# time to device 0.004016 sec
# time forward 0.001067 sec
# loss time 0.000084 sec
# backward time 0.001179 sec
# optimizer time 0.000510 sec
# training time in round 40 cost 0.043256521224975586 sec
# loss 1.512445, train acc 0.430259
# round 41
# time to device 0.004025 sec
# time forward 0.001114 sec
# loss time 0.000083 sec
# backward time 0.001274 sec
# optimizer time 0.000472 sec
# training time in round 41 cost 0.043410301208496094 sec
# loss 1.495851, train acc 0.435640
# round 42
# time to device 0.004033 sec
# time forward 0.001077 sec
# loss time 0.000083 sec
# backward time 0.001178 sec
# optimizer time 0.000496 sec
# training time in round 42 cost 0.042900800704956055 sec
# loss 1.484739, train acc 0.439680
# round 43
# time to device 0.004019 sec
# time forward 0.001083 sec
# loss time 0.000087 sec
# backward time 0.001265 sec
# optimizer time 0.000497 sec
# training time in round 43 cost 0.043673038482666016 sec
# loss 1.471618, train acc 0.444247
# round 44
# time to device 0.004041 sec
# time forward 0.001102 sec
# loss time 0.000083 sec
# backward time 0.001209 sec
# optimizer time 0.000502 sec
# training time in round 44 cost 0.04308962821960449 sec
# loss 1.458518, train acc 0.449132
# round 45
# time to device 0.004068 sec
# time forward 0.001113 sec
# loss time 0.000085 sec
# backward time 0.001230 sec
# optimizer time 0.000492 sec
# training time in round 45 cost 0.04376339912414551 sec
# loss 1.445600, train acc 0.453635
# round 46
# time to device 0.004029 sec
# time forward 0.001023 sec
# loss time 0.000085 sec
# backward time 0.001220 sec
# optimizer time 0.000720 sec
# training time in round 46 cost 0.042636871337890625 sec
# loss 1.429345, train acc 0.459275
# round 47
# time to device 0.004041 sec
# time forward 0.001067 sec
# loss time 0.000088 sec
# backward time 0.001177 sec
# optimizer time 0.000489 sec
# training time in round 47 cost 0.04299616813659668 sec
# loss 1.420623, train acc 0.462891
# round 48
# time to device 0.004032 sec
# time forward 0.001031 sec
# loss time 0.000085 sec
# backward time 0.001780 sec
# optimizer time 0.000775 sec
# training time in round 48 cost 0.04381752014160156 sec
# loss 1.409052, train acc 0.467315
# round 49
# time to device 0.004254 sec
# time forward 0.001068 sec
# loss time 0.000084 sec
# backward time 0.001299 sec
# optimizer time 0.000554 sec
# training time in round 49 cost 0.04325413703918457 sec
# loss 1.404323, train acc 0.468906
# round 50
# time to device 0.004006 sec
# time forward 0.001053 sec
# loss time 0.000085 sec
# backward time 0.001228 sec
# optimizer time 0.000492 sec
# training time in round 50 cost 0.042619943618774414 sec
# loss 1.393258, train acc 0.473499
# round 51
# time to device 0.004079 sec
# time forward 0.001096 sec
# loss time 0.000085 sec
# backward time 0.001169 sec
# optimizer time 0.000491 sec
# training time in round 51 cost 0.04298067092895508 sec
# loss 1.379939, train acc 0.479267
# round 52
# time to device 0.004009 sec
# time forward 0.001054 sec
# loss time 0.000094 sec
# backward time 0.001239 sec
# optimizer time 0.000714 sec
# training time in round 52 cost 0.04345822334289551 sec
# loss 1.369987, train acc 0.483638
# round 53
# time to device 0.004144 sec
# time forward 0.001027 sec
# loss time 0.000087 sec
# backward time 0.001201 sec
# optimizer time 0.000498 sec
# training time in round 53 cost 0.04276871681213379 sec
# loss 1.360808, train acc 0.487124
# round 54
# time to device 0.004065 sec
# time forward 0.001291 sec
# loss time 0.000093 sec
# backward time 0.001350 sec
# optimizer time 0.000565 sec
# training time in round 54 cost 0.04387187957763672 sec
# loss 1.349498, train acc 0.490341
# round 55
# time to device 0.004214 sec
# time forward 0.001109 sec
# loss time 0.000094 sec
# backward time 0.001266 sec
# optimizer time 0.000612 sec
# training time in round 55 cost 0.04345393180847168 sec
# loss 1.339815, train acc 0.494001
# round 56
# time to device 0.004008 sec
# time forward 0.001026 sec
# loss time 0.000086 sec
# backward time 0.001221 sec
# optimizer time 0.000515 sec
# training time in round 56 cost 0.04291939735412598 sec
# loss 1.332538, train acc 0.495614
# round 57
# time to device 0.004040 sec
# time forward 0.001151 sec
# loss time 0.000097 sec
# backward time 0.001234 sec
# optimizer time 0.000520 sec
# training time in round 57 cost 0.04291701316833496 sec
# loss 1.321857, train acc 0.499461
# round 58
# time to device 0.004013 sec
# time forward 0.001044 sec
# loss time 0.000083 sec
# backward time 0.001173 sec
# optimizer time 0.000473 sec
# training time in round 58 cost 0.04324221611022949 sec
# loss 1.313499, train acc 0.501721
# round 59
# time to device 0.004013 sec
# time forward 0.001131 sec
# loss time 0.000086 sec
# backward time 0.001205 sec
# optimizer time 0.000491 sec
# training time in round 59 cost 0.042758941650390625 sec
# loss 1.304803, train acc 0.504557
# round 60
# time to device 0.004004 sec
# time forward 0.001071 sec
# loss time 0.000083 sec
# backward time 0.001224 sec
# optimizer time 0.000713 sec
# training time in round 60 cost 0.0428776741027832 sec
# loss 1.296573, train acc 0.507428
# round 61
# time to device 0.004026 sec
# time forward 0.001113 sec
# loss time 0.000082 sec
# backward time 0.001219 sec
# optimizer time 0.000490 sec
# training time in round 61 cost 0.04338693618774414 sec
# loss 1.288051, train acc 0.510837
# round 62
# time to device 0.004014 sec
# time forward 0.001123 sec
# loss time 0.000084 sec
# backward time 0.001221 sec
# optimizer time 0.000493 sec
# training time in round 62 cost 0.04304075241088867 sec
# loss 1.278970, train acc 0.514509
# round 63
# time to device 0.004101 sec
# time forward 0.001230 sec
# loss time 0.000084 sec
# backward time 0.001182 sec
# optimizer time 0.000492 sec
# training time in round 63 cost 0.04308748245239258 sec
# loss 1.269577, train acc 0.517700
# round 64
# time to device 0.004082 sec
# time forward 0.001012 sec
# loss time 0.000085 sec
# backward time 0.001220 sec
# optimizer time 0.000503 sec
# training time in round 64 cost 0.04300403594970703 sec
# loss 1.259385, train acc 0.521514
# round 65
# time to device 0.004109 sec
# time forward 0.001109 sec
# loss time 0.000084 sec
# backward time 0.001159 sec
# optimizer time 0.000485 sec
# training time in round 65 cost 0.043375492095947266 sec
# loss 1.251757, train acc 0.524384
# round 66
# time to device 0.004049 sec
# time forward 0.001118 sec
# loss time 0.000085 sec
# backward time 0.001229 sec
# optimizer time 0.000489 sec
# training time in round 66 cost 0.042926788330078125 sec
# loss 1.246727, train acc 0.526469
# round 67
# time to device 0.004077 sec
# time forward 0.001211 sec
# loss time 0.000082 sec
# backward time 0.001218 sec
# optimizer time 0.000693 sec
# training time in round 67 cost 0.043308258056640625 sec
# loss 1.238622, train acc 0.529412
# round 68
# time to device 0.004049 sec
# time forward 0.001089 sec
# loss time 0.000086 sec
# backward time 0.001191 sec
# optimizer time 0.000731 sec
# training time in round 68 cost 0.04396533966064453 sec
# loss 1.229810, train acc 0.533062
# round 69
# time to device 0.004035 sec
# time forward 0.001070 sec
# loss time 0.000084 sec
# backward time 0.001179 sec
# optimizer time 0.000492 sec
# training time in round 69 cost 0.04301881790161133 sec
# loss 1.222945, train acc 0.535937
# round 70
# time to device 0.004002 sec
# time forward 0.001082 sec
# loss time 0.000087 sec
# backward time 0.001256 sec
# optimizer time 0.000671 sec
# training time in round 70 cost 0.043215274810791016 sec
# loss 1.215326, train acc 0.538952
# round 71
# time to device 0.004029 sec
# time forward 0.001143 sec
# loss time 0.000085 sec
# backward time 0.001212 sec
# optimizer time 0.000790 sec
# training time in round 71 cost 0.0430145263671875 sec
# loss 1.206753, train acc 0.541667
# round 72
# time to device 0.004064 sec
# time forward 0.001061 sec
# loss time 0.000085 sec
# backward time 0.001201 sec
# optimizer time 0.000661 sec
# training time in round 72 cost 0.04364156723022461 sec
# loss 1.200870, train acc 0.543664
# round 73
# time to device 0.004015 sec
# time forward 0.001122 sec
# loss time 0.000087 sec
# backward time 0.001184 sec
# optimizer time 0.000483 sec
# training time in round 73 cost 0.04270029067993164 sec
# loss 1.193571, train acc 0.546453
# round 74
# time to device 0.004051 sec
# time forward 0.001082 sec
# loss time 0.000085 sec
# backward time 0.001174 sec
# optimizer time 0.000493 sec
# training time in round 74 cost 0.042775630950927734 sec
# loss 1.187608, train acc 0.548438
# round 75
# time to device 0.004046 sec
# time forward 0.001119 sec
# loss time 0.000083 sec
# backward time 0.001241 sec
# optimizer time 0.000487 sec
# training time in round 75 cost 0.04379630088806152 sec
# loss 1.180477, train acc 0.550576
# round 76
# time to device 0.003992 sec
# time forward 0.001024 sec
# loss time 0.000082 sec
# backward time 0.001185 sec
# optimizer time 0.000602 sec
# training time in round 76 cost 0.04289507865905762 sec
# loss 1.173807, train acc 0.553064
# round 77
# time to device 0.004036 sec
# time forward 0.001132 sec
# loss time 0.000083 sec
# backward time 0.001293 sec
# optimizer time 0.000509 sec
# training time in round 77 cost 0.043180227279663086 sec
# loss 1.169698, train acc 0.554788
# round 78
# time to device 0.004028 sec
# time forward 0.001068 sec
# loss time 0.000085 sec
# backward time 0.001205 sec
# optimizer time 0.000484 sec
# training time in round 78 cost 0.042871952056884766 sec
# loss 1.162292, train acc 0.557259
# round 79
# time to device 0.004046 sec
# time forward 0.001103 sec
# loss time 0.000085 sec
# backward time 0.001206 sec
# optimizer time 0.000487 sec
# training time in round 79 cost 0.04344058036804199 sec
# loss 1.157395, train acc 0.559277
# round 80
# time to device 0.004011 sec
# time forward 0.001078 sec
# loss time 0.000101 sec
# backward time 0.001283 sec
# optimizer time 0.000516 sec
# training time in round 80 cost 0.042960166931152344 sec
# loss 1.154614, train acc 0.560378
# round 81
# time to device 0.004042 sec
# time forward 0.001231 sec
# loss time 0.000083 sec
# backward time 0.001189 sec
# optimizer time 0.000521 sec
# training time in round 81 cost 0.04313850402832031 sec
# loss 1.148533, train acc 0.562786
# round 82
# time to device 0.004032 sec
# time forward 0.001076 sec
# loss time 0.000087 sec
# backward time 0.001209 sec
# optimizer time 0.000498 sec
# training time in round 82 cost 0.043791770935058594 sec
# loss 1.141863, train acc 0.565512
# round 83
# time to device 0.004103 sec
# time forward 0.001093 sec
# loss time 0.000083 sec
# backward time 0.001175 sec
# optimizer time 0.000489 sec
# training time in round 83 cost 0.043132781982421875 sec
# loss 1.135559, train acc 0.567615
# round 84
# time to device 0.004016 sec
# time forward 0.001027 sec
# loss time 0.000084 sec
# backward time 0.001245 sec
# optimizer time 0.000496 sec
# training time in round 84 cost 0.04307818412780762 sec
# loss 1.129303, train acc 0.570312
# round 85
# time to device 0.004019 sec
# time forward 0.001102 sec
# loss time 0.000084 sec
# backward time 0.001187 sec
# optimizer time 0.000791 sec
# training time in round 85 cost 0.0431060791015625 sec
# loss 1.124229, train acc 0.572402
# round 86
# time to device 0.003997 sec
# time forward 0.001070 sec
# loss time 0.000084 sec
# backward time 0.001600 sec
# optimizer time 0.000546 sec
# training time in round 86 cost 0.04383730888366699 sec
# loss 1.118399, train acc 0.574174
# round 87
# time to device 0.004096 sec
# time forward 0.001101 sec
# loss time 0.000087 sec
# backward time 0.001187 sec
# optimizer time 0.000498 sec
# training time in round 87 cost 0.042612552642822266 sec
# loss 1.112576, train acc 0.575906
# round 88
# time to device 0.004023 sec
# time forward 0.001019 sec
# loss time 0.000084 sec
# backward time 0.001165 sec
# optimizer time 0.000708 sec
# training time in round 88 cost 0.043150901794433594 sec
# loss 1.106573, train acc 0.577862
# round 89
# time to device 0.004010 sec
# time forward 0.001077 sec
# loss time 0.000098 sec
# backward time 0.001209 sec
# optimizer time 0.001024 sec
# training time in round 89 cost 0.044507741928100586 sec
# loss 1.101226, train acc 0.580122
# round 90
# time to device 0.004038 sec
# time forward 0.001016 sec
# loss time 0.000083 sec
# backward time 0.001210 sec
# optimizer time 0.000485 sec
# training time in round 90 cost 0.04274797439575195 sec
# loss 1.096662, train acc 0.581817
# round 91
# time to device 0.004043 sec
# time forward 0.001117 sec
# loss time 0.000085 sec
# backward time 0.001264 sec
# optimizer time 0.000513 sec
# training time in round 91 cost 0.04308438301086426 sec
# loss 1.092202, train acc 0.583815
# round 92
# time to device 0.004049 sec
# time forward 0.001059 sec
# loss time 0.000084 sec
# backward time 0.001171 sec
# optimizer time 0.000476 sec
# training time in round 92 cost 0.04280567169189453 sec
# loss 1.087497, train acc 0.585685
# round 93
# time to device 0.004083 sec
# time forward 0.001148 sec
# loss time 0.000082 sec
# backward time 0.001504 sec
# optimizer time 0.000908 sec
# training time in round 93 cost 0.04436302185058594 sec
# loss 1.082948, train acc 0.587101
# round 94
# time to device 0.004033 sec
# time forward 0.001117 sec
# loss time 0.000086 sec
# backward time 0.001229 sec
# optimizer time 0.000509 sec
# training time in round 94 cost 0.042517662048339844 sec
# loss 1.077623, train acc 0.588980
# round 95
# time to device 0.004050 sec
# time forward 0.001141 sec
# loss time 0.000088 sec
# backward time 0.001231 sec
# optimizer time 0.000495 sec
# training time in round 95 cost 0.04314827919006348 sec
# loss 1.073509, train acc 0.590413
# round 96
# time to device 0.004037 sec
# time forward 0.001057 sec
# loss time 0.000096 sec
# backward time 0.001661 sec
# optimizer time 0.001054 sec
# training time in round 96 cost 0.04432344436645508 sec
# loss 1.069057, train acc 0.591898
# round 97
# time to device 0.004035 sec
# time forward 0.001117 sec
# loss time 0.000085 sec
# backward time 0.001243 sec
# optimizer time 0.000483 sec
# training time in round 97 cost 0.04340624809265137 sec
# loss 1.064535, train acc 0.593431
# round 98
# time to device 0.003996 sec
# time forward 0.001077 sec
# loss time 0.000085 sec
# backward time 0.001197 sec
# optimizer time 0.000487 sec
# training time in round 98 cost 0.04287576675415039 sec
# loss 1.060800, train acc 0.595013
# round 99
# time to device 0.004097 sec
# time forward 0.001083 sec
# loss time 0.000087 sec
# backward time 0.001194 sec
# optimizer time 0.000668 sec
# training time in round 99 cost 0.043610334396362305 sec
# loss 1.057347, train acc 0.596016
# round 100
# time to device 0.004104 sec
# time forward 0.001105 sec
# loss time 0.000084 sec
# backward time 0.001180 sec
# optimizer time 0.000491 sec
# training time in round 100 cost 0.04267454147338867 sec
# loss 1.051770, train acc 0.598082
# round 101
# time to device 0.004055 sec
# time forward 0.001086 sec
# loss time 0.000087 sec
# backward time 0.001277 sec
# optimizer time 0.000797 sec
# training time in round 101 cost 0.043231964111328125 sec
# loss 1.047894, train acc 0.599954
# round 102
# time to device 0.004203 sec
# time forward 0.001372 sec
# loss time 0.000091 sec
# backward time 0.001929 sec
# optimizer time 0.000533 sec
# training time in round 102 cost 0.044391632080078125 sec
# loss 1.043514, train acc 0.601714
# round 103
# time to device 0.004068 sec
# time forward 0.001101 sec
# loss time 0.000087 sec
# backward time 0.001197 sec
# optimizer time 0.000507 sec
# training time in round 103 cost 0.04323720932006836 sec
# loss 1.038483, train acc 0.603741
# round 104
# time to device 0.004016 sec
# time forward 0.001042 sec
# loss time 0.000087 sec
# backward time 0.001202 sec
# optimizer time 0.000677 sec
# training time in round 104 cost 0.04291534423828125 sec
# loss 1.033768, train acc 0.605804
# round 105
# time to device 0.004081 sec
# time forward 0.001165 sec
# loss time 0.000102 sec
# backward time 0.001204 sec
# optimizer time 0.000480 sec
# training time in round 105 cost 0.04325270652770996 sec
# loss 1.028536, train acc 0.607606
# round 106
# time to device 0.004022 sec
# time forward 0.001063 sec
# loss time 0.000086 sec
# backward time 0.001239 sec
# optimizer time 0.000988 sec
# training time in round 106 cost 0.04399991035461426 sec
# loss 1.024886, train acc 0.609010
# round 107
# time to device 0.004026 sec
# time forward 0.001148 sec
# loss time 0.000084 sec
# backward time 0.001208 sec
# optimizer time 0.000961 sec
# training time in round 107 cost 0.043365478515625 sec
# loss 1.021273, train acc 0.610605
# round 108
# time to device 0.004001 sec
# time forward 0.001032 sec
# loss time 0.000083 sec
# backward time 0.001206 sec
# optimizer time 0.000485 sec
# training time in round 108 cost 0.04326128959655762 sec
# loss 1.019707, train acc 0.611525
# round 109
# time to device 0.004066 sec
# time forward 0.001122 sec
# loss time 0.000085 sec
# backward time 0.001218 sec
# optimizer time 0.000489 sec
# training time in round 109 cost 0.043206214904785156 sec
# loss 1.016645, train acc 0.612429
# round 110
# time to device 0.003980 sec
# time forward 0.001101 sec
# loss time 0.000083 sec
# backward time 0.001252 sec
# optimizer time 0.000530 sec
# training time in round 110 cost 0.04333829879760742 sec
# loss 1.013922, train acc 0.613528
# round 111
# time to device 0.004065 sec
# time forward 0.001101 sec
# loss time 0.000095 sec
# backward time 0.001215 sec
# optimizer time 0.000673 sec
# training time in round 111 cost 0.04280281066894531 sec
# loss 1.010970, train acc 0.614886
# round 112
# time to device 0.004011 sec
# time forward 0.001023 sec
# loss time 0.000084 sec
# backward time 0.001177 sec
# optimizer time 0.000506 sec
# training time in round 112 cost 0.04329681396484375 sec
# loss 1.007465, train acc 0.616289
# round 113
# time to device 0.004012 sec
# time forward 0.001096 sec
# loss time 0.000086 sec
# backward time 0.001245 sec
# optimizer time 0.000962 sec
# training time in round 113 cost 0.04326963424682617 sec
# loss 1.002945, train acc 0.618490
# round 114
# time to device 0.004049 sec
# time forward 0.001118 sec
# loss time 0.000083 sec
# backward time 0.001195 sec
# optimizer time 0.000575 sec
# training time in round 114 cost 0.04267621040344238 sec
# loss 0.999530, train acc 0.619973
# round 115
# time to device 0.004129 sec
# time forward 0.001138 sec
# loss time 0.000086 sec
# backward time 0.001292 sec
# optimizer time 0.000503 sec
# training time in round 115 cost 0.043788909912109375 sec
# loss 0.995590, train acc 0.621430
# round 116
# time to device 0.004021 sec
# time forward 0.001048 sec
# loss time 0.000086 sec
# backward time 0.001200 sec
# optimizer time 0.000993 sec
# training time in round 116 cost 0.04376626014709473 sec
# loss 0.991918, train acc 0.622730
# round 117
# time to device 0.004110 sec
# time forward 0.001060 sec
# loss time 0.000084 sec
# backward time 0.001228 sec
# optimizer time 0.000485 sec
# training time in round 117 cost 0.04347062110900879 sec
# loss 0.987989, train acc 0.624073
# round 118
# time to device 0.004010 sec
# time forward 0.001049 sec
# loss time 0.000085 sec
# backward time 0.001231 sec
# optimizer time 0.000874 sec
# training time in round 118 cost 0.04301142692565918 sec
# loss 0.983038, train acc 0.625985
# round 119
# time to device 0.004046 sec
# time forward 0.001130 sec
# loss time 0.000085 sec
# backward time 0.001215 sec
# optimizer time 0.000529 sec
# training time in round 119 cost 0.04356694221496582 sec
# loss 0.979988, train acc 0.626823
# round 120
# time to device 0.004034 sec
# time forward 0.001061 sec
# loss time 0.000087 sec
# backward time 0.001185 sec
# optimizer time 0.001088 sec
# training time in round 120 cost 0.04345440864562988 sec
# loss 0.976802, train acc 0.628357
# round 121
# time to device 0.004030 sec
# time forward 0.001071 sec
# loss time 0.000085 sec
# backward time 0.001261 sec
# optimizer time 0.000487 sec
# training time in round 121 cost 0.04305863380432129 sec
# loss 0.972736, train acc 0.630059
# round 122
# time to device 0.004001 sec
# time forward 0.001019 sec
# loss time 0.000086 sec
# backward time 0.001204 sec
# optimizer time 0.000506 sec
# training time in round 122 cost 0.042821645736694336 sec
# loss 0.969967, train acc 0.631034
# round 123
# time to device 0.004020 sec
# time forward 0.001085 sec
# loss time 0.000083 sec
# backward time 0.001172 sec
# optimizer time 0.000519 sec
# training time in round 123 cost 0.0433650016784668 sec
# loss 0.966788, train acc 0.631867
# round 124
# time to device 0.004122 sec
# time forward 0.001073 sec
# loss time 0.000084 sec
# backward time 0.001221 sec
# optimizer time 0.000500 sec
# training time in round 124 cost 0.042791128158569336 sec
# loss 0.963454, train acc 0.633062
# round 125
# time to device 0.004132 sec
# time forward 0.001099 sec
# loss time 0.000084 sec
# backward time 0.001192 sec
# optimizer time 0.000499 sec
# training time in round 125 cost 0.04303455352783203 sec
# loss 0.959964, train acc 0.634239
# round 126
# time to device 0.004070 sec
# time forward 0.001039 sec
# loss time 0.000087 sec
# backward time 0.001741 sec
# optimizer time 0.000515 sec
# training time in round 126 cost 0.043921470642089844 sec
# loss 0.956984, train acc 0.635396
# round 127
# time to device 0.004096 sec
# time forward 0.001143 sec
# loss time 0.000082 sec
# backward time 0.001207 sec
# optimizer time 0.000509 sec
# training time in round 127 cost 0.04305148124694824 sec
# loss 0.954994, train acc 0.635925
# round 128
# time to device 0.004030 sec
# time forward 0.001071 sec
# loss time 0.000086 sec
# backward time 0.001192 sec
# optimizer time 0.000513 sec
# training time in round 128 cost 0.04289054870605469 sec
# loss 0.953482, train acc 0.636567
# round 129
# time to device 0.004121 sec
# time forward 0.001181 sec
# loss time 0.000083 sec
# backward time 0.001208 sec
# optimizer time 0.000491 sec
# training time in round 129 cost 0.043350934982299805 sec
# loss 0.949213, train acc 0.638221
# round 130
# time to device 0.004006 sec
# time forward 0.001032 sec
# loss time 0.000086 sec
# backward time 0.001188 sec
# optimizer time 0.000482 sec
# training time in round 130 cost 0.04297637939453125 sec
# loss 0.945792, train acc 0.639730
# round 131
# time to device 0.004150 sec
# time forward 0.001135 sec
# loss time 0.000085 sec
# backward time 0.001212 sec
# optimizer time 0.000575 sec
# training time in round 131 cost 0.04294753074645996 sec
# loss 0.942983, train acc 0.640862
# round 132
# time to device 0.004030 sec
# time forward 0.001063 sec
# loss time 0.000093 sec
# backward time 0.001212 sec
# optimizer time 0.000876 sec
# training time in round 132 cost 0.04372906684875488 sec
# loss 0.940075, train acc 0.642152
# round 133
# time to device 0.004029 sec
# time forward 0.001049 sec
# loss time 0.000082 sec
# backward time 0.001260 sec
# optimizer time 0.000495 sec
# training time in round 133 cost 0.04331088066101074 sec
# loss 0.936411, train acc 0.643657
# round 134
# time to device 0.004043 sec
# time forward 0.001098 sec
# loss time 0.000084 sec
# backward time 0.001224 sec
# optimizer time 0.000495 sec
# training time in round 134 cost 0.0431218147277832 sec
# loss 0.933327, train acc 0.644965
# round 135
# time to device 0.004050 sec
# time forward 0.001158 sec
# loss time 0.000084 sec
# backward time 0.001183 sec
# optimizer time 0.000474 sec
# training time in round 135 cost 0.04261970520019531 sec
# loss 0.930011, train acc 0.646255
# round 136
# time to device 0.004001 sec
# time forward 0.001028 sec
# loss time 0.000085 sec
# backward time 0.001212 sec
# optimizer time 0.000506 sec
# training time in round 136 cost 0.04377126693725586 sec
# loss 0.926934, train acc 0.647411
# round 137
# time to device 0.004111 sec
# time forward 0.001101 sec
# loss time 0.000087 sec
# backward time 0.001187 sec
# optimizer time 0.000508 sec
# training time in round 137 cost 0.04277324676513672 sec
# loss 0.925189, train acc 0.648494
# round 138
# time to device 0.004029 sec
# time forward 0.001028 sec
# loss time 0.000095 sec
# backward time 0.001221 sec
# optimizer time 0.001109 sec
# training time in round 138 cost 0.04398155212402344 sec
# loss 0.922551, train acc 0.649562
# round 139
# time to device 0.004238 sec
# time forward 0.001135 sec
# loss time 0.000084 sec
# backward time 0.001237 sec
# optimizer time 0.000484 sec
# training time in round 139 cost 0.04334735870361328 sec
# loss 0.920271, train acc 0.650279
# round 140
# time to device 0.003994 sec
# time forward 0.001029 sec
# loss time 0.000093 sec
# backward time 0.001218 sec
# optimizer time 0.000488 sec
# training time in round 140 cost 0.04328513145446777 sec
# loss 0.917695, train acc 0.651042
# round 141
# time to device 0.004075 sec
# time forward 0.001114 sec
# loss time 0.000085 sec
# backward time 0.001145 sec
# optimizer time 0.000494 sec
# training time in round 141 cost 0.04262423515319824 sec
# loss 0.915699, train acc 0.652014
# round 142
# time to device 0.004027 sec
# time forward 0.001055 sec
# loss time 0.000086 sec
# backward time 0.001204 sec
# optimizer time 0.000575 sec
# training time in round 142 cost 0.043614864349365234 sec
# loss 0.912933, train acc 0.652808
# round 143
# time to device 0.004018 sec
# time forward 0.001035 sec
# loss time 0.000085 sec
# backward time 0.001220 sec
# optimizer time 0.000487 sec
# training time in round 143 cost 0.04284071922302246 sec
# loss 0.910957, train acc 0.653212
# round 144
# time to device 0.004078 sec
# time forward 0.001036 sec
# loss time 0.000086 sec
# backward time 0.001206 sec
# optimizer time 0.001120 sec
# training time in round 144 cost 0.04356575012207031 sec
# loss 0.909193, train acc 0.653556
# round 145
# time to device 0.004106 sec
# time forward 0.001043 sec
# loss time 0.000086 sec
# backward time 0.001245 sec
# optimizer time 0.000510 sec
# training time in round 145 cost 0.04295682907104492 sec
# loss 0.905881, train acc 0.654859
# round 146
# time to device 0.003982 sec
# time forward 0.001076 sec
# loss time 0.000083 sec
# backward time 0.001183 sec
# optimizer time 0.000557 sec
# training time in round 146 cost 0.04367852210998535 sec
# loss 0.903640, train acc 0.655665
# round 147
# time to device 0.004106 sec
# time forward 0.001201 sec
# loss time 0.000083 sec
# backward time 0.001230 sec
# optimizer time 0.000800 sec
# training time in round 147 cost 0.04288220405578613 sec
# loss 0.900799, train acc 0.656989
# round 148
# time to device 0.004019 sec
# time forward 0.001073 sec
# loss time 0.000085 sec
# backward time 0.001211 sec
# optimizer time 0.000474 sec
# training time in round 148 cost 0.04280900955200195 sec
# loss 0.898271, train acc 0.657980
# round 149
# time to device 0.004006 sec
# time forward 0.001073 sec
# loss time 0.000087 sec
# backward time 0.001179 sec
# optimizer time 0.000495 sec
# training time in round 149 cost 0.043931007385253906 sec
# loss 0.895730, train acc 0.658958
# round 150
# time to device 0.004129 sec
# time forward 0.001373 sec
# loss time 0.000089 sec
# backward time 0.001358 sec
# optimizer time 0.000520 sec
# training time in round 150 cost 0.04403543472290039 sec
# loss 0.892741, train acc 0.659975
# round 151
# time to device 0.004164 sec
# time forward 0.001166 sec
# loss time 0.000085 sec
# backward time 0.001205 sec
# optimizer time 0.000483 sec
# training time in round 151 cost 0.04276847839355469 sec
# loss 0.890994, train acc 0.660567
# round 152
# time to device 0.004042 sec
# time forward 0.001123 sec
# loss time 0.000086 sec
# backward time 0.001258 sec
# optimizer time 0.000520 sec
# training time in round 152 cost 0.043929100036621094 sec
# loss 0.888979, train acc 0.661152
# round 153
# time to device 0.004023 sec
# time forward 0.001109 sec
# loss time 0.000086 sec
# backward time 0.001261 sec
# optimizer time 0.000495 sec
# training time in round 153 cost 0.04295611381530762 sec
# loss 0.886182, train acc 0.661983
# round 154
# time to device 0.004041 sec
# time forward 0.001035 sec
# loss time 0.000085 sec
# backward time 0.001241 sec
# optimizer time 0.000497 sec
# training time in round 154 cost 0.04319620132446289 sec
# loss 0.883652, train acc 0.663004
# round 155
# time to device 0.004097 sec
# time forward 0.001059 sec
# loss time 0.000084 sec
# backward time 0.001182 sec
# optimizer time 0.000633 sec
# training time in round 155 cost 0.04313468933105469 sec
# loss 0.881556, train acc 0.663862
# round 156
# time to device 0.004032 sec
# time forward 0.001032 sec
# loss time 0.000086 sec
# backward time 0.001225 sec
# optimizer time 0.000881 sec
# training time in round 156 cost 0.0437161922454834 sec
# loss 0.879493, train acc 0.664709
# round 157
# time to device 0.004104 sec
# time forward 0.001116 sec
# loss time 0.000086 sec
# backward time 0.001175 sec
# optimizer time 0.000482 sec
# training time in round 157 cost 0.04268145561218262 sec
# loss 0.877511, train acc 0.665447
# round 158
# time to device 0.004031 sec
# time forward 0.001058 sec
# loss time 0.000086 sec
# backward time 0.001217 sec
# optimizer time 0.000753 sec
# training time in round 158 cost 0.04376220703125 sec
# loss 0.875264, train acc 0.666421
# round 159
# time to device 0.004230 sec
# time forward 0.001123 sec
# loss time 0.000086 sec
# backward time 0.001238 sec
# optimizer time 0.000506 sec
# training time in round 159 cost 0.043199777603149414 sec
# loss 0.872282, train acc 0.667676
# round 160
# time to device 0.003981 sec
# time forward 0.001053 sec
# loss time 0.000106 sec
# backward time 0.001214 sec
# optimizer time 0.000487 sec
# training time in round 160 cost 0.04302811622619629 sec
# loss 0.870392, train acc 0.668672
# round 161
# time to device 0.004015 sec
# time forward 0.001114 sec
# loss time 0.000084 sec
# backward time 0.001635 sec
# optimizer time 0.000497 sec
# training time in round 161 cost 0.0433354377746582 sec
# loss 0.868496, train acc 0.669271
# round 162
# time to device 0.004011 sec
# time forward 0.001037 sec
# loss time 0.000086 sec
# backward time 0.001225 sec
# optimizer time 0.000777 sec
# training time in round 162 cost 0.04399371147155762 sec
# loss 0.866681, train acc 0.670006
# round 163
# time to device 0.004074 sec
# time forward 0.001173 sec
# loss time 0.000085 sec
# backward time 0.001174 sec
# optimizer time 0.000779 sec
# training time in round 163 cost 0.042711734771728516 sec
# loss 0.864707, train acc 0.670922
# round 164
# time to device 0.004018 sec
# time forward 0.001062 sec
# loss time 0.000083 sec
# backward time 0.001599 sec
# optimizer time 0.001162 sec
# training time in round 164 cost 0.04406857490539551 sec
# loss 0.862883, train acc 0.671733
# round 165
# time to device 0.004094 sec
# time forward 0.001084 sec
# loss time 0.000087 sec
# backward time 0.001155 sec
# optimizer time 0.000514 sec
# training time in round 165 cost 0.042955875396728516 sec
# loss 0.860932, train acc 0.672299
# round 166
# time to device 0.004098 sec
# time forward 0.001274 sec
# loss time 0.000094 sec
# backward time 0.001291 sec
# optimizer time 0.000538 sec
# training time in round 166 cost 0.04363584518432617 sec
# loss 0.858647, train acc 0.673045
# round 167
# time to device 0.004081 sec
# time forward 0.001061 sec
# loss time 0.000089 sec
# backward time 0.001726 sec
# optimizer time 0.000527 sec
# training time in round 167 cost 0.043410301208496094 sec
# loss 0.856520, train acc 0.674200
# round 168
# time to device 0.004007 sec
# time forward 0.001041 sec
# loss time 0.000086 sec
# backward time 0.001220 sec
# optimizer time 0.000976 sec
# training time in round 168 cost 0.04375720024108887 sec
# loss 0.853917, train acc 0.675388
# round 169
# time to device 0.004114 sec
# time forward 0.001064 sec
# loss time 0.000086 sec
# backward time 0.001200 sec
# optimizer time 0.000493 sec
# training time in round 169 cost 0.04294443130493164 sec
# loss 0.852201, train acc 0.676057
# round 170
# time to device 0.004003 sec
# time forward 0.001034 sec
# loss time 0.000084 sec
# backward time 0.001234 sec
# optimizer time 0.000516 sec
# training time in round 170 cost 0.042574167251586914 sec
# loss 0.850320, train acc 0.676992
# round 171
# time to device 0.004026 sec
# time forward 0.001189 sec
# loss time 0.000082 sec
# backward time 0.001217 sec
# optimizer time 0.000983 sec
# training time in round 171 cost 0.04371929168701172 sec
# loss 0.848182, train acc 0.677916
# round 172
# time to device 0.004043 sec
# time forward 0.001085 sec
# loss time 0.000083 sec
# backward time 0.001270 sec
# optimizer time 0.000486 sec
# training time in round 172 cost 0.04320883750915527 sec
# loss 0.846527, train acc 0.678468
# round 173
# time to device 0.003972 sec
# time forward 0.001099 sec
# loss time 0.000084 sec
# backward time 0.001202 sec
# optimizer time 0.000506 sec
# training time in round 173 cost 0.04335761070251465 sec
# loss 0.844674, train acc 0.679059
# round 174
# time to device 0.003992 sec
# time forward 0.001061 sec
# loss time 0.000087 sec
# backward time 0.001271 sec
# optimizer time 0.000492 sec
# training time in round 174 cost 0.04276895523071289 sec
# loss 0.843047, train acc 0.679777
# round 175
# time to device 0.004067 sec
# time forward 0.001141 sec
# loss time 0.000083 sec
# backward time 0.001169 sec
# optimizer time 0.000489 sec
# training time in round 175 cost 0.04348421096801758 sec
# loss 0.841387, train acc 0.680309
# round 176
# time to device 0.004034 sec
# time forward 0.001045 sec
# loss time 0.000084 sec
# backward time 0.001249 sec
# optimizer time 0.000879 sec
# training time in round 176 cost 0.043272972106933594 sec
# loss 0.839136, train acc 0.681056
# round 177
# time to device 0.004122 sec
# time forward 0.001163 sec
# loss time 0.000086 sec
# backward time 0.001245 sec
# optimizer time 0.000521 sec
# training time in round 177 cost 0.0430605411529541 sec
# loss 0.837129, train acc 0.681838
# round 178
# time to device 0.004008 sec
# time forward 0.001027 sec
# loss time 0.000084 sec
# backward time 0.001194 sec
# optimizer time 0.000901 sec
# training time in round 178 cost 0.043650150299072266 sec
# loss 0.835556, train acc 0.682699
# round 179
# time to device 0.004083 sec
# time forward 0.001124 sec
# loss time 0.000087 sec
# backward time 0.001272 sec
# optimizer time 0.000485 sec
# training time in round 179 cost 0.042304277420043945 sec
# loss 0.833708, train acc 0.683290
# round 180
# time to device 0.003976 sec
# time forward 0.001019 sec
# loss time 0.000083 sec
# backward time 0.001208 sec
# optimizer time 0.000674 sec
# training time in round 180 cost 0.04329252243041992 sec
# loss 0.830764, train acc 0.684306
# round 181
# time to device 0.004208 sec
# time forward 0.001104 sec
# loss time 0.000100 sec
# backward time 0.001253 sec
# optimizer time 0.000492 sec
# training time in round 181 cost 0.04277515411376953 sec
# loss 0.828418, train acc 0.685440
# round 182
# time to device 0.004056 sec
# time forward 0.001117 sec
# loss time 0.000084 sec
# backward time 0.001686 sec
# optimizer time 0.000492 sec
# training time in round 182 cost 0.04413342475891113 sec
# loss 0.825916, train acc 0.686390
# round 183
# time to device 0.004146 sec
# time forward 0.001164 sec
# loss time 0.000086 sec
# backward time 0.001190 sec
# optimizer time 0.000482 sec
# training time in round 183 cost 0.04280662536621094 sec
# loss 0.824784, train acc 0.686948
# round 184
# time to device 0.004000 sec
# time forward 0.001030 sec
# loss time 0.000085 sec
# backward time 0.001876 sec
# optimizer time 0.000911 sec
# training time in round 184 cost 0.04431462287902832 sec
# loss 0.822077, train acc 0.688007
# round 185
# time to device 0.004079 sec
# time forward 0.001181 sec
# loss time 0.000084 sec
# backward time 0.001630 sec
# optimizer time 0.000520 sec
# training time in round 185 cost 0.04406237602233887 sec
# loss 0.820305, train acc 0.688970
# round 186
# time to device 0.004067 sec
# time forward 0.001073 sec
# loss time 0.000088 sec
# backward time 0.001216 sec
# optimizer time 0.000563 sec
# training time in round 186 cost 0.043111562728881836 sec
# loss 0.818810, train acc 0.689631
# round 187
# time to device 0.004063 sec
# time forward 0.001096 sec
# loss time 0.000086 sec
# backward time 0.001186 sec
# optimizer time 0.000483 sec
# training time in round 187 cost 0.04306483268737793 sec
# loss 0.816686, train acc 0.690326
# round 188
# time to device 0.004064 sec
# time forward 0.001046 sec
# loss time 0.000087 sec
# backward time 0.001182 sec
# optimizer time 0.000477 sec
# training time in round 188 cost 0.043001651763916016 sec
# loss 0.815090, train acc 0.690683
# round 189
# time to device 0.004097 sec
# time forward 0.001082 sec
# loss time 0.000084 sec
# backward time 0.001419 sec
# optimizer time 0.000543 sec
# training time in round 189 cost 0.04364585876464844 sec
# loss 0.813499, train acc 0.691160
# round 190
# time to device 0.004203 sec
# time forward 0.001077 sec
# loss time 0.000083 sec
# backward time 0.001178 sec
# optimizer time 0.000479 sec
# training time in round 190 cost 0.04277515411376953 sec
# loss 0.811598, train acc 0.691754
# round 191
# time to device 0.004131 sec
# time forward 0.001079 sec
# loss time 0.000086 sec
# backward time 0.001236 sec
# optimizer time 0.000496 sec
# training time in round 191 cost 0.04357409477233887 sec
# loss 0.809510, train acc 0.692505
# round 192
# time to device 0.004102 sec
# time forward 0.001053 sec
# loss time 0.000087 sec
# backward time 0.001206 sec
# optimizer time 0.000480 sec
# training time in round 192 cost 0.04300498962402344 sec
# loss 0.807839, train acc 0.693167
# round 193
# time to device 0.004143 sec
# time forward 0.001072 sec
# loss time 0.000085 sec
# backward time 0.001234 sec
# optimizer time 0.000506 sec
# training time in round 193 cost 0.0431208610534668 sec
# loss 0.806006, train acc 0.693782
# round 194
# time to device 0.004042 sec
# time forward 0.001064 sec
# loss time 0.000083 sec
# backward time 0.001222 sec
# optimizer time 0.000515 sec
# training time in round 194 cost 0.043219804763793945 sec
# loss 0.804682, train acc 0.694511
# round 195
# time to device 0.004056 sec
# time forward 0.001155 sec
# loss time 0.000084 sec
# backward time 0.001209 sec
# optimizer time 0.000485 sec
# training time in round 195 cost 0.04348158836364746 sec
# loss 0.802938, train acc 0.695233
# round 196
# time to device 0.004027 sec
# time forward 0.001036 sec
# loss time 0.000085 sec
# backward time 0.001196 sec
# optimizer time 0.000520 sec
# training time in round 196 cost 0.042687416076660156 sec
# loss 0.800968, train acc 0.696026
# round 197
# time to device 0.004025 sec
# time forward 0.001025 sec
# loss time 0.000086 sec
# backward time 0.001547 sec
# optimizer time 0.000521 sec
# training time in round 197 cost 0.043386220932006836 sec
# loss 0.799992, train acc 0.696575
# round 198
# time to device 0.004083 sec
# time forward 0.001429 sec
# loss time 0.000106 sec
# backward time 0.001459 sec
# optimizer time 0.000527 sec
# training time in round 198 cost 0.043710947036743164 sec
# loss 0.799008, train acc 0.696922
# round 199
# time to device 0.004134 sec
# time forward 0.001171 sec
# loss time 0.000087 sec
# backward time 0.001242 sec
# optimizer time 0.000508 sec
# training time in round 199 cost 0.04320693016052246 sec
# loss 0.797668, train acc 0.697461
# round 200
# time to device 0.004019 sec
# time forward 0.001066 sec
# loss time 0.000084 sec
# backward time 0.001210 sec
# optimizer time 0.000490 sec
# training time in round 200 cost 0.04295611381530762 sec
# loss 0.796262, train acc 0.697800
# round 201
# time to device 0.004044 sec
# time forward 0.001152 sec
# loss time 0.000086 sec
# backward time 0.001227 sec
# optimizer time 0.000482 sec
# training time in round 201 cost 0.04419827461242676 sec
# loss 0.794588, train acc 0.698368
# round 202
# time to device 0.004029 sec
# time forward 0.001052 sec
# loss time 0.000084 sec
# backward time 0.001211 sec
# optimizer time 0.000483 sec
# training time in round 202 cost 0.042449951171875 sec
# loss 0.793312, train acc 0.698776
# round 203
# time to device 0.004035 sec
# time forward 0.001105 sec
# loss time 0.000091 sec
# backward time 0.002018 sec
# optimizer time 0.000921 sec
# training time in round 203 cost 0.04461669921875 sec
# loss 0.791805, train acc 0.699449
# round 204
# time to device 0.004052 sec
# time forward 0.001050 sec
# loss time 0.000086 sec
# backward time 0.001175 sec
# optimizer time 0.000499 sec
# training time in round 204 cost 0.04340839385986328 sec
# loss 0.790138, train acc 0.700152
# round 205
# time to device 0.004071 sec
# time forward 0.001156 sec
# loss time 0.000086 sec
# backward time 0.001230 sec
# optimizer time 0.000512 sec
# training time in round 205 cost 0.042987823486328125 sec
# loss 0.788528, train acc 0.700887
# round 206
# time to device 0.004014 sec
# time forward 0.001062 sec
# loss time 0.000085 sec
# backward time 0.001204 sec
# optimizer time 0.000502 sec
# training time in round 206 cost 0.043073177337646484 sec
# loss 0.786874, train acc 0.701578
# round 207
# time to device 0.003992 sec
# time forward 0.001154 sec
# loss time 0.000083 sec
# backward time 0.001187 sec
# ...
# loss time 0.000201 sec
# backward time 0.001242 sec
# optimizer time 0.000502 sec
# training time in round 400 cost 0.04442429542541504 sec
# loss 0.091223, train acc 0.966899
# round 401
# time to device 0.004066 sec
# time forward 0.001156 sec
# loss time 0.000087 sec
# backward time 0.001253 sec
# optimizer time 0.000562 sec
# training time in round 401 cost 0.043791770935058594 sec
# loss 0.091390, train acc 0.966845
# round 402
# time to device 0.004091 sec
# time forward 0.001126 sec
# loss time 0.000197 sec
# backward time 0.001156 sec
# optimizer time 0.000505 sec
# training time in round 402 cost 0.04383397102355957 sec
# loss 0.091314, train acc 0.966850
# round 403
# time to device 0.004045 sec
# time forward 0.001109 sec
# loss time 0.000088 sec
# backward time 0.001256 sec
# optimizer time 0.000531 sec
# training time in round 403 cost 0.04308152198791504 sec
# loss 0.091482, train acc 0.966816
# round 404
# time to device 0.004041 sec
# time forward 0.001140 sec
# loss time 0.000198 sec
# backward time 0.001259 sec
# optimizer time 0.000494 sec
# training time in round 404 cost 0.04463005065917969 sec
# loss 0.091619, train acc 0.966802
# round 405
# time to device 0.004072 sec
# time forward 0.001171 sec
# loss time 0.000086 sec
# backward time 0.001265 sec
# optimizer time 0.001039 sec
# training time in round 405 cost 0.044687747955322266 sec
# loss 0.091757, train acc 0.966749
# round 406
# time to device 0.004086 sec
# time forward 0.001187 sec
# loss time 0.000211 sec
# backward time 0.001242 sec
# optimizer time 0.000520 sec
# training time in round 406 cost 0.04420971870422363 sec
# loss 0.091737, train acc 0.966734
# round 407
# time to device 0.004068 sec
# time forward 0.001190 sec
# loss time 0.000128 sec
# backward time 0.001392 sec
# optimizer time 0.000722 sec
# training time in round 407 cost 0.044489383697509766 sec
# loss 0.091776, train acc 0.966759
# round 408
# time to device 0.004489 sec
# time forward 0.002289 sec
# loss time 0.000208 sec
# backward time 0.001345 sec
# optimizer time 0.000549 sec
# training time in round 408 cost 0.04655933380126953 sec
# loss 0.091870, train acc 0.966744
# round 409
# time to device 0.004878 sec
# time forward 0.002266 sec
# loss time 0.000123 sec
# backward time 0.001470 sec
# optimizer time 0.000619 sec
# training time in round 409 cost 0.04662442207336426 sec
# loss 0.091728, train acc 0.966806
# round 410
# time to device 0.004088 sec
# time forward 0.001148 sec
# loss time 0.000208 sec
# backward time 0.001194 sec
# optimizer time 0.000492 sec
# training time in round 410 cost 0.04430985450744629 sec
# loss 0.091621, train acc 0.966830
# round 411
# time to device 0.004029 sec
# time forward 0.001085 sec
# loss time 0.000090 sec
# backward time 0.001210 sec
# optimizer time 0.000510 sec
# training time in round 411 cost 0.04439806938171387 sec
# loss 0.091739, train acc 0.966778
# round 412
# time to device 0.004063 sec
# time forward 0.001230 sec
# loss time 0.000195 sec
# backward time 0.001650 sec
# optimizer time 0.001056 sec
# training time in round 412 cost 0.04494142532348633 sec
# loss 0.091765, train acc 0.966745
# round 413
# time to device 0.004053 sec
# time forward 0.001182 sec
# loss time 0.000086 sec
# backward time 0.001275 sec
# optimizer time 0.000830 sec
# training time in round 413 cost 0.04449629783630371 sec
# loss 0.091672, train acc 0.966806
# round 414
# time to device 0.004069 sec
# time forward 0.001162 sec
# loss time 0.000204 sec
# backward time 0.001337 sec
# optimizer time 0.000503 sec
# training time in round 414 cost 0.04380965232849121 sec
# loss 0.091693, train acc 0.966792
# round 415
# time to device 0.004033 sec
# time forward 0.001092 sec
# loss time 0.000090 sec
# backward time 0.001261 sec
# optimizer time 0.000512 sec
# training time in round 415 cost 0.04343867301940918 sec
# loss 0.091747, train acc 0.966759
# round 416
# time to device 0.004059 sec
# time forward 0.001216 sec
# loss time 0.000192 sec
# backward time 0.001433 sec
# optimizer time 0.000951 sec
# training time in round 416 cost 0.04486870765686035 sec
# loss 0.091786, train acc 0.966745
# round 417
# time to device 0.004039 sec
# time forward 0.001131 sec
# loss time 0.000091 sec
# backward time 0.001274 sec
# optimizer time 0.000499 sec
# training time in round 417 cost 0.04418444633483887 sec
# loss 0.091703, train acc 0.966750
# round 418
# time to device 0.004128 sec
# time forward 0.001184 sec
# loss time 0.000197 sec
# backward time 0.001211 sec
# optimizer time 0.000483 sec
# training time in round 418 cost 0.044867753982543945 sec
# loss 0.091704, train acc 0.966718
# round 419
# time to device 0.004108 sec
# time forward 0.001124 sec
# loss time 0.000089 sec
# backward time 0.001207 sec
# optimizer time 0.000506 sec
# training time in round 419 cost 0.04371309280395508 sec
# loss 0.091823, train acc 0.966648
# round 420
# time to device 0.004056 sec
# time forward 0.001162 sec
# loss time 0.000199 sec
# backward time 0.001222 sec
# optimizer time 0.000510 sec
# training time in round 420 cost 0.044088125228881836 sec
# loss 0.091807, train acc 0.966616
# round 421
# time to device 0.004085 sec
# time forward 0.001185 sec
# loss time 0.000087 sec
# backward time 0.001395 sec
# optimizer time 0.000587 sec
# training time in round 421 cost 0.0438077449798584 sec
# loss 0.091711, train acc 0.966677
# round 422
# time to device 0.004050 sec
# time forward 0.001240 sec
# loss time 0.000207 sec
# backward time 0.001277 sec
# optimizer time 0.000528 sec
# training time in round 422 cost 0.04366016387939453 sec
# loss 0.092064, train acc 0.966534
# round 423
# time to device 0.004120 sec
# time forward 0.001075 sec
# loss time 0.000088 sec
# backward time 0.001160 sec
# optimizer time 0.000494 sec
# training time in round 423 cost 0.04466700553894043 sec
# loss 0.092085, train acc 0.966520
# round 424
# time to device 0.004057 sec
# time forward 0.001119 sec
# loss time 0.000237 sec
# backward time 0.001236 sec
# optimizer time 0.000502 sec
# training time in round 424 cost 0.04357290267944336 sec
# loss 0.092178, train acc 0.966489
# round 425
# time to device 0.004033 sec
# time forward 0.001168 sec
# loss time 0.000087 sec
# backward time 0.001372 sec
# optimizer time 0.000508 sec
# training time in round 425 cost 0.04441642761230469 sec
# loss 0.092028, train acc 0.966549
# round 426
# time to device 0.004067 sec
# time forward 0.001091 sec
# loss time 0.000199 sec
# backward time 0.001193 sec
# optimizer time 0.000533 sec
# training time in round 426 cost 0.04377388954162598 sec
# loss 0.091881, train acc 0.966591
# round 427
# time to device 0.004158 sec
# time forward 0.001099 sec
# loss time 0.000087 sec
# backward time 0.001423 sec
# optimizer time 0.000514 sec
# training time in round 427 cost 0.04375910758972168 sec
# loss 0.091782, train acc 0.966614
# round 428
# time to device 0.004050 sec
# time forward 0.001108 sec
# loss time 0.000196 sec
# backward time 0.001220 sec
# optimizer time 0.001086 sec
# training time in round 428 cost 0.0443117618560791 sec
# loss 0.091797, train acc 0.966565
# round 429
# time to device 0.004061 sec
# time forward 0.001135 sec
# loss time 0.000088 sec
# backward time 0.001327 sec
# optimizer time 0.000712 sec
# training time in round 429 cost 0.04446697235107422 sec
# loss 0.091698, train acc 0.966624
# round 430
# time to device 0.004041 sec
# time forward 0.001154 sec
# loss time 0.000208 sec
# backward time 0.001235 sec
# optimizer time 0.000530 sec
# training time in round 430 cost 0.04439878463745117 sec
# loss 0.091726, train acc 0.966629
# round 431
# time to device 0.004105 sec
# time forward 0.001079 sec
# loss time 0.000088 sec
# backward time 0.001218 sec
# optimizer time 0.000510 sec
# training time in round 431 cost 0.043654680252075195 sec
# loss 0.091832, train acc 0.966598
# round 432
# time to device 0.004066 sec
# time forward 0.001263 sec
# loss time 0.000200 sec
# backward time 0.001223 sec
# optimizer time 0.000503 sec
# training time in round 432 cost 0.04369974136352539 sec
# loss 0.091870, train acc 0.966567
# round 433
# time to device 0.004037 sec
# time forward 0.001198 sec
# loss time 0.000088 sec
# backward time 0.001658 sec
# optimizer time 0.001070 sec
# training time in round 433 cost 0.04470109939575195 sec
# loss 0.091786, train acc 0.966590
# round 434
# time to device 0.004012 sec
# time forward 0.001159 sec
# loss time 0.000203 sec
# backward time 0.001230 sec
# optimizer time 0.000519 sec
# training time in round 434 cost 0.04448127746582031 sec
# loss 0.091863, train acc 0.966541
# round 435
# time to device 0.004098 sec
# time forward 0.001099 sec
# loss time 0.000089 sec
# backward time 0.001319 sec
# optimizer time 0.000500 sec
# training time in round 435 cost 0.0447850227355957 sec
# loss 0.091899, train acc 0.966528
# round 436
# time to device 0.004125 sec
# time forward 0.001125 sec
# loss time 0.000223 sec
# backward time 0.001136 sec
# optimizer time 0.000494 sec
# training time in round 436 cost 0.04387259483337402 sec
# loss 0.091832, train acc 0.966533
# round 437
# time to device 0.004056 sec
# time forward 0.001197 sec
# loss time 0.000085 sec
# backward time 0.001353 sec
# optimizer time 0.000507 sec
# training time in round 437 cost 0.044112443923950195 sec
# loss 0.091814, train acc 0.966538
# round 438
# time to device 0.004045 sec
# time forward 0.001157 sec
# loss time 0.000088 sec
# backward time 0.001348 sec
# optimizer time 0.000563 sec
# training time in round 438 cost 0.04395866394042969 sec
# loss 0.091725, train acc 0.966561
# round 439
# time to device 0.004043 sec
# time forward 0.001097 sec
# loss time 0.000087 sec
# backward time 0.001243 sec
# optimizer time 0.000505 sec
# training time in round 439 cost 0.04333019256591797 sec
# loss 0.091863, train acc 0.966548
# round 440
# time to device 0.004051 sec
# time forward 0.001113 sec
# loss time 0.000214 sec
# backward time 0.001197 sec
# optimizer time 0.000488 sec
# training time in round 440 cost 0.04458451271057129 sec
# loss 0.092025, train acc 0.966500
# round 441
# time to device 0.004076 sec
# time forward 0.001140 sec
# loss time 0.000087 sec
# backward time 0.001298 sec
# optimizer time 0.000494 sec
# training time in round 441 cost 0.04417300224304199 sec
# loss 0.091929, train acc 0.966523
# round 442
# time to device 0.004027 sec
# time forward 0.001105 sec
# loss time 0.000198 sec
# backward time 0.001220 sec
# optimizer time 0.000536 sec
# training time in round 442 cost 0.044745683670043945 sec
# loss 0.091826, train acc 0.966546
# round 443
# time to device 0.004032 sec
# time forward 0.001118 sec
# loss time 0.000088 sec
# backward time 0.001258 sec
# optimizer time 0.000537 sec
# training time in round 443 cost 0.04392409324645996 sec
# loss 0.091845, train acc 0.966533
# round 444
# time to device 0.004063 sec
# time forward 0.001124 sec
# loss time 0.000194 sec
# backward time 0.001131 sec
# optimizer time 0.000500 sec
# training time in round 444 cost 0.04385066032409668 sec
# loss 0.091857, train acc 0.966538
# round 445
# time to device 0.004138 sec
# time forward 0.001196 sec
# loss time 0.000085 sec
# backward time 0.001602 sec
# optimizer time 0.000519 sec
# training time in round 445 cost 0.044045448303222656 sec
# loss 0.091970, train acc 0.966508
# round 446
# time to device 0.004066 sec
# time forward 0.001132 sec
# loss time 0.000222 sec
# backward time 0.001193 sec
# optimizer time 0.000484 sec
# training time in round 446 cost 0.04339408874511719 sec
# loss 0.091906, train acc 0.966530
# round 447
# time to device 0.004023 sec
# time forward 0.001168 sec
# loss time 0.000088 sec
# backward time 0.001230 sec
# optimizer time 0.000539 sec
# training time in round 447 cost 0.04434037208557129 sec
# loss 0.091956, train acc 0.966535
# round 448
# time to device 0.004060 sec
# time forward 0.001136 sec
# loss time 0.000200 sec
# backward time 0.001238 sec
# optimizer time 0.000517 sec
# training time in round 448 cost 0.0442042350769043 sec
# loss 0.091835, train acc 0.966575
# round 449
# time to device 0.004047 sec
# time forward 0.001314 sec
# loss time 0.000090 sec
# backward time 0.001219 sec
# optimizer time 0.000521 sec
# training time in round 449 cost 0.04472994804382324 sec
# loss 0.091906, train acc 0.966528
# round 450
# time to device 0.004057 sec
# time forward 0.001099 sec
# loss time 0.000247 sec
# backward time 0.001270 sec
# optimizer time 0.000519 sec
# training time in round 450 cost 0.04424595832824707 sec
# loss 0.091951, train acc 0.966515
# round 451
# time to device 0.004047 sec
# time forward 0.001115 sec
# loss time 0.000089 sec
# backward time 0.001185 sec
# optimizer time 0.000530 sec
# training time in round 451 cost 0.04337310791015625 sec
# loss 0.091913, train acc 0.966486
# round 452
# time to device 0.004084 sec
# time forward 0.001178 sec
# loss time 0.000205 sec
# backward time 0.001278 sec
# optimizer time 0.000511 sec
# training time in round 452 cost 0.0440983772277832 sec
# loss 0.092178, train acc 0.966439
# round 453
# time to device 0.004057 sec
# time forward 0.001170 sec
# loss time 0.000098 sec
# backward time 0.001267 sec
# optimizer time 0.000507 sec
# training time in round 453 cost 0.043802738189697266 sec
# loss 0.092078, train acc 0.966461
# round 454
# time to device 0.004097 sec
# time forward 0.001103 sec
# loss time 0.000230 sec
# backward time 0.001225 sec
# optimizer time 0.000500 sec
# training time in round 454 cost 0.04490089416503906 sec
# loss 0.092137, train acc 0.966449
# round 455
# time to device 0.004048 sec
# time forward 0.001207 sec
# loss time 0.000102 sec
# backward time 0.001262 sec
# optimizer time 0.000505 sec
# training time in round 455 cost 0.04401803016662598 sec
# loss 0.092017, train acc 0.966488
# round 456
# time to device 0.004066 sec
# time forward 0.001180 sec
# loss time 0.000189 sec
# backward time 0.001761 sec
# optimizer time 0.001255 sec
# training time in round 456 cost 0.045327186584472656 sec
# loss 0.092032, train acc 0.966476
# round 457
# time to device 0.003999 sec
# time forward 0.001158 sec
# loss time 0.000089 sec
# backward time 0.001249 sec
# optimizer time 0.001019 sec
# training time in round 457 cost 0.04430580139160156 sec
# loss 0.091948, train acc 0.966498
# round 458
# time to device 0.004051 sec
# time forward 0.001150 sec
# loss time 0.000204 sec
# backward time 0.001279 sec
# optimizer time 0.000506 sec
# training time in round 458 cost 0.04330730438232422 sec
# loss 0.091902, train acc 0.966503
# round 459
# time to device 0.004011 sec
# time forward 0.001124 sec
# loss time 0.000091 sec
# backward time 0.001229 sec
# optimizer time 0.000565 sec
# training time in round 459 cost 0.044487714767456055 sec
# loss 0.091951, train acc 0.966474
# round 460
# time to device 0.004088 sec
# time forward 0.001110 sec
# loss time 0.000139 sec
# backward time 0.001213 sec
# optimizer time 0.000477 sec
# training time in round 460 cost 0.04389476776123047 sec
# loss 0.091910, train acc 0.966513
# round 461
# time to device 0.003978 sec
# time forward 0.000931 sec
# loss time 0.000080 sec
# backward time 0.001220 sec
# optimizer time 0.000498 sec
# training time in round 461 cost 0.043633222579956055 sec
# loss 0.091729, train acc 0.966585
# round 462
# time to device 0.003995 sec
# time forward 0.000965 sec
# loss time 0.000156 sec
# backward time 0.001163 sec
# optimizer time 0.000481 sec
# training time in round 462 cost 0.043752431869506836 sec
# loss 0.091589, train acc 0.966641
# round 463
# time to device 0.004001 sec
# time forward 0.000964 sec
# loss time 0.000081 sec
# backward time 0.001229 sec
# optimizer time 0.000498 sec
# training time in round 463 cost 0.04300642013549805 sec
# loss 0.091765, train acc 0.966612
# round 464
# time to device 0.003955 sec
# time forward 0.001002 sec
# loss time 0.000178 sec
# backward time 0.001149 sec
# optimizer time 0.000502 sec
# training time in round 464 cost 0.04407548904418945 sec
# loss 0.091737, train acc 0.966583
# round 465
# time to device 0.003953 sec
# time forward 0.000939 sec
# loss time 0.000080 sec
# backward time 0.001192 sec
# optimizer time 0.000518 sec
# training time in round 465 cost 0.043842315673828125 sec
# loss 0.091719, train acc 0.966587
# round 466
# time to device 0.004002 sec
# time forward 0.000976 sec
# loss time 0.000091 sec
# backward time 0.001380 sec
# optimizer time 0.000534 sec
# training time in round 466 cost 0.043689727783203125 sec
# loss 0.091680, train acc 0.966575
# round 467
# time to device 0.003969 sec
# time forward 0.000946 sec
# loss time 0.000080 sec
# backward time 0.001183 sec
# optimizer time 0.000475 sec
# training time in round 467 cost 0.04356837272644043 sec
# loss 0.091716, train acc 0.966546
# round 468
# time to device 0.003010 sec
# time forward 0.001030 sec
# loss time 0.000153 sec
# backward time 0.001390 sec
# optimizer time 0.000483 sec
# training time in round 468 cost 0.03425765037536621 sec
# loss 0.091813, train acc 0.966500
# test acc is 0.915300

# %%
time_forward = timeenergy_data_forward[:,:,0]
time_round = timeenergy_data_round[:,:,0]
test_acc = acc_data

# %%
time_data_epoch

time_epoch = np.zeros((time_data_epoch.shape[0], time_data_epoch.shape[1]))
for i in range(len(time_data_epoch[:,0])):
    if i == 0:
        time_epoch[i,0] = time_data_epoch[i,0]
        time_epoch[i,1] = time_data_epoch[i,1]
    else:
        time_epoch[i,0] = time_data_epoch[i,0]
        time_epoch[i,1] = time_data_epoch[i,1] - time_data_epoch[i-1,1]
time_epoch
# Out:
# array([[ 1.        , 53.316113  ],
#        [ 2.        , 53.41226625],
#        [ 3.        , 53.63434768],
#        [ 4.        , 53.73032928],
#        [ 5.        , 53.72700596],
#        [ 6.        , 53.76467514],
#        [ 7.        , 53.82761407],
#        [ 8.        , 53.85618567],
#        [ 9.        , 53.94939947],
#        [10.        , 53.93382478],
#        [11.        , 53.88861251],
#        [12.        , 53.88462758],
#        [13.        , 53.92338061],
#        [14.        , 53.9100914 ],
#        [15.        , 53.89397073],
#        [16.        , 53.88452983],
#        [17.        , 53.87999463],
#        [18.        , 53.87740397],
#        [19.        , 53.86002016],
#        [20.        , 53.86129475]])

# %%
import os
working_dir = os.getcwd()
working_dir

# find out the parent directory
parent_dir1 = os.path.dirname(working_dir)
print(parent_dir1)

parent_dir2 = os.path.dirname(parent_dir1)
print(parent_dir2)

parent_dir3 = os.path.dirname(parent_dir2)
print(parent_dir3)

data_folder = os.path.join(parent_dir3, 'data')
print(data_folder)
# Out:
# /home/yj/FinalThesis/GreenAI/Alexnet_linux/code/nvidia-smi
# /home/yj/FinalThesis/GreenAI/Alexnet_linux/code
# /home/yj/FinalThesis/GreenAI/Alexnet_linux
# /home/yj/FinalThesis/GreenAI/Alexnet_linux/data

# %%
# find the second_part folder
second_part_dir = os.path.join(data_folder, 'epoch_20ADAM_GPU')
second_part_dir
# Out:
# '/home/yj/FinalThesis/GreenAI/Alexnet_linux/data/epoch_20ADAM_GPU'

# %%
# save the data as .npy file
np.save(os.path.join(second_part_dir, 'time_forward.npy'), time_forward)
np.save(os.path.join(second_part_dir, 'time_round.npy'), time_round)
np.save(os.path.join(second_part_dir, 'test_acc.npy'), test_acc)
np.save(os.path.join(second_part_dir, 'train_acc.npy'), train_acc)
np.save(os.path.join(second_part_dir, 'train_l.npy'), train_l)
np.save(os.path.join(second_part_dir, 'time_epoch.npy'), time_epoch)
np.save(os.path.join(second_part_dir, 'energy_epoch.npy'), energy_data_epoch)
