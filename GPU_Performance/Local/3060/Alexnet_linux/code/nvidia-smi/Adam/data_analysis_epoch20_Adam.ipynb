# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
working_dir = os.getcwd()
print(working_dir)
# find the parent directory
parent_dir1 = os.path.dirname(working_dir)
print(parent_dir1)

parent_dir2 = os.path.dirname(parent_dir1)
print(parent_dir2)

parent_dir3 = os.path.dirname(parent_dir2)
print(parent_dir3)

data_folder = parent_dir3 + '/data'
print(data_folder)

folder_path = os.path.join(data_folder, 'epoch_20ADAM_GPU')
print(folder_path)

# Load data
test_acc = np.load(os.path.join(folder_path, 'test_acc.npy'), allow_pickle=True)
train_acc = np.load(os.path.join(folder_path, 'train_acc.npy'), allow_pickle=True)
train_loss = np.load(os.path.join(folder_path, 'train_l.npy'), allow_pickle=True)
time_forward = np.load(os.path.join(folder_path, 'time_forward.npy'), allow_pickle=True)
time_round = np.load(os.path.join(folder_path, 'time_round.npy'), allow_pickle=True)
time_epoch = np.load(os.path.join(folder_path, 'time_epoch.npy'), allow_pickle=True)
energy_epoch = np.load(os.path.join(folder_path, 'energy_epoch.npy'), allow_pickle=True)

print('Test accuracy: ', test_acc)
print('Train accuracy: ', train_acc)
print('Test loss: ', train_loss)
print('Time forward: ', time_forward)
print('Time round: ', time_round)
print('Time epoch: ', time_epoch)
print('Energy epoch: ', energy_epoch)
# Out:
# /home/yj/FinalThesis/GreenAI/Alexnet_linux/code/nvidia-smi/Adam
# /home/yj/FinalThesis/GreenAI/Alexnet_linux/code/nvidia-smi
# /home/yj/FinalThesis/GreenAI/Alexnet_linux/code
# /home/yj/FinalThesis/GreenAI/Alexnet_linux
# /home/yj/FinalThesis/GreenAI/Alexnet_linux/data
# /home/yj/FinalThesis/GreenAI/Alexnet_linux/data/epoch_20ADAM_GPU
# Test accuracy:  [0.8696 0.8835 0.8985 0.9037 0.9079 0.9073 0.9134 0.9181 0.9186 0.9192
#  0.9186 0.9171 0.9186 0.9127 0.9187 0.919  0.9169 0.9221 0.9206 0.9153]
# Train accuracy:  [[0.078125   0.0859375  0.10416667 ... 0.7857334  0.78595753 0.7861    ]
#  [0.9140625  0.86328125 0.8671875  ... 0.8810894  0.88117655 0.88123333]
#  [0.875      0.8671875  0.87239583 ... 0.89798581 0.89798678 0.89803333]
#  ...
#  [0.953125   0.95703125 0.953125   ... 0.96430005 0.96429287 0.96431667]
#  [0.9609375  0.96484375 0.97395833 ... 0.9626606  0.96264022 0.9626    ]
#  [0.9453125  0.94140625 0.953125   ... 0.96657521 0.96654647 0.9665    ]]
# Test loss:  [[2.30522966 2.93265128 2.72545775 ... 0.57018693 0.56967219 0.5693207 ]
#  [0.26748306 0.38222803 0.36656569 ... 0.319637   0.31943918 0.31929984]
#  [0.30226493 0.32277453 0.33872937 ... 0.27296238 0.27296434 0.27283206]
#  ...
#  [0.09188909 0.09175788 0.11833196 ... 0.10071792 0.10079162 0.10076559]
#  [0.12185348 0.11239269 0.08301188 ... 0.10616133 0.10616612 0.10627072]
#  [0.13560911 0.14679348 0.11629451 ... 0.09167993 0.09171589 0.09181312]]
# Time forward:  [[0.43118405 0.09790564 0.04874754 0.08265638 0.04106379 0.00896788]
#  [0.27787447 0.09005117 0.04867864 0.08026171 0.0373137  0.00931835]
#  [0.26992869 0.0875957  0.0470438  0.07996297 0.03680992 0.00927281]
#  [0.28863502 0.09253216 0.05104017 0.08050323 0.03708982 0.00948715]
#  [0.2702148  0.08758473 0.04783082 0.08077788 0.0369103  0.00929165]
#  [0.27009749 0.0865202  0.04741383 0.07958007 0.03696704 0.00930524]
#  [0.26432252 0.08522773 0.04683423 0.07988334 0.03693771 0.0091536 ]
#  [0.27195168 0.08717895 0.04793525 0.08165646 0.03731203 0.00941253]
#  [0.26734233 0.0851016  0.04715371 0.08024979 0.03709435 0.00939631]
#  [0.26913381 0.08484817 0.04746318 0.07986474 0.03697371 0.00901699]
#  [0.2684691  0.08543181 0.04745507 0.08026934 0.0371182  0.00928926]
#  [0.26781774 0.08513832 0.04741955 0.08042526 0.03704548 0.00935841]
#  [0.26644945 0.0852983  0.04686689 0.07990837 0.03668261 0.00939703]
#  [0.27312732 0.08817124 0.04851484 0.08064914 0.0372107  0.00935578]
#  [0.2722621  0.08672023 0.04785037 0.08062339 0.03728127 0.00936985]
#  [0.26968718 0.08532572 0.04778743 0.08016682 0.03701043 0.00926661]
#  [0.27140951 0.0871315  0.0482161  0.08023787 0.03714919 0.00940418]
#  [0.27257681 0.08712006 0.04779291 0.08106518 0.03688884 0.00942516]
#  [0.26805067 0.08644605 0.04721427 0.08041072 0.03672528 0.00923753]
#  [0.27301073 0.08736849 0.0477581  0.08026743 0.0371666  0.00949454]]
# Time round:  [[1.92343235 0.71052527 0.0600276  0.72826648 0.34584236 2.87415218]
#  [1.93523598 0.54349804 0.0668335  0.60229659 0.30693626 2.86535501]
#  [1.92771816 0.5306139  0.06757498 0.60949421 0.31488466 2.88899827]
#  [1.94030166 0.55928755 0.06693077 0.59849048 0.29518652 2.90972543]
#  [1.91486359 0.53261018 0.06773686 0.60052872 0.30419016 2.91857767]
#  [1.91774511 0.52988386 0.06787825 0.59551692 0.30780721 2.9110353 ]
#  [1.90794778 0.52235913 0.06676269 0.60153675 0.29794216 2.91117287]
#  [1.90614891 0.53544688 0.06827378 0.58967137 0.2856307  2.90971541]
#  [1.90904284 0.5263381  0.06730652 0.60543489 0.31381226 2.91741967]
#  [1.89857268 0.5273006  0.04247093 0.59896994 0.30143285 2.9283092 ]
#  [1.90883493 0.52803278 0.06861782 0.6028049  0.30241156 2.91781449]
#  [1.90760803 0.52720475 0.06718707 0.60097384 0.32952285 2.93908548]
#  [1.90793562 0.52460265 0.06801605 0.59960985 0.2899971  2.9401021 ]
#  [1.91034222 0.53702903 0.06591368 0.60021162 0.29841781 2.91387534]
#  [1.90143394 0.53410721 0.06724906 0.60333085 0.31565261 2.93106079]
#  [1.90544367 0.52924418 0.06733274 0.59981537 0.29950213 2.93875122]
#  [1.91079521 0.53354836 0.06786013 0.59986496 0.30305743 2.92484021]
#  [1.90915966 0.53486896 0.06657243 0.60020304 0.30601287 2.94287729]
#  [1.90493321 0.52808452 0.06690311 0.59469509 0.29845023 2.93892717]
#  [1.90830898 0.53506589 0.06770444 0.59769511 0.29210877 2.93691969]]
# Time epoch:  [[ 1.         53.316113  ]
#  [ 2.         53.41226625]
#  [ 3.         53.63434768]
#  [ 4.         53.73032928]
#  [ 5.         53.72700596]
#  [ 6.         53.76467514]
#  [ 7.         53.82761407]
#  [ 8.         53.85618567]
#  [ 9.         53.94939947]
#  [10.         53.93382478]
#  [11.         53.88861251]
#  [12.         53.88462758]
#  [13.         53.92338061]
#  [14.         53.9100914 ]
#  [15.         53.89397073]
#  [16.         53.88452983]
#  [17.         53.87999463]
#  [18.         53.87740397]
#  [19.         53.86002016]
#  [20.         53.86129475]]
# Energy epoch:  [[power.draw [W]    4159.32
#   dtype: float64           ]
#  [power.draw [W]    4267.18
#   dtype: float64           ]
#  [power.draw [W]    4203.79
#   dtype: float64           ]
#  [power.draw [W]    4202.03
#   dtype: float64           ]
#  [power.draw [W]    4208.27
#   dtype: float64           ]
#  [power.draw [W]    4207.72
#   dtype: float64           ]
#  [power.draw [W]    4213.18
#   dtype: float64           ]
#  [power.draw [W]    4212.39
#   dtype: float64           ]
#  [power.draw [W]    4214.41
#   dtype: float64           ]
#  [power.draw [W]    4278.99
#   dtype: float64           ]
#  [power.draw [W]    4215.51
#   dtype: float64           ]
#  [power.draw [W]    4214.94
#   dtype: float64           ]
#  [power.draw [W]    4211.43
#   dtype: float64           ]
#  [power.draw [W]    4206.76
#   dtype: float64           ]
#  [power.draw [W]    4212.71
#   dtype: float64           ]
#  [power.draw [W]    4213.27
#   dtype: float64           ]
#  [power.draw [W]    4211.75
#   dtype: float64           ]
#  [power.draw [W]    4213.92
#   dtype: float64           ]
#  [power.draw [W]    4212.46
#   dtype: float64           ]
#  [power.draw [W]    4212.75
#   dtype: float64           ]]

# %% [markdown]
# #### test_acc

# %%
test_acc
# Out:
# array([0.8696, 0.8835, 0.8985, 0.9037, 0.9079, 0.9073, 0.9134, 0.9181,
#        0.9186, 0.9192, 0.9186, 0.9171, 0.9186, 0.9127, 0.9187, 0.919 ,
#        0.9169, 0.9221, 0.9206, 0.9153])

# %%
# plot test accuracy
plt.figure(figsize=(10, 5))
plt.plot(test_acc)
plt.xlabel('Epoch')
plt.ylabel('Test accuracy')
plt.title('Test accuracy')
plt.show()

# %% [markdown]
# #### train_acc

# %%
train_acc
# Out:
# array([[0.078125  , 0.0859375 , 0.10416667, ..., 0.7857334 , 0.78595753,
#         0.7861    ],
#        [0.9140625 , 0.86328125, 0.8671875 , ..., 0.8810894 , 0.88117655,
#         0.88123333],
#        [0.875     , 0.8671875 , 0.87239583, ..., 0.89798581, 0.89798678,
#         0.89803333],
#        ...,
#        [0.953125  , 0.95703125, 0.953125  , ..., 0.96430005, 0.96429287,
#         0.96431667],
#        [0.9609375 , 0.96484375, 0.97395833, ..., 0.9626606 , 0.96264022,
#         0.9626    ],
#        [0.9453125 , 0.94140625, 0.953125  , ..., 0.96657521, 0.96654647,
#         0.9665    ]])

# %%
# plot train accuracy of each epoch in one figure
plt.figure(figsize=(10, 5))
for i in range(len(train_acc)):
    plt.plot(train_acc[i])
plt.xlabel('batch number')
plt.ylabel('Train accuracy')
plt.title('Train accuracy')
plt.show()

# %%
# calculate average train accuracy of each epoch
train_acc_mean = []
for i in range(len(train_acc)):
    train_acc_mean.append(np.mean(train_acc[i]))
train_acc_mean

print(train_acc.shape)
# plot average train accuracy of each epoch
plt.figure(figsize=(10, 5))
plt.plot(np.arange(train_acc.shape[0]),train_acc_mean)
plt.xlabel('Epoch')
plt.ylabel('Average train accuracy')
plt.title('Average train accuracy of 10 epochs')
plt.show()
# Out:
# (20, 469)

# %% [markdown]
# #### train_loss

# %%
train_loss
# Out:
# array([[2.30522966, 2.93265128, 2.72545775, ..., 0.57018693, 0.56967219,
#         0.5693207 ],
#        [0.26748306, 0.38222803, 0.36656569, ..., 0.319637  , 0.31943918,
#         0.31929984],
#        [0.30226493, 0.32277453, 0.33872937, ..., 0.27296238, 0.27296434,
#         0.27283206],
#        ...,
#        [0.09188909, 0.09175788, 0.11833196, ..., 0.10071792, 0.10079162,
#         0.10076559],
#        [0.12185348, 0.11239269, 0.08301188, ..., 0.10616133, 0.10616612,
#         0.10627072],
#        [0.13560911, 0.14679348, 0.11629451, ..., 0.09167993, 0.09171589,
#         0.09181312]])

# %%
# plot train loss of each epoch in one figure
plt.figure(figsize=(10, 5))
for i in range(len(train_loss)):
    plt.plot(train_loss[i])
plt.xlabel('batch number')
plt.ylabel('Train loss')
plt.title('Train loss')
plt.show()

# %%
# calculate average train loss of each epoch
train_loss_mean = []
for i in range(len(train_loss)):
    train_loss_mean.append(np.mean(train_loss[i]))
train_loss_mean

# plot average train loss of each epoch
plt.figure(figsize=(10, 5))
plt.plot(train_loss_mean)
plt.xlabel('Epoch')
plt.ylabel('Average train loss')
plt.title('Average train loss of 10 epochs')
plt.show()

# %% [markdown]
# #### time_forward

# %%
time_forward
# Out:
# array([[0.43118405, 0.09790564, 0.04874754, 0.08265638, 0.04106379,
#         0.00896788],
#        [0.27787447, 0.09005117, 0.04867864, 0.08026171, 0.0373137 ,
#         0.00931835],
#        [0.26992869, 0.0875957 , 0.0470438 , 0.07996297, 0.03680992,
#         0.00927281],
#        [0.28863502, 0.09253216, 0.05104017, 0.08050323, 0.03708982,
#         0.00948715],
#        [0.2702148 , 0.08758473, 0.04783082, 0.08077788, 0.0369103 ,
#         0.00929165],
#        [0.27009749, 0.0865202 , 0.04741383, 0.07958007, 0.03696704,
#         0.00930524],
#        [0.26432252, 0.08522773, 0.04683423, 0.07988334, 0.03693771,
#         0.0091536 ],
#        [0.27195168, 0.08717895, 0.04793525, 0.08165646, 0.03731203,
#         0.00941253],
#        [0.26734233, 0.0851016 , 0.04715371, 0.08024979, 0.03709435,
#         0.00939631],
#        [0.26913381, 0.08484817, 0.04746318, 0.07986474, 0.03697371,
#         0.00901699],
#        [0.2684691 , 0.08543181, 0.04745507, 0.08026934, 0.0371182 ,
#         0.00928926],
#        [0.26781774, 0.08513832, 0.04741955, 0.08042526, 0.03704548,
#         0.00935841],
#        [0.26644945, 0.0852983 , 0.04686689, 0.07990837, 0.03668261,
#         0.00939703],
#        [0.27312732, 0.08817124, 0.04851484, 0.08064914, 0.0372107 ,
#         0.00935578],
#        [0.2722621 , 0.08672023, 0.04785037, 0.08062339, 0.03728127,
#         0.00936985],
#        [0.26968718, 0.08532572, 0.04778743, 0.08016682, 0.03701043,
#         0.00926661],
#        [0.27140951, 0.0871315 , 0.0482161 , 0.08023787, 0.03714919,
#         0.00940418],
#        [0.27257681, 0.08712006, 0.04779291, 0.08106518, 0.03688884,
#         0.00942516],
#        [0.26805067, 0.08644605, 0.04721427, 0.08041072, 0.03672528,
#         0.00923753],
#        [0.27301073, 0.08736849, 0.0477581 , 0.08026743, 0.0371666 ,
#         0.00949454]])

# %%
# plot time forward of each epoch in one figure
plt.figure(figsize=(10, 5))
for i in range(len(time_forward)):
    plt.plot(['Conv2d','ReLU','MaxPool2d','Linear','Dropout','Flatten'],time_forward[i])
plt.xlabel('layer number')
plt.ylabel('time')
plt.title('Time of each layer in forward')
plt.legend(['epoch1','epoch2','epoch3','epoch4','epoch5','epoch6','epoch7','epoch8','epoch9','epoch10'])
plt.show()

# %%
# calculate average time of each layer in forward for 10 epochs
time_forward_mean = np.mean(time_forward, axis=0)
print(time_forward_mean)
print(np.sum(time_forward_mean))

# plot average time of each layer in forward for 10 epochs
plt.figure(figsize=(10, 5))
plt.plot(['Conv2d','ReLU','MaxPool2d','Linear','Dropout','Flatten'],time_forward_mean)
plt.xlabel('layer number')
plt.ylabel('time')
plt.title('Average time of each layer in forward')
plt.show()
# Out:
# [0.27917727 0.08743489 0.04785084 0.080471   0.03723755 0.00931104]
# 0.5414825916290283

# %% [markdown]
# #### time_round

# %%
time_round
# Out:
# array([[1.92343235, 0.71052527, 0.0600276 , 0.72826648, 0.34584236,
#         2.87415218],
#        [1.93523598, 0.54349804, 0.0668335 , 0.60229659, 0.30693626,
#         2.86535501],
#        [1.92771816, 0.5306139 , 0.06757498, 0.60949421, 0.31488466,
#         2.88899827],
#        [1.94030166, 0.55928755, 0.06693077, 0.59849048, 0.29518652,
#         2.90972543],
#        [1.91486359, 0.53261018, 0.06773686, 0.60052872, 0.30419016,
#         2.91857767],
#        [1.91774511, 0.52988386, 0.06787825, 0.59551692, 0.30780721,
#         2.9110353 ],
#        [1.90794778, 0.52235913, 0.06676269, 0.60153675, 0.29794216,
#         2.91117287],
#        [1.90614891, 0.53544688, 0.06827378, 0.58967137, 0.2856307 ,
#         2.90971541],
#        [1.90904284, 0.5263381 , 0.06730652, 0.60543489, 0.31381226,
#         2.91741967],
#        [1.89857268, 0.5273006 , 0.04247093, 0.59896994, 0.30143285,
#         2.9283092 ],
#        [1.90883493, 0.52803278, 0.06861782, 0.6028049 , 0.30241156,
#         2.91781449],
#        [1.90760803, 0.52720475, 0.06718707, 0.60097384, 0.32952285,
#         2.93908548],
#        [1.90793562, 0.52460265, 0.06801605, 0.59960985, 0.2899971 ,
#         2.9401021 ],
#        [1.91034222, 0.53702903, 0.06591368, 0.60021162, 0.29841781,
#         2.91387534],
#        [1.90143394, 0.53410721, 0.06724906, 0.60333085, 0.31565261,
#         2.93106079],
#        [1.90544367, 0.52924418, 0.06733274, 0.59981537, 0.29950213,
#         2.93875122],
#        [1.91079521, 0.53354836, 0.06786013, 0.59986496, 0.30305743,
#         2.92484021],
#        [1.90915966, 0.53486896, 0.06657243, 0.60020304, 0.30601287,
#         2.94287729],
#        [1.90493321, 0.52808452, 0.06690311, 0.59469509, 0.29845023,
#         2.93892717],
#        [1.90830898, 0.53506589, 0.06770444, 0.59769511, 0.29210877,
#         2.93691969]])

# %%
# the column of time_round is time_to_device, time_forward, time_loss, time_backward, time_optimizer, time_test
# plot time of each step in one figure
plt.figure(figsize=(10, 5))
for i in range(len(time_round)):
    plt.plot(['time_to_device','time_forward','time_loss','time_backward','time_optimizer','time_test'],time_round[i])
plt.xlabel('step name')
plt.ylabel('time')
plt.title('Time of each step in round')
plt.legend(['epoch1','epoch2','epoch3','epoch4','epoch5','epoch6','epoch7','epoch8','epoch9','epoch10'])
plt.show()

# %%
# calculate average time of each step in round for 10 epochs
time_round_mean = np.mean(time_round, axis=0)
time_round_mean.shape
print(time_round_mean)
print(np.sum(time_round_mean))

# plot average time of each step in round for 10 epochs
plt.figure(figsize=(10, 5))
plt.plot(['time_to_device','time_forward','time_loss','time_backward','time_optimizer','time_test'],time_round_mean)
plt.xlabel('step name')
plt.ylabel('time/s')
plt.title('Average time of each step in round')
plt.show()
# Out:
# [1.91279023 0.54148259 0.06575762 0.60647055 0.30543993 2.91793574]
# 6.349876654148102

# %% [markdown]
# #### time_epoch

# %%
time_epoch
# Out:
# array([[ 1.        , 53.316113  ],
#        [ 2.        , 53.41226625],
#        [ 3.        , 53.63434768],
#        [ 4.        , 53.73032928],
#        [ 5.        , 53.72700596],
#        [ 6.        , 53.76467514],
#        [ 7.        , 53.82761407],
#        [ 8.        , 53.85618567],
#        [ 9.        , 53.94939947],
#        [10.        , 53.93382478],
#        [11.        , 53.88861251],
#        [12.        , 53.88462758],
#        [13.        , 53.92338061],
#        [14.        , 53.9100914 ],
#        [15.        , 53.89397073],
#        [16.        , 53.88452983],
#        [17.        , 53.87999463],
#        [18.        , 53.87740397],
#        [19.        , 53.86002016],
#        [20.        , 53.86129475]])

# %%
# plot time of each epoch in one figure
plt.figure(figsize=(10, 5))
plt.plot(time_epoch[:, 1])
plt.xlabel('Epoch')
plt.ylabel('Time')
plt.title('Time of each epoch')
plt.show()

# %% [markdown]
# #### combined plot

# %%
# plot the time_epoch, the y axis set to left, and the value between 49 and 49.6, using bar chart
# plot the test_acc, train_loss_mean, train_acc_mean, the y axis set to right, using line chart
fig, ax1 = plt.subplots(figsize=(10, 5))
ax1.bar(np.arange(20), time_epoch[:, 1], color='lightblue')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Time/s', color='b')
ax1.tick_params('y', colors='b')
ax1.set_ylim([52, 54])
ax2 = ax1.twinx()
ax2.plot(test_acc, color='r')
ax2.plot(train_loss_mean, color='g')
ax2.plot(train_acc_mean, color='y')
ax2.set_ylabel('Accuracy and Loss', color='r')
ax2.tick_params('y', colors='r')
ax2.set_ylim([0, 1])
plt.title('Time and Accuracy/Loss of each epoch')
plt.legend(['Test accuracy','Train loss','Train accuracy'])
plt.show()

# %% [markdown]
# #### energy_epoch

# %%
energy_epoch.shape
# change energy_epoch to float
energy_epoch_f = energy_epoch.astype(float)
energy_epoch_f = energy_epoch_f.reshape(1,20)
energy_epoch_f.shape
energy_epoch_f = energy_epoch_f[0]
print(energy_epoch_f)

print(min(energy_epoch_f))
print(max(energy_epoch_f))
# Out:
# [4159.32 4267.18 4203.79 4202.03 4208.27 4207.72 4213.18 4212.39 4214.41
#  4278.99 4215.51 4214.94 4211.43 4206.76 4212.71 4213.27 4211.75 4213.92
#  4212.46 4212.75]
# 4159.32
# 4278.990000000001
# /tmp/ipykernel_85077/2475744048.py:3: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   energy_epoch_f = energy_epoch.astype(float)

# %%
print(energy_epoch_f.shape)
# Out:
# (20,)

# %%
energy_mean = np.mean(energy_epoch_f)
energy_mean
# Out:
# 4214.639

# %%
# plot the energy_epoch using bar chart, set the y axis value between 3845 to 3944
plt.figure(figsize=(10, 5))
plt.bar(np.arange(energy_epoch_f.shape[0]), energy_epoch_f)
plt.xlabel('Epoch')
plt.ylabel('Energy')
plt.title('Energy of each epoch')
plt.ylim([4000, 4400])
plt.show()

# %%
# plot the energy_epoch, the y axis set to right, and the value between 3845 to 3944, using line chart
# plot the time_epoch, the y axis set to left, and the value between 49 and 49.6, using bar chart
fig, ax1 = plt.subplots(figsize=(10, 5))
ax1.plot(energy_epoch_f, color='b')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Energy/J', color='b')
ax1.tick_params('y', colors='b')
ax1.set_ylim([4000, 4300])
ax2 = ax1.twinx()
ax2.bar(np.arange(20), time_epoch[:, 1], color= '#FF6666')
ax2.set_ylabel('Time', color='r')
ax2.tick_params('y', colors='r')
ax2.set_ylim([52, 54])
plt.title('Energy and Time of each epoch')
plt.legend(['Energy','Time'])
plt.show()

# %%
# plot the energy_epoch, the y axis set to right, and the value between 3845 to 3944, using bar chart
# plot the test_acc, train_loss_mean, train_acc_mean, the y axis set to left, and the value between 0.6 to 0.95, using line chart
fig, ax1 = plt.subplots(figsize=(10, 5))
ax1.bar(np.arange(20), energy_epoch_f, color='b')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Energy/J', color='b')
ax1.tick_params('y', colors='b')
ax1.set_ylim([4100, 4290])
ax2 = ax1.twinx()
ax2.plot(test_acc, color='r')
ax2.plot(train_loss_mean, color='g')
ax2.plot(train_acc_mean, color='y')
ax2.set_ylabel('Accuracy and Loss', color='r')
ax2.tick_params('y', colors='r')
ax2.set_ylim([0, 1])
plt.title('Energy and Accuracy/Loss of each epoch')
plt.legend(['Test accuracy','Train loss','Train accuracy'])
plt.show()
